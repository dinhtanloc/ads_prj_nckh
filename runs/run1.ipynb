# %%
import argparse,sys
parser = argparse.ArgumentParser(prog='maincode',description='Fraud Detections')

args, unknown= parser.parse_known_args()

# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
# Out:
# d:\ads_test

# %%
sys.argv=['sdhakjfhak','6','../data/insurance_claims.csv','../exps']

# %%
prj_root = '../prj'

# %%
# %run $prj_root/1.EDA/EDA2.ipynb
# Out:
# d:\ads_test\prj
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
# %run $prj_root/2.pre-processing/pre-processing_test_6.ipynb
# Out:
# d:\ads_test\prj
# (670, 43) (330, 43)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_27120\2765144672.py:1
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 x_train, y_train = SMOTE().fit_resample(x_train, y_train)
#       3 x_train.to_excel(f'{exps_dir}/Standard_Label/SMOTE/feature/x_train.xlsx', index=False)
#
# ModuleNotFoundError: No module named 'imblearn'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 get_ipython().run_line_magic('run', '$prj_root/2.pre-processing/pre-processing_test_6.ipynb')
#
# File d:\ads_test\.conda\lib\site-packages\IPython\core\interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
# ...

# %%
# %run $prj_root/4.model/traditional_model.ipynb
# Out:
# Accuracy LR: 75.152% (2.462%)
# Accuracy LDA: 77.273% (4.391%)
# Accuracy DTC: 76.667% (4.753%)
# Accuracy RD: 75.758% (2.535%)
# Accuracy KNC: 73.333% (4.556%)
# Accuracy NB: 66.364% (2.424%)
# Accuracy SVM: 74.545% (4.830%)
# Accuracy NN: 74.242% (4.177%)
# Accuracy BG: 74.848% (3.120%)
# Precision LR: 62.300% (20.534%)
# Precision LDA: 68.131% (18.536%)
# Precision DTC: 55.630% (12.110%)
# Precision RD: 56.488% (10.715%)
# Precision KNC: 0.000% (0.000%)
# Precision NB: 41.328% (7.937%)
# Precision SVM: 62.540% (36.866%)
# Precision NN: 52.706% (14.017%)
# Precision BG: 53.247% (6.402%)
# Recall LR: 32.359% (6.401%)
# Recall LDA: 35.769% (10.744%)
# Recall DTC: 52.897% (6.464%)
# Recall RD: 40.897% (5.537%)
# Recall KNC: 0.000% (0.000%)
# Recall NB: 54.308% (8.251%)
# Recall SVM: 14.026% (13.893%)
# Recall NN: 47.436% (11.043%)
# Recall BG: 44.359% (10.345%)
# F1 LR: 40.209% (4.047%)
# F1 LDA: 44.753% (7.666%)
# F1 DTC: 56.475% (12.573%)
# F1 RD: 46.889% (5.667%)
# ...

# %%
# %run $prj_root/4.model/VGG16/maincode_VGG16_basis_test_tabnie.ipynb
# Out:
# d:\ads_test\prj
# 2.13.0
# Standard_Label: basic
# (656, 42) (656, 2) (324, 42) (324, 2)
# Standard_Label: class_dict_weight
# (656, 42) (656, 2) (324, 42) (324, 2)
# Standard_Label: Oversampling
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# Standard_Label: SMOTE
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# Standard_Label: Undersampling
# (355, 42) (355, 2) (324, 42) (324, 2)
# MinMax_Label: basic
# (656, 42) (656, 2) (324, 42) (324, 2)
# MinMax_Label: class_dict_weight
# (656, 42) (656, 2) (324, 42) (324, 2)
# MinMax_Label: Oversampling
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# MinMax_Label: SMOTE
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# MinMax_Label: Undersampling
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10
# Best SVM Hyperparameters:
# {'C': 3.1049410210968498, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Random Forest Hyperparameters:
# {'n_estimators': 500, 'max_depth': 10}
# Best Gradient Boosting Hyperparameters:
# ...
