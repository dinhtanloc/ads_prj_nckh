# %% [markdown]
# - ID: ID duy nhất cho mỗi hồ sơ.
# - KIDSDRIV: Số lượng trẻ em lái xe.
# - BIRTH: Ngày sinh của người đóng bảo hiểm.
# - AGE: Tuổi của người đóng bảo hiểm.
# - HOMEKIDS: Số lượng trẻ em ở nhà.
# - YOJ: Số năm kinh nghiệm lái xe của người đóng bảo hiểm.
# - INCOME: Thu nhập của người đóng bảo hiểm.
# - PARENT1: Biến đánh dấu liệu người đóng bảo hiểm có là phụ huynh không.
# - HOME_VAL: Giá trị nhà của người đóng bảo hiểm.
# - MSTATUS: Tình trạng hôn nhân.
# - GENDER: Giới tính của người đóng bảo hiểm.
# - EDUCATION: Trình độ học vấn của người đóng bảo hiểm.
# - OCCUPATION: Nghề nghiệp của người đóng bảo hiểm.
# - TRAVTIME: Thời gian di chuyển hàng ngày.
# - CAR_USE: Mục đích sử dụng xe hơi.
# - BLUEBOOK: Giá trị xe hơi.
# - TIF: Thời gian sử dụng bảo hiểm.
# - CAR_TYPE: Loại xe hơi.
# - RED_CAR: Biến đánh dấu liệu có sử dụng xe màu đỏ không.
# - OLDCLAIM: Số tiền đền bù từ các yêu cầu trước đây.
# - CLM_FREQ: Số lần yêu cầu bồi thường trước đó.
# - REVOKED: Biến đánh dấu liệu đã thu hồi bằng lái xe chưa.
# - MVR_PTS: Điểm trên lệnh vi phạm giao thông.
# - CLM_AMT: Số tiền đã yêu cầu bồi thường.
# - CAR_AGE: Tuổi của xe hơi.
# - CLAIM_FLAG: Biến đánh dấu liệu có yêu cầu bồi thường không.
# - URBANICITY: Đô thị hoặc nông thôn.
# Đô thị hoặc nông thôn.

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/prj/EDA/.ipynb_checkpoints/car_insurance_claim.csv")

# %%
data
# Out:
#               ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 0       63581743         0  16MAR39  60.0         0  11.0   $67,349      No
# 1      132761049         0  21JAN56  43.0         0  11.0   $91,449      No
# 2      921317019         0  18NOV51  48.0         0  11.0   $52,881      No
# 3      727598473         0  05MAR64  35.0         1  10.0   $16,039      No
# 4      450221861         0  05JUN48  51.0         0  14.0       NaN      No
# ...          ...       ...      ...   ...       ...   ...       ...     ...
# 10297   67790126         1  13AUG54  45.0         2   9.0  $164,669      No
# 10298   61970712         0  17JUN53  46.0         0   9.0  $107,204      No
# 10299  849208064         0  18JUN51  48.0         0  15.0   $39,837      No
# 10300  627828331         0  12DEC48  50.0         0   7.0   $43,445      No
# 10301  680381960         0  27FEB47  52.0         0  11.0   $53,235      No
#
#        HOME_VAL MSTATUS  ...     CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED  \
# 0            $0    z_No  ...      Minivan     yes   $4,461         2      No
# 1      $257,252    z_No  ...      Minivan     yes       $0         0      No
# 2            $0    z_No  ...          Van     yes       $0         0      No
# 3      $124,191     Yes  ...        z_SUV      no  $38,690         2      No
# 4      $306,251     Yes  ...      Minivan     yes       $0         0      No
# ...         ...     ...  ...          ...     ...      ...       ...     ...
# 10297  $386,273     Yes  ...      Minivan      no       $0         0      No
# 10298  $332,591     Yes  ...  Panel Truck      no       $0         0      No
# 10299  $170,611     Yes  ...        z_SUV      no       $0         0      No
# 10300  $149,248     Yes  ...      Minivan      no       $0         0      No
# 10301  $197,017     Yes  ...      Minivan      no       $0         0      No
#
#       MVR_PTS  CLM_AMT CAR_AGE CLAIM_FLAG             URBANICITY
# 0           3       $0    18.0          0    Highly Urban/ Urban
# 1           0       $0     1.0          0    Highly Urban/ Urban
# 2           2       $0    10.0          0    Highly Urban/ Urban
# 3           3       $0    10.0          0    Highly Urban/ Urban
# 4           0       $0     6.0          0    Highly Urban/ Urban
# ...       ...      ...     ...        ...                    ...
# 10297       2       $0    17.0          0    Highly Urban/ Urban
# 10298       0       $0     1.0          0    Highly Urban/ Urban
# 10299       0       $0     1.0          0    Highly Urban/ Urban
# 10300       0       $0    11.0          0    Highly Urban/ Urban
# 10301       0       $0     9.0          0  z_Highly Rural/ Rural
#
# [10302 rows x 27 columns]

# %%
data.describe()
# Out:
#                  ID      KIDSDRIV           AGE      HOMEKIDS          YOJ  \
# count  1.030200e+04  10302.000000  10295.000000  10302.000000  9754.000000
# mean   4.956631e+08      0.169288     44.837397      0.720443    10.474062
# std    2.864675e+08      0.506512      8.606445      1.116323     4.108943
# min    6.317500e+04      0.000000     16.000000      0.000000     0.000000
# 25%    2.442869e+08      0.000000     39.000000      0.000000     9.000000
# 50%    4.970043e+08      0.000000     45.000000      0.000000    11.000000
# 75%    7.394551e+08      0.000000     51.000000      1.000000    13.000000
# max    9.999264e+08      4.000000     81.000000      5.000000    23.000000
#
#            TRAVTIME           TIF      CLM_FREQ       MVR_PTS      CAR_AGE  \
# count  10302.000000  10302.000000  10302.000000  10302.000000  9663.000000
# mean      33.416424      5.329159      0.800718      1.710153     8.298148
# std       15.869687      4.110795      1.154079      2.159015     5.714450
# min        5.000000      1.000000      0.000000      0.000000    -3.000000
# 25%       22.000000      1.000000      0.000000      0.000000     1.000000
# 50%       33.000000      4.000000      0.000000      1.000000     8.000000
# 75%       44.000000      7.000000      2.000000      3.000000    12.000000
# max      142.000000     25.000000      5.000000     13.000000    28.000000
#
#          CLAIM_FLAG
# count  10302.000000
# mean       0.266550
# std        0.442177
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10302 non-null  int64
#  1   KIDSDRIV    10302 non-null  int64
#  2   BIRTH       10302 non-null  object
#  3   AGE         10295 non-null  float64
#  4   HOMEKIDS    10302 non-null  int64
#  5   YOJ         9754 non-null   float64
#  6   INCOME      9732 non-null   object
#  7   PARENT1     10302 non-null  object
#  8   HOME_VAL    9727 non-null   object
#  9   MSTATUS     10302 non-null  object
#  10  GENDER      10302 non-null  object
#  11  EDUCATION   10302 non-null  object
#  12  OCCUPATION  9637 non-null   object
#  13  TRAVTIME    10302 non-null  int64
#  14  CAR_USE     10302 non-null  object
#  15  BLUEBOOK    10302 non-null  object
#  16  TIF         10302 non-null  int64
#  17  CAR_TYPE    10302 non-null  object
#  18  RED_CAR     10302 non-null  object
#  19  OLDCLAIM    10302 non-null  object
#  20  CLM_FREQ    10302 non-null  int64
#  21  REVOKED     10302 non-null  object
#  22  MVR_PTS     10302 non-null  int64
#  23  CLM_AMT     10302 non-null  object
#  24  CAR_AGE     9663 non-null   float64
#  25  CLAIM_FLAG  10302 non-null  int64
#  26  URBANICITY  10302 non-null  object
# dtypes: float64(3), int64(8), object(16)
# memory usage: 2.1+ MB

# %%
data.head()
# Out:
#           ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ   INCOME PARENT1  \
# 0   63581743         0  16MAR39  60.0         0  11.0  $67,349      No
# 1  132761049         0  21JAN56  43.0         0  11.0  $91,449      No
# 2  921317019         0  18NOV51  48.0         0  11.0  $52,881      No
# 3  727598473         0  05MAR64  35.0         1  10.0  $16,039      No
# 4  450221861         0  05JUN48  51.0         0  14.0      NaN      No
#
#    HOME_VAL MSTATUS  ... CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED MVR_PTS  \
# 0        $0    z_No  ...  Minivan     yes   $4,461         2      No       3
# 1  $257,252    z_No  ...  Minivan     yes       $0         0      No       0
# 2        $0    z_No  ...      Van     yes       $0         0      No       2
# 3  $124,191     Yes  ...    z_SUV      no  $38,690         2      No       3
# 4  $306,251     Yes  ...  Minivan     yes       $0         0      No       0
#
#    CLM_AMT CAR_AGE CLAIM_FLAG           URBANICITY
# 0       $0    18.0          0  Highly Urban/ Urban
# 1       $0     1.0          0  Highly Urban/ Urban
# 2       $0    10.0          0  Highly Urban/ Urban
# 3       $0    10.0          0  Highly Urban/ Urban
# 4       $0     6.0          0  Highly Urban/ Urban
#
# [5 rows x 27 columns]

# %%
data.tail()
# Out:
#               ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 10297   67790126         1  13AUG54  45.0         2   9.0  $164,669      No
# 10298   61970712         0  17JUN53  46.0         0   9.0  $107,204      No
# 10299  849208064         0  18JUN51  48.0         0  15.0   $39,837      No
# 10300  627828331         0  12DEC48  50.0         0   7.0   $43,445      No
# 10301  680381960         0  27FEB47  52.0         0  11.0   $53,235      No
#
#        HOME_VAL MSTATUS  ...     CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED  \
# 10297  $386,273     Yes  ...      Minivan      no       $0         0      No
# 10298  $332,591     Yes  ...  Panel Truck      no       $0         0      No
# 10299  $170,611     Yes  ...        z_SUV      no       $0         0      No
# 10300  $149,248     Yes  ...      Minivan      no       $0         0      No
# 10301  $197,017     Yes  ...      Minivan      no       $0         0      No
#
#       MVR_PTS  CLM_AMT CAR_AGE CLAIM_FLAG             URBANICITY
# 10297       2       $0    17.0          0    Highly Urban/ Urban
# 10298       0       $0     1.0          0    Highly Urban/ Urban
# 10299       0       $0     1.0          0    Highly Urban/ Urban
# 10300       0       $0    11.0          0    Highly Urban/ Urban
# 10301       0       $0     9.0          0  z_Highly Rural/ Rural
#
# [5 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['ID', 'KIDSDRIV', 'BIRTH', 'AGE', 'HOMEKIDS', 'YOJ', 'INCOME',
#        'PARENT1', 'HOME_VAL', 'MSTATUS', 'GENDER', 'EDUCATION', 'OCCUPATION',
#        'TRAVTIME', 'CAR_USE', 'BLUEBOOK', 'TIF', 'CAR_TYPE', 'RED_CAR',
#        'OLDCLAIM', 'CLM_FREQ', 'REVOKED', 'MVR_PTS', 'CLM_AMT', 'CAR_AGE',
#        'CLAIM_FLAG', 'URBANICITY'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ID              0
# KIDSDRIV        0
# BIRTH           0
# AGE             7
# HOMEKIDS        0
# YOJ           548
# INCOME        570
# PARENT1         0
# HOME_VAL      575
# MSTATUS         0
# GENDER          0
# EDUCATION       0
# OCCUPATION    665
# TRAVTIME        0
# CAR_USE         0
# BLUEBOOK        0
# TIF             0
# CAR_TYPE        0
# RED_CAR         0
# OLDCLAIM        0
# CLM_FREQ        0
# REVOKED         0
# MVR_PTS         0
# CLM_AMT         0
# CAR_AGE       639
# CLAIM_FLAG      0
# URBANICITY      0
# dtype: int64

# %% [markdown]
# **Qua kiểm tra, ta dễ dàng nhận ra có 5 cột bị khuyết thiếu dữ liệu là cột "YOJ","INCOME","HOME_VAL","OCCUPATION","CAR_AGE".**

# %%
data.dtypes
# Out:
# ID              int64
# KIDSDRIV        int64
# BIRTH          object
# AGE           float64
# HOMEKIDS        int64
# YOJ           float64
# INCOME         object
# PARENT1        object
# HOME_VAL       object
# MSTATUS        object
# GENDER         object
# EDUCATION      object
# OCCUPATION     object
# TRAVTIME        int64
# CAR_USE        object
# BLUEBOOK       object
# TIF             int64
# CAR_TYPE       object
# RED_CAR        object
# OLDCLAIM       object
# CLM_FREQ        int64
# REVOKED        object
# MVR_PTS         int64
# CLM_AMT        object
# CAR_AGE       float64
# CLAIM_FLAG      int64
# URBANICITY     object
# dtype: object

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10297    False
# 10298    False
# 10299    False
# 10300    False
# 10301    False
# Length: 10302, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 1

# %% [markdown]
# **Nhóm phát hiện có một dòng trùng dữ liệu.**

# %%
data_duplicated = data[data.duplicated()]
data_duplicated
# Out:
#              ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ   INCOME PARENT1  \
# 9801  279799481         0  21FEB60  39.0         0  14.0  $93,077      No
#
#       HOME_VAL MSTATUS  ... CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED  \
# 9801  $244,764     Yes  ...  Minivan     yes       $0         0      No
#
#      MVR_PTS  CLM_AMT CAR_AGE CLAIM_FLAG             URBANICITY
# 9801       0       $0     1.0          0  z_Highly Rural/ Rural
#
# [1 rows x 27 columns]

# %% [markdown]
# **Dòng đầu tiên của cột 27 có dữ liệu bị trùng.**

# %%
object_columns = list(data.select_dtypes(['object']).columns)
len(object_columns)
numeric_columns = list(data.select_dtypes(['number']).columns)
len(numeric_columns)
print(f"Biến phân loại : {len(object_columns)}, Biến liên tục : {len(numeric_columns)}")
# Out:
# Biến phân loại : 16, Biến liên tục : 11

# %%
data[object_columns].describe()
# Out:
#           BIRTH INCOME PARENT1 HOME_VAL MSTATUS GENDER      EDUCATION  \
# count     10302   9732   10302     9727   10302  10302          10302
# unique     6560   8151       2     6334       2      2              5
# top     20OCT60     $0      No       $0     Yes    z_F  z_High School
# freq          8    797    8959     2908    6188   5545           2952
#
#            OCCUPATION  CAR_USE BLUEBOOK CAR_TYPE RED_CAR OLDCLAIM REVOKED  \
# count            9637    10302    10302    10302   10302    10302   10302
# unique              8        2     2985        6       2     3545       2
# top     z_Blue Collar  Private   $1,500    z_SUV      no       $0      No
# freq             2288     6513      207     2883    7326     6292    9041
#
#        CLM_AMT           URBANICITY
# count    10302                10302
# unique    2346                    2
# top         $0  Highly Urban/ Urban
# freq      7556                 8230

# %%
data[numeric_columns].describe()
# Out:
#                  ID      KIDSDRIV           AGE      HOMEKIDS          YOJ  \
# count  1.030200e+04  10302.000000  10295.000000  10302.000000  9754.000000
# mean   4.956631e+08      0.169288     44.837397      0.720443    10.474062
# std    2.864675e+08      0.506512      8.606445      1.116323     4.108943
# min    6.317500e+04      0.000000     16.000000      0.000000     0.000000
# 25%    2.442869e+08      0.000000     39.000000      0.000000     9.000000
# 50%    4.970043e+08      0.000000     45.000000      0.000000    11.000000
# 75%    7.394551e+08      0.000000     51.000000      1.000000    13.000000
# max    9.999264e+08      4.000000     81.000000      5.000000    23.000000
#
#            TRAVTIME           TIF      CLM_FREQ       MVR_PTS      CAR_AGE  \
# count  10302.000000  10302.000000  10302.000000  10302.000000  9663.000000
# mean      33.416424      5.329159      0.800718      1.710153     8.298148
# std       15.869687      4.110795      1.154079      2.159015     5.714450
# min        5.000000      1.000000      0.000000      0.000000    -3.000000
# 25%       22.000000      1.000000      0.000000      0.000000     1.000000
# 50%       33.000000      4.000000      0.000000      1.000000     8.000000
# 75%       44.000000      7.000000      2.000000      3.000000    12.000000
# max      142.000000     25.000000      5.000000     13.000000    28.000000
#
#          CLAIM_FLAG
# count  10302.000000
# mean       0.266550
# std        0.442177
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
for column in object_columns : 
    print("\033[1m","*,Column : ", column,"\033[0m")
    print('\t',len(data[column].unique()),"unique values","\t & \t",
        data[column].notnull().sum(), "non-null values\t",
        round(100* data[column].notnull().sum()/len(data[column]),2),
        "% non-null")
    if len (data[column].unique())<=10 :
        print('\t',data[column].unique())
# Out:
#  *,Column :  BIRTH
# 	 6560 unique values 	 & 	 10302 non-null values	 100.0 % non-null
#  *,Column :  INCOME
# 	 8152 unique values 	 & 	 9732 non-null values	 94.47 % non-null
#  *,Column :  PARENT1
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['No' 'Yes']
#  *,Column :  HOME_VAL
# 	 6335 unique values 	 & 	 9727 non-null values	 94.42 % non-null
#  *,Column :  MSTATUS
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['z_No' 'Yes']
#  *,Column :  GENDER
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['M' 'z_F']
#  *,Column :  EDUCATION
# 	 5 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['PhD' 'z_High School' 'Bachelors' '<High School' 'Masters']
#  *,Column :  OCCUPATION
# 	 9 unique values 	 & 	 9637 non-null values	 93.54 % non-null
# 	 ['Professional' 'z_Blue Collar' 'Manager' 'Clerical' 'Doctor' 'Lawyer' nan
#  'Home Maker' 'Student']
#  *,Column :  CAR_USE
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['Private' 'Commercial']
#  *,Column :  BLUEBOOK
# 	 2985 unique values 	 & 	 10302 non-null values	 100.0 % non-null
#  *,Column :  CAR_TYPE
# 	 6 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['Minivan' 'Van' 'z_SUV' 'Sports Car' 'Panel Truck' 'Pickup']
#  *,Column :  RED_CAR
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['yes' 'no']
#  *,Column :  OLDCLAIM
# 	 3545 unique values 	 & 	 10302 non-null values	 100.0 % non-null
#  *,Column :  REVOKED
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['No' 'Yes']
#  *,Column :  CLM_AMT
# 	 2346 unique values 	 & 	 10302 non-null values	 100.0 % non-null
#  *,Column :  URBANICITY
# 	 2 unique values 	 & 	 10302 non-null values	 100.0 % non-null
# 	 ['Highly Urban/ Urban' 'z_Highly Rural/ Rural']

# %% [markdown]
# KẾT LUẬN
# - Dựa vào thống kê các biến mang tính duy nhất ở cột phân loại, chúng ta thấy có 1 cột mang tính chất phân loại có tác dụng như mã số, mỗi dòng là một số cột khác nhau => Không quá quan trọng trong bộ dữ liệu nên ta có thể bỏ nó.
# - Ngoài ra, ta có thể quan sát thấy các dòng có ký tự đặc biệt "$" tượng trưng cho ký hiệu tiền tệ USD ở các cột "Income","Home_Val","BlueBook","Oldclaim" không phù hợp với mô hình dự đoán, ta biến đổi những biến này sang biến liên tục.
# - Cuối cùng, một số cột có dữ liệu bị bỏ trống.

# %%
for column in object_columns :
    if len(data[column].unique())<=10:
        print("-"*100)
        print("*,Column: ",column)
        print(data[column].value_counts())
        print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# *,Column:  PARENT1
# PARENT1
# No     8959
# Yes    1343
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  MSTATUS
# MSTATUS
# Yes     6188
# z_No    4114
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  GENDER
# GENDER
# z_F    5545
# M      4757
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  EDUCATION
# EDUCATION
# z_High School    2952
# Bachelors        2823
# Masters          2078
# <High School     1515
# PhD               934
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  OCCUPATION
# OCCUPATION
# z_Blue Collar    2288
# Clerical         1590
# Professional     1408
# Manager          1257
# Lawyer           1031
# Student           899
# Home Maker        843
# Doctor            321
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  CAR_USE
# CAR_USE
# Private       6513
# Commercial    3789
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  CAR_TYPE
# CAR_TYPE
# z_SUV          2883
# Minivan        2694
# Pickup         1772
# Sports Car     1179
# Van             921
# Panel Truck     853
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  RED_CAR
# RED_CAR
# no     7326
# yes    2976
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  REVOKED
# REVOKED
# No     9041
# Yes    1261
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# *,Column:  URBANICITY
# URBANICITY
# Highly Urban/ Urban      8230
# z_Highly Rural/ Rural    2072
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_columns
# Out:
# ['ID',
#  'KIDSDRIV',
#  'AGE',
#  'HOMEKIDS',
#  'YOJ',
#  'TRAVTIME',
#  'TIF',
#  'CLM_FREQ',
#  'MVR_PTS',
#  'CAR_AGE',
#  'CLAIM_FLAG']

# %%
for column in numeric_columns : 
    print("*, Column: ",column)
    print(len(data[column].unique()), "unique values","\t & \t",
        data[column].notnull().sum(), "non-null values\t",
        round(100* data[column].notnull().sum()/len(data[column]),2),
        "% nono-null")
    if len(data[column].unique())<=10:
        print(data[column].unique())
# Out:
# *, Column:  ID
# 8753 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# *, Column:  KIDSDRIV
# 5 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# [0 1 2 3 4]
# *, Column:  AGE
# 62 unique values 	 & 	 10295 non-null values	 99.93 % nono-null
# *, Column:  HOMEKIDS
# 6 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# [0 1 2 3 4 5]
# *, Column:  YOJ
# 22 unique values 	 & 	 9754 non-null values	 94.68 % nono-null
# *, Column:  TRAVTIME
# 100 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# *, Column:  TIF
# 23 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# *, Column:  CLM_FREQ
# 6 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# [2 0 1 3 5 4]
# *, Column:  MVR_PTS
# 14 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# *, Column:  CAR_AGE
# 31 unique values 	 & 	 9663 non-null values	 93.8 % nono-null
# *, Column:  CLAIM_FLAG
# 2 unique values 	 & 	 10302 non-null values	 100.0 % nono-null
# [0 1]

# %% [markdown]
# KẾT LUẬN
# - Dù là kiểu dữ liệu số, nhưng một số cột thuộc kiểu dữ liệu rời rạc chứ không phải kiểu số liệu liên tục ( KIDSRIV, CLM_FREQ, CLAIM_FLAG,...) mang vai trò như một phân lớp. Chúng ta sẽ chuyển cột dữ liệu này sang kiểu dữ liệu mang tính phân loại để tăng hiệu suất dự án !
# - Các biến rời rạc nhưng chiếm khá nhiều giá trị như tuổi nhóm sẽ xem xét chuyển sang cột phân loại như Young, Middle, Old để máy học tốt hơn.

# %%
change_tocategory = [i for i in numeric_columns if len(data[i].unique())<=16]
change_tocategory
# Out:
# ['KIDSDRIV', 'HOMEKIDS', 'CLM_FREQ', 'MVR_PTS', 'CLAIM_FLAG']

# %%
data[change_tocategory] = data[change_tocategory].astype('object')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10302 non-null  int64
#  1   KIDSDRIV    10302 non-null  object
#  2   BIRTH       10302 non-null  object
#  3   AGE         10295 non-null  float64
#  4   HOMEKIDS    10302 non-null  object
#  5   YOJ         9754 non-null   float64
#  6   INCOME      9732 non-null   object
#  7   PARENT1     10302 non-null  object
#  8   HOME_VAL    9727 non-null   object
#  9   MSTATUS     10302 non-null  object
#  10  GENDER      10302 non-null  object
#  11  EDUCATION   10302 non-null  object
#  12  OCCUPATION  9637 non-null   object
#  13  TRAVTIME    10302 non-null  int64
#  14  CAR_USE     10302 non-null  object
#  15  BLUEBOOK    10302 non-null  object
#  16  TIF         10302 non-null  int64
#  17  CAR_TYPE    10302 non-null  object
#  18  RED_CAR     10302 non-null  object
#  19  OLDCLAIM    10302 non-null  object
#  20  CLM_FREQ    10302 non-null  object
#  21  REVOKED     10302 non-null  object
#  22  MVR_PTS     10302 non-null  object
#  23  CLM_AMT     10302 non-null  object
#  24  CAR_AGE     9663 non-null   float64
#  25  CLAIM_FLAG  10302 non-null  object
#  26  URBANICITY  10302 non-null  object
# dtypes: float64(3), int64(3), object(21)
# memory usage: 2.1+ MB

# %%
# Hàm chuyển đổi giá trị tiền tệ
def convert_money(x):
    if isinstance(x, str):
        # Loại bỏ dấu "$" và dấu phẩy từ chuỗi và chuyển đổi thành số
        return float(x.replace("$", "").replace(",", ""))
    elif isinstance(x, (int, float)):
        # Trả về giá trị ban đầu nếu đã là số
        return x
    else:
        # Trả về NaN cho các giá trị không phải là số hoặc NaN
        return np.nan

# %%
data['INCOME' + '_converted'] = data['INCOME'].apply(convert_money)
data['HOME_VAL' + '_converted'] = data['HOME_VAL'].apply(convert_money)
data['OLDCLAIM' + '_converted'] = data['OLDCLAIM'].apply(convert_money)
data['CLM_AMT' + '_converted'] = data['CLM_AMT'].apply(convert_money)

data['BLUEBOOK' + '_converted'] = data['BLUEBOOK'].apply(convert_money)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  10302 non-null  int64
#  1   KIDSDRIV            10302 non-null  object
#  2   BIRTH               10302 non-null  object
#  3   AGE                 10295 non-null  float64
#  4   HOMEKIDS            10302 non-null  object
#  5   YOJ                 9754 non-null   float64
#  6   INCOME              9732 non-null   object
#  7   PARENT1             10302 non-null  object
#  8   HOME_VAL            9727 non-null   object
#  9   MSTATUS             10302 non-null  object
#  10  GENDER              10302 non-null  object
#  11  EDUCATION           10302 non-null  object
#  12  OCCUPATION          9637 non-null   object
#  13  TRAVTIME            10302 non-null  int64
#  14  CAR_USE             10302 non-null  object
#  15  BLUEBOOK            10302 non-null  object
#  16  TIF                 10302 non-null  int64
#  17  CAR_TYPE            10302 non-null  object
#  18  RED_CAR             10302 non-null  object
#  19  OLDCLAIM            10302 non-null  object
#  20  CLM_FREQ            10302 non-null  object
#  21  REVOKED             10302 non-null  object
#  22  MVR_PTS             10302 non-null  object
#  23  CLM_AMT             10302 non-null  object
#  24  CAR_AGE             9663 non-null   float64
#  25  CLAIM_FLAG          10302 non-null  object
#  26  URBANICITY          10302 non-null  object
#  27  INCOME_converted    9732 non-null   float64
#  28  HOME_VAL_converted  9727 non-null   float64
#  29  OLDCLAIM_converted  10302 non-null  float64
#  30  CLM_AMT_converted   10302 non-null  float64
#  31  BLUEBOOK_converted  10302 non-null  float64
# dtypes: float64(8), int64(3), object(21)
# memory usage: 2.5+ MB

# %%
data.drop(columns=['INCOME', 'HOME_VAL', 'OLDCLAIM','ID','BLUEBOOK'], inplace=True)

# %%
data
# Out:
#       KIDSDRIV    BIRTH   AGE HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0            0  16MAR39  60.0        0  11.0      No    z_No      M
# 1            0  21JAN56  43.0        0  11.0      No    z_No      M
# 2            0  18NOV51  48.0        0  11.0      No    z_No      M
# 3            0  05MAR64  35.0        1  10.0      No     Yes    z_F
# 4            0  05JUN48  51.0        0  14.0      No     Yes      M
# ...        ...      ...   ...      ...   ...     ...     ...    ...
# 10297        1  13AUG54  45.0        2   9.0      No     Yes      M
# 10298        0  17JUN53  46.0        0   9.0      No     Yes      M
# 10299        0  18JUN51  48.0        0  15.0      No     Yes    z_F
# 10300        0  12DEC48  50.0        0   7.0      No     Yes    z_F
# 10301        0  27FEB47  52.0        0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  MVR_PTS CLM_AMT  CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...        3      $0     18.0          0
# 1      z_High School  z_Blue Collar  ...        0      $0      1.0          0
# 2          Bachelors        Manager  ...        2      $0     10.0          0
# 3      z_High School       Clerical  ...        3      $0     10.0          0
# 4       <High School  z_Blue Collar  ...        0      $0      6.0          0
# ...              ...            ...  ...      ...     ...      ...        ...
# 10297            PhD        Manager  ...        2      $0     17.0          0
# 10298        Masters            NaN  ...        0      $0      1.0          0
# 10299   <High School  z_Blue Collar  ...        0      $0      1.0          0
# 10300      Bachelors     Home Maker  ...        0      $0     11.0          0
# 10301  z_High School       Clerical  ...        0      $0      9.0          0
#
#                   URBANICITY INCOME_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban          67349.0                0.0
# 1        Highly Urban/ Urban          91449.0           257252.0
# 2        Highly Urban/ Urban          52881.0                0.0
# 3        Highly Urban/ Urban          16039.0           124191.0
# 4        Highly Urban/ Urban              NaN           306251.0
# ...                      ...              ...                ...
# 10297    Highly Urban/ Urban         164669.0           386273.0
# 10298    Highly Urban/ Urban         107204.0           332591.0
# 10299    Highly Urban/ Urban          39837.0           170611.0
# 10300    Highly Urban/ Urban          43445.0           149248.0
# 10301  z_Highly Rural/ Rural          53235.0           197017.0
#
#       OLDCLAIM_converted CLM_AMT_converted  BLUEBOOK_converted
# 0                 4461.0               0.0             14230.0
# 1                    0.0               0.0             14940.0
# 2                    0.0               0.0             21970.0
# 3                38690.0               0.0              4010.0
# 4                    0.0               0.0             15440.0
# ...                  ...               ...                 ...
# 10297                0.0               0.0             13270.0
# 10298                0.0               0.0             24490.0
# 10299                0.0               0.0             13820.0
# 10300                0.0               0.0             22550.0
# 10301                0.0               0.0             19400.0
#
# [10302 rows x 27 columns]

# %% [markdown]
# KẾT LUẬN
# - Nhóm đã tiến hành chuyển đổi các cột có kí hiệu $ thành cột mới và đổi qua biến liên tục.

# %%
object_columns
# Out:
# ['BIRTH',
#  'INCOME',
#  'PARENT1',
#  'HOME_VAL',
#  'MSTATUS',
#  'GENDER',
#  'EDUCATION',
#  'OCCUPATION',
#  'CAR_USE',
#  'BLUEBOOK',
#  'CAR_TYPE',
#  'RED_CAR',
#  'OLDCLAIM',
#  'REVOKED',
#  'CLM_AMT',
#  'URBANICITY']

# %%
numeric_columns=list(data.select_dtypes('number'))
numeric_columns
# Out:
# ['AGE',
#  'YOJ',
#  'TRAVTIME',
#  'TIF',
#  'CAR_AGE',
#  'INCOME_converted',
#  'HOME_VAL_converted',
#  'OLDCLAIM_converted',
#  'CLM_AMT_converted',
#  'BLUEBOOK_converted']

# %%
nulldata_numeric =(data[numeric_columns]==0).sum()
nulldata_numeric
# Out:
# AGE                      0
# YOJ                    807
# TRAVTIME                 0
# TIF                      0
# CAR_AGE                  4
# INCOME_converted       797
# HOME_VAL_converted    2908
# OLDCLAIM_converted    6292
# CLM_AMT_converted     7556
# BLUEBOOK_converted       0
# dtype: int64

# %%
for c in numeric_columns : 
    print(c)
    data.hist(c)
    plt.show()
# Out:
# AGE
# YOJ
# TRAVTIME
# TIF
# CAR_AGE
# INCOME_converted
# HOME_VAL_converted
# OLDCLAIM_converted
# CLM_AMT_converted
# BLUEBOOK_converted

# %%
for c in numeric_columns:
    plt.figure()
    data.boxplot(c , rot=0, grid=True, fontsize=12);
    plt.show()

# %%
import numpy as np
def check_outliers(name,outliers_list):
    we=data[name].values
    Q1=np.quantile(we,0.25)
    Q3=np.quantile(we,0.75)
    IQR=Q3-Q1
    print("Q1: ",Q1,"Q3: ",Q3,"IQR:",IQR)
    outliers=np.unique(we[[(n<Q1-1.5*IQR)|(n>Q3+1.5*IQR) for n in we]])
    indexes=[we.tolist().index(i) for i in outliers]
    if len(indexes)>0:
        outliers_list.append(name)
    print("Indexes of outliers: ", indexes)
    print("Number of outliers: ", len(indexes))
    print("Outlier values", we[indexes])
    print("-----")

# %%
outliers_list=[]
for col in numeric_columns:
    check_outliers(col,outliers_list)
print(outliers_list)
# Out:
# Q1:  nan Q3:  nan IQR: nan
# Indexes of outliers:  []
# Number of outliers:  0
# Outlier values []
# -----
# Q1:  nan Q3:  nan IQR: nan
# Indexes of outliers:  []
# Number of outliers:  0
# Outlier values []
# -----
# Q1:  22.0 Q3:  44.0 IQR: 22.0
# Indexes of outliers:  [764, 658, 1909, 260, 3345, 272, 314, 4177, 1663, 1724, 1069, 7727, 1262, 10017, 7301, 3233, 4924, 9072, 2261, 4685, 10133, 8719, 6335, 1771, 3415, 7495, 4318]
# Number of outliers:  27
# Outlier values [ 78  79  80  81  82  83  84  85  86  87  88  89  90  91  92  93  95  97
#   98  99 101 103 105 113 124 134 142]
# -----
# Q1:  1.0 Q3:  7.0 IQR: 6.0
# Indexes of outliers:  [33, 57, 1102, 762, 924, 865, 1631]
# Number of outliers:  7
# Outlier values [17 18 19 20 21 22 25]
# -----
# Q1:  nan Q3:  nan IQR: nan
# Indexes of outliers:  []
# Number of outliers:  0
# Outlier values []
# -----
# Q1:  nan Q3:  nan IQR: nan
# Indexes of outliers:  []
# Number of outliers:  0
# Outlier values []
# -----
# Indexes of outliers:  [4335, 9338, 2804, 7894, 9748, 4567, 5019, 1994, 6792, 5381, 750, 1132, 3427, 9735, 423, 3769, 8843, 9881, 7378, 7872, 5725, 6268, 1298, 8759, 6831, 4447, 6632, 6312, 8852, 9177, 3672, 4945, 3989, 3986, 6265, 6233, 8859, 8523, 10126, 3681, 6962, 1050, 8424, 2299, 4395, 878, 7827, 8731, 2610, 2965, 3013, 4566, 3238, 10045, 10175, 1413, 6964, 6402, 9505, 8377, 4497, 3541, 234, 5699, 5512, 6570, 2682, 2869, 5557, 9043, 5919, 7685, 4629, 7415, 4042, 9937, 3443, 4651, 4527, 5436, 4548, 6666, 6510, 1194, 6201, 9518, 5246, 10254, 10261, 8127, 4902, 6370, 3440, 3396, 8907, 610, 3472, 3848, 5399, 9308, 3200, 6558, 1654, 4524, 5031, 3851, 3670, 8755]
# Number of outliers:  108
# Outlier values [38440. 38500. 38550. 38600. 38700. 38750. 38810. 38820. 38870. 38900.
#  38910. 38940. 39090. 39130. 39190. 39360. 39420. 39480. 39520. 39540.
#  39560. 39580. 39720. 39900. 40100. 40180. 40240. 40260. 40420. 40520.
#  40580. 40610. 40630. 40750. 40760. 40860. 40880. 40900. 40950. 40980.
#  41030. 41180. 41230. 41250. 41280. 41310. 41400. 41440. 41470. 41490.
#  41570. 41620. 41710. 41790. 41830. 42010. 42020. 42170. 42190. 42320.
#  42520. 42540. 42550. 42560. 42580. 42680. 42690. 42770. 43090. 43250.
#  43280. 43290. 43350. 43450. 43510. 43530. 43560. 43590. 43960. 44050.
#  44110. 44130. 44250. 44270. 44590. 45130. 45360. 45410. 45420. 45480.
#  45680. 45730. 46250. 46610. 46990. 47030. 48380. 48620. 49230. 49880.
#  49940. 50180. 50970. 57970. 61050. 62240. 65970. 69740.]
# -----
# ['TRAVTIME', 'TIF', 'OLDCLAIM_converted', 'CLM_AMT_converted', 'BLUEBOOK_converted']

# %% [markdown]
# KẾT LUẬN
# - Một số cột chứ rất nhiều giá trị ngoại lệ. Cần phải cân nhắc

# %%
corrle = data[numeric_columns].corr()
corrle
# Out:
#                          AGE       YOJ  TRAVTIME       TIF   CAR_AGE  \
# AGE                 1.000000  0.140878 -0.001569 -0.001890  0.178592
# YOJ                 0.140878  1.000000 -0.017152  0.023921  0.064685
# TRAVTIME           -0.001569 -0.017152  1.000000 -0.013327 -0.033290
# TIF                -0.001890  0.023921 -0.013327  1.000000  0.007897
# CAR_AGE             0.178592  0.064685 -0.033290  0.007897  1.000000
# INCOME_converted    0.186202  0.293899 -0.051853  0.002361  0.417301
# HOME_VAL_converted  0.209600  0.272198 -0.035139  0.006768  0.223198
# OLDCLAIM_converted -0.033378 -0.005077 -0.013806 -0.015520 -0.019163
# CLM_AMT_converted  -0.049034 -0.026799  0.031270 -0.046518 -0.066060
# BLUEBOOK_converted  0.166290  0.148086 -0.022536  0.000705  0.194366
#
#                     INCOME_converted  HOME_VAL_converted  OLDCLAIM_converted  \
# AGE                         0.186202            0.209600           -0.033378
# YOJ                         0.293899            0.272198           -0.005077
# TRAVTIME                   -0.051853           -0.035139           -0.013806
# TIF                         0.002361            0.006768           -0.015520
# CAR_AGE                     0.417301            0.223198           -0.019163
# INCOME_converted            1.000000            0.578943           -0.039347
# HOME_VAL_converted          0.578943            1.000000           -0.059803
# OLDCLAIM_converted         -0.039347           -0.059803            1.000000
# CLM_AMT_converted          -0.057686           -0.091987            0.076535
# BLUEBOOK_converted          0.429095            0.261962           -0.030725
#
#                     CLM_AMT_converted  BLUEBOOK_converted
# AGE                         -0.049034            0.166290
# YOJ                         -0.026799            0.148086
# TRAVTIME                     0.031270           -0.022536
# TIF                         -0.046518            0.000705
# CAR_AGE                     -0.066060            0.194366
# INCOME_converted            -0.057686            0.429095
# HOME_VAL_converted          -0.091987            0.261962
# OLDCLAIM_converted           0.076535           -0.030725
# CLM_AMT_converted            1.000000           -0.002443
# BLUEBOOK_converted          -0.002443            1.000000

# %%
sns.heatmap(corrle, vmin=-1,vmax=1, annot=False,fmt=".2f",cmap='coolwarm')
plt.show()

# %% [markdown]
# KẾT LUẬN
# - Dựa vào ma trận tương quan trên, ta nhận thấy những biến có tương quan mạnh : Income_converted & Home_val_converted (0.578943),Income_converted & car_age (0.417301), Home_val_converted & car_age (0.223198).
# - Hầu như các biến không tương quan với nhau.

# %%
data
# Out:
#       KIDSDRIV    BIRTH   AGE HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0            0  16MAR39  60.0        0  11.0      No    z_No      M
# 1            0  21JAN56  43.0        0  11.0      No    z_No      M
# 2            0  18NOV51  48.0        0  11.0      No    z_No      M
# 3            0  05MAR64  35.0        1  10.0      No     Yes    z_F
# 4            0  05JUN48  51.0        0  14.0      No     Yes      M
# ...        ...      ...   ...      ...   ...     ...     ...    ...
# 10297        1  13AUG54  45.0        2   9.0      No     Yes      M
# 10298        0  17JUN53  46.0        0   9.0      No     Yes      M
# 10299        0  18JUN51  48.0        0  15.0      No     Yes    z_F
# 10300        0  12DEC48  50.0        0   7.0      No     Yes    z_F
# 10301        0  27FEB47  52.0        0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  MVR_PTS CLM_AMT  CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...        3      $0     18.0          0
# 1      z_High School  z_Blue Collar  ...        0      $0      1.0          0
# 2          Bachelors        Manager  ...        2      $0     10.0          0
# 3      z_High School       Clerical  ...        3      $0     10.0          0
# 4       <High School  z_Blue Collar  ...        0      $0      6.0          0
# ...              ...            ...  ...      ...     ...      ...        ...
# 10297            PhD        Manager  ...        2      $0     17.0          0
# 10298        Masters            NaN  ...        0      $0      1.0          0
# 10299   <High School  z_Blue Collar  ...        0      $0      1.0          0
# 10300      Bachelors     Home Maker  ...        0      $0     11.0          0
# 10301  z_High School       Clerical  ...        0      $0      9.0          0
#
#                   URBANICITY INCOME_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban          67349.0                0.0
# 1        Highly Urban/ Urban          91449.0           257252.0
# 2        Highly Urban/ Urban          52881.0                0.0
# 3        Highly Urban/ Urban          16039.0           124191.0
# 4        Highly Urban/ Urban              NaN           306251.0
# ...                      ...              ...                ...
# 10297    Highly Urban/ Urban         164669.0           386273.0
# 10298    Highly Urban/ Urban         107204.0           332591.0
# 10299    Highly Urban/ Urban          39837.0           170611.0
# 10300    Highly Urban/ Urban          43445.0           149248.0
# 10301  z_Highly Rural/ Rural          53235.0           197017.0
#
#       OLDCLAIM_converted CLM_AMT_converted  BLUEBOOK_converted
# 0                 4461.0               0.0             14230.0
# 1                    0.0               0.0             14940.0
# 2                    0.0               0.0             21970.0
# 3                38690.0               0.0              4010.0
# 4                    0.0               0.0             15440.0
# ...                  ...               ...                 ...
# 10297                0.0               0.0             13270.0
# 10298                0.0               0.0             24490.0
# 10299                0.0               0.0             13820.0
# 10300                0.0               0.0             22550.0
# 10301                0.0               0.0             19400.0
#
# [10302 rows x 27 columns]

# %% [markdown]
# ## **Chỉnh sửa dữ liệu**

# %% [markdown]
# - Sau những phân tích trên, chúng ta sẽ tiến hành chỉnh sử data theo kết luận trước đó

# %%
bins = [16,30,60,81]
labels=['Young','Middle','Old']
data['AGE'] = pd.cut(data.AGE, bins=bins,labels=labels, right=False)
data
# Out:
#       KIDSDRIV    BIRTH     AGE HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0            0  16MAR39     Old        0  11.0      No    z_No      M
# 1            0  21JAN56  Middle        0  11.0      No    z_No      M
# 2            0  18NOV51  Middle        0  11.0      No    z_No      M
# 3            0  05MAR64  Middle        1  10.0      No     Yes    z_F
# 4            0  05JUN48  Middle        0  14.0      No     Yes      M
# ...        ...      ...     ...      ...   ...     ...     ...    ...
# 10297        1  13AUG54  Middle        2   9.0      No     Yes      M
# 10298        0  17JUN53  Middle        0   9.0      No     Yes      M
# 10299        0  18JUN51  Middle        0  15.0      No     Yes    z_F
# 10300        0  12DEC48  Middle        0   7.0      No     Yes    z_F
# 10301        0  27FEB47  Middle        0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  MVR_PTS CLM_AMT  CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...        3      $0     18.0          0
# 1      z_High School  z_Blue Collar  ...        0      $0      1.0          0
# 2          Bachelors        Manager  ...        2      $0     10.0          0
# 3      z_High School       Clerical  ...        3      $0     10.0          0
# 4       <High School  z_Blue Collar  ...        0      $0      6.0          0
# ...              ...            ...  ...      ...     ...      ...        ...
# 10297            PhD        Manager  ...        2      $0     17.0          0
# 10298        Masters            NaN  ...        0      $0      1.0          0
# 10299   <High School  z_Blue Collar  ...        0      $0      1.0          0
# 10300      Bachelors     Home Maker  ...        0      $0     11.0          0
# 10301  z_High School       Clerical  ...        0      $0      9.0          0
#
#                   URBANICITY INCOME_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban          67349.0                0.0
# 1        Highly Urban/ Urban          91449.0           257252.0
# 2        Highly Urban/ Urban          52881.0                0.0
# 3        Highly Urban/ Urban          16039.0           124191.0
# 4        Highly Urban/ Urban              NaN           306251.0
# ...                      ...              ...                ...
# 10297    Highly Urban/ Urban         164669.0           386273.0
# 10298    Highly Urban/ Urban         107204.0           332591.0
# 10299    Highly Urban/ Urban          39837.0           170611.0
# 10300    Highly Urban/ Urban          43445.0           149248.0
# 10301  z_Highly Rural/ Rural          53235.0           197017.0
#
#       OLDCLAIM_converted CLM_AMT_converted  BLUEBOOK_converted
# 0                 4461.0               0.0             14230.0
# 1                    0.0               0.0             14940.0
# 2                    0.0               0.0             21970.0
# 3                38690.0               0.0              4010.0
# 4                    0.0               0.0             15440.0
# ...                  ...               ...                 ...
# 10297                0.0               0.0             13270.0
# 10298                0.0               0.0             24490.0
# 10299                0.0               0.0             13820.0
# 10300                0.0               0.0             22550.0
# 10301                0.0               0.0             19400.0
#
# [10302 rows x 27 columns]

# %% [markdown]
# Chuyển các giá trị trong cột AGE thành giá trị phân loại :
# - Young : từ 16-30 tuổi
# - Middle : từ 30-60 tuổi
# - Old : từ 60-81 tuổi

# %%
data.describe()
# Out:
#                YOJ      TRAVTIME           TIF      CAR_AGE  INCOME_converted  \
# count  9754.000000  10302.000000  10302.000000  9663.000000       9732.000000
# mean     10.474062     33.416424      5.329159     8.298148      61572.073263
# std       4.108943     15.869687      4.110795     5.714450      47457.202749
# min       0.000000      5.000000      1.000000    -3.000000          0.000000
# 25%       9.000000     22.000000      1.000000     1.000000      27584.000000
# 50%      11.000000     33.000000      4.000000     8.000000      53529.000000
# 75%      13.000000     44.000000      7.000000    12.000000      86166.000000
# max      23.000000    142.000000     25.000000    28.000000     367030.000000
#
#        HOME_VAL_converted  OLDCLAIM_converted  CLM_AMT_converted  \
# count         9727.000000        10302.000000       10302.000000
# mean        154523.018608         4033.977868        1511.266453
# std         129188.439405         8733.143119        4725.249896
# min              0.000000            0.000000           0.000000
# 25%              0.000000            0.000000           0.000000
# 50%         160661.000000            0.000000           0.000000
# 75%         238256.000000         4647.500000        1144.750000
# max         885282.000000        57037.000000      123247.000000
#
#        BLUEBOOK_converted
# count        10302.000000
# mean         15659.923316
# std           8428.765264
# min           1500.000000
# 25%           9200.000000
# 50%          14400.000000
# 75%          20890.000000
# max          69740.000000

# %%
# bins = [0.000000,27584.000000,86166.000000,367030.000000]
# labels=['Low','Middle','High']
# data['INCOME_converted'] = pd.cut(data.INCOME_converted, bins=bins,labels=labels, right=False)
# data

# %% [markdown]
# ### Chuyển các giá trị trong cột INCOME_converted thành giá trị phân loại :
# - Low : 0-27584
# - Middle : 27584-86166
# - High : 86166-367030ổi

# %%
bins = [0,2,7,25]
labels=['Short','Middle','Long']
data['TIF'] = pd.cut(data.TIF, bins=bins,labels=labels, right=False)
data
# Out:
#       KIDSDRIV    BIRTH     AGE HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0            0  16MAR39     Old        0  11.0      No    z_No      M
# 1            0  21JAN56  Middle        0  11.0      No    z_No      M
# 2            0  18NOV51  Middle        0  11.0      No    z_No      M
# 3            0  05MAR64  Middle        1  10.0      No     Yes    z_F
# 4            0  05JUN48  Middle        0  14.0      No     Yes      M
# ...        ...      ...     ...      ...   ...     ...     ...    ...
# 10297        1  13AUG54  Middle        2   9.0      No     Yes      M
# 10298        0  17JUN53  Middle        0   9.0      No     Yes      M
# 10299        0  18JUN51  Middle        0  15.0      No     Yes    z_F
# 10300        0  12DEC48  Middle        0   7.0      No     Yes    z_F
# 10301        0  27FEB47  Middle        0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  MVR_PTS CLM_AMT CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...        3      $0    18.0          0
# 1      z_High School  z_Blue Collar  ...        0      $0     1.0          0
# 2          Bachelors        Manager  ...        2      $0    10.0          0
# 3      z_High School       Clerical  ...        3      $0    10.0          0
# 4       <High School  z_Blue Collar  ...        0      $0     6.0          0
# ...              ...            ...  ...      ...     ...     ...        ...
# 10297            PhD        Manager  ...        2      $0    17.0          0
# 10298        Masters            NaN  ...        0      $0     1.0          0
# 10299   <High School  z_Blue Collar  ...        0      $0     1.0          0
# 10300      Bachelors     Home Maker  ...        0      $0    11.0          0
# 10301  z_High School       Clerical  ...        0      $0     9.0          0
#
#                   URBANICITY INCOME_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban          67349.0                0.0
# 1        Highly Urban/ Urban          91449.0           257252.0
# 2        Highly Urban/ Urban          52881.0                0.0
# 3        Highly Urban/ Urban          16039.0           124191.0
# 4        Highly Urban/ Urban              NaN           306251.0
# ...                      ...              ...                ...
# 10297    Highly Urban/ Urban         164669.0           386273.0
# 10298    Highly Urban/ Urban         107204.0           332591.0
# 10299    Highly Urban/ Urban          39837.0           170611.0
# 10300    Highly Urban/ Urban          43445.0           149248.0
# 10301  z_Highly Rural/ Rural          53235.0           197017.0
#
#       OLDCLAIM_converted CLM_AMT_converted  BLUEBOOK_converted
# 0                 4461.0               0.0             14230.0
# 1                    0.0               0.0             14940.0
# 2                    0.0               0.0             21970.0
# 3                38690.0               0.0              4010.0
# 4                    0.0               0.0             15440.0
# ...                  ...               ...                 ...
# 10297                0.0               0.0             13270.0
# 10298                0.0               0.0             24490.0
# 10299                0.0               0.0             13820.0
# 10300                0.0               0.0             22550.0
# 10301                0.0               0.0             19400.0
#
# [10302 rows x 27 columns]

# %% [markdown]
# ### Chuyển các giá trị trong cột thời gian sử dụng bảo hiểm thành giá trị phân loại :
# - Short : 0-2
# - Middle : 2-7
# - Long : 7-25

# %%
data.CLAIM_FLAG.value_counts()
# Out:
# CLAIM_FLAG
# 0    7556
# 1    2746
# Name: count, dtype: int64

# %%
sns.countplot(x='CLAIM_FLAG',data=data)
plt.title("Biểu đồ yêu cầu bồi thường bảo hiểm")
plt.show()

# %% [markdown]
# ## KẾT LUẬN
# -Tỉ lệ hồ sơ yêu cầu bồi thường bảo hiểm có sự chênh lệch quá lớn. Số hồ sơ không yêu cầu bổi thường gấp 3 lần số hồ sơ yêu cầu bồi thường. => (Imbalanced variable)

# %%
data.shape
# Out:
# (10302, 27)

# %%
data.AGE.value_counts()
# Out:
# AGE
# Middle    9469
# Old        428
# Young      397
# Name: count, dtype: int64

# %%
sns.countplot(x="AGE",hue="CLAIM_FLAG",data=data)
plt.title("Biểu đồ thể hiện lứa tuổi của người yêu cầu bồi thường bảo hiểm")
plt.show()

# %% [markdown]
# Sự tương quan giữa age không được hiển thị rõ rệt ở các nhóm tuổi bởi vốn dĩ tỉ lệ số hồ sơ được cho là không gian lận quá lớn, gấp 3 lần số bộ hồ sơ gian lận. Tuy nhiên, ta có thể nhận thấy được nhóm tuổi yêu cầu đòi bòi thường bảo hiểm nhiều nhất là ở nhóm tuổi trung niên (Middle).

# %%
data.OCCUPATION.value_counts()
# Out:
# OCCUPATION
# z_Blue Collar    2288
# Clerical         1590
# Professional     1408
# Manager          1257
# Lawyer           1031
# Student           899
# Home Maker        843
# Doctor            321
# Name: count, dtype: int64

# %%
OCCUPATION_Y = data[data.CLAIM_FLAG==0].groupby('OCCUPATION')['CLAIM_FLAG'].count().sort_values(ascending=False)
OCCUPATION_Y.head(5).plot.bar()
plt.title('Top 5 ngành nghề của khách hàng thuộc hồ sơ được chấp nhận')
plt.show()

# %%
OCCUPATION_N = data[data.CLAIM_FLAG==1].groupby('OCCUPATION')['CLAIM_FLAG'].count().sort_values(ascending=False)
OCCUPATION_N.head(5).plot.bar()
plt.title('Top 5 ngành nghề của khách hàng thuộc hồ sơ không được chấp nhận')
plt.show()

# %% [markdown]
# ## KẾT LUẬN
# - Có thể thấy rõ sự khác nhau về nghề nghiệp của khách hàng giữa bộ hồ sơ gian lận với được chấp nhận.
# - Chúng ta có thể cân nhắc đây là một đặc trưng đưa vào mô hình dự đoán!

# %%
available_request=data[data['CLAIM_FLAG']==1]

# %%
data.GENDER.value_counts()
# Out:
# GENDER
# z_F    5545
# M      4757
# Name: count, dtype: int64

# %%
sns.histplot(data=data,x="HOME_VAL_converted",hue="GENDER");
plt.title("Biểu đồ thể hiện tương quan giới tính với số giá trị nhà người nộp bảo hiểm")
plt.show()

# %% [markdown]
# Biểu đồ cho thấy mối tương quan tích cực giữa giới tính nam và giá trị nhà sau khi quy đổi. Tuy nhiên, mức độ tương quan không mạnh và dữ liệu phân bố không đều. Cần thêm thông tin về số lượng dữ liệu và phân bố độ tuổi để có kết luận chính xác hơn.
# Ta có thể thử phân phố giá trị nhà theo nhóm tuổi.

# %%
g = sns.displot(data, x = 'HOME_VAL_converted', col= 'AGE', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Phân phối giá trị nhà theo nhóm tuổi', y = 1.03)
g.set_ylabels('Số hóa đơn')
plt.show()
# Out:
# C:\Users\Ngoc\miniconda3\envs\EDA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Qua quan sát, ta thấy độ tuổi trung niên sở hữu giá trị nhà nhiều nhất và giá trị dao động cao nhất.

# %%
sns.countplot(x='CLAIM_FLAG',hue='GENDER',data=data)
# Out:
# <Axes: xlabel='CLAIM_FLAG', ylabel='count'>

# %%
g = sns.displot(data, x = 'HOME_VAL_converted', col= 'CLAIM_FLAG', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Phân phối tổng hóa đơn yêu cầu bảo hiểm và giá trị nhà ở', y = 1.03)
g.set_ylabels('Số đơn yêu cầu')
plt.show()
# Out:
# C:\Users\Ngoc\miniconda3\envs\EDA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Theo quan sát, giá trị nhà tương quan với yêu cầu bảo hiểm.
# - Phần lớn yêu cầu bồi thường bảo hiểm dao động trong khoagr từ 100000 đến 400000.

# %%
g = sns.displot(data, x ='CAR_AGE', col= 'CAR_USE', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Tuổi đời của xe và mục đích sử dụng', y = 1.03)
g.set_ylabels('Mục đích sử dụng')
plt.show()
# Out:
# C:\Users\Ngoc\miniconda3\envs\EDA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Có thể thấy với xe cá nhân, vòng đời sẽ ngắn hơn so với xe thương mại. => Xe thương mại dùng lâu hơn và tăng dần theo thời gian. Còn xe cá nhân người ta thường chuộng những xe đời mới.

# %%
g = sns.displot(data, x ='CAR_AGE', col= 'CLAIM_FLAG', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Tuổi đời của xe và đơn yêu cầu bồi thường bảo hiểm', y = 1.03)
g.set_ylabels('Số lượng đơn')
plt.show()
# Out:
# C:\Users\Ngoc\miniconda3\envs\EDA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Số lượng đơn yêu cầu bồi thường bảo hiểm diễn ra nhiều nhất ở năm đầu tiên và dao động từ năm thứ 5 đến năm thứ 15

# %%
g = sns.displot(data, x ='BLUEBOOK_converted', col= 'CLAIM_FLAG', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Giá trị của xe và đơn yêu cầu bồi thường bảo hiểm', y = 1.03)
g.set_ylabels('Giá trị của xe')
plt.show()
# Out:
# C:\Users\Ngoc\miniconda3\envs\EDA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Nhìn vào hình, ta có thể thấy xe có ít giá trị thường yêu cầu bồi thường sẽ nhiều hơn. Có thể xe giá trị thấp, linh kiện không thật sự chất lượng khiến xe nhanh xuống cấp.

# %%
palette = sns.color_palette("muted")
plt.figure(figsize=(16, 8))

my_order = data.groupby(by=["CAR_TYPE"])["BLUEBOOK_converted"].median().iloc[::-1].index

sns.boxplot(x = 'CAR_TYPE', y = 'BLUEBOOK_converted' ,data = data, order = my_order,palette=palette).set(title = 'Loại xe và giá trị của nó')
plt.xticks(rotation = 90);

# %% [markdown]
# Các cột đều có nhiều giá trị ngoại lệ.
# Cần phải cân nhắc khi đưa các biến này vào mô hình.

# %%
# sns.countplot(x='YOJ',hue='INCOME_converted', data=data)
g = sns.displot(data, x ='YOJ', col= 'INCOME_converted', kde = True) # chỉ vẽ kde: kind = 'kde'
plt.suptitle('Số năm kinh nghiệm và bình quân thu nhập của khách hàng', y = 1.03)
g.set_ylabels('Số năm kinh nghiệm')
plt.show()

# %% [markdown]
# Có thể kết luận, với kinh nghiệm lái xe càng cao thì thu nhập càng tăng

# %%
data.columns
# Out:
# Index(['KIDSDRIV', 'BIRTH', 'AGE', 'HOMEKIDS', 'YOJ', 'PARENT1', 'MSTATUS',
#        'GENDER', 'EDUCATION', 'OCCUPATION', 'TRAVTIME', 'CAR_USE', 'TIF',
#        'CAR_TYPE', 'RED_CAR', 'CLM_FREQ', 'REVOKED', 'MVR_PTS', 'CLM_AMT',
#        'CAR_AGE', 'CLAIM_FLAG', 'URBANICITY', 'INCOME_converted',
#        'HOME_VAL_converted', 'OLDCLAIM_converted', 'CLM_AMT_converted',
#        'BLUEBOOK_converted'],
#       dtype='object')

# %%
data.dtypes
