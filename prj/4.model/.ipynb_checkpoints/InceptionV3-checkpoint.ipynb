# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x


def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 384, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # mixed 5, 6: 17 x 17 x 768
    for i in range(2):
        branch1x1 = conv1d_bn(x, 192, 1,padding='same')

        branch7x7 = conv1d_bn(x, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

        branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

        branch_pool = AveragePooling1D(
            3, strides=1, padding='same')(x)
        branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
        x = layers.concatenate(
            [branch1x1, branch7x7, branch7x7dbl, branch_pool],
            axis=channel_axis,
            name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # mixed 8: 8 x 8 x 1280
    branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    branch3x3 = conv1d_bn(branch3x3, 320, 3,
                          strides=2, padding='valid')

    branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    branch7x7x3 = conv1d_bn(
        branch7x7x3, 192, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # mixed 9: 8 x 8 x 2048
    for i in range(2):
        branch1x1 = conv1d_bn(x, 320, 1,padding='same')

        branch3x3 = conv1d_bn(x, 384, 1,padding='same')
        branch3x3_1 = conv1d_bn(branch3x3, 384, 1,padding='same')
        branch3x3_2 = conv1d_bn(branch3x3, 384, 3,padding='same')
        branch3x3 = layers.concatenate(
            [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

        branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
        branch3x3dbl = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
        branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 384, 1,padding='same')
        branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
        branch3x3dbl = layers.concatenate(
            [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

        branch_pool = AveragePooling1D(
            3, strides=1, padding='same')(x)
        branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
        x = layers.concatenate(
            [branch1x1, branch3x3, branch3x3dbl, branch_pool],
            axis=channel_axis,
            name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(1, activation='sigmoid', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 42, 1)]      0           []
#
#  conv1d_336 (Conv1D)            (None, 20, 32)       96          ['input_17[0][0]']
#
#  batch_normalization_329 (Batch  (None, 20, 32)      60          ['conv1d_336[0][0]']
#  Normalization)
#
#  activation_329 (Activation)    (None, 20, 32)       0           ['batch_normalization_329[0][0]']
#
#  conv1d_337 (Conv1D)            (None, 18, 32)       3072        ['activation_329[0][0]']
#
#  batch_normalization_330 (Batch  (None, 18, 32)      54          ['conv1d_337[0][0]']
#  Normalization)
#
#  activation_330 (Activation)    (None, 18, 32)       0           ['batch_normalization_330[0][0]']
#
#  conv1d_338 (Conv1D)            (None, 16, 64)       6144        ['activation_330[0][0]']
#
#  batch_normalization_331 (Batch  (None, 16, 64)      48          ['conv1d_338[0][0]']
#  Normalization)
#
#  activation_331 (Activation)    (None, 16, 64)       0           ['batch_normalization_331[0][0]']
#
#  block1_pool (MaxPooling1D)     (None, 7, 64)        0           ['activation_331[0][0]']
#
#  conv1d_342 (Conv1D)            (None, 7, 64)        4096        ['block1_pool[0][0]']
#
#  batch_normalization_335 (Batch  (None, 7, 64)       21          ['conv1d_342[0][0]']
#  Normalization)
#
#  activation_335 (Activation)    (None, 7, 64)        0           ['batch_normalization_335[0][0]']
#
#  conv1d_340 (Conv1D)            (None, 7, 48)        3072        ['block1_pool[0][0]']
#
#  conv1d_343 (Conv1D)            (None, 7, 96)        18432       ['activation_335[0][0]']
#
#  batch_normalization_333 (Batch  (None, 7, 48)       21          ['conv1d_340[0][0]']
#  Normalization)
#
#  batch_normalization_336 (Batch  (None, 7, 96)       21          ['conv1d_343[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 7, 48)        0           ['batch_normalization_333[0][0]']
#
#  activation_336 (Activation)    (None, 7, 96)        0           ['batch_normalization_336[0][0]']
#
#  average_pooling1d_27 (AverageP  (None, 7, 64)       0           ['block1_pool[0][0]']
#  ooling1D)
#
#  conv1d_339 (Conv1D)            (None, 7, 64)        4096        ['block1_pool[0][0]']
#
#  conv1d_341 (Conv1D)            (None, 7, 64)        15360       ['activation_333[0][0]']
#
#  conv1d_344 (Conv1D)            (None, 7, 96)        27648       ['activation_336[0][0]']
#
#  conv1d_345 (Conv1D)            (None, 7, 32)        2048        ['average_pooling1d_27[0][0]']
#
#  batch_normalization_332 (Batch  (None, 7, 64)       21          ['conv1d_339[0][0]']
#  Normalization)
#
#  batch_normalization_334 (Batch  (None, 7, 64)       21          ['conv1d_341[0][0]']
#  Normalization)
#
#  batch_normalization_337 (Batch  (None, 7, 96)       21          ['conv1d_344[0][0]']
#  Normalization)
#
#  batch_normalization_338 (Batch  (None, 7, 32)       21          ['conv1d_345[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 7, 64)        0           ['batch_normalization_332[0][0]']
#
#  activation_334 (Activation)    (None, 7, 64)        0           ['batch_normalization_334[0][0]']
#
#  activation_337 (Activation)    (None, 7, 96)        0           ['batch_normalization_337[0][0]']
#
#  activation_338 (Activation)    (None, 7, 32)        0           ['batch_normalization_338[0][0]']
#
#  mixed0 (Concatenate)           (None, 7, 256)       0           ['activation_332[0][0]',
#                                                                   'activation_334[0][0]',
#                                                                   'activation_337[0][0]',
#                                                                   'activation_338[0][0]']
#
#  conv1d_349 (Conv1D)            (None, 7, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_342 (Batch  (None, 7, 64)       21          ['conv1d_349[0][0]']
#  Normalization)
#
#  activation_342 (Activation)    (None, 7, 64)        0           ['batch_normalization_342[0][0]']
#
#  conv1d_347 (Conv1D)            (None, 7, 48)        12288       ['mixed0[0][0]']
#
#  conv1d_350 (Conv1D)            (None, 7, 96)        18432       ['activation_342[0][0]']
#
#  batch_normalization_340 (Batch  (None, 7, 48)       21          ['conv1d_347[0][0]']
#  Normalization)
#
#  batch_normalization_343 (Batch  (None, 7, 96)       21          ['conv1d_350[0][0]']
#  Normalization)
#
#  activation_340 (Activation)    (None, 7, 48)        0           ['batch_normalization_340[0][0]']
#
#  activation_343 (Activation)    (None, 7, 96)        0           ['batch_normalization_343[0][0]']
#
#  average_pooling1d_28 (AverageP  (None, 7, 256)      0           ['mixed0[0][0]']
#  ooling1D)
#
#  conv1d_346 (Conv1D)            (None, 7, 64)        16384       ['mixed0[0][0]']
#
#  conv1d_348 (Conv1D)            (None, 7, 64)        15360       ['activation_340[0][0]']
#
#  conv1d_351 (Conv1D)            (None, 7, 96)        27648       ['activation_343[0][0]']
#
#  conv1d_352 (Conv1D)            (None, 7, 64)        16384       ['average_pooling1d_28[0][0]']
#
#  batch_normalization_339 (Batch  (None, 7, 64)       21          ['conv1d_346[0][0]']
#  Normalization)
#
#  batch_normalization_341 (Batch  (None, 7, 64)       21          ['conv1d_348[0][0]']
#  Normalization)
#
#  batch_normalization_344 (Batch  (None, 7, 96)       21          ['conv1d_351[0][0]']
#  Normalization)
#
#  batch_normalization_345 (Batch  (None, 7, 64)       21          ['conv1d_352[0][0]']
#  Normalization)
#
#  activation_339 (Activation)    (None, 7, 64)        0           ['batch_normalization_339[0][0]']
#
#  activation_341 (Activation)    (None, 7, 64)        0           ['batch_normalization_341[0][0]']
#
#  activation_344 (Activation)    (None, 7, 96)        0           ['batch_normalization_344[0][0]']
#
#  activation_345 (Activation)    (None, 7, 64)        0           ['batch_normalization_345[0][0]']
#
#  mixed1 (Concatenate)           (None, 7, 288)       0           ['activation_339[0][0]',
#                                                                   'activation_341[0][0]',
#                                                                   'activation_344[0][0]',
#                                                                   'activation_345[0][0]']
#
#  conv1d_356 (Conv1D)            (None, 7, 64)        18432       ['mixed1[0][0]']
#
#  batch_normalization_349 (Batch  (None, 7, 64)       21          ['conv1d_356[0][0]']
#  Normalization)
#
#  activation_349 (Activation)    (None, 7, 64)        0           ['batch_normalization_349[0][0]']
#
#  conv1d_354 (Conv1D)            (None, 7, 48)        13824       ['mixed1[0][0]']
#
#  conv1d_357 (Conv1D)            (None, 7, 96)        18432       ['activation_349[0][0]']
#
#  batch_normalization_347 (Batch  (None, 7, 48)       21          ['conv1d_354[0][0]']
#  Normalization)
#
#  batch_normalization_350 (Batch  (None, 7, 96)       21          ['conv1d_357[0][0]']
#  Normalization)
#
#  activation_347 (Activation)    (None, 7, 48)        0           ['batch_normalization_347[0][0]']
#
#  activation_350 (Activation)    (None, 7, 96)        0           ['batch_normalization_350[0][0]']
#
#  average_pooling1d_29 (AverageP  (None, 7, 288)      0           ['mixed1[0][0]']
#  ooling1D)
#  conv1d_353 (Conv1D)            (None, 7, 64)        18432       ['mixed1[0][0]']
#
#  conv1d_355 (Conv1D)            (None, 7, 64)        15360       ['activation_347[0][0]']
#
#  conv1d_358 (Conv1D)            (None, 7, 96)        27648       ['activation_350[0][0]']
#
#  conv1d_359 (Conv1D)            (None, 7, 64)        18432       ['average_pooling1d_29[0][0]']
#
#  batch_normalization_346 (Batch  (None, 7, 64)       21          ['conv1d_353[0][0]']
#  Normalization)
#
#  batch_normalization_348 (Batch  (None, 7, 64)       21          ['conv1d_355[0][0]']
#  Normalization)
#
#  batch_normalization_351 (Batch  (None, 7, 96)       21          ['conv1d_358[0][0]']
#  Normalization)
#
#  batch_normalization_352 (Batch  (None, 7, 64)       21          ['conv1d_359[0][0]']
#  Normalization)
#
#  activation_346 (Activation)    (None, 7, 64)        0           ['batch_normalization_346[0][0]']
#
#  activation_348 (Activation)    (None, 7, 64)        0           ['batch_normalization_348[0][0]']
#
#  activation_351 (Activation)    (None, 7, 96)        0           ['batch_normalization_351[0][0]']
#
#  activation_352 (Activation)    (None, 7, 64)        0           ['batch_normalization_352[0][0]']
#
#  mixed2 (Concatenate)           (None, 7, 288)       0           ['activation_346[0][0]',
#                                                                   'activation_348[0][0]',
#                                                                   'activation_351[0][0]',
#                                                                   'activation_352[0][0]']
#
#  conv1d_361 (Conv1D)            (None, 7, 64)        18432       ['mixed2[0][0]']
#
#  batch_normalization_354 (Batch  (None, 7, 64)       21          ['conv1d_361[0][0]']
#  Normalization)
#
#  activation_354 (Activation)    (None, 7, 64)        0           ['batch_normalization_354[0][0]']
#
#  conv1d_362 (Conv1D)            (None, 7, 96)        18432       ['activation_354[0][0]']
#
#  batch_normalization_355 (Batch  (None, 7, 96)       21          ['conv1d_362[0][0]']
#  Normalization)
#
#  activation_355 (Activation)    (None, 7, 96)        0           ['batch_normalization_355[0][0]']
#
#  conv1d_360 (Conv1D)            (None, 3, 384)       331776      ['mixed2[0][0]']
#
#  conv1d_363 (Conv1D)            (None, 3, 96)        27648       ['activation_355[0][0]']
#
#  batch_normalization_353 (Batch  (None, 3, 384)      9           ['conv1d_360[0][0]']
#  Normalization)
#
#  batch_normalization_356 (Batch  (None, 3, 96)       9           ['conv1d_363[0][0]']
#  Normalization)
#
#  activation_353 (Activation)    (None, 3, 384)       0           ['batch_normalization_353[0][0]']
#
#  activation_356 (Activation)    (None, 3, 96)        0           ['batch_normalization_356[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 3, 288)      0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 3, 768)       0           ['activation_353[0][0]',
#                                                                   'activation_356[0][0]',
#                                                                   'max_pooling1d_5[0][0]']
#
#  conv1d_368 (Conv1D)            (None, 3, 128)       98304       ['mixed3[0][0]']
#
#  batch_normalization_361 (Batch  (None, 3, 128)      9           ['conv1d_368[0][0]']
#  Normalization)
#
#  activation_361 (Activation)    (None, 3, 128)       0           ['batch_normalization_361[0][0]']
#
#  conv1d_369 (Conv1D)            (None, 3, 128)       114688      ['activation_361[0][0]']
#
#  batch_normalization_362 (Batch  (None, 3, 128)      9           ['conv1d_369[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 3, 128)       0           ['batch_normalization_362[0][0]']
#
#  conv1d_365 (Conv1D)            (None, 3, 128)       98304       ['mixed3[0][0]']
#  conv1d_370 (Conv1D)            (None, 3, 128)       16384       ['activation_362[0][0]']
#
#  batch_normalization_358 (Batch  (None, 3, 128)      9           ['conv1d_365[0][0]']
#  Normalization)
#
#  batch_normalization_363 (Batch  (None, 3, 128)      9           ['conv1d_370[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 3, 128)       0           ['batch_normalization_358[0][0]']
#
#  activation_363 (Activation)    (None, 3, 128)       0           ['batch_normalization_363[0][0]']
#
#  conv1d_366 (Conv1D)            (None, 3, 128)       16384       ['activation_358[0][0]']
#
#  conv1d_371 (Conv1D)            (None, 3, 128)       114688      ['activation_363[0][0]']
#
#  batch_normalization_359 (Batch  (None, 3, 128)      9           ['conv1d_366[0][0]']
#  Normalization)
#
#  batch_normalization_364 (Batch  (None, 3, 128)      9           ['conv1d_371[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 3, 128)       0           ['batch_normalization_359[0][0]']
#
#  activation_364 (Activation)    (None, 3, 128)       0           ['batch_normalization_364[0][0]']
#
#  average_pooling1d_30 (AverageP  (None, 3, 768)      0           ['mixed3[0][0]']
#  ooling1D)
#
#  conv1d_364 (Conv1D)            (None, 3, 192)       147456      ['mixed3[0][0]']
#
#  conv1d_367 (Conv1D)            (None, 3, 192)       172032      ['activation_359[0][0]']
#
#  conv1d_372 (Conv1D)            (None, 3, 192)       24576       ['activation_364[0][0]']
#
#  conv1d_373 (Conv1D)            (None, 3, 192)       147456      ['average_pooling1d_30[0][0]']
#
#  batch_normalization_357 (Batch  (None, 3, 192)      9           ['conv1d_364[0][0]']
#  Normalization)
#
#  batch_normalization_360 (Batch  (None, 3, 192)      9           ['conv1d_367[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 3, 192)      9           ['conv1d_372[0][0]']
#  Normalization)
#
#  batch_normalization_366 (Batch  (None, 3, 192)      9           ['conv1d_373[0][0]']
#  Normalization)
#
#  activation_357 (Activation)    (None, 3, 192)       0           ['batch_normalization_357[0][0]']
#
#  activation_360 (Activation)    (None, 3, 192)       0           ['batch_normalization_360[0][0]']
#
#  activation_365 (Activation)    (None, 3, 192)       0           ['batch_normalization_365[0][0]']
#
#  activation_366 (Activation)    (None, 3, 192)       0           ['batch_normalization_366[0][0]']
#
#  mixed4 (Concatenate)           (None, 3, 768)       0           ['activation_357[0][0]',
#                                                                   'activation_360[0][0]',
#                                                                   'activation_365[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv1d_378 (Conv1D)            (None, 3, 160)       122880      ['mixed4[0][0]']
#
#  batch_normalization_371 (Batch  (None, 3, 160)      9           ['conv1d_378[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 3, 160)       0           ['batch_normalization_371[0][0]']
#
#  conv1d_379 (Conv1D)            (None, 3, 160)       179200      ['activation_371[0][0]']
#
#  batch_normalization_372 (Batch  (None, 3, 160)      9           ['conv1d_379[0][0]']
#  Normalization)
#
#  activation_372 (Activation)    (None, 3, 160)       0           ['batch_normalization_372[0][0]']
#
#  conv1d_375 (Conv1D)            (None, 3, 160)       122880      ['mixed4[0][0]']
#
#  conv1d_380 (Conv1D)            (None, 3, 160)       25600       ['activation_372[0][0]']
#
#  batch_normalization_368 (Batch  (None, 3, 160)      9           ['conv1d_375[0][0]']
#  Normalization)
#  batch_normalization_373 (Batch  (None, 3, 160)      9           ['conv1d_380[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 3, 160)       0           ['batch_normalization_368[0][0]']
#
#  activation_373 (Activation)    (None, 3, 160)       0           ['batch_normalization_373[0][0]']
#
#  conv1d_376 (Conv1D)            (None, 3, 160)       25600       ['activation_368[0][0]']
#
#  conv1d_381 (Conv1D)            (None, 3, 160)       179200      ['activation_373[0][0]']
#
#  batch_normalization_369 (Batch  (None, 3, 160)      9           ['conv1d_376[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 3, 160)      9           ['conv1d_381[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 3, 160)       0           ['batch_normalization_369[0][0]']
#
#  activation_374 (Activation)    (None, 3, 160)       0           ['batch_normalization_374[0][0]']
#
#  average_pooling1d_31 (AverageP  (None, 3, 768)      0           ['mixed4[0][0]']
#  ooling1D)
#
#  conv1d_374 (Conv1D)            (None, 3, 192)       147456      ['mixed4[0][0]']
#
#  conv1d_377 (Conv1D)            (None, 3, 192)       215040      ['activation_369[0][0]']
#
#  conv1d_382 (Conv1D)            (None, 3, 192)       30720       ['activation_374[0][0]']
#
#  conv1d_383 (Conv1D)            (None, 3, 192)       147456      ['average_pooling1d_31[0][0]']
#
#  batch_normalization_367 (Batch  (None, 3, 192)      9           ['conv1d_374[0][0]']
#  Normalization)
#
#  batch_normalization_370 (Batch  (None, 3, 192)      9           ['conv1d_377[0][0]']
#  Normalization)
#
#  batch_normalization_375 (Batch  (None, 3, 192)      9           ['conv1d_382[0][0]']
#  Normalization)
#
#  batch_normalization_376 (Batch  (None, 3, 192)      9           ['conv1d_383[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 3, 192)       0           ['batch_normalization_367[0][0]']
#
#  activation_370 (Activation)    (None, 3, 192)       0           ['batch_normalization_370[0][0]']
#
#  activation_375 (Activation)    (None, 3, 192)       0           ['batch_normalization_375[0][0]']
#
#  activation_376 (Activation)    (None, 3, 192)       0           ['batch_normalization_376[0][0]']
#
#  mixed5 (Concatenate)           (None, 3, 768)       0           ['activation_367[0][0]',
#                                                                   'activation_370[0][0]',
#                                                                   'activation_375[0][0]',
#                                                                   'activation_376[0][0]']
#
#  conv1d_388 (Conv1D)            (None, 3, 160)       122880      ['mixed5[0][0]']
#
#  batch_normalization_381 (Batch  (None, 3, 160)      9           ['conv1d_388[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 3, 160)       0           ['batch_normalization_381[0][0]']
#
#  conv1d_389 (Conv1D)            (None, 3, 160)       179200      ['activation_381[0][0]']
#
#  batch_normalization_382 (Batch  (None, 3, 160)      9           ['conv1d_389[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 3, 160)       0           ['batch_normalization_382[0][0]']
#
#  conv1d_385 (Conv1D)            (None, 3, 160)       122880      ['mixed5[0][0]']
#
#  conv1d_390 (Conv1D)            (None, 3, 160)       25600       ['activation_382[0][0]']
#
#  batch_normalization_378 (Batch  (None, 3, 160)      9           ['conv1d_385[0][0]']
#  Normalization)
#
#  batch_normalization_383 (Batch  (None, 3, 160)      9           ['conv1d_390[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 3, 160)       0           ['batch_normalization_378[0][0]']
#  activation_383 (Activation)    (None, 3, 160)       0           ['batch_normalization_383[0][0]']
#
#  conv1d_386 (Conv1D)            (None, 3, 160)       25600       ['activation_378[0][0]']
#
#  conv1d_391 (Conv1D)            (None, 3, 160)       179200      ['activation_383[0][0]']
#
#  batch_normalization_379 (Batch  (None, 3, 160)      9           ['conv1d_386[0][0]']
#  Normalization)
#
#  batch_normalization_384 (Batch  (None, 3, 160)      9           ['conv1d_391[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 3, 160)       0           ['batch_normalization_379[0][0]']
#
#  activation_384 (Activation)    (None, 3, 160)       0           ['batch_normalization_384[0][0]']
#
#  average_pooling1d_32 (AverageP  (None, 3, 768)      0           ['mixed5[0][0]']
#  ooling1D)
#
#  conv1d_384 (Conv1D)            (None, 3, 192)       147456      ['mixed5[0][0]']
#
#  conv1d_387 (Conv1D)            (None, 3, 192)       215040      ['activation_379[0][0]']
#
#  conv1d_392 (Conv1D)            (None, 3, 192)       30720       ['activation_384[0][0]']
#
#  conv1d_393 (Conv1D)            (None, 3, 192)       147456      ['average_pooling1d_32[0][0]']
#
#  batch_normalization_377 (Batch  (None, 3, 192)      9           ['conv1d_384[0][0]']
#  Normalization)
#
#  batch_normalization_380 (Batch  (None, 3, 192)      9           ['conv1d_387[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 3, 192)      9           ['conv1d_392[0][0]']
#  Normalization)
#
#  batch_normalization_386 (Batch  (None, 3, 192)      9           ['conv1d_393[0][0]']
#  Normalization)
#
#  activation_377 (Activation)    (None, 3, 192)       0           ['batch_normalization_377[0][0]']
#
#  activation_380 (Activation)    (None, 3, 192)       0           ['batch_normalization_380[0][0]']
#
#  activation_385 (Activation)    (None, 3, 192)       0           ['batch_normalization_385[0][0]']
#
#  activation_386 (Activation)    (None, 3, 192)       0           ['batch_normalization_386[0][0]']
#
#  mixed6 (Concatenate)           (None, 3, 768)       0           ['activation_377[0][0]',
#                                                                   'activation_380[0][0]',
#                                                                   'activation_385[0][0]',
#                                                                   'activation_386[0][0]']
#
#  conv1d_398 (Conv1D)            (None, 3, 192)       147456      ['mixed6[0][0]']
#
#  batch_normalization_391 (Batch  (None, 3, 192)      9           ['conv1d_398[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 3, 192)       0           ['batch_normalization_391[0][0]']
#
#  conv1d_399 (Conv1D)            (None, 3, 192)       258048      ['activation_391[0][0]']
#
#  batch_normalization_392 (Batch  (None, 3, 192)      9           ['conv1d_399[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 3, 192)       0           ['batch_normalization_392[0][0]']
#
#  conv1d_395 (Conv1D)            (None, 3, 192)       147456      ['mixed6[0][0]']
#
#  conv1d_400 (Conv1D)            (None, 3, 192)       36864       ['activation_392[0][0]']
#
#  batch_normalization_388 (Batch  (None, 3, 192)      9           ['conv1d_395[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 3, 192)      9           ['conv1d_400[0][0]']
#  Normalization)
# ...
#  conv1d_414 (Conv1D)            (None, 1, 448)       573440      ['mixed8[0][0]']
#
#  batch_normalization_407 (Batch  (None, 1, 448)      3           ['conv1d_414[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 1, 448)       0           ['batch_normalization_407[0][0]']
#
#  conv1d_411 (Conv1D)            (None, 1, 384)       491520      ['mixed8[0][0]']
#
#  conv1d_415 (Conv1D)            (None, 1, 384)       516096      ['activation_407[0][0]']
#
#  batch_normalization_404 (Batch  (None, 1, 384)      3           ['conv1d_411[0][0]']
#  Normalization)
#
#  batch_normalization_408 (Batch  (None, 1, 384)      3           ['conv1d_415[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 1, 384)       0           ['batch_normalization_404[0][0]']
#
#  activation_408 (Activation)    (None, 1, 384)       0           ['batch_normalization_408[0][0]']
#
#  conv1d_412 (Conv1D)            (None, 1, 384)       147456      ['activation_404[0][0]']
#
#  conv1d_413 (Conv1D)            (None, 1, 384)       442368      ['activation_404[0][0]']
#
#  conv1d_416 (Conv1D)            (None, 1, 384)       147456      ['activation_408[0][0]']
#
#  conv1d_417 (Conv1D)            (None, 1, 384)       442368      ['activation_408[0][0]']
#
#  average_pooling1d_34 (AverageP  (None, 1, 1280)     0           ['mixed8[0][0]']
#  ooling1D)
#
#  conv1d_410 (Conv1D)            (None, 1, 320)       409600      ['mixed8[0][0]']
#
#  batch_normalization_405 (Batch  (None, 1, 384)      3           ['conv1d_412[0][0]']
#  Normalization)
#
#  batch_normalization_406 (Batch  (None, 1, 384)      3           ['conv1d_413[0][0]']
#  Normalization)
#
#  batch_normalization_409 (Batch  (None, 1, 384)      3           ['conv1d_416[0][0]']
#  Normalization)
#
#  batch_normalization_410 (Batch  (None, 1, 384)      3           ['conv1d_417[0][0]']
#  Normalization)
#
#  conv1d_418 (Conv1D)            (None, 1, 192)       245760      ['average_pooling1d_34[0][0]']
#
#  batch_normalization_403 (Batch  (None, 1, 320)      3           ['conv1d_410[0][0]']
#  Normalization)
#
#  activation_405 (Activation)    (None, 1, 384)       0           ['batch_normalization_405[0][0]']
#
#  activation_406 (Activation)    (None, 1, 384)       0           ['batch_normalization_406[0][0]']
#
#  activation_409 (Activation)    (None, 1, 384)       0           ['batch_normalization_409[0][0]']
#
#  activation_410 (Activation)    (None, 1, 384)       0           ['batch_normalization_410[0][0]']
#
#  batch_normalization_411 (Batch  (None, 1, 192)      3           ['conv1d_418[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 1, 320)       0           ['batch_normalization_403[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 1, 768)       0           ['activation_405[0][0]',
#                                                                   'activation_406[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 1, 768)       0           ['activation_409[0][0]',
#                                                                   'activation_410[0][0]']
#
#  activation_411 (Activation)    (None, 1, 192)       0           ['batch_normalization_411[0][0]']
#
#  mixed9 (Concatenate)           (None, 1, 2048)      0           ['activation_403[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'activation_411[0][0]']
#
#  conv1d_423 (Conv1D)            (None, 1, 448)       917504      ['mixed9[0][0]']
#
#  batch_normalization_416 (Batch  (None, 1, 448)      3           ['conv1d_423[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 1, 448)       0           ['batch_normalization_416[0][0]']
#
#  conv1d_420 (Conv1D)            (None, 1, 384)       786432      ['mixed9[0][0]']
#
#  conv1d_424 (Conv1D)            (None, 1, 384)       516096      ['activation_416[0][0]']
#
#  batch_normalization_413 (Batch  (None, 1, 384)      3           ['conv1d_420[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 1, 384)      3           ['conv1d_424[0][0]']
#  Normalization)
#
#  activation_413 (Activation)    (None, 1, 384)       0           ['batch_normalization_413[0][0]']
#
#  activation_417 (Activation)    (None, 1, 384)       0           ['batch_normalization_417[0][0]']
#
#  conv1d_421 (Conv1D)            (None, 1, 384)       147456      ['activation_413[0][0]']
#
#  conv1d_422 (Conv1D)            (None, 1, 384)       442368      ['activation_413[0][0]']
#
#  conv1d_425 (Conv1D)            (None, 1, 384)       147456      ['activation_417[0][0]']
#
#  conv1d_426 (Conv1D)            (None, 1, 384)       442368      ['activation_417[0][0]']
#
#  average_pooling1d_35 (AverageP  (None, 1, 2048)     0           ['mixed9[0][0]']
#  ooling1D)
#
#  conv1d_419 (Conv1D)            (None, 1, 320)       655360      ['mixed9[0][0]']
#
#  batch_normalization_414 (Batch  (None, 1, 384)      3           ['conv1d_421[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 1, 384)      3           ['conv1d_422[0][0]']
#  Normalization)
#
#  batch_normalization_418 (Batch  (None, 1, 384)      3           ['conv1d_425[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 1, 384)      3           ['conv1d_426[0][0]']
#  Normalization)
#
#  conv1d_427 (Conv1D)            (None, 1, 192)       393216      ['average_pooling1d_35[0][0]']
#
#  batch_normalization_412 (Batch  (None, 1, 320)      3           ['conv1d_419[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 1, 384)       0           ['batch_normalization_414[0][0]']
#
#  activation_415 (Activation)    (None, 1, 384)       0           ['batch_normalization_415[0][0]']
#
#  activation_418 (Activation)    (None, 1, 384)       0           ['batch_normalization_418[0][0]']
#
#  activation_419 (Activation)    (None, 1, 384)       0           ['batch_normalization_419[0][0]']
#
#  batch_normalization_420 (Batch  (None, 1, 192)      3           ['conv1d_427[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 1, 320)       0           ['batch_normalization_412[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 768)       0           ['activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 1, 768)       0           ['activation_418[0][0]',
#                                                                   'activation_419[0][0]']
#
#  activation_420 (Activation)    (None, 1, 192)       0           ['batch_normalization_420[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 2048)      0           ['activation_412[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_420[0][0]']
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 1)            2049        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 14,302,912
# Trainable params: 14,302,166
# Non-trainable params: 746
# __________________________________________________________________________________________________
