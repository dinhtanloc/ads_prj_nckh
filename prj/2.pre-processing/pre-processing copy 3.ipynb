# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 3. Tiền xử lí dữ liệu

# %%
exps_dir = "../../exps"
if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
test_size=0.33
seed=42
data=pd.read_excel(f'{exps_dir}/data/data_EDA.xlsx')
data
# Out:
#     months_as_customer     age policy_state policy_csl  policy_deductable  \
# 0                    Y  Middle           OH    250/500               1000
# 1                    Y  Middle           IN    250/500               2000
# 2                    Y  Middle           OH    100/300               2000
# 3                    Y  Middle           IL    250/500               2000
# 4                    Y  Middle           IL   500/1000               1000
# ..                 ...     ...          ...        ...                ...
# 995                  N  Middle           OH   500/1000               1000
# 996                  Y  Middle           IL    100/300               1000
# 997                  Y  Middle           OH    250/500                500
# 998                  Y     Old           IL   500/1000               2000
# 999                  Y     Old           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# 0                  1406.91               0        MALE
# 1                  1197.22         5000000        MALE
# 2                  1413.14         5000000      FEMALE
# 3                  1415.74         6000000      FEMALE
# 4                  1583.91         6000000        MALE
# ..                     ...             ...         ...
# 995                1310.80               0      FEMALE
# 996                1436.79               0      FEMALE
# 997                1383.49         3000000      FEMALE
# 998                1356.92         5000000        MALE
# 999                 766.19               0      FEMALE
#
#     insured_education_level insured_occupation  ... fraud_reported  \
# 0                        MD       craft-repair  ...              Y
# 1                        MD  machine-op-inspct  ...              Y
# 2                       PhD              sales  ...              N
# 3                       PhD       armed-forces  ...              Y
# 4                 Associate              sales  ...              N
# ..                      ...                ...  ...            ...
# 995                 Masters       craft-repair  ...              N
# 996                     PhD     prof-specialty  ...              N
# 997                 Masters       armed-forces  ...              N
# 998               Associate  handlers-cleaners  ...              N
# 999               Associate              sales  ...              N
#
#     day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 0                     17                      10                   2014
# 1                     27                       6                   2006
# 2                      6                       9                   2000
# 3                     25                       5                   1990
# 4                      6                       6                   2014
# ..                   ...                     ...                    ...
# 995                   16                       7                   1991
# 996                    5                       1                   2014
# 997                   17                       2                   2003
# 998                   18                      11                   2011
# 999                   11                      11                   1996
#
#     day_incident_date month_incident_date year_incident_date  \
# 0                  25                   1               2015
# 1                  21                   1               2015
# 2                  22                   2               2015
# 3                  10                   1               2015
# 4                  17                   2               2015
# ..                ...                 ...                ...
# 995                22                   2               2015
# 996                24                   1               2015
# 997                23                   1               2015
# 998                26                   2               2015
# 999                26                   2               2015
#
#     week_incident_date high_week high_hour
# 0                    4         Y         N
# 1                    4         Y         N
# 2                    8         N         N
# 3                    2         N         N
# 4                    8         N         N
# ..                 ...       ...       ...
# 995                  8         N         N
# 996                  4         Y         N
# 997                  4         Y         N
# 998                  9         N         Y
# 999                  9         N         Y
#
# [1000 rows x 43 columns]

# %%
data_train, data_test = train_test_split(data, test_size = 0.33, random_state=seed)
print(data_train.shape,data_test.shape)
data_train.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/data/datatrain.xlsx', index=None)
data_test.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/data/datatest.xlsx', index=None)
# Out:
# (670, 43) (330, 43)

# %%
data_train
# Out:
#     months_as_customer     age policy_state policy_csl  policy_deductable  \
# 703                  Y  Middle           IL    250/500               1000
# 311                  N   Young           IN    100/300               2000
# 722                  Y  Middle           OH    100/300               2000
# 629                  Y  Middle           IL    100/300               2000
# 0                    Y  Middle           OH    250/500               1000
# ..                 ...     ...          ...        ...                ...
# 106                  Y     Old           OH   500/1000               1000
# 270                  Y     Old           OH    250/500               2000
# 860                  Y  Middle           IN    100/300               1000
# 435                  N  Middle           OH    250/500                500
# 102                  Y  Middle           IL    250/500                500
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# 703                 817.28               0        MALE
# 311                 765.64               0        MALE
# 722                1422.21               0      FEMALE
# 629                1133.27               0      FEMALE
# 0                  1406.91               0        MALE
# ..                     ...             ...         ...
# 106                1125.37               0      FEMALE
# 270                1589.54               0        MALE
# 860                1023.11               0      FEMALE
# 435                1075.41               0        MALE
# 102                1497.35               0      FEMALE
#
#     insured_education_level insured_occupation  ... fraud_reported  \
# 703             High School              sales  ...              Y
# 311                      MD              sales  ...              Y
# 722               Associate  handlers-cleaners  ...              Y
# 629             High School       craft-repair  ...              Y
# 0                        MD       craft-repair  ...              Y
# ..                      ...                ...  ...            ...
# 106               Associate     prof-specialty  ...              Y
# 270                 College  handlers-cleaners  ...              N
# 860                      MD       adm-clerical  ...              N
# 435                      MD  machine-op-inspct  ...              N
# 102                      JD     prof-specialty  ...              N
#
#     day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 703                   21                       6                   1994
# 311                   11                       6                   2008
# 722                   29                       7                   1996
# 629                   28                       5                   2014
# 0                     17                      10                   2014
# ..                   ...                     ...                    ...
# 106                    7                      10                   1990
# 270                   15                       4                   2013
# 860                   16                      11                   2004
# 435                   29                       8                   1999
# 102                    6                       6                   2001
#
#     day_incident_date month_incident_date year_incident_date  \
# 703                 3                   1               2015
# 311                16                   2               2015
# 722                16                   1               2015
# 629                 1                   3               2015
# 0                  25                   1               2015
# ..                ...                 ...                ...
# 106                13                   1               2015
# 270                27                   1               2015
# 860                 6                   2               2015
# 435                15                   2               2015
# 102                29                   1               2015
#
#     week_incident_date high_week high_hour
# 703                  1         N         N
# 311                  8         N         N
# 722                  3         Y         N
# 629                  9         N         N
# 0                    4         Y         N
# ..                 ...       ...       ...
# 106                  3         Y         Y
# 270                  5         Y         Y
# 860                  6         Y         N
# 435                  7         Y         Y
# 102                  5         Y         Y
#
# [670 rows x 43 columns]

# %%
outliers_list=dict(np.load(f'{exps_dir}/data/outliers.npz'))['outliers']
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# Áp dụng hàm cho các cột chứa dữ liệu cần loại bỏ ngoại lệ
for column in outliers_list:
    data_train = remove_outliers_iqr(data_train, column)
data_train
# Out:
#     months_as_customer     age policy_state policy_csl  policy_deductable  \
# 703                  Y  Middle           IL    250/500               1000
# 311                  N   Young           IN    100/300               2000
# 722                  Y  Middle           OH    100/300               2000
# 629                  Y  Middle           IL    100/300               2000
# 0                    Y  Middle           OH    250/500               1000
# ..                 ...     ...          ...        ...                ...
# 106                  Y     Old           OH   500/1000               1000
# 270                  Y     Old           OH    250/500               2000
# 860                  Y  Middle           IN    100/300               1000
# 435                  N  Middle           OH    250/500                500
# 102                  Y  Middle           IL    250/500                500
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# 703                 817.28               0        MALE
# 311                 765.64               0        MALE
# 722                1422.21               0      FEMALE
# 629                1133.27               0      FEMALE
# 0                  1406.91               0        MALE
# ..                     ...             ...         ...
# 106                1125.37               0      FEMALE
# 270                1589.54               0        MALE
# 860                1023.11               0      FEMALE
# 435                1075.41               0        MALE
# 102                1497.35               0      FEMALE
#
#     insured_education_level insured_occupation  ... fraud_reported  \
# 703             High School              sales  ...              Y
# 311                      MD              sales  ...              Y
# 722               Associate  handlers-cleaners  ...              Y
# 629             High School       craft-repair  ...              Y
# 0                        MD       craft-repair  ...              Y
# ..                      ...                ...  ...            ...
# 106               Associate     prof-specialty  ...              Y
# 270                 College  handlers-cleaners  ...              N
# 860                      MD       adm-clerical  ...              N
# 435                      MD  machine-op-inspct  ...              N
# 102                      JD     prof-specialty  ...              N
#
#     day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 703                   21                       6                   1994
# 311                   11                       6                   2008
# 722                   29                       7                   1996
# 629                   28                       5                   2014
# 0                     17                      10                   2014
# ..                   ...                     ...                    ...
# 106                    7                      10                   1990
# 270                   15                       4                   2013
# 860                   16                      11                   2004
# 435                   29                       8                   1999
# 102                    6                       6                   2001
#
#     day_incident_date month_incident_date year_incident_date  \
# 703                 3                   1               2015
# 311                16                   2               2015
# 722                16                   1               2015
# 629                 1                   3               2015
# 0                  25                   1               2015
# ..                ...                 ...                ...
# 106                13                   1               2015
# 270                27                   1               2015
# 860                 6                   2               2015
# 435                15                   2               2015
# 102                29                   1               2015
#
#     week_incident_date high_week high_hour
# 703                  1         N         N
# 311                  8         N         N
# 722                  3         Y         N
# 629                  9         N         N
# 0                    4         Y         N
# ..                 ...       ...       ...
# 106                  3         Y         Y
# 270                  5         Y         Y
# 860                  6         Y         N
# 435                  7         Y         Y
# 102                  5         Y         Y
#
# [656 rows x 43 columns]

# %%
(data_train=='?').sum()
# Out:
# months_as_customer               0
# age                              0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_type                    0
# collision_type                 112
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                235
# bodily_injuries                  0
# witnesses                        0
# police_report_available        207
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_make                        0
# auto_model                       0
# auto_year                        0
# fraud_reported                   0
# day_policy_bind_date             0
# month_policy_bind_date           0
# year_policy_bind_date            0
# day_incident_date                0
# month_incident_date              0
# year_incident_date               0
# week_incident_date               0
# high_week                        0
# high_hour                        0
# dtype: int64

# %%
data_train['collision_type']=data_train['collision_type'].replace('?',np.nan)
data_train['collision_type'].fillna(method='ffill',inplace=True)
data_train[['property_damage','police_report_available']]=data_train[['property_damage','police_report_available']].replace('?','Unknow')
(data_train=='?').sum()
# Out:
# months_as_customer             0
# age                            0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# day_policy_bind_date           0
# month_policy_bind_date         0
# year_policy_bind_date          0
# day_incident_date              0
# month_incident_date            0
# year_incident_date             0
# week_incident_date             0
# high_week                      0
# high_hour                      0
# dtype: int64

# %% [markdown]
# # 4.Chuẩn hóa dữ liệu

# %%
numeric_columns=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['numeric_columns']
numeric_columns
# Out:
# array(['policy_annual_premium', 'capital-gains', 'capital-loss',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim', 'day_policy_bind_date', 'month_policy_bind_date',
#        'year_policy_bind_date', 'day_incident_date',
#        'month_incident_date', 'year_incident_date', 'week_incident_date'],
#       dtype='<U22')

# %%
category_columns=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['category_columns']
category_columns
# Out:
# array(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage',
#        'bodily_injuries', 'witnesses', 'police_report_available',
#        'auto_make', 'auto_model', 'auto_year', 'fraud_reported',
#        'high_week', 'high_hour'], dtype='<U27')

# %%
label_encoders = {}
for column in category_columns:
    label_encoder = LabelEncoder()
    data_train[column] = label_encoder.fit_transform(data_train[column])
    label_encoders[column] = label_encoder  # Lưu trữ label encoder nếu cần sau này

scaler = MinMaxScaler()
data_train[numeric_columns] = scaler.fit_transform(data_train[numeric_columns])
data_train
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 703                   1    0             0           1                  1
# 311                   0    2             1           0                  2
# 722                   1    0             2           0                  2
# 629                   1    0             0           0                  2
# 0                     1    0             2           1                  1
# ..                  ...  ...           ...         ...                ...
# 106                   1    1             2           2                  1
# 270                   1    1             2           1                  2
# 860                   1    0             1           0                  1
# 435                   0    0             2           1                  0
# 102                   1    0             0           1                  0
#
#      policy_annual_premium  umbrella_limit  insured_sex  \
# 703               0.156407               0            1
# 311               0.116057               0            1
# 722               0.629083               0            0
# 629               0.403313               0            0
# 0                 0.617128               0            1
# ..                     ...             ...          ...
# 106               0.397140               0            0
# 270               0.759830               0            1
# 860               0.317237               0            0
# 435               0.358103               0            1
# 102               0.687795               0            0
#
#      insured_education_level  insured_occupation  ...  fraud_reported  \
# 703                        2                  11  ...               1
# 311                        4                  11  ...               1
# 722                        0                   5  ...               1
# 629                        2                   2  ...               1
# 0                          4                   2  ...               1
# ..                       ...                 ...  ...             ...
# 106                        0                   9  ...               1
# 270                        1                   5  ...               0
# 860                        4                   0  ...               0
# 435                        4                   6  ...               0
# 102                        3                   9  ...               0
#
#      day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 703              0.666667                0.454545               0.166667
# 311              0.333333                0.454545               0.750000
# 722              0.933333                0.545455               0.250000
# 629              0.900000                0.363636               1.000000
# 0                0.533333                0.818182               1.000000
# ..                    ...                     ...                    ...
# 106              0.200000                0.818182               0.000000
# 270              0.466667                0.272727               0.958333
# 860              0.500000                0.909091               0.583333
# 435              0.933333                0.636364               0.375000
# 102              0.166667                0.454545               0.458333
#
#      day_incident_date  month_incident_date  year_incident_date  \
# 703           0.066667                  0.0                 0.0
# 311           0.500000                  0.5                 0.0
# 722           0.500000                  0.0                 0.0
# 629           0.000000                  1.0                 0.0
# 0             0.800000                  0.0                 0.0
# ..                 ...                  ...                 ...
# 106           0.400000                  0.0                 0.0
# 270           0.866667                  0.0                 0.0
# 860           0.166667                  0.5                 0.0
# 435           0.466667                  0.5                 0.0
# 102           0.933333                  0.0                 0.0
#
#      week_incident_date  high_week  high_hour
# 703               0.000          0          0
# 311               0.875          0          0
# 722               0.250          1          0
# 629               1.000          0          0
# 0                 0.375          1          0
# ..                  ...        ...        ...
# 106               0.250          1          1
# 270               0.500          1          1
# 860               0.625          1          0
# 435               0.750          1          1
# 102               0.500          1          1
#
# [656 rows x 43 columns]

# %%
x_train=data_train.drop('fraud_reported',axis=1)
y_train=data_train['fraud_reported']
x_train.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/x_train.xlsx', index=False)
y_train.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/y_train.xlsx', index=False)

# %%
from sklearn.utils import resample


X_minority = x_train[y_train == 1]
X_oversampled, y_oversampled = resample(X_minority, y_train[y_train == 1], replace=True, n_samples=500, random_state=42)

print("Dữ liệu sau khi oversampling:")
print("X_oversampled:", X_oversampled.shape)
print("y_oversampled:", y_oversampled.shape)
# Out:
# Dữ liệu sau khi oversampling:
# X_oversampled: (500, 42)
# y_oversampled: (500,)

# %%
x_train = np.concatenate([X_oversampled, x_train[y_train == 0]], axis=0)
y_train = np.concatenate([y_oversampled, y_train[y_train == 0]], axis=0)
x_train.shape
x_train = pd.DataFrame(x_train)
y_train = pd.DataFrame(y_train)

x_train.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/x_train.xlsx', index=False)
y_train.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/y_train.xlsx', index=False)

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
#   965  966  967  968  969  970  971  972  973  974  975  976  978  979
#   980  982  984  985  986  987  988  989  990  991  992  994  995  996
#   998  999 1000]
# + valid_idx: [  1   4  13  14  20  21  27  32  34  35  40  47  52  58  62  64  71  80
#   85  87  91  95  98  99 102 105 106 121 128 130 134 138 156 159 160 161
#  166 170 187 189 191 200 201 205 206 214 216 217 230 240 241 242 243 251
#  252 269 270 273 276 288 295 308 313 315 330 337 339 343 345 366 372 378
#  379 385 387 389 391 392 397 401 406 413 418 427 435 454 455 458 459 460
#  461 466 471 474 475 476 484 489 491 492 498 502 504 508 510 520 524 540
#  546 553 555 556 560 561 562 563 564 565 566 573 574 577 592 600 612 614
#  642 646 647 654 661 663 674 681 683 686 690 698 699 700 701 702 719 724
#  725 726 727 729 733 738 742 747 748 763 766 768 769 771 772 775 776 779
#  782 791 794 795 804 805 812 815 818 821 831 838 839 840 848 849 856 858
#  860 862 871 875 878 879 881 891 897 898 938 945 955 958 963 977 981 983
#  993 997]
# + train / valid: [  1   4  13  14  20  21  27  32  34  35  40  47  52  58  62  64  71  80
#   85  87  91  95  98  99 102 105 106 121 128 130 134 138 156 159 160 161
#  166 170 187 189 191 200 201 205 206 214 216 217 230 240 241 242 243 251
#  252 269 270 273 276 288 295 308 313 315 330 337 339 343 345 366 372 378
#  379 385 387 389 391 392 397 401 406 413 418 427 435 454 455 458 459 460
#  461 466 471 474 475 476 484 489 491 492 498 502 504 508 510 520 524 540
#  546 553 555 556 560 561 562 563 564 565 566 573 574 577 592 600 612 614
#  642 646 647 654 661 663 674 681 683 686 690 698 699 700 701 702 719 724
#  725 726 727 729 733 738 742 747 748 763 766 768 769 771 772 775 776 779
#  782 791 794 795 804 805 812 815 818 821 831 838 839 840 848 849 856 858
#  860 862 871 875 878 879 881 891 897 898 938 945 955 958 963 977 981 983
#  993 997]

# %%
object_cols_test=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['category_columns']
numeric_cols_test=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['numeric_columns']
for column in outliers_list:
    data_test = remove_outliers_iqr(data_test, column)
data_test['collision_type'].replace('?',np.nan,inplace=True)
data_test['collision_type'].fillna(method='ffill',inplace=True)
data_test[['property_damage','police_report_available']].replace('?','Unknow',inplace=True)
(data_test=='?').sum()
label_encoders = {}
for column in object_cols_test:
    label_encoder = LabelEncoder()
    data_test[column] = label_encoder.fit_transform(data_test[column])
    label_encoders[column] = label_encoder  # Lưu trữ label encoder nếu cần sau này

scaler = MinMaxScaler()
data_test[numeric_cols_test] = scaler.fit_transform(data_test[numeric_cols_test])

x_test=data_test.drop('fraud_reported',axis=1)
y_test=data_test['fraud_reported']
data_test.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/df_test_minmax.xlsx', index=False)
x_test.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/x_test.xlsx', index=False)
y_test.to_excel(f'{exps_dir}/MinMax_Label/Oversampling/feature/y_test.xlsx', index=False)
