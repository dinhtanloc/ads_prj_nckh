# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [32, 32, 96], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='b')
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='c')

    x = conv_block(x, 3, [182, 182, 256], stage=3, block='a')
    x = identity_block(x, 3, [182, 182, 256], stage=3, block='b')
    x = identity_block(x, 3, [182, 182, 256], stage=3, block='c')
    # x = identity_block(x, 3, [182, 182, 256], stage=3, block='d')
    
    # x = conv_block(x, 3, [128, 128, 256], stage=4, block='a')
    # x = identity_block(x, 3, [128, 128, 256], stage=4, block='b')
    # x = identity_block(x, 3, [128, 128, 256], stage=4, block='c')
    # # x = identity_block(x, 3, [128, 128, 256], stage=4, block='d')
    # # x = identity_block(x, 3, [128, 128, 256], stage=4, block='e')
    # # x = identity_block(x, 3,  [128, 128, 256], stage=4, block='f')

    # # x = conv_block(x, 3, [256, 256, 384], stage=5, block='a')
    # # x = identity_block(x, 3, [256, 256, 384], stage=5, block='b')
    # # x = identity_block(x, 3, [256, 256, 384], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalMaxPooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.95,
    patience=5,
    min_lr=0.000001,
    verbose=1,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5",monitor='val_loss',mode='min', verbose = 1, save_best_only=True)

resNet50=build_model()
resNet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 182)       17654       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 182)       0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 182)       0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 256)       24832       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 256)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 256)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 256)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 182)       46774       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 182)       0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 182)       0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 256)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 256)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 182)       46774       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 182)       0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 182)       0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 256)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 256)       0           ['add_5[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['activation_18[0][0]']
#  xPooling1D)
#
#  fc1000 (Dense)                 (None, 2)            514         ['global_max_pooling1d[0][0]']
#
# ==================================================================================================
# Total params: 610,466
# Trainable params: 610,038
# Non-trainable params: 428
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 7s 82ms/step - loss: 2.7471 - accuracy: 0.5090 - f1_score: 0.5088 - val_loss: 0.6439 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.7960 - accuracy: 0.5389 - f1_score: 0.5360 - val_loss: 0.7125 - val_accuracy: 0.5741 - val_f1_score: 0.4844 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.6678 - accuracy: 0.6038 - f1_score: 0.6046 - val_loss: 0.9273 - val_accuracy: 0.3272 - val_f1_score: 0.3151 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5811 - accuracy: 0.6547 - f1_score: 0.6570 - val_loss: 0.7518 - val_accuracy: 0.5247 - val_f1_score: 0.4818 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.5563 - accuracy: 0.6796 - f1_score: 0.6789 - val_loss: 0.7817 - val_accuracy: 0.4568 - val_f1_score: 0.4245 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5284 - accuracy: 0.7365 - f1_score: 0.7365
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 16/16 [==============================] - 1s 34ms/step - loss: 0.5306 - accuracy: 0.7305 - f1_score: 0.7276 - val_loss: 0.7172 - val_accuracy: 0.5617 - val_f1_score: 0.5130 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4630 - accuracy: 0.7595 - f1_score: 0.7595 - val_loss: 0.7296 - val_accuracy: 0.5154 - val_f1_score: 0.5130 - lr: 9.5000e-04
# Epoch 8/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.4214 - accuracy: 0.7705 - f1_score: 0.7723 - val_loss: 0.5670 - val_accuracy: 0.7130 - val_f1_score: 0.6797 - lr: 9.5000e-04
# Epoch 9/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3388 - accuracy: 0.8234 - f1_score: 0.8231 - val_loss: 0.5661 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 9.5000e-04
# Epoch 10/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.3029 - accuracy: 0.8553 - f1_score: 0.8574 - val_loss: 0.5781 - val_accuracy: 0.7222 - val_f1_score: 0.6875 - lr: 9.5000e-04
# Epoch 11/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2358 - accuracy: 0.9022 - f1_score: 0.9007 - val_loss: 0.7075 - val_accuracy: 0.6080 - val_f1_score: 0.5911 - lr: 9.5000e-04
# Epoch 12/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2563 - accuracy: 0.8852 - f1_score: 0.8872 - val_loss: 0.5935 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 9.5000e-04
# Epoch 13/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1780 - accuracy: 0.9162 - f1_score: 0.9164 - val_loss: 0.6271 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 9.5000e-04
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1456 - accuracy: 0.9427 - f1_score: 0.9427
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1517 - accuracy: 0.9401 - f1_score: 0.9388 - val_loss: 0.6522 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 9.5000e-04
# Epoch 15/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1150 - accuracy: 0.9491 - f1_score: 0.9502 - val_loss: 0.6767 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 9.0250e-04
# Epoch 16/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1182 - accuracy: 0.9521 - f1_score: 0.9516 - val_loss: 0.8894 - val_accuracy: 0.5772 - val_f1_score: 0.6042 - lr: 9.0250e-04
# Epoch 17/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2141 - accuracy: 0.8962 - f1_score: 0.8969 - val_loss: 0.8682 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 9.0250e-04
# Epoch 18/10000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1347 - accuracy: 0.9481 - f1_score: 0.9477 - val_loss: 0.9394 - val_accuracy: 0.5895 - val_f1_score: 0.6536 - lr: 9.0250e-04
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1191 - accuracy: 0.9552 - f1_score: 0.9552
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1210 - accuracy: 0.9531 - f1_score: 0.9521 - val_loss: 0.9585 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 9.0250e-04
# Epoch 20/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0810 - accuracy: 0.9731 - f1_score: 0.9721 - val_loss: 0.9946 - val_accuracy: 0.6667 - val_f1_score: 0.6797 - lr: 8.5737e-04
# Epoch 21/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0685 - accuracy: 0.9681 - f1_score: 0.9672 - val_loss: 1.0360 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 8.5737e-04
# Epoch 22/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0556 - accuracy: 0.9760 - f1_score: 0.9766 - val_loss: 1.1459 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 8.5737e-04
# Epoch 23/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0919 - accuracy: 0.9681 - f1_score: 0.9682 - val_loss: 1.3469 - val_accuracy: 0.5741 - val_f1_score: 0.5625 - lr: 8.5737e-04
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0798 - accuracy: 0.9656 - f1_score: 0.9656
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0779 - accuracy: 0.9661 - f1_score: 0.9663 - val_loss: 1.4030 - val_accuracy: 0.5833 - val_f1_score: 0.6094 - lr: 8.5737e-04
# Epoch 25/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0287 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 1.3281 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 8.1451e-04
# Epoch 26/10000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0139 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 1.5544 - val_accuracy: 0.7191 - val_f1_score: 0.7240 - lr: 8.1451e-04
# Epoch 27/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0051 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.5056 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 8.1451e-04
# Epoch 28/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0044 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.6140 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 8.1451e-04
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0060 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6029 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 8.1451e-04
# Epoch 30/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0029 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.7479 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 7.7378e-04
# Epoch 31/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0058 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.9252 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 7.7378e-04
# Epoch 32/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0049 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1523 - val_accuracy: 0.6204 - val_f1_score: 0.6797 - lr: 7.7378e-04
# Epoch 33/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0227 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 2.2486 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 7.7378e-04
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0407 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0394 - accuracy: 0.9850 - f1_score: 0.9854 - val_loss: 2.2675 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 7.7378e-04
# Epoch 35/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0864 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 1.9554 - val_accuracy: 0.6019 - val_f1_score: 0.6641 - lr: 7.3509e-04
# Epoch 36/10000
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0810 - accuracy: 0.9641 - f1_score: 0.9638 - val_loss: 2.5449 - val_accuracy: 0.5370 - val_f1_score: 0.5703 - lr: 7.3509e-04
# Epoch 37/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0613 - accuracy: 0.9780 - f1_score: 0.9780 - val_loss: 2.5990 - val_accuracy: 0.5586 - val_f1_score: 0.5885 - lr: 7.3509e-04
# Epoch 38/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0644 - accuracy: 0.9760 - f1_score: 0.9761 - val_loss: 2.1146 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 7.3509e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0274 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0270 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 2.0378 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 7.3509e-04
# Epoch 40/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0293 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 2.5409 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 6.9834e-04
# Epoch 41/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1059 - accuracy: 0.9621 - f1_score: 0.9608 - val_loss: 3.2171 - val_accuracy: 0.4784 - val_f1_score: 0.5208 - lr: 6.9834e-04
# Epoch 42/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0487 - accuracy: 0.9830 - f1_score: 0.9834 - val_loss: 1.5762 - val_accuracy: 0.6327 - val_f1_score: 0.6901 - lr: 6.9834e-04
# Epoch 43/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0179 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9219 - val_accuracy: 0.6451 - val_f1_score: 0.7005 - lr: 6.9834e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0118 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0113 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 2.0629 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 6.9834e-04
# Epoch 45/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0078 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9366 - val_accuracy: 0.6728 - val_f1_score: 0.6849 - lr: 6.6342e-04
# Epoch 46/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0034 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9513 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 6.6342e-04
# Epoch 47/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0086 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9934 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 6.6342e-04
# Epoch 48/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0057 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0722 - val_accuracy: 0.6358 - val_f1_score: 0.6536 - lr: 6.6342e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0079 - accuracy: 0.9960 - f1_score: 0.9951 - val_loss: 2.0993 - val_accuracy: 0.6296 - val_f1_score: 0.6484 - lr: 6.6342e-04
# Epoch 50/10000
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0108 - accuracy: 0.9980 - f1_score: 0.9975 - val_loss: 2.5422 - val_accuracy: 0.6327 - val_f1_score: 0.6901 - lr: 6.3025e-04
# Epoch 51/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0233 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 2.4936 - val_accuracy: 0.5895 - val_f1_score: 0.6146 - lr: 6.3025e-04
# Epoch 52/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0160 - accuracy: 0.9930 - f1_score: 0.9932 - val_loss: 2.0376 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 6.3025e-04
# Epoch 53/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0046 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3116 - val_accuracy: 0.6204 - val_f1_score: 0.6797 - lr: 6.3025e-04
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9870 - f1_score: 0.9868
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0330 - accuracy: 0.9870 - f1_score: 0.9868 - val_loss: 2.0781 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 6.3025e-04
# Epoch 55/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0291 - accuracy: 0.9860 - f1_score: 0.9863 - val_loss: 2.1269 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 5.9874e-04
# Epoch 56/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0352 - accuracy: 0.9860 - f1_score: 0.9863 - val_loss: 2.6760 - val_accuracy: 0.6080 - val_f1_score: 0.6693 - lr: 5.9874e-04
# Epoch 57/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0265 - accuracy: 0.9910 - f1_score: 0.9907 - val_loss: 2.5169 - val_accuracy: 0.6204 - val_f1_score: 0.6797 - lr: 5.9874e-04
# Epoch 58/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0169 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 2.1258 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 5.9874e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0038 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0037 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1696 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 5.9874e-04
# Epoch 60/10000
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2541 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 5.6880e-04
# Epoch 61/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2850 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.6880e-04
# Epoch 62/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2805 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 5.6880e-04
# Epoch 63/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 4.2460e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2875 - val_accuracy: 0.6389 - val_f1_score: 0.6562 - lr: 5.6880e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.7884e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
# 16/16 [==============================] - 1s 35ms/step - loss: 5.7207e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2948 - val_accuracy: 0.6389 - val_f1_score: 0.6562 - lr: 5.6880e-04
# Epoch 65/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 4.2484e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3136 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 5.4036e-04
# Epoch 66/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 3.7932e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3412 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.4036e-04
# Epoch 67/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 3.7748e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3596 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 5.4036e-04
# Epoch 68/10000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0010 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3980 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 5.4036e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.0076e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
# 16/16 [==============================] - 1s 31ms/step - loss: 4.1959e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4274 - val_accuracy: 0.6636 - val_f1_score: 0.6771 - lr: 5.4036e-04
# Epoch 70/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 5.0488e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4442 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 71/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 1.6293e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4686 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 72/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 2.0944e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4932 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 73/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 1.8750e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5035 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9235e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
# 16/16 [==============================] - 1s 35ms/step - loss: 2.8639e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5231 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 75/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 1.4947e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5454 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 4.8767e-04
# Epoch 76/10000
# 16/16 [==============================] - 1s 40ms/step - loss: 1.0412e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5603 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 4.8767e-04
# Epoch 77/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 1.7732e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5712 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 4.8767e-04
# Epoch 78/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 2.0531e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5744 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 4.8767e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.6524e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
# 16/16 [==============================] - 1s 32ms/step - loss: 1.0569e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5894 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 4.8767e-04
# Epoch 80/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 9.9277e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6035 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.6329e-04
# Epoch 81/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 1.0652e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6220 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 4.6329e-04
# Epoch 82/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 6.7571e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6334 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 4.6329e-04
# Epoch 83/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 8.1251e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6460 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 4.6329e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.9681e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
# 16/16 [==============================] - 1s 31ms/step - loss: 8.7821e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6568 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 4.6329e-04
# Epoch 85/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 7.9250e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6646 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.4013e-04
# Epoch 86/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 6.1716e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6727 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.4013e-04
# Epoch 87/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 7.1060e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6838 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.4013e-04
# Epoch 88/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 1.2633e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6984 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.4013e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.2208e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
# 16/16 [==============================] - 1s 31ms/step - loss: 6.4315e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7106 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.4013e-04
# Epoch 90/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 1.0923e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7146 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.1812e-04
# Epoch 91/10000
# 16/16 [==============================] - 1s 36ms/step - loss: 6.2829e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7294 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 4.1812e-04
# Epoch 92/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 7.9105e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7422 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.1812e-04
# Epoch 93/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 8.6548e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7586 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.1812e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.8624e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
# 16/16 [==============================] - 1s 32ms/step - loss: 4.9156e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7710 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 4.1812e-04
# Epoch 95/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 5.0270e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7832 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.9721e-04
# Epoch 96/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 6.4309e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7949 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.9721e-04
# Epoch 97/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 5.4107e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8018 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.9721e-04
# Epoch 98/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 3.8590e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8112 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.9721e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.4100e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
# 16/16 [==============================] - 1s 36ms/step - loss: 4.2617e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8224 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.9721e-04
# Epoch 100/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 6.1070e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8312 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.7735e-04
# Epoch 101/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 3.5177e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8393 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.7735e-04
# Epoch 102/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 3.4999e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8483 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.7735e-04
# Epoch 103/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 3.2873e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8572 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.7735e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.2692e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
# 16/16 [==============================] - 1s 32ms/step - loss: 3.3575e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8670 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.7735e-04
# Epoch 105/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 5.7385e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8751 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 3.5849e-04
# Epoch 106/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 4.1455e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8845 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.5849e-04
# Epoch 107/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 3.7156e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8933 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.5849e-04
# Epoch 108/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 5.9939e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9001 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.5849e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.5693e-05 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 9.
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 0.00034056155709549785.
# 16/16 [==============================] - 1s 33ms/step - loss: 3.5595e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9044 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 3.5849e-04
# Epoch 109: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 5ms/step
# 0.7314814814814815

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7314814814814815
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.45      0.12      0.19        85
#            0       0.75      0.95      0.84       239
#
#     accuracy                           0.73       324
#    macro avg       0.60      0.53      0.51       324
# weighted avg       0.67      0.73      0.67       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 237 chiếm khoảng 73.14814814814815% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 10 chiếm khoảng 11.76470588235294% so với thực tế
