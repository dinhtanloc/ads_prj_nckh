# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [32, 32, 96], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='b')
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='c')

    x = conv_block(x, 3, [182, 182, 256], stage=3, block='a')
    x = identity_block(x, 3, [182, 182, 256], stage=3, block='b')
    x = identity_block(x, 3, [182, 182, 256], stage=3, block='c')
    x = identity_block(x, 3, [182, 182, 256], stage=3, block='d')
    
    # x = conv_block(x, 3, [128, 128, 256], stage=4, block='a')
    # x = identity_block(x, 3, [128, 128, 256], stage=4, block='b')
    # x = identity_block(x, 3, [128, 128, 256], stage=4, block='c')
    # # x = identity_block(x, 3, [128, 128, 256], stage=4, block='d')
    # # x = identity_block(x, 3, [128, 128, 256], stage=4, block='e')
    # # x = identity_block(x, 3,  [128, 128, 256], stage=4, block='f')

    # # x = conv_block(x, 3, [256, 256, 384], stage=5, block='a')
    # # x = identity_block(x, 3, [256, 256, 384], stage=5, block='b')
    # # x = identity_block(x, 3, [256, 256, 384], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalMaxPooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.95,
    patience=5,
    min_lr=0.000001,
    verbose=1,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5",monitor='val_loss',mode='min', verbose = 1, save_best_only=True)

resNet50=build_model()
resNet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 182)       17654       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 182)       0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 182)       0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 256)       24832       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 256)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 256)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 256)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 182)       46774       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 182)       0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 182)       0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 256)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 256)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 182)       46774       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 182)       0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 182)       0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 256)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 256)       0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 5, 182)       46774       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 5, 182)      20          ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 5, 182)       0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 5, 182)       99554       ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 5, 182)      20          ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 5, 182)       0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)        (None, 5, 256)       46848       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 5, 256)      20          ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 5, 256)       0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 5, 256)       0           ['add_6[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['activation_21[0][0]']
#  xPooling1D)
#
#  fc1000 (Dense)                 (None, 2)            514         ['global_max_pooling1d[0][0]']
#
# ==================================================================================================
# Total params: 803,702
# Trainable params: 803,244
# Non-trainable params: 458
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpointer],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.0781 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 1: val_loss improved from inf to 2.03951, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 8s 119ms/step - loss: 2.0340 - accuracy: 0.4990 - f1_score: 0.4985 - val_loss: 2.0395 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7253 - accuracy: 0.5020 - f1_score: 0.5025
# Epoch 2: val_loss improved from 2.03951 to 0.96684, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 53ms/step - loss: 0.7253 - accuracy: 0.5020 - f1_score: 0.5025 - val_loss: 0.9668 - val_accuracy: 0.3488 - val_f1_score: 0.3333 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7191 - accuracy: 0.5396 - f1_score: 0.5396
# Epoch 3: val_loss improved from 0.96684 to 0.65133, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 51ms/step - loss: 0.7146 - accuracy: 0.5399 - f1_score: 0.5401 - val_loss: 0.6513 - val_accuracy: 0.5926 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6724 - accuracy: 0.6042 - f1_score: 0.6042
# Epoch 4: val_loss did not improve from 0.65133
# 16/16 [==============================] - 1s 37ms/step - loss: 0.6753 - accuracy: 0.5948 - f1_score: 0.5902 - val_loss: 0.6530 - val_accuracy: 0.6111 - val_f1_score: 0.5156 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6134 - accuracy: 0.6510 - f1_score: 0.6510
# Epoch 5: val_loss did not improve from 0.65133
# 16/16 [==============================] - 1s 38ms/step - loss: 0.6119 - accuracy: 0.6487 - f1_score: 0.6476 - val_loss: 0.6896 - val_accuracy: 0.6019 - val_f1_score: 0.5078 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6261 - accuracy: 0.6604 - f1_score: 0.6604
# Epoch 6: val_loss did not improve from 0.65133
# 16/16 [==============================] - 1s 37ms/step - loss: 0.6290 - accuracy: 0.6637 - f1_score: 0.6653 - val_loss: 0.9221 - val_accuracy: 0.4815 - val_f1_score: 0.4453 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7412 - accuracy: 0.6677 - f1_score: 0.6677
# Epoch 7: val_loss did not improve from 0.65133
# 16/16 [==============================] - 1s 37ms/step - loss: 0.7331 - accuracy: 0.6667 - f1_score: 0.6662 - val_loss: 0.7322 - val_accuracy: 0.5679 - val_f1_score: 0.5964 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4423 - accuracy: 0.7688 - f1_score: 0.7687
# Epoch 8: val_loss improved from 0.65133 to 0.58697, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 51ms/step - loss: 0.4485 - accuracy: 0.7675 - f1_score: 0.7668 - val_loss: 0.5870 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4064 - accuracy: 0.7934 - f1_score: 0.7943
# Epoch 9: val_loss did not improve from 0.58697
# 16/16 [==============================] - 1s 39ms/step - loss: 0.4064 - accuracy: 0.7934 - f1_score: 0.7943 - val_loss: 0.6039 - val_accuracy: 0.6636 - val_f1_score: 0.6380 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3467 - accuracy: 0.8302 - f1_score: 0.8302
# Epoch 10: val_loss did not improve from 0.58697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3560 - accuracy: 0.8253 - f1_score: 0.8230 - val_loss: 0.5919 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3130 - accuracy: 0.8573 - f1_score: 0.8573
# Epoch 11: val_loss improved from 0.58697 to 0.55697, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 51ms/step - loss: 0.3180 - accuracy: 0.8523 - f1_score: 0.8498 - val_loss: 0.5570 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3063 - accuracy: 0.8594 - f1_score: 0.8594
# Epoch 12: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3109 - accuracy: 0.8573 - f1_score: 0.8563 - val_loss: 0.6725 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2925 - accuracy: 0.8833 - f1_score: 0.8833
# Epoch 13: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3002 - accuracy: 0.8792 - f1_score: 0.8772 - val_loss: 0.5978 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2401 - accuracy: 0.8896 - f1_score: 0.8896
# Epoch 14: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2427 - accuracy: 0.8902 - f1_score: 0.8905 - val_loss: 0.6283 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1940 - accuracy: 0.9115 - f1_score: 0.9115
# Epoch 15: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1912 - accuracy: 0.9132 - f1_score: 0.9140 - val_loss: 0.6345 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1872 - accuracy: 0.9219 - f1_score: 0.9219
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
#
# Epoch 16: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1912 - accuracy: 0.9222 - f1_score: 0.9223 - val_loss: 0.6251 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1744 - accuracy: 0.9240 - f1_score: 0.9240
# Epoch 17: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1727 - accuracy: 0.9251 - f1_score: 0.9257 - val_loss: 0.6400 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 9.5000e-04
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1408 - accuracy: 0.9417 - f1_score: 0.9417
# Epoch 18: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1383 - accuracy: 0.9431 - f1_score: 0.9438 - val_loss: 0.7381 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 9.5000e-04
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1317 - accuracy: 0.9458 - f1_score: 0.9458
# Epoch 19: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1407 - accuracy: 0.9431 - f1_score: 0.9418 - val_loss: 0.8470 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 9.5000e-04
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1294 - accuracy: 0.9354 - f1_score: 0.9354
# Epoch 20: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1285 - accuracy: 0.9371 - f1_score: 0.9380 - val_loss: 0.7656 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 9.5000e-04
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1171 - accuracy: 0.9510 - f1_score: 0.9510
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
#
# Epoch 21: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1144 - accuracy: 0.9511 - f1_score: 0.9511 - val_loss: 0.8677 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 9.5000e-04
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0847 - accuracy: 0.9656 - f1_score: 0.9656
# Epoch 22: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0882 - accuracy: 0.9621 - f1_score: 0.9603 - val_loss: 1.1500 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 9.0250e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9731 - f1_score: 0.9726
# Epoch 23: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0628 - accuracy: 0.9731 - f1_score: 0.9726 - val_loss: 1.1456 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 9.0250e-04
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0821 - accuracy: 0.9698 - f1_score: 0.9698
# Epoch 24: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0794 - accuracy: 0.9711 - f1_score: 0.9717 - val_loss: 1.5493 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 9.0250e-04
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0826 - accuracy: 0.9563 - f1_score: 0.9563
# Epoch 25: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0928 - accuracy: 0.9551 - f1_score: 0.9545 - val_loss: 1.1914 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 9.0250e-04
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1163 - accuracy: 0.9438 - f1_score: 0.9437
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
#
# Epoch 26: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1152 - accuracy: 0.9441 - f1_score: 0.9443 - val_loss: 1.5703 - val_accuracy: 0.6049 - val_f1_score: 0.6276 - lr: 9.0250e-04
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1026 - accuracy: 0.9521 - f1_score: 0.9521
# Epoch 27: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1066 - accuracy: 0.9531 - f1_score: 0.9536 - val_loss: 1.2673 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 8.5737e-04
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0793 - accuracy: 0.9677 - f1_score: 0.9677
# Epoch 28: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0786 - accuracy: 0.9661 - f1_score: 0.9653 - val_loss: 1.1348 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 8.5737e-04
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0708 - accuracy: 0.9688 - f1_score: 0.9688
# Epoch 29: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0747 - accuracy: 0.9681 - f1_score: 0.9677 - val_loss: 1.1634 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 8.5737e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9681 - f1_score: 0.9672
# Epoch 30: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0747 - accuracy: 0.9681 - f1_score: 0.9672 - val_loss: 1.1472 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 8.5737e-04
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0529 - accuracy: 0.9760 - f1_score: 0.9760
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
#
# Epoch 31: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0528 - accuracy: 0.9760 - f1_score: 0.9761 - val_loss: 1.4699 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 8.5737e-04
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1091 - accuracy: 0.9604 - f1_score: 0.9604
# Epoch 32: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1084 - accuracy: 0.9591 - f1_score: 0.9584 - val_loss: 1.8032 - val_accuracy: 0.6235 - val_f1_score: 0.6432 - lr: 8.1451e-04
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1018 - accuracy: 0.9583 - f1_score: 0.9583
# Epoch 33: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1035 - accuracy: 0.9561 - f1_score: 0.9550 - val_loss: 1.6182 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 8.1451e-04
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9823 - f1_score: 0.9823
# Epoch 34: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0432 - accuracy: 0.9820 - f1_score: 0.9819 - val_loss: 1.4049 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 8.1451e-04
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0261 - accuracy: 0.9885 - f1_score: 0.9885
# Epoch 35: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0258 - accuracy: 0.9890 - f1_score: 0.9893 - val_loss: 1.5430 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 8.1451e-04
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0352 - accuracy: 0.9823 - f1_score: 0.9823
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
#
# Epoch 36: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0340 - accuracy: 0.9830 - f1_score: 0.9834 - val_loss: 1.6916 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 8.1451e-04
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0264 - accuracy: 0.9927 - f1_score: 0.9927
# Epoch 37: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0258 - accuracy: 0.9930 - f1_score: 0.9932 - val_loss: 2.2308 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 7.7378e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0286 - accuracy: 0.9875 - f1_score: 0.9875
# Epoch 38: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0300 - accuracy: 0.9870 - f1_score: 0.9868 - val_loss: 1.9229 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 7.7378e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0197 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 39: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0194 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 1.7801 - val_accuracy: 0.6667 - val_f1_score: 0.6797 - lr: 7.7378e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0352 - accuracy: 0.9865 - f1_score: 0.9865
# Epoch 40: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0482 - accuracy: 0.9850 - f1_score: 0.9843 - val_loss: 2.4731 - val_accuracy: 0.6019 - val_f1_score: 0.6250 - lr: 7.7378e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0405 - accuracy: 0.9771 - f1_score: 0.9771
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
#
# Epoch 41: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0390 - accuracy: 0.9780 - f1_score: 0.9785 - val_loss: 1.4572 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 7.7378e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0244 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 42: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0235 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 1.6426 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 7.3509e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0150 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 43: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0147 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 1.8789 - val_accuracy: 0.6667 - val_f1_score: 0.6797 - lr: 7.3509e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 44: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0039 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9375 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 7.3509e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 45: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0020 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0975 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 7.3509e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
#
# Epoch 46: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0856 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 7.3509e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.5049e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 47: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 5.4831e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0833 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 6.9834e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.1672e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 48: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 5.0165e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1105 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 6.9834e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.0120e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 49: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 3.8769e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1256 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 6.9834e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.8059e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 50: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 2.9567e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1275 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 6.9834e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.7427e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
#
# Epoch 51: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 5.5289e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1304 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 6.9834e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.6871e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 52: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 2.6506e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0843 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 6.6342e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.1867e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 4.4181e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1156 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 6.6342e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5655e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 2.5305e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1453 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 6.6342e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.2838e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 55: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 2.2563e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1601 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 6.6342e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4639e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
#
# Epoch 56: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 37ms/step - loss: 2.3798e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1739 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 6.6342e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9709e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 1.9237e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1934 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 6.3025e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9321e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 58: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 1.9144e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2267 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 6.3025e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3658e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 59: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 1.3231e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2404 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 6.3025e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5161e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 60: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 1.6192e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2505 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 6.3025e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7333e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
#
# Epoch 61: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 1.6720e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2529 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 6.3025e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0093e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 1.2064e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2706 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.9874e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.7428e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 9.5209e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2809 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.9874e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.3851e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 4.2163e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2915 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 5.9874e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6146e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 1.5694e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3238 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 5.9874e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.6475e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
#
# Epoch 66: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 3.6197e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3640 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 5.9874e-04
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.4666e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 1.4666e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3973 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.6880e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.2597e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 68: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 7.9988e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4366 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.6880e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.5026e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 7.3182e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4400 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.6880e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.7740e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 8.8415e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4342 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 5.6880e-04
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 7.8035e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
#
# Epoch 71: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 7.8035e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4405 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.6880e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.2321e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 3.1513e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4957 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.4036e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1719e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1959e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5411 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 5.4036e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.5007e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 1.0856e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5172 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.4036e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.2668e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 5.1908e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5182 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.4036e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.7468e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
#
# Epoch 76: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 3.6022e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4144 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 5.4036e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5247e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 2.5732e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4215 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 5.1334e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.1366e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 6.1459e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4437 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 5.1334e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.9520e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 6.7350e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4748 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.1334e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5346e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 1.5132e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5383 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 5.1334e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.3427e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
#
# Epoch 81: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 4.8020e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5562 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 5.1334e-04
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.2472e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 5.2472e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5415 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.8767e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7957e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 5.0722e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5413 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.8767e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.0570e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 4.2276e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5434 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.8767e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.9949e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 85: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 5.7800e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5467 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 4.8767e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.6091e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
#
# Epoch 86: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 3.5008e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5505 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 4.8767e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.7698e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 3.7458e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5579 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 4.6329e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.9694e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 4.3201e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5673 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 4.6329e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5726e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 38ms/step - loss: 4.4998e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5773 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 4.6329e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.0590e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 7.3107e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5710 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 4.6329e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.8446e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
#
# Epoch 91: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 39ms/step - loss: 3.7243e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5770 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 4.6329e-04
# Epoch 92/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2736e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 3.2736e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5870 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.4013e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5522e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 2.8270e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5966 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.4013e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.8830e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 40ms/step - loss: 3.8120e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5944 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 4.4013e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.8468e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 2.7786e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5969 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 4.4013e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.9394e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
#
# Epoch 96: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 3.9142e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6088 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 4.4013e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.1391e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 45ms/step - loss: 3.1107e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6211 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.1812e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9999e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 2.8836e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6273 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 4.1812e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.2585e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 2.2006e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6318 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.1812e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.3491e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 2.3298e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6355 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 4.1812e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.2358e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
#
# Epoch 101: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 4.2241e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6538 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 4.1812e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4489e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 44ms/step - loss: 2.4587e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6629 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.9721e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4150e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 2.3883e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6694 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.9721e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.7957e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 41ms/step - loss: 5.7058e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6721 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.9721e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.2046e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 2.1541e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6796 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.9721e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.8101e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
#
# Epoch 106: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 43ms/step - loss: 4.6419e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6793 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 3.9721e-04
# Epoch 107/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.1333e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 45ms/step - loss: 4.1333e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6864 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 3.7735e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6362e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 42ms/step - loss: 1.6259e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6895 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 3.7735e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4734e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 43ms/step - loss: 1.4255e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6964 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 3.7735e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9577e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 43ms/step - loss: 2.8919e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7113 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 3.7735e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8039e-05 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 11.
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
#
# Epoch 111: val_loss did not improve from 0.55697
# 16/16 [==============================] - 1s 44ms/step - loss: 1.8897e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7159 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.7735e-04
# Epoch 111: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 6ms/step
# 0.7314814814814815

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7314814814814815
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.47      0.20      0.28        85
#            0       0.76      0.92      0.83       239
#
#     accuracy                           0.73       324
#    macro avg       0.62      0.56      0.56       324
# weighted avg       0.69      0.73      0.69       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 237 chiếm khoảng 73.14814814814815% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 17 chiếm khoảng 20.0% so với thực tế
