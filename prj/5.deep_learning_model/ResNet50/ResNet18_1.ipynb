# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7081 - accuracy: 0.5250 - f1_score: 0.3552
# Epoch 1: val_f1_score improved from -inf to 0.42663, saving model to best_model.h5
# 16/16 [==============================] - 11s 134ms/step - loss: 1.6702 - accuracy: 0.5180 - f1_score: 0.3495 - val_loss: 0.7512 - val_accuracy: 0.4877 - val_f1_score: 0.4266 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7882 - accuracy: 0.5000 - f1_score: 0.3451
# Epoch 2: val_f1_score did not improve from 0.42663
# 16/16 [==============================] - 1s 37ms/step - loss: 0.7867 - accuracy: 0.5020 - f1_score: 0.3457 - val_loss: 1.0844 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7835 - accuracy: 0.4969 - f1_score: 0.3665
# Epoch 3: val_f1_score improved from 0.42663 to 0.42765, saving model to best_model.h5
# 16/16 [==============================] - 1s 68ms/step - loss: 0.7800 - accuracy: 0.5000 - f1_score: 0.3664 - val_loss: 0.6955 - val_accuracy: 0.5525 - val_f1_score: 0.4276 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6824 - accuracy: 0.5688 - f1_score: 0.4667
# Epoch 4: val_f1_score improved from 0.42765 to 0.51543, saving model to best_model.h5
# 16/16 [==============================] - 1s 56ms/step - loss: 0.6831 - accuracy: 0.5689 - f1_score: 0.4699 - val_loss: 0.6927 - val_accuracy: 0.5802 - val_f1_score: 0.5154 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5944 - accuracy: 0.6760 - f1_score: 0.6449
# Epoch 5: val_f1_score improved from 0.51543 to 0.53015, saving model to best_model.h5
# 16/16 [==============================] - 1s 52ms/step - loss: 0.6015 - accuracy: 0.6697 - f1_score: 0.6372 - val_loss: 0.6364 - val_accuracy: 0.6883 - val_f1_score: 0.5302 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5184 - accuracy: 0.7312 - f1_score: 0.7148
# Epoch 6: val_f1_score did not improve from 0.53015
# 16/16 [==============================] - 1s 40ms/step - loss: 0.5210 - accuracy: 0.7315 - f1_score: 0.7158 - val_loss: 1.0012 - val_accuracy: 0.3086 - val_f1_score: 0.2663 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4574 - accuracy: 0.7708 - f1_score: 0.7599
# Epoch 7: val_f1_score did not improve from 0.53015
# 16/16 [==============================] - 1s 42ms/step - loss: 0.4544 - accuracy: 0.7735 - f1_score: 0.7643 - val_loss: 1.0916 - val_accuracy: 0.3179 - val_f1_score: 0.2762 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3729 - accuracy: 0.8240 - f1_score: 0.8193
# Epoch 8: val_f1_score did not improve from 0.53015
# 16/16 [==============================] - 1s 40ms/step - loss: 0.3732 - accuracy: 0.8224 - f1_score: 0.8171 - val_loss: 1.0094 - val_accuracy: 0.3488 - val_f1_score: 0.3556 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3513 - accuracy: 0.8483 - f1_score: 0.8437
# Epoch 9: val_f1_score did not improve from 0.53015
# 16/16 [==============================] - 1s 50ms/step - loss: 0.3513 - accuracy: 0.8483 - f1_score: 0.8437 - val_loss: 0.9678 - val_accuracy: 0.4105 - val_f1_score: 0.4972 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3122 - accuracy: 0.8510 - f1_score: 0.8476
# Epoch 10: val_f1_score improved from 0.53015 to 0.53258, saving model to best_model.h5
# 16/16 [==============================] - 1s 63ms/step - loss: 0.3204 - accuracy: 0.8523 - f1_score: 0.8494 - val_loss: 0.8657 - val_accuracy: 0.5123 - val_f1_score: 0.5326 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3167 - accuracy: 0.8667 - f1_score: 0.8648
# Epoch 11: val_f1_score did not improve from 0.53258
# 16/16 [==============================] - 1s 40ms/step - loss: 0.3186 - accuracy: 0.8653 - f1_score: 0.8627 - val_loss: 0.7610 - val_accuracy: 0.7160 - val_f1_score: 0.5144 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2805 - accuracy: 0.8802 - f1_score: 0.8783
# Epoch 12: val_f1_score did not improve from 0.53258
# 16/16 [==============================] - 1s 43ms/step - loss: 0.2862 - accuracy: 0.8772 - f1_score: 0.8739 - val_loss: 1.6913 - val_accuracy: 0.7315 - val_f1_score: 0.4487 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2874 - accuracy: 0.8833 - f1_score: 0.8820
# Epoch 13: val_f1_score improved from 0.53258 to 0.61347, saving model to best_model.h5
# 16/16 [==============================] - 1s 56ms/step - loss: 0.2938 - accuracy: 0.8792 - f1_score: 0.8756 - val_loss: 0.9182 - val_accuracy: 0.5648 - val_f1_score: 0.6135 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2173 - accuracy: 0.9052 - f1_score: 0.9038
# Epoch 14: val_f1_score improved from 0.61347 to 0.64071, saving model to best_model.h5
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2244 - accuracy: 0.9022 - f1_score: 0.8993 - val_loss: 0.8224 - val_accuracy: 0.6667 - val_f1_score: 0.6407 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1513 - accuracy: 0.9375 - f1_score: 0.9370
# Epoch 15: val_f1_score did not improve from 0.64071
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1509 - accuracy: 0.9391 - f1_score: 0.9395 - val_loss: 1.1169 - val_accuracy: 0.6821 - val_f1_score: 0.4977 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1726 - accuracy: 0.9354 - f1_score: 0.9350
# Epoch 16: val_f1_score improved from 0.64071 to 0.67140, saving model to best_model.h5
# 16/16 [==============================] - 1s 62ms/step - loss: 0.1731 - accuracy: 0.9351 - f1_score: 0.9346 - val_loss: 1.0647 - val_accuracy: 0.7006 - val_f1_score: 0.6714 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9222 - f1_score: 0.9215
# Epoch 17: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1789 - accuracy: 0.9222 - f1_score: 0.9215 - val_loss: 1.2019 - val_accuracy: 0.6574 - val_f1_score: 0.6564 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2192 - accuracy: 0.9031 - f1_score: 0.9006
# Epoch 18: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 43ms/step - loss: 0.2147 - accuracy: 0.9042 - f1_score: 0.9024 - val_loss: 0.9502 - val_accuracy: 0.6821 - val_f1_score: 0.6540 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1611 - accuracy: 0.9406 - f1_score: 0.9400
# Epoch 19: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1589 - accuracy: 0.9391 - f1_score: 0.9378 - val_loss: 1.2452 - val_accuracy: 0.7222 - val_f1_score: 0.6454 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1692 - accuracy: 0.9302 - f1_score: 0.9288
# Epoch 20: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1714 - accuracy: 0.9301 - f1_score: 0.9282 - val_loss: 1.5311 - val_accuracy: 0.7500 - val_f1_score: 0.6388 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1250 - accuracy: 0.9500 - f1_score: 0.9495
# Epoch 21: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1246 - accuracy: 0.9491 - f1_score: 0.9482 - val_loss: 1.3890 - val_accuracy: 0.6728 - val_f1_score: 0.6061 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.
10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9800 - f1_score: 0.9793
# Epoch 35: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0798 - accuracy: 0.9800 - f1_score: 0.9793 - val_loss: 2.7813 - val_accuracy: 0.6173 - val_f1_score: 0.5857 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1383 - accuracy: 0.9458 - f1_score: 0.9453
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 36: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1370 - accuracy: 0.9461 - f1_score: 0.9457 - val_loss: 2.1503 - val_accuracy: 0.7407 - val_f1_score: 0.6444 - lr: 0.0010
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0924 - accuracy: 0.9625 - f1_score: 0.9621
# Epoch 37: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0911 - accuracy: 0.9631 - f1_score: 0.9629 - val_loss: 1.5553 - val_accuracy: 0.6420 - val_f1_score: 0.5947 - lr: 5.0000e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0531 - accuracy: 0.9833 - f1_score: 0.9827
# Epoch 38: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0512 - accuracy: 0.9840 - f1_score: 0.9838 - val_loss: 1.5397 - val_accuracy: 0.6759 - val_f1_score: 0.6577 - lr: 5.0000e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 39: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0162 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 1.8142 - val_accuracy: 0.6543 - val_f1_score: 0.6164 - lr: 5.0000e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0135 - accuracy: 0.9958 - f1_score: 0.9957
# Epoch 40: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0133 - accuracy: 0.9960 - f1_score: 0.9959 - val_loss: 1.9214 - val_accuracy: 0.6327 - val_f1_score: 0.6012 - lr: 5.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9974
# Epoch 41: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9974 - val_loss: 1.7961 - val_accuracy: 0.6759 - val_f1_score: 0.6675 - lr: 5.0000e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0055 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 42: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0054 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.2012 - val_accuracy: 0.6173 - val_f1_score: 0.5916 - lr: 5.0000e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 43: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0044 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.9686 - val_accuracy: 0.6605 - val_f1_score: 0.6600 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 44: val_f1_score did not improve from 0.67140
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0035 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.9471 - val_accuracy: 0.6667 - val_f1_score: 0.6644 - lr: 5.0000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0037 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 45: val_f1_score improved from 0.67140 to 0.67235, saving model to best_model.h5
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0036 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.9923 - val_accuracy: 0.6759 - val_f1_score: 0.6724 - lr: 5.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990 - f1_score: 0.9984
# Epoch 46: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0033 - accuracy: 0.9990 - f1_score: 0.9984 - val_loss: 2.1163 - val_accuracy: 0.6698 - val_f1_score: 0.6280 - lr: 5.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 47: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0023 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.9902 - val_accuracy: 0.6883 - val_f1_score: 0.6328 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 48: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0088 - val_accuracy: 0.6852 - val_f1_score: 0.6310 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 49: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0023 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0838 - val_accuracy: 0.6821 - val_f1_score: 0.6722 - lr: 5.0000e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0020 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 50: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0019 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1832 - val_accuracy: 0.6759 - val_f1_score: 0.6679 - lr: 5.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9990 - f1_score: 0.9985
# Epoch 51: val_f1_score did not improve from 0.67235
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0021 - accuracy: 0.9990 - f1_score: 0.9985 - val_loss: 2.1975 - val_accuracy: 0.6790 - val_f1_score: 0.6696 - lr: 5.0000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0020 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 52: val_f1_score improved from 0.67235 to 0.68192, saving model to best_model.h5
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0020 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1277 - val_accuracy: 0.6975 - val_f1_score: 0.6819 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0020 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 53: val_f1_score did not improve from 0.68192
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0019 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2542 - val_accuracy: 0.6728 - val_f1_score: 0.6270 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 54: val_f1_score did not improve from 0.68192
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0015 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2329 - val_accuracy: 0.6790 - val_f1_score: 0.6300 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 55: val_f1_score did not improve from 0.68192
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3330 - val_accuracy: 0.6728 - val_f1_score: 0.6233 - lr: 5.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 56: val_f1_score did not improve from 0.68192
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0018 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3423 - val_accuracy: 0.6759 - val_f1_score: 0.6255 - lr: 5.0000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 57: val_f1_score did not improve from 0.68192
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2090 - val_accuracy: 0.6944 - val_f1_score: 0.6801 - lr: 5.0000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 58: val_f1_score improved from 0.68192 to 0.68849, saving model to best_model.h5
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0010 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1983 - val_accuracy: 0.7068 - val_f1_score: 0.6885 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 59: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1928 - val_accuracy: 0.7068 - val_f1_score: 0.6885 - lr: 5.0000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.2019e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 60: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 36ms/step - loss: 8.9920e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3009 - val_accuracy: 0.6883 - val_f1_score: 0.6337 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 61: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3379 - val_accuracy: 0.6975 - val_f1_score: 0.6396 - lr: 5.0000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.7535e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 37ms/step - loss: 8.4663e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3498 - val_accuracy: 0.7006 - val_f1_score: 0.6838 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.9171e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 39ms/step - loss: 8.7651e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3578 - val_accuracy: 0.6944 - val_f1_score: 0.6799 - lr: 5.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - ETA: 0s - loss: 6.1582e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 39ms/step - loss: 6.1582e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4464 - val_accuracy: 0.6975 - val_f1_score: 0.6827 - lr: 5.0000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.5456e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 35ms/step - loss: 6.3500e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5534 - val_accuracy: 0.6883 - val_f1_score: 0.6408 - lr: 5.0000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.6383e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 34ms/step - loss: 5.4704e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5725 - val_accuracy: 0.6821 - val_f1_score: 0.6728 - lr: 5.0000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.7237e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_f1_score did not improve from 0.68849
# 16/16 [==============================] - 1s 39ms/step - loss: 3.6431e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.
10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0126 - accuracy: 0.9969 - f1_score: 0.9967
# Epoch 84: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0122 - accuracy: 0.9970 - f1_score: 0.9969 - val_loss: 2.2808 - val_accuracy: 0.6852 - val_f1_score: 0.6679 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 85: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0044 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2984 - val_accuracy: 0.6821 - val_f1_score: 0.6635 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0035 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 86: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0035 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1982 - val_accuracy: 0.6852 - val_f1_score: 0.6586 - lr: 2.5000e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2422 - val_accuracy: 0.6944 - val_f1_score: 0.6757 - lr: 2.5000e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2502 - val_accuracy: 0.6944 - val_f1_score: 0.6748 - lr: 2.5000e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3653 - val_accuracy: 0.6759 - val_f1_score: 0.6640 - lr: 2.5000e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 0.9990 - f1_score: 0.9988
# Epoch 90: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0047 - accuracy: 0.9990 - f1_score: 0.9988 - val_loss: 2.5987 - val_accuracy: 0.6574 - val_f1_score: 0.6526 - lr: 2.5000e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 91: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0042 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.6242 - val_accuracy: 0.6574 - val_f1_score: 0.6520 - lr: 2.5000e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0190 - accuracy: 0.9927 - f1_score: 0.9926
# Epoch 92: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0207 - accuracy: 0.9900 - f1_score: 0.9881 - val_loss: 2.3343 - val_accuracy: 0.7130 - val_f1_score: 0.6694 - lr: 2.5000e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0211 - accuracy: 0.9958 - f1_score: 0.9957
# Epoch 93: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0203 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 2.5693 - val_accuracy: 0.7099 - val_f1_score: 0.6760 - lr: 2.5000e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 94: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0034 - accuracy: 0.9980 - f1_score: 0.9974 - val_loss: 2.8498 - val_accuracy: 0.6636 - val_f1_score: 0.6576 - lr: 2.5000e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 95: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0022 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.4782 - val_accuracy: 0.7130 - val_f1_score: 0.6809 - lr: 2.5000e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6148 - val_accuracy: 0.7006 - val_f1_score: 0.6800 - lr: 2.5000e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0038 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 97: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0037 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.7452 - val_accuracy: 0.6790 - val_f1_score: 0.6612 - lr: 2.5000e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 98: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0045 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.6081 - val_accuracy: 0.6728 - val_f1_score: 0.6550 - lr: 2.5000e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.5446e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 99: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 8.1154e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5523 - val_accuracy: 0.6883 - val_f1_score: 0.6726 - lr: 2.5000e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 100: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.5124 - val_accuracy: 0.6821 - val_f1_score: 0.6661 - lr: 1.2500e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.6911e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5201 - val_accuracy: 0.6821 - val_f1_score: 0.6678 - lr: 1.2500e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 102: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 2.7539 - val_accuracy: 0.6420 - val_f1_score: 0.6434 - lr: 1.2500e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5
10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9173e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 123: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 58ms/step - loss: 1.9046e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8084 - val_accuracy: 0.6574 - val_f1_score: 0.6518 - lr: 6.2500e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.0767e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 124: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 44ms/step - loss: 2.0195e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8110 - val_accuracy: 0.6574 - val_f1_score: 0.6518 - lr: 6.2500e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.1242e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 125: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 2.1537e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8082 - val_accuracy: 0.6574 - val_f1_score: 0.6518 - lr: 6.2500e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4805e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 126: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 40ms/step - loss: 2.5674e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8124 - val_accuracy: 0.6605 - val_f1_score: 0.6540 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5376e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 127: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 4.4149e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8185 - val_accuracy: 0.6605 - val_f1_score: 0.6540 - lr: 6.2500e-05
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6815e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 128: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 38ms/step - loss: 1.6407e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8212 - val_accuracy: 0.6605 - val_f1_score: 0.6540 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.9489e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 129: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 42ms/step - loss: 5.8522e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7864 - val_accuracy: 0.6605 - val_f1_score: 0.6530 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.4938e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 130: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 3.3654e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7886 - val_accuracy: 0.6636 - val_f1_score: 0.6553 - lr: 6.2500e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4237e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 131: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.3870e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7915 - val_accuracy: 0.6636 - val_f1_score: 0.6553 - lr: 6.2500e-05
# Epoch 132/10000
# ...
# 16/16 [==============================] - 1s 38ms/step - loss: 1.4755e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8182 - val_accuracy: 0.6636 - val_f1_score: 0.6547 - lr: 6.2500e-05
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.3467e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 138: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 37ms/step - loss: 2.3438e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8272 - val_accuracy: 0.6636 - val_f1_score: 0.6547 - lr: 6.2500e-05
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.5256e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 139: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 139: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 7.2250e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8322 - val_accuracy: 0.6667 - val_f1_score: 0.6570 - lr: 6.2500e-05
# Epoch 140/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.8550e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 140: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 41ms/step - loss: 2.8550e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8447 - val_accuracy: 0.6605 - val_f1_score: 0.6535 - lr: 3.1250e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9120e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 141: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.8570e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8518 - val_accuracy: 0.6574 - val_f1_score: 0.6513 - lr: 3.1250e-05
# Epoch 142/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7943e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 142: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.8497e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8538 - val_accuracy: 0.6605 - val_f1_score: 0.6535 - lr: 3.1250e-05
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8835e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 143: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 39ms/step - loss: 1.9117e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8558 - val_accuracy: 0.6636 - val_f1_score: 0.6551 - lr: 3.1250e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.8389e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 144: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 40ms/step - loss: 4.6829e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8633 - val_accuracy: 0.6605 - val_f1_score: 0.6529 - lr: 3.1250e-05
# Epoch 145/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.0232e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 145: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.9740e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8671 - val_accuracy: 0.6605 - val_f1_score: 0.6529 - lr: 3.1250e-05
# Epoch 146/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7600e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 146: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.7884e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8682 - val_accuracy: 0.6605 - val_f1_score: 0.6529 - lr: 3.1250e-05
# Epoch 147/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4555e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 147: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.6273e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8697 - val_accuracy: 0.6605 - val_f1_score: 0.6529 - lr: 3.1250e-05
# Epoch 148/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5584e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 148: val_f1_score did not improve from 0.69427
# 16/16 [==============================] - 1s 36ms/step - loss: 1.5085e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8676 - val_accuracy: 0.6605 - val_f1_score: 0.6529 - lr: 3.1250e-05
# Epoch 149/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1

# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 8ms/step
# 0.7253086419753086

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 6ms/step
# 0.7253086419753086

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7253086419753086
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.48      0.49      0.49        85
#            0       0.82      0.81      0.81       239
#
#     accuracy                           0.73       324
#    macro avg       0.65      0.65      0.65       324
# weighted avg       0.73      0.73      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 235 chiếm khoảng 72.53086419753086% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 42 chiếm khoảng 49.411764705882355% so với thực tế
