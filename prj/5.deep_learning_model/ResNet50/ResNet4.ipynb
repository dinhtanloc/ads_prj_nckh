# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.00001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(32, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [16, 16, 32], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [16, 16, 32], stage=2, block='b')
    x = identity_block(x, 3, [16, 16, 32], stage=2, block='c')

    x = conv_block(x, 3, [32, 32, 96], stage=3, block='a')
    x = identity_block(x, 3, [32, 32, 96], stage=3, block='b')
    x = identity_block(x, 3, [32, 32, 96], stage=3, block='c')
    x = identity_block(x, 3, [32, 32, 96], stage=3, block='d')
    
    x = conv_block(x, 3, [64, 64, 128], stage=4, block='a')
    x = identity_block(x, 3, [64, 64, 128], stage=4, block='b')
    x = identity_block(x, 3, [64, 64, 128], stage=4, block='c')
    x = identity_block(x, 3, [64, 64, 128], stage=4, block='d')
    x = identity_block(x, 3, [64, 64, 128], stage=4, block='e')
    # x = identity_block(x, 3, [64, 64, 128], stage=4, block='f')

    # x = conv_block(x, 3, [128, 128, 256], stage=5, block='a')
    # x = identity_block(x, 3, [128, 128, 256], stage=5, block='b')
    # x = identity_block(x, 3, [128, 128, 256], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Flatten()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)

resNet50=build_model()
resNet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 32)       256         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 32)       128         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 32)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 32)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 16)       528         ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 16)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 16)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 16)       784         ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 16)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 16)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 32)       544         ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 32)       1056        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 32)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 32)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 32)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 16)       528         ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 16)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 16)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 16)       784         ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 16)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 16)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 32)       544         ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 32)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 32)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 16)       528         ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 16)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 16)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 16)       784         ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 16)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 16)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 32)       544         ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 32)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 32)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 32)        1056        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 32)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 32)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 32)        3104        ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 32)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 32)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 96)        3168        ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 96)        3168        ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 96)       20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 96)        0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 96)        0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 32)        3104        ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 32)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 32)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 32)        3104        ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 32)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 32)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 96)        3168        ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 96)        0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 96)        0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 32)        3104        ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 32)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 32)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 32)        3104        ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 32)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 32)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 96)        3168        ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 96)        0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 96)        0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 5, 32)        3104        ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 5, 32)       20          ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 5, 32)        0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 5, 32)        3104        ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 5, 32)       20          ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 5, 32)        0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)        (None, 5, 96)        3168        ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 5, 96)       20          ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 5, 96)        0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 5, 96)        0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 64)        6208        ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 64)       12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 3, 64)        0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 64)        12352       ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 64)       12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 3, 64)        0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 128)       8320        ['activation_23[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 128)       12416       ['activation_21[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 128)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 128)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 3, 128)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 3, 128)       0           ['add_7[0][0]']
#
#  res4b_branch2a (Conv1D)        (None, 3, 64)        8256        ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 3, 64)       12          ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 3, 64)        0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv1D)        (None, 3, 64)        12352       ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 3, 64)       12          ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 3, 64)        0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv1D)        (None, 3, 128)       8320        ['activation_26[0][0]']
#
#  bn4b_branch2c (BatchNormalizat  (None, 3, 128)      12          ['res4b_branch2c[0][0]']
#  ion)
#
#  add_8 (Add)                    (None, 3, 128)       0           ['bn4b_branch2c[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 3, 128)       0           ['add_8[0][0]']
#
#  res4c_branch2a (Conv1D)        (None, 3, 64)        8256        ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 3, 64)       12          ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 3, 64)        0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv1D)        (None, 3, 64)        12352       ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 3, 64)       12          ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 3, 64)        0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv1D)        (None, 3, 128)       8320        ['activation_29[0][0]']
#
#  bn4c_branch2c (BatchNormalizat  (None, 3, 128)      12          ['res4c_branch2c[0][0]']
#  ion)
#
#  add_9 (Add)                    (None, 3, 128)       0           ['bn4c_branch2c[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 3, 128)       0           ['add_9[0][0]']
#
#  res4d_branch2a (Conv1D)        (None, 3, 64)        8256        ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 3, 64)       12          ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 3, 64)        0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv1D)        (None, 3, 64)        12352       ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 3, 64)       12          ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 3, 64)        0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv1D)        (None, 3, 128)       8320        ['activation_32[0][0]']
#
#  bn4d_branch2c (BatchNormalizat  (None, 3, 128)      12          ['res4d_branch2c[0][0]']
#  ion)
#
#  add_10 (Add)                   (None, 3, 128)       0           ['bn4d_branch2c[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 3, 128)       0           ['add_10[0][0]']
#
#  res4e_branch2a (Conv1D)        (None, 3, 64)        8256        ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 3, 64)       12          ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 3, 64)        0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv1D)        (None, 3, 64)        12352       ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 3, 64)       12          ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 3, 64)        0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv1D)        (None, 3, 128)       8320        ['activation_35[0][0]']
#
#  bn4e_branch2c (BatchNormalizat  (None, 3, 128)      12          ['res4e_branch2c[0][0]']
#  ion)
#
#  add_11 (Add)                   (None, 3, 128)       0           ['bn4e_branch2c[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 3, 128)       0           ['add_11[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['activation_36[0][0]']
#  alAveragePooling1D)
#
#  flatten (Flatten)              (None, 128)          0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  fc1000 (Dense)                 (None, 2)            258         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 201,750
# Trainable params: 201,260
# Non-trainable params: 490
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 12s 114ms/step - loss: 0.4850 - accuracy: 0.4990 - f1_score: 0.5000 - val_loss: 0.4798 - val_accuracy: 0.6204 - val_f1_score: 0.6406 - lr: 1.0000e-05
# Epoch 2/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.4667 - accuracy: 0.5739 - f1_score: 0.5728 - val_loss: 0.4795 - val_accuracy: 0.6173 - val_f1_score: 0.6380 - lr: 1.0000e-05
# Epoch 3/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4482 - accuracy: 0.6856 - f1_score: 0.6883 - val_loss: 0.4800 - val_accuracy: 0.6173 - val_f1_score: 0.6380 - lr: 1.0000e-05
# Epoch 4/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.4307 - accuracy: 0.7126 - f1_score: 0.7131 - val_loss: 0.4818 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.0000e-05
# Epoch 5/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.4155 - accuracy: 0.7086 - f1_score: 0.7082 - val_loss: 0.4829 - val_accuracy: 0.5895 - val_f1_score: 0.6146 - lr: 1.0000e-05
# Epoch 6/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.4017 - accuracy: 0.7126 - f1_score: 0.7136 - val_loss: 0.4834 - val_accuracy: 0.5864 - val_f1_score: 0.6120 - lr: 1.0000e-05
# Epoch 7/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3859 - accuracy: 0.7146 - f1_score: 0.7141 - val_loss: 0.4819 - val_accuracy: 0.5833 - val_f1_score: 0.6094 - lr: 1.0000e-05
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3699 - accuracy: 0.7271 - f1_score: 0.7271
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3704 - accuracy: 0.7255 - f1_score: 0.7248 - val_loss: 0.4734 - val_accuracy: 0.6204 - val_f1_score: 0.6406 - lr: 1.0000e-05
# Epoch 9/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3648 - accuracy: 0.7246 - f1_score: 0.7213 - val_loss: 0.4691 - val_accuracy: 0.6142 - val_f1_score: 0.6354 - lr: 5.0000e-06
# Epoch 10/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3575 - accuracy: 0.7226 - f1_score: 0.7224 - val_loss: 0.4580 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 5.0000e-06
# Epoch 11/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3504 - accuracy: 0.7285 - f1_score: 0.7313 - val_loss: 0.4525 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 5.0000e-06
# Epoch 12/10000
# 16/16 [==============================] - 1s 40ms/step - loss: 0.3478 - accuracy: 0.7275 - f1_score: 0.7288 - val_loss: 0.4442 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 5.0000e-06
# Epoch 13/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3404 - accuracy: 0.7305 - f1_score: 0.7302 - val_loss: 0.4365 - val_accuracy: 0.6698 - val_f1_score: 0.6823 - lr: 5.0000e-06
# Epoch 14/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3322 - accuracy: 0.7305 - f1_score: 0.7322 - val_loss: 0.4303 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 5.0000e-06
# Epoch 15/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3281 - accuracy: 0.7355 - f1_score: 0.7330 - val_loss: 0.4225 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 5.0000e-06
# Epoch 16/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3242 - accuracy: 0.7365 - f1_score: 0.7360 - val_loss: 0.4159 - val_accuracy: 0.6636 - val_f1_score: 0.6771 - lr: 5.0000e-06
# Epoch 17/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3225 - accuracy: 0.7335 - f1_score: 0.7347 - val_loss: 0.4143 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 5.0000e-06
# Epoch 18/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.3135 - accuracy: 0.7425 - f1_score: 0.7440 - val_loss: 0.4115 - val_accuracy: 0.6481 - val_f1_score: 0.6641 - lr: 5.0000e-06
# Epoch 19/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3128 - accuracy: 0.7415 - f1_score: 0.7425 - val_loss: 0.4039 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 5.0000e-06
# Epoch 20/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3077 - accuracy: 0.7415 - f1_score: 0.7414 - val_loss: 0.4019 - val_accuracy: 0.6358 - val_f1_score: 0.6536 - lr: 5.0000e-06
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3070 - accuracy: 0.7354 - f1_score: 0.7354
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3072 - accuracy: 0.7355 - f1_score: 0.7356 - val_loss: 0.4062 - val_accuracy: 0.6389 - val_f1_score: 0.6562 - lr: 5.0000e-06
# Epoch 22/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2992 - accuracy: 0.7435 - f1_score: 0.7439 - val_loss: 0.4054 - val_accuracy: 0.6358 - val_f1_score: 0.6536 - lr: 2.5000e-06
# Epoch 23/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2991 - accuracy: 0.7525 - f1_score: 0.7522 - val_loss: 0.4028 - val_accuracy: 0.6296 - val_f1_score: 0.6484 - lr: 2.5000e-06
# Epoch 24/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3019 - accuracy: 0.7375 - f1_score: 0.7380 - val_loss: 0.4041 - val_accuracy: 0.6327 - val_f1_score: 0.6510 - lr: 2.5000e-06
# Epoch 25/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2979 - accuracy: 0.7405 - f1_score: 0.7394 - val_loss: 0.4036 - val_accuracy: 0.6389 - val_f1_score: 0.6562 - lr: 2.5000e-06
# Epoch 26/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2954 - accuracy: 0.7435 - f1_score: 0.7434 - val_loss: 0.4067 - val_accuracy: 0.6296 - val_f1_score: 0.6484 - lr: 2.5000e-06
# Epoch 27/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2975 - accuracy: 0.7455 - f1_score: 0.7469 - val_loss: 0.4065 - val_accuracy: 0.6265 - val_f1_score: 0.6458 - lr: 2.5000e-06
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2970 - accuracy: 0.7427 - f1_score: 0.7427
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2955 - accuracy: 0.7455 - f1_score: 0.7469 - val_loss: 0.4099 - val_accuracy: 0.6142 - val_f1_score: 0.6354 - lr: 2.5000e-06
# Epoch 29/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2915 - accuracy: 0.7485 - f1_score: 0.7467 - val_loss: 0.4093 - val_accuracy: 0.6049 - val_f1_score: 0.6276 - lr: 1.2500e-06
# Epoch 30/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2864 - accuracy: 0.7535 - f1_score: 0.7542 - val_loss: 0.4099 - val_accuracy: 0.6049 - val_f1_score: 0.6276 - lr: 1.2500e-06
# Epoch 31/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2883 - accuracy: 0.7525 - f1_score: 0.7517 - val_loss: 0.4098 - val_accuracy: 0.6049 - val_f1_score: 0.6276 - lr: 1.2500e-06
# Epoch 32/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2915 - accuracy: 0.7435 - f1_score: 0.7444 - val_loss: 0.4119 - val_accuracy: 0.6019 - val_f1_score: 0.6250 - lr: 1.2500e-06
# Epoch 33/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2875 - accuracy: 0.7505 - f1_score: 0.7477 - val_loss: 0.4118 - val_accuracy: 0.6019 - val_f1_score: 0.6250 - lr: 1.2500e-06
# Epoch 34/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2867 - accuracy: 0.7495 - f1_score: 0.7477 - val_loss: 0.4126 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.2500e-06
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.7455 - f1_score: 0.7443
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2876 - accuracy: 0.7455 - f1_score: 0.7443 - val_loss: 0.4109 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.2500e-06
# Epoch 36/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2862 - accuracy: 0.7425 - f1_score: 0.7414 - val_loss: 0.4107 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.0000e-06
# Epoch 37/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2888 - accuracy: 0.7495 - f1_score: 0.7508 - val_loss: 0.4108 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.0000e-06
# Epoch 38/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2883 - accuracy: 0.7405 - f1_score: 0.7369 - val_loss: 0.4097 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.0000e-06
# Epoch 39/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2884 - accuracy: 0.7475 - f1_score: 0.7478 - val_loss: 0.4092 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.0000e-06
# Epoch 40/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2846 - accuracy: 0.7405 - f1_score: 0.7405 - val_loss: 0.4103 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.0000e-06
# Epoch 41/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2845 - accuracy: 0.7545 - f1_score: 0.7567 - val_loss: 0.4100 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.0000e-06
# Epoch 42/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2834 - accuracy: 0.7465 - f1_score: 0.7468 - val_loss: 0.4093 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.0000e-06
# Epoch 43/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2830 - accuracy: 0.7525 - f1_score: 0.7527 - val_loss: 0.4084 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 1.0000e-06
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2786 - accuracy: 0.7573 - f1_score: 0.7573Restoring model weights from the end of the best epoch: 14.
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2828 - accuracy: 0.7515 - f1_score: 0.7487 - val_loss: 0.4100 - val_accuracy: 0.5926 - val_f1_score: 0.6172 - lr: 1.0000e-06
# Epoch 44: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.6759259259259259

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6759259259259259
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.31      0.20      0.24        85
#            0       0.75      0.85      0.79       239
#
#     accuracy                           0.68       324
#    macro avg       0.53      0.52      0.52       324
# weighted avg       0.63      0.68      0.65       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 219 chiếm khoảng 67.5925925925926% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 17 chiếm khoảng 20.0% so với thực tế
