# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [32, 32, 96], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='b')
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='c')

    x = conv_block(x, 3, [64, 64, 128], stage=3, block='a')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='b')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='c')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='d')
    
    # x = conv_block(x, 3, [128, 128, 512], stage=4, block='a')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='b')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='c')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='d')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='e')
    # x = identity_block(x, 3,  [128, 128, 512], stage=4, block='f')

    # x = conv_block(x, 3, [256, 256, 1024], stage=5, block='a')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='b')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.95,
    patience=5,
    min_lr=0.000001,
    verbose=1,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5",monitor='val_accuracy',mode='max', verbose = 1, save_best_only=True)

resNet50=build_model()
resNet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 64)        6208        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 64)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 64)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 128)       12416       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 128)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 128)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 128)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 64)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 64)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 128)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 128)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 64)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 64)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 128)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 128)       0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 5, 64)        0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 5, 64)        0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 5, 128)       0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 5, 128)       0           ['add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['activation_21[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            258         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 161,110
# Trainable params: 160,652
# Non-trainable params: 458
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpointer],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2521 - accuracy: 0.5220 - f1_score: 0.5215
# Epoch 1: val_accuracy improved from -inf to 0.26235, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 8s 106ms/step - loss: 1.2521 - accuracy: 0.5220 - f1_score: 0.5215 - val_loss: 1.1734 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7505 - accuracy: 0.5210 - f1_score: 0.5231
# Epoch 2: val_accuracy improved from 0.26235 to 0.42593, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.7505 - accuracy: 0.5210 - f1_score: 0.5231 - val_loss: 0.7059 - val_accuracy: 0.4259 - val_f1_score: 0.3984 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6784 - accuracy: 0.5579 - f1_score: 0.5561
# Epoch 3: val_accuracy did not improve from 0.42593
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6784 - accuracy: 0.5579 - f1_score: 0.5561 - val_loss: 0.7440 - val_accuracy: 0.3241 - val_f1_score: 0.3125 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.6517 - f1_score: 0.6551
# Epoch 4: val_accuracy improved from 0.42593 to 0.57716, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 41ms/step - loss: 0.6470 - accuracy: 0.6517 - f1_score: 0.6551 - val_loss: 0.6727 - val_accuracy: 0.5772 - val_f1_score: 0.6432 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.6687 - f1_score: 0.6681
# Epoch 5: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5687 - accuracy: 0.6687 - f1_score: 0.6681 - val_loss: 0.9444 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5226 - accuracy: 0.7302 - f1_score: 0.7302
# Epoch 6: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 28ms/step - loss: 0.5162 - accuracy: 0.7365 - f1_score: 0.7396 - val_loss: 0.7123 - val_accuracy: 0.5247 - val_f1_score: 0.5599 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4210 - accuracy: 0.7944 - f1_score: 0.7947
# Epoch 7: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 29ms/step - loss: 0.4210 - accuracy: 0.7944 - f1_score: 0.7947 - val_loss: 1.1647 - val_accuracy: 0.2654 - val_f1_score: 0.2630 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.8353 - f1_score: 0.8353
# Epoch 8: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3595 - accuracy: 0.8353 - f1_score: 0.8353 - val_loss: 1.1676 - val_accuracy: 0.2747 - val_f1_score: 0.2708 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3110 - accuracy: 0.8593 - f1_score: 0.8587
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
#
# Epoch 9: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3110 - accuracy: 0.8593 - f1_score: 0.8587 - val_loss: 1.0603 - val_accuracy: 0.3457 - val_f1_score: 0.3698 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.8962 - f1_score: 0.8959
# Epoch 10: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2517 - accuracy: 0.8962 - f1_score: 0.8959 - val_loss: 1.6981 - val_accuracy: 0.2747 - val_f1_score: 0.2708 - lr: 9.5000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.8822 - f1_score: 0.8817
# Epoch 11: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2708 - accuracy: 0.8822 - f1_score: 0.8817 - val_loss: 1.2939 - val_accuracy: 0.3117 - val_f1_score: 0.3021 - lr: 9.5000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9102 - f1_score: 0.9106
# Epoch 12: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2374 - accuracy: 0.9102 - f1_score: 0.9106 - val_loss: 2.0983 - val_accuracy: 0.2778 - val_f1_score: 0.2734 - lr: 9.5000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.8902 - f1_score: 0.8880
# Epoch 13: val_accuracy did not improve from 0.57716
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2354 - accuracy: 0.8902 - f1_score: 0.8880 - val_loss: 1.9285 - val_accuracy: 0.3086 - val_f1_score: 0.2995 - lr: 9.5000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9182 - f1_score: 0.9194
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
#
# Epoch 14: val_accuracy improved from 0.57716 to 0.66049, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1972 - accuracy: 0.9182 - f1_score: 0.9194 - val_loss: 0.8787 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 9.5000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9242 - f1_score: 0.9242
# Epoch 15: val_accuracy did not improve from 0.66049
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1952 - accuracy: 0.9242 - f1_score: 0.9242 - val_loss: 1.4352 - val_accuracy: 0.4414 - val_f1_score: 0.4505 - lr: 9.0250e-04
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1898 - accuracy: 0.9196 - f1_score: 0.9196
# Epoch 16: val_accuracy did not improve from 0.66049
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1789 - accuracy: 0.9251 - f1_score: 0.9257 - val_loss: 1.3254 - val_accuracy: 0.4907 - val_f1_score: 0.4922 - lr: 9.0250e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9391 - f1_score: 0.9389
# Epoch 17: val_accuracy did not improve from 0.66049
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1424 - accuracy: 0.9391 - f1_score: 0.9389 - val_loss: 1.6420 - val_accuracy: 0.4630 - val_f1_score: 0.4297 - lr: 9.0250e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9411 - f1_score: 0.9393
# Epoch 18: val_accuracy did not improve from 0.66049
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1340 - accuracy: 0.9411 - f1_score: 0.9393 - val_loss: 1.3458 - val_accuracy: 0.5833 - val_f1_score: 0.6484 - lr: 9.0250e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9601 - f1_score: 0.9604
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
#
# Epoch 19: val_accuracy improved from 0.66049 to 0.67284, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1062 - accuracy: 0.9601 - f1_score: 0.9604 - val_loss: 1.1963 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 9.0250e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9691 - f1_score: 0.9687
# Epoch 20: val_accuracy did not improve from 0.67284
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0768 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 2.1709 - val_accuracy: 0.5062 - val_f1_score: 0.4661 - lr: 8.5737e-04
# Epoch 21/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1072 - accuracy: 0.9587 - f1_score: 0.9587
# Epoch 21: val_accuracy did not improve from 0.67284
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1056 - accuracy: 0.9581 - f1_score: 0.9585 - val_loss: 1.5989 - val_accuracy: 0.5679 - val_f1_score: 0.5573 - lr: 8.5737e-04
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1092 - accuracy: 0.9510 - f1_score: 0.9510
# Epoch 22: val_accuracy improved from 0.67284 to 0.69753, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1127 - accuracy: 0.9521 - f1_score: 0.9526 - val_loss: 1.3330 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 8.5737e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9581 - f1_score: 0.9590
# Epoch 23: val_accuracy did not improve from 0.69753
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0959 - accuracy: 0.9581 - f1_score: 0.9590 - val_loss: 1.3635 - val_accuracy: 0.6296 - val_f1_score: 0.6875 - lr: 8.5737e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9691 - f1_score: 0.9687
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
#
# Epoch 24: val_accuracy did not improve from 0.69753
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0885 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 1.7240 - val_accuracy: 0.5556 - val_f1_score: 0.5859 - lr: 8.5737e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9760 - f1_score: 0.9766
# Epoch 25: val_accuracy improved from 0.69753 to 0.70370, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0758 - accuracy: 0.9760 - f1_score: 0.9766 - val_loss: 1.5738 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 8.1451e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9691 - f1_score: 0.9692
# Epoch 26: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0657 - accuracy: 0.9691 - f1_score: 0.9692 - val_loss: 2.1101 - val_accuracy: 0.5586 - val_f1_score: 0.6276 - lr: 8.1451e-04
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0425 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 27: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0431 - accuracy: 0.9850 - f1_score: 0.9854 - val_loss: 1.6696 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 8.1451e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9840 - f1_score: 0.9823
# Epoch 28: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0389 - accuracy: 0.9840 - f1_score: 0.9823 - val_loss: 2.6376 - val_accuracy: 0.5309 - val_f1_score: 0.6042 - lr: 8.1451e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9870 - f1_score: 0.9873
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
#
# Epoch 29: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0414 - accuracy: 0.9870 - f1_score: 0.9873 - val_loss: 2.0458 - val_accuracy: 0.5926 - val_f1_score: 0.5781 - lr: 8.1451e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9790 - f1_score: 0.9774
# Epoch 30: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0385 - accuracy: 0.9790 - f1_score: 0.9774 - val_loss: 1.7223 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 7.7378e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9920 - f1_score: 0.9917
# Epoch 31: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0300 - accuracy: 0.9920 - f1_score: 0.9917 - val_loss: 2.3696 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 7.7378e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9770 - f1_score: 0.9775
# Epoch 32: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0639 - accuracy: 0.9770 - f1_score: 0.9775 - val_loss: 1.5242 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 7.7378e-04
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0331 - accuracy: 0.9865 - f1_score: 0.9865
# Epoch 33: val_accuracy did not improve from 0.70370
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0331 - accuracy: 0.9860 - f1_score: 0.9858 - val_loss: 1.5771 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 7.7378e-04
# Epoch 34/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0224 - accuracy: 0.9911 - f1_score: 0.9911
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
#
# Epoch 34: val_accuracy improved from 0.70370 to 0.71605, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0237 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 1.7734 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 7.7378e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 35: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0132 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9269 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 7.3509e-04
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 36: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0046 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.3404 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 7.3509e-04
# Epoch 37/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 37: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0079 - accuracy: 0.9980 - f1_score: 0.9975 - val_loss: 2.4646 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 7.3509e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0191 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 38: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0189 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 2.7623 - val_accuracy: 0.6142 - val_f1_score: 0.6354 - lr: 7.3509e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0236 - accuracy: 0.9885 - f1_score: 0.9885
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
#
# Epoch 39: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0227 - accuracy: 0.9890 - f1_score: 0.9893 - val_loss: 3.0846 - val_accuracy: 0.5370 - val_f1_score: 0.5312 - lr: 7.3509e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0232 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 40: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0225 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 3.1696 - val_accuracy: 0.5710 - val_f1_score: 0.5599 - lr: 6.9834e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0160 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 41: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0163 - accuracy: 0.9930 - f1_score: 0.9927 - val_loss: 3.2898 - val_accuracy: 0.5895 - val_f1_score: 0.5365 - lr: 6.9834e-04
# Epoch 42/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0408 - accuracy: 0.9900 - f1_score: 0.9900
# Epoch 42: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0411 - accuracy: 0.9890 - f1_score: 0.9887 - val_loss: 4.3669 - val_accuracy: 0.4475 - val_f1_score: 0.4167 - lr: 6.9834e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0392 - accuracy: 0.9802 - f1_score: 0.9802
# Epoch 43: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0446 - accuracy: 0.9790 - f1_score: 0.9785 - val_loss: 1.9279 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 6.9834e-04
# Epoch 44/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0981 - accuracy: 0.9688 - f1_score: 0.9688
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
#
# Epoch 44: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0953 - accuracy: 0.9691 - f1_score: 0.9697 - val_loss: 1.9844 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 6.9834e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0449 - accuracy: 0.9875 - f1_score: 0.9875
# Epoch 45: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0438 - accuracy: 0.9870 - f1_score: 0.9868 - val_loss: 2.0060 - val_accuracy: 0.6605 - val_f1_score: 0.7135 - lr: 6.6342e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0276 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 46: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0283 - accuracy: 0.9940 - f1_score: 0.9936 - val_loss: 2.3447 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 6.6342e-04
# Epoch 47/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0127 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 47: val_accuracy did not improve from 0.71605
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0122 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 2.4459 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 6.6342e-04
# Epoch 48/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0105 - accuracy: 0.9978 - f1_score: 0.9978
# Epoch 48: val_accuracy improved from 0.71605 to 0.72222, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0112 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.6064 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 6.6342e-04
# Epoch 49/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
#
# Epoch 49: val_accuracy improved from 0.72222 to 0.74383, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0030 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.7581 - val_accuracy: 0.7438 - val_f1_score: 0.7839 - lr: 6.6342e-04
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0103 - accuracy: 0.9967 - f1_score: 0.9967
# Epoch 50: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0098 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.4114 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 6.3025e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9960 - f1_score: 0.9961
# Epoch 51: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0133 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 2.3808 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 6.3025e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 52: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0064 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.2090 - val_accuracy: 0.6605 - val_f1_score: 0.7135 - lr: 6.3025e-04
# Epoch 53/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5179 - val_accuracy: 0.6358 - val_f1_score: 0.6927 - lr: 6.3025e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.7152e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
#
# Epoch 54: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4717 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 6.3025e-04
# Epoch 55/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 6.6803e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 55: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 7.4160e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3793 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 5.9874e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9990 - f1_score: 0.9985
# Epoch 56: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0016 - accuracy: 0.9990 - f1_score: 0.9985 - val_loss: 2.3464 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 5.9874e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.5194e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 8.2726e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3623 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 5.9874e-04
# Epoch 58/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 58: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5354 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 5.9874e-04
# Epoch 59/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
#
# Epoch 59: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0023 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.4964 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 5.9874e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 60: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4997 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 5.6880e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5658e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 30ms/step - loss: 4.3891e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5804 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 5.6880e-04
# Epoch 62/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 2.5698e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 2.5894e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5778 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 5.6880e-04
# Epoch 63/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 2.3474e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 2.4339e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5666 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 5.6880e-04
# Epoch 64/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.8595e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
#
# Epoch 64: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 1.7538e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5588 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 5.6880e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1005e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 31ms/step - loss: 1.8419e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5677 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 5.4036e-04
# Epoch 66/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.4056e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 1.4209e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5798 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 5.4036e-04
# Epoch 67/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.5271e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 1.4785e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5670 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 5.4036e-04
# Epoch 68/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 7.1691e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 68: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 6.4739e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6124 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 5.4036e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9506e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
#
# Epoch 69: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 30ms/step - loss: 1.8732e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6429 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 5.4036e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.4950e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 1s 32ms/step - loss: 6.3255e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6727 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 5.1334e-04
# Epoch 71/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 4.8894e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 4.4933e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6917 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 5.1334e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.0873e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 2.0039e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6792 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 5.1334e-04
# Epoch 73/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.0995e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 30ms/step - loss: 2.8153e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5880 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 5.1334e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.9414e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
#
# Epoch 74: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 4.8356e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5679 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 5.1334e-04
# Epoch 75/10000
# 16/16 [==============================] - ETA: 0s - loss: 6.2288e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 6.2288e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5727 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 4.8767e-04
# Epoch 76/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 9.8872e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 9.6925e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5784 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 4.8767e-04
# Epoch 77/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.1696e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 1.0714e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5948 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.8767e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.6591e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 5.8745e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6025 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 4.8767e-04
# Epoch 79/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.3575e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
#
# Epoch 79: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 1.3780e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6189 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 4.8767e-04
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4121e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 2.4121e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6265 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 4.6329e-04
# Epoch 81/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 6.1735e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 31ms/step - loss: 6.0315e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6515 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 4.6329e-04
# Epoch 82/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 6.0237e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 7.5993e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6536 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.6329e-04
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 6.1861e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 6.1861e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6618 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 4.6329e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.6259e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
#
# Epoch 84: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 4.2000e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6653 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.6329e-04
# Epoch 85/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 2.7060e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 85: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 2.8111e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6617 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.4013e-04
# Epoch 86/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.3436e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 3.5900e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6584 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.4013e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.0132e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 6.9410e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6611 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.4013e-04
# Epoch 88/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.0608e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 2.0608e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6629 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.4013e-04
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 7.3723e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
#
# Epoch 89: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 7.3723e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6771 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.4013e-04
# Epoch 90/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 4.0422e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 3.8552e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6850 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.1812e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.9953e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 4.9953e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6880 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.1812e-04
# Epoch 92/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.7430e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 29ms/step - loss: 4.7430e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6850 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 4.1812e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.3726e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 5.1796e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6853 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 4.1812e-04
# Epoch 94/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 4.4192e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
#
# Epoch 94: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 5.9170e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7324 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 4.1812e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1434e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1003e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9333 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 3.9721e-04
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 96: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0019 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.7160 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 3.9721e-04
# Epoch 97/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 2.0682e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0063 - accuracy: 0.9990 - f1_score: 0.9985 - val_loss: 2.9302 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 3.9721e-04
# Epoch 98/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0605 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 98: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0559 - accuracy: 0.9840 - f1_score: 0.9844 - val_loss: 2.8884 - val_accuracy: 0.6173 - val_f1_score: 0.6380 - lr: 3.9721e-04
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9671 - f1_score: 0.9673
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
#
# Epoch 99: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0746 - accuracy: 0.9671 - f1_score: 0.9673 - val_loss: 2.2816 - val_accuracy: 0.5957 - val_f1_score: 0.6198 - lr: 3.9721e-04
# Epoch 100/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9840 - f1_score: 0.9844
# Epoch 100: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0399 - accuracy: 0.9840 - f1_score: 0.9844 - val_loss: 2.6384 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 3.7735e-04
# Epoch 101/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9880 - f1_score: 0.9883
# Epoch 101: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0289 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 2.2277 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 3.7735e-04
# Epoch 102/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9960 - f1_score: 0.9961
# Epoch 102: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0155 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 2.3176 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 3.7735e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0042 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3339 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 3.7735e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0097 - accuracy: 0.9958 - f1_score: 0.9958 Restoring model weights from the end of the best epoch: 4.
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
#
# Epoch 104: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0093 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 2.3830 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 3.7735e-04
# Epoch 104: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.5771604938271605

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.5771604938271605
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.30      0.46      0.36        85
#            0       0.76      0.62      0.68       239
#
#     accuracy                           0.58       324
#    macro avg       0.53      0.54      0.52       324
# weighted avg       0.64      0.58      0.60       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 187 chiếm khoảng 57.71604938271605% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 39 chiếm khoảng 45.88235294117647% so với thực tế
