# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [32, 32, 96], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='b')
    x = identity_block(x, 3, [32, 32, 96], stage=2, block='c')

    x = conv_block(x, 3, [64, 64, 128], stage=3, block='a')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='b')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='c')
    x = identity_block(x, 3, [64, 64, 128], stage=3, block='d')
    
    # x = conv_block(x, 3, [128, 128, 512], stage=4, block='a')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='b')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='c')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='d')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='e')
    # x = identity_block(x, 3,  [128, 128, 512], stage=4, block='f')

    # x = conv_block(x, 3, [256, 256, 1024], stage=5, block='a')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='b')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.95,
    patience=5,
    min_lr=0.000001,
    verbose=1,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5",monitor='val_accuracy',mode='max', verbose = 1, save_best_only=True)

resNet50=build_model()
resNet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 64)        6208        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 64)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 64)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 128)       12416       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 128)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 128)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 128)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 64)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 64)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 128)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 128)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 64)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 64)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 128)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 128)       0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 5, 64)        8256        ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 5, 64)       20          ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 5, 64)        0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 5, 64)        12352       ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 5, 64)       20          ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 5, 64)        0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)        (None, 5, 128)       8320        ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 5, 128)      20          ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 5, 128)       0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 5, 128)       0           ['add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['activation_21[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            258         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 161,110
# Trainable params: 160,652
# Non-trainable params: 458
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpointer],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7141 - accuracy: 0.4850 - f1_score: 0.4854
# Epoch 1: val_accuracy improved from -inf to 0.26235, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 9s 116ms/step - loss: 0.7141 - accuracy: 0.4850 - f1_score: 0.4854 - val_loss: 0.6634 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6915 - accuracy: 0.4978 - f1_score: 0.4978
# Epoch 2: val_accuracy did not improve from 0.26235
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6902 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7077 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6883 - accuracy: 0.5010 - f1_score: 0.5010
# Epoch 3: val_accuracy did not improve from 0.26235
# 16/16 [==============================] - 0s 28ms/step - loss: 0.6891 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7083 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6849 - accuracy: 0.5052 - f1_score: 0.5052
# Epoch 4: val_accuracy did not improve from 0.26235
# 16/16 [==============================] - 0s 29ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.4974 - val_loss: 0.6821 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6361 - accuracy: 0.5375 - f1_score: 0.5375
# Epoch 5: val_accuracy improved from 0.26235 to 0.73765, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.6364 - accuracy: 0.5369 - f1_score: 0.5366 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 6/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7103 - accuracy: 0.4967 - f1_score: 0.4967
# Epoch 6: val_accuracy did not improve from 0.73765
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7025 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.2622 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7037 - accuracy: 0.4958 - f1_score: 0.4958
# Epoch 7: val_accuracy did not improve from 0.73765
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6953 - accuracy: 0.5000 - f1_score: 0.5020 - val_loss: 0.2620 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6547 - accuracy: 0.5333 - f1_score: 0.5333
# Epoch 8: val_accuracy improved from 0.73765 to 0.74074, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 41ms/step - loss: 0.6436 - accuracy: 0.5419 - f1_score: 0.5461 - val_loss: 0.2594 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 9/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4989 - accuracy: 0.6362 - f1_score: 0.6362
# Epoch 9: val_accuracy improved from 0.74074 to 0.74383, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4842 - accuracy: 0.6477 - f1_score: 0.6502 - val_loss: 0.2553 - val_accuracy: 0.7438 - val_f1_score: 0.7448 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4203 - accuracy: 0.6969 - f1_score: 0.6969
# Epoch 10: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4181 - accuracy: 0.6976 - f1_score: 0.6980 - val_loss: 0.2765 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 0.0010
# Epoch 11/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3825 - accuracy: 0.7243 - f1_score: 0.7243
# Epoch 11: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3770 - accuracy: 0.7295 - f1_score: 0.7313 - val_loss: 0.4402 - val_accuracy: 0.5586 - val_f1_score: 0.5885 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3308 - accuracy: 0.7552 - f1_score: 0.7552
# Epoch 12: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3324 - accuracy: 0.7545 - f1_score: 0.7541 - val_loss: 0.3002 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.7725 - f1_score: 0.7722
# Epoch 13: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3115 - accuracy: 0.7725 - f1_score: 0.7722 - val_loss: 0.2799 - val_accuracy: 0.7191 - val_f1_score: 0.7240 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8104 - f1_score: 0.8119
# Epoch 14: val_accuracy improved from 0.74383 to 0.75000, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.2632 - accuracy: 0.8104 - f1_score: 0.8119 - val_loss: 0.2537 - val_accuracy: 0.7500 - val_f1_score: 0.7500 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.8094 - f1_score: 0.8068
# Epoch 15: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2679 - accuracy: 0.8094 - f1_score: 0.8068 - val_loss: 0.2763 - val_accuracy: 0.7253 - val_f1_score: 0.7292 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2684 - accuracy: 0.8031 - f1_score: 0.8031
# Epoch 16: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2676 - accuracy: 0.8044 - f1_score: 0.8050 - val_loss: 0.2904 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.8114 - f1_score: 0.8108
# Epoch 17: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2602 - accuracy: 0.8114 - f1_score: 0.8108 - val_loss: 0.3022 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2561 - accuracy: 0.8184 - f1_score: 0.8182
# Epoch 18: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2561 - accuracy: 0.8184 - f1_score: 0.8182 - val_loss: 0.4009 - val_accuracy: 0.5988 - val_f1_score: 0.6615 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8024 - f1_score: 0.8036
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
#
# Epoch 19: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2746 - accuracy: 0.8024 - f1_score: 0.8036 - val_loss: 0.2968 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.8303 - f1_score: 0.8309
# Epoch 20: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2368 - accuracy: 0.8303 - f1_score: 0.8309 - val_loss: 0.2932 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 9.5000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.8463 - f1_score: 0.8460
# Epoch 21: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2156 - accuracy: 0.8463 - f1_score: 0.8460 - val_loss: 0.2814 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 9.5000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.8463 - f1_score: 0.8471
# Epoch 22: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2117 - accuracy: 0.8463 - f1_score: 0.8471 - val_loss: 0.3139 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 9.5000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.8543 - f1_score: 0.8549
# Epoch 23: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2054 - accuracy: 0.8543 - f1_score: 0.8549 - val_loss: 0.2684 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 9.5000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.8483 - f1_score: 0.8511
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
#
# Epoch 24: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2137 - accuracy: 0.8483 - f1_score: 0.8511 - val_loss: 0.4371 - val_accuracy: 0.5617 - val_f1_score: 0.5521 - lr: 9.5000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.8443 - f1_score: 0.8410
# Epoch 25: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2103 - accuracy: 0.8443 - f1_score: 0.8410 - val_loss: 0.4912 - val_accuracy: 0.5093 - val_f1_score: 0.5078 - lr: 9.0250e-04
# Epoch 26/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2254 - accuracy: 0.8382 - f1_score: 0.8382
# Epoch 26: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2258 - accuracy: 0.8383 - f1_score: 0.8382 - val_loss: 0.2725 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 9.0250e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.8563 - f1_score: 0.8558
# Epoch 27: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2028 - accuracy: 0.8563 - f1_score: 0.8558 - val_loss: 0.2785 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 9.0250e-04
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1888 - accuracy: 0.8667 - f1_score: 0.8667
# Epoch 28: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1896 - accuracy: 0.8663 - f1_score: 0.8661 - val_loss: 0.2935 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 9.0250e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.8792 - f1_score: 0.8803
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
#
# Epoch 29: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1696 - accuracy: 0.8792 - f1_score: 0.8803 - val_loss: 0.2906 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 9.0250e-04
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1633 - accuracy: 0.8844 - f1_score: 0.8844
# Epoch 30: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1621 - accuracy: 0.8852 - f1_score: 0.8856 - val_loss: 0.3183 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 8.5737e-04
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1678 - accuracy: 0.8802 - f1_score: 0.8802
# Epoch 31: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1642 - accuracy: 0.8832 - f1_score: 0.8847 - val_loss: 0.3002 - val_accuracy: 0.6944 - val_f1_score: 0.6641 - lr: 8.5737e-04
# Epoch 32/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1834 - accuracy: 0.8683 - f1_score: 0.8683
# Epoch 32: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1834 - accuracy: 0.8693 - f1_score: 0.8700 - val_loss: 0.3095 - val_accuracy: 0.6944 - val_f1_score: 0.6641 - lr: 8.5737e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.8643 - f1_score: 0.8651
# Epoch 33: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1889 - accuracy: 0.8643 - f1_score: 0.8651 - val_loss: 0.3403 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 8.5737e-04
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.8723 - f1_score: 0.8714
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
#
# Epoch 34: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1835 - accuracy: 0.8723 - f1_score: 0.8714 - val_loss: 0.2794 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 8.5737e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.8743 - f1_score: 0.8749
# Epoch 35: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1733 - accuracy: 0.8743 - f1_score: 0.8749 - val_loss: 0.3134 - val_accuracy: 0.6883 - val_f1_score: 0.6589 - lr: 8.1451e-04
# Epoch 36/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1682 - accuracy: 0.8772 - f1_score: 0.8772
# Epoch 36: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1600 - accuracy: 0.8842 - f1_score: 0.8857 - val_loss: 0.2910 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 8.1451e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.8553 - f1_score: 0.8574
# Epoch 37: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2025 - accuracy: 0.8553 - f1_score: 0.8574 - val_loss: 0.3260 - val_accuracy: 0.6759 - val_f1_score: 0.6484 - lr: 8.1451e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.8713 - f1_score: 0.8699
# Epoch 38: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1776 - accuracy: 0.8713 - f1_score: 0.8699 - val_loss: 0.2882 - val_accuracy: 0.7191 - val_f1_score: 0.7240 - lr: 8.1451e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.8683 - f1_score: 0.8680
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
#
# Epoch 39: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1802 - accuracy: 0.8683 - f1_score: 0.8680 - val_loss: 0.2871 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 8.1451e-04
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.8743 - f1_score: 0.8749
# Epoch 40: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1728 - accuracy: 0.8743 - f1_score: 0.8749 - val_loss: 0.3016 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 7.7378e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1442 - accuracy: 0.8958 - f1_score: 0.8958
# Epoch 41: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1491 - accuracy: 0.8912 - f1_score: 0.8890 - val_loss: 0.3182 - val_accuracy: 0.6821 - val_f1_score: 0.6536 - lr: 7.7378e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1390 - accuracy: 0.9010 - f1_score: 0.9010
# Epoch 42: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1420 - accuracy: 0.8992 - f1_score: 0.8983 - val_loss: 0.2996 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 7.7378e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9112 - f1_score: 0.9126
# Epoch 43: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1216 - accuracy: 0.9112 - f1_score: 0.9126 - val_loss: 0.2995 - val_accuracy: 0.7006 - val_f1_score: 0.6693 - lr: 7.7378e-04
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9032 - f1_score: 0.9043
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
#
# Epoch 44: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1356 - accuracy: 0.9032 - f1_score: 0.9043 - val_loss: 0.3540 - val_accuracy: 0.6420 - val_f1_score: 0.6198 - lr: 7.7378e-04
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.8982 - f1_score: 0.8994
# Epoch 45: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1397 - accuracy: 0.8982 - f1_score: 0.8994 - val_loss: 0.3198 - val_accuracy: 0.6821 - val_f1_score: 0.6536 - lr: 7.3509e-04
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9022 - f1_score: 0.9007
# Epoch 46: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1373 - accuracy: 0.9022 - f1_score: 0.9007 - val_loss: 0.4442 - val_accuracy: 0.5617 - val_f1_score: 0.5521 - lr: 7.3509e-04
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.8553 - f1_score: 0.8574
# Epoch 47: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2001 - accuracy: 0.8553 - f1_score: 0.8574 - val_loss: 0.3707 - val_accuracy: 0.6235 - val_f1_score: 0.5651 - lr: 7.3509e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.8882 - f1_score: 0.8906
# Epoch 48: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1584 - accuracy: 0.8882 - f1_score: 0.8906 - val_loss: 0.2940 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 7.3509e-04
# Epoch 49/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.8733 - f1_score: 0.8750
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
#
# Epoch 49: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1728 - accuracy: 0.8733 - f1_score: 0.8750 - val_loss: 0.3084 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 7.3509e-04
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1374 - accuracy: 0.9007 - f1_score: 0.9007
# Epoch 50: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1385 - accuracy: 0.9012 - f1_score: 0.9018 - val_loss: 0.3317 - val_accuracy: 0.6759 - val_f1_score: 0.6484 - lr: 6.9834e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1224 - accuracy: 0.9115 - f1_score: 0.9115
# Epoch 51: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1267 - accuracy: 0.9082 - f1_score: 0.9066 - val_loss: 0.2908 - val_accuracy: 0.7068 - val_f1_score: 0.6745 - lr: 6.9834e-04
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.8812 - f1_score: 0.8812
# Epoch 52: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1622 - accuracy: 0.8812 - f1_score: 0.8812 - val_loss: 0.3177 - val_accuracy: 0.6821 - val_f1_score: 0.6536 - lr: 6.9834e-04
# Epoch 53/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9032 - f1_score: 0.9048
# Epoch 53: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1357 - accuracy: 0.9032 - f1_score: 0.9048 - val_loss: 0.3485 - val_accuracy: 0.6512 - val_f1_score: 0.6276 - lr: 6.9834e-04
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9142 - f1_score: 0.9140
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
#
# Epoch 54: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1181 - accuracy: 0.9142 - f1_score: 0.9140 - val_loss: 0.3630 - val_accuracy: 0.6358 - val_f1_score: 0.6146 - lr: 6.9834e-04
# Epoch 55/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9162 - f1_score: 0.9154
# Epoch 55: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1208 - accuracy: 0.9162 - f1_score: 0.9154 - val_loss: 0.2878 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 6.6342e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.8992 - f1_score: 0.8993
# Epoch 56: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1379 - accuracy: 0.8992 - f1_score: 0.8993 - val_loss: 0.3046 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 6.6342e-04
# Epoch 57/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1239 - accuracy: 0.9107 - f1_score: 0.9107
# Epoch 57: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1172 - accuracy: 0.9152 - f1_score: 0.9165 - val_loss: 0.3357 - val_accuracy: 0.6636 - val_f1_score: 0.6380 - lr: 6.6342e-04
# Epoch 58/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9172 - f1_score: 0.9169
# Epoch 58: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1157 - accuracy: 0.9172 - f1_score: 0.9169 - val_loss: 0.4154 - val_accuracy: 0.5833 - val_f1_score: 0.5703 - lr: 6.6342e-04
# Epoch 59/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9132 - f1_score: 0.9130
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
#
# Epoch 59: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1208 - accuracy: 0.9132 - f1_score: 0.9130 - val_loss: 0.3159 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 6.6342e-04
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9182 - f1_score: 0.9189
# Epoch 60: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1151 - accuracy: 0.9182 - f1_score: 0.9189 - val_loss: 0.3070 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 6.3025e-04
# Epoch 61/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9192 - f1_score: 0.9189
# Epoch 61: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1131 - accuracy: 0.9192 - f1_score: 0.9189 - val_loss: 0.3459 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 6.3025e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0977 - accuracy: 0.9292 - f1_score: 0.9292
# Epoch 62: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1012 - accuracy: 0.9271 - f1_score: 0.9262 - val_loss: 0.2994 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 6.3025e-04
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9232 - f1_score: 0.9238
# Epoch 63: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1063 - accuracy: 0.9232 - f1_score: 0.9238 - val_loss: 0.3578 - val_accuracy: 0.6420 - val_f1_score: 0.6198 - lr: 6.3025e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0940 - accuracy: 0.9344 - f1_score: 0.9344
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
#
# Epoch 64: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0914 - accuracy: 0.9361 - f1_score: 0.9370 - val_loss: 0.3300 - val_accuracy: 0.6728 - val_f1_score: 0.6849 - lr: 6.3025e-04
# Epoch 65/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9251 - f1_score: 0.9252
# Epoch 65: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1062 - accuracy: 0.9251 - f1_score: 0.9252 - val_loss: 0.3656 - val_accuracy: 0.6296 - val_f1_score: 0.6094 - lr: 5.9874e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0908 - accuracy: 0.9344 - f1_score: 0.9344
# Epoch 66: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0943 - accuracy: 0.9311 - f1_score: 0.9295 - val_loss: 0.2890 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 5.9874e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0970 - accuracy: 0.9302 - f1_score: 0.9302
# Epoch 67: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0957 - accuracy: 0.9311 - f1_score: 0.9316 - val_loss: 0.3436 - val_accuracy: 0.6512 - val_f1_score: 0.6276 - lr: 5.9874e-04
# Epoch 68/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1170 - accuracy: 0.9163 - f1_score: 0.9163
# Epoch 68: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1158 - accuracy: 0.9162 - f1_score: 0.9159 - val_loss: 0.3046 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 5.9874e-04
# Epoch 69/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9172 - f1_score: 0.9179
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
#
# Epoch 69: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1168 - accuracy: 0.9172 - f1_score: 0.9179 - val_loss: 0.3428 - val_accuracy: 0.6636 - val_f1_score: 0.6380 - lr: 5.9874e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1186 - accuracy: 0.9167 - f1_score: 0.9167
# Epoch 70: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1167 - accuracy: 0.9182 - f1_score: 0.9189 - val_loss: 0.3134 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 5.6880e-04
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9232 - f1_score: 0.9222
# Epoch 71: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1068 - accuracy: 0.9232 - f1_score: 0.9222 - val_loss: 0.3452 - val_accuracy: 0.6574 - val_f1_score: 0.6328 - lr: 5.6880e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1000 - accuracy: 0.9260 - f1_score: 0.9260
# Epoch 72: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0968 - accuracy: 0.9281 - f1_score: 0.9292 - val_loss: 0.3149 - val_accuracy: 0.6821 - val_f1_score: 0.6536 - lr: 5.6880e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1272 - accuracy: 0.9094 - f1_score: 0.9094
# Epoch 73: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1292 - accuracy: 0.9082 - f1_score: 0.9076 - val_loss: 0.3288 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 5.6880e-04
# Epoch 74/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9281 - f1_score: 0.9292
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
#
# Epoch 74: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1022 - accuracy: 0.9281 - f1_score: 0.9292 - val_loss: 0.3212 - val_accuracy: 0.6790 - val_f1_score: 0.6510 - lr: 5.6880e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0972 - accuracy: 0.9292 - f1_score: 0.9292
# Epoch 75: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0931 - accuracy: 0.9321 - f1_score: 0.9336 - val_loss: 0.3157 - val_accuracy: 0.6790 - val_f1_score: 0.6120 - lr: 5.4036e-04
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9421 - f1_score: 0.9428
# Epoch 76: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0820 - accuracy: 0.9421 - f1_score: 0.9428 - val_loss: 0.3510 - val_accuracy: 0.6512 - val_f1_score: 0.6276 - lr: 5.4036e-04
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9371 - f1_score: 0.9359
# Epoch 77: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0855 - accuracy: 0.9371 - f1_score: 0.9359 - val_loss: 0.3503 - val_accuracy: 0.6481 - val_f1_score: 0.6250 - lr: 5.4036e-04
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9441 - f1_score: 0.9438
# Epoch 78: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0793 - accuracy: 0.9441 - f1_score: 0.9438 - val_loss: 0.3039 - val_accuracy: 0.6944 - val_f1_score: 0.6250 - lr: 5.4036e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1010 - accuracy: 0.9260 - f1_score: 0.9260
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
#
# Epoch 79: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0985 - accuracy: 0.9281 - f1_score: 0.9292 - val_loss: 0.3078 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.4036e-04
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9112 - f1_score: 0.9121
# Epoch 80: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1236 - accuracy: 0.9112 - f1_score: 0.9121 - val_loss: 0.3004 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 5.1334e-04
# Epoch 81/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9261 - f1_score: 0.9257
# Epoch 81: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1058 - accuracy: 0.9261 - f1_score: 0.9257 - val_loss: 0.3182 - val_accuracy: 0.6790 - val_f1_score: 0.6510 - lr: 5.1334e-04
# Epoch 82/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0818 - accuracy: 0.9420 - f1_score: 0.9420
# Epoch 82: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0801 - accuracy: 0.9421 - f1_score: 0.9418 - val_loss: 0.3510 - val_accuracy: 0.6543 - val_f1_score: 0.5911 - lr: 5.1334e-04
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9471 - f1_score: 0.9482
# Epoch 83: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0745 - accuracy: 0.9471 - f1_score: 0.9482 - val_loss: 0.3116 - val_accuracy: 0.6914 - val_f1_score: 0.6615 - lr: 5.1334e-04
# Epoch 84/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9491 - f1_score: 0.9497
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
#
# Epoch 84: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0701 - accuracy: 0.9491 - f1_score: 0.9497 - val_loss: 0.3330 - val_accuracy: 0.6698 - val_f1_score: 0.6432 - lr: 5.1334e-04
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9371 - f1_score: 0.9344
# Epoch 85: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0875 - accuracy: 0.9371 - f1_score: 0.9344 - val_loss: 0.4172 - val_accuracy: 0.5833 - val_f1_score: 0.5703 - lr: 4.8767e-04
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9381 - f1_score: 0.9379
# Epoch 86: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0851 - accuracy: 0.9381 - f1_score: 0.9379 - val_loss: 0.2957 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 4.8767e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0910 - accuracy: 0.9344 - f1_score: 0.9344
# Epoch 87: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0899 - accuracy: 0.9351 - f1_score: 0.9355 - val_loss: 0.3138 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.8767e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0680 - accuracy: 0.9510 - f1_score: 0.9510
# Epoch 88: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0678 - accuracy: 0.9511 - f1_score: 0.9511 - val_loss: 0.3146 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.8767e-04
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9471 - f1_score: 0.9462
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
#
# Epoch 89: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0764 - accuracy: 0.9471 - f1_score: 0.9462 - val_loss: 0.3466 - val_accuracy: 0.6420 - val_f1_score: 0.5807 - lr: 4.8767e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0756 - accuracy: 0.9479 - f1_score: 0.9479
# Epoch 90: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0750 - accuracy: 0.9481 - f1_score: 0.9482 - val_loss: 0.2963 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 4.6329e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9501 - f1_score: 0.9496
# Epoch 91: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0723 - accuracy: 0.9501 - f1_score: 0.9496 - val_loss: 0.3090 - val_accuracy: 0.6944 - val_f1_score: 0.7031 - lr: 4.6329e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0773 - accuracy: 0.9458 - f1_score: 0.9458
# Epoch 92: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0761 - accuracy: 0.9461 - f1_score: 0.9462 - val_loss: 0.3304 - val_accuracy: 0.6667 - val_f1_score: 0.6406 - lr: 4.6329e-04
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9481 - f1_score: 0.9487
# Epoch 93: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0717 - accuracy: 0.9481 - f1_score: 0.9487 - val_loss: 0.3219 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 4.6329e-04
# Epoch 94/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0721 - accuracy: 0.9487 - f1_score: 0.9487
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
#
# Epoch 94: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0719 - accuracy: 0.9491 - f1_score: 0.9497 - val_loss: 0.3001 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 4.6329e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0741 - accuracy: 0.9469 - f1_score: 0.9469
# Epoch 95: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0713 - accuracy: 0.9491 - f1_score: 0.9502 - val_loss: 0.3163 - val_accuracy: 0.6821 - val_f1_score: 0.6146 - lr: 4.4013e-04
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9351 - f1_score: 0.9329
# Epoch 96: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0896 - accuracy: 0.9351 - f1_score: 0.9329 - val_loss: 0.3852 - val_accuracy: 0.6142 - val_f1_score: 0.5964 - lr: 4.4013e-04
# Epoch 97/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0691 - accuracy: 0.9498 - f1_score: 0.9498
# Epoch 97: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0709 - accuracy: 0.9491 - f1_score: 0.9487 - val_loss: 0.3227 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 4.4013e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0813 - accuracy: 0.9406 - f1_score: 0.9406
# Epoch 98: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0818 - accuracy: 0.9401 - f1_score: 0.9399 - val_loss: 0.4682 - val_accuracy: 0.5309 - val_f1_score: 0.4870 - lr: 4.4013e-04
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9401 - f1_score: 0.9404
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
#
# Epoch 99: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0846 - accuracy: 0.9401 - f1_score: 0.9404 - val_loss: 0.2859 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 4.4013e-04
# Epoch 100/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0736 - accuracy: 0.9475 - f1_score: 0.9475
# Epoch 100: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0735 - accuracy: 0.9471 - f1_score: 0.9472 - val_loss: 0.3005 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 4.1812e-04
# Epoch 101/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9491 - f1_score: 0.9487
# Epoch 101: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0703 - accuracy: 0.9491 - f1_score: 0.9487 - val_loss: 0.3371 - val_accuracy: 0.6605 - val_f1_score: 0.6354 - lr: 4.1812e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0672 - accuracy: 0.9531 - f1_score: 0.9531
# Epoch 102: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0704 - accuracy: 0.9511 - f1_score: 0.9501 - val_loss: 0.3143 - val_accuracy: 0.6852 - val_f1_score: 0.6953 - lr: 4.1812e-04
# Epoch 103/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0709 - accuracy: 0.9509 - f1_score: 0.9509
# Epoch 103: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0728 - accuracy: 0.9491 - f1_score: 0.9481 - val_loss: 0.3562 - val_accuracy: 0.6451 - val_f1_score: 0.6224 - lr: 4.1812e-04
# Epoch 104/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0719 - accuracy: 0.9487 - f1_score: 0.9487
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
#
# Epoch 104: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0808 - accuracy: 0.9431 - f1_score: 0.9433 - val_loss: 0.3046 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 4.1812e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0715 - accuracy: 0.9500 - f1_score: 0.9500
# Epoch 105: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0708 - accuracy: 0.9501 - f1_score: 0.9501 - val_loss: 0.2889 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 3.9721e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0699 - accuracy: 0.9510 - f1_score: 0.9510
# Epoch 106: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0719 - accuracy: 0.9491 - f1_score: 0.9481 - val_loss: 0.3272 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 3.9721e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0570 - accuracy: 0.9604 - f1_score: 0.9604
# Epoch 107: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0620 - accuracy: 0.9561 - f1_score: 0.9540 - val_loss: 0.3365 - val_accuracy: 0.6636 - val_f1_score: 0.6771 - lr: 3.9721e-04
# Epoch 108/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0719 - accuracy: 0.9475 - f1_score: 0.9475
# Epoch 108: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0743 - accuracy: 0.9461 - f1_score: 0.9452 - val_loss: 0.2891 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 3.9721e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0897 - accuracy: 0.9365 - f1_score: 0.9365
# Epoch 109: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
#
# Epoch 109: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0894 - accuracy: 0.9371 - f1_score: 0.9375 - val_loss: 0.3129 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 3.9721e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0681 - accuracy: 0.9500 - f1_score: 0.9500
# Epoch 110: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0682 - accuracy: 0.9501 - f1_score: 0.9501 - val_loss: 0.2943 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 3.7735e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0610 - accuracy: 0.9563 - f1_score: 0.9562
# Epoch 111: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0614 - accuracy: 0.9561 - f1_score: 0.9560 - val_loss: 0.2991 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 3.7735e-04
# Epoch 112/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9581 - f1_score: 0.9585
# Epoch 112: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0588 - accuracy: 0.9581 - f1_score: 0.9585 - val_loss: 0.3114 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 3.7735e-04
# Epoch 113/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9541 - f1_score: 0.9551
# Epoch 113: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0637 - accuracy: 0.9541 - f1_score: 0.9551 - val_loss: 0.3180 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 3.7735e-04
# Epoch 114/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9611 - f1_score: 0.9604Restoring model weights from the end of the best epoch: 14.
#
# Epoch 114: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
#
# Epoch 114: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0542 - accuracy: 0.9611 - f1_score: 0.9604 - val_loss: 0.3221 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 3.7735e-04
# Epoch 114: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.75

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.75
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.53      0.38      0.44        85
#            0       0.80      0.88      0.84       239
#
#     accuracy                           0.75       324
#    macro avg       0.67      0.63      0.64       324
# weighted avg       0.73      0.75      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 243 chiếm khoảng 75.0% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 32 chiếm khoảng 37.64705882352941% so với thực tế
