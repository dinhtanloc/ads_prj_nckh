# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder(sparse=False)
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder(sparse=False)
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels

y_train=oneHot(y_train)
y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
# input_shape =(42,1)
# x_input = Input(shape=input_shape)
# dense_units = 1024
# learning_rate = 0.0001
# kernel_size =3
# filter_size=96

# def VGG19():
#     # Determine proper input shape
#     input_shape =(42,1)
#     x_input = Input(shape=input_shape)

#     # Block 1
#     x = Conv1D(filter_size, 3, activation='relu', padding='same', name='block1_conv1')(x_input)
#     x = Conv1D(filter_size, 3, activation='relu', padding='same', name='block1_conv2')(x)
#     x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

#     # Block 2
#     x = Conv1D(filter_size*2, 3, activation='relu', padding='same', name='block2_conv1')(x)
#     x = Conv1D(filter_size*2, 3, activation='relu', padding='same', name='block2_conv2')(x)
#     x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

#     # Block 3
#     x = Conv1D(filter_size*4, 3, activation='relu', padding='same', name='block3_conv1')(x)
#     x = Conv1D(filter_size*4, 3, activation='relu', padding='same', name='block3_conv2')(x)
#     x = Conv1D(filter_size*4, 3, activation='relu', padding='same', name='block3_conv3')(x)
#     x = Conv1D(filter_size*4, 3, activation='relu', padding='same', name='block3_conv4')(x)
#     x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

#     # Block 4
#     x = Conv1D(filter_size*6, 3, activation='relu', padding='same', name='block4_conv1')(x)
#     x = Conv1D(filter_size*6, 3, activation='relu', padding='same', name='block4_conv2')(x)
#     x = Conv1D(filter_size*6, 3, activation='relu', padding='same', name='block4_conv3')(x)
#     x = Conv1D(filter_size*6, 3, activation='relu', padding='same', name='block4_conv4')(x)
#     x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

#     # Block 5
#     x = Conv1D(filter_size*8, 3, activation='relu', padding='same', name='block5_conv1')(x)
#     x = Conv1D(filter_size*8, 3, activation='relu', padding='same', name='block5_conv2')(x)
#     x = Conv1D(filter_size*8, 3, activation='relu', padding='same', name='block5_conv3')(x)
#     x = Conv1D(filter_size*8, 3, activation='relu', padding='same', name='block5_conv4')(x)

#     x = MaxPooling1D(2, strides=2, name='block5_pool')(x)
    
#     # x = Flatten(name='flatten')(x)
#     # x = Dense(4096, activation='relu', name='fc1')(x)
#     # x = Dense(4096, activation='relu', name='fc2')(x)
#     # x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

#     x = GlobalAveragePooling1D()(x)
#     #x = GlobalMaxPooling1D()(x)
#     x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

#     # Create model.
#     model = Model(x_input, x, name='vgg19')
#     return model
# model = VGG19()
# # lr=0.0001
# # model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# # model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# # model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
# early_stopping = EarlyStopping(monitor='val_accuracy',
#     # min_delta=0.00005,
#     patience=60,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_accuracy',
#     factor=0.95,
#     patience=10,
#     min_lr=0.000001,
#     verbose=1,
# )

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 2)

# %%
# from tensorflow.keras.optimizers import Adam
# from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
# from keras.models import Model
# from keras.layers import Input
# from kerastuner import Objective  # Add this line to import Objective

# lr=0.0001

# def build_model(hp):
#     input_shape =(42,1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1
#     step=32
#     # Sử dụng filters trong hàm build_resnet_model
#     filters1 = [hp.Int('filter1', min_value=32, max_value=1024, step=step), hp.Int('filter2', min_value=32, max_value=1024, step=step), hp.Int('filter3', min_value=128, max_value=3096, step=128)]
#     filters2 = [hp.Int('filter4', min_value=32, max_value=1024, step=step), hp.Int('filter5', min_value=32, max_value=1024, step=step), hp.Int('filter6', min_value=128, max_value=3096, step=128)]
#     filters3 = [hp.Int('filter7', min_value=32, max_value=1024, step=step), hp.Int('filter8', min_value=32, max_value=1024, step=step), hp.Int('filter9', min_value=128, max_value=3096, step=128)]
#     # filters4 = [hp.Int('filter10', min_value=32, max_value=1024, step=step), hp.Int('filter11', min_value=32, max_value=1024, step=step), hp.Int('filter12', min_value=128, max_value=3096, step=128)]
#     # 3 = hp.Int('3', min_value=2, max_value=5, step=1)
#     learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, filters1, stage=2, block='a', strides=1)
#     # x = identity_block(x, 3, filters1, stage=2, block='b')
#     # x = identity_block(x, 3, filters1, stage=2, block='c')

#     x = conv_block(x, 3, filters2, stage=3, block='a')
#     # x = identity_block(x, 3, filters2, stage=3, block='b')
#     # x = identity_block(x, 3, filters2, stage=3, block='c')
#     # x = identity_block(x, 3, filters2, stage=3, block='d')
    
#     x = conv_block(x, 3, filters3, stage=4, block='a')
#     # x = identity_block(x, 3, filters3, stage=4, block='b')
#     # x = identity_block(x, 3, filters3, stage=4, block='c')
#     # x = identity_block(x, 3, filters3, stage=4, block='d')
#     # x = identity_block(x, 3, filters3, stage=4, block='e')
#     # x = identity_block(x, 3, filters3, stage=4, block='f')

#     # x = conv_block(x, 3, filters4, stage=5, block='a')
#     # x = identity_block(x, 3, filters4, stage=5, block='b')
#     # x = identity_block(x, 3, filters4, stage=5, block='c')
#     # Repeat this pattern as needed

#     # Ending layers
#     x = GlobalAveragePooling1D()(x)
#     #x = GlobalMaxPooling1D()(x)
#     # x = Flatten()(x)
#     #x = Dense(1, activation='sigmoid', name='fc')(x)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(x_input, x, name='resnet50_1d')
#     # model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics='accuracy')
#     # # model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

#     # model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
#     # # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
#     # model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])

#     return model

early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)

checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_accuracy',  # Theo dõi val_loss
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)
# # Tạo đối tượng RandomSearch tuner
# tuner = RandomSearch(build_model, objective=Objective("val_f1_score", direction="max"),  executions_per_trial=1, max_trials=10,directory='ResNet50')

# tuner.search_space_summary()

# data_order=8

# # Tìm kiếm tham số tốt nhất
# tuner.search(dict_data[data_order][0],dict_data[data_order][1],
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3]),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# # Lấy mô hình tốt nhất
# best_model = tuner.get_best_models(num_models=1)[0]
# best_model.summary()

# %%
# from tensorflow.keras.optimizers import Adam
# from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
# from keras.models import Model
# from keras.layers import Input
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 
# from kerastuner import Objective  # Add this line to import Objective

# from tensorflow.keras.optimizers import Adam
# from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
# from keras.models import Model
# from keras.layers import Input
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# # lr=0.001

# def build_model(hp):
#     input_shape =(42,1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1
#     step=32
#     # Sử dụng filters trong hàm build_resnet_model
#     # filters1 = 96
#     # filters2 = filters1 * 2
#     # filters3 = filters1 * 4
#     # filters4 = filters1 * 6
#     # filters5 = filters1 * 8
#     filters1=hp.Int('filter1', min_value=32, max_value=96, step=step)
#     filters2=hp.Int('filter2', min_value=64, max_value=256, step=step)
#     filters3=hp.Int('filter3', min_value=128, max_value=384, step=step)
#     filters4=hp.Int('filter4', min_value=192, max_value=512, step=step)
#     filters5=hp.Int('filter5', min_value=384, max_value=2048, step=step)

#     learning_rate = 0.001

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output=x
#     # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
#     # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output=x
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
#     x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
#     block3_output=x
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

#     x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
#     # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
#     # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
#     # Repeat this pattern as needed
#     hypercolumns = concatenate([GlobalMaxPooling1D()(block1_output),
#                                 GlobalMaxPooling1D()(block2_output),
#                                 GlobalMaxPooling1D()(block3_output),
#                                 GlobalMaxPooling1D()(x)], axis=-1)

#     # Ending layers
#     # x = GlobalAveragePooling1D()(hypercolumns)
#     # x = Dense(128, activation='relu')(hypercolumns)

#     x = Dense(2, activation='softmax', name='fc1000')(hypercolumns)

#     # Create model
#     model = Model(x_input, x, name='resnet50_1d')

#     # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
#     model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
    
#     return model



# # Tạo đối tượng RandomSearch tuner
# tuner = RandomSearch(build_model, objective=Objective("val_f1_score", direction="max"),  executions_per_trial=1, max_trials=100,directory='ResNet50_hyper')

# tuner.search_space_summary()

# data_order=8

# # Tìm kiếm tham số tốt nhất
# tuner.search(dict_data[data_order][0],dict_data[data_order][1],
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3]),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# # Lấy mô hình tốt nhất
# best_model = tuner.get_best_models(num_models=1)[0]
# best_model.summary()

# %%
# # Sau khi tìm kiếm xong và lấy mô hình tốt nhất
# best_model = tuner.get_best_models(num_models=1)[0]

# # Lấy đối tượng HyperParameters từ tuner
# best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

# # In ra các giá trị tham số
# print("Best hyperparameters:")
# for param in best_hp.values.keys():
#     print(f"{param}: {best_hp.get(param)}")

# # Nếu bạn muốn in chuỗi các tham số
# best_params_str = ", ".join([f"{param}: {best_hp.get(param)}" for param in best_hp.values.keys()])
# print(f"Best hyperparameters as string: {best_params_str}")

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from scikeras.wrappers import KerasClassifier 
from kerastuner import Objective  # Add this line to import Objective

from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from scikeras.wrappers import KerasClassifier 

# lr=0.001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=96, step=step)
    # filters2=hp.Int('filter2', min_value=64, max_value=256, step=step)
    # filters3=hp.Int('filter3', min_value=128, max_value=384, step=step)
    # filters4=hp.Int('filter4', min_value=192, max_value=512, step=step)
    # filters5=hp.Int('filter5', min_value=384, max_value=2048, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    block1_output=x
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    block2_output=x
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    block3_output=x
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed
    hypercolumns = concatenate([GlobalMaxPooling1D()(block1_output),
                                GlobalMaxPooling1D()(block2_output),
                                GlobalMaxPooling1D()(block3_output),
                                GlobalMaxPooling1D()(x)], axis=-1)

    # Ending layers
    # x = GlobalAveragePooling1D()(hypercolumns)
    # x = Dense(128, activation='relu')(hypercolumns)

    x = Dense(2, activation='softmax', name='fc1000')(hypercolumns)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
    
    return model



# # Tạo đối tượng RandomSearch tuner
# tuner = RandomSearch(build_model, objective=Objective("val_f1_score", direction="max"),  executions_per_trial=1, max_trials=100,directory='ResNet50_hyper')

# tuner.search_space_summary()

# data_order=8

# # Tìm kiếm tham số tốt nhất
# tuner.search(dict_data[data_order][0],dict_data[data_order][1],
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3]),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# # Lấy mô hình tốt nhất
# best_model = tuner.get_best_models(num_models=1)[0]
best_model=build_model(32,256,192,256,672)
best_model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d (ZeroPaddin  (None, 44, 1)                0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 256)              8448      ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 256)              16640     ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 256)              40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 256)              40        ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 10, 256)              0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 10, 256)              0         ['add[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 256)               65792     ['activation_3[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 256)               20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 5, 256)               0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 256)               196864    ['activation_4[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 256)               20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 5, 256)               0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 192)               49344     ['activation_5[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 192)               49344     ['activation_3[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 192)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 192)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_1 (Add)                 (None, 5, 192)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_6 (Activation)   (None, 5, 192)               0         ['add_1[0][0]']
#
#  res4a_branch2a (Conv1D)     (None, 3, 192)               37056     ['activation_6[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 3, 192)               12        ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 3, 192)               0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)     (None, 3, 192)               110784    ['activation_7[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 3, 192)               12        ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 3, 192)               0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)     (None, 3, 256)               49408     ['activation_8[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 3, 256)               49408     ['activation_6[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 3, 256)               12        ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 3, 256)               12        ['res4a_branch1[0][0]']
#  zation)
#
#  add_2 (Add)                 (None, 3, 256)               0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_9 (Activation)   (None, 3, 256)               0         ['add_2[0][0]']
#
#  res5a_branch2a (Conv1D)     (None, 2, 256)               65792     ['activation_9[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 2, 256)               8         ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 2, 256)               0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)     (None, 2, 256)               196864    ['activation_10[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 2, 256)               8         ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 2, 256)               0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)     (None, 2, 672)               172704    ['activation_11[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 2, 672)               172704    ['activation_9[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 2, 672)               8         ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 2, 672)               8         ['res5a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 2, 672)               0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 2, 672)               0         ['add_3[0][0]']
#
#  global_max_pooling1d (Glob  (None, 256)                  0         ['activation_3[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 192)                  0         ['activation_6[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_2 (Gl  (None, 256)                  0         ['activation_9[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 672)                  0         ['activation_12[0][0]']
#  obalMaxPooling1D)
#
#  concatenate (Concatenate)   (None, 1376)                 0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  fc1000 (Dense)              (None, 2)                    2754      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1250178 (4.77 MB)
# Trainable params: 1249890 (4.77 MB)
# Non-trainable params: 288 (1.12 KB)
# __________________________________________________________________________________________________

# %%
best_model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1],
          validation_data=(dict_data[data_order][2],dict_data[data_order][3]),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2842 - accuracy: 0.5073 - f1_score: 0.5073
# Epoch 1: val_accuracy improved from -inf to 0.64506, saving model to best_model.h5
# 16/16 [==============================] - 7s 64ms/step - loss: 1.2346 - accuracy: 0.5090 - f1_score: 0.5098 - val_loss: 0.1079 - val_accuracy: 0.6451 - val_f1_score: 0.5833 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.5689 - f1_score: 0.5705
# Epoch 2: val_accuracy did not improve from 0.64506
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1796 - accuracy: 0.5689 - f1_score: 0.5705 - val_loss: 0.1221 - val_accuracy: 0.5494 - val_f1_score: 0.4635 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.6786 - f1_score: 0.6774
# Epoch 3: val_accuracy did not improve from 0.64506
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0615 - accuracy: 0.6786 - f1_score: 0.6774 - val_loss: 0.1730 - val_accuracy: 0.3210 - val_f1_score: 0.3099 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0470 - accuracy: 0.7396 - f1_score: 0.7396
# Epoch 4: val_accuracy did not improve from 0.64506
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0478 - accuracy: 0.7375 - f1_score: 0.7365 - val_loss: 0.1812 - val_accuracy: 0.3241 - val_f1_score: 0.3125 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.7754 - f1_score: 0.7746
# Epoch 5: val_accuracy did not improve from 0.64506
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0435 - accuracy: 0.7754 - f1_score: 0.7746 - val_loss: 0.0637 - val_accuracy: 0.4907 - val_f1_score: 0.4531 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.8114 - f1_score: 0.8088
# Epoch 6: val_accuracy did not improve from 0.64506
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0372 - accuracy: 0.8114 - f1_score: 0.8088 - val_loss: 0.0439 - val_accuracy: 0.6327 - val_f1_score: 0.6510 - lr: 0.0010
# Epoch 7/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0384 - accuracy: 0.8089 - f1_score: 0.8089
# Epoch 7: val_accuracy improved from 0.64506 to 0.74074, saving model to best_model.h5
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0395 - accuracy: 0.7914 - f1_score: 0.7928 - val_loss: 0.0519 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 8/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0343 - accuracy: 0.8365 - f1_score: 0.8365
# Epoch 8: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0343 - accuracy: 0.8343 - f1_score: 0.8328 - val_loss: 0.0429 - val_accuracy: 0.6327 - val_f1_score: 0.6510 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.8743 - f1_score: 0.8723
# Epoch 9: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0281 - accuracy: 0.8743 - f1_score: 0.8723 - val_loss: 0.0405 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 0.0010
# Epoch 10/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0265 - accuracy: 0.8918 - f1_score: 0.8918
# Epoch 10: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0263 - accuracy: 0.8942 - f1_score: 0.8934 - val_loss: 0.0397 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0233 - accuracy: 0.8927 - f1_score: 0.8927
# Epoch 11: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0232 - accuracy: 0.8932 - f1_score: 0.8935 - val_loss: 0.0414 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 0.0010
# Epoch 12/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0240 - accuracy: 0.8882 - f1_score: 0.8882
# Epoch 12: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0245 - accuracy: 0.8832 - f1_score: 0.8837 - val_loss: 0.0490 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 13/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0220 - accuracy: 0.8966 - f1_score: 0.8966
# Epoch 13: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0229 - accuracy: 0.8912 - f1_score: 0.8920 - val_loss: 0.0399 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9421 - f1_score: 0.9413
# Epoch 14: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0170 - accuracy: 0.9421 - f1_score: 0.9413 - val_loss: 0.0443 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 15/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0149 - accuracy: 0.9531 - f1_score: 0.9531
# Epoch 15: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0147 - accuracy: 0.9491 - f1_score: 0.9487 - val_loss: 0.0486 - val_accuracy: 0.7253 - val_f1_score: 0.7292 - lr: 0.0010
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0128 - accuracy: 0.9509 - f1_score: 0.9509
# Epoch 16: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0126 - accuracy: 0.9511 - f1_score: 0.9511 - val_loss: 0.0456 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 0.0010
# Epoch 17/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0104 - accuracy: 0.9675 - f1_score: 0.9675
# Epoch 17: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0107 - accuracy: 0.9661 - f1_score: 0.9668 - val_loss: 0.0500 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9591 - f1_score: 0.9579
# Epoch 18: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0120 - accuracy: 0.9591 - f1_score: 0.9579 - val_loss: 0.0506 - val_accuracy: 0.7253 - val_f1_score: 0.7292 - lr: 0.0010
# Epoch 19/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0092 - accuracy: 0.9732 - f1_score: 0.9732
# Epoch 19: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0094 - accuracy: 0.9711 - f1_score: 0.9701 - val_loss: 0.0515 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9631 - f1_score: 0.9618
# Epoch 20: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0093 - accuracy: 0.9631 - f1_score: 0.9618 - val_loss: 0.0506 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9701 - f1_score: 0.9702
# Epoch 21: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0085 - accuracy: 0.9701 - f1_score: 0.9702 - val_loss: 0.0589 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9890 - f1_score: 0.9893
# Epoch 22: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0049 - accuracy: 0.9890 - f1_score: 0.9893 - val_loss: 0.0598 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 0.0010
# Epoch 23/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0029 - accuracy: 0.9967 - f1_score: 0.9967
# Epoch 23: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0029 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.0663 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 0.0010
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9880 - f1_score: 0.9878
# Epoch 24: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0046 - accuracy: 0.9880 - f1_score: 0.9878 - val_loss: 0.0666 - val_accuracy: 0.6512 - val_f1_score: 0.6667 - lr: 0.0010
# Epoch 25/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0079 - accuracy: 0.9643 - f1_score: 0.9643
# Epoch 25: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0077 - accuracy: 0.9671 - f1_score: 0.9678 - val_loss: 0.1009 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 0.0010
# Epoch 26/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0121 - accuracy: 0.9487 - f1_score: 0.9487
# Epoch 26: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0120 - accuracy: 0.9491 - f1_score: 0.9476 - val_loss: 0.1077 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 0.0010
# Epoch 27/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0165 - accuracy: 0.9339 - f1_score: 0.9339
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0164 - accuracy: 0.9291 - f1_score: 0.9286 - val_loss: 0.0916 - val_accuracy: 0.6605 - val_f1_score: 0.7135 - lr: 0.0010
# Epoch 28/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0062 - accuracy: 0.9736 - f1_score: 0.9736
# Epoch 28: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0075 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 0.0887 - val_accuracy: 0.6049 - val_f1_score: 0.6276 - lr: 5.0000e-04
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0047 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 29: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0050 - accuracy: 0.9810 - f1_score: 0.9794 - val_loss: 0.0906 - val_accuracy: 0.6358 - val_f1_score: 0.6536 - lr: 5.0000e-04
# Epoch 30/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0018 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 30: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0019 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.0877 - val_accuracy: 0.6636 - val_f1_score: 0.6771 - lr: 5.0000e-04
# Epoch 31/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0013 - accuracy: 0.9976 - f1_score: 0.9976
# Epoch 31: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.1015 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 5.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 32: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.0995 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 5.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 8.8793e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 33: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 23ms/step - loss: 8.8793e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.0000e-04
# Epoch 34/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 6.8017e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 34: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 6.6493e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 5.0000e-04
# Epoch 35/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 5.2443e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 35: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 5.4518e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.6420 - val_f1_score: 0.6589 - lr: 5.0000e-04
# Epoch 36/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 4.3100e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 36: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 21ms/step - loss: 4.4642e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.6667 - val_f1_score: 0.6797 - lr: 5.0000e-04
# Epoch 37/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.7327e-04 - accuracy: 0.9989 - f1_score: 0.9989Restoring model weights from the end of the best epoch: 7.
#
# Epoch 37: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 22ms/step - loss: 3.6762e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.1246 - val_accuracy: 0.6605 - val_f1_score: 0.6745 - lr: 5.0000e-04
# Epoch 37: early stopping

# %%
predictions = best_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 5ms/step
# 0.7407407407407407

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7407407407407407
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.01      0.02        85
#            0       0.74      1.00      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.87      0.51      0.44       324
# weighted avg       0.81      0.74      0.63       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 243 chiếm khoảng 75.0% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 30 chiếm khoảng 35.294117647058826% so với thực tế
