# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
print(y_test.shape)
# Out:
# (330, 1)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
lr=0.0001

def build_model():
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    filters1 = 96
    filters2 = filters1 * 2
    filters3 = filters1 * 4
    filters4 = filters1 * 8

    learning_rate = 0.00001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [32, 32, 128], stage=2, block='a', strides=1)
    x = identity_block(x, 3, [32, 32, 128], stage=2, block='b')
    x = identity_block(x, 3, [32, 32, 128], stage=2, block='c')

    x = conv_block(x, 3, [64, 64, 256], stage=3, block='a')
    x = identity_block(x, 3, [64, 64, 256], stage=3, block='b')
    x = identity_block(x, 3, [64, 64, 256], stage=3, block='c')
    x = identity_block(x, 3, [64, 64, 256], stage=3, block='d')
    
    # x = conv_block(x, 3, [128, 128, 512], stage=4, block='a')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='b')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='c')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='d')
    # x = identity_block(x, 3, [128, 128, 512], stage=4, block='e')
    # x = identity_block(x, 3,  [128, 128, 512], stage=4, block='f')

    # x = conv_block(x, 3, [256, 256, 1024], stage=5, block='a')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='b')
    # x = identity_block(x, 3, [256, 256, 1024], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# resNet50 = build_model()
# resNet50.summary()


early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.95,
    patience=2,
    min_lr=0.000001,
    verbose=1,
)

resNet50=build_model()
resNet50.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d (ZeroPaddin  (None, 44, 1)                0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 128)              4224      ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 128)              8320      ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 128)              40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 128)              40        ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 10, 128)              0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 10, 128)              0         ['add[0][0]']
#
#  res2b_branch2a (Conv1D)     (None, 10, 32)               4128      ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 10, 32)               40        ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 10, 32)               0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 10, 32)               40        ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 10, 32)               0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)     (None, 10, 128)              4224      ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 10, 128)              40        ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 10, 128)              0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 10, 128)              0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)     (None, 10, 32)               4128      ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 10, 32)               40        ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 10, 32)               0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 10, 32)               40        ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 10, 32)               0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)     (None, 10, 128)              4224      ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 10, 128)              40        ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 10, 128)              0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 10, 128)              0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 64)                8256      ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 64)                20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 5, 64)                0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 64)                12352     ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 64)                20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 5, 64)                0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 256)               16640     ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 256)               33024     ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 256)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 256)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 5, 256)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 5, 256)               0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)     (None, 5, 64)                16448     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 5, 64)                20        ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 5, 64)                0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)     (None, 5, 64)                12352     ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 5, 64)                20        ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 5, 64)                0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)     (None, 5, 256)               16640     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 5, 256)               20        ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 5, 256)               0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 5, 256)               0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)     (None, 5, 64)                16448     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 5, 64)                20        ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 5, 64)                0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)     (None, 5, 64)                12352     ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 5, 64)                20        ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 5, 64)                0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)     (None, 5, 256)               16640     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 5, 256)               20        ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 5, 256)               0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 5, 256)               0         ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)     (None, 5, 64)                16448     ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormal  (None, 5, 64)                20        ['res3d_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 5, 64)                0         ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)     (None, 5, 64)                12352     ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormal  (None, 5, 64)                20        ['res3d_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 5, 64)                0         ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)     (None, 5, 256)               16640     ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormal  (None, 5, 256)               20        ['res3d_branch2c[0][0]']
#  ization)
#
#  add_6 (Add)                 (None, 5, 256)               0         ['bn3d_branch2c[0][0]',
#                                                                      'activation_18[0][0]']
#
#  activation_21 (Activation)  (None, 5, 256)               0         ['add_6[0][0]']
#
#  global_average_pooling1d (  (None, 256)                  0         ['activation_21[0][0]']
#  GlobalAveragePooling1D)
#
#  fc1000 (Dense)              (None, 2)                    514       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 249174 (973.34 KB)
# Trainable params: 248716 (971.55 KB)
# Non-trainable params: 458 (1.79 KB)
# __________________________________________________________________________________________________

# %%
data_order = 8
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 10s 74ms/step - loss: 0.5014 - accuracy: 0.4990 - f1_score: 0.5006 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.2624 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5020
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5020 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.5000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4969
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4969 - val_loss: 0.2624 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.5000e-04
# Epoch 7/10000
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.2624 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.0250e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.0250e-04
# Epoch 9/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4969 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 8.5737e-04
# Epoch 10/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 8.5737e-04
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4990 - accuracy: 0.5010 - f1_score: 0.5010
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 8.5737e-04
# Epoch 12/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 8.1451e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4980
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 8.1451e-04
# Epoch 14/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 7.7378e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 7.7378e-04
# Epoch 16/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 7.3509e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4959
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4959 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 7.3509e-04
# Epoch 18/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.9834e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5031
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.9834e-04
# Epoch 20/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.6342e-04
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5094 - accuracy: 0.4906 - f1_score: 0.4906
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5046 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.6342e-04
# Epoch 22/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.3025e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5015
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.3025e-04
# Epoch 24/10000
# 16/16 [==============================] - 0s 22ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.9874e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4959
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4959 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.9874e-04
# Epoch 26/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.6880e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.6880e-04
# Epoch 28/10000
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.4036e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5020
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5020 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.4036e-04
# Epoch 30/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5036 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.1334e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
# 16/16 [==============================] - 0s 22ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.1334e-04
# Epoch 32/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.8767e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.8767e-04
# Epoch 34/10000
# 16/16 [==============================] - 0s 22ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.6329e-04
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5010 - accuracy: 0.4990 - f1_score: 0.4990
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.6329e-04
# Epoch 36/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.4013e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5005
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.4013e-04
# Epoch 38/10000
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.1812e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4980Restoring model weights from the end of the best epoch: 9.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 4.1812e-04
# Epoch 39: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 3ms/step
# 0.7376543209876543

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7376543209876543
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        85
#            0       0.74      1.00      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.37      0.50      0.42       324
# weighted avg       0.54      0.74      0.63       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 239 chiếm khoảng 73.76543209876543% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 0 chiếm khoảng 0.0% so với thực tế
