# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner



# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.4998 - accuracy: 0.4924 - f1_score: 0.3331
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 11/11 [==============================] - 11s 200ms/step - loss: 1.4998 - accuracy: 0.4924 - f1_score: 0.3331 - val_loss: 0.6188 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7341 - accuracy: 0.5069 - f1_score: 0.3624
# Epoch 2: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 0s 37ms/step - loss: 0.7344 - accuracy: 0.5213 - f1_score: 0.3707 - val_loss: 0.7744 - val_accuracy: 0.2747 - val_f1_score: 0.2239 - lr: 0.0010
# Epoch 3/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7009 - accuracy: 0.4774 - f1_score: 0.3836
# Epoch 3: val_f1_score improved from 0.42467 to 0.46665, saving model to best_model.h5
# 11/11 [==============================] - 1s 71ms/step - loss: 0.6944 - accuracy: 0.5030 - f1_score: 0.4097 - val_loss: 0.6247 - val_accuracy: 0.7346 - val_f1_score: 0.4667 - lr: 0.0010
# Epoch 4/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6755 - accuracy: 0.5716 - f1_score: 0.5150
# Epoch 4: val_f1_score did not improve from 0.46665
# 11/11 [==============================] - 0s 40ms/step - loss: 0.6755 - accuracy: 0.5716 - f1_score: 0.5150 - val_loss: 1.0349 - val_accuracy: 0.2593 - val_f1_score: 0.2036 - lr: 0.0010
# Epoch 5/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.7951 - accuracy: 0.5213 - f1_score: 0.3938
# Epoch 5: val_f1_score did not improve from 0.46665
# 11/11 [==============================] - 0s 39ms/step - loss: 0.7951 - accuracy: 0.5213 - f1_score: 0.3938 - val_loss: 0.7074 - val_accuracy: 0.4815 - val_f1_score: 0.3903 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.7496 - accuracy: 0.4451 - f1_score: 0.3749
# Epoch 6: val_f1_score did not improve from 0.46665
# 11/11 [==============================] - 0s 44ms/step - loss: 0.7496 - accuracy: 0.4451 - f1_score: 0.3749 - val_loss: 0.6483 - val_accuracy: 0.7407 - val_f1_score: 0.4567 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6599 - accuracy: 0.5198 - f1_score: 0.5110
# Epoch 7: val_f1_score improved from 0.46665 to 0.47341, saving model to best_model.h5
# 11/11 [==============================] - 1s 72ms/step - loss: 0.6599 - accuracy: 0.5198 - f1_score: 0.5110 - val_loss: 0.5971 - val_accuracy: 0.7191 - val_f1_score: 0.4734 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6175 - accuracy: 0.6387 - f1_score: 0.5659
# Epoch 8: val_f1_score improved from 0.47341 to 0.62565, saving model to best_model.h5
# 11/11 [==============================] - 1s 69ms/step - loss: 0.6175 - accuracy: 0.6387 - f1_score: 0.5659 - val_loss: 0.6504 - val_accuracy: 0.5988 - val_f1_score: 0.6256 - lr: 0.0010
# Epoch 9/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5568 - accuracy: 0.6829 - f1_score: 0.6500
# Epoch 9: val_f1_score improved from 0.62565 to 0.62661, saving model to best_model.h5
# 11/11 [==============================] - 1s 68ms/step - loss: 0.5568 - accuracy: 0.6829 - f1_score: 0.6500 - val_loss: 0.6353 - val_accuracy: 0.6049 - val_f1_score: 0.6266 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5310 - accuracy: 0.7088 - f1_score: 0.6717
# Epoch 10: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 0s 43ms/step - loss: 0.5310 - accuracy: 0.7088 - f1_score: 0.6717 - val_loss: 0.6720 - val_accuracy: 0.5586 - val_f1_score: 0.6016 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.6555 - f1_score: 0.6247
# Epoch 11: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 0s 40ms/step - loss: 0.5450 - accuracy: 0.6555 - f1_score: 0.6247 - val_loss: 0.6232 - val_accuracy: 0.6420 - val_f1_score: 0.6235 - lr: 0.0010
# Epoch 12/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.6829 - f1_score: 0.6773
# Epoch 12: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 0s 44ms/step - loss: 0.5001 - accuracy: 0.6829 - f1_score: 0.6773 - val_loss: 0.5969 - val_accuracy: 0.6173 - val_f1_score: 0.6211 - lr: 0.0010
# Epoch 13/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.4778 - accuracy: 0.7625 - f1_score: 0.7149
# Epoch 13: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 1s 48ms/step - loss: 0.4748 - accuracy: 0.7668 - f1_score: 0.7349 - val_loss: 0.7567 - val_accuracy: 0.5062 - val_f1_score: 0.5674 - lr: 0.0010
# Epoch 14/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4773 - accuracy: 0.7302 - f1_score: 0.6997
# Epoch 14: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 0s 42ms/step - loss: 0.4773 - accuracy: 0.7302 - f1_score: 0.6997 - val_loss: 0.6224 - val_accuracy: 0.6296 - val_f1_score: 0.6141 - lr: 0.0010
# Epoch 15/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.3810 - accuracy: 0.8062 - f1_score: 0.7762
# Epoch 15: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3788 - accuracy: 0.8064 - f1_score: 0.7642 - val_loss: 0.6132 - val_accuracy: 0.6914 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 16/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4377 - accuracy: 0.7866 - f1_score: 0.7525
# Epoch 16: val_f1_score did not improve from 0.62661
# 11/11 [==============================] - 1s 54ms/step - loss: 0.4377 - accuracy: 0.7866 - f1_score: 0.7525 - val_loss: 0.6975 - val_accuracy: 0.5494 - val_f1_score: 0.5597 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8308 - f1_score: 0.7907
# Epoch 17: val_f1_score improved from 0.62661 to 0.65233, saving model to best_model.h5
# 11/11 [==============================] - 1s 94ms/step - loss: 0.3280 - accuracy: 0.8308 - f1_score: 0.7907 - val_loss: 0.7457 - val_accuracy: 0.6944 - val_f1_score: 0.6523 - lr: 0.0010
# Epoch 18/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2786 - accuracy: 0.8704 - f1_score: 0.8404
# Epoch 18: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 42ms/step - loss: 0.2786 - accuracy: 0.8704 - f1_score: 0.8404 - val_loss: 0.6444 - val_accuracy: 0.6481 - val_f1_score: 0.6478 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.8628 - f1_score: 0.8072
# Epoch 19: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 43ms/step - loss: 0.2710 - accuracy: 0.8628 - f1_score: 0.8072 - val_loss: 0.7257 - val_accuracy: 0.6883 - val_f1_score: 0.5619 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.8857 - f1_score: 0.8583
# Epoch 20: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 41ms/step - loss: 0.2514 - accuracy: 0.8857 - f1_score: 0.8583 - val_loss: 1.0519 - val_accuracy: 0.5988 - val_f1_score: 0.6240 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.8933 - f1_score: 0.8698
# Epoch 21: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 40ms/step - loss: 0.2629 - accuracy: 0.8933 - f1_score: 0.8698 - val_loss: 1.2828 - val_accuracy: 0.6327 - val_f1_score: 0.6295 - lr: 0.0010
# Epoch 22/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.8720 - f1_score: 0.8408
# Epoch 22: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 42ms/step - loss: 0.2631 - accuracy: 0.8720 - f1_score: 0.8408 - val_loss: 0.9917 - val_accuracy: 0.6358 - val_f1_score: 0.5879 - lr: 0.0010
# Epoch 23/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8857 - f1_score: 0.8495
# Epoch 23: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 40ms/step - loss: 0.2637 - accuracy: 0.8857 - f1_score: 0.8495 - val_loss: 0.8785 - val_accuracy: 0.7160 - val_f1_score: 0.5899 - lr: 0.0010
# Epoch 24/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.8872 - f1_score: 0.8652
# Epoch 24: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 41ms/step - loss: 0.2184 - accuracy: 0.8872 - f1_score: 0.8652 - val_loss: 1.6035 - val_accuracy: 0.5617 - val_f1_score: 0.5508 - lr: 0.0010
# Epoch 25/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9375 - f1_score: 0.9222
# Epoch 25: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1421 - accuracy: 0.9375 - f1_score: 0.9222 - val_loss: 1.4320 - val_accuracy: 0.5556 - val_f1_score: 0.5580 - lr: 0.0010
# Epoch 26/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.9284 - f1_score: 0.9044
# Epoch 26: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 41ms/step - loss: 0.1730 - accuracy: 0.9284 - f1_score: 0.9044 - val_loss: 1.9365 - val_accuracy: 0.5340 - val_f1_score: 0.5153 - lr: 0.0010
# Epoch 27/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8979 - f1_score: 0.8650
# Epoch 27: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 43ms/step - loss: 0.2624 - accuracy: 0.8979 - f1_score: 0.8650 - val_loss: 1.2505 - val_accuracy: 0.7469 - val_f1_score: 0.5607 - lr: 0.0010
# Epoch 28/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2375 - accuracy: 0.8841 - f1_score: 0.8441
# Epoch 28: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 0s 43ms/step - loss: 0.2375 - accuracy: 0.8841 - f1_score: 0.8441 - val_loss: 1.6326 - val_accuracy: 0.5864 - val_f1_score: 0.6119 - lr: 0.0010
# Epoch 29/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9451 - f1_score: 0.9249
# Epoch 29: val_f1_score did not improve from 0.65233
# 11/11 [==============================] - 1s 46ms/step - loss: 0.1513 - accuracy: 0.9451 - f1_score: 0.9249 - val_loss: 1.1674 - val_accuracy: 0.7130 - val_f1_score: 0.6482 - lr: 0.0010
# Epoch 30/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9101 - f1_score: 0.8760
# Epoch 30: val_f1_score improved from 0.65233 to 0.66113, saving model to best_model.h5
# 11/11 [==============================] - 1s 84ms/step - loss: 0.1945 - accuracy: 0.9101 - f1_score: 0.8760 - val_loss: 1.5237 - val_accuracy: 0.6636 - val_f1_score: 0.6611 - lr: 0.0010
# Epoch 31/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9101 - f1_score: 0.8842
# Epoch 31: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 0s 41ms/step - loss: 0.2000 - accuracy: 0.9101 - f1_score: 0.8842 - val_loss: 1.2130 - val_accuracy: 0.6605 - val_f1_score: 0.6394 - lr: 0.0010
# Epoch 32/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9451 - f1_score: 0.9177
# Epoch 32: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 1s 43ms/step - loss: 0.1240 - accuracy: 0.9451 - f1_score: 0.9177 - val_loss: 1.4604 - val_accuracy: 0.6636 - val_f1_score: 0.6156 - lr: 0.0010
# Epoch 33/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9253 - f1_score: 0.8877
# Epoch 33: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 0s 41ms/step - loss: 0.1643 - accuracy: 0.9253 - f1_score: 0.8877 - val_loss: 1.4950 - val_accuracy: 0.7006 - val_f1_score: 0.6054 - lr: 0.0010
# Epoch 34/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9253 - f1_score: 0.9069
# Epoch 34: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 0s 46ms/step - loss: 0.1418 - accuracy: 0.9253 - f1_score: 0.9069 - val_loss: 1.3456 - val_accuracy: 0.7222 - val_f1_score: 0.6088 - lr: 0.0010
# Epoch 35/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9497 - f1_score: 0.9252
# Epoch 35: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 1s 51ms/step - loss: 0.1178 - accuracy: 0.9497 - f1_score: 0.9252 - val_loss: 1.6381 - val_accuracy: 0.7006 - val_f1_score: 0.6040 - lr: 0.0010
# Epoch 36/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1742 - accuracy: 0.9328 - f1_score: 0.9103
# Epoch 36: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 1s 51ms/step - loss: 0.1805 - accuracy: 0.9299 - f1_score: 0.8936 - val_loss: 1.8156 - val_accuracy: 0.7284 - val_f1_score: 0.5359 - lr: 0.0010
# Epoch 37/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9451 - f1_score: 0.9155
# Epoch 37: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 1s 53ms/step - loss: 0.1127 - accuracy: 0.9451 - f1_score: 0.9155 - val_loss: 1.6099 - val_accuracy: 0.7191 - val_f1_score: 0.6493 - lr: 0.0010
# Epoch 38/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1961 - accuracy: 0.9312 - f1_score: 0.9093
# Epoch 38: val_f1_score did not improve from 0.66113
# 11/11 [==============================] - 1s 52ms/step - loss: 0.1923 - accuracy: 0.9329 - f1_score: 0.9176 - val_loss: 1.3710 - val_accuracy: 0.7130 - val_f1_score: 0.6490 - lr: 0.0010
# Epoch 39/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9604 - f1_score: 0.9487
# Epoch 39: val_f1_score improved from 0.66113 to 0.66985, saving model to best_model.h5
# 11/11 [==============================] - 1s 67ms/step - loss: 0.0988 - accuracy: 0.9604 - f1_score: 0.9487 - val_loss: 1.2328 - val_accuracy: 0.7346 - val_f1_score: 0.6699 - lr: 0.0010
# Epoch 40/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9771 - f1_score: 0.9603
# Epoch 40: val_f1_score did not improve from 0.66985
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0591 - accuracy: 0.9771 - f1_score: 0.9603 - val_loss: 1.4237 - val_accuracy: 0.7068 - val_f1_score: 0.6098 - lr: 0.0010
# Epoch 41/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9878 - f1_score: 0.9836
# Epoch 41: val_f1_score improved from 0.66985 to 0.67715, saving model to best_model.h5
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0453 - accuracy: 0.9878 - f1_score: 0.9836 - val_loss: 1.3064 - val_accuracy: 0.7222 - val_f1_score: 0.6771 - lr: 0.0010
# Epoch 42/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9848 - f1_score: 0.9790
# Epoch 42: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0368 - accuracy: 0.9848 - f1_score: 0.9790 - val_loss: 1.3953 - val_accuracy: 0.7222 - val_f1_score: 0.6706 - lr: 0.0010
# Epoch 43/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9756 - f1_score: 0.9613
# Epoch 43: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0567 - accuracy: 0.9756 - f1_score: 0.9613 - val_loss: 1.6040 - val_accuracy: 0.7407 - val_f1_score: 0.5565 - lr: 0.0010
# Epoch 44/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0561 - accuracy: 0.9781 - f1_score: 0.9695
# Epoch 44: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0572 - accuracy: 0.9756 - f1_score: 0.9463 - val_loss: 1.9980 - val_accuracy: 0.6636 - val_f1_score: 0.6105 - lr: 0.0010
# Epoch 45/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0646 - accuracy: 0.9756 - f1_score: 0.9465
# Epoch 45: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0646 - accuracy: 0.9756 - f1_score: 0.9465 - val_loss: 1.8042 - val_accuracy: 0.7006 - val_f1_score: 0.6559 - lr: 0.0010
# Epoch 46/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9345 - f1_score: 0.9176
# Epoch 46: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1592 - accuracy: 0.9345 - f1_score: 0.9176 - val_loss: 1.5782 - val_accuracy: 0.6605 - val_f1_score: 0.6102 - lr: 0.0010
# Epoch 47/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1304 - accuracy: 0.9531 - f1_score: 0.9349
# Epoch 47: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1366 - accuracy: 0.9512 - f1_score: 0.9149 - val_loss: 1.4686 - val_accuracy: 0.7160 - val_f1_score: 0.6671 - lr: 0.0010
# Epoch 48/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1175 - accuracy: 0.9500 - f1_score: 0.9313
# Epoch 48: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1226 - accuracy: 0.9466 - f1_score: 0.9199 - val_loss: 1.6094 - val_accuracy: 0.6759 - val_f1_score: 0.6696 - lr: 0.0010
# Epoch 49/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9238 - f1_score: 0.9068
# Epoch 49: val_f1_score did not improve from 0.67715
# 11/11 [==============================] - 0s 46ms/step - loss: 0.1233 - accuracy: 0.9238 - f1_score: 0.9068 - val_loss: 1.5261 - val_accuracy: 0.7099 - val_f1_score: 0.5297 - lr: 0.0010
# Epoch 50/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9710 - f1_score: 0.9613
# Epoch 50: val_f1_score improved from 0.67715 to 0.69726, saving model to best_model.h5
# 11/11 [==============================] - 1s 81ms/step - loss: 0.0823 - accuracy: 0.9710 - f1_score: 0.9613 - val_loss: 1.5762 - val_accuracy: 0.7130 - val_f1_score: 0.6973 - lr: 0.0010
# Epoch 51/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9863 - f1_score: 0.9812
# Epoch 51: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0349 - accuracy: 0.9863 - f1_score: 0.9812 - val_loss: 1.5034 - val_accuracy: 0.6944 - val_f1_score: 0.5388 - lr: 0.0010
# Epoch 52/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0194 - accuracy: 0.9922 - f1_score: 0.9883
# Epoch 52: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0409 - accuracy: 0.9878 - f1_score: 0.9717 - val_loss: 1.5675 - val_accuracy: 0.7006 - val_f1_score: 0.6598 - lr: 0.0010
# Epoch 53/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9619 - f1_score: 0.9520
# Epoch 53: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0813 - accuracy: 0.9619 - f1_score: 0.9520 - val_loss: 1.7291 - val_accuracy: 0.7006 - val_f1_score: 0.5907 - lr: 0.0010
# Epoch 54/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0973 - accuracy: 0.9578 - f1_score: 0.9421
# Epoch 54: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0955 - accuracy: 0.9588 - f1_score: 0.9474 - val_loss: 1.6206 - val_accuracy: 0.7346 - val_f1_score: 0.5603 - lr: 0.0010
# Epoch 55/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0958 - accuracy: 0.9656 - f1_score: 0.9524
# Epoch 55: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0986 - accuracy: 0.9634 - f1_score: 0.9446 - val_loss: 1.6523 - val_accuracy: 0.6944 - val_f1_score: 0.6458 - lr: 0.0010
# Epoch 56/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9771 - f1_score: 0.9698
# Epoch 56: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0771 - accuracy: 0.9771 - f1_score: 0.9698 - val_loss: 1.4341 - val_accuracy: 0.7160 - val_f1_score: 0.5964 - lr: 0.0010
# Epoch 57/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9741 - f1_score: 0.9670
# Epoch 57: val_f1_score did not improve from 0.69726
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0472 - accuracy: 0.9741 - f1_score: 0.9670 - val_loss: 1.6471 - val_accuracy: 0.7130 - val_f1_score: 0.6536 - lr: 0.0010
# Epoch 58/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9954 - f1_score: 0.9941
# Epoch 58: val_f1_score improved from 0.69726 to 0.72392, saving model to best_model.h5
# 11/11 [==============================] - 1s 73ms/step - loss: 0.0274 - accuracy: 0.9954 - f1_score: 0.9941 - val_loss: 1.6607 - val_accuracy: 0.7469 - val_f1_score: 0.7239 - lr: 0.0010
# Epoch 59/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9878 - f1_score: 0.9830
# Epoch 59: val_f1_score improved from 0.72392 to 0.72501, saving model to best_model.h5
# 11/11 [==============================] - 1s 69ms/step - loss: 0.0261 - accuracy: 0.9878 - f1_score: 0.9830 - val_loss: 1.5604 - val_accuracy: 0.7500 - val_f1_score: 0.7250 - lr: 0.0010
# Epoch 60/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9985 - f1_score: 0.9981
# Epoch 60: val_f1_score did not improve from 0.72501
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0070 - accuracy: 0.9985 - f1_score: 0.9981 - val_loss: 1.5631 - val_accuracy: 0.7716 - val_f1_score: 0.7220 - lr: 0.0010
# Epoch 61/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_f1_score improved from 0.72501 to 0.72871, saving model to best_model.h5
# 11/11 [==============================] - 1s 69ms/step - loss: 0.0031 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6105 - val_accuracy: 0.7747 - val_f1_score: 0.7287 - lr: 0.0010
# Epoch 62/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_f1_score improved from 0.72871 to 0.73648, saving model to best_model.h5
# 11/11 [==============================] - 1s 69ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6515 - val_accuracy: 0.7716 - val_f1_score: 0.7365 - lr: 0.0010
# Epoch 63/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.5060e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 8.5060e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6924 - val_accuracy: 0.7716 - val_f1_score: 0.6443 - lr: 0.0010
# Epoch 64/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.5650e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 5.5650e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7273 - val_accuracy: 0.7716 - val_f1_score: 0.6443 - lr: 0.0010
# Epoch 65/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.9133e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 6.9133e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7699 - val_accuracy: 0.7716 - val_f1_score: 0.6463 - lr: 0.0010
# Epoch 66/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9985 - f1_score: 0.9930
# Epoch 66: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0168 - accuracy: 0.9985 - f1_score: 0.9930 - val_loss: 2.3361 - val_accuracy: 0.6728 - val_f1_score: 0.6809 - lr: 0.0010
# Epoch 67/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8857 - f1_score: 0.8206
# Epoch 67: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.4060 - accuracy: 0.8857 - f1_score: 0.8206 - val_loss: 1.7609 - val_accuracy: 0.6821 - val_f1_score: 0.6651 - lr: 0.0010
# Epoch 68/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8552 - f1_score: 0.8108
# Epoch 68: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 0.2924 - accuracy: 0.8552 - f1_score: 0.8108 - val_loss: 2.4857 - val_accuracy: 0.4537 - val_f1_score: 0.4894 - lr: 0.0010
# Epoch 69/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1819 - accuracy: 0.9266 - f1_score: 0.9044
# Epoch 69: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1811 - accuracy: 0.9284 - f1_score: 0.9131 - val_loss: 1.5217 - val_accuracy: 0.6235 - val_f1_score: 0.6443 - lr: 0.0010
# Epoch 70/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.1245 - accuracy: 0.9358 - f1_score: 0.9145
# Epoch 70: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.1144 - accuracy: 0.9436 - f1_score: 0.9301 - val_loss: 1.5607 - val_accuracy: 0.7130 - val_f1_score: 0.5796 - lr: 0.0010
# Epoch 71/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9848 - f1_score: 0.9756
# Epoch 71: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0559 - accuracy: 0.9848 - f1_score: 0.9756 - val_loss: 1.7393 - val_accuracy: 0.6883 - val_f1_score: 0.6745 - lr: 0.0010
# Epoch 72/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9787 - f1_score: 0.9689
# Epoch 72: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0486 - accuracy: 0.9787 - f1_score: 0.9689 - val_loss: 1.8120 - val_accuracy: 0.6852 - val_f1_score: 0.5753 - lr: 0.0010
# Epoch 73/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9466 - f1_score: 0.9277
# Epoch 73: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.1093 - accuracy: 0.9466 - f1_score: 0.9277 - val_loss: 1.8439 - val_accuracy: 0.6759 - val_f1_score: 0.6464 - lr: 0.0010
# Epoch 74/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9741 - f1_score: 0.9645
# Epoch 74: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0826 - accuracy: 0.9741 - f1_score: 0.9645 - val_loss: 1.9214 - val_accuracy: 0.7191 - val_f1_score: 0.6841 - lr: 0.0010
# Epoch 75/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9832 - f1_score: 0.9720
# Epoch 75: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0335 - accuracy: 0.9832 - f1_score: 0.9720 - val_loss: 1.9876 - val_accuracy: 0.7438 - val_f1_score: 0.5877 - lr: 0.0010
# Epoch 76/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9985 - f1_score: 0.9981
# Epoch 76: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0201 - accuracy: 0.9985 - f1_score: 0.9981 - val_loss: 1.9798 - val_accuracy: 0.7315 - val_f1_score: 0.5727 - lr: 0.0010
# Epoch 77/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9939 - f1_score: 0.9916
# Epoch 77: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0152 - accuracy: 0.9939 - f1_score: 0.9916 - val_loss: 1.9771 - val_accuracy: 0.7037 - val_f1_score: 0.5897 - lr: 0.0010
# Epoch 78/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9954 - f1_score: 0.9929
# Epoch 78: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0167 - accuracy: 0.9954 - f1_score: 0.9929 - val_loss: 2.0062 - val_accuracy: 0.7346 - val_f1_score: 0.6004 - lr: 0.0010
# Epoch 79/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9970 - f1_score: 0.9953
# Epoch 79: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0085 - accuracy: 0.9970 - f1_score: 0.9953 - val_loss: 1.8759 - val_accuracy: 0.7407 - val_f1_score: 0.6048 - lr: 0.0010
# Epoch 80/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0151 - accuracy: 0.9954 - f1_score: 0.9498 - val_loss: 1.8945 - val_accuracy: 0.7438 - val_f1_score: 0.5928 - lr: 0.0010
# Epoch 81/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9771 - f1_score: 0.9601
# Epoch 81: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0994 - accuracy: 0.9771 - f1_score: 0.9601 - val_loss: 2.6502 - val_accuracy: 0.5185 - val_f1_score: 0.5822 - lr: 0.0010
# Epoch 82/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9085 - f1_score: 0.8927
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 82: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1849 - accuracy: 0.9085 - f1_score: 0.8927 - val_loss: 1.4975 - val_accuracy: 0.7037 - val_f1_score: 0.5650 - lr: 0.0010
# Epoch 83/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9710 - f1_score: 0.9435
# Epoch 83: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.1435 - accuracy: 0.9710 - f1_score: 0.9435 - val_loss: 1.5540 - val_accuracy: 0.6512 - val_f1_score: 0.6449 - lr: 5.0000e-04
# Epoch 84/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0559 - accuracy: 0.9719 - f1_score: 0.9567
# Epoch 84: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0571 - accuracy: 0.9695 - f1_score: 0.9420 - val_loss: 1.7376 - val_accuracy: 0.6605 - val_f1_score: 0.6695 - lr: 5.0000e-04
# Epoch 85/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9832 - f1_score: 0.9705
# Epoch 85: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0343 - accuracy: 0.9832 - f1_score: 0.9705 - val_loss: 1.6619 - val_accuracy: 0.6914 - val_f1_score: 0.6591 - lr: 5.0000e-04
# Epoch 86/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9954 - f1_score: 0.9934
# Epoch 86: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0180 - accuracy: 0.9954 - f1_score: 0.9934 - val_loss: 1.5809 - val_accuracy: 0.7284 - val_f1_score: 0.6856 - lr: 5.0000e-04
# Epoch 87/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9970 - f1_score: 0.9941
# Epoch 87: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0125 - accuracy: 0.9970 - f1_score: 0.9941 - val_loss: 1.5066 - val_accuracy: 0.7284 - val_f1_score: 0.6907 - lr: 5.0000e-04
# Epoch 88/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0045 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.5208 - val_accuracy: 0.7191 - val_f1_score: 0.6835 - lr: 5.0000e-04
# Epoch 89/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9985 - f1_score: 0.9833
# Epoch 89: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0046 - accuracy: 0.9985 - f1_score: 0.9833 - val_loss: 1.5581 - val_accuracy: 0.7160 - val_f1_score: 0.6855 - lr: 5.0000e-04
# Epoch 90/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.5787 - val_accuracy: 0.7253 - val_f1_score: 0.6820 - lr: 5.0000e-04
# Epoch 91/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0067 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6341 - val_accuracy: 0.7130 - val_f1_score: 0.6864 - lr: 5.0000e-04
# Epoch 92/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0029 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6761 - val_accuracy: 0.7099 - val_f1_score: 0.6889 - lr: 5.0000e-04
# Epoch 93/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6848 - val_accuracy: 0.7068 - val_f1_score: 0.6804 - lr: 5.0000e-04
# Epoch 94/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6854 - val_accuracy: 0.7037 - val_f1_score: 0.6755 - lr: 5.0000e-04
# Epoch 95/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.7243e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 9.7243e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6900 - val_accuracy: 0.7037 - val_f1_score: 0.6755 - lr: 5.0000e-04
# Epoch 96/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.9171e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 9.9171e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6922 - val_accuracy: 0.7130 - val_f1_score: 0.6822 - lr: 5.0000e-04
# Epoch 97/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.6945 - val_accuracy: 0.7130 - val_f1_score: 0.6822 - lr: 5.0000e-04
# Epoch 98/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.7428e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 9.7428e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7035 - val_accuracy: 0.7099 - val_f1_score: 0.6799 - lr: 5.0000e-04
# Epoch 99/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7229 - val_accuracy: 0.7130 - val_f1_score: 0.6822 - lr: 5.0000e-04
# Epoch 100/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.0857e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 46ms/step - loss: 7.0857e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7343 - val_accuracy: 0.7130 - val_f1_score: 0.6822 - lr: 5.0000e-04
# Epoch 101/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.7274e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 5.7274e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7400 - val_accuracy: 0.7068 - val_f1_score: 0.6744 - lr: 5.0000e-04
# Epoch 102/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.2533e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 102: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 5.2533e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7482 - val_accuracy: 0.7068 - val_f1_score: 0.6744 - lr: 5.0000e-04
# Epoch 103/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.4657e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 46ms/step - loss: 4.4657e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7551 - val_accuracy: 0.7037 - val_f1_score: 0.6711 - lr: 2.5000e-04
# Epoch 104/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.9919e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 4.9919e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7616 - val_accuracy: 0.7068 - val_f1_score: 0.6733 - lr: 2.5000e-04
# Epoch 105/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3079e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 5.3079e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7681 - val_accuracy: 0.7099 - val_f1_score: 0.6754 - lr: 2.5000e-04
# Epoch 106/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.0121e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.0121e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7737 - val_accuracy: 0.7099 - val_f1_score: 0.6754 - lr: 2.5000e-04
# Epoch 107/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 6.0548e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 6.2822e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7796 - val_accuracy: 0.7099 - val_f1_score: 0.6754 - lr: 2.5000e-04
# Epoch 108/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.9656e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.9656e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7867 - val_accuracy: 0.7130 - val_f1_score: 0.6788 - lr: 2.5000e-04
# Epoch 109/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.5597e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 39ms/step - loss: 3.5597e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.7955 - val_accuracy: 0.7191 - val_f1_score: 0.6895 - lr: 2.5000e-04
# Epoch 110/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.9107e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 9.9107e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8121 - val_accuracy: 0.7191 - val_f1_score: 0.6895 - lr: 2.5000e-04
# Epoch 111/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.6353e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.6353e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8196 - val_accuracy: 0.7191 - val_f1_score: 0.6895 - lr: 2.5000e-04
# Epoch 112/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 4.2636e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 112: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 4.2274e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8251 - val_accuracy: 0.7191 - val_f1_score: 0.6895 - lr: 2.5000e-04
# Epoch 113/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.3733e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.3733e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8313 - val_accuracy: 0.7191 - val_f1_score: 0.6895 - lr: 2.5000e-04
# Epoch 114/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.3270e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 114: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 3.3270e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8335 - val_accuracy: 0.7160 - val_f1_score: 0.6861 - lr: 2.5000e-04
# Epoch 115/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.5108e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 115: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 4.5108e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8356 - val_accuracy: 0.7130 - val_f1_score: 0.6804 - lr: 2.5000e-04
# Epoch 116/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.5343e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 46ms/step - loss: 5.5343e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8434 - val_accuracy: 0.7160 - val_f1_score: 0.6861 - lr: 2.5000e-04
# Epoch 117/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.1633e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 117: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 5.1633e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8801 - val_accuracy: 0.7130 - val_f1_score: 0.6823 - lr: 2.5000e-04
# Epoch 118/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9970 - f1_score: 0.9515
# Epoch 118: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0064 - accuracy: 0.9970 - f1_score: 0.9515 - val_loss: 1.8853 - val_accuracy: 0.7068 - val_f1_score: 0.6784 - lr: 2.5000e-04
# Epoch 119/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9985 - f1_score: 0.9980
# Epoch 119: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0055 - accuracy: 0.9985 - f1_score: 0.9980 - val_loss: 1.8580 - val_accuracy: 0.6914 - val_f1_score: 0.6586 - lr: 2.5000e-04
# Epoch 120/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0129 - accuracy: 0.9969 - f1_score: 0.9962
# Epoch 120: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0126 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 1.8910 - val_accuracy: 0.6821 - val_f1_score: 0.6450 - lr: 2.5000e-04
# Epoch 121/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 121: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9079 - val_accuracy: 0.6914 - val_f1_score: 0.6591 - lr: 2.5000e-04
# Epoch 122/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9970 - f1_score: 0.9909
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 122: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0072 - accuracy: 0.9970 - f1_score: 0.9909 - val_loss: 1.8868 - val_accuracy: 0.6883 - val_f1_score: 0.6561 - lr: 2.5000e-04
# Epoch 123/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0025 - accuracy: 0.9984 - f1_score: 0.9975
# Epoch 123: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0024 - accuracy: 0.9985 - f1_score: 0.9977 - val_loss: 1.9660 - val_accuracy: 0.7006 - val_f1_score: 0.6815 - lr: 1.2500e-04
# Epoch 124/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9985 - f1_score: 0.9977
# Epoch 124: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0031 - accuracy: 0.9985 - f1_score: 0.9977 - val_loss: 1.9779 - val_accuracy: 0.7068 - val_f1_score: 0.6805 - lr: 1.2500e-04
# Epoch 125/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9970 - f1_score: 0.9953
# Epoch 125: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0030 - accuracy: 0.9970 - f1_score: 0.9953 - val_loss: 1.9622 - val_accuracy: 0.7068 - val_f1_score: 0.6805 - lr: 1.2500e-04
# Epoch 126/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9970 - f1_score: 0.9953
# Epoch 126: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0036 - accuracy: 0.9970 - f1_score: 0.9953 - val_loss: 1.9000 - val_accuracy: 0.7068 - val_f1_score: 0.6749 - lr: 1.2500e-04
# Epoch 127/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.6497e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 127: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 8.6497e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8879 - val_accuracy: 0.7191 - val_f1_score: 0.6837 - lr: 1.2500e-04
# Epoch 128/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 5.4475e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 128: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 49ms/step - loss: 6.1362e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8876 - val_accuracy: 0.7130 - val_f1_score: 0.6794 - lr: 1.2500e-04
# Epoch 129/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.2105e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 129: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 5.2105e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8879 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 130/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 130: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8927 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 131/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.7728e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 131: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 40ms/step - loss: 3.7728e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9009 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 132/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.2603e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 132: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 45ms/step - loss: 4.2603e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9047 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 133/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.0886e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 133: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.0886e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9070 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 134/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.0763e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 134: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 8.0763e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9084 - val_accuracy: 0.7068 - val_f1_score: 0.6730 - lr: 1.2500e-04
# Epoch 135/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.3488e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 135: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 4.3488e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9125 - val_accuracy: 0.7068 - val_f1_score: 0.6730 - lr: 1.2500e-04
# Epoch 136/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.0039e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 136: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 44ms/step - loss: 7.0039e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9161 - val_accuracy: 0.7068 - val_f1_score: 0.6730 - lr: 1.2500e-04
# Epoch 137/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.7567e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 137: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 3.7567e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9113 - val_accuracy: 0.7068 - val_f1_score: 0.6730 - lr: 1.2500e-04
# Epoch 138/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.9070e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 138: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 3.9070e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9101 - val_accuracy: 0.7099 - val_f1_score: 0.6753 - lr: 1.2500e-04
# Epoch 139/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.3665e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 139: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 46ms/step - loss: 6.3665e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9117 - val_accuracy: 0.7130 - val_f1_score: 0.6793 - lr: 1.2500e-04
# Epoch 140/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.0847e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 140: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 4.0847e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9192 - val_accuracy: 0.7068 - val_f1_score: 0.6632 - lr: 1.2500e-04
# Epoch 141/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9985 - f1_score: 0.9833
# Epoch 141: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0028 - accuracy: 0.9985 - f1_score: 0.9833 - val_loss: 1.9183 - val_accuracy: 0.7068 - val_f1_score: 0.6632 - lr: 1.2500e-04
# Epoch 142/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 142: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 142: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8885 - val_accuracy: 0.7407 - val_f1_score: 0.6918 - lr: 1.2500e-04
# Epoch 143/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9985 - f1_score: 0.9531
# Epoch 143: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0031 - accuracy: 0.9985 - f1_score: 0.9531 - val_loss: 1.8952 - val_accuracy: 0.7315 - val_f1_score: 0.6836 - lr: 6.2500e-05
# Epoch 144/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.8109e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 144: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 5.8109e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9025 - val_accuracy: 0.7191 - val_f1_score: 0.6732 - lr: 6.2500e-05
# Epoch 145/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 145: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9093 - val_accuracy: 0.7253 - val_f1_score: 0.6796 - lr: 6.2500e-05
# Epoch 146/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.2850e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 146: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 48ms/step - loss: 9.2850e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9097 - val_accuracy: 0.7284 - val_f1_score: 0.6819 - lr: 6.2500e-05
# Epoch 147/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 9.7158e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 147: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9137 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 148/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 4.8936e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 148: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 73ms/step - loss: 5.3473e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9173 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 149/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 8.7875e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 149: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 59ms/step - loss: 8.6913e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9222 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 150/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.0290e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 150: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 48ms/step - loss: 5.0290e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9247 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 151/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.3675e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 151: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 48ms/step - loss: 4.3675e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9254 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 152/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3449e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 152: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 5.3449e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9287 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 153/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 3.6810e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 153: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 52ms/step - loss: 3.7856e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9280 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 154/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.6226e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 154: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 48ms/step - loss: 4.6226e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9279 - val_accuracy: 0.7253 - val_f1_score: 0.6800 - lr: 6.2500e-05
# Epoch 155/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.3493e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 155: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 48ms/step - loss: 7.3493e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9292 - val_accuracy: 0.7222 - val_f1_score: 0.6779 - lr: 6.2500e-05
# Epoch 156/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.5954e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 156: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 47ms/step - loss: 6.5954e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9314 - val_accuracy: 0.7191 - val_f1_score: 0.6737 - lr: 6.2500e-05
# Epoch 157/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.2186e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 157: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 42ms/step - loss: 8.2186e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9299 - val_accuracy: 0.7191 - val_f1_score: 0.6737 - lr: 6.2500e-05
# Epoch 158/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.9841e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 158: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 44ms/step - loss: 3.9841e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9308 - val_accuracy: 0.7160 - val_f1_score: 0.6716 - lr: 6.2500e-05
# Epoch 159/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.7320e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 159: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 41ms/step - loss: 5.7320e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9332 - val_accuracy: 0.7160 - val_f1_score: 0.6716 - lr: 6.2500e-05
# Epoch 160/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.8912e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 160: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 43ms/step - loss: 3.8912e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9363 - val_accuracy: 0.7191 - val_f1_score: 0.6757 - lr: 6.2500e-05
# Epoch 161/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 5.6762e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 161: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 1s 47ms/step - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9423 - val_accuracy: 0.7191 - val_f1_score: 0.6737 - lr: 6.2500e-05
# Epoch 162/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9985 - f1_score: 0.9943    Restoring model weights from the end of the best epoch: 62.
#
# Epoch 162: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 162: val_f1_score did not improve from 0.73648
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0033 - accuracy: 0.9985 - f1_score: 0.9943 - val_loss: 1.9790 - val_accuracy: 0.7191 - val_f1_score: 0.6739 - lr: 6.2500e-05
# Epoch 162: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
check_model=resnet50
check_model.load_weights('best_model.h5')
check_model.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 6ms/step
# 0.7716049382716049

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 7ms/step
# 0.7716049382716049

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7716049382716049
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.57      0.51      0.54        85
#            0       0.83      0.87      0.85       239
#
#     accuracy                           0.77       324
#    macro avg       0.70      0.69      0.69       324
# weighted avg       0.76      0.77      0.77       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 250 chiếm khoảng 77.1604938271605% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 43 chiếm khoảng 50.588235294117645% so với thực tế
