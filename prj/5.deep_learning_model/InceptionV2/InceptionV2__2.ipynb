# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
# -*- coding: utf-8 -*-
"""Inception-ResNet V2 model for Keras.

Model naming and structure follows TF-slim implementation (which has some additional
layers and different number of filters from the original arXiv paper):
https://github.com/tensorflow/models/blob/master/slim/nets/inception_resnet_v2.py

Pre-trained ImageNet weights are also converted from TF-slim, which can be found in:
https://github.com/tensorflow/models/tree/master/slim#pre-trained-models

# Reference
- [Inception-v4, Inception-ResNet and the Impact of
   Residual Connections on Learning](https://arxiv.org/abs/1602.07261)

"""
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np
from keras.layers import Input, Conv1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D,AveragePooling1D,Concatenate, Dense
from keras.models import Model
import keras.backend as K




def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.

    This function applies the "Inception" preprocessing which converts
    the RGB values from [0, 255] to [-1, 1]. Note that this preprocessing
    function is different from `imagenet_utils.preprocess_input()`.

    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].

    # Returns
        Preprocessed array.
    """
    x /= 255.
    x -= 0.5
    x *= 2.
    return x


def conv1d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              name=None):
    bn_axis=1
    x = Conv1D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               name=name)(x)
    bn_name = None if name is None else name + '_bn'
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = None if name is None else name + '_ac'
        x = Activation(activation, name=ac_name)(x)
    return x

from keras.layers import Lambda, ZeroPadding1D

def adjust_padding(branches):
    max_length = max(K.int_shape(branch)[1] for branch in branches)
    adjusted_branches = []
    for branch in branches:
        branch_length = K.int_shape(branch)[1]
        if branch_length < max_length:
            padding = max_length - branch_length
            branch = ZeroPadding1D(padding=(0, padding))(branch)
        adjusted_branches.append(branch)
    return adjusted_branches

def check_and_adjust_branches(branches, channel_axis):
    max_length = max([K.int_shape(branch)[channel_axis] for branch in branches])
    adjusted_branches = []
    for branch in branches:
        branch_length = K.int_shape(branch)[channel_axis]
        if branch_length != max_length:
            # Adjust the size of the branch
            # This can be done using ZeroPadding1D, Cropping1D, or other methods
            # For example, using ZeroPadding1D:
            padding_size = (max_length - branch_length)
            padding = (padding_size // 2, padding_size - padding_size // 2)
            branch = ZeroPadding1D(padding=padding)(branch)
        adjusted_branches.append(branch)
    return adjusted_branches

def adjust_branches_for_concat(branches):
    adjusted_branches = []
    for branch in branches:
        if K.int_shape(branch)[2] != 96:
            # Thêm đệm để kích thước chiều kênh tăng lên 96
            padding_size = 96 - K.int_shape(branch)[2]
            left_pad = padding_size // 2
            right_pad = padding_size - left_pad
            branch = ZeroPadding1D(padding=(left_pad, right_pad))(branch)
        adjusted_branches.append(branch)
    return adjusted_branches


def inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
 
    if block_type == 'block35':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 32, 1)
        branch_1 = conv1d_bn(x, 32, 1)
        branch_1 = conv1d_bn(branch_1, 32, 3)
        branch_2 = conv1d_bn(x, 32, 1)
        branch_2 = conv1d_bn(branch_2, 48, 3)
        branch_2 = conv1d_bn(branch_2, 64, 3)
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'block17':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(x, 128, 1)
        branch_1 = conv1d_bn(branch_1, 160, 1)
        branch_1 = conv1d_bn(branch_1, 192, 7)
        branches = [branch_0, branch_1]
    elif block_type == 'block8':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(branch_1, 224, 1)
        branch_1 = conv1d_bn(branch_1, 256, 3)
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: ' + str(block_type))

    block_name = block_type + '_' + str(block_idx)
    channel_axis = -1
    branches = check_and_adjust_branches(branches, channel_axis=1)
    mixed = Concatenate(axis=channel_axis, name=block_name + '_mixed')(branches)
    up = conv1d_bn(mixed,
                   K.int_shape(x)[channel_axis],
                   1,
                   activation=None,
                   name=block_name + '_conv')

    x = Lambda(lambda inputs, scale: inputs[0] + inputs[1] * scale,
               output_shape=K.int_shape(x)[1:],
               arguments={'scale': scale},
               name=block_name)([x, up])
    if activation is not None:
        x = Activation(activation, name=block_name + '_ac')(x)
    return x

# %%
def InceptionResNetV2():

    # Determine proper input shape
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    # Stem block: 35 x 35 x 192
    x = conv1d_bn(x_input, 16, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 16, 3, padding='valid')
    x = conv1d_bn(x, 32, 3)
    x = MaxPooling1D(3, strides=2)(x)
    x = conv1d_bn(x, 80, 1, padding='valid')
    x = conv1d_bn(x, 192, 3, padding='valid')
    x = MaxPooling1D(3, strides=2)(x)

    # Mixed 5b (Inception-A block): 35 x 35 x 160
    branch_0 = conv1d_bn(x, 64, 1)
    branch_1 = conv1d_bn(x, 48, 1)
    branch_1 = conv1d_bn(branch_1, 32, 5)
    branch_2 = conv1d_bn(x, 32, 1)
    branch_2 = conv1d_bn(branch_2, 64, 3)
    branch_2 = conv1d_bn(branch_2, 64, 3)
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1)
    target_shape = (None, 2, 64)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    channel_axis = -1
    #branches = adjust_branches_for_concat(branches)
    x = Concatenate(axis=-1, name='mixed_5b')(branches)

    # 10x block35 (Inception-ResNet-A block): 35 x 35 x 160
    for block_idx in range(1, 11):
        x = inception_resnet_block(x,
                                   scale=0.17,
                                   block_type='block35',
                                   block_idx=block_idx)

    # Mixed 6a (Reduction-A block): 17 x 17 x 1088
    branch_0 = conv1d_bn(x, 128, 3, strides=2, padding='same')
    branch_1 = conv1d_bn(x, 96, 1)
    branch_1 = conv1d_bn(branch_1, 96, 3)
    branch_1 = conv1d_bn(branch_1, 128, 3, strides=2, padding='same')
    branch_pool = MaxPooling1D(3, strides=2, padding='same')(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_6a')(branches)

    # 20x block17 (Inception-ResNet-B block): 17 x 17 x 1088
    for block_idx in range(1, 21):
        x = inception_resnet_block(x,
                                   scale=0.1,
                                   block_type='block17',
                                   block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    branch_0 = conv1d_bn(x, 96, 1)
    branch_0 = conv1d_bn(branch_0, 128, 3, strides=2, padding='same')
    branch_1 = conv1d_bn(x, 96, 1)
    branch_1 = conv1d_bn(branch_1, 288, 3, strides=2, padding='same')
    branch_2 = conv1d_bn(x, 96, 1)
    branch_2 = conv1d_bn(branch_2, 288, 3)
    branch_2 = conv1d_bn(branch_2, 128, 3, strides=2, padding='same')
    branch_pool = MaxPooling1D(3, strides=2, padding='same')(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_7a')(branches)

    # 10x block8 (Inception-ResNet-C block): 8 x 8 x 2080
    for block_idx in range(1, 10):
        x = inception_resnet_block(x,
                                   scale=0.2,
                                   block_type='block8',
                                   block_idx=block_idx)
    x = inception_resnet_block(x,
                               scale=1.,
                               activation=None,
                               block_type='block8',
                               block_idx=10)

    # Final convolution block: 8 x 8 x 1536
    x = conv1d_bn(x, 1536, 1, name='conv_7b')
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

 

    # Create model
    model = Model(x_input, x, name='inception_resnet_v2')

    

    return model


model = InceptionResNetV2()
lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 16)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 16)               784       ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 16)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 16)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 18, 32)               1568      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 18, 32)               54        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 18, 32)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 8, 32)                0         ['activation_2[0][0]']
#  D)
#
#  conv1d_3 (Conv1D)           (None, 8, 80)                2640      ['max_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 8, 80)                24        ['conv1d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 8, 80)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 6, 192)               46272     ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 6, 192)               18        ['conv1d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 6, 192)               0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 192)               0         ['activation_4[0][0]']
#  g1D)
#
#  conv1d_8 (Conv1D)           (None, 2, 32)                6176      ['max_pooling1d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 2, 32)                6         ['conv1d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 2, 32)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv1d_6 (Conv1D)           (None, 2, 48)                9264      ['max_pooling1d_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 2, 64)                6208      ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 2, 48)                6         ['conv1d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 2, 64)                6         ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 2, 48)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 2, 64)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 2, 192)               0         ['max_pooling1d_1[0][0]']
#  Pooling1D)
#
#  conv1d_5 (Conv1D)           (None, 2, 64)                12352     ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 2, 32)                7712      ['activation_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 2, 64)                12352     ['activation_9[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 2, 32)                6176      ['average_pooling1d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 2, 64)                6         ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 2, 32)                6         ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 2, 64)                6         ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 2, 32)                6         ['conv1d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 2, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 2, 32)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 2, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 2, 32)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 2, 192)               0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 32)                6         ['conv1d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 2, 32)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv1d_13 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 2, 48)                4656      ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 2, 32)                6         ['conv1d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 2, 48)                6         ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 2, 32)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 2, 48)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv1d_12 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 2, 32)                3104      ['activation_13[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 2, 64)                9280      ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 2, 32)                6         ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 2, 32)                6         ['conv1d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 2, 64)                6         ['conv1d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 2, 32)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 2, 32)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 2, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 2, 128)               0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv1D)     (None, 2, 192)               24768     ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_1_conv[0][0]']
#  rmalization)
#
#  block35_1 (Lambda)          (None, 2, 192)               0         ['mixed_5b[0][0]',
#                                                                      'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)   (None, 2, 192)               0         ['block35_1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 2, 32)                6         ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 2, 32)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv1d_19 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 2, 48)                4656      ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 2, 32)                6         ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 2, 48)                6         ['conv1d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 2, 32)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 2, 48)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 2, 32)                3104      ['activation_19[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 2, 64)                9280      ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 2, 32)                6         ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 2, 32)                6         ['conv1d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 2, 64)                6         ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 2, 32)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 2, 32)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 2, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 2, 128)               0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv1D)     (None, 2, 192)               24768     ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_2_conv[0][0]']
#  rmalization)
#
#  block35_2 (Lambda)          (None, 2, 192)               0         ['block35_1_ac[0][0]',
#                                                                      'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)   (None, 2, 192)               0         ['block35_2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 2, 32)                6         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 2, 32)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv1d_25 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  conv1d_28 (Conv1D)          (None, 2, 48)                4656      ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 2, 32)                6         ['conv1d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 2, 48)                6         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 2, 32)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 2, 48)                0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  conv1d_26 (Conv1D)          (None, 2, 32)                3104      ['activation_25[0][0]']
#
#  conv1d_29 (Conv1D)          (None, 2, 64)                9280      ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 2, 32)                6         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 2, 32)                6         ['conv1d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 2, 64)                6         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 2, 32)                0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 2, 32)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 2, 64)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 2, 128)               0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv1D)     (None, 2, 192)               24768     ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_3_conv[0][0]']
#  rmalization)
#
#  block35_3 (Lambda)          (None, 2, 192)               0         ['block35_2_ac[0][0]',
#                                                                      'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)   (None, 2, 192)               0         ['block35_3[0][0]']
#
#  conv1d_33 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 2, 32)                6         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 2, 32)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_31 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 2, 48)                4656      ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 2, 32)                6         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 2, 48)                6         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 2, 32)                0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 2, 48)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 2, 32)                3104      ['activation_31[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 2, 64)                9280      ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 2, 32)                6         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 2, 32)                6         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 2, 64)                6         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 2, 32)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 2, 32)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 2, 64)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 2, 128)               0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv1D)     (None, 2, 192)               24768     ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_4_conv[0][0]']
#  rmalization)
#
#  block35_4 (Lambda)          (None, 2, 192)               0         ['block35_3_ac[0][0]',
#                                                                      'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)   (None, 2, 192)               0         ['block35_4[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 2, 32)                6         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 2, 32)                0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv1d_37 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  conv1d_40 (Conv1D)          (None, 2, 48)                4656      ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 2, 32)                6         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 2, 48)                6         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 2, 32)                0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 2, 48)                0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv1d_36 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  conv1d_38 (Conv1D)          (None, 2, 32)                3104      ['activation_37[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 2, 64)                9280      ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 2, 32)                6         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 2, 32)                6         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 2, 64)                6         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 2, 32)                0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 2, 32)                0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 2, 64)                0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 2, 128)               0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv1D)     (None, 2, 192)               24768     ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_5_conv[0][0]']
#  rmalization)
#
#  block35_5 (Lambda)          (None, 2, 192)               0         ['block35_4_ac[0][0]',
#                                                                      'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)   (None, 2, 192)               0         ['block35_5[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 2, 32)                6         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 2, 32)                0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv1d_43 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  conv1d_46 (Conv1D)          (None, 2, 48)                4656      ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 2, 32)                6         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 2, 48)                6         ['conv1d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 2, 32)                0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 2, 48)                0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv1d_42 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 2, 32)                3104      ['activation_43[0][0]']
#
#  conv1d_47 (Conv1D)          (None, 2, 64)                9280      ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 2, 32)                6         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 2, 32)                6         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 2, 64)                6         ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 2, 32)                0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 2, 32)                0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 2, 64)                0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 2, 128)               0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv1D)     (None, 2, 192)               24768     ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_6_conv[0][0]']
#  rmalization)
#
#  block35_6 (Lambda)          (None, 2, 192)               0         ['block35_5_ac[0][0]',
#                                                                      'block35_6_conv_bn[0][0]']
# ...
#  block8_7_mixed (Concatenat  (None, 1, 448)               0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv1D)      (None, 1, 992)               445408    ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_7_conv[0][0]']
#  malization)
#
#  block8_7 (Lambda)           (None, 1, 992)               0         ['block8_6_ac[0][0]',
#                                                                      'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)    (None, 1, 992)               0         ['block8_7[0][0]']
#
#  conv1d_192 (Conv1D)         (None, 1, 192)               190656    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 1, 192)               3         ['conv1d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 1, 192)               0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv1d_193 (Conv1D)         (None, 1, 224)               43232     ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 1, 224)               3         ['conv1d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 1, 224)               0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv1d_191 (Conv1D)         (None, 1, 192)               190656    ['block8_7_ac[0][0]']
#
#  conv1d_194 (Conv1D)         (None, 1, 256)               172288    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 1, 192)               3         ['conv1d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 1, 256)               3         ['conv1d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 1, 192)               0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 1, 256)               0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 1, 448)               0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv1D)      (None, 1, 992)               445408    ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_8_conv[0][0]']
#  malization)
#
#  block8_8 (Lambda)           (None, 1, 992)               0         ['block8_7_ac[0][0]',
#                                                                      'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)    (None, 1, 992)               0         ['block8_8[0][0]']
#
#  conv1d_196 (Conv1D)         (None, 1, 192)               190656    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 1, 192)               3         ['conv1d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 1, 192)               0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv1d_197 (Conv1D)         (None, 1, 224)               43232     ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 1, 224)               3         ['conv1d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 1, 224)               0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv1d_195 (Conv1D)         (None, 1, 192)               190656    ['block8_8_ac[0][0]']
#
#  conv1d_198 (Conv1D)         (None, 1, 256)               172288    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 1, 192)               3         ['conv1d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 1, 256)               3         ['conv1d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 1, 192)               0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 1, 256)               0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 1, 448)               0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv1D)      (None, 1, 992)               445408    ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_9_conv[0][0]']
#  malization)
#
#  block8_9 (Lambda)           (None, 1, 992)               0         ['block8_8_ac[0][0]',
#                                                                      'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)    (None, 1, 992)               0         ['block8_9[0][0]']
#
#  conv1d_200 (Conv1D)         (None, 1, 192)               190656    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 1, 192)               3         ['conv1d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 1, 192)               0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv1d_201 (Conv1D)         (None, 1, 224)               43232     ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 1, 224)               3         ['conv1d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 1, 224)               0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv1d_199 (Conv1D)         (None, 1, 192)               190656    ['block8_9_ac[0][0]']
#
#  conv1d_202 (Conv1D)         (None, 1, 256)               172288    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 1, 192)               3         ['conv1d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 1, 256)               3         ['conv1d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 1, 192)               0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 1, 256)               0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 1, 448)               0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv1D)     (None, 1, 992)               445408    ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNo  (None, 1, 992)               3         ['block8_10_conv[0][0]']
#  rmalization)
#
#  block8_10 (Lambda)          (None, 1, 992)               0         ['block8_9_ac[0][0]',
#                                                                      'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)            (None, 1, 1536)              1525248   ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormaliza  (None, 1, 1536)              3         ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 1, 1536)              0         ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    3074      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24308062 (92.73 MB)
# Trainable params: 24307286 (92.72 MB)
# Non-trainable params: 776 (3.03 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.7850 - accuracy: 0.6174 - f1_score: 0.3719
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 11/11 [==============================] - 338s 2s/step - loss: 0.7850 - accuracy: 0.6174 - f1_score: 0.3719 - val_loss: 0.9187 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.7378 - f1_score: 0.4412
# Epoch 2: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 527ms/step - loss: 0.0464 - accuracy: 0.7378 - f1_score: 0.4412 - val_loss: 0.4047 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.7637 - f1_score: 0.4324
# Epoch 3: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 514ms/step - loss: 0.0402 - accuracy: 0.7637 - f1_score: 0.4324 - val_loss: 0.0385 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.7637 - f1_score: 0.4322
# Epoch 4: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 512ms/step - loss: 0.0388 - accuracy: 0.7637 - f1_score: 0.4322 - val_loss: 0.0372 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 5/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.7637 - f1_score: 0.4295
# Epoch 5: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 518ms/step - loss: 0.0328 - accuracy: 0.7637 - f1_score: 0.4295 - val_loss: 0.0368 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.7637 - f1_score: 0.4290
# Epoch 6: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 512ms/step - loss: 0.0327 - accuracy: 0.7637 - f1_score: 0.4290 - val_loss: 0.0372 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.7637 - f1_score: 0.4349
# Epoch 7: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 495ms/step - loss: 0.0326 - accuracy: 0.7637 - f1_score: 0.4349 - val_loss: 0.0373 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.7637 - f1_score: 0.4344
# Epoch 8: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0323 - accuracy: 0.7637 - f1_score: 0.4344 - val_loss: 0.0368 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 9/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.7637 - f1_score: 0.4382
# Epoch 9: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0307 - accuracy: 0.7637 - f1_score: 0.4382 - val_loss: 0.0368 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.7652 - f1_score: 0.4541
# Epoch 10: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 6s 517ms/step - loss: 0.0303 - accuracy: 0.7652 - f1_score: 0.4541 - val_loss: 0.0371 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.7774 - f1_score: 0.5194
# Epoch 11: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 500ms/step - loss: 0.0292 - accuracy: 0.7774 - f1_score: 0.5194 - val_loss: 0.0370 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 12/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.7896 - f1_score: 0.5922
# Epoch 12: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0286 - accuracy: 0.7896 - f1_score: 0.5922 - val_loss: 0.0367 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 13/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.7927 - f1_score: 0.6125
# Epoch 13: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0279 - accuracy: 0.7927 - f1_score: 0.6125 - val_loss: 0.0368 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 14/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.8201 - f1_score: 0.7061
# Epoch 14: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 4s 364ms/step - loss: 0.0263 - accuracy: 0.8201 - f1_score: 0.7061 - val_loss: 0.0376 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 15/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.8034 - f1_score: 0.5889
# Epoch 15: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 4s 362ms/step - loss: 0.0279 - accuracy: 0.8034 - f1_score: 0.5889 - val_loss: 0.0375 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 16/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.7668 - f1_score: 0.5178
# Epoch 16: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0321 - accuracy: 0.7668 - f1_score: 0.5178 - val_loss: 0.0368 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.8049 - f1_score: 0.5911
# Epoch 17: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 4s 369ms/step - loss: 0.0294 - accuracy: 0.8049 - f1_score: 0.5911 - val_loss: 0.0493 - val_accuracy: 0.7222 - val_f1_score: 0.4204 - lr: 0.0010
# Epoch 18/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.7957 - f1_score: 0.6547
# Epoch 18: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 4s 375ms/step - loss: 0.0284 - accuracy: 0.7957 - f1_score: 0.6547 - val_loss: 0.0485 - val_accuracy: 0.7346 - val_f1_score: 0.4238 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.8110 - f1_score: 0.6102
# Epoch 19: val_f1_score improved from 0.42467 to 0.46010, saving model to best_model.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.0263 - accuracy: 0.8110 - f1_score: 0.6102 - val_loss: 0.0507 - val_accuracy: 0.7037 - val_f1_score: 0.4601 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.8110 - f1_score: 0.7199
# Epoch 20: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 370ms/step - loss: 0.0257 - accuracy: 0.8110 - f1_score: 0.7199 - val_loss: 0.0473 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.8491 - f1_score: 0.7405
# Epoch 21: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 376ms/step - loss: 0.0210 - accuracy: 0.8491 - f1_score: 0.7405 - val_loss: 0.0393 - val_accuracy: 0.6698 - val_f1_score: 0.4441 - lr: 0.0010
# Epoch 22/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.8735 - f1_score: 0.8102
# Epoch 22: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 380ms/step - loss: 0.0183 - accuracy: 0.8735 - f1_score: 0.8102 - val_loss: 0.0363 - val_accuracy: 0.7346 - val_f1_score: 0.4347 - lr: 0.0010
# Epoch 23/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9162 - f1_score: 0.8695
# Epoch 23: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 376ms/step - loss: 0.0136 - accuracy: 0.9162 - f1_score: 0.8695 - val_loss: 0.0387 - val_accuracy: 0.6944 - val_f1_score: 0.4507 - lr: 0.0010
# Epoch 24/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.8491 - f1_score: 0.7396
# Epoch 24: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 372ms/step - loss: 0.0227 - accuracy: 0.8491 - f1_score: 0.7396 - val_loss: 0.0362 - val_accuracy: 0.7377 - val_f1_score: 0.4511 - lr: 0.0010
# Epoch 25/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.8521 - f1_score: 0.7792
# Epoch 25: val_f1_score did not improve from 0.46010
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0218 - accuracy: 0.8521 - f1_score: 0.7792 - val_loss: 0.0384 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 26/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.8857 - f1_score: 0.8311
# Epoch 26: val_f1_score improved from 0.46010 to 0.56660, saving model to best_model.h5
# 11/11 [==============================] - 6s 531ms/step - loss: 0.0164 - accuracy: 0.8857 - f1_score: 0.8311 - val_loss: 0.0404 - val_accuracy: 0.6636 - val_f1_score: 0.5666 - lr: 0.0010
# Epoch 27/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9162 - f1_score: 0.8727
# Epoch 27: val_f1_score did not improve from 0.56660
# 11/11 [==============================] - 4s 380ms/step - loss: 0.0137 - accuracy: 0.9162 - f1_score: 0.8727 - val_loss: 0.0636 - val_accuracy: 0.4969 - val_f1_score: 0.5549 - lr: 0.0010
# Epoch 28/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.8780 - f1_score: 0.8443
# Epoch 28: val_f1_score did not improve from 0.56660
# 11/11 [==============================] - 4s 380ms/step - loss: 0.0179 - accuracy: 0.8780 - f1_score: 0.8443 - val_loss: 0.1291 - val_accuracy: 0.7222 - val_f1_score: 0.4274 - lr: 0.0010
# Epoch 29/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9131 - f1_score: 0.8757
# Epoch 29: val_f1_score did not improve from 0.56660
# 11/11 [==============================] - 5s 432ms/step - loss: 0.0128 - accuracy: 0.9131 - f1_score: 0.8757 - val_loss: 0.1596 - val_accuracy: 0.7099 - val_f1_score: 0.4753 - lr: 0.0010
# Epoch 30/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9314 - f1_score: 0.9008
# Epoch 30: val_f1_score improved from 0.56660 to 0.57752, saving model to best_model.h5
# 11/11 [==============================] - 6s 583ms/step - loss: 0.0102 - accuracy: 0.9314 - f1_score: 0.9008 - val_loss: 0.0779 - val_accuracy: 0.5278 - val_f1_score: 0.5775 - lr: 0.0010
# Epoch 31/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9558 - f1_score: 0.9440
# Epoch 31: val_f1_score improved from 0.57752 to 0.59271, saving model to best_model.h5
# 11/11 [==============================] - 6s 601ms/step - loss: 0.0080 - accuracy: 0.9558 - f1_score: 0.9440 - val_loss: 0.1520 - val_accuracy: 0.7099 - val_f1_score: 0.5927 - lr: 0.0010
# Epoch 32/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9771 - f1_score: 0.9598
# Epoch 32: val_f1_score improved from 0.59271 to 0.59457, saving model to best_model.h5
# 11/11 [==============================] - 6s 599ms/step - loss: 0.0055 - accuracy: 0.9771 - f1_score: 0.9598 - val_loss: 0.1315 - val_accuracy: 0.7315 - val_f1_score: 0.5946 - lr: 0.0010
# Epoch 33/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9360 - f1_score: 0.9167
# Epoch 33: val_f1_score improved from 0.59457 to 0.60700, saving model to best_model.h5
# 11/11 [==============================] - 6s 598ms/step - loss: 0.0115 - accuracy: 0.9360 - f1_score: 0.9167 - val_loss: 0.1279 - val_accuracy: 0.6605 - val_f1_score: 0.6070 - lr: 0.0010
# Epoch 34/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9451 - f1_score: 0.9256
# Epoch 34: val_f1_score did not improve from 0.60700
# 11/11 [==============================] - 5s 452ms/step - loss: 0.0083 - accuracy: 0.9451 - f1_score: 0.9256 - val_loss: 0.1253 - val_accuracy: 0.4444 - val_f1_score: 0.4830 - lr: 0.0010
# Epoch 35/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9756 - f1_score: 0.9677
# Epoch 35: val_f1_score did not improve from 0.60700
# 11/11 [==============================] - 5s 433ms/step - loss: 0.0048 - accuracy: 0.9756 - f1_score: 0.9677 - val_loss: 0.0847 - val_accuracy: 0.6173 - val_f1_score: 0.5953 - lr: 0.0010
# Epoch 36/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9848 - f1_score: 0.9808
# Epoch 36: val_f1_score did not improve from 0.60700
# 11/11 [==============================] - 5s 421ms/step - loss: 0.0026 - accuracy: 0.9848 - f1_score: 0.9808 - val_loss: 0.1021 - val_accuracy: 0.7191 - val_f1_score: 0.5277 - lr: 0.0010
# Epoch 37/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9817 - f1_score: 0.9780
# Epoch 37: val_f1_score did not improve from 0.60700
# 11/11 [==============================] - 5s 427ms/step - loss: 0.0030 - accuracy: 0.9817 - f1_score: 0.9780 - val_loss: 0.1133 - val_accuracy: 0.7130 - val_f1_score: 0.4589 - lr: 0.0010
# Epoch 38/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9817 - f1_score: 0.9770
# Epoch 38: val_f1_score did not improve from 0.60700
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0045 - accuracy: 0.9817 - f1_score: 0.9770 - val_loss: 0.1501 - val_accuracy: 0.4444 - val_f1_score: 0.4856 - lr: 0.0010
# Epoch 39/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9695 - f1_score: 0.9180
# Epoch 39: val_f1_score improved from 0.60700 to 0.64371, saving model to best_model.h5
# 11/11 [==============================] - 6s 592ms/step - loss: 0.0053 - accuracy: 0.9695 - f1_score: 0.9180 - val_loss: 0.0949 - val_accuracy: 0.6667 - val_f1_score: 0.6437 - lr: 0.0010
# Epoch 40/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9466 - f1_score: 0.9201
# Epoch 40: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 5s 449ms/step - loss: 0.0067 - accuracy: 0.9466 - f1_score: 0.9201 - val_loss: 0.1311 - val_accuracy: 0.6389 - val_f1_score: 0.6120 - lr: 0.0010
# Epoch 41/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9771 - f1_score: 0.9259
# Epoch 41: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 5s 443ms/step - loss: 0.0045 - accuracy: 0.9771 - f1_score: 0.9259 - val_loss: 0.1980 - val_accuracy: 0.7315 - val_f1_score: 0.5307 - lr: 0.0010
# Epoch 42/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9954 - f1_score: 0.9937
# Epoch 42: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 5s 436ms/step - loss: 0.0015 - accuracy: 0.9954 - f1_score: 0.9937 - val_loss: 0.1522 - val_accuracy: 0.7222 - val_f1_score: 0.5430 - lr: 0.0010
# Epoch 43/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9970 - f1_score: 0.9899
# Epoch 43: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 5s 427ms/step - loss: 0.0015 - accuracy: 0.9970 - f1_score: 0.9899 - val_loss: 0.1857 - val_accuracy: 0.7407 - val_f1_score: 0.5714 - lr: 0.0010
# Epoch 44/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9436 - f1_score: 0.8984
# Epoch 44: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 5s 426ms/step - loss: 0.0099 - accuracy: 0.9436 - f1_score: 0.8984 - val_loss: 0.3313 - val_accuracy: 0.6049 - val_f1_score: 0.5143 - lr: 0.0010
# Epoch 45/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9040 - f1_score: 0.8505
# Epoch 45: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 409ms/step - loss: 0.0139 - accuracy: 0.9040 - f1_score: 0.8505 - val_loss: 0.3870 - val_accuracy: 0.3889 - val_f1_score: 0.3465 - lr: 0.0010
# Epoch 46/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9436 - f1_score: 0.9180
# Epoch 46: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 406ms/step - loss: 0.0098 - accuracy: 0.9436 - f1_score: 0.9180 - val_loss: 0.2681 - val_accuracy: 0.3796 - val_f1_score: 0.3862 - lr: 0.0010
# Epoch 47/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9710 - f1_score: 0.9626
# Epoch 47: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 379ms/step - loss: 0.0060 - accuracy: 0.9710 - f1_score: 0.9626 - val_loss: 0.3043 - val_accuracy: 0.3241 - val_f1_score: 0.3296 - lr: 0.0010
# Epoch 48/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9924 - f1_score: 0.9895
# Epoch 48: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 397ms/step - loss: 0.0025 - accuracy: 0.9924 - f1_score: 0.9895 - val_loss: 0.2245 - val_accuracy: 0.4043 - val_f1_score: 0.4126 - lr: 0.0010
# Epoch 49/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.0927e-04 - accuracy: 0.9970 - f1_score: 0.9816
# Epoch 49: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 401ms/step - loss: 6.0927e-04 - accuracy: 0.9970 - f1_score: 0.9816 - val_loss: 0.1479 - val_accuracy: 0.6080 - val_f1_score: 0.6377 - lr: 0.0010
# Epoch 50/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9878 - f1_score: 0.9769
# Epoch 50: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 407ms/step - loss: 0.0025 - accuracy: 0.9878 - f1_score: 0.9769 - val_loss: 0.2952 - val_accuracy: 0.3735 - val_f1_score: 0.3850 - lr: 0.0010
# Epoch 51/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9848 - f1_score: 0.9760
# Epoch 51: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 409ms/step - loss: 0.0046 - accuracy: 0.9848 - f1_score: 0.9760 - val_loss: 0.1753 - val_accuracy: 0.6296 - val_f1_score: 0.6349 - lr: 0.0010
# Epoch 52/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9649 - f1_score: 0.9559
# Epoch 52: val_f1_score did not improve from 0.64371
# 11/11 [==============================] - 4s 401ms/step - loss: 0.0060 - accuracy: 0.9649 - f1_score: 0.9559 - val_loss: 0.2860 - val_accuracy: 0.7407 - val_f1_score: 0.5622 - lr: 0.0010
# Epoch 53/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9909 - f1_score: 0.9876
# Epoch 53: val_f1_score improved from 0.64371 to 0.64569, saving model to best_model.h5
# 11/11 [==============================] - 6s 530ms/step - loss: 0.0022 - accuracy: 0.9909 - f1_score: 0.9876 - val_loss: 0.1702 - val_accuracy: 0.6358 - val_f1_score: 0.6457 - lr: 0.0010
# Epoch 54/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9848 - f1_score: 0.9660
# Epoch 54: val_f1_score did not improve from 0.64569
# 11/11 [==============================] - 4s 401ms/step - loss: 0.0023 - accuracy: 0.9848 - f1_score: 0.9660 - val_loss: 0.2319 - val_accuracy: 0.7407 - val_f1_score: 0.5885 - lr: 0.0010
# Epoch 55/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9817 - f1_score: 0.9740
# Epoch 55: val_f1_score did not improve from 0.64569
# 11/11 [==============================] - 4s 406ms/step - loss: 0.0030 - accuracy: 0.9817 - f1_score: 0.9740 - val_loss: 0.3828 - val_accuracy: 0.6728 - val_f1_score: 0.6337 - lr: 0.0010
# Epoch 56/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9924 - f1_score: 0.9902
# Epoch 56: val_f1_score did not improve from 0.64569
# 11/11 [==============================] - 4s 397ms/step - loss: 0.0021 - accuracy: 0.9924 - f1_score: 0.9902 - val_loss: 0.6064 - val_accuracy: 0.7191 - val_f1_score: 0.6077 - lr: 0.0010
# Epoch 57/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.0303e-04 - accuracy: 0.9954 - f1_score: 0.9944
# Epoch 57: val_f1_score did not improve from 0.64569
# 11/11 [==============================] - 4s 389ms/step - loss: 9.0303e-04 - accuracy: 0.9954 - f1_score: 0.9944 - val_loss: 0.5550 - val_accuracy: 0.7191 - val_f1_score: 0.6025 - lr: 0.0010
# Epoch 58/10000
-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 145/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.4005e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 145: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 411ms/step - loss: 1.4005e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 146/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.8318e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 146: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 424ms/step - loss: 9.8318e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2361 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 147/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.8464e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 147: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 414ms/step - loss: 2.8464e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 148/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.0324e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 148: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 418ms/step - loss: 8.0324e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2368 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 149/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.2186e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 149: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 405ms/step - loss: 1.2186e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2375 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 150/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.1552e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 150: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 427ms/step - loss: 2.1552e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 151/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.6656e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 151: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 419ms/step - loss: 2.6656e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2384 - val_accuracy: 0.6821 - val_f1_score: 0.6265 - lr: 6.2500e-05
# Epoch 152/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.1775e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 152: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 408ms/step - loss: 1.1775e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.6821 - val_f1_score: 0.6265 - lr: 6.2500e-05
# Epoch 153/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.2519e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 153: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 419ms/step - loss: 8.2519e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2396 - val_accuracy: 0.6821 - val_f1_score: 0.6265 - lr: 6.2500e-05
# Epoch 154/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.6501e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 154: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 405ms/step - loss: 1.6501e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2404 - val_accuracy: 0.6821 - val_f1_score: 0.6265 - lr: 6.2500e-05
# Epoch 155/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.3060e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 155: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 403ms/step - loss: 3.3060e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2405 - val_accuracy: 0.6852 - val_f1_score: 0.6279 - lr: 6.2500e-05
# Epoch 156/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8570e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 156: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 400ms/step - loss: 1.8570e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.6883 - val_f1_score: 0.6301 - lr: 6.2500e-05
# Epoch 157/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0950e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 157: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 4s 399ms/step - loss: 2.0950e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.6883 - val_f1_score: 0.6301 - lr: 6.2500e-05
# Epoch 158/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.9134e-06 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 58.
#
# Epoch 158: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 158: val_f1_score did not improve from 0.67053
# 11/11 [==============================] - 5s 433ms/step - loss: 6.9134e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2419 - val_accuracy: 0.6883 - val_f1_score: 0.6325 - lr: 6.2500e-05
# Epoch 158: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 6s 47ms/step
# 0.7098765432098766

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7098765432098766
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.44      0.42      0.43        85
#            0       0.80      0.81      0.80       239
#
#     accuracy                           0.71       324
#    macro avg       0.62      0.62      0.62       324
# weighted avg       0.71      0.71      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 230 chiếm khoảng 70.98765432098766% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 36 chiếm khoảng 42.35294117647059% so với thực tế
