# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
# -*- coding: utf-8 -*-
"""Inception-ResNet V2 model for Keras.

Model naming and structure follows TF-slim implementation (which has some additional
layers and different number of filters from the original arXiv paper):
https://github.com/tensorflow/models/blob/master/slim/nets/inception_resnet_v2.py

Pre-trained ImageNet weights are also converted from TF-slim, which can be found in:
https://github.com/tensorflow/models/tree/master/slim#pre-trained-models

# Reference
- [Inception-v4, Inception-ResNet and the Impact of
   Residual Connections on Learning](https://arxiv.org/abs/1602.07261)

"""
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np
from keras.layers import Input, Conv1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D,AveragePooling1D,Concatenate, Dense
from keras.models import Model
import keras.backend as K




def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.

    This function applies the "Inception" preprocessing which converts
    the RGB values from [0, 255] to [-1, 1]. Note that this preprocessing
    function is different from `imagenet_utils.preprocess_input()`.

    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].

    # Returns
        Preprocessed array.
    """
    x /= 255.
    x -= 0.5
    x *= 2.
    return x


def conv1d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              name=None):
    bn_axis=1
    x = Conv1D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               name=name)(x)
    bn_name = None if name is None else name + '_bn'
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = None if name is None else name + '_ac'
        x = Activation(activation, name=ac_name)(x)
    return x

from keras.layers import Lambda, ZeroPadding1D

def adjust_padding(branches):
    max_length = max(K.int_shape(branch)[1] for branch in branches)
    adjusted_branches = []
    for branch in branches:
        branch_length = K.int_shape(branch)[1]
        if branch_length < max_length:
            padding = max_length - branch_length
            branch = ZeroPadding1D(padding=(0, padding))(branch)
        adjusted_branches.append(branch)
    return adjusted_branches

def check_and_adjust_branches(branches, channel_axis):
    max_length = max([K.int_shape(branch)[channel_axis] for branch in branches])
    adjusted_branches = []
    for branch in branches:
        branch_length = K.int_shape(branch)[channel_axis]
        if branch_length != max_length:
            # Adjust the size of the branch
            # This can be done using ZeroPadding1D, Cropping1D, or other methods
            # For example, using ZeroPadding1D:
            padding_size = (max_length - branch_length)
            padding = (padding_size // 2, padding_size - padding_size // 2)
            branch = ZeroPadding1D(padding=padding)(branch)
        adjusted_branches.append(branch)
    return adjusted_branches

def adjust_branches_for_concat(branches):
    adjusted_branches = []
    for branch in branches:
        if K.int_shape(branch)[2] != 96:
            # Thêm đệm để kích thước chiều kênh tăng lên 96
            padding_size = 96 - K.int_shape(branch)[2]
            left_pad = padding_size // 2
            right_pad = padding_size - left_pad
            branch = ZeroPadding1D(padding=(left_pad, right_pad))(branch)
        adjusted_branches.append(branch)
    return adjusted_branches


def inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
 
    if block_type == 'block35':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 32, 1)
        branch_1 = conv1d_bn(x, 32, 1)
        branch_1 = conv1d_bn(branch_1, 32, 3)
        branch_2 = conv1d_bn(x, 32, 1)
        branch_2 = conv1d_bn(branch_2, 48, 3)
        branch_2 = conv1d_bn(branch_2, 64, 3)
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'block17':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(x, 128, 1)
        branch_1 = conv1d_bn(branch_1, 160, 1)
        branch_1 = conv1d_bn(branch_1, 192, 7)
        branches = [branch_0, branch_1]
    elif block_type == 'block8':
        target_length = K.int_shape(x)[1]
        branch_0 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(x, 192, 1)
        branch_1 = conv1d_bn(branch_1, 224, 1)
        branch_1 = conv1d_bn(branch_1, 256, 3)
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: ' + str(block_type))

    block_name = block_type + '_' + str(block_idx)
    channel_axis = -1
    branches = check_and_adjust_branches(branches, channel_axis=1)
    mixed = Concatenate(axis=channel_axis, name=block_name + '_mixed')(branches)
    up = conv1d_bn(mixed,
                   K.int_shape(x)[channel_axis],
                   1,
                   activation=None,
                   name=block_name + '_conv')

    x = Lambda(lambda inputs, scale: inputs[0] + inputs[1] * scale,
               output_shape=K.int_shape(x)[1:],
               arguments={'scale': scale},
               name=block_name)([x, up])
    if activation is not None:
        x = Activation(activation, name=block_name + '_ac')(x)
    return x

# %%
def InceptionResNetV2():

    # Determine proper input shape
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    # Stem block: 35 x 35 x 192
    x = conv1d_bn(x_input, 16, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 16, 3, padding='valid')
    x = conv1d_bn(x, 32, 3)
    x = MaxPooling1D(3, strides=2)(x)
    x = conv1d_bn(x, 80, 1, padding='valid')
    x = conv1d_bn(x, 192, 3, padding='valid')
    x = MaxPooling1D(3, strides=2)(x)

    # Mixed 5b (Inception-A block): 35 x 35 x 160
    branch_0 = conv1d_bn(x, 64, 1)
    branch_1 = conv1d_bn(x, 48, 1)
    branch_1 = conv1d_bn(branch_1, 32, 5)
    branch_2 = conv1d_bn(x, 32, 1)
    branch_2 = conv1d_bn(branch_2, 64, 3)
    branch_2 = conv1d_bn(branch_2, 64, 3)
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1)
    target_shape = (None, 2, 64)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    channel_axis = -1
    #branches = adjust_branches_for_concat(branches)
    x = Concatenate(axis=-1, name='mixed_5b')(branches)

    # 10x block35 (Inception-ResNet-A block): 35 x 35 x 160
    for block_idx in range(1, 11):
        x = inception_resnet_block(x,
                                   scale=0.17,
                                   block_type='block35',
                                   block_idx=block_idx)

    # Mixed 6a (Reduction-A block): 17 x 17 x 1088
    branch_0 = conv1d_bn(x, 128, 3, strides=2, padding='same')
    branch_1 = conv1d_bn(x, 96, 1)
    branch_1 = conv1d_bn(branch_1, 96, 3)
    branch_1 = conv1d_bn(branch_1, 128, 3, strides=2, padding='same')
    branch_pool = MaxPooling1D(3, strides=2, padding='same')(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_6a')(branches)

    # 20x block17 (Inception-ResNet-B block): 17 x 17 x 1088
    for block_idx in range(1, 21):
        x = inception_resnet_block(x,
                                   scale=0.1,
                                   block_type='block17',
                                   block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    branch_0 = conv1d_bn(x, 96, 1)
    branch_0 = conv1d_bn(branch_0, 128, 3, strides=2, padding='same')
    branch_1 = conv1d_bn(x, 96, 1)
    branch_1 = conv1d_bn(branch_1, 288, 3, strides=2, padding='same')
    branch_2 = conv1d_bn(x, 96, 1)
    branch_2 = conv1d_bn(branch_2, 288, 3)
    branch_2 = conv1d_bn(branch_2, 128, 3, strides=2, padding='same')
    branch_pool = MaxPooling1D(3, strides=2, padding='same')(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_7a')(branches)

    # 10x block8 (Inception-ResNet-C block): 8 x 8 x 2080
    for block_idx in range(1, 10):
        x = inception_resnet_block(x,
                                   scale=0.2,
                                   block_type='block8',
                                   block_idx=block_idx)
    x = inception_resnet_block(x,
                               scale=1.,
                               activation=None,
                               block_type='block8',
                               block_idx=10)

    # Final convolution block: 8 x 8 x 1536
    x = conv1d_bn(x, 1536, 1, name='conv_7b')
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

 

    # Create model
    model = Model(x_input, x, name='inception_resnet_v2')

    

    return model


model = InceptionResNetV2()
lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 16)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 16)               784       ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 16)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 16)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 18, 32)               1568      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 18, 32)               54        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 18, 32)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 8, 32)                0         ['activation_2[0][0]']
#  D)
#
#  conv1d_3 (Conv1D)           (None, 8, 80)                2640      ['max_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 8, 80)                24        ['conv1d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 8, 80)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 6, 192)               46272     ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 6, 192)               18        ['conv1d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 6, 192)               0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 192)               0         ['activation_4[0][0]']
#  g1D)
#
#  conv1d_8 (Conv1D)           (None, 2, 32)                6176      ['max_pooling1d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 2, 32)                6         ['conv1d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 2, 32)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv1d_6 (Conv1D)           (None, 2, 48)                9264      ['max_pooling1d_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 2, 64)                6208      ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 2, 48)                6         ['conv1d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 2, 64)                6         ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 2, 48)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 2, 64)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 2, 192)               0         ['max_pooling1d_1[0][0]']
#  Pooling1D)
#
#  conv1d_5 (Conv1D)           (None, 2, 64)                12352     ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 2, 32)                7712      ['activation_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 2, 64)                12352     ['activation_9[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 2, 32)                6176      ['average_pooling1d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 2, 64)                6         ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 2, 32)                6         ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 2, 64)                6         ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 2, 32)                6         ['conv1d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 2, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 2, 32)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 2, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 2, 32)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 2, 192)               0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 32)                6         ['conv1d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 2, 32)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv1d_13 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 2, 48)                4656      ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 2, 32)                6         ['conv1d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 2, 48)                6         ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 2, 32)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 2, 48)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv1d_12 (Conv1D)          (None, 2, 32)                6176      ['mixed_5b[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 2, 32)                3104      ['activation_13[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 2, 64)                9280      ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 2, 32)                6         ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 2, 32)                6         ['conv1d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 2, 64)                6         ['conv1d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 2, 32)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 2, 32)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 2, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 2, 128)               0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv1D)     (None, 2, 192)               24768     ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_1_conv[0][0]']
#  rmalization)
#
#  block35_1 (Lambda)          (None, 2, 192)               0         ['mixed_5b[0][0]',
#                                                                      'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)   (None, 2, 192)               0         ['block35_1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 2, 32)                6         ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 2, 32)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv1d_19 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 2, 48)                4656      ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 2, 32)                6         ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 2, 48)                6         ['conv1d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 2, 32)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 2, 48)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 2, 32)                6176      ['block35_1_ac[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 2, 32)                3104      ['activation_19[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 2, 64)                9280      ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 2, 32)                6         ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 2, 32)                6         ['conv1d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 2, 64)                6         ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 2, 32)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 2, 32)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 2, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 2, 128)               0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv1D)     (None, 2, 192)               24768     ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_2_conv[0][0]']
#  rmalization)
#
#  block35_2 (Lambda)          (None, 2, 192)               0         ['block35_1_ac[0][0]',
#                                                                      'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)   (None, 2, 192)               0         ['block35_2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 2, 32)                6         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 2, 32)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv1d_25 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  conv1d_28 (Conv1D)          (None, 2, 48)                4656      ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 2, 32)                6         ['conv1d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 2, 48)                6         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 2, 32)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 2, 48)                0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 2, 32)                6176      ['block35_2_ac[0][0]']
#
#  conv1d_26 (Conv1D)          (None, 2, 32)                3104      ['activation_25[0][0]']
#
#  conv1d_29 (Conv1D)          (None, 2, 64)                9280      ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 2, 32)                6         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 2, 32)                6         ['conv1d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 2, 64)                6         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 2, 32)                0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 2, 32)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 2, 64)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 2, 128)               0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv1D)     (None, 2, 192)               24768     ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_3_conv[0][0]']
#  rmalization)
#
#  block35_3 (Lambda)          (None, 2, 192)               0         ['block35_2_ac[0][0]',
#                                                                      'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)   (None, 2, 192)               0         ['block35_3[0][0]']
#
#  conv1d_33 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 2, 32)                6         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 2, 32)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_31 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 2, 48)                4656      ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 2, 32)                6         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 2, 48)                6         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 2, 32)                0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 2, 48)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 2, 32)                6176      ['block35_3_ac[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 2, 32)                3104      ['activation_31[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 2, 64)                9280      ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 2, 32)                6         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 2, 32)                6         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 2, 64)                6         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 2, 32)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 2, 32)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 2, 64)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 2, 128)               0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv1D)     (None, 2, 192)               24768     ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_4_conv[0][0]']
#  rmalization)
#
#  block35_4 (Lambda)          (None, 2, 192)               0         ['block35_3_ac[0][0]',
#                                                                      'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)   (None, 2, 192)               0         ['block35_4[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 2, 32)                6         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 2, 32)                0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv1d_37 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  conv1d_40 (Conv1D)          (None, 2, 48)                4656      ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 2, 32)                6         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 2, 48)                6         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 2, 32)                0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 2, 48)                0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv1d_36 (Conv1D)          (None, 2, 32)                6176      ['block35_4_ac[0][0]']
#
#  conv1d_38 (Conv1D)          (None, 2, 32)                3104      ['activation_37[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 2, 64)                9280      ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 2, 32)                6         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 2, 32)                6         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 2, 64)                6         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 2, 32)                0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 2, 32)                0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 2, 64)                0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 2, 128)               0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv1D)     (None, 2, 192)               24768     ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_5_conv[0][0]']
#  rmalization)
#
#  block35_5 (Lambda)          (None, 2, 192)               0         ['block35_4_ac[0][0]',
#                                                                      'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)   (None, 2, 192)               0         ['block35_5[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 2, 32)                6         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 2, 32)                0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv1d_43 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  conv1d_46 (Conv1D)          (None, 2, 48)                4656      ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 2, 32)                6         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 2, 48)                6         ['conv1d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 2, 32)                0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 2, 48)                0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv1d_42 (Conv1D)          (None, 2, 32)                6176      ['block35_5_ac[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 2, 32)                3104      ['activation_43[0][0]']
#
#  conv1d_47 (Conv1D)          (None, 2, 64)                9280      ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 2, 32)                6         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 2, 32)                6         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 2, 64)                6         ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 2, 32)                0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 2, 32)                0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 2, 64)                0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 2, 128)               0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv1D)     (None, 2, 192)               24768     ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNo  (None, 2, 192)               6         ['block35_6_conv[0][0]']
#  rmalization)
#
#  block35_6 (Lambda)          (None, 2, 192)               0         ['block35_5_ac[0][0]',
#                                                                      'block35_6_conv_bn[0][0]']
# ...
#  block8_7_mixed (Concatenat  (None, 1, 448)               0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv1D)      (None, 1, 992)               445408    ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_7_conv[0][0]']
#  malization)
#
#  block8_7 (Lambda)           (None, 1, 992)               0         ['block8_6_ac[0][0]',
#                                                                      'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)    (None, 1, 992)               0         ['block8_7[0][0]']
#
#  conv1d_192 (Conv1D)         (None, 1, 192)               190656    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 1, 192)               3         ['conv1d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 1, 192)               0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv1d_193 (Conv1D)         (None, 1, 224)               43232     ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 1, 224)               3         ['conv1d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 1, 224)               0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv1d_191 (Conv1D)         (None, 1, 192)               190656    ['block8_7_ac[0][0]']
#
#  conv1d_194 (Conv1D)         (None, 1, 256)               172288    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 1, 192)               3         ['conv1d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 1, 256)               3         ['conv1d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 1, 192)               0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 1, 256)               0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 1, 448)               0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv1D)      (None, 1, 992)               445408    ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_8_conv[0][0]']
#  malization)
#
#  block8_8 (Lambda)           (None, 1, 992)               0         ['block8_7_ac[0][0]',
#                                                                      'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)    (None, 1, 992)               0         ['block8_8[0][0]']
#
#  conv1d_196 (Conv1D)         (None, 1, 192)               190656    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 1, 192)               3         ['conv1d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 1, 192)               0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv1d_197 (Conv1D)         (None, 1, 224)               43232     ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 1, 224)               3         ['conv1d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 1, 224)               0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv1d_195 (Conv1D)         (None, 1, 192)               190656    ['block8_8_ac[0][0]']
#
#  conv1d_198 (Conv1D)         (None, 1, 256)               172288    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 1, 192)               3         ['conv1d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 1, 256)               3         ['conv1d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 1, 192)               0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 1, 256)               0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 1, 448)               0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv1D)      (None, 1, 992)               445408    ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNor  (None, 1, 992)               3         ['block8_9_conv[0][0]']
#  malization)
#
#  block8_9 (Lambda)           (None, 1, 992)               0         ['block8_8_ac[0][0]',
#                                                                      'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)    (None, 1, 992)               0         ['block8_9[0][0]']
#
#  conv1d_200 (Conv1D)         (None, 1, 192)               190656    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 1, 192)               3         ['conv1d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 1, 192)               0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv1d_201 (Conv1D)         (None, 1, 224)               43232     ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 1, 224)               3         ['conv1d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 1, 224)               0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv1d_199 (Conv1D)         (None, 1, 192)               190656    ['block8_9_ac[0][0]']
#
#  conv1d_202 (Conv1D)         (None, 1, 256)               172288    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 1, 192)               3         ['conv1d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 1, 256)               3         ['conv1d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 1, 192)               0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 1, 256)               0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 1, 448)               0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv1D)     (None, 1, 992)               445408    ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNo  (None, 1, 992)               3         ['block8_10_conv[0][0]']
#  rmalization)
#
#  block8_10 (Lambda)          (None, 1, 992)               0         ['block8_9_ac[0][0]',
#                                                                      'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)            (None, 1, 1536)              1525248   ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormaliza  (None, 1, 1536)              3         ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 1, 1536)              0         ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    3074      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24308062 (92.73 MB)
# Trainable params: 24307286 (92.72 MB)
# Non-trainable params: 776 (3.03 KB)
# __________________________________________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/10000
# 11/11 [==============================] - 87s 945ms/step - loss: 2.6475 - accuracy: 0.6418 - f1_score: 0.6491 - val_loss: 3.3534 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 2/10000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.7479 - accuracy: 0.6143 - f1_score: 0.6364 - val_loss: 3.2005 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.6061 - accuracy: 0.7637 - f1_score: 0.7585 - val_loss: 0.5651 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
# 11/11 [==============================] - 4s 335ms/step - loss: 0.5249 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 0.7919 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 5/10000
# 11/11 [==============================] - 4s 334ms/step - loss: 0.4891 - accuracy: 0.7637 - f1_score: 0.7713 - val_loss: 0.5781 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - 4s 333ms/step - loss: 0.4743 - accuracy: 0.7637 - f1_score: 0.7713 - val_loss: 0.6171 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - 4s 337ms/step - loss: 0.4431 - accuracy: 0.7637 - f1_score: 0.7500 - val_loss: 0.6349 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.4313 - accuracy: 0.7637 - f1_score: 0.7457 - val_loss: 0.6407 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 9/10000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.4133 - accuracy: 0.7744 - f1_score: 0.7727 - val_loss: 0.6591 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3726 - accuracy: 0.7942 - f1_score: 0.7997 - val_loss: 0.6680 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - 4s 340ms/step - loss: 0.3230 - accuracy: 0.8476 - f1_score: 0.8452 - val_loss: 0.6748 - val_accuracy: 0.4784 - val_f1_score: 0.4818 - lr: 0.0010
# Epoch 12/10000
# 11/11 [==============================] - 4s 333ms/step - loss: 0.2743 - accuracy: 0.8796 - f1_score: 0.8793 - val_loss: 0.8094 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 13/10000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.2643 - accuracy: 0.8780 - f1_score: 0.8778 - val_loss: 0.7938 - val_accuracy: 0.4290 - val_f1_score: 0.4401 - lr: 0.0010
# Epoch 14/10000
# 11/11 [==============================] - 4s 336ms/step - loss: 0.2538 - accuracy: 0.8811 - f1_score: 0.8722 - val_loss: 0.9530 - val_accuracy: 0.3210 - val_f1_score: 0.3099 - lr: 0.0010
# Epoch 15/10000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.2889 - accuracy: 0.8537 - f1_score: 0.8509 - val_loss: 4.4476 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 0.0010
# Epoch 16/10000
# 11/11 [==============================] - 4s 341ms/step - loss: 0.2737 - accuracy: 0.8796 - f1_score: 0.8707 - val_loss: 1.2599 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - 4s 337ms/step - loss: 0.1778 - accuracy: 0.9314 - f1_score: 0.9233 - val_loss: 4.4949 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 0.0010
# Epoch 18/10000
# 11/11 [==============================] - 4s 338ms/step - loss: 0.2078 - accuracy: 0.9238 - f1_score: 0.9247 - val_loss: 1.3286 - val_accuracy: 0.6327 - val_f1_score: 0.6510 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - 4s 340ms/step - loss: 0.1587 - accuracy: 0.9314 - f1_score: 0.9276 - val_loss: 4.7800 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.0989 - accuracy: 0.9573 - f1_score: 0.9602 - val_loss: 3.9635 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9787 - f1_score: 0.9801
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 [==============================] - 4s 340ms/step - loss: 0.0823 - accuracy: 0.9787 - f1_score: 0.9801 - val_loss: 7.8564 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 0.0010
# Epoch 22/10000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.0512 - accuracy: 0.9802 - f1_score: 0.9815 - val_loss: 4.4975 - val_accuracy: 0.7438 - val_f1_score: 0.7839 - lr: 5.0000e-04
# Epoch 23/10000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.0296 - accuracy: 0.9939 - f1_score: 0.9901 - val_loss: 4.3058 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 5.0000e-04
# Epoch 24/10000
# 11/11 [==============================] - 4s 361ms/step - loss: 0.0371 - accuracy: 0.9863 - f1_score: 0.9872 - val_loss: 3.7518 - val_accuracy: 0.7500 - val_f1_score: 0.7500 - lr: 5.0000e-04
# Epoch 25/10000
# 11/11 [==============================] - 4s 343ms/step - loss: 0.0250 - accuracy: 0.9939 - f1_score: 0.9943 - val_loss: 3.0997 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 5.0000e-04
# Epoch 26/10000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.0295 - accuracy: 0.9909 - f1_score: 0.9872 - val_loss: 3.9468 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 5.0000e-04
# Epoch 27/10000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.0576 - accuracy: 0.9817 - f1_score: 0.9830 - val_loss: 5.9344 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 5.0000e-04
# Epoch 28/10000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.0356 - accuracy: 0.9909 - f1_score: 0.9830 - val_loss: 3.1659 - val_accuracy: 0.7469 - val_f1_score: 0.7474 - lr: 5.0000e-04
# Epoch 29/10000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0522 - accuracy: 0.9802 - f1_score: 0.9815 - val_loss: 6.0873 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 5.0000e-04
# Epoch 30/10000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.0326 - accuracy: 0.9893 - f1_score: 0.9901 - val_loss: 2.5921 - val_accuracy: 0.7531 - val_f1_score: 0.7917 - lr: 5.0000e-04
# Epoch 31/10000
# 11/11 [==============================] - 4s 360ms/step - loss: 0.0219 - accuracy: 0.9954 - f1_score: 0.9915 - val_loss: 1.5880 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 5.0000e-04
# Epoch 32/10000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.0305 - accuracy: 0.9924 - f1_score: 0.9929 - val_loss: 1.6268 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 5.0000e-04
# Epoch 33/10000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.0284 - accuracy: 0.9924 - f1_score: 0.9929 - val_loss: 2.3673 - val_accuracy: 0.7469 - val_f1_score: 0.7865 - lr: 5.0000e-04
# Epoch 34/10000
# 11/11 [==============================] - 4s 366ms/step - loss: 0.0189 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 2.8099 - val_accuracy: 0.7438 - val_f1_score: 0.7448 - lr: 5.0000e-04
# Epoch 35/10000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.0270 - accuracy: 0.9939 - f1_score: 0.9858 - val_loss: 2.2101 - val_accuracy: 0.7377 - val_f1_score: 0.7786 - lr: 5.0000e-04
# Epoch 36/10000
# 11/11 [==============================] - 4s 354ms/step - loss: 0.0481 - accuracy: 0.9848 - f1_score: 0.9730 - val_loss: 2.2563 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 5.0000e-04
# Epoch 37/10000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.0705 - accuracy: 0.9710 - f1_score: 0.9688 - val_loss: 2.9005 - val_accuracy: 0.7531 - val_f1_score: 0.7917 - lr: 5.0000e-04
# Epoch 38/10000
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0260 - accuracy: 0.9970 - f1_score: 0.9972 - val_loss: 2.4126 - val_accuracy: 0.7531 - val_f1_score: 0.7917 - lr: 5.0000e-04
# Epoch 39/10000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.0229 - accuracy: 0.9939 - f1_score: 0.9858 - val_loss: 2.0799 - val_accuracy: 0.7500 - val_f1_score: 0.7891 - lr: 5.0000e-04
# Epoch 40/10000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.0167 - accuracy: 0.9970 - f1_score: 0.9972 - val_loss: 1.8641 - val_accuracy: 0.6080 - val_f1_score: 0.6302 - lr: 5.0000e-04
# Epoch 41/10000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0198 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 2.7642 - val_accuracy: 0.7531 - val_f1_score: 0.7526 - lr: 5.0000e-04
# Epoch 42/10000
# 11/11 [==============================] - 4s 353ms/step - loss: 0.0202 - accuracy: 0.9939 - f1_score: 0.9943 - val_loss: 2.5563 - val_accuracy: 0.7531 - val_f1_score: 0.7526 - lr: 5.0000e-04
# Epoch 43/10000
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0180 - accuracy: 0.9970 - f1_score: 0.9929 - val_loss: 1.7389 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 5.0000e-04
# Epoch 44/10000
# 11/11 [==============================] - 4s 347ms/step - loss: 0.0220 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 1.8236 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 5.0000e-04
# Epoch 45/10000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.0116 - accuracy: 0.9985 - f1_score: 0.9986 - val_loss: 2.0573 - val_accuracy: 0.7377 - val_f1_score: 0.7786 - lr: 5.0000e-04
# Epoch 46/10000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.0168 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 1.7127 - val_accuracy: 0.6574 - val_f1_score: 0.7109 - lr: 5.0000e-04
# Epoch 47/10000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.0120 - accuracy: 0.9985 - f1_score: 0.9986 - val_loss: 1.6197 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 5.0000e-04
# Epoch 48/10000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.0109 - accuracy: 0.9985 - f1_score: 0.9986 - val_loss: 1.5528 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 5.0000e-04
# Epoch 49/10000
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0183 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 1.6911 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 5.0000e-04
# Epoch 50/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9939 - f1_score: 0.9901
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 [==============================] - 4s 349ms/step - loss: 0.0261 - accuracy: 0.9939 - f1_score: 0.9901 - val_loss: 1.7404 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 5.0000e-04
# Epoch 51/10000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.0301 - accuracy: 0.9909 - f1_score: 0.9915 - val_loss: 1.8734 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 52/10000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.0156 - accuracy: 0.9954 - f1_score: 0.9915 - val_loss: 1.7578 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 2.5000e-04
# Epoch 53/10000
# 11/11 [==============================] - 4s 348ms/step - loss: 0.0189 - accuracy: 0.9939 - f1_score: 0.9901 - val_loss: 1.7348 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 54/10000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.0287 - accuracy: 0.9924 - f1_score: 0.9929 - val_loss: 2.0028 - val_accuracy: 0.5370 - val_f1_score: 0.6094 - lr: 2.5000e-04
# Epoch 55/10000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.0207 - accuracy: 0.9970 - f1_score: 0.9886 - val_loss: 1.9810 - val_accuracy: 0.5494 - val_f1_score: 0.6198 - lr: 2.5000e-04
# Epoch 56/10000
# 11/11 [==============================] - 4s 348ms/step - loss: 0.0242 - accuracy: 0.9909 - f1_score: 0.9915 - val_loss: 1.6148 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 2.5000e-04
# Epoch 57/10000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0293 - accuracy: 0.9924 - f1_score: 0.9844 - val_loss: 1.6806 - val_accuracy: 0.6420 - val_f1_score: 0.6979 - lr: 2.5000e-04
# Epoch 58/10000
# 11/11 [==============================] - 4s 335ms/step - loss: 0.0214 - accuracy: 0.9939 - f1_score: 0.9943 - val_loss: 1.9781 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 2.5000e-04
# Epoch 59/10000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.0182 - accuracy: 0.9954 - f1_score: 0.9957 - val_loss: 2.8138 - val_accuracy: 0.7469 - val_f1_score: 0.7474 - lr: 2.5000e-04
# Epoch 60/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9985 - f1_score: 0.9986Restoring model weights from the end of the best epoch: 30.
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0136 - accuracy: 0.9985 - f1_score: 0.9986 - val_loss: 2.9948 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 2.5000e-04
# Epoch 60: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 6s 48ms/step
# 0.7530864197530864

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7530864197530864
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.58      0.21      0.31        85
#            0       0.77      0.95      0.85       239
#
#     accuracy                           0.75       324
#    macro avg       0.68      0.58      0.58       324
# weighted avg       0.72      0.75      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 244 chiếm khoảng 75.30864197530865% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 18 chiếm khoảng 21.176470588235293% so với thực tế
