# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 128, 1,padding='same')

    branch7x7 = conv1d_bn(x, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 128, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # # mixed 5, 6: 17 x 17 x 768
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    #     branch7x7 = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    #     branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch7x7, branch7x7dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 960
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 288, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 288, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 256, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 256, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 256, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 256, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
# model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d_46 (Conv1D)          (None, 20, 32)               96        ['input_2[0][0]']
#
#  batch_normalization_46 (Ba  (None, 20, 32)               60        ['conv1d_46[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 20, 32)               0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv1d_47 (Conv1D)          (None, 18, 32)               3072      ['activation_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 18, 32)               54        ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 18, 32)               0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv1d_48 (Conv1D)          (None, 16, 64)               6144      ['activation_47[0][0]']
#
#  batch_normalization_48 (Ba  (None, 16, 64)               48        ['conv1d_48[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 16, 64)               0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_48[0][0]']
#
#  conv1d_52 (Conv1D)          (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_52 (Ba  (None, 7, 64)                21        ['conv1d_52[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 7, 64)                0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv1d_50 (Conv1D)          (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_53 (Conv1D)          (None, 7, 96)                18432     ['activation_52[0][0]']
#
#  batch_normalization_50 (Ba  (None, 7, 48)                21        ['conv1d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_53 (Ba  (None, 7, 96)                21        ['conv1d_53[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 7, 48)                0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_53 (Activation)  (None, 7, 96)                0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  average_pooling1d_5 (Avera  (None, 7, 64)                0         ['block1_pool[0][0]']
#  gePooling1D)
#
#  conv1d_49 (Conv1D)          (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_51 (Conv1D)          (None, 7, 64)                15360     ['activation_50[0][0]']
#
#  conv1d_54 (Conv1D)          (None, 7, 96)                27648     ['activation_53[0][0]']
#
#  conv1d_55 (Conv1D)          (None, 7, 32)                2048      ['average_pooling1d_5[0][0]']
#
#  batch_normalization_49 (Ba  (None, 7, 64)                21        ['conv1d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_51 (Ba  (None, 7, 64)                21        ['conv1d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_54 (Ba  (None, 7, 96)                21        ['conv1d_54[0][0]']
#  tchNormalization)
#
#  batch_normalization_55 (Ba  (None, 7, 32)                21        ['conv1d_55[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 7, 64)                0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 7, 64)                0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 7, 96)                0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  activation_55 (Activation)  (None, 7, 32)                0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_49[0][0]',
#                                                                      'activation_51[0][0]',
#                                                                      'activation_54[0][0]',
#                                                                      'activation_55[0][0]']
#
#  conv1d_59 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_59 (Ba  (None, 7, 64)                21        ['conv1d_59[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 7, 64)                0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv1d_57 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_60 (Conv1D)          (None, 7, 96)                18432     ['activation_59[0][0]']
#
#  batch_normalization_57 (Ba  (None, 7, 48)                21        ['conv1d_57[0][0]']
#  tchNormalization)
#
#  batch_normalization_60 (Ba  (None, 7, 96)                21        ['conv1d_60[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 7, 48)                0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  activation_60 (Activation)  (None, 7, 96)                0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  average_pooling1d_6 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_56 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_58 (Conv1D)          (None, 7, 64)                15360     ['activation_57[0][0]']
#
#  conv1d_61 (Conv1D)          (None, 7, 96)                27648     ['activation_60[0][0]']
#
#  conv1d_62 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_6[0][0]']
#
#  batch_normalization_56 (Ba  (None, 7, 64)                21        ['conv1d_56[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 7, 64)                21        ['conv1d_58[0][0]']
#  tchNormalization)
#
#  batch_normalization_61 (Ba  (None, 7, 96)                21        ['conv1d_61[0][0]']
#  tchNormalization)
#
#  batch_normalization_62 (Ba  (None, 7, 64)                21        ['conv1d_62[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 7, 64)                0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  activation_58 (Activation)  (None, 7, 64)                0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  activation_61 (Activation)  (None, 7, 96)                0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  activation_62 (Activation)  (None, 7, 64)                0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_56[0][0]',
#                                                                      'activation_58[0][0]',
#                                                                      'activation_61[0][0]',
#                                                                      'activation_62[0][0]']
#
#  conv1d_66 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_66 (Ba  (None, 7, 64)                21        ['conv1d_66[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 7, 64)                0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv1d_64 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_67 (Conv1D)          (None, 7, 96)                18432     ['activation_66[0][0]']
#
#  batch_normalization_64 (Ba  (None, 7, 48)                21        ['conv1d_64[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 7, 96)                21        ['conv1d_67[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 7, 48)                0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  activation_67 (Activation)  (None, 7, 96)                0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  average_pooling1d_7 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_63 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_65 (Conv1D)          (None, 7, 64)                15360     ['activation_64[0][0]']
#
#  conv1d_68 (Conv1D)          (None, 7, 96)                27648     ['activation_67[0][0]']
#
#  conv1d_69 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_7[0][0]']
#
#  batch_normalization_63 (Ba  (None, 7, 64)                21        ['conv1d_63[0][0]']
#  tchNormalization)
#
#  batch_normalization_65 (Ba  (None, 7, 64)                21        ['conv1d_65[0][0]']
#  tchNormalization)
#
#  batch_normalization_68 (Ba  (None, 7, 96)                21        ['conv1d_68[0][0]']
#  tchNormalization)
#
#  batch_normalization_69 (Ba  (None, 7, 64)                21        ['conv1d_69[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 7, 64)                0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  activation_65 (Activation)  (None, 7, 64)                0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  activation_68 (Activation)  (None, 7, 96)                0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  activation_69 (Activation)  (None, 7, 64)                0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_63[0][0]',
#                                                                      'activation_65[0][0]',
#                                                                      'activation_68[0][0]',
#                                                                      'activation_69[0][0]']
#
#  conv1d_71 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_71 (Ba  (None, 7, 64)                21        ['conv1d_71[0][0]']
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 7, 64)                0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv1d_72 (Conv1D)          (None, 7, 96)                18432     ['activation_71[0][0]']
#
#  batch_normalization_72 (Ba  (None, 7, 96)                21        ['conv1d_72[0][0]']
#  tchNormalization)
#
#  activation_72 (Activation)  (None, 7, 96)                0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv1d_70 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_73 (Conv1D)          (None, 3, 96)                27648     ['activation_72[0][0]']
#
#  batch_normalization_70 (Ba  (None, 3, 128)               9         ['conv1d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_73 (Ba  (None, 3, 96)                9         ['conv1d_73[0][0]']
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 3, 128)               0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  activation_73 (Activation)  (None, 3, 96)                0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  max_pooling1d_1 (MaxPoolin  (None, 3, 288)               0         ['mixed2[0][0]']
#  g1D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_70[0][0]',
#                                                                      'activation_73[0][0]',
#                                                                      'max_pooling1d_1[0][0]']
#
#  conv1d_78 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  batch_normalization_78 (Ba  (None, 3, 96)                9         ['conv1d_78[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 3, 96)                0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  conv1d_79 (Conv1D)          (None, 3, 96)                64512     ['activation_78[0][0]']
#
#  batch_normalization_79 (Ba  (None, 3, 96)                9         ['conv1d_79[0][0]']
#  tchNormalization)
#
#  activation_79 (Activation)  (None, 3, 96)                0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv1d_75 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  conv1d_80 (Conv1D)          (None, 3, 96)                9216      ['activation_79[0][0]']
#
#  batch_normalization_75 (Ba  (None, 3, 96)                9         ['conv1d_75[0][0]']
#  tchNormalization)
#
#  batch_normalization_80 (Ba  (None, 3, 96)                9         ['conv1d_80[0][0]']
#  tchNormalization)
#
#  activation_75 (Activation)  (None, 3, 96)                0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  activation_80 (Activation)  (None, 3, 96)                0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  conv1d_76 (Conv1D)          (None, 3, 96)                9216      ['activation_75[0][0]']
#
#  conv1d_81 (Conv1D)          (None, 3, 96)                64512     ['activation_80[0][0]']
#
#  batch_normalization_76 (Ba  (None, 3, 96)                9         ['conv1d_76[0][0]']
#  tchNormalization)
#
#  batch_normalization_81 (Ba  (None, 3, 96)                9         ['conv1d_81[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 3, 96)                0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  activation_81 (Activation)  (None, 3, 96)                0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  average_pooling1d_8 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_74 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_77 (Conv1D)          (None, 3, 128)               86016     ['activation_76[0][0]']
#
#  conv1d_82 (Conv1D)          (None, 3, 128)               12288     ['activation_81[0][0]']
#
#  conv1d_83 (Conv1D)          (None, 3, 128)               65536     ['average_pooling1d_8[0][0]']
#
#  batch_normalization_74 (Ba  (None, 3, 128)               9         ['conv1d_74[0][0]']
#  tchNormalization)
#
#  batch_normalization_77 (Ba  (None, 3, 128)               9         ['conv1d_77[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 3, 128)               9         ['conv1d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 3, 128)               9         ['conv1d_83[0][0]']
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 3, 128)               0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  activation_77 (Activation)  (None, 3, 128)               0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 3, 128)               0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 3, 128)               0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 512)               0         ['activation_74[0][0]',
#                                                                      'activation_77[0][0]',
#                                                                      'activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  conv1d_85 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_88 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  batch_normalization_85 (Ba  (None, 3, 192)               9         ['conv1d_85[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 3, 192)               9         ['conv1d_88[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 3, 192)               0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 3, 192)               0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv1d_86 (Conv1D)          (None, 3, 192)               36864     ['activation_85[0][0]']
#
#  conv1d_89 (Conv1D)          (None, 3, 192)               258048    ['activation_88[0][0]']
#
#  batch_normalization_86 (Ba  (None, 3, 192)               9         ['conv1d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_89 (Ba  (None, 3, 192)               9         ['conv1d_89[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 3, 192)               0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_89 (Activation)  (None, 3, 192)               0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  average_pooling1d_9 (Avera  (None, 3, 512)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_84 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_87 (Conv1D)          (None, 3, 192)               258048    ['activation_86[0][0]']
#
#  conv1d_90 (Conv1D)          (None, 3, 192)               36864     ['activation_89[0][0]']
#
#  conv1d_91 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_9[0][0]']
#
#  batch_normalization_84 (Ba  (None, 3, 192)               9         ['conv1d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_87 (Ba  (None, 3, 192)               9         ['conv1d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 3, 192)               9         ['conv1d_90[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 3, 192)               9         ['conv1d_91[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 3, 192)               0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  activation_87 (Activation)  (None, 3, 192)               0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 3, 192)               0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 3, 192)               0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_84[0][0]',
#                                                                      'activation_87[0][0]',
#                                                                      'activation_90[0][0]',
#                                                                      'activation_91[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1973147 (7.53 MB)
# Trainable params: 1972597 (7.52 MB)
# Non-trainable params: 550 (2.15 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5816 - accuracy: 0.5906 - f1_score: 0.5064
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 12s 104ms/step - loss: 0.5758 - accuracy: 0.5908 - f1_score: 0.5113 - val_loss: 0.2619 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3909 - accuracy: 0.7188 - f1_score: 0.7164
# Epoch 2: val_f1_score improved from 0.42467 to 0.44415, saving model to best_model.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3879 - accuracy: 0.7206 - f1_score: 0.7192 - val_loss: 0.2602 - val_accuracy: 0.7377 - val_f1_score: 0.4442 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3040 - accuracy: 0.7844 - f1_score: 0.7823
# Epoch 3: val_f1_score did not improve from 0.44415
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3049 - accuracy: 0.7844 - f1_score: 0.7825 - val_loss: 0.7365 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.7585 - f1_score: 0.7559
# Epoch 4: val_f1_score improved from 0.44415 to 0.53164, saving model to best_model.h5
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3385 - accuracy: 0.7585 - f1_score: 0.7559 - val_loss: 0.3999 - val_accuracy: 0.6204 - val_f1_score: 0.5316 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2693 - accuracy: 0.8083 - f1_score: 0.8055
# Epoch 5: val_f1_score did not improve from 0.53164
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2683 - accuracy: 0.8084 - f1_score: 0.8053 - val_loss: 0.3779 - val_accuracy: 0.6235 - val_f1_score: 0.5239 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2763 - accuracy: 0.8010 - f1_score: 0.7964
# Epoch 6: val_f1_score improved from 0.53164 to 0.54595, saving model to best_model.h5
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2817 - accuracy: 0.7964 - f1_score: 0.7892 - val_loss: 0.5247 - val_accuracy: 0.4722 - val_f1_score: 0.5460 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2861 - accuracy: 0.7937 - f1_score: 0.7897
# Epoch 7: val_f1_score did not improve from 0.54595
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2933 - accuracy: 0.7904 - f1_score: 0.7849 - val_loss: 0.2676 - val_accuracy: 0.7346 - val_f1_score: 0.4610 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2489 - accuracy: 0.8219 - f1_score: 0.8197
# Epoch 8: val_f1_score did not improve from 0.54595
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2485 - accuracy: 0.8214 - f1_score: 0.8190 - val_loss: 0.7246 - val_accuracy: 0.2778 - val_f1_score: 0.2234 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2264 - accuracy: 0.8427 - f1_score: 0.8416
# Epoch 9: val_f1_score improved from 0.54595 to 0.62741, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2274 - accuracy: 0.8413 - f1_score: 0.8396 - val_loss: 0.3565 - val_accuracy: 0.6420 - val_f1_score: 0.6274 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2109 - accuracy: 0.8500 - f1_score: 0.8477
# Epoch 10: val_f1_score did not improve from 0.62741
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2202 - accuracy: 0.8443 - f1_score: 0.8393 - val_loss: 0.2583 - val_accuracy: 0.7407 - val_f1_score: 0.5228 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.8263 - f1_score: 0.8237
# Epoch 11: val_f1_score did not improve from 0.62741
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2368 - accuracy: 0.8263 - f1_score: 0.8237 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2246 - accuracy: 0.8417 - f1_score: 0.8398
# Epoch 12: val_f1_score did not improve from 0.62741
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2235 - accuracy: 0.8423 - f1_score: 0.8408 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2069 - accuracy: 0.8521 - f1_score: 0.8512
# Epoch 13: val_f1_score did not improve from 0.62741
# 16/16 [==============================] - 1s 44ms/step - loss: 0.2054 - accuracy: 0.8523 - f1_score: 0.8513 - val_loss: 0.2569 - val_accuracy: 0.7438 - val_f1_score: 0.5990 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2011 - accuracy: 0.8594 - f1_score: 0.8580
# Epoch 14: val_f1_score did not improve from 0.62741
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2021 - accuracy: 0.8583 - f1_score: 0.8564 - val_loss: 0.2414 - val_accuracy: 0.7593 - val_f1_score: 0.5140 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1821 - accuracy: 0.8708 - f1_score: 0.8697
# Epoch 15: val_f1_score improved from 0.62741 to 0.71042, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1824 - accuracy: 0.8713 - f1_score: 0.8702 - val_loss: 0.2703 - val_accuracy: 0.7284 - val_f1_score: 0.7104 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2228 - accuracy: 0.8385 - f1_score: 0.8364
# Epoch 16: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2242 - accuracy: 0.8383 - f1_score: 0.8362 - val_loss: 0.2400 - val_accuracy: 0.7623 - val_f1_score: 0.5464 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2275 - accuracy: 0.8375 - f1_score: 0.8360
# Epoch 17: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2262 - accuracy: 0.8383 - f1_score: 0.8372 - val_loss: 0.2242 - val_accuracy: 0.7809 - val_f1_score: 0.6259 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1910 - accuracy: 0.8646 - f1_score: 0.8634
# Epoch 18: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1887 - accuracy: 0.8663 - f1_score: 0.8660 - val_loss: 0.2536 - val_accuracy: 0.7469 - val_f1_score: 0.4743 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1603 - accuracy: 0.8844 - f1_score: 0.8839
# Epoch 19: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1686 - accuracy: 0.8782 - f1_score: 0.8747 - val_loss: 0.2543 - val_accuracy: 0.7469 - val_f1_score: 0.5784 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1548 - accuracy: 0.8917 - f1_score: 0.8911
# Epoch 20: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1585 - accuracy: 0.8882 - f1_score: 0.8859 - val_loss: 0.3041 - val_accuracy: 0.6944 - val_f1_score: 0.6011 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2013 - accuracy: 0.8573 - f1_score: 0.8560
# Epoch 21: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1969 - accuracy: 0.8603 - f1_score: 0.8605 - val_loss: 0.4250 - val_accuracy: 0.5772 - val_f1_score: 0.5900 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1664 - accuracy: 0.8823 - f1_score: 0.8816
# Epoch 22: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1714 - accuracy: 0.8792 - f1_score: 0.8771 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.4398 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1982 - accuracy: 0.8604 - f1_score: 0.8589
# Epoch 23: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1967 - accuracy: 0.8603 - f1_score: 0.8585 - val_loss: 0.2560 - val_accuracy: 0.7438 - val_f1_score: 0.4769 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1906 - accuracy: 0.8615 - f1_score: 0.8603
# Epoch 24: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1969 - accuracy: 0.8573 - f1_score: 0.8542 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1592 - accuracy: 0.8833 - f1_score: 0.8826
# Epoch 25: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1621 - accuracy: 0.8812 - f1_score: 0.8793 - val_loss: 0.2554 - val_accuracy: 0.7438 - val_f1_score: 0.4527 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.8962 - f1_score: 0.8951
# Epoch 26: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1486 - accuracy: 0.8962 - f1_score: 0.8951 - val_loss: 0.2624 - val_accuracy: 0.7407 - val_f1_score: 0.6236 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1393 - accuracy: 0.8990 - f1_score: 0.8981
# Epoch 27: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1378 - accuracy: 0.9002 - f1_score: 0.9000 - val_loss: 0.2587 - val_accuracy: 0.7407 - val_f1_score: 0.4445 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.8872 - f1_score: 0.8862
# Epoch 28: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1560 - accuracy: 0.8872 - f1_score: 0.8862 - val_loss: 0.2557 - val_accuracy: 0.7438 - val_f1_score: 0.4458 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1570 - accuracy: 0.8896 - f1_score: 0.8880
# Epoch 29: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1544 - accuracy: 0.8912 - f1_score: 0.8904 - val_loss: 0.2606 - val_accuracy: 0.7407 - val_f1_score: 0.5808 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.8902 - f1_score: 0.8907
# Epoch 30: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1517 - accuracy: 0.8902 - f1_score: 0.8907 - val_loss: 0.2796 - val_accuracy: 0.7191 - val_f1_score: 0.5279 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1542 - accuracy: 0.8885 - f1_score: 0.8875
# Epoch 31: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1682 - accuracy: 0.8802 - f1_score: 0.8749 - val_loss: 0.2593 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1657 - accuracy: 0.8813 - f1_score: 0.8803
# Epoch 32: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1640 - accuracy: 0.8822 - f1_score: 0.8818 - val_loss: 0.2562 - val_accuracy: 0.7438 - val_f1_score: 0.4458 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1405 - accuracy: 0.9000 - f1_score: 0.8990
# Epoch 33: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1436 - accuracy: 0.8982 - f1_score: 0.8964 - val_loss: 0.2588 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1293 - accuracy: 0.9083 - f1_score: 0.9079
# Epoch 34: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1336 - accuracy: 0.9042 - f1_score: 0.9013 - val_loss: 0.2524 - val_accuracy: 0.7531 - val_f1_score: 0.6294 - lr: 0.0010
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1499 - accuracy: 0.8917 - f1_score: 0.8902
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 35: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1517 - accuracy: 0.8902 - f1_score: 0.8881 - val_loss: 0.2594 - val_accuracy: 0.7438 - val_f1_score: 0.5613 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1426 - accuracy: 0.8969 - f1_score: 0.8962
# Epoch 36: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1425 - accuracy: 0.8972 - f1_score: 0.8965 - val_loss: 0.2623 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 5.0000e-04
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1318 - accuracy: 0.9052 - f1_score: 0.9043
# Epoch 37: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1323 - accuracy: 0.9052 - f1_score: 0.9044 - val_loss: 0.2497 - val_accuracy: 0.7500 - val_f1_score: 0.5392 - lr: 5.0000e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1282 - accuracy: 0.9083 - f1_score: 0.9064
# Epoch 38: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1273 - accuracy: 0.9092 - f1_score: 0.9077 - val_loss: 0.2592 - val_accuracy: 0.7438 - val_f1_score: 0.6382 - lr: 5.0000e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1295 - accuracy: 0.9073 - f1_score: 0.9060
# Epoch 39: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1299 - accuracy: 0.9072 - f1_score: 0.9059 - val_loss: 0.2536 - val_accuracy: 0.7469 - val_f1_score: 0.5210 - lr: 5.0000e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1011 - accuracy: 0.9271 - f1_score: 0.9266
# Epoch 40: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1035 - accuracy: 0.9251 - f1_score: 0.9236 - val_loss: 0.3019 - val_accuracy: 0.6975 - val_f1_score: 0.6033 - lr: 5.0000e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1055 - accuracy: 0.9260 - f1_score: 0.9254
# Epoch 41: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1071 - accuracy: 0.9242 - f1_score: 0.9220 - val_loss: 0.2626 - val_accuracy: 0.7377 - val_f1_score: 0.5960 - lr: 5.0000e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1122 - accuracy: 0.9187 - f1_score: 0.9180
# Epoch 42: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1118 - accuracy: 0.9192 - f1_score: 0.9186 - val_loss: 0.2613 - val_accuracy: 0.7377 - val_f1_score: 0.6381 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9232 - f1_score: 0.9231
# Epoch 43: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1078 - accuracy: 0.9232 - f1_score: 0.9231 - val_loss: 0.6426 - val_accuracy: 0.3580 - val_f1_score: 0.3692 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1067 - accuracy: 0.9240 - f1_score: 0.9234
# Epoch 44: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1076 - accuracy: 0.9232 - f1_score: 0.9222 - val_loss: 0.3804 - val_accuracy: 0.6142 - val_f1_score: 0.6508 - lr: 5.0000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1074 - accuracy: 0.9229 - f1_score: 0.9218
# Epoch 45: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1085 - accuracy: 0.9222 - f1_score: 0.9207 - val_loss: 0.5181 - val_accuracy: 0.4753 - val_f1_score: 0.5545 - lr: 5.0000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1051 - accuracy: 0.9250 - f1_score: 0.9240
# Epoch 46: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1032 - accuracy: 0.9261 - f1_score: 0.9257 - val_loss: 0.2646 - val_accuracy: 0.7346 - val_f1_score: 0.6126 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1066 - accuracy: 0.9219 - f1_score: 0.9212
# Epoch 47: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1035 - accuracy: 0.9242 - f1_score: 0.9246 - val_loss: 0.3533 - val_accuracy: 0.6389 - val_f1_score: 0.6735 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9271 - f1_score: 0.9277
# Epoch 48: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1017 - accuracy: 0.9271 - f1_score: 0.9277 - val_loss: 0.4500 - val_accuracy: 0.5494 - val_f1_score: 0.5701 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0941 - accuracy: 0.9312 - f1_score: 0.9308
# Epoch 49: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0929 - accuracy: 0.9321 - f1_score: 0.9321 - val_loss: 0.2512 - val_accuracy: 0.7469 - val_f1_score: 0.6201 - lr: 5.0000e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0923 - accuracy: 0.9344 - f1_score: 0.9331
# Epoch 50: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0917 - accuracy: 0.9351 - f1_score: 0.9343 - val_loss: 0.2491 - val_accuracy: 0.7531 - val_f1_score: 0.5423 - lr: 5.0000e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0934 - accuracy: 0.9312 - f1_score: 0.9303
# Epoch 51: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0925 - accuracy: 0.9321 - f1_score: 0.9316 - val_loss: 0.4528 - val_accuracy: 0.5463 - val_f1_score: 0.5686 - lr: 5.0000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0979 - accuracy: 0.9271 - f1_score: 0.9265
# Epoch 52: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0968 - accuracy: 0.9281 - f1_score: 0.9281 - val_loss: 0.2916 - val_accuracy: 0.7160 - val_f1_score: 0.6207 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0939 - accuracy: 0.9323 - f1_score: 0.9313
# Epoch 53: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0958 - accuracy: 0.9311 - f1_score: 0.9297 - val_loss: 0.2434 - val_accuracy: 0.7562 - val_f1_score: 0.6152 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0938 - accuracy: 0.9312 - f1_score: 0.9300
# Epoch 54: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0940 - accuracy: 0.9311 - f1_score: 0.9299 - val_loss: 0.2622 - val_accuracy: 0.7377 - val_f1_score: 0.6275 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0868 - accuracy: 0.9365 - f1_score: 0.9360
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 55: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0867 - accuracy: 0.9371 - f1_score: 0.9368 - val_loss: 0.2488 - val_accuracy: 0.7531 - val_f1_score: 0.6033 - lr: 5.0000e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0854 - accuracy: 0.9396 - f1_score: 0.9388
# Epoch 56: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0859 - accuracy: 0.9391 - f1_score: 0.9379 - val_loss: 0.3413 - val_accuracy: 0.6667 - val_f1_score: 0.6875 - lr: 2.5000e-04
# Epoch 57/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9461 - f1_score: 0.9467
# Epoch 57: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0754 - accuracy: 0.9461 - f1_score: 0.9467 - val_loss: 0.3419 - val_accuracy: 0.6574 - val_f1_score: 0.6791 - lr: 2.5000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0750 - accuracy: 0.9469 - f1_score: 0.9462
# Epoch 58: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0724 - accuracy: 0.9491 - f1_score: 0.9495 - val_loss: 0.2925 - val_accuracy: 0.7068 - val_f1_score: 0.6146 - lr: 2.5000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0931 - accuracy: 0.9344 - f1_score: 0.9334
# Epoch 59: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0930 - accuracy: 0.9341 - f1_score: 0.9330 - val_loss: 0.2374 - val_accuracy: 0.7623 - val_f1_score: 0.5944 - lr: 2.5000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0842 - accuracy: 0.9396 - f1_score: 0.9383
# Epoch 60: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0841 - accuracy: 0.9391 - f1_score: 0.9376 - val_loss: 0.2605 - val_accuracy: 0.7407 - val_f1_score: 0.6116 - lr: 2.5000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0700 - accuracy: 0.9479 - f1_score: 0.9473
# Epoch 61: val_f1_score did not improve from 0.71042
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0698 - accuracy: 0.9481 - f1_score: 0.9476 - val_loss: 0.2836 - val_accuracy: 0.7130 - val_f1_score: 0.5961 - lr: 2.5000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0764 - accuracy: 0.9469 - f1_score: 0.9461
# Epoch 62: val_f1_score improved from 0.71042 to 0.71614, saving model to best_model.h5
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0768 - accuracy: 0.9461 - f1_score: 0.9450 - val_loss: 0.2990 - val_accuracy: 0.7037 - val_f1_score: 0.7161 - lr: 2.5000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0737 - accuracy: 0.9479 - f1_score: 0.9472
# Epoch 63: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0752 - accuracy: 0.9471 - f1_score: 0.9459 - val_loss: 0.5618 - val_accuracy: 0.4383 - val_f1_score: 0.4793 - lr: 2.5000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0790 - accuracy: 0.9448 - f1_score: 0.9435
# Epoch 64: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0796 - accuracy: 0.9441 - f1_score: 0.9426 - val_loss: 0.5657 - val_accuracy: 0.4352 - val_f1_score: 0.4767 - lr: 2.5000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0662 - accuracy: 0.9521 - f1_score: 0.9517
# Epoch 65: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0701 - accuracy: 0.9491 - f1_score: 0.9472 - val_loss: 0.2665 - val_accuracy: 0.7315 - val_f1_score: 0.6106 - lr: 2.5000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0691 - accuracy: 0.9521 - f1_score: 0.9515
# Epoch 66: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0699 - accuracy: 0.9511 - f1_score: 0.9498 - val_loss: 0.2675 - val_accuracy: 0.7315 - val_f1_score: 0.6123 - lr: 2.5000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0665 - accuracy: 0.9521 - f1_score: 0.9514
# Epoch 67: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0672 - accuracy: 0.9511 - f1_score: 0.9500 - val_loss: 0.4733 - val_accuracy: 0.5309 - val_f1_score: 0.5567 - lr: 2.5000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0599 - accuracy: 0.9563 - f1_score: 0.9557
# Epoch 68: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0618 - accuracy: 0.9551 - f1_score: 0.9540 - val_loss: 0.6427 - val_accuracy: 0.3549 - val_f1_score: 0.3170 - lr: 2.5000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0754 - accuracy: 0.9469 - f1_score: 0.9462
# Epoch 69: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0765 - accuracy: 0.9461 - f1_score: 0.9451 - val_loss: 0.2917 - val_accuracy: 0.7099 - val_f1_score: 0.6130 - lr: 2.5000e-04
# Epoch 70/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9571 - f1_score: 0.9554
# Epoch 70: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0587 - accuracy: 0.9571 - f1_score: 0.9554 - val_loss: 0.2738 - val_accuracy: 0.7284 - val_f1_score: 0.6166 - lr: 2.5000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0593 - accuracy: 0.9583 - f1_score: 0.9578
# Epoch 71: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0616 - accuracy: 0.9561 - f1_score: 0.9543 - val_loss: 0.2878 - val_accuracy: 0.7130 - val_f1_score: 0.6066 - lr: 2.5000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0616 - accuracy: 0.9563 - f1_score: 0.9555
# Epoch 72: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0624 - accuracy: 0.9561 - f1_score: 0.9553 - val_loss: 0.3545 - val_accuracy: 0.6481 - val_f1_score: 0.6789 - lr: 2.5000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0835 - accuracy: 0.9385 - f1_score: 0.9370
# Epoch 73: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0829 - accuracy: 0.9391 - f1_score: 0.9379 - val_loss: 0.2487 - val_accuracy: 0.7500 - val_f1_score: 0.5255 - lr: 2.5000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0691 - accuracy: 0.9510 - f1_score: 0.9507
# Epoch 74: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0676 - accuracy: 0.9521 - f1_score: 0.9523 - val_loss: 0.2489 - val_accuracy: 0.7531 - val_f1_score: 0.5316 - lr: 2.5000e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0646 - accuracy: 0.9542 - f1_score: 0.9538
# Epoch 75: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0644 - accuracy: 0.9541 - f1_score: 0.9536 - val_loss: 0.3068 - val_accuracy: 0.6914 - val_f1_score: 0.6038 - lr: 2.5000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0606 - accuracy: 0.9573 - f1_score: 0.9570
# Epoch 76: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0593 - accuracy: 0.9581 - f1_score: 0.9582 - val_loss: 0.3292 - val_accuracy: 0.6728 - val_f1_score: 0.5906 - lr: 2.5000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0582 - accuracy: 0.9583 - f1_score: 0.9577
# Epoch 77: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0582 - accuracy: 0.9591 - f1_score: 0.9588 - val_loss: 0.3082 - val_accuracy: 0.6975 - val_f1_score: 0.5927 - lr: 2.5000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0641 - accuracy: 0.9552 - f1_score: 0.9544
# Epoch 78: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0680 - accuracy: 0.9521 - f1_score: 0.9497 - val_loss: 0.3653 - val_accuracy: 0.6327 - val_f1_score: 0.6688 - lr: 2.5000e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0609 - accuracy: 0.9563 - f1_score: 0.9559
# Epoch 79: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0583 - accuracy: 0.9581 - f1_score: 0.9587 - val_loss: 0.3338 - val_accuracy: 0.6636 - val_f1_score: 0.6860 - lr: 2.5000e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0586 - accuracy: 0.9563 - f1_score: 0.9558
# Epoch 80: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0589 - accuracy: 0.9561 - f1_score: 0.9555 - val_loss: 0.2688 - val_accuracy: 0.7284 - val_f1_score: 0.6028 - lr: 2.5000e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0515 - accuracy: 0.9635 - f1_score: 0.9630
# Epoch 81: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0523 - accuracy: 0.9631 - f1_score: 0.9622 - val_loss: 0.3466 - val_accuracy: 0.6512 - val_f1_score: 0.5897 - lr: 2.5000e-04
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0529 - accuracy: 0.9615 - f1_score: 0.9611
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 82: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0544 - accuracy: 0.9601 - f1_score: 0.9590 - val_loss: 0.5163 - val_accuracy: 0.4815 - val_f1_score: 0.5185 - lr: 2.5000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0591 - accuracy: 0.9583 - f1_score: 0.9577
# Epoch 83: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0568 - accuracy: 0.9601 - f1_score: 0.9603 - val_loss: 0.4205 - val_accuracy: 0.5741 - val_f1_score: 0.6275 - lr: 1.2500e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0494 - accuracy: 0.9646 - f1_score: 0.9640
# Epoch 84: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0491 - accuracy: 0.9651 - f1_score: 0.9648 - val_loss: 0.3635 - val_accuracy: 0.6420 - val_f1_score: 0.5832 - lr: 1.2500e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0504 - accuracy: 0.9646 - f1_score: 0.9640
# Epoch 85: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0521 - accuracy: 0.9631 - f1_score: 0.9617 - val_loss: 0.3551 - val_accuracy: 0.6481 - val_f1_score: 0.5877 - lr: 1.2500e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0443 - accuracy: 0.9688 - f1_score: 0.9685
# Epoch 86: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0481 - accuracy: 0.9661 - f1_score: 0.9646 - val_loss: 0.3988 - val_accuracy: 0.5988 - val_f1_score: 0.5516 - lr: 1.2500e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0473 - accuracy: 0.9667 - f1_score: 0.9663
# Epoch 87: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0467 - accuracy: 0.9671 - f1_score: 0.9669 - val_loss: 0.4129 - val_accuracy: 0.5833 - val_f1_score: 0.5404 - lr: 1.2500e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0491 - accuracy: 0.9646 - f1_score: 0.9641
# Epoch 88: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0485 - accuracy: 0.9651 - f1_score: 0.9649 - val_loss: 0.3099 - val_accuracy: 0.7006 - val_f1_score: 0.6165 - lr: 1.2500e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0502 - accuracy: 0.9646 - f1_score: 0.9636
# Epoch 89: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0481 - accuracy: 0.9661 - f1_score: 0.9659 - val_loss: 0.2884 - val_accuracy: 0.7099 - val_f1_score: 0.6090 - lr: 1.2500e-04
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9681 - f1_score: 0.9670
# Epoch 90: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0457 - accuracy: 0.9681 - f1_score: 0.9670 - val_loss: 0.2641 - val_accuracy: 0.7315 - val_f1_score: 0.5988 - lr: 1.2500e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0474 - accuracy: 0.9656 - f1_score: 0.9652
# Epoch 91: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0483 - accuracy: 0.9651 - f1_score: 0.9644 - val_loss: 0.2669 - val_accuracy: 0.7284 - val_f1_score: 0.6013 - lr: 1.2500e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0462 - accuracy: 0.9667 - f1_score: 0.9661
# Epoch 92: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0487 - accuracy: 0.9651 - f1_score: 0.9634 - val_loss: 0.2715 - val_accuracy: 0.7284 - val_f1_score: 0.6116 - lr: 1.2500e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0464 - accuracy: 0.9667 - f1_score: 0.9660
# Epoch 93: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0446 - accuracy: 0.9681 - f1_score: 0.9682 - val_loss: 0.4118 - val_accuracy: 0.5833 - val_f1_score: 0.6336 - lr: 1.2500e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0494 - accuracy: 0.9656 - f1_score: 0.9654
# Epoch 94: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0485 - accuracy: 0.9661 - f1_score: 0.9660 - val_loss: 0.2822 - val_accuracy: 0.7191 - val_f1_score: 0.6157 - lr: 1.2500e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0435 - accuracy: 0.9688 - f1_score: 0.9686
# Epoch 95: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0446 - accuracy: 0.9681 - f1_score: 0.9675 - val_loss: 0.2916 - val_accuracy: 0.7130 - val_f1_score: 0.6090 - lr: 1.2500e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0398 - accuracy: 0.9719 - f1_score: 0.9715
# Epoch 96: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0451 - accuracy: 0.9681 - f1_score: 0.9658 - val_loss: 0.2949 - val_accuracy: 0.7099 - val_f1_score: 0.6075 - lr: 1.2500e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0499 - accuracy: 0.9646 - f1_score: 0.9639
# Epoch 97: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0478 - accuracy: 0.9661 - f1_score: 0.9662 - val_loss: 0.3118 - val_accuracy: 0.6883 - val_f1_score: 0.5996 - lr: 1.2500e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0483 - accuracy: 0.9667 - f1_score: 0.9657
# Epoch 98: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0509 - accuracy: 0.9651 - f1_score: 0.9632 - val_loss: 0.2905 - val_accuracy: 0.7099 - val_f1_score: 0.6065 - lr: 1.2500e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0423 - accuracy: 0.9698 - f1_score: 0.9695
# Epoch 99: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0421 - accuracy: 0.9701 - f1_score: 0.9699 - val_loss: 0.2999 - val_accuracy: 0.7037 - val_f1_score: 0.6043 - lr: 1.2500e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9677 - f1_score: 0.9675
# Epoch 100: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0468 - accuracy: 0.9661 - f1_score: 0.9650 - val_loss: 0.3306 - val_accuracy: 0.6698 - val_f1_score: 0.5885 - lr: 1.2500e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0472 - accuracy: 0.9656 - f1_score: 0.9651
# Epoch 101: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0465 - accuracy: 0.9661 - f1_score: 0.9658 - val_loss: 0.3573 - val_accuracy: 0.6512 - val_f1_score: 0.5872 - lr: 1.2500e-04
# Epoch 102/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9681 - f1_score: 0.9683
# Epoch 102: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 102: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0453 - accuracy: 0.9681 - f1_score: 0.9683 - val_loss: 0.3591 - val_accuracy: 0.6420 - val_f1_score: 0.5788 - lr: 1.2500e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0410 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 103: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0431 - accuracy: 0.9691 - f1_score: 0.9679 - val_loss: 0.3427 - val_accuracy: 0.6512 - val_f1_score: 0.5819 - lr: 6.2500e-05
# Epoch 104/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9631 - f1_score: 0.9633
# Epoch 104: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0496 - accuracy: 0.9631 - f1_score: 0.9633 - val_loss: 0.3151 - val_accuracy: 0.6883 - val_f1_score: 0.5973 - lr: 6.2500e-05
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0411 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 105: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0420 - accuracy: 0.9701 - f1_score: 0.9694 - val_loss: 0.2950 - val_accuracy: 0.7037 - val_f1_score: 0.6003 - lr: 6.2500e-05
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0488 - accuracy: 0.9635 - f1_score: 0.9630
# Epoch 106: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0482 - accuracy: 0.9641 - f1_score: 0.9639 - val_loss: 0.2775 - val_accuracy: 0.7284 - val_f1_score: 0.6079 - lr: 6.2500e-05
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0404 - accuracy: 0.9708 - f1_score: 0.9704
# Epoch 107: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0417 - accuracy: 0.9701 - f1_score: 0.9690 - val_loss: 0.2915 - val_accuracy: 0.7130 - val_f1_score: 0.6072 - lr: 6.2500e-05
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0422 - accuracy: 0.9698 - f1_score: 0.9694
# Epoch 108: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0434 - accuracy: 0.9691 - f1_score: 0.9683 - val_loss: 0.2849 - val_accuracy: 0.7222 - val_f1_score: 0.6111 - lr: 6.2500e-05
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0458 - accuracy: 0.9677 - f1_score: 0.9670
# Epoch 109: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0451 - accuracy: 0.9681 - f1_score: 0.9675 - val_loss: 0.2605 - val_accuracy: 0.7407 - val_f1_score: 0.5996 - lr: 6.2500e-05
# Epoch 110/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9701 - f1_score: 0.9700
# Epoch 110: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0418 - accuracy: 0.9701 - f1_score: 0.9700 - val_loss: 0.2605 - val_accuracy: 0.7438 - val_f1_score: 0.6002 - lr: 6.2500e-05
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0412 - accuracy: 0.9698 - f1_score: 0.9696
# Epoch 111: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0423 - accuracy: 0.9691 - f1_score: 0.9685 - val_loss: 0.2654 - val_accuracy: 0.7346 - val_f1_score: 0.6007 - lr: 6.2500e-05
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0459 - accuracy: 0.9667 - f1_score: 0.9661
# Epoch 112: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0440 - accuracy: 0.9681 - f1_score: 0.9683 - val_loss: 0.2746 - val_accuracy: 0.7253 - val_f1_score: 0.5998 - lr: 6.2500e-05
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0435 - accuracy: 0.9688 - f1_score: 0.9682
# Epoch 113: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0429 - accuracy: 0.9691 - f1_score: 0.9686 - val_loss: 0.2779 - val_accuracy: 0.7222 - val_f1_score: 0.6009 - lr: 6.2500e-05
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0500 - accuracy: 0.9635 - f1_score: 0.9627
# Epoch 114: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0493 - accuracy: 0.9641 - f1_score: 0.9635 - val_loss: 0.2692 - val_accuracy: 0.7315 - val_f1_score: 0.6058 - lr: 6.2500e-05
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0476 - accuracy: 0.9656 - f1_score: 0.9646
# Epoch 115: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0456 - accuracy: 0.9671 - f1_score: 0.9668 - val_loss: 0.3071 - val_accuracy: 0.6944 - val_f1_score: 0.5990 - lr: 6.2500e-05
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0393 - accuracy: 0.9719 - f1_score: 0.9715
# Epoch 116: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0405 - accuracy: 0.9711 - f1_score: 0.9703 - val_loss: 0.3425 - val_accuracy: 0.6636 - val_f1_score: 0.5887 - lr: 6.2500e-05
# Epoch 117/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9681 - f1_score: 0.9679
# Epoch 117: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0444 - accuracy: 0.9681 - f1_score: 0.9679 - val_loss: 0.3326 - val_accuracy: 0.6698 - val_f1_score: 0.5901 - lr: 6.2500e-05
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0448 - accuracy: 0.9667 - f1_score: 0.9657
# Epoch 118: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0443 - accuracy: 0.9671 - f1_score: 0.9664 - val_loss: 0.3111 - val_accuracy: 0.6883 - val_f1_score: 0.5943 - lr: 6.2500e-05
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0433 - accuracy: 0.9698 - f1_score: 0.9694
# Epoch 119: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0441 - accuracy: 0.9691 - f1_score: 0.9683 - val_loss: 0.3063 - val_accuracy: 0.6914 - val_f1_score: 0.5857 - lr: 6.2500e-05
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0397 - accuracy: 0.9719 - f1_score: 0.9716
# Epoch 120: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0408 - accuracy: 0.9711 - f1_score: 0.9704 - val_loss: 0.2974 - val_accuracy: 0.7037 - val_f1_score: 0.5911 - lr: 6.2500e-05
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0466 - accuracy: 0.9677 - f1_score: 0.9673
# Epoch 121: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0454 - accuracy: 0.9681 - f1_score: 0.9677 - val_loss: 0.2834 - val_accuracy: 0.7253 - val_f1_score: 0.6058 - lr: 6.2500e-05
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0430 - accuracy: 0.9698 - f1_score: 0.9693
# Epoch 122: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 122: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0430 - accuracy: 0.9701 - f1_score: 0.9697 - val_loss: 0.2490 - val_accuracy: 0.7531 - val_f1_score: 0.6079 - lr: 6.2500e-05
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0420 - accuracy: 0.9698 - f1_score: 0.9696
# Epoch 123: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0417 - accuracy: 0.9701 - f1_score: 0.9700 - val_loss: 0.2507 - val_accuracy: 0.7500 - val_f1_score: 0.5992 - lr: 3.1250e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0385 - accuracy: 0.9729 - f1_score: 0.9725
# Epoch 124: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0408 - accuracy: 0.9711 - f1_score: 0.9697 - val_loss: 0.2523 - val_accuracy: 0.7500 - val_f1_score: 0.5992 - lr: 3.1250e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0406 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 125: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0401 - accuracy: 0.9711 - f1_score: 0.9709 - val_loss: 0.2506 - val_accuracy: 0.7500 - val_f1_score: 0.5992 - lr: 3.1250e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0393 - accuracy: 0.9719 - f1_score: 0.9715
# Epoch 126: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0404 - accuracy: 0.9711 - f1_score: 0.9703 - val_loss: 0.2507 - val_accuracy: 0.7531 - val_f1_score: 0.6065 - lr: 3.1250e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0400 - accuracy: 0.9719 - f1_score: 0.9717
# Epoch 127: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0430 - accuracy: 0.9701 - f1_score: 0.9689 - val_loss: 0.2511 - val_accuracy: 0.7500 - val_f1_score: 0.6020 - lr: 3.1250e-05
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0390 - accuracy: 0.9719 - f1_score: 0.9716
# Epoch 128: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0413 - accuracy: 0.9701 - f1_score: 0.9688 - val_loss: 0.2555 - val_accuracy: 0.7469 - val_f1_score: 0.6042 - lr: 3.1250e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0451 - accuracy: 0.9688 - f1_score: 0.9683
# Epoch 129: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0432 - accuracy: 0.9701 - f1_score: 0.9703 - val_loss: 0.2648 - val_accuracy: 0.7377 - val_f1_score: 0.6058 - lr: 3.1250e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0446 - accuracy: 0.9688 - f1_score: 0.9685
# Epoch 130: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0428 - accuracy: 0.9701 - f1_score: 0.9704 - val_loss: 0.2664 - val_accuracy: 0.7315 - val_f1_score: 0.6077 - lr: 3.1250e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0424 - accuracy: 0.9698 - f1_score: 0.9691
# Epoch 131: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0435 - accuracy: 0.9691 - f1_score: 0.9680 - val_loss: 0.2669 - val_accuracy: 0.7377 - val_f1_score: 0.6125 - lr: 3.1250e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0429 - accuracy: 0.9688 - f1_score: 0.9684
# Epoch 132: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0411 - accuracy: 0.9701 - f1_score: 0.9704 - val_loss: 0.2695 - val_accuracy: 0.7346 - val_f1_score: 0.6101 - lr: 3.1250e-05
# Epoch 133/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0397 - accuracy: 0.9719 - f1_score: 0.9714
# Epoch 133: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0409 - accuracy: 0.9711 - f1_score: 0.9702 - val_loss: 0.2738 - val_accuracy: 0.7284 - val_f1_score: 0.6081 - lr: 3.1250e-05
# Epoch 134/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0404 - accuracy: 0.9719 - f1_score: 0.9714
# Epoch 134: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0415 - accuracy: 0.9711 - f1_score: 0.9702 - val_loss: 0.2767 - val_accuracy: 0.7253 - val_f1_score: 0.6058 - lr: 3.1250e-05
# Epoch 135/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0400 - accuracy: 0.9719 - f1_score: 0.9716
# Epoch 135: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0413 - accuracy: 0.9711 - f1_score: 0.9704 - val_loss: 0.2805 - val_accuracy: 0.7191 - val_f1_score: 0.6015 - lr: 3.1250e-05
# Epoch 136/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9701 - f1_score: 0.9696
# Epoch 136: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0420 - accuracy: 0.9701 - f1_score: 0.9696 - val_loss: 0.2819 - val_accuracy: 0.7191 - val_f1_score: 0.6015 - lr: 3.1250e-05
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0422 - accuracy: 0.9698 - f1_score: 0.9695
# Epoch 137: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0405 - accuracy: 0.9711 - f1_score: 0.9714 - val_loss: 0.2922 - val_accuracy: 0.7037 - val_f1_score: 0.5927 - lr: 3.1250e-05
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0405 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 138: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0402 - accuracy: 0.9711 - f1_score: 0.9709 - val_loss: 0.2921 - val_accuracy: 0.7068 - val_f1_score: 0.5973 - lr: 3.1250e-05
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0432 - accuracy: 0.9688 - f1_score: 0.9684
# Epoch 139: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0426 - accuracy: 0.9691 - f1_score: 0.9688 - val_loss: 0.2930 - val_accuracy: 0.7068 - val_f1_score: 0.5973 - lr: 3.1250e-05
# Epoch 140/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0436 - accuracy: 0.9688 - f1_score: 0.9683
# Epoch 140: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0418 - accuracy: 0.9701 - f1_score: 0.9703 - val_loss: 0.2905 - val_accuracy: 0.7037 - val_f1_score: 0.5922 - lr: 3.1250e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0459 - accuracy: 0.9677 - f1_score: 0.9674
# Epoch 141: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0440 - accuracy: 0.9691 - f1_score: 0.9695 - val_loss: 0.3102 - val_accuracy: 0.6821 - val_f1_score: 0.5882 - lr: 3.1250e-05
# Epoch 142/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9671 - f1_score: 0.9666
# Epoch 142: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 142: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0467 - accuracy: 0.9671 - f1_score: 0.9666 - val_loss: 0.2966 - val_accuracy: 0.7037 - val_f1_score: 0.5982 - lr: 3.1250e-05
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0376 - accuracy: 0.9729 - f1_score: 0.9727
# Epoch 143: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0407 - accuracy: 0.9711 - f1_score: 0.9696 - val_loss: 0.2857 - val_accuracy: 0.7160 - val_f1_score: 0.5988 - lr: 1.5625e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0410 - accuracy: 0.9698 - f1_score: 0.9691
# Epoch 144: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0406 - accuracy: 0.9701 - f1_score: 0.9693 - val_loss: 0.2851 - val_accuracy: 0.7160 - val_f1_score: 0.5988 - lr: 1.5625e-05
# Epoch 145/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0422 - accuracy: 0.9698 - f1_score: 0.9695
# Epoch 145: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0404 - accuracy: 0.9711 - f1_score: 0.9714 - val_loss: 0.2818 - val_accuracy: 0.7160 - val_f1_score: 0.5949 - lr: 1.5625e-05
# Epoch 146/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0410 - accuracy: 0.9698 - f1_score: 0.9693
# Epoch 146: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0393 - accuracy: 0.9711 - f1_score: 0.9713 - val_loss: 0.2795 - val_accuracy: 0.7191 - val_f1_score: 0.5973 - lr: 1.5625e-05
# Epoch 147/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0405 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 147: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0415 - accuracy: 0.9701 - f1_score: 0.9694 - val_loss: 0.2811 - val_accuracy: 0.7160 - val_f1_score: 0.5949 - lr: 1.5625e-05
# Epoch 148/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0399 - accuracy: 0.9708 - f1_score: 0.9705
# Epoch 148: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0397 - accuracy: 0.9711 - f1_score: 0.9708 - val_loss: 0.2802 - val_accuracy: 0.7191 - val_f1_score: 0.5972 - lr: 1.5625e-05
# Epoch 149/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0428 - accuracy: 0.9698 - f1_score: 0.9694
# Epoch 149: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0423 - accuracy: 0.9701 - f1_score: 0.9698 - val_loss: 0.2792 - val_accuracy: 0.7191 - val_f1_score: 0.5972 - lr: 1.5625e-05
# Epoch 150/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0429 - accuracy: 0.9698 - f1_score: 0.9694
# Epoch 150: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0411 - accuracy: 0.9711 - f1_score: 0.9713 - val_loss: 0.2793 - val_accuracy: 0.7222 - val_f1_score: 0.5996 - lr: 1.5625e-05
# Epoch 151/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0448 - accuracy: 0.9688 - f1_score: 0.9683
# Epoch 151: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0441 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 0.2841 - val_accuracy: 0.7160 - val_f1_score: 0.5970 - lr: 1.5625e-05
# Epoch 152/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0398 - accuracy: 0.9708 - f1_score: 0.9705
# Epoch 152: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0408 - accuracy: 0.9701 - f1_score: 0.9692 - val_loss: 0.2840 - val_accuracy: 0.7160 - val_f1_score: 0.5970 - lr: 1.5625e-05
# Epoch 153/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0408 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 153: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0415 - accuracy: 0.9701 - f1_score: 0.9692 - val_loss: 0.2783 - val_accuracy: 0.7191 - val_f1_score: 0.5972 - lr: 1.5625e-05
# Epoch 154/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9701 - f1_score: 0.9694
# Epoch 154: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0414 - accuracy: 0.9701 - f1_score: 0.9694 - val_loss: 0.2747 - val_accuracy: 0.7222 - val_f1_score: 0.5996 - lr: 1.5625e-05
# Epoch 155/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0406 - accuracy: 0.9708 - f1_score: 0.9704
# Epoch 155: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0389 - accuracy: 0.9721 - f1_score: 0.9722 - val_loss: 0.2724 - val_accuracy: 0.7284 - val_f1_score: 0.6040 - lr: 1.5625e-05
# Epoch 156/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0445 - accuracy: 0.9688 - f1_score: 0.9680
# Epoch 156: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0427 - accuracy: 0.9701 - f1_score: 0.9700 - val_loss: 0.2690 - val_accuracy: 0.7284 - val_f1_score: 0.5998 - lr: 1.5625e-05
# Epoch 157/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0421 - accuracy: 0.9698 - f1_score: 0.9696
# Epoch 157: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0403 - accuracy: 0.9711 - f1_score: 0.9715 - val_loss: 0.2629 - val_accuracy: 0.7407 - val_f1_score: 0.6079 - lr: 1.5625e-05
# Epoch 158/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0429 - accuracy: 0.9698 - f1_score: 0.9694
# Epoch 158: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0412 - accuracy: 0.9711 - f1_score: 0.9713 - val_loss: 0.2646 - val_accuracy: 0.7377 - val_f1_score: 0.6061 - lr: 1.5625e-05
# Epoch 159/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0398 - accuracy: 0.9708 - f1_score: 0.9705
# Epoch 159: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0411 - accuracy: 0.9701 - f1_score: 0.9693 - val_loss: 0.2653 - val_accuracy: 0.7377 - val_f1_score: 0.6061 - lr: 1.5625e-05
# Epoch 160/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0400 - accuracy: 0.9719 - f1_score: 0.9713
# Epoch 160: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0412 - accuracy: 0.9711 - f1_score: 0.9701 - val_loss: 0.2638 - val_accuracy: 0.7377 - val_f1_score: 0.6061 - lr: 1.5625e-05
# Epoch 161/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0396 - accuracy: 0.9719 - f1_score: 0.9713
# Epoch 161: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0403 - accuracy: 0.9711 - f1_score: 0.9698 - val_loss: 0.2691 - val_accuracy: 0.7315 - val_f1_score: 0.6016 - lr: 1.5625e-05
# Epoch 162/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0408 - accuracy: 0.9708 - f1_score: 0.9704Restoring model weights from the end of the best epoch: 62.
#
# Epoch 162: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 162: val_f1_score did not improve from 0.71614
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0406 - accuracy: 0.9711 - f1_score: 0.9707 - val_loss: 0.2706 - val_accuracy: 0.7315 - val_f1_score: 0.6016 - lr: 1.5625e-05
# Epoch 162: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 7ms/step
# 0.7037037037037037

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7037037037037037
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.46      0.68      0.55        85
#            0       0.86      0.71      0.78       239
#
#     accuracy                           0.70       324
#    macro avg       0.66      0.70      0.66       324
# weighted avg       0.76      0.70      0.72       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 228 chiếm khoảng 70.37037037037037% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 58 chiếm khoảng 68.23529411764706% so với thực tế
