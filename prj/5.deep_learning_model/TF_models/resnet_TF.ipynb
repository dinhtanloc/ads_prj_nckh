# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
print(__script_dir)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)



from libs.lib import *
from libs.lib import ResNet
# from libs.resnet import *
# Out:
# d:\ads_test\prj\5.deep_learning_model
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        # y_train=oneHot(y_train)
        # y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 1) (324, 42) (324, 1)
# (656, 42) (656, 1) (324, 42) (324, 1)
# (1001, 42) (1001, 1) (324, 42) (324, 1)
# (1002, 42) (1002, 1) (324, 42) (324, 1)
# (355, 42) (355, 1) (324, 42) (324, 1)
# (656, 42) (656, 1) (324, 42) (324, 1)
# (656, 42) (656, 1) (324, 42) (324, 1)
# (1001, 42) (1001, 1) (324, 42) (324, 1)
# (1002, 42) (1002, 1) (324, 42) (324, 1)
# (355, 42) (355, 1) (324, 42) (324, 1)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
df=pd.read_excel(f'{save_dir}/df_minmax_labelencode.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_state  policy_csl  \
# 0                   1.0    0       0.599041             0           1
# 1                   0.0    2       0.536582             1           0
# 2                   1.0    0       0.259992             2           0
# 3                   1.0    0       0.903949             0           0
# 4                   1.0    0       0.468179             2           1
# ..                  ...  ...            ...           ...         ...
# 520                 1.0    1       0.591910             2           2
# 521                 1.0    1       0.530829             2           1
# 522                 1.0    0       0.083057             1           0
# 523                 0.0    2       0.789763             2           1
# 524                 1.0    0       0.320707             0           1
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                    1               0.156407               0     0.158095
# 1                    2               0.116057               0     0.189170
# 2                    2               0.629083               0     0.998102
# 3                    2               0.403313               0     0.011082
# 4                    1               0.617128               0     0.188861
# ..                 ...                    ...             ...          ...
# 520                  1               0.397140               0     0.913931
# 521                  2               0.759830               0     0.076691
# 522                  1               0.317237               0     0.241271
# 523                  0               0.358103               0     0.081482
# 524                  0               0.687795               0     0.160606
#
#      insured_sex  ...  auto_make  auto_model  auto_year  fraud_reported  \
# 0              1  ...          8          24          2               1
# 1              1  ...          6           6          1               1
# 2              0  ...         11          15          1               1
# 3              0  ...          5          14          0               1
# 4              1  ...         10           1          1               1
# ..           ...  ...        ...         ...        ...             ...
# 520            0  ...         10           3          0               1
# 521            1  ...         12          18          1               0
# 522            0  ...          0          23          0               0
# 523            1  ...          4          27          0               0
# 524            0  ...          5          16          2               0
#
#      day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 0                      21                       6                   1994
# 1                      11                       6                   2008
# 2                      29                       7                   1996
# 3                      28                       5                   2014
# 4                      17                      10                   2014
# ..                    ...                     ...                    ...
# 520                     7                      10                   1990
# 521                    15                       4                   2013
# 522                    16                      11                   2004
# 523                    29                       8                   1999
# 524                     6                       6                   2001
#
#      day_incident_date  month_incident_date  year_incident_date
# 0                    3                    1                2015
# 1                   16                    2                2015
# 2                   16                    1                2015
# 3                    1                    3                2015
# 4                   25                    1                2015
# ..                 ...                  ...                 ...
# 520                 13                    1                2015
# 521                 27                    1                2015
# 522                  6                    2                2015
# 523                 15                    2                2015
# 524                 29                    1                2015
#
# [525 rows x 43 columns]

# %%
category_columns=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['category_columns']
numeric_columns=dict(np.load(f'{exps_dir}/data/columns_dtype.npz',allow_pickle=True))['numeric_columns']
if 'fraud_reported' in category_columns:
    category_columns = np.delete(category_columns, np.where(category_columns == 'fraud_reported'))
category_columns
# Out:
# array(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage',
#        'bodily_injuries', 'witnesses', 'police_report_available',
#        'auto_make', 'auto_model', 'auto_year', 'high_week', 'high_hour'],
#       dtype='<U27')

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset
from torch import nn, optim
import torch.nn.functional as F

x_train_num  = torch.tensor(dict_data[data_order][0][numeric_columns].values, dtype=torch.float32)
x_train_cat  = torch.tensor(dict_data[data_order][0][category_columns].values, dtype=torch.int64)
y_train  = torch.tensor(dict_data[data_order][1].values, dtype=torch.int64)

x_test_num  = torch.tensor(dict_data[data_order][2][numeric_columns].values, dtype=torch.float32)
x_test_cat  = torch.tensor(dict_data[data_order][2][category_columns].values, dtype=torch.int64)
y_test  = torch.tensor(dict_data[data_order][3].values, dtype=torch.int64)

# Tạo TensorDataset cho tập huấn luyện và tập kiểm tra
train_dataset = TensorDataset(x_train_num, x_train_cat, y_train)
test_dataset = TensorDataset(x_test_num, x_test_cat, y_test)

# Tạo DataLoader cho tập huấn luyện và tập kiểm tra
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
if 'high_week' in df:
    print("'high_week' tồn tại trong DataFrame.")
else:
    print("'high_week' không tồn tại trong DataFrame.")
# Out:
# 'high_week' không tồn tại trong DataFrame.

# %%
# from TF_models.resnet import *
import torch
from torch.utils.data import DataLoader, TensorDataset
from torch import nn, optim
model = ResNet(
    d_numerical=len(numeric_columns),
    categories=[df[col].nunique() for col in category_columns],
    d_embedding=4,
    d=64,
    d_hidden_factor=1.0,
    n_layers=3,
    activation='reglu',
    normalization='batchnorm',
    hidden_dropout=0.1,
    residual_dropout=0.1,
    d_out=2  # Số lớp đầu ra cho phân loại nhị phân
)
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


# Hàm đánh giá mô hình trên tập kiểm tra
def evaluate(model, dataloader):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for x_num_batch, x_cat_batch, y_batch in dataloader:
            outputs = model(x_num_batch, x_cat_batch)
            loss = criterion(outputs, y_batch)
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
    return total_loss / len(dataloader), correct / total

def model_summary(model, input_size):
    summary = []
    summary.append(f"{'Layer (type)':<20} {'Output Shape':>20} {'Param #':>12}")
    summary.append("=" * 54)

    total_params = 0
    for name, module in model.named_children():
        output_shape = module(torch.zeros(*input_size)).shape
        num_params = sum(p.numel() for p in module.parameters() if p.requires_grad)
        total_params += num_params
        summary.append(f"{name:<20} {str(output_shape):>20} {num_params:>12}")

    summary.append("=" * 54)
    summary.append(f"Total Params: {total_params}")

    return "\n".join(summary)

# Sử dụng hàm model_summary để tạo tóm tắt của mô hình
input_size = (42, 1)  # input_size phải được thay đổi tương ứng với kích thước đầu vào của mô hình
print(model_summary(model, input_size))
# Training loop
epochs = 10
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for x_num, x_cat, y in train_loader:
        optimizer.zero_grad()
        outputs = model(x_num, x_cat)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss/len(train_loader)}")

print("Training complete")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\ads_test\.conda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File d:\ads_test\.conda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\ads_test\.conda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'high_week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 7
#       3 from torch.utils.data import DataLoader, TensorDataset
#       4 from torch import nn, optim
#       5 model = ResNet(
#       6     d_numerical=len(numeric_columns),
# ----> 7     categories=[df[col].nunique() for col in category_columns],
#       8     d_embedding=4,
#       9     d=64,
#      10     d_hidden_factor=1.0,
#      11     n_layers=3,
#      12     activation='reglu',
#      13     normalization='batchnorm',
#      14     hidden_dropout=0.1,
#      15     residual_dropout=0.1,
#      16     d_out=2  # Số lớp đầu ra cho phân loại nhị phân
#      17 )
#      18 # Define loss function and optimizer
#      19 criterion = nn.CrossEntropyLoss()
#
# Cell In[20], line 7, in <listcomp>(.0)
#       3 from torch.utils.data import DataLoader, TensorDataset
#       4 from torch import nn, optim
#       5 model = ResNet(
#       6     d_numerical=len(numeric_columns),
# ----> 7     categories=[df[col].nunique() for col in category_columns],
#       8     d_embedding=4,
#       9     d=64,
#      10     d_hidden_factor=1.0,
#      11     n_layers=3,
#      12     activation='reglu',
#      13     normalization='batchnorm',
#      14     hidden_dropout=0.1,
#      15     residual_dropout=0.1,
#      16     d_out=2  # Số lớp đầu ra cho phân loại nhị phân
#      17 )
#      18 # Define loss function and optimizer
#      19 criterion = nn.CrossEntropyLoss()
#
# File d:\ads_test\.conda\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File d:\ads_test\.conda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'high_week'

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_loss',  # Theo dõi val_loss
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from scikeras.wrappers import KerasClassifier 

lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.0001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d_6 (ZeroPadd  (None, 44, 1)                0         ['input_7[0][0]']
#  ing1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d_6[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation_78 (Activation)  (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 10, 64)               0         ['activation_78[0][0]']
#  g1D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d_6[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_79 (Activation)  (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_79[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_80 (Activation)  (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_80[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 96)               6240      ['max_pooling1d_6[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 96)               40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 96)               40        ['res2a_branch1[0][0]']
#  zation)
#
#  add_24 (Add)                (None, 10, 96)               0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_81 (Activation)  (None, 10, 96)               0         ['add_24[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 96)                9312      ['activation_81[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 96)                20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_82 (Activation)  (None, 5, 96)                0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_82[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 96)                20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_83 (Activation)  (None, 5, 96)                0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_83[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 192)               18624     ['activation_81[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 192)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 192)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_25 (Add)                (None, 5, 192)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_84 (Activation)  (None, 5, 192)               0         ['add_25[0][0]']
#
#  res4a_branch2a (Conv1D)     (None, 3, 192)               37056     ['activation_84[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 3, 192)               12        ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_85 (Activation)  (None, 3, 192)               0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)     (None, 3, 192)               110784    ['activation_85[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 3, 192)               12        ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_86 (Activation)  (None, 3, 192)               0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)     (None, 3, 256)               49408     ['activation_86[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 3, 256)               49408     ['activation_84[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 3, 256)               12        ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 3, 256)               12        ['res4a_branch1[0][0]']
#  zation)
#
#  add_26 (Add)                (None, 3, 256)               0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_87 (Activation)  (None, 3, 256)               0         ['add_26[0][0]']
#
#  res5a_branch2a (Conv1D)     (None, 2, 256)               65792     ['activation_87[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 2, 256)               8         ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_88 (Activation)  (None, 2, 256)               0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)     (None, 2, 256)               196864    ['activation_88[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 2, 256)               8         ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_89 (Activation)  (None, 2, 256)               0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)     (None, 2, 384)               98688     ['activation_89[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 2, 384)               98688     ['activation_87[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 2, 384)               8         ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 2, 384)               8         ['res5a_branch1[0][0]']
#  zation)
#
#  add_27 (Add)                (None, 2, 384)               0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_90 (Activation)  (None, 2, 384)               0         ['add_27[0][0]']
#
#  global_average_pooling1d_6  (None, 384)                  0         ['activation_90[0][0]']
#   (GlobalAveragePooling1D)
#
#  fc1000 (Dense)              (None, 2)                    770       ['global_average_pooling1d_6[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 797442 (3.04 MB)
# Trainable params: 797154 (3.04 MB)
# Non-trainable params: 288 (1.12 KB)
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 5.1161290322580646})
# Out:
# Epoch 1/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.9594 - accuracy: 0.4820 - f1_score: 0.4820
# Epoch 1: val_loss improved from inf to 0.05281, saving model to best_model.h5
# 16/16 [==============================] - 7s 53ms/step - loss: 0.8237 - accuracy: 0.4900 - f1_score: 0.4928 - val_loss: 0.0528 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1381 - accuracy: 0.5084 - f1_score: 0.5084
# Epoch 2: val_loss improved from 0.05281 to 0.04753, saving model to best_model.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1370 - accuracy: 0.5180 - f1_score: 0.5166 - val_loss: 0.0475 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1174 - accuracy: 0.6370 - f1_score: 0.6370
# Epoch 3: val_loss improved from 0.04753 to 0.04083, saving model to best_model.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1174 - accuracy: 0.6407 - f1_score: 0.6392 - val_loss: 0.0408 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1091 - accuracy: 0.6815 - f1_score: 0.6815
# Epoch 4: val_loss improved from 0.04083 to 0.03826, saving model to best_model.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1107 - accuracy: 0.6756 - f1_score: 0.6749 - val_loss: 0.0383 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 5/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1024 - accuracy: 0.7091 - f1_score: 0.7091
# Epoch 5: val_loss did not improve from 0.03826
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1030 - accuracy: 0.7126 - f1_score: 0.7121 - val_loss: 0.0423 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 0.0010
# Epoch 6/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0912 - accuracy: 0.7536 - f1_score: 0.7536
# Epoch 6: val_loss improved from 0.03826 to 0.03659, saving model to best_model.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0934 - accuracy: 0.7465 - f1_score: 0.7453 - val_loss: 0.0366 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 0.0010
# Epoch 7/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0830 - accuracy: 0.8065 - f1_score: 0.8065
# Epoch 7: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0828 - accuracy: 0.8054 - f1_score: 0.8045 - val_loss: 0.0375 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 0.0010
# Epoch 8/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0748 - accuracy: 0.8221 - f1_score: 0.8221
# Epoch 8: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0737 - accuracy: 0.8224 - f1_score: 0.8241 - val_loss: 0.0375 - val_accuracy: 0.6481 - val_f1_score: 0.7031 - lr: 0.0010
# Epoch 9/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0687 - accuracy: 0.8462 - f1_score: 0.8462
# Epoch 9: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0681 - accuracy: 0.8433 - f1_score: 0.8416 - val_loss: 0.0372 - val_accuracy: 0.6759 - val_f1_score: 0.6875 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.8772 - f1_score: 0.8773
# Epoch 10: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0550 - accuracy: 0.8772 - f1_score: 0.8773 - val_loss: 0.0390 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 0.0010
# Epoch 11/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0597 - accuracy: 0.8750 - f1_score: 0.8750
# Epoch 11: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0621 - accuracy: 0.8673 - f1_score: 0.8650 - val_loss: 0.0482 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 0.0010
# Epoch 12/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0649 - accuracy: 0.8606 - f1_score: 0.8606
# Epoch 12: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0648 - accuracy: 0.8633 - f1_score: 0.8616 - val_loss: 0.0410 - val_accuracy: 0.6296 - val_f1_score: 0.6094 - lr: 0.0010
# Epoch 13/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0347 - accuracy: 0.9339 - f1_score: 0.9339
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 13: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0380 - accuracy: 0.9212 - f1_score: 0.9198 - val_loss: 0.0464 - val_accuracy: 0.6327 - val_f1_score: 0.6901 - lr: 0.0010
# Epoch 14/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0268 - accuracy: 0.9387 - f1_score: 0.9387
# Epoch 14: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0264 - accuracy: 0.9411 - f1_score: 0.9414 - val_loss: 0.0445 - val_accuracy: 0.6389 - val_f1_score: 0.6953 - lr: 5.0000e-04
# Epoch 15/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0229 - accuracy: 0.9519 - f1_score: 0.9519
# Epoch 15: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0221 - accuracy: 0.9521 - f1_score: 0.9516 - val_loss: 0.0572 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 5.0000e-04
# Epoch 16/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0231 - accuracy: 0.9591 - f1_score: 0.9591
# Epoch 16: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0227 - accuracy: 0.9581 - f1_score: 0.9574 - val_loss: 0.0574 - val_accuracy: 0.6451 - val_f1_score: 0.6615 - lr: 5.0000e-04
# Epoch 17/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0157 - accuracy: 0.9724 - f1_score: 0.9724
# Epoch 17: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0150 - accuracy: 0.9711 - f1_score: 0.9707 - val_loss: 0.0557 - val_accuracy: 0.6636 - val_f1_score: 0.6771 - lr: 5.0000e-04
# Epoch 18/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0120 - accuracy: 0.9772 - f1_score: 0.9772
# Epoch 18: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0151 - accuracy: 0.9691 - f1_score: 0.9677 - val_loss: 0.0685 - val_accuracy: 0.6451 - val_f1_score: 0.7005 - lr: 5.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9501 - f1_score: 0.9501
# Epoch 19: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0248 - accuracy: 0.9501 - f1_score: 0.9501 - val_loss: 0.0676 - val_accuracy: 0.6821 - val_f1_score: 0.6927 - lr: 5.0000e-04
# Epoch 20/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0152 - accuracy: 0.9675 - f1_score: 0.9675
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0155 - accuracy: 0.9701 - f1_score: 0.9707 - val_loss: 0.0710 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 5.0000e-04
# Epoch 21/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0077 - accuracy: 0.9880 - f1_score: 0.9880
# Epoch 21: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0071 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 0.0800 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 2.5000e-04
# Epoch 22/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0051 - accuracy: 0.9928 - f1_score: 0.9928
# Epoch 22: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.0870 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 2.5000e-04
# Epoch 23/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0031 - accuracy: 0.9976 - f1_score: 0.9976
# Epoch 23: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0034 - accuracy: 0.9940 - f1_score: 0.9931 - val_loss: 0.1012 - val_accuracy: 0.6451 - val_f1_score: 0.7005 - lr: 2.5000e-04
# Epoch 24/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0019 - accuracy: 0.9988 - f1_score: 0.9988
# Epoch 24: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.1045 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 2.5000e-04
# Epoch 25/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 25: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0022 - accuracy: 0.9990 - f1_score: 0.9985 - val_loss: 0.1242 - val_accuracy: 0.6389 - val_f1_score: 0.6953 - lr: 2.5000e-04
# Epoch 26/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 6.
#
# Epoch 26: val_loss did not improve from 0.03659
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.6790 - val_f1_score: 0.6901 - lr: 2.5000e-04
# Epoch 26: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 3ms/step
# 0.7067901234567902

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7067901234567902
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.38      0.18      0.24        85
#            0       0.75      0.90      0.82       239
#
#     accuracy                           0.71       324
#    macro avg       0.56      0.54      0.53       324
# weighted avg       0.65      0.71      0.67       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 229 chiếm khoảng 70.67901234567901% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 15 chiếm khoảng 17.647058823529413% so với thực tế
