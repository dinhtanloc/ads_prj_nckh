# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d (ZeroPaddin  (None, 44, 1)                0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 96)               6240      ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 96)               40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 96)               40        ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 10, 96)               0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 10, 96)               0         ['add[0][0]']
#
#  res2b_branch2a (Conv1D)     (None, 10, 32)               3104      ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 10, 32)               40        ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 10, 32)               0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 10, 32)               40        ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 10, 32)               0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 10, 96)               40        ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 10, 96)               0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 10, 96)               0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)     (None, 10, 32)               3104      ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 10, 32)               40        ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 10, 32)               0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 10, 32)               40        ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 10, 32)               0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 10, 96)               40        ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 10, 96)               0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 10, 96)               0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 96)                9312      ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 96)                20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 5, 96)                0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 96)                20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 5, 96)                0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 192)               18624     ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 192)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 192)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 5, 192)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 5, 192)               0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)     (None, 5, 96)                18528     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 5, 96)                20        ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 5, 96)                0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 5, 96)                20        ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 5, 96)                0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 5, 192)               20        ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 5, 192)               0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 5, 192)               0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)     (None, 5, 96)                18528     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 5, 96)                20        ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 5, 96)                0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 5, 96)                20        ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 5, 96)                0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 5, 192)               20        ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 5, 192)               0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 5, 192)               0         ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)     (None, 3, 192)               37056     ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 3, 192)               12        ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 3, 192)               0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)     (None, 3, 192)               110784    ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 3, 192)               12        ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 3, 192)               0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)     (None, 3, 256)               49408     ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 3, 256)               49408     ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 3, 256)               12        ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 3, 256)               12        ['res4a_branch1[0][0]']
#  zation)
#
#  add_6 (Add)                 (None, 3, 256)               0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)  (None, 3, 256)               0         ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)     (None, 2, 256)               65792     ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 2, 256)               8         ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_22 (Activation)  (None, 2, 256)               0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)     (None, 2, 256)               196864    ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 2, 256)               8         ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 2, 256)               0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)     (None, 2, 384)               98688     ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 2, 384)               98688     ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 2, 384)               8         ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 2, 384)               8         ['res5a_branch1[0][0]']
#  zation)
#
#  add_7 (Add)                 (None, 2, 384)               0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)  (None, 2, 384)               0         ['add_7[0][0]']
#
#  global_average_pooling1d (  (None, 384)                  0         ['activation_24[0][0]']
#  GlobalAveragePooling1D)
#
#  fc1000 (Dense)              (None, 2)                    770       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 946346 (3.61 MB)
# Trainable params: 945878 (3.61 MB)
# Non-trainable params: 468 (1.83 KB)
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.4930 - f1_score: 0.3625
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 11s 90ms/step - loss: 0.6666 - accuracy: 0.4930 - f1_score: 0.3625 - val_loss: 0.3906 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4229 - accuracy: 0.6667 - f1_score: 0.6608
# Epoch 2: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 24ms/step - loss: 0.4229 - accuracy: 0.6667 - f1_score: 0.6608 - val_loss: 0.5609 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3237 - accuracy: 0.7465 - f1_score: 0.7403
# Epoch 3: val_f1_score improved from 0.42467 to 0.46026, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.3237 - accuracy: 0.7465 - f1_score: 0.7403 - val_loss: 0.3912 - val_accuracy: 0.7284 - val_f1_score: 0.4603 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.7874 - f1_score: 0.7860
# Epoch 4: val_f1_score improved from 0.46026 to 0.46906, saving model to best_model.h5
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2696 - accuracy: 0.7874 - f1_score: 0.7860 - val_loss: 0.3725 - val_accuracy: 0.7346 - val_f1_score: 0.4691 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.8244 - f1_score: 0.8228
# Epoch 5: val_f1_score did not improve from 0.46906
# 16/16 [==============================] - 0s 23ms/step - loss: 0.2344 - accuracy: 0.8244 - f1_score: 0.8228 - val_loss: 0.4580 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.8603 - f1_score: 0.8602
# Epoch 6: val_f1_score improved from 0.46906 to 0.46925, saving model to best_model.h5
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1872 - accuracy: 0.8603 - f1_score: 0.8602 - val_loss: 0.3702 - val_accuracy: 0.7315 - val_f1_score: 0.4693 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.8703 - f1_score: 0.8695
# Epoch 7: val_f1_score improved from 0.46925 to 0.54557, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1675 - accuracy: 0.8703 - f1_score: 0.8695 - val_loss: 0.3177 - val_accuracy: 0.7222 - val_f1_score: 0.5456 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.8792 - f1_score: 0.8781
# Epoch 8: val_f1_score did not improve from 0.54557
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1628 - accuracy: 0.8792 - f1_score: 0.8781 - val_loss: 0.4284 - val_accuracy: 0.7284 - val_f1_score: 0.4303 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9002 - f1_score: 0.8977
# Epoch 9: val_f1_score improved from 0.54557 to 0.55449, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1406 - accuracy: 0.9002 - f1_score: 0.8977 - val_loss: 0.3433 - val_accuracy: 0.7253 - val_f1_score: 0.5545 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9232 - f1_score: 0.9238
# Epoch 10: val_f1_score did not improve from 0.55449
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1164 - accuracy: 0.9232 - f1_score: 0.9238 - val_loss: 0.4353 - val_accuracy: 0.7253 - val_f1_score: 0.4480 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9242 - f1_score: 0.9234
# Epoch 11: val_f1_score did not improve from 0.55449
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1035 - accuracy: 0.9242 - f1_score: 0.9234 - val_loss: 0.3681 - val_accuracy: 0.7130 - val_f1_score: 0.5038 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9321 - f1_score: 0.9318
# Epoch 12: val_f1_score improved from 0.55449 to 0.61795, saving model to best_model.h5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0913 - accuracy: 0.9321 - f1_score: 0.9318 - val_loss: 0.3874 - val_accuracy: 0.6389 - val_f1_score: 0.6180 - lr: 0.0010
# Epoch 13/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0879 - accuracy: 0.9442 - f1_score: 0.9438
# Epoch 13: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0884 - accuracy: 0.9421 - f1_score: 0.9404 - val_loss: 0.3846 - val_accuracy: 0.7099 - val_f1_score: 0.5324 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9232 - f1_score: 0.9216
# Epoch 14: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1043 - accuracy: 0.9232 - f1_score: 0.9216 - val_loss: 0.3668 - val_accuracy: 0.6914 - val_f1_score: 0.5437 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9591 - f1_score: 0.9585
# Epoch 15: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0694 - accuracy: 0.9591 - f1_score: 0.9585 - val_loss: 0.3566 - val_accuracy: 0.7346 - val_f1_score: 0.5717 - lr: 0.0010
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9451 - f1_score: 0.9448
# Epoch 16: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0727 - accuracy: 0.9451 - f1_score: 0.9448 - val_loss: 0.4593 - val_accuracy: 0.7068 - val_f1_score: 0.4730 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9431 - f1_score: 0.9416
# Epoch 17: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0841 - accuracy: 0.9431 - f1_score: 0.9416 - val_loss: 0.4229 - val_accuracy: 0.7099 - val_f1_score: 0.5313 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9571 - f1_score: 0.9567
# Epoch 18: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0643 - accuracy: 0.9571 - f1_score: 0.9567 - val_loss: 0.3876 - val_accuracy: 0.7006 - val_f1_score: 0.5402 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9501 - f1_score: 0.9485
# Epoch 19: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0677 - accuracy: 0.9501 - f1_score: 0.9485 - val_loss: 0.4173 - val_accuracy: 0.6389 - val_f1_score: 0.5302 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9621 - f1_score: 0.9614
# Epoch 20: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0529 - accuracy: 0.9621 - f1_score: 0.9614 - val_loss: 0.4278 - val_accuracy: 0.6420 - val_f1_score: 0.5204 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0543 - accuracy: 0.9646 - f1_score: 0.9643
# Epoch 21: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0541 - accuracy: 0.9651 - f1_score: 0.9650 - val_loss: 0.4087 - val_accuracy: 0.7284 - val_f1_score: 0.5549 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9711 - f1_score: 0.9697
# Epoch 22: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0446 - accuracy: 0.9711 - f1_score: 0.9697 - val_loss: 0.4005 - val_accuracy: 0.6975 - val_f1_score: 0.5830 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9571 - f1_score: 0.9556
# Epoch 23: val_f1_score did not improve from 0.61795
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0612 - accuracy: 0.9571 - f1_score: 0.9556 - val_loss: 0.4844 - val_accuracy: 0.6080 - val_f1_score: 0.5158 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0662 - accuracy: 0.9573 - f1_score: 0.9570
# Epoch 24: val_f1_score improved from 0.61795 to 0.63257, saving model to best_model.h5
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0638 - accuracy: 0.9591 - f1_score: 0.9597 - val_loss: 0.4047 - val_accuracy: 0.6636 - val_f1_score: 0.6326 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9621 - f1_score: 0.9611
# Epoch 25: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0599 - accuracy: 0.9621 - f1_score: 0.9611 - val_loss: 0.4076 - val_accuracy: 0.6944 - val_f1_score: 0.5511 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9431 - f1_score: 0.9410
# Epoch 26: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0780 - accuracy: 0.9431 - f1_score: 0.9410 - val_loss: 0.4746 - val_accuracy: 0.6944 - val_f1_score: 0.5128 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9581 - f1_score: 0.9566
# Epoch 27: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0588 - accuracy: 0.9581 - f1_score: 0.9566 - val_loss: 0.4908 - val_accuracy: 0.6451 - val_f1_score: 0.5292 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9750 - f1_score: 0.9753
# Epoch 28: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0404 - accuracy: 0.9750 - f1_score: 0.9753 - val_loss: 0.4970 - val_accuracy: 0.7284 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9731 - f1_score: 0.9727
# Epoch 29: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0376 - accuracy: 0.9731 - f1_score: 0.9727 - val_loss: 0.4741 - val_accuracy: 0.7222 - val_f1_score: 0.5396 - lr: 0.0010
# Epoch 30/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0337 - accuracy: 0.9788 - f1_score: 0.9786
# Epoch 30: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0338 - accuracy: 0.9790 - f1_score: 0.9787 - val_loss: 0.4888 - val_accuracy: 0.6389 - val_f1_score: 0.5401 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9750 - f1_score: 0.9741
# Epoch 31: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0393 - accuracy: 0.9750 - f1_score: 0.9741 - val_loss: 0.4383 - val_accuracy: 0.7160 - val_f1_score: 0.5608 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9561 - f1_score: 0.9541
# Epoch 32: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0631 - accuracy: 0.9561 - f1_score: 0.9541 - val_loss: 0.4376 - val_accuracy: 0.6944 - val_f1_score: 0.5267 - lr: 0.0010
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9571 - f1_score: 0.9576
# Epoch 33: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0555 - accuracy: 0.9571 - f1_score: 0.9576 - val_loss: 0.3826 - val_accuracy: 0.7037 - val_f1_score: 0.5831 - lr: 0.0010
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9691 - f1_score: 0.9694
# Epoch 34: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0453 - accuracy: 0.9691 - f1_score: 0.9694 - val_loss: 0.4460 - val_accuracy: 0.6204 - val_f1_score: 0.5922 - lr: 0.0010
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9641 - f1_score: 0.9635
# Epoch 35: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0469 - accuracy: 0.9641 - f1_score: 0.9635 - val_loss: 0.4170 - val_accuracy: 0.7191 - val_f1_score: 0.6189 - lr: 0.0010
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9731 - f1_score: 0.9727
# Epoch 36: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0432 - accuracy: 0.9731 - f1_score: 0.9727 - val_loss: 0.4363 - val_accuracy: 0.6759 - val_f1_score: 0.6246 - lr: 0.0010
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9711 - f1_score: 0.9710
# Epoch 37: val_f1_score did not improve from 0.63257
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0365 - accuracy: 0.9711 - f1_score: 0.9710 - val_loss: 0.4800 - val_accuracy: 0.6883 - val_f1_score: 0.5209 - lr: 0.0010
# Epoch 38/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0373 - accuracy: 0.9760 - f1_score: 0.9758
# Epoch 38: val_f1_score improved from 0.63257 to 0.64297, saving model to best_model.h5
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0374 - accuracy: 0.9750 - f1_score: 0.9754 - val_loss: 0.5044 - val_accuracy: 0.6296 - val_f1_score: 0.6430 - lr: 0.0010
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9731 - f1_score: 0.9734
# Epoch 39: val_f1_score did not improve from 0.64297
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0353 - accuracy: 0.9731 - f1_score: 0.9734 - val_loss: 0.4652 - val_accuracy: 0.6698 - val_f1_score: 0.5541 - lr: 0.0010
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0232 - accuracy: 0.9833 - f1_score: 0.9832
# Epoch 40: val_f1_score did not improve from 0.64297
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0231 - accuracy: 0.9840 - f1_score: 0.9842 - val_loss: 0.4479 - val_accuracy: 0.7006 - val_f1_score: 0.6084 - lr: 0.0010
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9840 - f1_score: 0.9839
# Epoch 41: val_f1_score improved from 0.64297 to 0.65021, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0197 - accuracy: 0.9840 - f1_score: 0.9839 - val_loss: 0.4552 - val_accuracy: 0.6574 - val_f1_score: 0.6502 - lr: 0.0010
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9830 - f1_score: 0.9820
# Epoch 42: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0284 - accuracy: 0.9830 - f1_score: 0.9820 - val_loss: 0.4228 - val_accuracy: 0.7037 - val_f1_score: 0.6231 - lr: 0.0010
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9880 - f1_score: 0.9876
# Epoch 43: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0192 - accuracy: 0.9880 - f1_score: 0.9876 - val_loss: 0.4303 - val_accuracy: 0.6975 - val_f1_score: 0.6083 - lr: 0.0010
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9820 - f1_score: 0.9823
# Epoch 44: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0260 - accuracy: 0.9820 - f1_score: 0.9823 - val_loss: 0.4229 - val_accuracy: 0.6852 - val_f1_score: 0.6142 - lr: 0.0010
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9810 - f1_score: 0.9812
# Epoch 45: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0246 - accuracy: 0.9810 - f1_score: 0.9812 - val_loss: 0.4501 - val_accuracy: 0.6667 - val_f1_score: 0.6109 - lr: 0.0010
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9830 - f1_score: 0.9827
# Epoch 46: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0230 - accuracy: 0.9830 - f1_score: 0.9827 - val_loss: 0.4408 - val_accuracy: 0.6605 - val_f1_score: 0.5556 - lr: 0.0010
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9830 - f1_score: 0.9831
# Epoch 47: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0253 - accuracy: 0.9830 - f1_score: 0.9831 - val_loss: 0.4822 - val_accuracy: 0.6481 - val_f1_score: 0.5940 - lr: 0.0010
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9760 - f1_score: 0.9755
# Epoch 48: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0332 - accuracy: 0.9760 - f1_score: 0.9755 - val_loss: 0.4597 - val_accuracy: 0.6975 - val_f1_score: 0.5576 - lr: 0.0010
# Epoch 49/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9800 - f1_score: 0.9790
# Epoch 49: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0291 - accuracy: 0.9800 - f1_score: 0.9790 - val_loss: 0.4563 - val_accuracy: 0.7006 - val_f1_score: 0.6010 - lr: 0.0010
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0374 - accuracy: 0.9688 - f1_score: 0.9686
# Epoch 50: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0384 - accuracy: 0.9681 - f1_score: 0.9676 - val_loss: 0.4755 - val_accuracy: 0.6852 - val_f1_score: 0.5374 - lr: 0.0010
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9731 - f1_score: 0.9730
# Epoch 51: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0359 - accuracy: 0.9731 - f1_score: 0.9730 - val_loss: 0.4995 - val_accuracy: 0.6944 - val_f1_score: 0.5053 - lr: 0.0010
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9760 - f1_score: 0.9744
# Epoch 52: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0351 - accuracy: 0.9760 - f1_score: 0.9744 - val_loss: 0.4999 - val_accuracy: 0.6481 - val_f1_score: 0.5915 - lr: 0.0010
# Epoch 53/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9800 - f1_score: 0.9792
# Epoch 53: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0284 - accuracy: 0.9800 - f1_score: 0.9792 - val_loss: 0.4740 - val_accuracy: 0.6481 - val_f1_score: 0.5034 - lr: 0.0010
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9880 - f1_score: 0.9869
# Epoch 54: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0176 - accuracy: 0.9880 - f1_score: 0.9869 - val_loss: 0.4465 - val_accuracy: 0.6821 - val_f1_score: 0.5411 - lr: 0.0010
# Epoch 55/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9940 - f1_score: 0.9941
# Epoch 55: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0112 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.5004 - val_accuracy: 0.6111 - val_f1_score: 0.5397 - lr: 0.0010
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9870 - f1_score: 0.9866
# Epoch 56: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0162 - accuracy: 0.9870 - f1_score: 0.9866 - val_loss: 0.5146 - val_accuracy: 0.6235 - val_f1_score: 0.5799 - lr: 0.0010
# Epoch 57/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9850 - f1_score: 0.9851
# Epoch 57: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0243 - accuracy: 0.9850 - f1_score: 0.9851 - val_loss: 0.4705 - val_accuracy: 0.6512 - val_f1_score: 0.5862 - lr: 0.0010
# Epoch 58/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9920 - f1_score: 0.9915
# Epoch 58: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0119 - accuracy: 0.9920 - f1_score: 0.9915 - val_loss: 0.5010 - val_accuracy: 0.6265 - val_f1_score: 0.5730 - lr: 0.0010
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0220 - accuracy: 0.9854 - f1_score: 0.9850
# Epoch 59: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0226 - accuracy: 0.9850 - f1_score: 0.9845 - val_loss: 0.4918 - val_accuracy: 0.6358 - val_f1_score: 0.6049 - lr: 0.0010
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9770 - f1_score: 0.9748
# Epoch 60: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0353 - accuracy: 0.9770 - f1_score: 0.9748 - val_loss: 0.4892 - val_accuracy: 0.6667 - val_f1_score: 0.5111 - lr: 0.0010
# Epoch 61/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9750 - f1_score: 0.9743
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 61: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0364 - accuracy: 0.9750 - f1_score: 0.9743 - val_loss: 0.5054 - val_accuracy: 0.7068 - val_f1_score: 0.5246 - lr: 0.0010
# Epoch 62/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9780 - f1_score: 0.9781
# Epoch 62: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0278 - accuracy: 0.9780 - f1_score: 0.9781 - val_loss: 0.5157 - val_accuracy: 0.6389 - val_f1_score: 0.6200 - lr: 5.0000e-04
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9950 - f1_score: 0.9950
# Epoch 63: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0082 - accuracy: 0.9950 - f1_score: 0.9950 - val_loss: 0.5066 - val_accuracy: 0.6728 - val_f1_score: 0.6089 - lr: 5.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 64: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0052 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.5045 - val_accuracy: 0.6667 - val_f1_score: 0.6030 - lr: 5.0000e-04
# Epoch 65/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_f1_score did not improve from 0.65021
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0020 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.6543 - val_f1_score: 0.6241 - lr: 5.0000e-04
# Epoch 66/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 66: val_f1_score improved from 0.65021 to 0.65518, saving model to best_model.h5
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0029 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.4707 - val_accuracy: 0.6636 - val_f1_score: 0.6552 - lr: 5.0000e-04
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 67: val_f1_score did not improve from 0.65518
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0032 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.4915 - val_accuracy: 0.6574 - val_f1_score: 0.6387 - lr: 5.0000e-04
# Epoch 68/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 68: val_f1_score did not improve from 0.65518
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0041 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.4768 - val_accuracy: 0.6636 - val_f1_score: 0.6533 - lr: 5.0000e-04
# Epoch 69/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.8109e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: val_f1_score did not improve from 0.65518
# 16/16 [==============================] - 0s 25ms/step - loss: 5.8109e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.6512 - val_f1_score: 0.6448 - lr: 5.0000e-04
# Epoch 70/10000
# 16/16 [==============================] - ETA: 0s - loss: 6.9728e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_f1_score did not improve from 0.65518
# 16/16 [==============================] - 0s 25ms/step - loss: 6.9728e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.6574 - val_f1_score: 0.6327 - lr: 5.0000e-04
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 6.9775e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_f1_score did not improve from 0.65518
# 16/16 [==============================] - 0s 24ms/step - loss: 6.9775e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.6667 - val_f1_score: 0.6492 - lr: 5.0000e-04
# Epoch 72/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.8595e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_f1_score improved from 0.65518 to 0.67369, saving model to best_model.h5
# 16/16 [==============================] - 1s 37ms/step - loss: 1.8595e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4719 - val_accuracy: 0.6852 - val_f1_score: 0.6737 - lr: 5.0000e-04
# Epoch 73/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.1814e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_f1_score improved from 0.67369 to 0.67767, saving model to best_model.h5
# 16/16 [==============================] - 1s 38ms/step - loss: 2.1814e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4725 - val_accuracy: 0.6852 - val_f1_score: 0.6777 - lr: 5.0000e-04
# Epoch 74/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.1436e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 3.1436e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4838 - val_accuracy: 0.6790 - val_f1_score: 0.6640 - lr: 5.0000e-04
# Epoch 75/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.8806e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 4.8806e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.6759 - val_f1_score: 0.6584 - lr: 5.0000e-04
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9960 - f1_score: 0.9959
# Epoch 76: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0046 - accuracy: 0.9960 - f1_score: 0.9959 - val_loss: 0.5119 - val_accuracy: 0.6667 - val_f1_score: 0.6353 - lr: 5.0000e-04
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 77: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0021 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.5328 - val_accuracy: 0.6667 - val_f1_score: 0.6145 - lr: 5.0000e-04
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 78: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0021 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.5168 - val_accuracy: 0.6636 - val_f1_score: 0.5991 - lr: 5.0000e-04
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9970 - f1_score: 0.9968
# Epoch 79: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0047 - accuracy: 0.9970 - f1_score: 0.9968 - val_loss: 0.5322 - val_accuracy: 0.6451 - val_f1_score: 0.5925 - lr: 5.0000e-04
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9940 - f1_score: 0.9934
# Epoch 80: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0081 - accuracy: 0.9940 - f1_score: 0.9934 - val_loss: 0.5118 - val_accuracy: 0.6605 - val_f1_score: 0.6372 - lr: 5.0000e-04
# Epoch 81/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9950 - f1_score: 0.9937
# Epoch 81: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0073 - accuracy: 0.9950 - f1_score: 0.9937 - val_loss: 0.4756 - val_accuracy: 0.7037 - val_f1_score: 0.6242 - lr: 5.0000e-04
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 82: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0012 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.4752 - val_accuracy: 0.6914 - val_f1_score: 0.6253 - lr: 5.0000e-04
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 9.7145e-04 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 83: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 9.7145e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.4819 - val_accuracy: 0.6759 - val_f1_score: 0.6082 - lr: 5.0000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 84: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0025 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.4935 - val_accuracy: 0.6728 - val_f1_score: 0.6090 - lr: 5.0000e-04
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9960 - f1_score: 0.9955
# Epoch 85: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0051 - accuracy: 0.9960 - f1_score: 0.9955 - val_loss: 0.4930 - val_accuracy: 0.6883 - val_f1_score: 0.6141 - lr: 5.0000e-04
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9920 - f1_score: 0.9920
# Epoch 86: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0131 - accuracy: 0.9920 - f1_score: 0.9920 - val_loss: 0.5147 - val_accuracy: 0.6667 - val_f1_score: 0.6201 - lr: 5.0000e-04
# Epoch 87/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9920 - f1_score: 0.9922
# Epoch 87: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0091 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 0.4925 - val_accuracy: 0.6543 - val_f1_score: 0.6240 - lr: 5.0000e-04
# Epoch 88/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9940 - f1_score: 0.9936
# Epoch 88: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0097 - accuracy: 0.9940 - f1_score: 0.9936 - val_loss: 0.4822 - val_accuracy: 0.6759 - val_f1_score: 0.6392 - lr: 5.0000e-04
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9900 - f1_score: 0.9901
# Epoch 89: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0121 - accuracy: 0.9900 - f1_score: 0.9901 - val_loss: 0.4851 - val_accuracy: 0.6790 - val_f1_score: 0.6367 - lr: 5.0000e-04
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9950 - f1_score: 0.9951
# Epoch 90: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0088 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.4915 - val_accuracy: 0.6636 - val_f1_score: 0.6500 - lr: 5.0000e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 91: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0022 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.5112 - val_accuracy: 0.6605 - val_f1_score: 0.6395 - lr: 5.0000e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0039 - accuracy: 0.9969 - f1_score: 0.9968
# Epoch 92: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0037 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.5143 - val_accuracy: 0.6636 - val_f1_score: 0.6415 - lr: 5.0000e-04
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 93: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0040 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.4951 - val_accuracy: 0.6759 - val_f1_score: 0.6559 - lr: 5.0000e-04
# Epoch 94/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.1123e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.1123e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.6759 - val_f1_score: 0.6595 - lr: 2.5000e-04
# Epoch 95/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.8275e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.8275e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.6821 - val_f1_score: 0.6617 - lr: 2.5000e-04
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3369e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.3369e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.6759 - val_f1_score: 0.6484 - lr: 2.5000e-04
# Epoch 97/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.1457e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.1457e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.6667 - val_f1_score: 0.6504 - lr: 2.5000e-04
# Epoch 98/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 98: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.5014 - val_accuracy: 0.6698 - val_f1_score: 0.6531 - lr: 2.5000e-04
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.0528e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.0528e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5035 - val_accuracy: 0.6728 - val_f1_score: 0.6565 - lr: 2.5000e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.3411e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 3.8102e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5043 - val_accuracy: 0.6728 - val_f1_score: 0.6565 - lr: 2.5000e-04
# Epoch 101/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.4955e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 23ms/step - loss: 5.4955e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.6728 - val_f1_score: 0.6565 - lr: 2.5000e-04
# Epoch 102/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.9923e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.9923e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.6728 - val_f1_score: 0.6565 - lr: 2.5000e-04
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.4197e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.4197e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.6728 - val_f1_score: 0.6565 - lr: 2.5000e-04
# Epoch 104/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 104: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0017 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 0.5077 - val_accuracy: 0.6698 - val_f1_score: 0.6543 - lr: 2.5000e-04
# Epoch 105/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.6500e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.6500e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5108 - val_accuracy: 0.6636 - val_f1_score: 0.6524 - lr: 2.5000e-04
# Epoch 106/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.6428e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.6428e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.6605 - val_f1_score: 0.6504 - lr: 2.5000e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7440e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 4.5993e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5122 - val_accuracy: 0.6605 - val_f1_score: 0.6504 - lr: 2.5000e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.5148e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 27ms/step - loss: 3.4042e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.6574 - val_f1_score: 0.6471 - lr: 2.5000e-04
# Epoch 109/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.4862e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 3.4862e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.6605 - val_f1_score: 0.6491 - lr: 2.5000e-04
# Epoch 110/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.0045e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.0045e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5141 - val_accuracy: 0.6636 - val_f1_score: 0.6510 - lr: 2.5000e-04
# Epoch 111/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.0165e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.0165e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5144 - val_accuracy: 0.6605 - val_f1_score: 0.6475 - lr: 2.5000e-04
# Epoch 112/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.6064e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 112: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.6064e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.6605 - val_f1_score: 0.6475 - lr: 2.5000e-04
# Epoch 113/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.3348e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 113: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.3348e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.6605 - val_f1_score: 0.6475 - lr: 2.5000e-04
# Epoch 114/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.0866e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 114: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.0866e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.6605 - val_f1_score: 0.6475 - lr: 1.2500e-04
# Epoch 115/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4347e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 115: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4347e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.6636 - val_f1_score: 0.6494 - lr: 1.2500e-04
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.0594e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 7.8560e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.6636 - val_f1_score: 0.6494 - lr: 1.2500e-04
# Epoch 117/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4917e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 117: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4917e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.6636 - val_f1_score: 0.6494 - lr: 1.2500e-04
# Epoch 118/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.5209e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 118: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.5209e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5158 - val_accuracy: 0.6605 - val_f1_score: 0.6460 - lr: 1.2500e-04
# Epoch 119/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4827e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 119: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4827e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.6667 - val_f1_score: 0.6505 - lr: 1.2500e-04
# Epoch 120/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.6565e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 120: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.6565e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.6667 - val_f1_score: 0.6505 - lr: 1.2500e-04
# Epoch 121/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2584e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 121: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.2584e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.6636 - val_f1_score: 0.6451 - lr: 1.2500e-04
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2394e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 122: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.2394e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.6636 - val_f1_score: 0.6451 - lr: 1.2500e-04
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9820e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 123: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 27ms/step - loss: 2.4963e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.6636 - val_f1_score: 0.6435 - lr: 1.2500e-04
# Epoch 124/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4176e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 124: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4176e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.6636 - val_f1_score: 0.6435 - lr: 1.2500e-04
# Epoch 125/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.9322e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 125: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.9322e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5187 - val_accuracy: 0.6636 - val_f1_score: 0.6435 - lr: 1.2500e-04
# Epoch 126/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.7408e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 126: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.7408e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.6698 - val_f1_score: 0.6467 - lr: 1.2500e-04
# Epoch 127/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4922e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 127: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4922e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.6698 - val_f1_score: 0.6467 - lr: 1.2500e-04
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.9621e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 128: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.9621e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.6667 - val_f1_score: 0.6449 - lr: 1.2500e-04
# Epoch 129/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.4234e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 129: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.4234e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.6667 - val_f1_score: 0.6449 - lr: 1.2500e-04
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.2186e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 130: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 3.2315e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.6667 - val_f1_score: 0.6484 - lr: 1.2500e-04
# Epoch 131/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.5971e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 131: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.5971e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.6728 - val_f1_score: 0.6572 - lr: 1.2500e-04
# Epoch 132/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.3083e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 132: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 3.3083e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.6728 - val_f1_score: 0.6594 - lr: 1.2500e-04
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.3620e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 133: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 133: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.3620e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.6728 - val_f1_score: 0.6594 - lr: 1.2500e-04
# Epoch 134/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.1029e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 134: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 4.1029e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5178 - val_accuracy: 0.6698 - val_f1_score: 0.6571 - lr: 6.2500e-05
# Epoch 135/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.5039e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 135: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.5039e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.6698 - val_f1_score: 0.6571 - lr: 6.2500e-05
# Epoch 136/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.7525e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 136: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.7525e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.6698 - val_f1_score: 0.6571 - lr: 6.2500e-05
# Epoch 137/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.4363e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 137: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 27ms/step - loss: 1.4368e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.6698 - val_f1_score: 0.6571 - lr: 6.2500e-05
# Epoch 138/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.5395e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 138: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.5395e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.6698 - val_f1_score: 0.6571 - lr: 6.2500e-05
# Epoch 139/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.4277e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 139: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.4277e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.6667 - val_f1_score: 0.6552 - lr: 6.2500e-05
# Epoch 140/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6693e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 140: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6693e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.6667 - val_f1_score: 0.6552 - lr: 6.2500e-05
# Epoch 141/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.7881e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 141: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.7881e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.6667 - val_f1_score: 0.6552 - lr: 6.2500e-05
# Epoch 142/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.0956e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 142: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.0956e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.6667 - val_f1_score: 0.6552 - lr: 6.2500e-05
# Epoch 143/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.0860e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 143: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.0860e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4453e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 144: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 1.4226e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 145/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.7221e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 145: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.7221e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.6728 - val_f1_score: 0.6568 - lr: 6.2500e-05
# Epoch 146/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.7424e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 146: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.7424e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.6728 - val_f1_score: 0.6568 - lr: 6.2500e-05
# Epoch 147/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3469e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 147: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.3469e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 148/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.4078e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 148: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.4078e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 149/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.9459e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 149: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.9459e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 150/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.7804e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 150: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.7804e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 151/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8164e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 151: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.7644e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 152/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6629e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 152: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6629e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.6698 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 153/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.0176e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 153: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 153: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.0176e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 6.2500e-05
# Epoch 154/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.0495e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 154: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.0495e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.6728 - val_f1_score: 0.6513 - lr: 3.1250e-05
# Epoch 155/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.5567e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 155: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.5567e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.6759 - val_f1_score: 0.6567 - lr: 3.1250e-05
# Epoch 156/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.5713e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 156: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.5713e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.6759 - val_f1_score: 0.6567 - lr: 3.1250e-05
# Epoch 157/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7914e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 157: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 1.7290e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5189 - val_accuracy: 0.6759 - val_f1_score: 0.6567 - lr: 3.1250e-05
# Epoch 158/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.7334e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 158: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 2.7334e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 159/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2501e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 159: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.2501e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 160/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.1387e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 160: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.1387e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 161/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.8991e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 161: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.8991e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.6698 - val_f1_score: 0.6524 - lr: 3.1250e-05
# Epoch 162/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.3789e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 162: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 3.3789e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 163/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2178e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 163: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.2178e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 164/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3946e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 164: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.3946e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 165/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6855e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 165: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6855e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 166/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.1242e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 166: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 4.1242e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.6728 - val_f1_score: 0.6545 - lr: 3.1250e-05
# Epoch 167/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.7762e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 167: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 2.7762e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.6698 - val_f1_score: 0.6524 - lr: 3.1250e-05
# Epoch 168/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.1493e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 168: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 5.1493e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.6698 - val_f1_score: 0.6524 - lr: 3.1250e-05
# Epoch 169/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.8633e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 169: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.8633e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.6759 - val_f1_score: 0.6567 - lr: 3.1250e-05
# Epoch 170/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0461e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 170: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0496e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.6759 - val_f1_score: 0.6567 - lr: 3.1250e-05
# Epoch 171/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2758e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 171: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 25ms/step - loss: 1.2758e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.6821 - val_f1_score: 0.6608 - lr: 3.1250e-05
# Epoch 172/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2105e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 172: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 24ms/step - loss: 1.2105e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.6821 - val_f1_score: 0.6608 - lr: 3.1250e-05
# Epoch 173/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.9601e-05 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 73.
#
# Epoch 173: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 173: val_f1_score did not improve from 0.67767
# 16/16 [==============================] - 0s 26ms/step - loss: 1.9601e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.6790 - val_f1_score: 0.6589 - lr: 3.1250e-05
# Epoch 173: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
check_model=resnet50
check_model.load_weights('best_model.h5')
check_model.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d (ZeroPaddin  (None, 44, 1)                0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 96)               6240      ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 96)               40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 96)               40        ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 10, 96)               0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 10, 96)               0         ['add[0][0]']
#
#  res2b_branch2a (Conv1D)     (None, 10, 32)               3104      ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 10, 32)               40        ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 10, 32)               0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 10, 32)               40        ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 10, 32)               0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 10, 96)               40        ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 10, 96)               0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 10, 96)               0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)     (None, 10, 32)               3104      ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 10, 32)               40        ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 10, 32)               0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 10, 32)               40        ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 10, 32)               0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 10, 96)               40        ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 10, 96)               0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 10, 96)               0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 96)                9312      ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 96)                20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 5, 96)                0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 96)                20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 5, 96)                0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 192)               18624     ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 192)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 192)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 5, 192)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 5, 192)               0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)     (None, 5, 96)                18528     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 5, 96)                20        ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 5, 96)                0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 5, 96)                20        ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 5, 96)                0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 5, 192)               20        ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 5, 192)               0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 5, 192)               0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)     (None, 5, 96)                18528     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 5, 96)                20        ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 5, 96)                0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 5, 96)                20        ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 5, 96)                0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 5, 192)               20        ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 5, 192)               0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 5, 192)               0         ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)     (None, 3, 192)               37056     ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 3, 192)               12        ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 3, 192)               0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)     (None, 3, 192)               110784    ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 3, 192)               12        ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 3, 192)               0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)     (None, 3, 256)               49408     ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 3, 256)               49408     ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 3, 256)               12        ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 3, 256)               12        ['res4a_branch1[0][0]']
#  zation)
#
#  add_6 (Add)                 (None, 3, 256)               0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)  (None, 3, 256)               0         ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)     (None, 2, 256)               65792     ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 2, 256)               8         ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_22 (Activation)  (None, 2, 256)               0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)     (None, 2, 256)               196864    ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 2, 256)               8         ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 2, 256)               0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)     (None, 2, 384)               98688     ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 2, 384)               98688     ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 2, 384)               8         ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 2, 384)               8         ['res5a_branch1[0][0]']
#  zation)
#
#  add_7 (Add)                 (None, 2, 384)               0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)  (None, 2, 384)               0         ['add_7[0][0]']
#
#  global_average_pooling1d (  (None, 384)                  0         ['activation_24[0][0]']
#  GlobalAveragePooling1D)
#
#  fc1000 (Dense)              (None, 2)                    770       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 946346 (3.61 MB)
# Trainable params: 945878 (3.61 MB)
# Non-trainable params: 468 (1.83 KB)
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.6851851851851852

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.6851851851851852

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6851851851851852
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.42      0.54      0.47        85
#            0       0.82      0.74      0.78       239
#
#     accuracy                           0.69       324
#    macro avg       0.62      0.64      0.62       324
# weighted avg       0.71      0.69      0.70       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 222 chiếm khoảng 68.51851851851852% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 46 chiếm khoảng 54.11764705882353% so với thực tế
