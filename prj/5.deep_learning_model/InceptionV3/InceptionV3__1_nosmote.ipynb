# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 128, 1,padding='same')

    branch7x7 = conv1d_bn(x, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 128, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # # mixed 5, 6: 17 x 17 x 768
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    #     branch7x7 = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    #     branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch7x7, branch7x7dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 960
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 288, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 288, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 256, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 256, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 256, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 256, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 96)                9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 96)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 96)                64512     ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 96)                9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 96)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 96)                9216      ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 96)                9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 96)                9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 96)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 96)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 96)                9216      ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 96)                64512     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 96)                9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 96)                9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 96)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 96)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 128)               86016     ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 128)               12288     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 128)               65536     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 128)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 128)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 128)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 128)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 128)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 128)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 128)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 128)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 512)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 192)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 3, 192)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 192)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 3, 192)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 192)               36864     ['activation_39[0][0]']
#
#  conv1d_43 (Conv1D)          (None, 3, 192)               258048    ['activation_42[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 192)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 3, 192)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 192)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 3, 192)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 512)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               258048    ['activation_40[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 192)               36864     ['activation_43[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 192)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 192)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 192)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 192)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_44[0][0]',
#                                                                      'activation_45[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1973147 (7.53 MB)
# Trainable params: 1972597 (7.52 MB)
# Non-trainable params: 550 (2.15 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.4389 - accuracy: 0.5174 - f1_score: 0.3185
# Epoch 1: val_f1_score improved from -inf to 0.50757, saving model to best_model.h5
# 11/11 [==============================] - 12s 142ms/step - loss: 1.3634 - accuracy: 0.4863 - f1_score: 0.3004 - val_loss: 0.6896 - val_accuracy: 0.7068 - val_f1_score: 0.5076 - lr: 0.0010
# Epoch 2/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.7099 - accuracy: 0.5297 - f1_score: 0.3517
# Epoch 2: val_f1_score did not improve from 0.50757
# 11/11 [==============================] - 0s 38ms/step - loss: 0.7097 - accuracy: 0.5229 - f1_score: 0.3379 - val_loss: 0.5823 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.7110 - accuracy: 0.5229 - f1_score: 0.3387
# Epoch 3: val_f1_score did not improve from 0.50757
# 11/11 [==============================] - 0s 39ms/step - loss: 0.7110 - accuracy: 0.5229 - f1_score: 0.3387 - val_loss: 0.5665 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.7194 - accuracy: 0.4844 - f1_score: 0.3124
# Epoch 4: val_f1_score did not improve from 0.50757
# 11/11 [==============================] - 0s 43ms/step - loss: 0.7211 - accuracy: 0.4878 - f1_score: 0.3189 - val_loss: 0.5933 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 5/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7094 - accuracy: 0.4115 - f1_score: 0.3369
# Epoch 5: val_f1_score did not improve from 0.50757
# 11/11 [==============================] - 0s 38ms/step - loss: 0.7073 - accuracy: 0.3948 - f1_score: 0.3133 - val_loss: 0.5732 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.5899 - f1_score: 0.5171
# Epoch 6: val_f1_score did not improve from 0.50757
# 11/11 [==============================] - 0s 38ms/step - loss: 0.6565 - accuracy: 0.5899 - f1_score: 0.5171 - val_loss: 0.5603 - val_accuracy: 0.7407 - val_f1_score: 0.4490 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5788 - accuracy: 0.6784 - f1_score: 0.6417
# Epoch 7: val_f1_score improved from 0.50757 to 0.52557, saving model to best_model.h5
# 11/11 [==============================] - 1s 66ms/step - loss: 0.5788 - accuracy: 0.6784 - f1_score: 0.6417 - val_loss: 0.5865 - val_accuracy: 0.7253 - val_f1_score: 0.5256 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5364 - accuracy: 0.7210 - f1_score: 0.6656
# Epoch 8: val_f1_score improved from 0.52557 to 0.67869, saving model to best_model.h5
# 11/11 [==============================] - 1s 64ms/step - loss: 0.5364 - accuracy: 0.7210 - f1_score: 0.6656 - val_loss: 0.5549 - val_accuracy: 0.7160 - val_f1_score: 0.6787 - lr: 0.0010
# Epoch 9/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5060 - accuracy: 0.7378 - f1_score: 0.7037
# Epoch 9: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 35ms/step - loss: 0.5060 - accuracy: 0.7424 - f1_score: 0.7140 - val_loss: 0.6863 - val_accuracy: 0.5278 - val_f1_score: 0.5483 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.7424 - f1_score: 0.7041
# Epoch 10: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.4897 - accuracy: 0.7424 - f1_score: 0.7041 - val_loss: 0.7162 - val_accuracy: 0.5123 - val_f1_score: 0.5414 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.7957 - f1_score: 0.7661
# Epoch 11: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.4589 - accuracy: 0.7957 - f1_score: 0.7661 - val_loss: 0.9752 - val_accuracy: 0.2747 - val_f1_score: 0.2216 - lr: 0.0010
# Epoch 12/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.3803 - accuracy: 0.8090 - f1_score: 0.7712
# Epoch 12: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.3948 - accuracy: 0.8049 - f1_score: 0.7696 - val_loss: 0.9629 - val_accuracy: 0.3704 - val_f1_score: 0.3755 - lr: 0.0010
# Epoch 13/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.4092 - accuracy: 0.7812 - f1_score: 0.7465
# Epoch 13: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 35ms/step - loss: 0.4119 - accuracy: 0.7774 - f1_score: 0.7527 - val_loss: 0.8465 - val_accuracy: 0.4475 - val_f1_score: 0.4865 - lr: 0.0010
# Epoch 14/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.3362 - accuracy: 0.8490 - f1_score: 0.8091
# Epoch 14: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.3557 - accuracy: 0.8460 - f1_score: 0.8024 - val_loss: 1.0668 - val_accuracy: 0.3765 - val_f1_score: 0.4248 - lr: 0.0010
# Epoch 15/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.4430 - accuracy: 0.7847 - f1_score: 0.7441
# Epoch 15: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.4341 - accuracy: 0.7820 - f1_score: 0.7346 - val_loss: 0.7187 - val_accuracy: 0.6204 - val_f1_score: 0.6448 - lr: 0.0010
# Epoch 16/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.3905 - accuracy: 0.8266 - f1_score: 0.7778
# Epoch 16: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 36ms/step - loss: 0.3874 - accuracy: 0.8277 - f1_score: 0.7858 - val_loss: 0.6931 - val_accuracy: 0.6605 - val_f1_score: 0.6775 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.8613 - f1_score: 0.8305
# Epoch 17: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 39ms/step - loss: 0.2939 - accuracy: 0.8613 - f1_score: 0.8305 - val_loss: 0.8016 - val_accuracy: 0.6420 - val_f1_score: 0.6636 - lr: 0.0010
# Epoch 18/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.2819 - accuracy: 0.8609 - f1_score: 0.8304
# Epoch 18: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 44ms/step - loss: 0.2881 - accuracy: 0.8552 - f1_score: 0.8004 - val_loss: 0.9600 - val_accuracy: 0.5494 - val_f1_score: 0.6118 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.8796 - f1_score: 0.8424
# Epoch 19: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 41ms/step - loss: 0.2939 - accuracy: 0.8796 - f1_score: 0.8424 - val_loss: 0.8993 - val_accuracy: 0.7346 - val_f1_score: 0.6687 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.8872 - f1_score: 0.8655
# Epoch 20: val_f1_score did not improve from 0.67869
# 11/11 [==============================] - 0s 40ms/step - loss: 0.2537 - accuracy: 0.8872 - f1_score: 0.8655 - val_loss: 1.2338 - val_accuracy: 0.3920 - val_f1_score: 0.4031 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.8415 - f1_score: 0.8066
# Epoch 21: val_f1_score improved from 0.67869 to 0.70023, saving model to best_model.h5
# 11/11 [==============================] - 1s 58ms/step - loss: 0.2995 - accuracy: 0.8415 - f1_score: 0.8066 - val_loss: 0.7837 - val_accuracy: 0.7037 - val_f1_score: 0.7002 - lr: 0.0010
# Epoch 22/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.2035 - accuracy: 0.9028 - f1_score: 0.8786
# Epoch 22: val_f1_score did not improve from 0.70023
# 11/11 [==============================] - 0s 36ms/step - loss: 0.2058 - accuracy: 0.9055 - f1_score: 0.8779 - val_loss: 1.4693 - val_accuracy: 0.7500 - val_f1_score: 0.6336 - lr: 0.0010
# Epoch 23/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.1647 - accuracy: 0.9271 - f1_score: 0.9052
# Epoch 23: val_f1_score did not improve from 0.70023
# 11/11 [==============================] - 0s 39ms/step - loss: 0.1652 - accuracy: 0.9284 - f1_score: 0.8988 - val_loss: 0.9391 - val_accuracy: 0.6821 - val_f1_score: 0.6675 - lr: 0.0010
# Epoch 24/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9497 - f1_score: 0.9273
# Epoch 24: val_f1_score did not improve from 0.70023
# 11/11 [==============================] - 0s 40ms/step - loss: 0.1346 - accuracy: 0.9497 - f1_score: 0.9273 - val_loss: 1.6178 - val_accuracy: 0.4074 - val_f1_score: 0.4533 - lr: 0.0010
# Epoch 25/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.
val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.1317 - accuracy: 0.9299 - f1_score: 0.9052 - val_loss: 3.6699 - val_accuracy: 0.7377 - val_f1_score: 0.5017 - lr: 0.0010
# Epoch 49/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9619 - f1_score: 0.9446
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 49: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.1513 - accuracy: 0.9619 - f1_score: 0.9446 - val_loss: 4.2333 - val_accuracy: 0.4228 - val_f1_score: 0.4680 - lr: 0.0010
# Epoch 50/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.1539 - accuracy: 0.9010 - f1_score: 0.8797
# Epoch 50: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 37ms/step - loss: 0.1441 - accuracy: 0.9085 - f1_score: 0.8957 - val_loss: 1.8408 - val_accuracy: 0.6605 - val_f1_score: 0.6850 - lr: 5.0000e-04
# Epoch 51/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9909 - f1_score: 0.9837
# Epoch 51: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0337 - accuracy: 0.9909 - f1_score: 0.9837 - val_loss: 2.5469 - val_accuracy: 0.7407 - val_f1_score: 0.5378 - lr: 5.0000e-04
# Epoch 52/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9970 - f1_score: 0.9964
# Epoch 52: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0183 - accuracy: 0.9970 - f1_score: 0.9964 - val_loss: 2.7706 - val_accuracy: 0.7407 - val_f1_score: 0.5206 - lr: 5.0000e-04
# Epoch 53/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0056 - accuracy: 0.9985 - f1_score: 0.9892 - val_loss: 2.3711 - val_accuracy: 0.7500 - val_f1_score: 0.5627 - lr: 5.0000e-04
# Epoch 54/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0055 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4000 - val_accuracy: 0.7593 - val_f1_score: 0.5662 - lr: 5.0000e-04
# Epoch 55/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0052 - accuracy: 0.9965 - f1_score: 0.9951
# Epoch 55: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0049 - accuracy: 0.9970 - f1_score: 0.9960 - val_loss: 2.3119 - val_accuracy: 0.7500 - val_f1_score: 0.5711 - lr: 5.0000e-04
# Epoch 56/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9985 - f1_score: 0.9969
# Epoch 56: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0026 - accuracy: 0.9985 - f1_score: 0.9969 - val_loss: 2.1453 - val_accuracy: 0.7531 - val_f1_score: 0.5816 - lr: 5.0000e-04
# Epoch 57/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0021 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0086 - val_accuracy: 0.7531 - val_f1_score: 0.5867 - lr: 5.0000e-04
# Epoch 58/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 58: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9423 - val_accuracy: 0.7593 - val_f1_score: 0.6869 - lr: 5.0000e-04
# Epoch 59/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 3.9211e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 59: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 4.4859e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9069 - val_accuracy: 0.7562 - val_f1_score: 0.6869 - lr: 5.0000e-04
# Epoch 60/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 3.0768e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 60: val_f1_score did not improve from 0.70241
# 11/11 [==============================] - 0s 38ms/step - loss: 3.0855e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8960 - val_accuracy: 0.7562 - val_f1_score: 0.6932 - lr: 5.0000e-04
# Epoch 61/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 2.3124e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_f1_score improved from 0.70241 to 0.70365, saving model to best_model.h5
# 11/11 [==============================] - 1s 61ms/step - loss: 2.7998e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8807 - val_accuracy: 0.7593 - val_f1_score: 0.7037 - lr: 5.0000e-04
# Epoch 62/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 2.3552e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_f1_score improved from 0.70365 to 0.70399, saving model to best_model.h5
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0054 - accuracy: 0.9970 - f1_score: 0.9515 - val_loss: 1.8583 - val_accuracy: 0.7654 - val_f1_score: 0.7040 - lr: 5.0000e-04
# Epoch 63/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9970 - f1_score: 0.9965
# Epoch 63: val_f1_score improved from 0.70399 to 0.70496, saving model to best_model.h5
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0280 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 1.7978 - val_accuracy: 0.7716 - val_f1_score: 0.7050 - lr: 5.0000e-04
# Epoch 64/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0065 - accuracy: 0.9983 - f1_score: 0.9974
# Epoch 64: val_f1_score did not improve from 0.70496
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0075 - accuracy: 0.9970 - f1_score: 0.9908 - val_loss: 2.5505 - val_accuracy: 0.6481 - val_f1_score: 0.6295 - lr: 5.0000e-04
# Epoch 65/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9954 - f1_score: 0.9940
# Epoch 65: val_f1_score did not improve from 0.70496
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0096 - accuracy: 0.9954 - f1_score: 0.9940 - val_loss: 2.4416 - val_accuracy: 0.6481 - val_f1_score: 0.6282 - lr: 5.0000e-04
# Epoch 66/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0055 - accuracy: 0.9983 - f1_score: 0.9980
# Epoch 66: val_f1_score improved from 0.70496 to 0.70869, saving model to best_model.h5
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0066 - accuracy: 0.9985 - f1_score: 0.9983 - val_loss: 2.0117 - val_accuracy: 0.7160 - val_f1_score: 0.7087 - lr: 5.0000e-04
# Epoch 67/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0096 - accuracy: 0.9983 - f1_score: 0.9971
# Epoch 67: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0119 - accuracy: 0.9954 - f1_score: 0.9932 - val_loss: 2.0838 - val_accuracy: 0.7377 - val_f1_score: 0.7052 - lr: 5.0000e-04
# Epoch 68/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9970 - f1_score: 0.9956
# Epoch 68: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0067 - accuracy: 0.9970 - f1_score: 0.9956 - val_loss: 2.1530 - val_accuracy: 0.7377 - val_f1_score: 0.6684 - lr: 5.0000e-04
# Epoch 69/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0019 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1099 - val_accuracy: 0.7315 - val_f1_score: 0.6629 - lr: 5.0000e-04
# Epoch 70/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 9.0228e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 38ms/step - loss: 8.2713e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0598 - val_accuracy: 0.7284 - val_f1_score: 0.6734 - lr: 5.0000e-04
# Epoch 71/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0519 - val_accuracy: 0.7407 - val_f1_score: 0.7020 - lr: 5.0000e-04
# Epoch 72/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0027 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0246 - val_accuracy: 0.7438 - val_f1_score: 0.7005 - lr: 5.0000e-04
# Epoch 73/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0027 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3518 - val_accuracy: 0.7037 - val_f1_score: 0.6953 - lr: 5.0000e-04
# Epoch 74/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9985 - f1_score: 0.9974
# Epoch 74: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0023 - accuracy: 0.9985 - f1_score: 0.9974 - val_loss: 2.3775 - val_accuracy: 0.6914 - val_f1_score: 0.6894 - lr: 5.0000e-04
# Epoch 75/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 4.3264e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 41ms/step - loss: 7.3549e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3123 - val_accuracy: 0.7006 - val_f1_score: 0.6881 - lr: 5.0000e-04
# Epoch 76/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 5.2533e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 38ms/step - loss: 5.5045e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1680 - val_accuracy: 0.7346 - val_f1_score: 0.6964 - lr: 5.0000e-04
# Epoch 77/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3957e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 39ms/step - loss: 5.3957e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2122 - val_accuracy: 0.7315 - val_f1_score: 0.6845 - lr: 5.0000e-04
# Epoch 78/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3490e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_f1_score did not improve from 0.70869
# 11/11 [==============================] - 0s 40ms/step - loss: 5.3490e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1960 - val_accuracy: 0.7407 - val_f1_score: 0.6932 - lr: 5.0000e-04
# Epoch 79/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 4.0868e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: val_f1_score improved from 0.70869 to 0.71064, saving model to best_model.h5
# 11/11 [==============================] - 1s 60ms/step - loss: 3.6647e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2489 - val_accuracy: 0.7438 - val_f1_score: 0.7106 - lr: 5.0000e-04
# Epoch 80/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.7427e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 1.7427e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2814 - val_accuracy: 0.7284 - val_f1_score: 0.6998 - lr: 5.0000e-04
# Epoch 81/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 8.4174e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 1.1841e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3003 - val_accuracy: 0.7253 - val_f1_score: 0.7002 - lr: 5.0000e-04
# Epoch 82/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.8132e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 1.8091e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2950 - val_accuracy: 0.7284 - val_f1_score: 0.7027 - lr: 5.0000e-04
# Epoch 83/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.1589e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 2.1589e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3011 - val_accuracy: 0.7315 - val_f1_score: 0.7048 - lr: 5.0000e-04
# Epoch 84/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.1309e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 1.1309e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3668 - val_accuracy: 0.7222 - val_f1_score: 0.7036 - lr: 5.0000e-04
# Epoch 85/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.1590e-04 - accuracy: 0.9985 - f1_score: 0.9833
# Epoch 85: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 9.1590e-04 - accuracy: 0.9985 - f1_score: 0.9833 - val_loss: 2.3142 - val_accuracy: 0.7191 - val_f1_score: 0.6929 - lr: 5.0000e-04
# Epoch 86/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0046 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4051 - val_accuracy: 0.7130 - val_f1_score: 0.6883 - lr: 5.0000e-04
# Epoch 87/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0207 - accuracy: 0.9861 - f1_score: 0.9786
# Epoch 87: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0183 - accuracy: 0.9878 - f1_score: 0.9825 - val_loss: 3.1214 - val_accuracy: 0.6605 - val_f1_score: 0.6405 - lr: 5.0000e-04
# Epoch 88/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0170 - accuracy: 0.9965 - f1_score: 0.9950
# Epoch 88: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0154 - accuracy: 0.9970 - f1_score: 0.9959 - val_loss: 2.9510 - val_accuracy: 0.6667 - val_f1_score: 0.6601 - lr: 5.0000e-04
# Epoch 89/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0502 - accuracy: 0.9861 - f1_score: 0.9809
# Epoch 89: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0447 - accuracy: 0.9878 - f1_score: 0.9843 - val_loss: 2.3500 - val_accuracy: 0.7407 - val_f1_score: 0.6984 - lr: 5.0000e-04
# Epoch 90/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9893 - f1_score: 0.9816
# Epoch 90: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0394 - accuracy: 0.9893 - f1_score: 0.9816 - val_loss: 5.0809 - val_accuracy: 0.4444 - val_f1_score: 0.4880 - lr: 5.0000e-04
# Epoch 91/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0773 - accuracy: 0.9653 - f1_score: 0.9530
# Epoch 91: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0696 - accuracy: 0.9680 - f1_score: 0.9595 - val_loss: 3.5584 - val_accuracy: 0.7284 - val_f1_score: 0.4904 - lr: 5.0000e-04
# Epoch 92/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0622 - accuracy: 0.9774 - f1_score: 0.9685
# Epoch 92: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0582 - accuracy: 0.9787 - f1_score: 0.9725 - val_loss: 3.2758 - val_accuracy: 0.7346 - val_f1_score: 0.5140 - lr: 5.0000e-04
# Epoch 93/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9909 - f1_score: 0.9887
# Epoch 93: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0256 - accuracy: 0.9909 - f1_score: 0.9887 - val_loss: 3.4234 - val_accuracy: 0.7315 - val_f1_score: 0.6134 - lr: 5.0000e-04
# Epoch 94/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9985 - f1_score: 0.9976
# Epoch 94: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0060 - accuracy: 0.9985 - f1_score: 0.9976 - val_loss: 3.5124 - val_accuracy: 0.7222 - val_f1_score: 0.6023 - lr: 5.0000e-04
# Epoch 95/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8127 - val_accuracy: 0.7253 - val_f1_score: 0.6354 - lr: 5.0000e-04
# Epoch 96/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5626 - val_accuracy: 0.7284 - val_f1_score: 0.6663 - lr: 5.0000e-04
# Epoch 97/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9985 - f1_score: 0.9974
# Epoch 97: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0027 - accuracy: 0.9985 - f1_score: 0.9974 - val_loss: 2.3745 - val_accuracy: 0.7346 - val_f1_score: 0.6833 - lr: 5.0000e-04
# Epoch 98/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3015 - val_accuracy: 0.7284 - val_f1_score: 0.6786 - lr: 5.0000e-04
# Epoch 99/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 9.2260e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 99: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 8.7182e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2705 - val_accuracy: 0.7130 - val_f1_score: 0.6675 - lr: 5.0000e-04
# Epoch 100/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.0235e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 7.0235e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2458 - val_accuracy: 0.7130 - val_f1_score: 0.6694 - lr: 2.5000e-04
# Epoch 101/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.5690e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 9.5690e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2689 - val_accuracy: 0.7191 - val_f1_score: 0.6736 - lr: 2.5000e-04
# Epoch 102/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 5.2667e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2351 - val_accuracy: 0.7191 - val_f1_score: 0.6760 - lr: 2.5000e-04
# Epoch 103/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9985 - f1_score: 0.9917
# Epoch 103: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0030 - accuracy: 0.9985 - f1_score: 0.9917 - val_loss: 2.2030 - val_accuracy: 0.7253 - val_f1_score: 0.6766 - lr: 2.5000e-04
# Epoch 104/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9954 - f1_score: 0.9925
# Epoch 104: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0117 - accuracy: 0.9954 - f1_score: 0.9925 - val_loss: 2.1664 - val_accuracy: 0.7346 - val_f1_score: 0.6857 - lr: 2.5000e-04
# Epoch 105/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0028 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1407 - val_accuracy: 0.7160 - val_f1_score: 0.6772 - lr: 2.5000e-04
# Epoch 106/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9985 - f1_score: 0.9984
# Epoch 106: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0082 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 2.1545 - val_accuracy: 0.7099 - val_f1_score: 0.6795 - lr: 2.5000e-04
# Epoch 107/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1618 - val_accuracy: 0.6944 - val_f1_score: 0.6706 - lr: 2.5000e-04
# Epoch 108/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0021 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1492 - val_accuracy: 0.7068 - val_f1_score: 0.6867 - lr: 2.5000e-04
# Epoch 109/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.3969e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 39ms/step - loss: 4.3969e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1304 - val_accuracy: 0.7099 - val_f1_score: 0.6941 - lr: 2.5000e-04
# Epoch 110/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.71064
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1092 - val_accuracy: 0.7130 - val_f1_score: 0.6963 - lr: 2.5000e-04
# Epoch 111/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3267e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score improved from 0.71064 to 0.72068, saving model to best_model.h5
# 11/11 [==============================] - 1s 60ms/step - loss: 5.3267e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0103 - val_accuracy: 0.7407 - val_f1_score: 0.7207 - lr: 2.5000e-04
# Epoch 112/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0079 - accuracy: 0.9983 - f1_score: 0.9981
# Epoch 112: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0069 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 2.4870 - val_accuracy: 0.6574 - val_f1_score: 0.6398 - lr: 2.5000e-04
# Epoch 113/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0026 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4743 - val_accuracy: 0.5741 - val_f1_score: 0.5868 - lr: 2.5000e-04
# Epoch 114/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9985 - f1_score: 0.9930
# Epoch 114: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0040 - accuracy: 0.9985 - f1_score: 0.9930 - val_loss: 3.3887 - val_accuracy: 0.5772 - val_f1_score: 0.5880 - lr: 2.5000e-04
# Epoch 115/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9985 - f1_score: 0.9984
# Epoch 115: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0109 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 2.1814 - val_accuracy: 0.6975 - val_f1_score: 0.7070 - lr: 2.5000e-04
# Epoch 116/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.3389e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 39ms/step - loss: 7.3389e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1145 - val_accuracy: 0.6975 - val_f1_score: 0.7012 - lr: 2.5000e-04
# Epoch 117/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9970 - f1_score: 0.9956
# Epoch 117: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0080 - accuracy: 0.9970 - f1_score: 0.9956 - val_loss: 2.2910 - val_accuracy: 0.6883 - val_f1_score: 0.6955 - lr: 2.5000e-04
# Epoch 118/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.3791e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 118: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 5.3791e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6432 - val_accuracy: 0.6265 - val_f1_score: 0.6145 - lr: 2.5000e-04
# Epoch 119/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 119: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6127 - val_accuracy: 0.6389 - val_f1_score: 0.6217 - lr: 2.5000e-04
# Epoch 120/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.9073e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 120: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 6.9073e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5038 - val_accuracy: 0.6543 - val_f1_score: 0.6325 - lr: 2.5000e-04
# Epoch 121/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.0341e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 121: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 39ms/step - loss: 7.0341e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4648 - val_accuracy: 0.6636 - val_f1_score: 0.6390 - lr: 2.5000e-04
# Epoch 122/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.7751e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 122: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 39ms/step - loss: 2.7751e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4304 - val_accuracy: 0.6728 - val_f1_score: 0.6456 - lr: 2.5000e-04
# Epoch 123/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.0983e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 123: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 3.0983e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.
10000
# 11/11 [==============================] - ETA: 0s - loss: 1.3153e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 198: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 1.3153e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2890 - val_accuracy: 0.7037 - val_f1_score: 0.6530 - lr: 1.5625e-05
# Epoch 199/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.5299e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 199: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 1.5299e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2868 - val_accuracy: 0.7037 - val_f1_score: 0.6530 - lr: 1.5625e-05
# Epoch 200/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.8035e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 200: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 4.8035e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2850 - val_accuracy: 0.7099 - val_f1_score: 0.6574 - lr: 1.5625e-05
# Epoch 201/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.4918e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 201: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 1.4918e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2877 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 202/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.2500e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 202: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 2.2500e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2869 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 203/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.3682e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 203: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 1.3682e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2884 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 204/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.6317e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 204: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 2.6317e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2888 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 205/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.5512e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 205: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 40ms/step - loss: 2.5512e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2949 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 206/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.7702e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 206: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 42ms/step - loss: 2.7702e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2953 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 207/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 9.3986e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 207: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 1.0462e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2967 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 208/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.6365e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 208: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 3.6365e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2999 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 209/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.6874e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 209: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 1.6874e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2982 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 210/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.6166e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 210: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 41ms/step - loss: 1.6166e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2998 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 211/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.5584e-04 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 111.
#
# Epoch 211: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 211: val_f1_score did not improve from 0.72068
# 11/11 [==============================] - 0s 46ms/step - loss: 5.5584e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2994 - val_accuracy: 0.7068 - val_f1_score: 0.6552 - lr: 1.5625e-05
# Epoch 211: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 9ms/step
# 0.7407407407407407

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7407407407407407
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.51      0.54      0.52        85
#            0       0.83      0.81      0.82       239
#
#     accuracy                           0.74       324
#    macro avg       0.67      0.68      0.67       324
# weighted avg       0.75      0.74      0.74       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 240 chiếm khoảng 74.07407407407408% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 46 chiếm khoảng 54.11764705882353% so với thực tế
