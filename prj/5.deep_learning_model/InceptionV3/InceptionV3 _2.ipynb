# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # mixed 5, 6: 17 x 17 x 768
    for i in range(2):
        branch1x1 = conv1d_bn(x, 192, 1,padding='same')

        branch7x7 = conv1d_bn(x, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

        branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

        branch_pool = AveragePooling1D(
            3, strides=1, padding='same')(x)
        branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
        x = layers.concatenate(
            [branch1x1, branch7x7, branch7x7dbl, branch_pool],
            axis=channel_axis,
            name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 1280
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 320, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 320, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 384, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 384, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 384, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 384, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)


lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 128)               9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 128)               0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 128)               114688    ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 128)               9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 128)               0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 128)               16384     ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 128)               9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 128)               9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 128)               0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 128)               0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 128)               16384     ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 128)               114688    ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 128)               9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 128)               9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 128)               0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 128)               0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 192)               98304     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 192)               172032    ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 192)               24576     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 192)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 192)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 192)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 192)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 192)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 192)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 192)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 192)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 768)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 160)               122880    ['mixed4[0][0]']
#
#  batch_normalization_42 (Ba  (None, 3, 160)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 3, 160)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_43 (Conv1D)          (None, 3, 160)               179200    ['activation_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 3, 160)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 3, 160)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv1d_39 (Conv1D)          (None, 3, 160)               122880    ['mixed4[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 160)               25600     ['activation_43[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 160)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 160)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 160)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 160)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 160)               25600     ['activation_39[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 160)               179200    ['activation_44[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 160)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 160)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 160)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 160)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 768)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               147456    ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               215040    ['activation_40[0][0]']
#
#  conv1d_46 (Conv1D)          (None, 3, 192)               30720     ['activation_45[0][0]']
#
#  conv1d_47 (Conv1D)          (None, 3, 192)               147456    ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 3, 192)               9         ['conv1d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 3, 192)               9         ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 3, 192)               0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 3, 192)               0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_46[0][0]',
#                                                                      'activation_47[0][0]']
#
#  conv1d_52 (Conv1D)          (None, 3, 160)               122880    ['mixed5[0][0]']
#
#  batch_normalization_52 (Ba  (None, 3, 160)               9         ['conv1d_52[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 3, 160)               0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv1d_53 (Conv1D)          (None, 3, 160)               179200    ['activation_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 3, 160)               9         ['conv1d_53[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 3, 160)               0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv1d_49 (Conv1D)          (None, 3, 160)               122880    ['mixed5[0][0]']
#
#  conv1d_54 (Conv1D)          (None, 3, 160)               25600     ['activation_53[0][0]']
#
#  batch_normalization_49 (Ba  (None, 3, 160)               9         ['conv1d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_54 (Ba  (None, 3, 160)               9         ['conv1d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 3, 160)               0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 3, 160)               0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv1d_50 (Conv1D)          (None, 3, 160)               25600     ['activation_49[0][0]']
#
#  conv1d_55 (Conv1D)          (None, 3, 160)               179200    ['activation_54[0][0]']
#
#  batch_normalization_50 (Ba  (None, 3, 160)               9         ['conv1d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_55 (Ba  (None, 3, 160)               9         ['conv1d_55[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 3, 160)               0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_55 (Activation)  (None, 3, 160)               0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  average_pooling1d_5 (Avera  (None, 3, 768)               0         ['mixed5[0][0]']
#  gePooling1D)
#
#  conv1d_48 (Conv1D)          (None, 3, 192)               147456    ['mixed5[0][0]']
#
#  conv1d_51 (Conv1D)          (None, 3, 192)               215040    ['activation_50[0][0]']
#
#  conv1d_56 (Conv1D)          (None, 3, 192)               30720     ['activation_55[0][0]']
#
#  conv1d_57 (Conv1D)          (None, 3, 192)               147456    ['average_pooling1d_5[0][0]']
#
#  batch_normalization_48 (Ba  (None, 3, 192)               9         ['conv1d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_51 (Ba  (None, 3, 192)               9         ['conv1d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 3, 192)               9         ['conv1d_56[0][0]']
#  tchNormalization)
#
#  batch_normalization_57 (Ba  (None, 3, 192)               9         ['conv1d_57[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 3, 192)               0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 3, 192)               0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  activation_56 (Activation)  (None, 3, 192)               0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  activation_57 (Activation)  (None, 3, 192)               0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  mixed6 (Concatenate)        (None, 3, 768)               0         ['activation_48[0][0]',
#                                                                      'activation_51[0][0]',
#                                                                      'activation_56[0][0]',
#                                                                      'activation_57[0][0]']
#
#  conv1d_62 (Conv1D)          (None, 3, 192)               147456    ['mixed6[0][0]']
#
#  batch_normalization_62 (Ba  (None, 3, 192)               9         ['conv1d_62[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 3, 192)               0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv1d_63 (Conv1D)          (None, 3, 192)               258048    ['activation_62[0][0]']
#
#  batch_normalization_63 (Ba  (None, 3, 192)               9         ['conv1d_63[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 3, 192)               0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv1d_59 (Conv1D)          (None, 3, 192)               147456    ['mixed6[0][0]']
#
#  conv1d_64 (Conv1D)          (None, 3, 192)               36864     ['activation_63[0][0]']
#
#  batch_normalization_59 (Ba  (None, 3, 192)               9         ['conv1d_59[0][0]']
#  tchNormalization)
#
#  batch_normalization_64 (Ba  (None, 3, 192)               9         ['conv1d_64[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 3, 192)               0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  activation_64 (Activation)  (None, 3, 192)               0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv1d_60 (Conv1D)          (None, 3, 192)               36864     ['activation_59[0][0]']
#
#  conv1d_65 (Conv1D)          (None, 3, 192)               258048    ['activation_64[0][0]']
#
#  batch_normalization_60 (Ba  (None, 3, 192)               9         ['conv1d_60[0][0]']
#  tchNormalization)
#
#  batch_normalization_65 (Ba  (None, 3, 192)               9         ['conv1d_65[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 3, 192)               0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  activation_65 (Activation)  (None, 3, 192)               0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  average_pooling1d_6 (Avera  (None, 3, 768)               0         ['mixed6[0][0]']
#  gePooling1D)
#
#  conv1d_58 (Conv1D)          (None, 3, 192)               147456    ['mixed6[0][0]']
#
#  conv1d_61 (Conv1D)          (None, 3, 192)               258048    ['activation_60[0][0]']
#
#  conv1d_66 (Conv1D)          (None, 3, 192)               36864     ['activation_65[0][0]']
#
#  conv1d_67 (Conv1D)          (None, 3, 192)               147456    ['average_pooling1d_6[0][0]']
#
#  batch_normalization_58 (Ba  (None, 3, 192)               9         ['conv1d_58[0][0]']
#  tchNormalization)
#
#  batch_normalization_61 (Ba  (None, 3, 192)               9         ['conv1d_61[0][0]']
#  tchNormalization)
#
#  batch_normalization_66 (Ba  (None, 3, 192)               9         ['conv1d_66[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 3, 192)               9         ['conv1d_67[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 3, 192)               0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  activation_61 (Activation)  (None, 3, 192)               0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  activation_66 (Activation)  (None, 3, 192)               0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  activation_67 (Activation)  (None, 3, 192)               0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_58[0][0]',
#                                                                      'activation_61[0][0]',
#                                                                      'activation_66[0][0]',
#                                                                      'activation_67[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 5168225 (19.72 MB)
# Trainable params: 5167543 (19.71 MB)
# Non-trainable params: 682 (2.66 KB)
# __________________________________________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[checkpointer,early_stopping,lr_scheduler])
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2108 - accuracy: 0.5885 - f1_score: 0.5885
# Epoch 1: val_loss improved from inf to 0.91719, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 18s 195ms/step - loss: 1.1834 - accuracy: 0.5978 - f1_score: 0.6024 - val_loss: 0.9172 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5699 - accuracy: 0.7365 - f1_score: 0.7365
# Epoch 2: val_loss improved from 0.91719 to 0.88003, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 1s 83ms/step - loss: 0.5640 - accuracy: 0.7365 - f1_score: 0.7366 - val_loss: 0.8800 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4112 - accuracy: 0.8333 - f1_score: 0.8333
# Epoch 3: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.4198 - accuracy: 0.8244 - f1_score: 0.8199 - val_loss: 0.9848 - val_accuracy: 0.2654 - val_f1_score: 0.2630 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8244 - f1_score: 0.8271
# Epoch 4: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.4099 - accuracy: 0.8244 - f1_score: 0.8271 - val_loss: 0.8963 - val_accuracy: 0.6543 - val_f1_score: 0.6693 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3685 - accuracy: 0.8531 - f1_score: 0.8531
# Epoch 5: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.3627 - accuracy: 0.8553 - f1_score: 0.8564 - val_loss: 1.4614 - val_accuracy: 0.2654 - val_f1_score: 0.2630 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2930 - accuracy: 0.8792 - f1_score: 0.8792
# Epoch 6: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.2890 - accuracy: 0.8812 - f1_score: 0.8823 - val_loss: 1.7776 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2536 - accuracy: 0.8875 - f1_score: 0.8875
# Epoch 7: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.2598 - accuracy: 0.8852 - f1_score: 0.8841 - val_loss: 2.1143 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2172 - accuracy: 0.9177 - f1_score: 0.9177
# Epoch 8: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.2164 - accuracy: 0.9172 - f1_score: 0.9169 - val_loss: 2.6220 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1707 - accuracy: 0.9333 - f1_score: 0.9333
# Epoch 9: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.1832 - accuracy: 0.9271 - f1_score: 0.9241 - val_loss: 2.3488 - val_accuracy: 0.3549 - val_f1_score: 0.3385 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1866 - accuracy: 0.9250 - f1_score: 0.9250
# Epoch 10: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.1862 - accuracy: 0.9251 - f1_score: 0.9252 - val_loss: 3.1265 - val_accuracy: 0.2747 - val_f1_score: 0.2708 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1366 - accuracy: 0.9479 - f1_score: 0.9479
# Epoch 11: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.1516 - accuracy: 0.9451 - f1_score: 0.9437 - val_loss: 2.7477 - val_accuracy: 0.3735 - val_f1_score: 0.3932 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1957 - accuracy: 0.9135 - f1_score: 0.9135
# Epoch 12: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.1953 - accuracy: 0.9142 - f1_score: 0.9145 - val_loss: 1.2120 - val_accuracy: 0.6389 - val_f1_score: 0.6953 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1544 - accuracy: 0.9458 - f1_score: 0.9458
# Epoch 13: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 60ms/step - loss: 0.1572 - accuracy: 0.9441 - f1_score: 0.9433 - val_loss: 1.3017 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1077 - accuracy: 0.9604 - f1_score: 0.9604
# Epoch 14: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.1162 - accuracy: 0.9571 - f1_score: 0.9555 - val_loss: 2.9788 - val_accuracy: 0.3519 - val_f1_score: 0.3750 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1122 - accuracy: 0.9583 - f1_score: 0.9583
# Epoch 15: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.1112 - accuracy: 0.9581 - f1_score: 0.9580 - val_loss: 1.5521 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0925 - accuracy: 0.9625 - f1_score: 0.9625
# Epoch 16: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0981 - accuracy: 0.9621 - f1_score: 0.9619 - val_loss: 2.2882 - val_accuracy: 0.5031 - val_f1_score: 0.5417 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0663 - accuracy: 0.9740 - f1_score: 0.9740
# Epoch 17: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0806 - accuracy: 0.9691 - f1_score: 0.9667 - val_loss: 1.4423 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1243 - accuracy: 0.9552 - f1_score: 0.9552
# Epoch 18: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.1247 - accuracy: 0.9541 - f1_score: 0.9535 - val_loss: 2.5488 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0902 - accuracy: 0.9688 - f1_score: 0.9688
# Epoch 19: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0879 - accuracy: 0.9691 - f1_score: 0.9692 - val_loss: 1.4669 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0697 - accuracy: 0.9740 - f1_score: 0.9740
# Epoch 20: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0685 - accuracy: 0.9741 - f1_score: 0.9741 - val_loss: 2.4298 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0430 - accuracy: 0.9833 - f1_score: 0.9833
# Epoch 21: val_loss did not improve from 0.88003
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0419 - accuracy: 0.9840 - f1_score: 0.9844 - val_loss: 1.6563 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0169 - accuracy: 0.9927 - f1_score: 0.9927
# Epoch 22: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0163 - accuracy: 0.9930 - f1_score: 0.9932 - val_loss: 1.6388 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 5.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 23: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0060 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.7218 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 5.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 24: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0084 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.6989 - val_accuracy: 0.7377 - val_f1_score: 0.7786 - lr: 5.0000e-04
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0044 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 25: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0045 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.7667 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 5.0000e-04
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 26: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0047 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.0788 - val_accuracy: 0.7377 - val_f1_score: 0.7786 - lr: 5.0000e-04
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0198 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 27: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0201 - accuracy: 0.9910 - f1_score: 0.9907 - val_loss: 1.9642 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 5.0000e-04
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0421 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 28: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0433 - accuracy: 0.9910 - f1_score: 0.9907 - val_loss: 1.7608 - val_accuracy: 0.7500 - val_f1_score: 0.7500 - lr: 5.0000e-04
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0247 - accuracy: 0.9885 - f1_score: 0.9885
# Epoch 29: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0261 - accuracy: 0.9870 - f1_score: 0.9863 - val_loss: 1.9594 - val_accuracy: 0.6698 - val_f1_score: 0.7214 - lr: 5.0000e-04
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0192 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 30: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0191 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 2.8048 - val_accuracy: 0.7500 - val_f1_score: 0.7500 - lr: 5.0000e-04
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0128 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 31: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0124 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 1.9685 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 5.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 32: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0078 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.8160 - val_accuracy: 0.7191 - val_f1_score: 0.7240 - lr: 5.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 33: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0055 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.7617 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 5.0000e-04
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0028 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 34: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0028 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.8423 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 5.0000e-04
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0040 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 35: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0039 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 1.9795 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 5.0000e-04
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 36: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0012 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 5.0000e-04
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0207 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 37: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0264 - accuracy: 0.9930 - f1_score: 0.9921 - val_loss: 2.1520 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 5.0000e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0336 - accuracy: 0.9875 - f1_score: 0.9875
# Epoch 38: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0327 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 2.4601 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 5.0000e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0147 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 39: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0149 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 2.0351 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 5.0000e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0107 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 40: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0104 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.3892 - val_accuracy: 0.6235 - val_f1_score: 0.6432 - lr: 5.0000e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0091 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 41: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0088 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.2195 - val_accuracy: 0.7191 - val_f1_score: 0.7240 - lr: 5.0000e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0244 - accuracy: 0.9896 - f1_score: 0.9896
# Epoch 42: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0236 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 3.5806 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 43: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0040 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.2475 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 44: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1057 - val_accuracy: 0.6914 - val_f1_score: 0.7005 - lr: 5.0000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0115 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 45: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0119 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 2.0658 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 5.0000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0265 - accuracy: 0.9927 - f1_score: 0.9927
# Epoch 46: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0262 - accuracy: 0.9920 - f1_score: 0.9917 - val_loss: 3.1657 - val_accuracy: 0.7469 - val_f1_score: 0.7474 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 47: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0246 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 2.7074 - val_accuracy: 0.5525 - val_f1_score: 0.5443 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 48: val_loss did not improve from 0.88003
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0101 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.2229 - val_accuracy: 0.6481 - val_f1_score: 0.6250 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 49: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0049 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0233 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 2.5000e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0049 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 50: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0047 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.2406 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 2.5000e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 51: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0664 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 2.5000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0067 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 52: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0064 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9595 - val_accuracy: 0.6883 - val_f1_score: 0.6979 - lr: 2.5000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1314 - val_accuracy: 0.7438 - val_f1_score: 0.7448 - lr: 2.5000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.9910e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 9.0371e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1724 - val_accuracy: 0.7469 - val_f1_score: 0.7474 - lr: 2.5000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 55: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0024 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.0450 - val_accuracy: 0.7037 - val_f1_score: 0.7109 - lr: 2.5000e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 56: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0018 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.0186 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 2.5000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.6699e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_loss did not improve from 0.88003
# 16/16 [==============================] - 1s 66ms/step - loss: 6.5002e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0765 - val_accuracy: 0.7253 - val_f1_score: 0.7292 - lr: 2.5000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.7638e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 58: val_loss did not improve from 0.88003
# Restoring model weights from the end of the best epoch: 28.
# 16/16 [==============================] - 1s 68ms/step - loss: 2.7233e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0801 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 2.5000e-04
# Epoch 58: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 13ms/step
# 0.75

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.75
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.53      0.36      0.43        85
#            0       0.80      0.89      0.84       239
#
#     accuracy                           0.75       324
#    macro avg       0.67      0.63      0.64       324
# weighted avg       0.73      0.75      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 243 chiếm khoảng 75.0% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 31 chiếm khoảng 36.470588235294116% so với thực tế
