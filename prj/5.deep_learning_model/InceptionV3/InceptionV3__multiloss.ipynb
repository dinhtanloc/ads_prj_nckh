# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 128, 1,padding='same')

    branch7x7 = conv1d_bn(x, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 128, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # # mixed 5, 6: 17 x 17 x 768
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    #     branch7x7 = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    #     branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch7x7, branch7x7dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 960
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 288, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 288, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 256, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 256, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 256, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 256, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss=multi_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 96)                9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 96)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 96)                64512     ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 96)                9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 96)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 96)                9216      ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 96)                9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 96)                9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 96)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 96)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 96)                9216      ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 96)                64512     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 96)                9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 96)                9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 96)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 96)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 128)               86016     ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 128)               12288     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 128)               65536     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 128)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 128)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 128)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 128)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 128)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 128)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 128)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 128)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 512)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 192)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 3, 192)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 192)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 3, 192)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 192)               36864     ['activation_39[0][0]']
#
#  conv1d_43 (Conv1D)          (None, 3, 192)               258048    ['activation_42[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 192)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 3, 192)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 192)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 3, 192)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 512)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               258048    ['activation_40[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 192)               36864     ['activation_43[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 192)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 192)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 192)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 192)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_44[0][0]',
#                                                                      'activation_45[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1973147 (7.53 MB)
# Trainable params: 1972597 (7.52 MB)
# Non-trainable params: 550 (2.15 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5441 - accuracy: 0.6135 - f1_score: 0.5357
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 14s 127ms/step - loss: 0.5379 - accuracy: 0.6178 - f1_score: 0.5468 - val_loss: 0.4856 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3332 - accuracy: 0.7365 - f1_score: 0.7345
# Epoch 2: val_f1_score improved from 0.42467 to 0.50690, saving model to best_model.h5
# 16/16 [==============================] - 1s 52ms/step - loss: 0.3342 - accuracy: 0.7355 - f1_score: 0.7326 - val_loss: 0.3396 - val_accuracy: 0.7160 - val_f1_score: 0.5069 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2656 - accuracy: 0.8000 - f1_score: 0.7985
# Epoch 3: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2655 - accuracy: 0.7984 - f1_score: 0.7959 - val_loss: 0.4826 - val_accuracy: 0.4259 - val_f1_score: 0.4697 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2228 - accuracy: 0.8344 - f1_score: 0.8331
# Epoch 4: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2216 - accuracy: 0.8353 - f1_score: 0.8345 - val_loss: 0.6980 - val_accuracy: 0.2994 - val_f1_score: 0.2508 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1948 - accuracy: 0.8458 - f1_score: 0.8447
# Epoch 5: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1964 - accuracy: 0.8463 - f1_score: 0.8454 - val_loss: 0.7136 - val_accuracy: 0.2932 - val_f1_score: 0.2465 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1563 - accuracy: 0.8813 - f1_score: 0.8807
# Epoch 6: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1657 - accuracy: 0.8752 - f1_score: 0.8716 - val_loss: 0.6048 - val_accuracy: 0.4136 - val_f1_score: 0.4995 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1397 - accuracy: 0.9031 - f1_score: 0.9026
# Epoch 7: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1395 - accuracy: 0.9022 - f1_score: 0.9012 - val_loss: 1.0898 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1153 - accuracy: 0.9177 - f1_score: 0.9173
# Epoch 8: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1224 - accuracy: 0.9132 - f1_score: 0.9105 - val_loss: 1.1241 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1481 - accuracy: 0.8979 - f1_score: 0.8970
# Epoch 9: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1469 - accuracy: 0.8972 - f1_score: 0.8958 - val_loss: 0.9110 - val_accuracy: 0.2809 - val_f1_score: 0.2283 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0959 - accuracy: 0.9292 - f1_score: 0.9286
# Epoch 10: val_f1_score did not improve from 0.50690
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1036 - accuracy: 0.9251 - f1_score: 0.9226 - val_loss: 0.6578 - val_accuracy: 0.4167 - val_f1_score: 0.5013 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0907 - accuracy: 0.9333 - f1_score: 0.9327
# Epoch 11: val_f1_score improved from 0.50690 to 0.51190, saving model to best_model.h5
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0928 - accuracy: 0.9321 - f1_score: 0.9310 - val_loss: 0.6654 - val_accuracy: 0.4259 - val_f1_score: 0.5119 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9351 - f1_score: 0.9354
# Epoch 12: val_f1_score improved from 0.51190 to 0.53829, saving model to best_model.h5
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0820 - accuracy: 0.9351 - f1_score: 0.9354 - val_loss: 0.6447 - val_accuracy: 0.4568 - val_f1_score: 0.5383 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0794 - accuracy: 0.9448 - f1_score: 0.9442
# Epoch 13: val_f1_score did not improve from 0.53829
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0836 - accuracy: 0.9411 - f1_score: 0.9388 - val_loss: 0.7940 - val_accuracy: 0.3611 - val_f1_score: 0.4511 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0600 - accuracy: 0.9563 - f1_score: 0.9559
# Epoch 14: val_f1_score improved from 0.53829 to 0.67765, saving model to best_model.h5
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0636 - accuracy: 0.9531 - f1_score: 0.9512 - val_loss: 0.4063 - val_accuracy: 0.6759 - val_f1_score: 0.6776 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0590 - accuracy: 0.9594 - f1_score: 0.9590
# Epoch 15: val_f1_score did not improve from 0.67765
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0585 - accuracy: 0.9601 - f1_score: 0.9601 - val_loss: 1.1971 - val_accuracy: 0.2778 - val_f1_score: 0.2251 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0755 - accuracy: 0.9490 - f1_score: 0.9481
# Epoch 16: val_f1_score did not improve from 0.67765
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0756 - accuracy: 0.9491 - f1_score: 0.9483 - val_loss: 0.8769 - val_accuracy: 0.3981 - val_f1_score: 0.4066 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0511 - accuracy: 0.9635 - f1_score: 0.9631
# Epoch 17: val_f1_score did not improve from 0.67765
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0504 - accuracy: 0.9641 - f1_score: 0.9640 - val_loss: 0.4352 - val_accuracy: 0.7315 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9677 - f1_score: 0.9675
# Epoch 18: val_f1_score did not improve from 0.67765
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0430 - accuracy: 0.9691 - f1_score: 0.9695 - val_loss: 0.6788 - val_accuracy: 0.4599 - val_f1_score: 0.5406 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0630 - accuracy: 0.9552 - f1_score: 0.9548
# Epoch 19: val_f1_score improved from 0.67765 to 0.69038, saving model to best_model.h5
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0630 - accuracy: 0.9541 - f1_score: 0.9529 - val_loss: 0.3786 - val_accuracy: 0.7160 - val_f1_score: 0.6904 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0526 - accuracy: 0.9615 - f1_score: 0.9611
# Epoch 20: val_f1_score did not improve from 0.69038
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0506 - accuracy: 0.9631 - f1_score: 0.9636 - val_loss: 0.6117 - val_accuracy: 0.5093 - val_f1_score: 0.5804 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0413 - accuracy: 0.9729 - f1_score: 0.9723
# Epoch 21: val_f1_score improved from 0.69038 to 0.71257, saving model to best_model.h5
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0420 - accuracy: 0.9731 - f1_score: 0.9725 - val_loss: 0.3449 - val_accuracy: 0.7593 - val_f1_score: 0.7126 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0394 - accuracy: 0.9740 - f1_score: 0.9738
# Epoch 22: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0409 - accuracy: 0.9731 - f1_score: 0.9724 - val_loss: 0.5793 - val_accuracy: 0.5648 - val_f1_score: 0.5814 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0318 - accuracy: 0.9781 - f1_score: 0.9780
# Epoch 23: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0308 - accuracy: 0.9790 - f1_score: 0.9794 - val_loss: 0.6855 - val_accuracy: 0.5000 - val_f1_score: 0.5738 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0432 - accuracy: 0.9677 - f1_score: 0.9670
# Epoch 24: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0435 - accuracy: 0.9681 - f1_score: 0.9676 - val_loss: 0.6356 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0439 - accuracy: 0.9677 - f1_score: 0.9671
# Epoch 25: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0431 - accuracy: 0.9681 - f1_score: 0.9676 - val_loss: 0.4368 - val_accuracy: 0.7377 - val_f1_score: 0.6490 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0350 - accuracy: 0.9771 - f1_score: 0.9765
# Epoch 26: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0346 - accuracy: 0.9770 - f1_score: 0.9765 - val_loss: 0.4778 - val_accuracy: 0.7253 - val_f1_score: 0.5023 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0425 - accuracy: 0.9719 - f1_score: 0.9714
# Epoch 27: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0433 - accuracy: 0.9721 - f1_score: 0.9717 - val_loss: 0.5798 - val_accuracy: 0.7438 - val_f1_score: 0.4589 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0390 - accuracy: 0.9740 - f1_score: 0.9737
# Epoch 28: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0379 - accuracy: 0.9750 - f1_score: 0.9754 - val_loss: 0.6389 - val_accuracy: 0.5309 - val_f1_score: 0.5932 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0310 - accuracy: 0.9781 - f1_score: 0.9778
# Epoch 29: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0314 - accuracy: 0.9780 - f1_score: 0.9777 - val_loss: 0.4718 - val_accuracy: 0.7346 - val_f1_score: 0.6155 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0355 - accuracy: 0.9719 - f1_score: 0.9712
# Epoch 30: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0366 - accuracy: 0.9711 - f1_score: 0.9700 - val_loss: 0.3969 - val_accuracy: 0.7315 - val_f1_score: 0.7003 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0327 - accuracy: 0.9760 - f1_score: 0.9759
# Epoch 31: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0329 - accuracy: 0.9760 - f1_score: 0.9758 - val_loss: 0.4102 - val_accuracy: 0.7160 - val_f1_score: 0.6707 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0233 - accuracy: 0.9823 - f1_score: 0.9820
# Epoch 32: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0224 - accuracy: 0.9830 - f1_score: 0.9832 - val_loss: 0.4392 - val_accuracy: 0.6543 - val_f1_score: 0.6662 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0195 - accuracy: 0.9844 - f1_score: 0.9839
# Epoch 33: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0188 - accuracy: 0.9850 - f1_score: 0.9849 - val_loss: 0.4133 - val_accuracy: 0.7377 - val_f1_score: 0.6536 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0327 - accuracy: 0.9802 - f1_score: 0.9793
# Epoch 34: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0325 - accuracy: 0.9810 - f1_score: 0.9806 - val_loss: 0.5640 - val_accuracy: 0.7407 - val_f1_score: 0.4479 - lr: 0.0010
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9731 - f1_score: 0.9734
# Epoch 35: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0349 - accuracy: 0.9731 - f1_score: 0.9734 - val_loss: 0.4359 - val_accuracy: 0.7593 - val_f1_score: 0.5454 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0360 - accuracy: 0.9740 - f1_score: 0.9738
# Epoch 36: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0345 - accuracy: 0.9750 - f1_score: 0.9754 - val_loss: 0.4467 - val_accuracy: 0.6944 - val_f1_score: 0.6855 - lr: 0.0010
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0164 - accuracy: 0.9875 - f1_score: 0.9873
# Epoch 37: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0164 - accuracy: 0.9880 - f1_score: 0.9881 - val_loss: 0.5892 - val_accuracy: 0.7377 - val_f1_score: 0.4585 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0078 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 38: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0107 - accuracy: 0.9930 - f1_score: 0.9914 - val_loss: 0.4410 - val_accuracy: 0.7160 - val_f1_score: 0.6488 - lr: 0.0010
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0119 - accuracy: 0.9917 - f1_score: 0.9915
# Epoch 39: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0116 - accuracy: 0.9920 - f1_score: 0.9920 - val_loss: 0.5690 - val_accuracy: 0.7346 - val_f1_score: 0.4648 - lr: 0.0010
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0082 - accuracy: 0.9927 - f1_score: 0.9927
# Epoch 40: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0080 - accuracy: 0.9930 - f1_score: 0.9931 - val_loss: 0.4729 - val_accuracy: 0.7346 - val_f1_score: 0.6378 - lr: 0.0010
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9865 - f1_score: 0.9863
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 41: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0157 - accuracy: 0.9870 - f1_score: 0.9872 - val_loss: 0.4384 - val_accuracy: 0.7037 - val_f1_score: 0.6474 - lr: 0.0010
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0087 - accuracy: 0.9917 - f1_score: 0.9916
# Epoch 42: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0091 - accuracy: 0.9910 - f1_score: 0.9905 - val_loss: 0.4255 - val_accuracy: 0.7191 - val_f1_score: 0.6779 - lr: 5.0000e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 43: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0057 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.4590 - val_accuracy: 0.7284 - val_f1_score: 0.6434 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0077 - accuracy: 0.9948 - f1_score: 0.9946
# Epoch 44: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0077 - accuracy: 0.9950 - f1_score: 0.9950 - val_loss: 0.4532 - val_accuracy: 0.7284 - val_f1_score: 0.6340 - lr: 5.0000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0058 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 45: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0056 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.4134 - val_accuracy: 0.7346 - val_f1_score: 0.6819 - lr: 5.0000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0055 - accuracy: 0.9979 - f1_score: 0.9978
# Epoch 46: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0053 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.6226 - val_accuracy: 0.5463 - val_f1_score: 0.5670 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0038 - accuracy: 0.9969 - f1_score: 0.9967
# Epoch 47: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0043 - accuracy: 0.9960 - f1_score: 0.9953 - val_loss: 0.6771 - val_accuracy: 0.5123 - val_f1_score: 0.5417 - lr: 5.0000e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 48: val_f1_score did not improve from 0.71257
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0051 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 0.3816 - val_accuracy: 0.7253 - val_f1_score: 0.7053 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0039 - accuracy: 0.9969 - f1_score: 0.9968
# Epoch 49: val_f1_score improved from 0.71257 to 0.71449, saving model to best_model.h5
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0039 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.3757 - val_accuracy: 0.7315 - val_f1_score: 0.7145 - lr: 5.0000e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0035 - accuracy: 0.9979 - f1_score: 0.9978
# Epoch 50: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0033 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.3708 - val_accuracy: 0.7407 - val_f1_score: 0.6991 - lr: 5.0000e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 51: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.4110 - val_accuracy: 0.7407 - val_f1_score: 0.6573 - lr: 5.0000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0081 - accuracy: 0.9927 - f1_score: 0.9925
# Epoch 52: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0083 - accuracy: 0.9920 - f1_score: 0.9915 - val_loss: 0.6614 - val_accuracy: 0.5062 - val_f1_score: 0.5789 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4038 - val_accuracy: 0.7130 - val_f1_score: 0.6900 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 54: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0024 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.4718 - val_accuracy: 0.6451 - val_f1_score: 0.6643 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.8699e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 55: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0018 - accuracy: 0.9990 - f1_score: 0.9985 - val_loss: 0.4471 - val_accuracy: 0.6605 - val_f1_score: 0.6663 - lr: 5.0000e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.5226e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 56: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.2797e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.6821 - val_f1_score: 0.6833 - lr: 5.0000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0094e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.5243e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4287 - val_accuracy: 0.6914 - val_f1_score: 0.6862 - lr: 5.0000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0032 - accuracy: 0.9979 - f1_score: 0.9977
# Epoch 58: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0031 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.4321 - val_accuracy: 0.7346 - val_f1_score: 0.6472 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0055 - accuracy: 0.9958 - f1_score: 0.9954
# Epoch 59: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0053 - accuracy: 0.9960 - f1_score: 0.9957 - val_loss: 0.3820 - val_accuracy: 0.7222 - val_f1_score: 0.7143 - lr: 5.0000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0028 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 60: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0027 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.6756 - val_accuracy: 0.5093 - val_f1_score: 0.5381 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2746e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.2291e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.6296 - val_f1_score: 0.6640 - lr: 5.0000e-04
# Epoch 62/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.9068e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 41ms/step - loss: 1.9068e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.6883 - val_f1_score: 0.7037 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0002e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 9.6627e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.6852 - val_f1_score: 0.7006 - lr: 5.0000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 64: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 0.4206 - val_accuracy: 0.6883 - val_f1_score: 0.6935 - lr: 5.0000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3235e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3020e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.6975 - val_f1_score: 0.6987 - lr: 5.0000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.9373e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 3.7910e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.7006 - val_f1_score: 0.7000 - lr: 5.0000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.2519e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.3403e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4082 - val_accuracy: 0.7068 - val_f1_score: 0.7045 - lr: 5.0000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.4203e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 68: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 6.2000e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4122 - val_accuracy: 0.7006 - val_f1_score: 0.7011 - lr: 5.0000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5180e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 69: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 5.8312e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.6481 - val_f1_score: 0.6731 - lr: 5.0000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.2007e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 4.0287e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.6574 - val_f1_score: 0.6737 - lr: 2.5000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5624e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 5.1014e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4422 - val_accuracy: 0.6759 - val_f1_score: 0.6871 - lr: 2.5000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1261e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 2.0587e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.6790 - val_f1_score: 0.6892 - lr: 2.5000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2450e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.8456e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.6914 - val_f1_score: 0.6978 - lr: 2.5000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4925e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.4693e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4145 - val_accuracy: 0.7037 - val_f1_score: 0.6877 - lr: 2.5000e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2881e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.2735e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.7130 - val_f1_score: 0.6941 - lr: 2.5000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.2024e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 8.9682e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4081 - val_accuracy: 0.7099 - val_f1_score: 0.6920 - lr: 2.5000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6679e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.6697e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4084 - val_accuracy: 0.7068 - val_f1_score: 0.6900 - lr: 2.5000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.6566e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 4.5094e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4088 - val_accuracy: 0.7037 - val_f1_score: 0.6878 - lr: 2.5000e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.0049e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.8112e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.7068 - val_f1_score: 0.6915 - lr: 2.5000e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6095e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.5636e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4087 - val_accuracy: 0.7099 - val_f1_score: 0.6950 - lr: 2.5000e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3352e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 1.2845e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.7191 - val_f1_score: 0.6971 - lr: 2.5000e-04
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.5195e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 5.9641e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3968 - val_accuracy: 0.7253 - val_f1_score: 0.7039 - lr: 2.5000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9508e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 2.9282e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3962 - val_accuracy: 0.7253 - val_f1_score: 0.7039 - lr: 2.5000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7059e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 4.5426e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.7253 - val_f1_score: 0.7078 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7380e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 85: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.8027e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.7253 - val_f1_score: 0.7039 - lr: 2.5000e-04
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.0828e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 3.0828e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3962 - val_accuracy: 0.7222 - val_f1_score: 0.7017 - lr: 2.5000e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.7048e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 5.4946e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.7253 - val_f1_score: 0.6875 - lr: 2.5000e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5579e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 4.3883e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.7222 - val_f1_score: 0.6653 - lr: 2.5000e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.8975e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 89: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 5.8209e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.7284 - val_f1_score: 0.6694 - lr: 2.5000e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.1033e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 4.9230e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.7253 - val_f1_score: 0.6749 - lr: 1.2500e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.6402e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9990 - f1_score: 0.9982 - val_loss: 0.4015 - val_accuracy: 0.7315 - val_f1_score: 0.6908 - lr: 1.2500e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.8913e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 9.5363e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3938 - val_accuracy: 0.7284 - val_f1_score: 0.7103 - lr: 1.2500e-04
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.8773e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 2.8773e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.7191 - val_f1_score: 0.7046 - lr: 1.2500e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7359e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.6445e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3863 - val_accuracy: 0.7346 - val_f1_score: 0.7059 - lr: 1.2500e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.5826e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.3440e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.7253 - val_f1_score: 0.7046 - lr: 1.2500e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2202e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1727e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3860 - val_accuracy: 0.7407 - val_f1_score: 0.7144 - lr: 1.2500e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.1118e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.8965e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3865 - val_accuracy: 0.7438 - val_f1_score: 0.7141 - lr: 1.2500e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0787e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 3.1969e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.7222 - val_f1_score: 0.7056 - lr: 1.2500e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.8348e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 4.7246e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.6852 - val_f1_score: 0.6979 - lr: 1.2500e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.1091e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 5.0984e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4438 - val_accuracy: 0.6790 - val_f1_score: 0.6934 - lr: 1.2500e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.7870e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 2.6800e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4514 - val_accuracy: 0.6698 - val_f1_score: 0.6872 - lr: 1.2500e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.4782e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 3.4115e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4631 - val_accuracy: 0.6543 - val_f1_score: 0.6762 - lr: 1.2500e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.1157e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 2.5170e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4449 - val_accuracy: 0.6728 - val_f1_score: 0.6883 - lr: 1.2500e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.5542e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 3.4067e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4340 - val_accuracy: 0.6883 - val_f1_score: 0.6993 - lr: 1.2500e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3833e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3460e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4280 - val_accuracy: 0.6944 - val_f1_score: 0.7017 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.8647e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 9.5014e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.7068 - val_f1_score: 0.7104 - lr: 1.2500e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5021e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 4.3381e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.1129e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 3.9772e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4150 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 1.2500e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5743e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 109: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 1.5784e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 1.2500e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.1704e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 2.0935e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 6.2500e-05
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2730e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.2766e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4110 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4436e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 112: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 1.4562e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4107 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.9205e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.8356e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.7099 - val_f1_score: 0.7100 - lr: 6.2500e-05
# Epoch 114/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.1833e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 114: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 4.1833e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4107 - val_accuracy: 0.7099 - val_f1_score: 0.7098 - lr: 6.2500e-05
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0885e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 115: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0590e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.5386e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 9.1536e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.7130 - val_f1_score: 0.7119 - lr: 6.2500e-05
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.6119e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 117: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 2.5197e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.7099 - val_f1_score: 0.7098 - lr: 6.2500e-05
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.3227e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 118: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.4740e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.7099 - val_f1_score: 0.7098 - lr: 6.2500e-05
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.3872e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 119: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 2.3123e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4117 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4055e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 120: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.3763e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4120 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 121/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.2053e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 121: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 1.2053e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1625e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 122: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1185e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4126 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4034e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 123: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 1.6232e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4126 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.1347e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 124: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.2732e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.7068 - val_f1_score: 0.7077 - lr: 6.2500e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4444e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 125: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 2.3669e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.7099 - val_f1_score: 0.7098 - lr: 6.2500e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5467e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 126: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.5819e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.7130 - val_f1_score: 0.7119 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9623e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 127: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 2.8772e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.7099 - val_f1_score: 0.7098 - lr: 6.2500e-05
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5251e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 128: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 38ms/step - loss: 2.4865e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.7130 - val_f1_score: 0.7119 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.9799e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 129: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 129: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 5.8934e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.9494e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 130: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 38ms/step - loss: 3.8098e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8175e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 131: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 1.8150e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9945e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 132: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 5.4519e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 133/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2825e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 133: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 1.3020e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4162 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 134/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6559e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 134: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 1.6559e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4160 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 135/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.3170e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 135: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 35ms/step - loss: 3.2405e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 136/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4510e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 136: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.4264e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.7307e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 137: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 6.5489e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.9153e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 138: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 8.6268e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4169 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.2738e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 139: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 4.1871e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 140/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3225e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 140: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 39ms/step - loss: 1.3225e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4175 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0160e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 141: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0056e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 142/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.4386e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 142: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 8.0928e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.6314e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 143: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 2.5872e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.0881e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 144: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 38ms/step - loss: 3.9441e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4157 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 145/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.6575e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 145: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 5.4771e-04 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 0.4162 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 146/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3558e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 146: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 36ms/step - loss: 1.3120e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.7006 - val_f1_score: 0.7033 - lr: 3.1250e-05
# Epoch 147/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0947e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 147: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 38ms/step - loss: 2.2315e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4171 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 148/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6048e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 148: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 37ms/step - loss: 1.5608e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 149/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.7624e-06 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 49.
#
# Epoch 149: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 149: val_f1_score did not improve from 0.71449
# 16/16 [==============================] - 1s 40ms/step - loss: 7.5837e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.7037 - val_f1_score: 0.7054 - lr: 3.1250e-05
# Epoch 149: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 7ms/step
# 0.7314814814814815

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7314814814814815
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.49      0.55      0.52        85
#            0       0.83      0.79      0.81       239
#
#     accuracy                           0.73       324
#    macro avg       0.66      0.67      0.67       324
# weighted avg       0.74      0.73      0.74       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 237 chiếm khoảng 73.14814814814815% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 47 chiếm khoảng 55.294117647058826% so với thực tế
