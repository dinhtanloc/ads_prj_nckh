# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 128, 1,padding='same')

    branch7x7 = conv1d_bn(x, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 128, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # # mixed 5, 6: 17 x 17 x 768
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    #     branch7x7 = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    #     branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch7x7, branch7x7dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 960
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 288, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 288, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 256, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 256, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 256, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 256, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 96)                9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 96)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 96)                64512     ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 96)                9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 96)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 96)                9216      ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 96)                9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 96)                9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 96)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 96)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 96)                9216      ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 96)                64512     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 96)                9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 96)                9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 96)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 96)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 128)               86016     ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 128)               12288     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 128)               65536     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 128)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 128)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 128)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 128)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 128)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 128)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 128)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 128)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 512)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 192)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 3, 192)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 192)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 3, 192)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 192)               36864     ['activation_39[0][0]']
#
#  conv1d_43 (Conv1D)          (None, 3, 192)               258048    ['activation_42[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 192)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 3, 192)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 192)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 3, 192)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 512)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               258048    ['activation_40[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 192)               36864     ['activation_43[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 192)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 192)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 192)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 192)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_44[0][0]',
#                                                                      'activation_45[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1973147 (7.53 MB)
# Trainable params: 1972597 (7.52 MB)
# Non-trainable params: 550 (2.15 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.8842 - accuracy: 0.5156 - f1_score: 0.3556
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 12s 107ms/step - loss: 0.8875 - accuracy: 0.5140 - f1_score: 0.3535 - val_loss: 0.5746 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9357 - accuracy: 0.4938 - f1_score: 0.3300
# Epoch 2: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 31ms/step - loss: 0.9265 - accuracy: 0.5000 - f1_score: 0.3338 - val_loss: 0.5758 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9199 - accuracy: 0.5042 - f1_score: 0.3344
# Epoch 3: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 32ms/step - loss: 0.9268 - accuracy: 0.5000 - f1_score: 0.3315 - val_loss: 0.5757 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9357 - accuracy: 0.4948 - f1_score: 0.3298
# Epoch 4: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 1s 32ms/step - loss: 0.9262 - accuracy: 0.5000 - f1_score: 0.3331 - val_loss: 0.5750 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4911 - accuracy: 0.6833 - f1_score: 0.6702
# Epoch 5: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 31ms/step - loss: 0.4867 - accuracy: 0.6846 - f1_score: 0.6729 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3286 - accuracy: 0.7583 - f1_score: 0.7563
# Epoch 6: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3381 - accuracy: 0.7535 - f1_score: 0.7492 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3419 - accuracy: 0.7615 - f1_score: 0.7584
# Epoch 7: val_f1_score improved from 0.42467 to 0.47247, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3505 - accuracy: 0.7535 - f1_score: 0.7462 - val_loss: 0.5226 - val_accuracy: 0.7346 - val_f1_score: 0.4725 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.7585 - f1_score: 0.7538
# Epoch 8: val_f1_score did not improve from 0.47247
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3392 - accuracy: 0.7585 - f1_score: 0.7538 - val_loss: 0.5522 - val_accuracy: 0.7407 - val_f1_score: 0.4445 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3402 - accuracy: 0.7677 - f1_score: 0.7610
# Epoch 9: val_f1_score did not improve from 0.47247
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3339 - accuracy: 0.7715 - f1_score: 0.7670 - val_loss: 0.5649 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 0.0010
# Epoch 10/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2569 - accuracy: 0.8181 - f1_score: 0.8169
# Epoch 10: val_f1_score did not improve from 0.47247
# 16/16 [==============================] - 0s 32ms/step - loss: 0.2677 - accuracy: 0.8084 - f1_score: 0.8062 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2420 - accuracy: 0.8271 - f1_score: 0.8256
# Epoch 11: val_f1_score improved from 0.47247 to 0.52835, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.2445 - accuracy: 0.8263 - f1_score: 0.8243 - val_loss: 0.4536 - val_accuracy: 0.7099 - val_f1_score: 0.5284 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2377 - accuracy: 0.8323 - f1_score: 0.8312
# Epoch 12: val_f1_score did not improve from 0.52835
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2377 - accuracy: 0.8313 - f1_score: 0.8296 - val_loss: 0.4958 - val_accuracy: 0.7500 - val_f1_score: 0.5036 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2556 - accuracy: 0.8167 - f1_score: 0.8150
# Epoch 13: val_f1_score improved from 0.52835 to 0.58196, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2527 - accuracy: 0.8184 - f1_score: 0.8177 - val_loss: 0.3923 - val_accuracy: 0.7099 - val_f1_score: 0.5820 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2228 - accuracy: 0.8406 - f1_score: 0.8387
# Epoch 14: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2200 - accuracy: 0.8423 - f1_score: 0.8413 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 15/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2073 - accuracy: 0.8493 - f1_score: 0.8483
# Epoch 15: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2069 - accuracy: 0.8513 - f1_score: 0.8493 - val_loss: 0.5664 - val_accuracy: 0.7377 - val_f1_score: 0.4328 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2155 - accuracy: 0.8469 - f1_score: 0.8447
# Epoch 16: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2128 - accuracy: 0.8483 - f1_score: 0.8469 - val_loss: 0.4789 - val_accuracy: 0.7346 - val_f1_score: 0.5086 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1908 - accuracy: 0.8635 - f1_score: 0.8629
# Epoch 17: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1903 - accuracy: 0.8633 - f1_score: 0.8623 - val_loss: 0.4850 - val_accuracy: 0.7253 - val_f1_score: 0.4995 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.8493 - f1_score: 0.8481
# Epoch 18: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2108 - accuracy: 0.8493 - f1_score: 0.8481 - val_loss: 0.4564 - val_accuracy: 0.5525 - val_f1_score: 0.5692 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1952 - accuracy: 0.8604 - f1_score: 0.8592
# Epoch 19: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1914 - accuracy: 0.8633 - f1_score: 0.8634 - val_loss: 0.4607 - val_accuracy: 0.7346 - val_f1_score: 0.5214 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.8563 - f1_score: 0.8535
# Epoch 20: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2003 - accuracy: 0.8563 - f1_score: 0.8535 - val_loss: 0.5543 - val_accuracy: 0.7284 - val_f1_score: 0.4429 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1918 - accuracy: 0.8656 - f1_score: 0.8647
# Epoch 21: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1888 - accuracy: 0.8673 - f1_score: 0.8671 - val_loss: 0.4515 - val_accuracy: 0.5802 - val_f1_score: 0.5806 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1692 - accuracy: 0.8781 - f1_score: 0.8767
# Epoch 22: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1700 - accuracy: 0.8782 - f1_score: 0.8768 - val_loss: 0.6234 - val_accuracy: 0.3858 - val_f1_score: 0.3936 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.8752 - f1_score: 0.8745
# Epoch 23: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1709 - accuracy: 0.8752 - f1_score: 0.8745 - val_loss: 0.5777 - val_accuracy: 0.7284 - val_f1_score: 0.4220 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1813 - accuracy: 0.8698 - f1_score: 0.8686
# Epoch 24: val_f1_score did not improve from 0.58196
# 16/16 [==============================] - 0s 32ms/step - loss: 0.1824 - accuracy: 0.8693 - f1_score: 0.8679 - val_loss: 0.4737 - val_accuracy: 0.7222 - val_f1_score: 0.5111 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1864 - accuracy: 0.8656 - f1_score: 0.8648
# Epoch 25: val_f1_score improved from 0.58196 to 0.68933, saving model to best_model.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1924 - accuracy: 0.8623 - f1_score: 0.8595 - val_loss: 0.3246 - val_accuracy: 0.7284 - val_f1_score: 0.6893 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2000 - accuracy: 0.8542 - f1_score: 0.8532
# Epoch 26: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1964 - accuracy: 0.8573 - f1_score: 0.8579 - val_loss: 0.5569 - val_accuracy: 0.7377 - val_f1_score: 0.4439 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.8553 - f1_score: 0.8551
# Epoch 27: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2059 - accuracy: 0.8553 - f1_score: 0.8551 - val_loss: 0.4620 - val_accuracy: 0.5556 - val_f1_score: 0.5703 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.8653 - f1_score: 0.8642
# Epoch 28: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1944 - accuracy: 0.8653 - f1_score: 0.8642 - val_loss: 0.5761 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1906 - accuracy: 0.8615 - f1_score: 0.8602
# Epoch 29: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1883 - accuracy: 0.8633 - f1_score: 0.8629 - val_loss: 0.5686 - val_accuracy: 0.7377 - val_f1_score: 0.4328 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1579 - accuracy: 0.8896 - f1_score: 0.8887
# Epoch 30: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1552 - accuracy: 0.8912 - f1_score: 0.8911 - val_loss: 0.5593 - val_accuracy: 0.7253 - val_f1_score: 0.4358 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1575 - accuracy: 0.8885 - f1_score: 0.8878
# Epoch 31: val_f1_score did not improve from 0.68933
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1533 - accuracy: 0.8912 - f1_score: 0.8917 - val_loss: 0.4048 - val_accuracy: 0.7222 - val_f1_score: 0.5642 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1416 - accuracy: 0.8990 - f1_score: 0.8986
# Epoch 32: val_f1_score improved from 0.68933 to 0.69855, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1441 - accuracy: 0.8972 - f1_score: 0.8960 - val_loss: 0.3557 - val_accuracy: 0.6852 - val_f1_score: 0.6986 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1496 - accuracy: 0.8958 - f1_score: 0.8949
# Epoch 33: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1519 - accuracy: 0.8942 - f1_score: 0.8925 - val_loss: 0.5375 - val_accuracy: 0.7346 - val_f1_score: 0.4560 - lr: 0.0010
# Epoch 34/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1401 - accuracy: 0.9007 - f1_score: 0.9002
# Epoch 34: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1445 - accuracy: 0.8982 - f1_score: 0.8979 - val_loss: 0.3848 - val_accuracy: 0.6852 - val_f1_score: 0.5890 - lr: 0.0010
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1616 - accuracy: 0.8844 - f1_score: 0.8832
# Epoch 35: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1637 - accuracy: 0.8832 - f1_score: 0.8814 - val_loss: 0.4080 - val_accuracy: 0.6420 - val_f1_score: 0.5618 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1460 - accuracy: 0.8948 - f1_score: 0.8941
# Epoch 36: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1435 - accuracy: 0.8962 - f1_score: 0.8963 - val_loss: 0.4395 - val_accuracy: 0.7253 - val_f1_score: 0.5387 - lr: 0.0010
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9012 - f1_score: 0.8999
# Epoch 37: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1389 - accuracy: 0.9012 - f1_score: 0.8999 - val_loss: 0.5508 - val_accuracy: 0.7346 - val_f1_score: 0.4458 - lr: 0.0010
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9042 - f1_score: 0.9030
# Epoch 38: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1299 - accuracy: 0.9042 - f1_score: 0.9030 - val_loss: 0.4427 - val_accuracy: 0.7253 - val_f1_score: 0.5291 - lr: 0.0010
# Epoch 39/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1259 - accuracy: 0.9118 - f1_score: 0.9113
# Epoch 39: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1364 - accuracy: 0.9052 - f1_score: 0.9011 - val_loss: 0.5190 - val_accuracy: 0.7377 - val_f1_score: 0.4762 - lr: 0.0010
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1600 - accuracy: 0.8896 - f1_score: 0.8885
# Epoch 40: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1600 - accuracy: 0.8872 - f1_score: 0.8843 - val_loss: 0.5774 - val_accuracy: 0.7346 - val_f1_score: 0.4238 - lr: 0.0010
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1496 - accuracy: 0.8927 - f1_score: 0.8917
# Epoch 41: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1511 - accuracy: 0.8912 - f1_score: 0.8890 - val_loss: 0.5762 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1238 - accuracy: 0.9115 - f1_score: 0.9105
# Epoch 42: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1227 - accuracy: 0.9122 - f1_score: 0.9116 - val_loss: 0.5677 - val_accuracy: 0.7346 - val_f1_score: 0.4319 - lr: 0.0010
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1254 - accuracy: 0.9135 - f1_score: 0.9129
# Epoch 43: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1260 - accuracy: 0.9132 - f1_score: 0.9124 - val_loss: 0.5117 - val_accuracy: 0.7346 - val_f1_score: 0.4796 - lr: 0.0010
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1421 - accuracy: 0.8969 - f1_score: 0.8965
# Epoch 44: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1408 - accuracy: 0.8972 - f1_score: 0.8969 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9022 - f1_score: 0.8995
# Epoch 45: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1368 - accuracy: 0.9022 - f1_score: 0.8995 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1382 - accuracy: 0.9021 - f1_score: 0.9014
# Epoch 46: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1380 - accuracy: 0.9022 - f1_score: 0.9017 - val_loss: 0.3520 - val_accuracy: 0.7315 - val_f1_score: 0.5928 - lr: 0.0010
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1337 - accuracy: 0.9042 - f1_score: 0.9038
# Epoch 47: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1307 - accuracy: 0.9062 - f1_score: 0.9068 - val_loss: 0.5415 - val_accuracy: 0.7222 - val_f1_score: 0.4533 - lr: 0.0010
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1278 - accuracy: 0.9083 - f1_score: 0.9072
# Epoch 48: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1308 - accuracy: 0.9062 - f1_score: 0.9041 - val_loss: 0.5315 - val_accuracy: 0.7315 - val_f1_score: 0.4631 - lr: 0.0010
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1214 - accuracy: 0.9146 - f1_score: 0.9141
# Epoch 49: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1206 - accuracy: 0.9152 - f1_score: 0.9149 - val_loss: 0.5470 - val_accuracy: 0.7284 - val_f1_score: 0.4492 - lr: 0.0010
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1227 - accuracy: 0.9125 - f1_score: 0.9119
# Epoch 50: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1203 - accuracy: 0.9142 - f1_score: 0.9144 - val_loss: 0.5552 - val_accuracy: 0.7191 - val_f1_score: 0.4403 - lr: 0.0010
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1240 - accuracy: 0.9125 - f1_score: 0.9117
# Epoch 51: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1298 - accuracy: 0.9092 - f1_score: 0.9066 - val_loss: 0.5099 - val_accuracy: 0.7284 - val_f1_score: 0.4801 - lr: 0.0010
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1157 - accuracy: 0.9177 - f1_score: 0.9168
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 52: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1162 - accuracy: 0.9172 - f1_score: 0.9159 - val_loss: 0.4066 - val_accuracy: 0.7284 - val_f1_score: 0.5649 - lr: 0.0010
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1069 - accuracy: 0.9271 - f1_score: 0.9263
# Epoch 53: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1062 - accuracy: 0.9271 - f1_score: 0.9261 - val_loss: 0.5042 - val_accuracy: 0.7315 - val_f1_score: 0.4863 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1086 - accuracy: 0.9219 - f1_score: 0.9213
# Epoch 54: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1081 - accuracy: 0.9222 - f1_score: 0.9217 - val_loss: 0.3930 - val_accuracy: 0.7377 - val_f1_score: 0.5815 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1008 - accuracy: 0.9281 - f1_score: 0.9276
# Epoch 55: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1041 - accuracy: 0.9242 - f1_score: 0.9210 - val_loss: 0.3998 - val_accuracy: 0.7531 - val_f1_score: 0.5838 - lr: 5.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9291 - f1_score: 0.9290
# Epoch 56: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0998 - accuracy: 0.9291 - f1_score: 0.9290 - val_loss: 0.3485 - val_accuracy: 0.7222 - val_f1_score: 0.6139 - lr: 5.0000e-04
# Epoch 57/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9172 - f1_score: 0.9135
# Epoch 57: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1214 - accuracy: 0.9172 - f1_score: 0.9135 - val_loss: 0.3623 - val_accuracy: 0.6883 - val_f1_score: 0.6917 - lr: 5.0000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0940 - accuracy: 0.9333 - f1_score: 0.9325
# Epoch 58: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1015 - accuracy: 0.9291 - f1_score: 0.9263 - val_loss: 0.4176 - val_accuracy: 0.7068 - val_f1_score: 0.5545 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1030 - accuracy: 0.9281 - f1_score: 0.9269
# Epoch 59: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1013 - accuracy: 0.9291 - f1_score: 0.9284 - val_loss: 0.3731 - val_accuracy: 0.6883 - val_f1_score: 0.6838 - lr: 5.0000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0976 - accuracy: 0.9323 - f1_score: 0.9316
# Epoch 60: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0975 - accuracy: 0.9321 - f1_score: 0.9313 - val_loss: 0.3738 - val_accuracy: 0.6667 - val_f1_score: 0.6811 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0949 - accuracy: 0.9323 - f1_score: 0.9316
# Epoch 61: val_f1_score did not improve from 0.69855
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0959 - accuracy: 0.9311 - f1_score: 0.9299 - val_loss: 0.3949 - val_accuracy: 0.6790 - val_f1_score: 0.5768 - lr: 5.0000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0965 - accuracy: 0.9302 - f1_score: 0.9294
# Epoch 62: val_f1_score improved from 0.69855 to 0.70457, saving model to best_model.h5
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0951 - accuracy: 0.9311 - f1_score: 0.9308 - val_loss: 0.3555 - val_accuracy: 0.6975 - val_f1_score: 0.7046 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0886 - accuracy: 0.9365 - f1_score: 0.9360
# Epoch 63: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0896 - accuracy: 0.9361 - f1_score: 0.9355 - val_loss: 0.4032 - val_accuracy: 0.6204 - val_f1_score: 0.6199 - lr: 5.0000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0868 - accuracy: 0.9375 - f1_score: 0.9370
# Epoch 64: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0931 - accuracy: 0.9321 - f1_score: 0.9286 - val_loss: 0.3659 - val_accuracy: 0.6883 - val_f1_score: 0.6022 - lr: 5.0000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0912 - accuracy: 0.9354 - f1_score: 0.9351
# Epoch 65: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0900 - accuracy: 0.9361 - f1_score: 0.9361 - val_loss: 0.3408 - val_accuracy: 0.7160 - val_f1_score: 0.6188 - lr: 5.0000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0856 - accuracy: 0.9396 - f1_score: 0.9392
# Epoch 66: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0846 - accuracy: 0.9401 - f1_score: 0.9400 - val_loss: 0.6420 - val_accuracy: 0.3704 - val_f1_score: 0.3791 - lr: 5.0000e-04
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9351 - f1_score: 0.9342
# Epoch 67: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0883 - accuracy: 0.9351 - f1_score: 0.9342 - val_loss: 0.4279 - val_accuracy: 0.5926 - val_f1_score: 0.6413 - lr: 5.0000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0970 - accuracy: 0.9312 - f1_score: 0.9302
# Epoch 68: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0955 - accuracy: 0.9321 - f1_score: 0.9316 - val_loss: 0.3730 - val_accuracy: 0.7315 - val_f1_score: 0.5993 - lr: 5.0000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0936 - accuracy: 0.9333 - f1_score: 0.9326
# Epoch 69: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0950 - accuracy: 0.9321 - f1_score: 0.9307 - val_loss: 0.6626 - val_accuracy: 0.3519 - val_f1_score: 0.3964 - lr: 5.0000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0924 - accuracy: 0.9344 - f1_score: 0.9335
# Epoch 70: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0913 - accuracy: 0.9351 - f1_score: 0.9346 - val_loss: 0.3549 - val_accuracy: 0.7438 - val_f1_score: 0.6151 - lr: 5.0000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0946 - accuracy: 0.9323 - f1_score: 0.9317
# Epoch 71: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0950 - accuracy: 0.9321 - f1_score: 0.9315 - val_loss: 0.4135 - val_accuracy: 0.7346 - val_f1_score: 0.5600 - lr: 5.0000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0991 - accuracy: 0.9281 - f1_score: 0.9274
# Epoch 72: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0979 - accuracy: 0.9291 - f1_score: 0.9289 - val_loss: 0.3767 - val_accuracy: 0.7222 - val_f1_score: 0.5887 - lr: 5.0000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0935 - accuracy: 0.9354 - f1_score: 0.9347
# Epoch 73: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0933 - accuracy: 0.9351 - f1_score: 0.9343 - val_loss: 0.3919 - val_accuracy: 0.6420 - val_f1_score: 0.6665 - lr: 5.0000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0867 - accuracy: 0.9385 - f1_score: 0.9375
# Epoch 74: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0856 - accuracy: 0.9391 - f1_score: 0.9384 - val_loss: 0.4150 - val_accuracy: 0.6080 - val_f1_score: 0.6472 - lr: 5.0000e-04
# Epoch 75/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0920 - accuracy: 0.9330 - f1_score: 0.9322
# Epoch 75: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0905 - accuracy: 0.9351 - f1_score: 0.9352 - val_loss: 0.4029 - val_accuracy: 0.7284 - val_f1_score: 0.5667 - lr: 5.0000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0810 - accuracy: 0.9427 - f1_score: 0.9423
# Epoch 76: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0822 - accuracy: 0.9421 - f1_score: 0.9414 - val_loss: 0.4485 - val_accuracy: 0.7222 - val_f1_score: 0.5317 - lr: 5.0000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0876 - accuracy: 0.9385 - f1_score: 0.9375
# Epoch 77: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0867 - accuracy: 0.9391 - f1_score: 0.9385 - val_loss: 0.3629 - val_accuracy: 0.7407 - val_f1_score: 0.6019 - lr: 5.0000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0851 - accuracy: 0.9406 - f1_score: 0.9397
# Epoch 78: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0860 - accuracy: 0.9391 - f1_score: 0.9375 - val_loss: 0.5055 - val_accuracy: 0.7315 - val_f1_score: 0.4894 - lr: 5.0000e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0795 - accuracy: 0.9448 - f1_score: 0.9443
# Epoch 79: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0861 - accuracy: 0.9411 - f1_score: 0.9386 - val_loss: 0.4188 - val_accuracy: 0.5957 - val_f1_score: 0.6031 - lr: 5.0000e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0776 - accuracy: 0.9458 - f1_score: 0.9454
# Epoch 80: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0788 - accuracy: 0.9451 - f1_score: 0.9441 - val_loss: 0.3661 - val_accuracy: 0.6852 - val_f1_score: 0.6941 - lr: 5.0000e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0765 - accuracy: 0.9469 - f1_score: 0.9454
# Epoch 81: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0761 - accuracy: 0.9471 - f1_score: 0.9458 - val_loss: 0.3856 - val_accuracy: 0.6883 - val_f1_score: 0.5858 - lr: 5.0000e-04
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0784 - accuracy: 0.9458 - f1_score: 0.9451
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 82: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0792 - accuracy: 0.9451 - f1_score: 0.9440 - val_loss: 0.5115 - val_accuracy: 0.4938 - val_f1_score: 0.5680 - lr: 5.0000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0828 - accuracy: 0.9438 - f1_score: 0.9428
# Epoch 83: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0833 - accuracy: 0.9431 - f1_score: 0.9417 - val_loss: 0.3830 - val_accuracy: 0.6852 - val_f1_score: 0.5906 - lr: 2.5000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0738 - accuracy: 0.9479 - f1_score: 0.9472
# Epoch 84: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0766 - accuracy: 0.9461 - f1_score: 0.9443 - val_loss: 0.3949 - val_accuracy: 0.7160 - val_f1_score: 0.5775 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0762 - accuracy: 0.9458 - f1_score: 0.9447
# Epoch 85: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0745 - accuracy: 0.9471 - f1_score: 0.9467 - val_loss: 0.3988 - val_accuracy: 0.6389 - val_f1_score: 0.5708 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0725 - accuracy: 0.9479 - f1_score: 0.9473
# Epoch 86: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0719 - accuracy: 0.9481 - f1_score: 0.9475 - val_loss: 0.3960 - val_accuracy: 0.6451 - val_f1_score: 0.5764 - lr: 2.5000e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0673 - accuracy: 0.9521 - f1_score: 0.9519
# Epoch 87: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0689 - accuracy: 0.9511 - f1_score: 0.9504 - val_loss: 0.3631 - val_accuracy: 0.7037 - val_f1_score: 0.6091 - lr: 2.5000e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0667 - accuracy: 0.9521 - f1_score: 0.9512
# Epoch 88: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0665 - accuracy: 0.9521 - f1_score: 0.9512 - val_loss: 0.3703 - val_accuracy: 0.7160 - val_f1_score: 0.6011 - lr: 2.5000e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0714 - accuracy: 0.9500 - f1_score: 0.9492
# Epoch 89: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0698 - accuracy: 0.9511 - f1_score: 0.9509 - val_loss: 0.3680 - val_accuracy: 0.6698 - val_f1_score: 0.5969 - lr: 2.5000e-04
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9561 - f1_score: 0.9545
# Epoch 90: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0618 - accuracy: 0.9561 - f1_score: 0.9545 - val_loss: 0.3908 - val_accuracy: 0.6574 - val_f1_score: 0.5838 - lr: 2.5000e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9511 - f1_score: 0.9506
# Epoch 91: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0673 - accuracy: 0.9511 - f1_score: 0.9506 - val_loss: 0.4425 - val_accuracy: 0.5802 - val_f1_score: 0.5373 - lr: 2.5000e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0647 - accuracy: 0.9531 - f1_score: 0.9525
# Epoch 92: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0620 - accuracy: 0.9551 - f1_score: 0.9554 - val_loss: 0.4256 - val_accuracy: 0.6019 - val_f1_score: 0.5533 - lr: 2.5000e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0644 - accuracy: 0.9552 - f1_score: 0.9545
# Epoch 93: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0633 - accuracy: 0.9561 - f1_score: 0.9559 - val_loss: 0.3837 - val_accuracy: 0.6728 - val_f1_score: 0.5867 - lr: 2.5000e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0629 - accuracy: 0.9573 - f1_score: 0.9567
# Epoch 94: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0659 - accuracy: 0.9551 - f1_score: 0.9533 - val_loss: 0.3759 - val_accuracy: 0.6852 - val_f1_score: 0.5973 - lr: 2.5000e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0698 - accuracy: 0.9500 - f1_score: 0.9492
# Epoch 95: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0683 - accuracy: 0.9511 - f1_score: 0.9509 - val_loss: 0.3871 - val_accuracy: 0.6574 - val_f1_score: 0.5861 - lr: 2.5000e-04
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9511 - f1_score: 0.9504
# Epoch 96: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0678 - accuracy: 0.9511 - f1_score: 0.9504 - val_loss: 0.3611 - val_accuracy: 0.7222 - val_f1_score: 0.6093 - lr: 2.5000e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0705 - accuracy: 0.9510 - f1_score: 0.9501
# Epoch 97: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0702 - accuracy: 0.9511 - f1_score: 0.9501 - val_loss: 0.3681 - val_accuracy: 0.6914 - val_f1_score: 0.6053 - lr: 2.5000e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0677 - accuracy: 0.9531 - f1_score: 0.9522
# Epoch 98: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0685 - accuracy: 0.9521 - f1_score: 0.9506 - val_loss: 0.3848 - val_accuracy: 0.6512 - val_f1_score: 0.5873 - lr: 2.5000e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0669 - accuracy: 0.9510 - f1_score: 0.9503
# Epoch 99: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0694 - accuracy: 0.9501 - f1_score: 0.9486 - val_loss: 0.3622 - val_accuracy: 0.6852 - val_f1_score: 0.6084 - lr: 2.5000e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0584 - accuracy: 0.9594 - f1_score: 0.9588
# Epoch 100: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0612 - accuracy: 0.9571 - f1_score: 0.9554 - val_loss: 0.3712 - val_accuracy: 0.6698 - val_f1_score: 0.6043 - lr: 2.5000e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0635 - accuracy: 0.9552 - f1_score: 0.9546
# Epoch 101: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0685 - accuracy: 0.9521 - f1_score: 0.9497 - val_loss: 0.3822 - val_accuracy: 0.6728 - val_f1_score: 0.5835 - lr: 2.5000e-04
# Epoch 102/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0630 - accuracy: 0.9554 - f1_score: 0.9549
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 102: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0648 - accuracy: 0.9541 - f1_score: 0.9541 - val_loss: 0.3838 - val_accuracy: 0.6636 - val_f1_score: 0.5861 - lr: 2.5000e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0768 - accuracy: 0.9469 - f1_score: 0.9451
# Epoch 103: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0772 - accuracy: 0.9471 - f1_score: 0.9455 - val_loss: 0.3761 - val_accuracy: 0.6852 - val_f1_score: 0.5981 - lr: 1.2500e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0617 - accuracy: 0.9552 - f1_score: 0.9548
# Epoch 104: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0620 - accuracy: 0.9551 - f1_score: 0.9547 - val_loss: 0.3845 - val_accuracy: 0.6821 - val_f1_score: 0.5803 - lr: 1.2500e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0600 - accuracy: 0.9594 - f1_score: 0.9589
# Epoch 105: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0588 - accuracy: 0.9601 - f1_score: 0.9600 - val_loss: 0.3643 - val_accuracy: 0.7006 - val_f1_score: 0.6027 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0654 - accuracy: 0.9531 - f1_score: 0.9523
# Epoch 106: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0655 - accuracy: 0.9531 - f1_score: 0.9523 - val_loss: 0.3531 - val_accuracy: 0.7037 - val_f1_score: 0.6081 - lr: 1.2500e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0667 - accuracy: 0.9521 - f1_score: 0.9514
# Epoch 107: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0667 - accuracy: 0.9521 - f1_score: 0.9515 - val_loss: 0.3514 - val_accuracy: 0.7099 - val_f1_score: 0.6190 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0640 - accuracy: 0.9573 - f1_score: 0.9564
# Epoch 108: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0662 - accuracy: 0.9551 - f1_score: 0.9529 - val_loss: 0.3787 - val_accuracy: 0.7037 - val_f1_score: 0.5938 - lr: 1.2500e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0600 - accuracy: 0.9573 - f1_score: 0.9568
# Epoch 109: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0588 - accuracy: 0.9581 - f1_score: 0.9580 - val_loss: 0.3787 - val_accuracy: 0.7037 - val_f1_score: 0.5912 - lr: 1.2500e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0678 - accuracy: 0.9510 - f1_score: 0.9501
# Epoch 110: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0666 - accuracy: 0.9521 - f1_score: 0.9517 - val_loss: 0.3785 - val_accuracy: 0.7099 - val_f1_score: 0.5936 - lr: 1.2500e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0593 - accuracy: 0.9583 - f1_score: 0.9580
# Epoch 111: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0568 - accuracy: 0.9601 - f1_score: 0.9607 - val_loss: 0.3798 - val_accuracy: 0.7222 - val_f1_score: 0.5890 - lr: 1.2500e-04
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0570 - accuracy: 0.9604 - f1_score: 0.9597
# Epoch 112: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0589 - accuracy: 0.9591 - f1_score: 0.9577 - val_loss: 0.3762 - val_accuracy: 0.7191 - val_f1_score: 0.5942 - lr: 1.2500e-04
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0624 - accuracy: 0.9563 - f1_score: 0.9558
# Epoch 113: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0598 - accuracy: 0.9581 - f1_score: 0.9585 - val_loss: 0.3795 - val_accuracy: 0.7006 - val_f1_score: 0.5874 - lr: 1.2500e-04
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0614 - accuracy: 0.9563 - f1_score: 0.9558
# Epoch 114: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0602 - accuracy: 0.9571 - f1_score: 0.9570 - val_loss: 0.3559 - val_accuracy: 0.7130 - val_f1_score: 0.6172 - lr: 1.2500e-04
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0611 - accuracy: 0.9573 - f1_score: 0.9568
# Epoch 115: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0598 - accuracy: 0.9581 - f1_score: 0.9580 - val_loss: 0.3754 - val_accuracy: 0.6944 - val_f1_score: 0.5918 - lr: 1.2500e-04
# Epoch 116/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9601 - f1_score: 0.9602
# Epoch 116: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0558 - accuracy: 0.9601 - f1_score: 0.9602 - val_loss: 0.3817 - val_accuracy: 0.7253 - val_f1_score: 0.5948 - lr: 1.2500e-04
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0642 - accuracy: 0.9531 - f1_score: 0.9527
# Epoch 117: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0616 - accuracy: 0.9551 - f1_score: 0.9557 - val_loss: 0.3740 - val_accuracy: 0.6975 - val_f1_score: 0.5900 - lr: 1.2500e-04
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0632 - accuracy: 0.9552 - f1_score: 0.9544
# Epoch 118: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0619 - accuracy: 0.9561 - f1_score: 0.9557 - val_loss: 0.3885 - val_accuracy: 0.7006 - val_f1_score: 0.5814 - lr: 1.2500e-04
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0570 - accuracy: 0.9594 - f1_score: 0.9587
# Epoch 119: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0561 - accuracy: 0.9601 - f1_score: 0.9598 - val_loss: 0.3821 - val_accuracy: 0.6821 - val_f1_score: 0.5889 - lr: 1.2500e-04
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0583 - accuracy: 0.9594 - f1_score: 0.9586
# Epoch 120: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0572 - accuracy: 0.9601 - f1_score: 0.9597 - val_loss: 0.3842 - val_accuracy: 0.6636 - val_f1_score: 0.5848 - lr: 1.2500e-04
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0607 - accuracy: 0.9583 - f1_score: 0.9573
# Epoch 121: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0609 - accuracy: 0.9581 - f1_score: 0.9570 - val_loss: 0.3920 - val_accuracy: 0.6636 - val_f1_score: 0.5812 - lr: 1.2500e-04
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9591 - f1_score: 0.9584
# Epoch 122: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 122: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0584 - accuracy: 0.9591 - f1_score: 0.9584 - val_loss: 0.3881 - val_accuracy: 0.6451 - val_f1_score: 0.5785 - lr: 1.2500e-04
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0612 - accuracy: 0.9552 - f1_score: 0.9549
# Epoch 123: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0606 - accuracy: 0.9561 - f1_score: 0.9562 - val_loss: 0.3888 - val_accuracy: 0.6605 - val_f1_score: 0.5868 - lr: 6.2500e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0560 - accuracy: 0.9604 - f1_score: 0.9600
# Epoch 124: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0583 - accuracy: 0.9591 - f1_score: 0.9580 - val_loss: 0.3877 - val_accuracy: 0.6605 - val_f1_score: 0.5879 - lr: 6.2500e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0541 - accuracy: 0.9615 - f1_score: 0.9610
# Epoch 125: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0561 - accuracy: 0.9601 - f1_score: 0.9589 - val_loss: 0.4036 - val_accuracy: 0.6204 - val_f1_score: 0.6590 - lr: 6.2500e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0592 - accuracy: 0.9583 - f1_score: 0.9578
# Epoch 126: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0610 - accuracy: 0.9571 - f1_score: 0.9560 - val_loss: 0.4048 - val_accuracy: 0.6173 - val_f1_score: 0.6566 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0588 - accuracy: 0.9594 - f1_score: 0.9590
# Epoch 127: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0564 - accuracy: 0.9611 - f1_score: 0.9615 - val_loss: 0.3856 - val_accuracy: 0.6574 - val_f1_score: 0.5826 - lr: 6.2500e-05
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9581 - f1_score: 0.9582
# Epoch 128: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0573 - accuracy: 0.9581 - f1_score: 0.9582 - val_loss: 0.3833 - val_accuracy: 0.6667 - val_f1_score: 0.5877 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0538 - accuracy: 0.9615 - f1_score: 0.9612
# Epoch 129: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0542 - accuracy: 0.9611 - f1_score: 0.9607 - val_loss: 0.3836 - val_accuracy: 0.6759 - val_f1_score: 0.5800 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0560 - accuracy: 0.9604 - f1_score: 0.9594
# Epoch 130: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0596 - accuracy: 0.9581 - f1_score: 0.9559 - val_loss: 0.3868 - val_accuracy: 0.6914 - val_f1_score: 0.5811 - lr: 6.2500e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0513 - accuracy: 0.9646 - f1_score: 0.9642
# Epoch 131: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0561 - accuracy: 0.9611 - f1_score: 0.9589 - val_loss: 0.3864 - val_accuracy: 0.6975 - val_f1_score: 0.5855 - lr: 6.2500e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0573 - accuracy: 0.9594 - f1_score: 0.9591
# Epoch 132: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0563 - accuracy: 0.9601 - f1_score: 0.9602 - val_loss: 0.3852 - val_accuracy: 0.6975 - val_f1_score: 0.5855 - lr: 6.2500e-05
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9591 - f1_score: 0.9582
# Epoch 133: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0578 - accuracy: 0.9591 - f1_score: 0.9582 - val_loss: 0.3879 - val_accuracy: 0.7006 - val_f1_score: 0.5857 - lr: 6.2500e-05
# Epoch 134/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9601 - f1_score: 0.9596
# Epoch 134: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0574 - accuracy: 0.9601 - f1_score: 0.9596 - val_loss: 0.3900 - val_accuracy: 0.6975 - val_f1_score: 0.5786 - lr: 6.2500e-05
# Epoch 135/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0567 - accuracy: 0.9598 - f1_score: 0.9594
# Epoch 135: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0563 - accuracy: 0.9601 - f1_score: 0.9589 - val_loss: 0.3871 - val_accuracy: 0.6914 - val_f1_score: 0.5828 - lr: 6.2500e-05
# Epoch 136/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0534 - accuracy: 0.9635 - f1_score: 0.9629
# Epoch 136: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0538 - accuracy: 0.9631 - f1_score: 0.9622 - val_loss: 0.3858 - val_accuracy: 0.6790 - val_f1_score: 0.5846 - lr: 6.2500e-05
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0582 - accuracy: 0.9604 - f1_score: 0.9593
# Epoch 137: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0571 - accuracy: 0.9611 - f1_score: 0.9603 - val_loss: 0.3837 - val_accuracy: 0.6852 - val_f1_score: 0.5869 - lr: 6.2500e-05
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0600 - accuracy: 0.9583 - f1_score: 0.9575
# Epoch 138: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0588 - accuracy: 0.9591 - f1_score: 0.9586 - val_loss: 0.3810 - val_accuracy: 0.7006 - val_f1_score: 0.5861 - lr: 6.2500e-05
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0574 - accuracy: 0.9583 - f1_score: 0.9580
# Epoch 139: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0582 - accuracy: 0.9581 - f1_score: 0.9575 - val_loss: 0.3786 - val_accuracy: 0.7037 - val_f1_score: 0.5899 - lr: 6.2500e-05
# Epoch 140/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0540 - accuracy: 0.9615 - f1_score: 0.9609
# Epoch 140: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0557 - accuracy: 0.9601 - f1_score: 0.9589 - val_loss: 0.3789 - val_accuracy: 0.7130 - val_f1_score: 0.5946 - lr: 6.2500e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0601 - accuracy: 0.9583 - f1_score: 0.9574
# Epoch 141: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0590 - accuracy: 0.9591 - f1_score: 0.9586 - val_loss: 0.3776 - val_accuracy: 0.7006 - val_f1_score: 0.5922 - lr: 6.2500e-05
# Epoch 142/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0570 - accuracy: 0.9583 - f1_score: 0.9580
# Epoch 142: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 142: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0614 - accuracy: 0.9571 - f1_score: 0.9556 - val_loss: 0.3833 - val_accuracy: 0.6975 - val_f1_score: 0.5920 - lr: 6.2500e-05
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0563 - accuracy: 0.9594 - f1_score: 0.9590
# Epoch 143: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0569 - accuracy: 0.9591 - f1_score: 0.9585 - val_loss: 0.3817 - val_accuracy: 0.6790 - val_f1_score: 0.5944 - lr: 3.1250e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0528 - accuracy: 0.9625 - f1_score: 0.9623
# Epoch 144: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0536 - accuracy: 0.9621 - f1_score: 0.9616 - val_loss: 0.3803 - val_accuracy: 0.6790 - val_f1_score: 0.5923 - lr: 3.1250e-05
# Epoch 145/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0522 - accuracy: 0.9635 - f1_score: 0.9632
# Epoch 145: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0543 - accuracy: 0.9621 - f1_score: 0.9610 - val_loss: 0.3841 - val_accuracy: 0.6821 - val_f1_score: 0.5861 - lr: 3.1250e-05
# Epoch 146/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0518 - accuracy: 0.9635 - f1_score: 0.9634
# Epoch 146: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0544 - accuracy: 0.9621 - f1_score: 0.9611 - val_loss: 0.3841 - val_accuracy: 0.6790 - val_f1_score: 0.5825 - lr: 3.1250e-05
# Epoch 147/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0614 - accuracy: 0.9573 - f1_score: 0.9562
# Epoch 147: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0622 - accuracy: 0.9571 - f1_score: 0.9555 - val_loss: 0.3826 - val_accuracy: 0.6852 - val_f1_score: 0.5867 - lr: 3.1250e-05
# Epoch 148/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0569 - accuracy: 0.9594 - f1_score: 0.9586
# Epoch 148: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0574 - accuracy: 0.9591 - f1_score: 0.9582 - val_loss: 0.3899 - val_accuracy: 0.6852 - val_f1_score: 0.5805 - lr: 3.1250e-05
# Epoch 149/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0563 - accuracy: 0.9594 - f1_score: 0.9585
# Epoch 149: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0569 - accuracy: 0.9591 - f1_score: 0.9581 - val_loss: 0.3918 - val_accuracy: 0.6852 - val_f1_score: 0.5805 - lr: 3.1250e-05
# Epoch 150/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0552 - accuracy: 0.9604 - f1_score: 0.9598
# Epoch 150: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0543 - accuracy: 0.9611 - f1_score: 0.9608 - val_loss: 0.3808 - val_accuracy: 0.6759 - val_f1_score: 0.5887 - lr: 3.1250e-05
# Epoch 151/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0568 - accuracy: 0.9594 - f1_score: 0.9588
# Epoch 151: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0557 - accuracy: 0.9601 - f1_score: 0.9598 - val_loss: 0.3779 - val_accuracy: 0.6790 - val_f1_score: 0.5926 - lr: 3.1250e-05
# Epoch 152/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0552 - accuracy: 0.9615 - f1_score: 0.9611
# Epoch 152: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0536 - accuracy: 0.9621 - f1_score: 0.9620 - val_loss: 0.3771 - val_accuracy: 0.6821 - val_f1_score: 0.5912 - lr: 3.1250e-05
# Epoch 153/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0528 - accuracy: 0.9625 - f1_score: 0.9621
# Epoch 153: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0539 - accuracy: 0.9621 - f1_score: 0.9614 - val_loss: 0.3724 - val_accuracy: 0.6914 - val_f1_score: 0.5967 - lr: 3.1250e-05
# Epoch 154/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0532 - accuracy: 0.9615 - f1_score: 0.9608
# Epoch 154: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0537 - accuracy: 0.9611 - f1_score: 0.9602 - val_loss: 0.3797 - val_accuracy: 0.6914 - val_f1_score: 0.5876 - lr: 3.1250e-05
# Epoch 155/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0517 - accuracy: 0.9635 - f1_score: 0.9631
# Epoch 155: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0551 - accuracy: 0.9611 - f1_score: 0.9595 - val_loss: 0.3823 - val_accuracy: 0.7006 - val_f1_score: 0.5893 - lr: 3.1250e-05
# Epoch 156/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9601 - f1_score: 0.9588
# Epoch 156: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0561 - accuracy: 0.9601 - f1_score: 0.9588 - val_loss: 0.3769 - val_accuracy: 0.7160 - val_f1_score: 0.5913 - lr: 3.1250e-05
# Epoch 157/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0481 - accuracy: 0.9656 - f1_score: 0.9653
# Epoch 157: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0516 - accuracy: 0.9631 - f1_score: 0.9615 - val_loss: 0.3767 - val_accuracy: 0.7160 - val_f1_score: 0.5913 - lr: 3.1250e-05
# Epoch 158/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0538 - accuracy: 0.9625 - f1_score: 0.9618
# Epoch 158: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0557 - accuracy: 0.9611 - f1_score: 0.9598 - val_loss: 0.3773 - val_accuracy: 0.7191 - val_f1_score: 0.5916 - lr: 3.1250e-05
# Epoch 159/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0499 - accuracy: 0.9635 - f1_score: 0.9627
# Epoch 159: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0553 - accuracy: 0.9591 - f1_score: 0.9558 - val_loss: 0.3766 - val_accuracy: 0.7222 - val_f1_score: 0.5959 - lr: 3.1250e-05
# Epoch 160/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9621 - f1_score: 0.9619
# Epoch 160: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0541 - accuracy: 0.9621 - f1_score: 0.9619 - val_loss: 0.3736 - val_accuracy: 0.7253 - val_f1_score: 0.5980 - lr: 3.1250e-05
# Epoch 161/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0600 - accuracy: 0.9583 - f1_score: 0.9577
# Epoch 161: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0575 - accuracy: 0.9601 - f1_score: 0.9604 - val_loss: 0.3722 - val_accuracy: 0.7222 - val_f1_score: 0.5993 - lr: 3.1250e-05
# Epoch 162/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0516 - accuracy: 0.9635 - f1_score: 0.9631Restoring model weights from the end of the best epoch: 62.
#
# Epoch 162: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 162: val_f1_score did not improve from 0.70457
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0521 - accuracy: 0.9631 - f1_score: 0.9625 - val_loss: 0.3727 - val_accuracy: 0.7160 - val_f1_score: 0.5949 - lr: 3.1250e-05
# Epoch 162: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 7ms/step
# 0.6975308641975309

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6975308641975309
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.45      0.64      0.52        85
#            0       0.85      0.72      0.78       239
#
#     accuracy                           0.70       324
#    macro avg       0.65      0.68      0.65       324
# weighted avg       0.74      0.70      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 226 chiếm khoảng 69.75308641975309% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 54 chiếm khoảng 63.52941176470588% so với thực tế
