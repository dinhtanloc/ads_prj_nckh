# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 128, 1,padding='same')

    branch7x7 = conv1d_bn(x, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 96, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 96, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 128, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # # mixed 5, 6: 17 x 17 x 768
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    #     branch7x7 = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
    #     branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    #     branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
    #     branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch7x7, branch7x7dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    # branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # # mixed 8: 8 x 8 x 960
    # branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch3x3 = conv1d_bn(branch3x3, 288, 3,
    #                       strides=2, padding='valid')

    # branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    # branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    # branch7x7x3 = conv1d_bn(
    #     branch7x7x3, 192, 3, strides=2, padding='valid')

    # branch_pool = MaxPooling1D(3, strides=2)(x)
    # x = layers.concatenate(
    #     [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # # mixed 9: 8 x 8 x 2048
    # for i in range(2):
    #     branch1x1 = conv1d_bn(x, 288, 1,padding='same')

    #     branch3x3 = conv1d_bn(x, 256, 1,padding='same')
    #     branch3x3_1 = conv1d_bn(branch3x3, 256, 1,padding='same')
    #     branch3x3_2 = conv1d_bn(branch3x3, 256, 3,padding='same')
    #     branch3x3 = layers.concatenate(
    #         [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

    #     branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
    #     branch3x3dbl = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 256, 1,padding='same')
    #     branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 256, 3,padding='same')
    #     branch3x3dbl = layers.concatenate(
    #         [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

    #     branch_pool = AveragePooling1D(
    #         3, strides=1, padding='same')(x)
    #     branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    #     x = layers.concatenate(
    #         [branch1x1, branch3x3, branch3x3dbl, branch_pool],
    #         axis=channel_axis,
    #         name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 96)                9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 96)                0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 96)                64512     ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 96)                9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 96)                0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 96)                49152     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 96)                9216      ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 96)                9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 96)                9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 96)                0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 96)                0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 96)                9216      ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 96)                64512     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 96)                9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 96)                9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 96)                0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 96)                0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 128)               86016     ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 128)               12288     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 128)               65536     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 128)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 128)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 128)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 128)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 128)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 128)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 128)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 128)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 512)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 192)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 3, 192)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 192)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 3, 192)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 192)               36864     ['activation_39[0][0]']
#
#  conv1d_43 (Conv1D)          (None, 3, 192)               258048    ['activation_42[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 192)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 3, 192)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 192)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 3, 192)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 512)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               98304     ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               258048    ['activation_40[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 192)               36864     ['activation_43[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 192)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 192)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 192)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 192)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  mixed7 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_44[0][0]',
#                                                                      'activation_45[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 768)                  0         ['mixed7[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    1538      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1973147 (7.53 MB)
# Trainable params: 1972597 (7.52 MB)
# Non-trainable params: 550 (2.15 KB)
# __________________________________________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3193 - accuracy: 0.5417 - f1_score: 0.3798
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 12s 118ms/step - loss: 0.3086 - accuracy: 0.5429 - f1_score: 0.3894 - val_loss: 0.1150 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0562 - accuracy: 0.6771 - f1_score: 0.6524
# Epoch 2: val_f1_score improved from 0.42467 to 0.43554, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0556 - accuracy: 0.6806 - f1_score: 0.6589 - val_loss: 0.1077 - val_accuracy: 0.7377 - val_f1_score: 0.4355 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0475 - accuracy: 0.7292 - f1_score: 0.7267
# Epoch 3: val_f1_score improved from 0.43554 to 0.49962, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0476 - accuracy: 0.7265 - f1_score: 0.7228 - val_loss: 0.0420 - val_accuracy: 0.7315 - val_f1_score: 0.4996 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0410 - accuracy: 0.7760 - f1_score: 0.7746
# Epoch 4: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0408 - accuracy: 0.7784 - f1_score: 0.7780 - val_loss: 0.0760 - val_accuracy: 0.2747 - val_f1_score: 0.2233 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.8343 - f1_score: 0.8333
# Epoch 5: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0345 - accuracy: 0.8343 - f1_score: 0.8333 - val_loss: 0.1309 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0309 - accuracy: 0.8438 - f1_score: 0.8418
# Epoch 6: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0315 - accuracy: 0.8433 - f1_score: 0.8412 - val_loss: 0.2012 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.8643 - f1_score: 0.8603
# Epoch 7: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0269 - accuracy: 0.8643 - f1_score: 0.8603 - val_loss: 0.2005 - val_accuracy: 0.2685 - val_f1_score: 0.2132 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.8832 - f1_score: 0.8817
# Epoch 8: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0237 - accuracy: 0.8832 - f1_score: 0.8817 - val_loss: 0.2452 - val_accuracy: 0.2747 - val_f1_score: 0.2252 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0216 - accuracy: 0.8906 - f1_score: 0.8894
# Epoch 9: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0217 - accuracy: 0.8882 - f1_score: 0.8859 - val_loss: 0.3430 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0202 - accuracy: 0.9052 - f1_score: 0.9044
# Epoch 10: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0204 - accuracy: 0.9072 - f1_score: 0.9069 - val_loss: 0.4246 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9344 - f1_score: 0.9331
# Epoch 11: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0167 - accuracy: 0.9321 - f1_score: 0.9299 - val_loss: 0.5659 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0153 - accuracy: 0.9333 - f1_score: 0.9328
# Epoch 12: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0162 - accuracy: 0.9281 - f1_score: 0.9251 - val_loss: 0.4259 - val_accuracy: 0.2654 - val_f1_score: 0.2097 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0178 - accuracy: 0.9187 - f1_score: 0.9181
# Epoch 13: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0179 - accuracy: 0.9192 - f1_score: 0.9186 - val_loss: 0.3466 - val_accuracy: 0.2901 - val_f1_score: 0.2418 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0111 - accuracy: 0.9490 - f1_score: 0.9486
# Epoch 14: val_f1_score did not improve from 0.49962
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0122 - accuracy: 0.9471 - f1_score: 0.9459 - val_loss: 0.5577 - val_accuracy: 0.2716 - val_f1_score: 0.2193 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0181 - accuracy: 0.9083 - f1_score: 0.9070
# Epoch 15: val_f1_score improved from 0.49962 to 0.66818, saving model to best_model.h5
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0181 - accuracy: 0.9082 - f1_score: 0.9068 - val_loss: 0.0881 - val_accuracy: 0.6574 - val_f1_score: 0.6682 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0152 - accuracy: 0.9406 - f1_score: 0.9402
# Epoch 16: val_f1_score did not improve from 0.66818
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0155 - accuracy: 0.9381 - f1_score: 0.9365 - val_loss: 0.3011 - val_accuracy: 0.4568 - val_f1_score: 0.4971 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0156 - accuracy: 0.9271 - f1_score: 0.9262
# Epoch 17: val_f1_score did not improve from 0.66818
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0163 - accuracy: 0.9232 - f1_score: 0.9202 - val_loss: 0.0842 - val_accuracy: 0.7099 - val_f1_score: 0.6546 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0139 - accuracy: 0.9396 - f1_score: 0.9386
# Epoch 18: val_f1_score did not improve from 0.66818
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0138 - accuracy: 0.9401 - f1_score: 0.9394 - val_loss: 0.1752 - val_accuracy: 0.5093 - val_f1_score: 0.5338 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0063 - accuracy: 0.9677 - f1_score: 0.9675
# Epoch 19: val_f1_score did not improve from 0.66818
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0061 - accuracy: 0.9691 - f1_score: 0.9695 - val_loss: 0.1997 - val_accuracy: 0.6142 - val_f1_score: 0.6061 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0037 - accuracy: 0.9812 - f1_score: 0.9810
# Epoch 20: val_f1_score did not improve from 0.66818
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0036 - accuracy: 0.9820 - f1_score: 0.9822 - val_loss: 0.2856 - val_accuracy: 0.5741 - val_f1_score: 0.5744 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 0.9771 - f1_score: 0.9769
# Epoch 21: val_f1_score improved from 0.66818 to 0.70243, saving model to best_model.h5
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0049 - accuracy: 0.9760 - f1_score: 0.9753 - val_loss: 0.1609 - val_accuracy: 0.7284 - val_f1_score: 0.7024 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0060 - accuracy: 0.9792 - f1_score: 0.9790
# Epoch 22: val_f1_score did not improve from 0.70243
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0060 - accuracy: 0.9780 - f1_score: 0.9773 - val_loss: 0.1133 - val_accuracy: 0.6698 - val_f1_score: 0.6646 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0057 - accuracy: 0.9740 - f1_score: 0.9735
# Epoch 23: val_f1_score did not improve from 0.70243
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0055 - accuracy: 0.9750 - f1_score: 0.9752 - val_loss: 0.2308 - val_accuracy: 0.5185 - val_f1_score: 0.5398 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0094 - accuracy: 0.9677 - f1_score: 0.9672
# Epoch 24: val_f1_score did not improve from 0.70243
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0092 - accuracy: 0.9681 - f1_score: 0.9678 - val_loss: 0.4357 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9760 - f1_score: 0.9758
# Epoch 25: val_f1_score improved from 0.70243 to 0.71445, saving model to best_model.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0054 - accuracy: 0.9770 - f1_score: 0.9774 - val_loss: 0.1226 - val_accuracy: 0.7685 - val_f1_score: 0.7144 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 26: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0019 - accuracy: 0.9930 - f1_score: 0.9926 - val_loss: 0.1973 - val_accuracy: 0.7068 - val_f1_score: 0.6676 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.4946e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 27: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 6.3680e-04 - accuracy: 0.9990 - f1_score: 0.9984 - val_loss: 0.1832 - val_accuracy: 0.7469 - val_f1_score: 0.7036 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9906 - f1_score: 0.9905
# Epoch 28: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0036 - accuracy: 0.9900 - f1_score: 0.9895 - val_loss: 0.2196 - val_accuracy: 0.6605 - val_f1_score: 0.6768 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0059 - accuracy: 0.9802 - f1_score: 0.9801
# Epoch 29: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0057 - accuracy: 0.9810 - f1_score: 0.9813 - val_loss: 0.1606 - val_accuracy: 0.7130 - val_f1_score: 0.6574 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9850 - f1_score: 0.9852
# Epoch 30: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0039 - accuracy: 0.9850 - f1_score: 0.9852 - val_loss: 0.1979 - val_accuracy: 0.7346 - val_f1_score: 0.5384 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0044 - accuracy: 0.9844 - f1_score: 0.9840
# Epoch 31: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0044 - accuracy: 0.9840 - f1_score: 0.9835 - val_loss: 0.1625 - val_accuracy: 0.6975 - val_f1_score: 0.5560 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 0.9802 - f1_score: 0.9798
# Epoch 32: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0045 - accuracy: 0.9800 - f1_score: 0.9795 - val_loss: 0.3472 - val_accuracy: 0.7377 - val_f1_score: 0.4491 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 0.9771 - f1_score: 0.9770
# Epoch 33: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0046 - accuracy: 0.9770 - f1_score: 0.9769 - val_loss: 0.1918 - val_accuracy: 0.7253 - val_f1_score: 0.6763 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 34: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0023 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.1959 - val_accuracy: 0.7284 - val_f1_score: 0.6726 - lr: 0.0010
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0042 - accuracy: 0.9875 - f1_score: 0.9869
# Epoch 35: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0041 - accuracy: 0.9880 - f1_score: 0.9877 - val_loss: 0.1849 - val_accuracy: 0.6944 - val_f1_score: 0.6334 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9906 - f1_score: 0.9904
# Epoch 36: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0029 - accuracy: 0.9900 - f1_score: 0.9895 - val_loss: 0.3281 - val_accuracy: 0.7346 - val_f1_score: 0.4833 - lr: 0.0010
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 0.9875 - f1_score: 0.9873
# Epoch 37: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0025 - accuracy: 0.9880 - f1_score: 0.9880 - val_loss: 0.3209 - val_accuracy: 0.7253 - val_f1_score: 0.4822 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0041 - accuracy: 0.9854 - f1_score: 0.9852
# Epoch 38: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0040 - accuracy: 0.9860 - f1_score: 0.9862 - val_loss: 0.1702 - val_accuracy: 0.7469 - val_f1_score: 0.6505 - lr: 0.0010
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 39: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.2477 - val_accuracy: 0.4938 - val_f1_score: 0.5255 - lr: 0.0010
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.6372e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 40: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 4.9658e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.7006 - val_f1_score: 0.6281 - lr: 0.0010
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.6833e-04 - accuracy: 0.9958 - f1_score: 0.9957
# Epoch 41: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 6.4945e-04 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 0.1920 - val_accuracy: 0.7253 - val_f1_score: 0.6633 - lr: 0.0010
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0039 - accuracy: 0.9865 - f1_score: 0.9863
# Epoch 42: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0039 - accuracy: 0.9860 - f1_score: 0.9856 - val_loss: 0.4097 - val_accuracy: 0.4722 - val_f1_score: 0.5085 - lr: 0.0010
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0069 - accuracy: 0.9740 - f1_score: 0.9739
# Epoch 43: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0068 - accuracy: 0.9750 - f1_score: 0.9755 - val_loss: 0.1143 - val_accuracy: 0.6821 - val_f1_score: 0.6491 - lr: 0.0010
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0044 - accuracy: 0.9854 - f1_score: 0.9853
# Epoch 44: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0045 - accuracy: 0.9850 - f1_score: 0.9848 - val_loss: 0.1951 - val_accuracy: 0.7099 - val_f1_score: 0.5586 - lr: 0.0010
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0089 - accuracy: 0.9625 - f1_score: 0.9618
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 45: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0088 - accuracy: 0.9621 - f1_score: 0.9612 - val_loss: 0.5374 - val_accuracy: 0.3549 - val_f1_score: 0.4009 - lr: 0.0010
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0043 - accuracy: 0.9833 - f1_score: 0.9831
# Epoch 46: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0042 - accuracy: 0.9840 - f1_score: 0.9842 - val_loss: 0.1719 - val_accuracy: 0.7130 - val_f1_score: 0.6761 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0010 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 47: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2518 - val_accuracy: 0.7284 - val_f1_score: 0.5920 - lr: 5.0000e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.1549e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 48: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 5.4935e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2310 - val_accuracy: 0.7068 - val_f1_score: 0.6188 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.2517e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 49: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 2.1679e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2410 - val_accuracy: 0.7160 - val_f1_score: 0.6713 - lr: 5.0000e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.9652e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 50: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 9.9857e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.7191 - val_f1_score: 0.6794 - lr: 5.0000e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5875e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 51: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 1.6026e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2447 - val_accuracy: 0.7099 - val_f1_score: 0.6646 - lr: 5.0000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.7549e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 52: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 7.5946e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.6975 - val_f1_score: 0.6417 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.0251e-04 - accuracy: 0.9979 - f1_score: 0.9977
# Epoch 53: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 2.9015e-04 - accuracy: 0.9980 - f1_score: 0.9978 - val_loss: 0.2243 - val_accuracy: 0.6883 - val_f1_score: 0.6787 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.8677e-04 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 54: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 6.2493e-04 - accuracy: 0.9970 - f1_score: 0.9964 - val_loss: 0.2594 - val_accuracy: 0.6327 - val_f1_score: 0.6120 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9937 - f1_score: 0.9936
# Epoch 55: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.3732 - val_accuracy: 0.7191 - val_f1_score: 0.4445 - lr: 5.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9940 - f1_score: 0.9940
# Epoch 56: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0014 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.3011 - val_accuracy: 0.7253 - val_f1_score: 0.5950 - lr: 5.0000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9937 - f1_score: 0.9930
# Epoch 57: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0011 - accuracy: 0.9940 - f1_score: 0.9935 - val_loss: 0.5389 - val_accuracy: 0.7346 - val_f1_score: 0.4400 - lr: 5.0000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.8163e-04 - accuracy: 0.9969 - f1_score: 0.9968
# Epoch 58: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 5.9388e-04 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.4607 - val_accuracy: 0.7284 - val_f1_score: 0.4383 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.1021e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 59: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.8272e-04 - accuracy: 0.9980 - f1_score: 0.9975 - val_loss: 0.2297 - val_accuracy: 0.7253 - val_f1_score: 0.6804 - lr: 5.0000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5066e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 60: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.5418e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.7469 - val_f1_score: 0.7060 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.3565e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 7.1635e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.7315 - val_f1_score: 0.6950 - lr: 5.0000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.9520e-05 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 62: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 7.6892e-05 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2261 - val_accuracy: 0.7438 - val_f1_score: 0.7024 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.7580e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 1.0974e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.7346 - val_f1_score: 0.6990 - lr: 5.0000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5652e-04 - accuracy: 0.9990 - f1_score: 0.9989
# Epoch 64: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 1.5003e-04 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 0.2428 - val_accuracy: 0.6451 - val_f1_score: 0.6245 - lr: 5.0000e-04
# Epoch 65/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.1854e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 65: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 3.1854e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.6636 - val_f1_score: 0.6377 - lr: 5.0000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.3878e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.2533e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.6883 - val_f1_score: 0.6495 - lr: 2.5000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4349e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 2.3388e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.7068 - val_f1_score: 0.6975 - lr: 2.5000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.2770e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 68: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.1809e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.7037 - val_f1_score: 0.6939 - lr: 2.5000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8362e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 1.7976e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.7037 - val_f1_score: 0.6901 - lr: 2.5000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4089e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 2.3818e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.7099 - val_f1_score: 0.6907 - lr: 2.5000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.0178e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 2.9433e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.7099 - val_f1_score: 0.6938 - lr: 2.5000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.5084e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 1.1180e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.7160 - val_f1_score: 0.6982 - lr: 2.5000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1121e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0953e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.7130 - val_f1_score: 0.6948 - lr: 2.5000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9873e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 1.9382e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.7130 - val_f1_score: 0.6905 - lr: 2.5000e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2512e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 1.2097e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.7130 - val_f1_score: 0.6883 - lr: 2.5000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.6756e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 2.5814e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.7130 - val_f1_score: 0.6883 - lr: 2.5000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.7415e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.6891e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.7160 - val_f1_score: 0.6901 - lr: 2.5000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.9430e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 7.1710e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.7160 - val_f1_score: 0.6901 - lr: 2.5000e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6247e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.5609e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.7160 - val_f1_score: 0.6901 - lr: 2.5000e-04
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.9320e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 5.9320e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2372 - val_accuracy: 0.7222 - val_f1_score: 0.6794 - lr: 2.5000e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4123e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3618e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2376 - val_accuracy: 0.7191 - val_f1_score: 0.6807 - lr: 2.5000e-04
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3192e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 1.2660e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2397 - val_accuracy: 0.7222 - val_f1_score: 0.6870 - lr: 2.5000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.2105e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.4081e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2405 - val_accuracy: 0.7191 - val_f1_score: 0.6850 - lr: 2.5000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3521e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 1.3587e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.7191 - val_f1_score: 0.6893 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.3181e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 85: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 4.2021e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.7099 - val_f1_score: 0.6837 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.8010e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 6.5176e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.7099 - val_f1_score: 0.6861 - lr: 1.2500e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.0553e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 5.8548e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.7130 - val_f1_score: 0.6895 - lr: 1.2500e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.5532e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.4235e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.7130 - val_f1_score: 0.6883 - lr: 1.2500e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.2352e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 3.1323e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2468 - val_accuracy: 0.7099 - val_f1_score: 0.6847 - lr: 1.2500e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 8.0284e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 7.8587e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2470 - val_accuracy: 0.7099 - val_f1_score: 0.6847 - lr: 1.2500e-04
# Epoch 91/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 2.9559e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 2.8430e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.7068 - val_f1_score: 0.6825 - lr: 1.2500e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9252e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 2.8349e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.7130 - val_f1_score: 0.6895 - lr: 1.2500e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.4315e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.3995e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.7160 - val_f1_score: 0.6917 - lr: 1.2500e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.3808e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 6.2910e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.7191 - val_f1_score: 0.6956 - lr: 1.2500e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5066e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 4.3254e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2439 - val_accuracy: 0.7191 - val_f1_score: 0.6956 - lr: 1.2500e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.3193e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.2063e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.7284 - val_f1_score: 0.7106 - lr: 1.2500e-04
# Epoch 97/10000
# 16/16 [==============================] - ETA: 0s - loss: 7.5476e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 7.5476e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2458 - val_accuracy: 0.7284 - val_f1_score: 0.7106 - lr: 1.2500e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4331e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 2.3365e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.7222 - val_f1_score: 0.7016 - lr: 1.2500e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0159e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 1.0843e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2471 - val_accuracy: 0.7191 - val_f1_score: 0.6943 - lr: 1.2500e-04
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.8137e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 7.5521e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.7191 - val_f1_score: 0.6943 - lr: 1.2500e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1292e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 1.0829e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.7191 - val_f1_score: 0.6963 - lr: 1.2500e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5442e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 4.6545e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2504 - val_accuracy: 0.7191 - val_f1_score: 0.6963 - lr: 1.2500e-04
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.1236e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 2.1236e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.7191 - val_f1_score: 0.6963 - lr: 1.2500e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.1807e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 3.0762e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2534 - val_accuracy: 0.7160 - val_f1_score: 0.6907 - lr: 1.2500e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1294e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 105: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 1.0894e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2541 - val_accuracy: 0.7160 - val_f1_score: 0.6885 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.5749e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 7.3058e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.7160 - val_f1_score: 0.6885 - lr: 6.2500e-05
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5903e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 4.3993e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.7222 - val_f1_score: 0.7009 - lr: 6.2500e-05
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8168e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 3.7039e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.7130 - val_f1_score: 0.6977 - lr: 6.2500e-05
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.0161e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 3.4607e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.7191 - val_f1_score: 0.7000 - lr: 6.2500e-05
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.9927e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 3.8702e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.7160 - val_f1_score: 0.6949 - lr: 6.2500e-05
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.0157e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 9.8047e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.7160 - val_f1_score: 0.6949 - lr: 6.2500e-05
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.9242e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 112: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 2.8056e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.7160 - val_f1_score: 0.6949 - lr: 6.2500e-05
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.1871e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 5.1204e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.7191 - val_f1_score: 0.6968 - lr: 6.2500e-05
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 3.8446e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 114: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 3.7737e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.7191 - val_f1_score: 0.6968 - lr: 6.2500e-05
# Epoch 115/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.0034e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 115: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0034e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.7222 - val_f1_score: 0.6988 - lr: 6.2500e-05
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6782e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 1.6275e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.7222 - val_f1_score: 0.6988 - lr: 6.2500e-05
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.5454e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 117: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 4.3632e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.6852e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 118: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 1.6203e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.7160 - val_f1_score: 0.6912 - lr: 6.2500e-05
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 4.7590e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 119: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 36ms/step - loss: 4.5672e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.7160 - val_f1_score: 0.6912 - lr: 6.2500e-05
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3188e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 120: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2662e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 5.5944e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 121: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 33ms/step - loss: 5.4085e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 6.9134e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 122: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 38ms/step - loss: 1.9910e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.4466e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 123: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 2.3445e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2182e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 124: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 35ms/step - loss: 2.9412e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 7.3251e-06 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 25.
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 125: val_f1_score did not improve from 0.71445
# 16/16 [==============================] - 1s 37ms/step - loss: 7.3810e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2663 - val_accuracy: 0.7191 - val_f1_score: 0.6931 - lr: 6.2500e-05
# Epoch 125: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 7ms/step
# 0.7685185185185185

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7685185185185185
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.58      0.42      0.49        85
#            0       0.81      0.89      0.85       239
#
#     accuracy                           0.77       324
#    macro avg       0.70      0.66      0.67       324
# weighted avg       0.75      0.77      0.76       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 249 chiếm khoảng 76.85185185185185% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 36 chiếm khoảng 42.35294117647059% so với thực tế
