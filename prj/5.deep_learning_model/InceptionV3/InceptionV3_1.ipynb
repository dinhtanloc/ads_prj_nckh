# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from __future__ import print_function
from __future__ import absolute_import

import warnings
import numpy as np

from keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Reshape, GlobalAveragePooling1D,MaxPooling1D,Dense,AveragePooling1D
from keras.models import Model
from keras import layers

from keras.layers import Layer
from keras import backend as K


WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv1d_bn(x,
              filters,
              kernel_size,
              padding='same',
              strides=1,
              name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    bn_axis = 1
    x = Conv1D(
        filters, kernel_size,
        strides=strides,
        padding=str(padding),
        use_bias=False,
        name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    x = Activation('relu', name=name)(x)
    return x

# %%
def InceptionV3():
    # Determine proper input shape
    input_shape = (42,1)
    x_input = Input(shape=input_shape)
    channel_axis = -1

    x = conv1d_bn(x_input, 32, 3, strides=2, padding='valid')
    x = conv1d_bn(x, 32, 3, padding='valid')
    x = conv1d_bn(x, 64, 3, padding='valid')
    x = MaxPooling1D(3, strides=2, name="block1_pool")(x)
    # mixed 0, 1, 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')

    branch5x5 = conv1d_bn(x, 48,1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')
    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 32, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed0')

    # mixed 1: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64,1,padding='same')
    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64,5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed1')

    # mixed 2: 35 x 35 x 256
    branch1x1 = conv1d_bn(x, 64, 1,padding='same')

    branch5x5 = conv1d_bn(x, 48, 1,padding='same')
    branch5x5 = conv1d_bn(branch5x5, 64, 5,padding='same')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 64, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch5x5, branch3x3dbl, branch_pool],
        axis=channel_axis,
        name='mixed2')

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv1d_bn(x, 128, 3, strides=2, padding='valid')

    branch3x3dbl = conv1d_bn(x, 64, 1,padding='same')
    branch3x3dbl = conv1d_bn(branch3x3dbl, 96, 3,padding='same')
    branch3x3dbl = conv1d_bn(
        branch3x3dbl, 96, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch3x3dbl, branch_pool], axis=channel_axis, name='mixed3')

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 128, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 128, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed4')

    # mixed 5, 6: 17 x 17 x 768
    for i in range(2):
        branch1x1 = conv1d_bn(x, 192, 1,padding='same')

        branch7x7 = conv1d_bn(x, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 160, 1,padding='same')
        branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

        branch7x7dbl = conv1d_bn(x, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 1,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 160, 7,padding='same')
        branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

        branch_pool = AveragePooling1D(
            3, strides=1, padding='same')(x)
        branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
        x = layers.concatenate(
            [branch1x1, branch7x7, branch7x7dbl, branch_pool],
            axis=channel_axis,
            name='mixed' + str(5 + i))

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv1d_bn(x, 192, 1,padding='same')

    branch7x7 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 1,padding='same')
    branch7x7 = conv1d_bn(branch7x7, 192, 7,padding='same')

    branch7x7dbl = conv1d_bn(x, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 7,padding='same')
    branch7x7dbl = conv1d_bn(branch7x7dbl, 192, 1,padding='same')

    branch_pool = AveragePooling1D(3, strides=1, padding='same')(x)
    branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
    x = layers.concatenate(
        [branch1x1, branch7x7, branch7x7dbl, branch_pool],
        axis=channel_axis,
        name='mixed7')

    # mixed 8: 8 x 8 x 1280
    branch3x3 = conv1d_bn(x, 192, 1,padding='same')
    branch3x3 = conv1d_bn(branch3x3, 320, 3,
                          strides=2, padding='valid')

    branch7x7x3 = conv1d_bn(x, 192, 1,padding='same')
    branch7x7x3 = conv1d_bn(branch7x7x3, 192, 1,padding='same')
    branch7x7x3 = conv1d_bn(branch7x7x3, 192, 7,padding='same')
    branch7x7x3 = conv1d_bn(
        branch7x7x3, 192, 3, strides=2, padding='valid')

    branch_pool = MaxPooling1D(3, strides=2)(x)
    x = layers.concatenate(
        [branch3x3, branch7x7x3, branch_pool], axis=channel_axis, name='mixed8')

    # mixed 9: 8 x 8 x 2048
    for i in range(2):
        branch1x1 = conv1d_bn(x, 320, 1,padding='same')

        branch3x3 = conv1d_bn(x, 384, 1,padding='same')
        branch3x3_1 = conv1d_bn(branch3x3, 384, 1,padding='same')
        branch3x3_2 = conv1d_bn(branch3x3, 384, 3,padding='same')
        branch3x3 = layers.concatenate(
            [branch3x3_1, branch3x3_2], axis=channel_axis, name='mixed9_' + str(i))

        branch3x3dbl = conv1d_bn(x, 448, 1,padding='same')
        branch3x3dbl = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
        branch3x3dbl_1 = conv1d_bn(branch3x3dbl, 384, 1,padding='same')
        branch3x3dbl_2 = conv1d_bn(branch3x3dbl, 384, 3,padding='same')
        branch3x3dbl = layers.concatenate(
            [branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

        branch_pool = AveragePooling1D(
            3, strides=1, padding='same')(x)
        branch_pool = conv1d_bn(branch_pool, 192, 1,padding='same')
        x = layers.concatenate(
            [branch1x1, branch3x3, branch3x3dbl, branch_pool],
            axis=channel_axis,
            name='mixed' + str(9 + i))
    x = GlobalAveragePooling1D(name='avg_pool')(x)
    x = Dense(2, activation='softmax', name='predictions')(x)

    # Create model.
    model = Model(x_input, x, name='inception_v3')
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

model = InceptionV3()
# lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()

lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)


lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 20, 32)               96        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 20, 32)               60        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 20, 32)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 18, 32)               3072      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 18, 32)               54        ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 18, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 16, 64)               6144      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 64)               48        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_pool (MaxPooling1D)  (None, 7, 64)                0         ['activation_2[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 64)                21        ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 64)                0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 7, 48)                3072      ['block1_pool[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 7, 96)                18432     ['activation_6[0][0]']
#
#  batch_normalization_4 (Bat  (None, 7, 48)                21        ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 7, 96)                21        ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 48)                0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 7, 96)                0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling1d (Average  (None, 7, 64)                0         ['block1_pool[0][0]']
#  Pooling1D)
#
#  conv1d_3 (Conv1D)           (None, 7, 64)                4096      ['block1_pool[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 7, 64)                15360     ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 7, 96)                27648     ['activation_7[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 7, 32)                2048      ['average_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 7, 64)                21        ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 7, 64)                21        ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 7, 96)                21        ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 7, 32)                21        ['conv1d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 7, 64)                0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 7, 64)                0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 7, 96)                0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 7, 32)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  mixed0 (Concatenate)        (None, 7, 256)               0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]',
#                                                                      'activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 64)                21        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 7, 64)                0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 7, 96)                18432     ['activation_13[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 48)                21        ['conv1d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 7, 96)                21        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 7, 48)                0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 7, 96)                0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling1d_1 (Avera  (None, 7, 256)               0         ['mixed0[0][0]']
#  gePooling1D)
#
#  conv1d_10 (Conv1D)          (None, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 7, 64)                15360     ['activation_11[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 7, 96)                27648     ['activation_14[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 7, 64)                16384     ['average_pooling1d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 64)                21        ['conv1d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 64)                21        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 7, 96)                21        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 64)                21        ['conv1d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 7, 64)                0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 7, 64)                0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 7, 96)                0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 64)                0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 7, 288)               0         ['activation_10[0][0]',
#                                                                      'activation_12[0][0]',
#                                                                      'activation_15[0][0]',
#                                                                      'activation_16[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 7, 64)                21        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 7, 64)                0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 7, 96)                18432     ['activation_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 7, 48)                21        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 7, 96)                21        ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 7, 48)                0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 7, 96)                0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling1d_2 (Avera  (None, 7, 288)               0         ['mixed1[0][0]']
#  gePooling1D)
#
#  conv1d_17 (Conv1D)          (None, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 7, 64)                15360     ['activation_18[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 7, 96)                27648     ['activation_21[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 7, 64)                18432     ['average_pooling1d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 64)                21        ['conv1d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 7, 64)                21        ['conv1d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 7, 96)                21        ['conv1d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 7, 64)                21        ['conv1d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 64)                0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 7, 64)                0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 7, 96)                0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 7, 64)                0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 7, 288)               0         ['activation_17[0][0]',
#                                                                      'activation_19[0][0]',
#                                                                      'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 7, 64)                21        ['conv1d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 7, 64)                0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 7, 96)                18432     ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 7, 96)                21        ['conv1d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 7, 96)                0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 3, 128)               110592    ['mixed2[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 3, 96)                27648     ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 3, 128)               9         ['conv1d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 3, 96)                9         ['conv1d_27[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 3, 128)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 3, 96)                0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling1d (MaxPooling1  (None, 3, 288)               0         ['mixed2[0][0]']
#  D)
#
#  mixed3 (Concatenate)        (None, 3, 512)               0         ['activation_24[0][0]',
#                                                                      'activation_27[0][0]',
#                                                                      'max_pooling1d[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 3, 128)               9         ['conv1d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 3, 128)               0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv1d_33 (Conv1D)          (None, 3, 128)               114688    ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 3, 128)               9         ['conv1d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 3, 128)               0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 3, 128)               65536     ['mixed3[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 3, 128)               16384     ['activation_33[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 128)               9         ['conv1d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 3, 128)               9         ['conv1d_34[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 3, 128)               0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 3, 128)               0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 3, 128)               16384     ['activation_29[0][0]']
#
#  conv1d_35 (Conv1D)          (None, 3, 128)               114688    ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 3, 128)               9         ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 3, 128)               9         ['conv1d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 3, 128)               0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 3, 128)               0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling1d_3 (Avera  (None, 3, 512)               0         ['mixed3[0][0]']
#  gePooling1D)
#
#  conv1d_28 (Conv1D)          (None, 3, 192)               98304     ['mixed3[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 3, 192)               172032    ['activation_30[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3, 192)               24576     ['activation_35[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3, 192)               98304     ['average_pooling1d_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 192)               9         ['conv1d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 3, 192)               9         ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 3, 192)               9         ['conv1d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 3, 192)               9         ['conv1d_37[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 3, 192)               0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 3, 192)               0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 3, 192)               0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 3, 192)               0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 3, 768)               0         ['activation_28[0][0]',
#                                                                      'activation_31[0][0]',
#                                                                      'activation_36[0][0]',
#                                                                      'activation_37[0][0]']
#
#  conv1d_42 (Conv1D)          (None, 3, 160)               122880    ['mixed4[0][0]']
#
#  batch_normalization_42 (Ba  (None, 3, 160)               9         ['conv1d_42[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 3, 160)               0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv1d_43 (Conv1D)          (None, 3, 160)               179200    ['activation_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 3, 160)               9         ['conv1d_43[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 3, 160)               0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv1d_39 (Conv1D)          (None, 3, 160)               122880    ['mixed4[0][0]']
#
#  conv1d_44 (Conv1D)          (None, 3, 160)               25600     ['activation_43[0][0]']
#
#  batch_normalization_39 (Ba  (None, 3, 160)               9         ['conv1d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 3, 160)               9         ['conv1d_44[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 3, 160)               0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 3, 160)               0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv1d_40 (Conv1D)          (None, 3, 160)               25600     ['activation_39[0][0]']
#
#  conv1d_45 (Conv1D)          (None, 3, 160)               179200    ['activation_44[0][0]']
#
#  batch_normalization_40 (Ba  (None, 3, 160)               9         ['conv1d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 3, 160)               9         ['conv1d_45[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 3, 160)               0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 3, 160)               0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  average_pooling1d_4 (Avera  (None, 3, 768)               0         ['mixed4[0][0]']
#  gePooling1D)
#
#  conv1d_38 (Conv1D)          (None, 3, 192)               147456    ['mixed4[0][0]']
#
#  conv1d_41 (Conv1D)          (None, 3, 192)               215040    ['activation_40[0][0]']
#
#  conv1d_46 (Conv1D)          (None, 3, 192)               30720     ['activation_45[0][0]']
#
#  conv1d_47 (Conv1D)          (None, 3, 192)               147456    ['average_pooling1d_4[0][0]']
#
#  batch_normalization_38 (Ba  (None, 3, 192)               9         ['conv1d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 3, 192)               9         ['conv1d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 3, 192)               9         ['conv1d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 3, 192)               9         ['conv1d_47[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 3, 192)               0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 3, 192)               0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 3, 192)               0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 3, 192)               0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 3, 768)               0         ['activation_38[0][0]',
#                                                                      'activation_41[0][0]',
#                                                                      'activation_46[0][0]',
#                                                                      'activation_47[0][0]']
#
#  conv1d_52 (Conv1D)          (None, 3, 160)               122880    ['mixed5[0][0]']
#
#  batch_normalization_52 (Ba  (None, 3, 160)               9         ['conv1d_52[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 3, 160)               0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv1d_53 (Conv1D)          (None, 3, 160)               179200    ['activation_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 3, 160)               9         ['conv1d_53[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 3, 160)               0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv1d_49 (Conv1D)          (None, 3, 160)               122880    ['mixed5[0][0]']
#
#  conv1d_54 (Conv1D)          (None, 3, 160)               25600     ['activation_53[0][0]']
#
#  batch_normalization_49 (Ba  (None, 3, 160)               9         ['conv1d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_54 (Ba  (None, 3, 160)               9         ['conv1d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 3, 160)               0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 3, 160)               0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv1d_50 (Conv1D)          (None, 3, 160)               25600     ['activation_49[0][0]']
#
#  conv1d_55 (Conv1D)          (None, 3, 160)               179200    ['activation_54[0][0]']
#
#  batch_normalization_50 (Ba  (None, 3, 160)               9         ['conv1d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_55 (Ba  (None, 3, 160)               9         ['conv1d_55[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 3, 160)               0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_55 (Activation)  (None, 3, 160)               0         ['batch_normalization_55[0][0]
# ...
#                                                                     ']
#
#  activation_79 (Activation)  (None, 1, 384)               0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv1d_76 (Conv1D)          (None, 1, 384)               147456    ['activation_75[0][0]']
#
#  conv1d_77 (Conv1D)          (None, 1, 384)               442368    ['activation_75[0][0]']
#
#  conv1d_80 (Conv1D)          (None, 1, 384)               147456    ['activation_79[0][0]']
#
#  conv1d_81 (Conv1D)          (None, 1, 384)               442368    ['activation_79[0][0]']
#
#  average_pooling1d_7 (Avera  (None, 1, 1280)              0         ['mixed8[0][0]']
#  gePooling1D)
#
#  conv1d_74 (Conv1D)          (None, 1, 320)               409600    ['mixed8[0][0]']
#
#  batch_normalization_76 (Ba  (None, 1, 384)               3         ['conv1d_76[0][0]']
#  tchNormalization)
#
#  batch_normalization_77 (Ba  (None, 1, 384)               3         ['conv1d_77[0][0]']
#  tchNormalization)
#
#  batch_normalization_80 (Ba  (None, 1, 384)               3         ['conv1d_80[0][0]']
#  tchNormalization)
#
#  batch_normalization_81 (Ba  (None, 1, 384)               3         ['conv1d_81[0][0]']
#  tchNormalization)
#
#  conv1d_82 (Conv1D)          (None, 1, 192)               245760    ['average_pooling1d_7[0][0]']
#
#  batch_normalization_74 (Ba  (None, 1, 320)               3         ['conv1d_74[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 1, 384)               0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  activation_77 (Activation)  (None, 1, 384)               0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  activation_80 (Activation)  (None, 1, 384)               0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  activation_81 (Activation)  (None, 1, 384)               0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  batch_normalization_82 (Ba  (None, 1, 192)               3         ['conv1d_82[0][0]']
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 1, 320)               0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 1, 768)               0         ['activation_76[0][0]',
#                                                                      'activation_77[0][0]']
#
#  concatenate (Concatenate)   (None, 1, 768)               0         ['activation_80[0][0]',
#                                                                      'activation_81[0][0]']
#
#  activation_82 (Activation)  (None, 1, 192)               0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 1, 2048)              0         ['activation_74[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_82[0][0]']
#
#  conv1d_87 (Conv1D)          (None, 1, 448)               917504    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 1, 448)               3         ['conv1d_87[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 1, 448)               0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv1d_84 (Conv1D)          (None, 1, 384)               786432    ['mixed9[0][0]']
#
#  conv1d_88 (Conv1D)          (None, 1, 384)               516096    ['activation_87[0][0]']
#
#  batch_normalization_84 (Ba  (None, 1, 384)               3         ['conv1d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 1, 384)               3         ['conv1d_88[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 1, 384)               0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 1, 384)               0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv1d_85 (Conv1D)          (None, 1, 384)               147456    ['activation_84[0][0]']
#
#  conv1d_86 (Conv1D)          (None, 1, 384)               442368    ['activation_84[0][0]']
#
#  conv1d_89 (Conv1D)          (None, 1, 384)               147456    ['activation_88[0][0]']
#
#  conv1d_90 (Conv1D)          (None, 1, 384)               442368    ['activation_88[0][0]']
#
#  average_pooling1d_8 (Avera  (None, 1, 2048)              0         ['mixed9[0][0]']
#  gePooling1D)
#
#  conv1d_83 (Conv1D)          (None, 1, 320)               655360    ['mixed9[0][0]']
#
#  batch_normalization_85 (Ba  (None, 1, 384)               3         ['conv1d_85[0][0]']
#  tchNormalization)
#
#  batch_normalization_86 (Ba  (None, 1, 384)               3         ['conv1d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_89 (Ba  (None, 1, 384)               3         ['conv1d_89[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 1, 384)               3         ['conv1d_90[0][0]']
#  tchNormalization)
#
#  conv1d_91 (Conv1D)          (None, 1, 192)               393216    ['average_pooling1d_8[0][0]']
#
#  batch_normalization_83 (Ba  (None, 1, 320)               3         ['conv1d_83[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 1, 384)               0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  activation_86 (Activation)  (None, 1, 384)               0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_89 (Activation)  (None, 1, 384)               0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 1, 384)               0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  batch_normalization_91 (Ba  (None, 1, 192)               3         ['conv1d_91[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 1, 320)               0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 1, 768)               0         ['activation_85[0][0]',
#                                                                      'activation_86[0][0]']
#
#  concatenate_1 (Concatenate  (None, 1, 768)               0         ['activation_89[0][0]',
#  )                                                                   'activation_90[0][0]']
#
#  activation_91 (Activation)  (None, 1, 192)               0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 1, 2048)              0         ['activation_83[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_91[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling1D)
#
#  predictions (Dense)         (None, 2)                    4098      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 13919937 (53.10 MB)
# Trainable params: 13919191 (53.10 MB)
# Non-trainable params: 746 (2.91 KB)
# __________________________________________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[checkpointer,early_stopping,lr_scheduler])
# Out:
# Epoch 1/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9900 - accuracy: 0.6707 - f1_score: 0.6804
# Epoch 1: val_loss improved from inf to 105.30546, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 24s 369ms/step - loss: 1.9900 - accuracy: 0.6707 - f1_score: 0.6804 - val_loss: 105.3055 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 2/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.7546 - f1_score: 0.7585
# Epoch 2: val_loss did not improve from 105.30546
# 11/11 [==============================] - 1s 135ms/step - loss: 0.5681 - accuracy: 0.7546 - f1_score: 0.7585 - val_loss: 2918.4287 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5739 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 3: val_loss did not improve from 105.30546
# 11/11 [==============================] - 1s 136ms/step - loss: 0.5739 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 797.1759 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5460 - accuracy: 0.7637 - f1_score: 0.7585
# Epoch 4: val_loss did not improve from 105.30546
# 11/11 [==============================] - 1s 134ms/step - loss: 0.5460 - accuracy: 0.7637 - f1_score: 0.7585 - val_loss: 252.2940 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 5/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 5: val_loss did not improve from 105.30546
# 11/11 [==============================] - 1s 132ms/step - loss: 0.5319 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 111.7783 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5201 - accuracy: 0.7637 - f1_score: 0.7585
# Epoch 6: val_loss improved from 105.30546 to 51.85919, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 2s 178ms/step - loss: 0.5201 - accuracy: 0.7637 - f1_score: 0.7585 - val_loss: 51.8592 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.7637 - f1_score: 0.7457
# Epoch 7: val_loss improved from 51.85919 to 7.49232, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 2s 184ms/step - loss: 0.5186 - accuracy: 0.7637 - f1_score: 0.7457 - val_loss: 7.4923 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5435 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 8: val_loss improved from 7.49232 to 0.60522, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 2s 176ms/step - loss: 0.5435 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 0.6052 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 9/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5248 - accuracy: 0.7637 - f1_score: 0.7798
# Epoch 9: val_loss improved from 0.60522 to 0.58019, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 2s 178ms/step - loss: 0.5248 - accuracy: 0.7637 - f1_score: 0.7798 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5225 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 10: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 135ms/step - loss: 0.5225 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 8.6661 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 11: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 140ms/step - loss: 0.5073 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 6.7622 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 12/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5154 - accuracy: 0.7637 - f1_score: 0.7457
# Epoch 12: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 138ms/step - loss: 0.5154 - accuracy: 0.7637 - f1_score: 0.7457 - val_loss: 1.3277 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 13/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5244 - accuracy: 0.7637 - f1_score: 0.7713
# Epoch 13: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 136ms/step - loss: 0.5244 - accuracy: 0.7637 - f1_score: 0.7713 - val_loss: 23.0508 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 14/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5409 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 14: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 137ms/step - loss: 0.5409 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 24.6281 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 15/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 15: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 136ms/step - loss: 0.5290 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 22.3869 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 16/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 16: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 142ms/step - loss: 0.5267 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 22.2818 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.7637 - f1_score: 0.7713
# Epoch 17: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 135ms/step - loss: 0.5207 - accuracy: 0.7637 - f1_score: 0.7713 - val_loss: 5.7589 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 18/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5096 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 18: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 136ms/step - loss: 0.5096 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 1.8627 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 19: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 135ms/step - loss: 0.5110 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 0.6236 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7591 - f1_score: 0.7670
# Epoch 20: val_loss did not improve from 0.58019
# 11/11 [==============================] - 1s 136ms/step - loss: 0.4991 - accuracy: 0.7591 - f1_score: 0.7670 - val_loss: 0.5849 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.7637 - f1_score: 0.7457
# Epoch 21: val_loss did not improve from 0.58019
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 [==============================] - 1s 136ms/step - loss: 0.5024 - accuracy: 0.7637 - f1_score: 0.7457 - val_loss: 0.5891 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 22/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4839 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 22: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 143ms/step - loss: 0.4839 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 0.6004 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 23/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 23: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 153ms/step - loss: 0.4663 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 0.6039 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 24/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.7637 - f1_score: 0.7756
# Epoch 24: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 148ms/step - loss: 0.4566 - accuracy: 0.7637 - f1_score: 0.7756 - val_loss: 0.6091 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 25/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.7637 - f1_score: 0.7713
# Epoch 25: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 145ms/step - loss: 0.4365 - accuracy: 0.7637 - f1_score: 0.7713 - val_loss: 0.6064 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 26/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 26: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 145ms/step - loss: 0.4249 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 0.6129 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 27/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.7637 - f1_score: 0.7756
# Epoch 27: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 145ms/step - loss: 0.4197 - accuracy: 0.7637 - f1_score: 0.7756 - val_loss: 0.6146 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 28/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.7637 - f1_score: 0.7628
# Epoch 28: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 142ms/step - loss: 0.3873 - accuracy: 0.7637 - f1_score: 0.7628 - val_loss: 0.6230 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 29/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4392 - accuracy: 0.7637 - f1_score: 0.7670
# Epoch 29: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 141ms/step - loss: 0.4392 - accuracy: 0.7637 - f1_score: 0.7670 - val_loss: 0.6125 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 30/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.7637 - f1_score: 0.7543
# Epoch 30: val_loss did not improve from 0.58019
# 11/11 [==============================] - 2s 143ms/step - loss: 0.4150 - accuracy: 0.7637 - f1_score: 0.7543 - val_loss: 0.6009 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 31/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.7637 - f1_score: 0.7585
# Epoch 31: val_loss did not improve from 0.58019
# Restoring model weights from the end of the best epoch: 1.
# 11/11 [==============================] - 2s 150ms/step - loss: 0.3777 - accuracy: 0.7637 - f1_score: 0.7585 - val_loss: 0.6394 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 31: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 2s 20ms/step
# 0.7376543209876543

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7376543209876543
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        85
#            0       0.74      1.00      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.37      0.50      0.42       324
# weighted avg       0.54      0.74      0.63       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 239 chiếm khoảng 73.76543209876543% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 0 chiếm khoảng 0.0% so với thực tế
