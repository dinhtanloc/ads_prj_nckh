# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model():
    input_shape =(42,1)
    learning_rate=0.0001

    bn_axis = -1
    step=32
    model = Sequential()
    model.add(Dense(512,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Thêm các lớp ẩn
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Lớp đầu ra với activation function 'sigmoid' cho bài toán phân lớp nhị phân
    model.add(Dense(2, activation='softmax'))
   



    model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


# data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
model=build_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.4920 - f1_score: 0.4855
# Epoch 1: val_f1_score improved from -inf to 0.31716, saving model to best_model.h5
# 16/16 [==============================] - 3s 25ms/step - loss: 0.6020 - accuracy: 0.4920 - f1_score: 0.4855 - val_loss: 0.4619 - val_accuracy: 0.3488 - val_f1_score: 0.3172 - lr: 0.0010
# Epoch 2/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.4571 - accuracy: 0.6094 - f1_score: 0.6085
# Epoch 2: val_f1_score improved from 0.31716 to 0.46889, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5884 - accuracy: 0.5190 - f1_score: 0.5149 - val_loss: 0.3820 - val_accuracy: 0.5648 - val_f1_score: 0.4689 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5624 - accuracy: 0.5120 - f1_score: 0.5068
# Epoch 3: val_f1_score improved from 0.46889 to 0.48855, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5624 - accuracy: 0.5120 - f1_score: 0.5068 - val_loss: 0.3585 - val_accuracy: 0.6389 - val_f1_score: 0.4885 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5597 - accuracy: 0.5094 - f1_score: 0.5035
# Epoch 4: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.5080 - f1_score: 0.5015 - val_loss: 0.3556 - val_accuracy: 0.6759 - val_f1_score: 0.4688 - lr: 0.0010
# Epoch 5/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.4382 - accuracy: 0.5781 - f1_score: 0.5696
# Epoch 5: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5539 - accuracy: 0.5230 - f1_score: 0.5236 - val_loss: 0.3434 - val_accuracy: 0.7222 - val_f1_score: 0.4499 - lr: 0.0010
# Epoch 6/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.5233 - accuracy: 0.5434 - f1_score: 0.5406
# Epoch 6: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5370 - accuracy: 0.5240 - f1_score: 0.5208 - val_loss: 0.3402 - val_accuracy: 0.7346 - val_f1_score: 0.4607 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5281 - accuracy: 0.5469 - f1_score: 0.5432
# Epoch 7: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5290 - accuracy: 0.5439 - f1_score: 0.5389 - val_loss: 0.3368 - val_accuracy: 0.7407 - val_f1_score: 0.4526 - lr: 0.0010
# Epoch 8/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.4786 - accuracy: 0.5781 - f1_score: 0.5772
# Epoch 8: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4862 - accuracy: 0.5898 - f1_score: 0.5883 - val_loss: 0.3316 - val_accuracy: 0.7377 - val_f1_score: 0.4622 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.6018 - f1_score: 0.5985
# Epoch 9: val_f1_score did not improve from 0.48855
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4709 - accuracy: 0.6018 - f1_score: 0.5985 - val_loss: 0.3276 - val_accuracy: 0.7407 - val_f1_score: 0.4780 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4415 - accuracy: 0.6344 - f1_score: 0.6324
# Epoch 10: val_f1_score improved from 0.48855 to 0.49859, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4442 - accuracy: 0.6347 - f1_score: 0.6329 - val_loss: 0.3261 - val_accuracy: 0.7407 - val_f1_score: 0.4986 - lr: 0.0010
# Epoch 11/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4278 - accuracy: 0.6454 - f1_score: 0.6420
# Epoch 11: val_f1_score improved from 0.49859 to 0.52136, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4265 - accuracy: 0.6537 - f1_score: 0.6536 - val_loss: 0.3273 - val_accuracy: 0.7346 - val_f1_score: 0.5214 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.6577 - f1_score: 0.6548
# Epoch 12: val_f1_score did not improve from 0.52136
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4132 - accuracy: 0.6577 - f1_score: 0.6548 - val_loss: 0.3337 - val_accuracy: 0.7315 - val_f1_score: 0.5023 - lr: 0.0010
# Epoch 13/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3918 - accuracy: 0.6808 - f1_score: 0.6790
# Epoch 13: val_f1_score improved from 0.52136 to 0.53519, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3944 - accuracy: 0.6806 - f1_score: 0.6767 - val_loss: 0.3301 - val_accuracy: 0.7346 - val_f1_score: 0.5352 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3497 - accuracy: 0.7167 - f1_score: 0.7155
# Epoch 14: val_f1_score improved from 0.53519 to 0.54283, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3463 - accuracy: 0.7226 - f1_score: 0.7243 - val_loss: 0.3226 - val_accuracy: 0.7315 - val_f1_score: 0.5428 - lr: 0.0010
# Epoch 15/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.3608 - accuracy: 0.7344 - f1_score: 0.7338
# Epoch 15: val_f1_score improved from 0.54283 to 0.54897, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3216 - accuracy: 0.7435 - f1_score: 0.7410 - val_loss: 0.3175 - val_accuracy: 0.7253 - val_f1_score: 0.5490 - lr: 0.0010
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2934 - accuracy: 0.7801 - f1_score: 0.7793
# Epoch 16: val_f1_score improved from 0.54897 to 0.63761, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3002 - accuracy: 0.7715 - f1_score: 0.7673 - val_loss: 0.3145 - val_accuracy: 0.7099 - val_f1_score: 0.6376 - lr: 0.0010
# Epoch 17/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3176 - accuracy: 0.7522 - f1_score: 0.7509
# Epoch 17: val_f1_score improved from 0.63761 to 0.65492, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3135 - accuracy: 0.7545 - f1_score: 0.7542 - val_loss: 0.3139 - val_accuracy: 0.7160 - val_f1_score: 0.6549 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.7645 - f1_score: 0.7620
# Epoch 18: val_f1_score improved from 0.65492 to 0.66492, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3094 - accuracy: 0.7645 - f1_score: 0.7620 - val_loss: 0.3164 - val_accuracy: 0.7130 - val_f1_score: 0.6649 - lr: 0.0010
# Epoch 19/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2737 - accuracy: 0.8281 - f1_score: 0.8277
# Epoch 19: val_f1_score improved from 0.66492 to 0.66595, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3049 - accuracy: 0.7595 - f1_score: 0.7597 - val_loss: 0.3174 - val_accuracy: 0.7130 - val_f1_score: 0.6660 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.7774 - f1_score: 0.7773
# Epoch 20: val_f1_score improved from 0.66595 to 0.68298, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2856 - accuracy: 0.7774 - f1_score: 0.7773 - val_loss: 0.3175 - val_accuracy: 0.7191 - val_f1_score: 0.6830 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.7954 - f1_score: 0.7942
# Epoch 21: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2760 - accuracy: 0.7954 - f1_score: 0.7942 - val_loss: 0.3216 - val_accuracy: 0.7099 - val_f1_score: 0.6727 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2731 - accuracy: 0.7958 - f1_score: 0.7935
# Epoch 22: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2685 - accuracy: 0.8004 - f1_score: 0.8004 - val_loss: 0.3207 - val_accuracy: 0.7222 - val_f1_score: 0.6749 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2442 - accuracy: 0.8240 - f1_score: 0.8224
# Epoch 23: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2472 - accuracy: 0.8224 - f1_score: 0.8201 - val_loss: 0.3297 - val_accuracy: 0.6975 - val_f1_score: 0.6737 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2418 - accuracy: 0.8094 - f1_score: 0.8086
# Epoch 24: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2400 - accuracy: 0.8104 - f1_score: 0.8101 - val_loss: 0.3368 - val_accuracy: 0.7037 - val_f1_score: 0.6772 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2352 - accuracy: 0.8302 - f1_score: 0.8293
# Epoch 25: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2343 - accuracy: 0.8303 - f1_score: 0.8296 - val_loss: 0.3372 - val_accuracy: 0.7068 - val_f1_score: 0.6675 - lr: 0.0010
# Epoch 26/10000
# 10/16 [=================>............] - ETA: 0s - loss: 0.2238 - accuracy: 0.8391 - f1_score: 0.8383
# Epoch 26: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2287 - accuracy: 0.8393 - f1_score: 0.8399 - val_loss: 0.3389 - val_accuracy: 0.7037 - val_f1_score: 0.6679 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.8253 - f1_score: 0.8245
# Epoch 27: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2381 - accuracy: 0.8253 - f1_score: 0.8245 - val_loss: 0.3417 - val_accuracy: 0.6728 - val_f1_score: 0.6662 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.8194 - f1_score: 0.8214
# Epoch 28: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2299 - accuracy: 0.8194 - f1_score: 0.8214 - val_loss: 0.3372 - val_accuracy: 0.6852 - val_f1_score: 0.6701 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.8403 - f1_score: 0.8370
# Epoch 29: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2183 - accuracy: 0.8403 - f1_score: 0.8370 - val_loss: 0.3438 - val_accuracy: 0.6790 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.8323 - f1_score: 0.8339
# Epoch 30: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.8323 - f1_score: 0.8339 - val_loss: 0.3430 - val_accuracy: 0.6944 - val_f1_score: 0.6272 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.8433 - f1_score: 0.8414
# Epoch 31: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2185 - accuracy: 0.8433 - f1_score: 0.8414 - val_loss: 0.3427 - val_accuracy: 0.6883 - val_f1_score: 0.6234 - lr: 0.0010
# Epoch 32/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2182 - accuracy: 0.8449 - f1_score: 0.8438
# Epoch 32: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.8493 - f1_score: 0.8495 - val_loss: 0.3399 - val_accuracy: 0.6975 - val_f1_score: 0.6683 - lr: 0.0010
# Epoch 33/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1892 - accuracy: 0.8605 - f1_score: 0.8598
# Epoch 33: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1935 - accuracy: 0.8583 - f1_score: 0.8556 - val_loss: 0.3438 - val_accuracy: 0.6852 - val_f1_score: 0.6800 - lr: 0.0010
# Epoch 34/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2132 - accuracy: 0.8474 - f1_score: 0.8459
# Epoch 34: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2081 - accuracy: 0.8483 - f1_score: 0.8478 - val_loss: 0.3470 - val_accuracy: 0.6852 - val_f1_score: 0.6730 - lr: 0.0010
# Epoch 35/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1920 - accuracy: 0.8583 - f1_score: 0.8579
# Epoch 35: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1939 - accuracy: 0.8553 - f1_score: 0.8543 - val_loss: 0.3499 - val_accuracy: 0.6790 - val_f1_score: 0.6639 - lr: 0.0010
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.8473 - f1_score: 0.8472
# Epoch 36: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2164 - accuracy: 0.8473 - f1_score: 0.8472 - val_loss: 0.3467 - val_accuracy: 0.7068 - val_f1_score: 0.6742 - lr: 0.0010
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.8613 - f1_score: 0.8606
# Epoch 37: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1975 - accuracy: 0.8613 - f1_score: 0.8606 - val_loss: 0.3502 - val_accuracy: 0.7068 - val_f1_score: 0.6643 - lr: 0.0010
# Epoch 38/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1785 - accuracy: 0.8739 - f1_score: 0.8732
# Epoch 38: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.8683 - f1_score: 0.8654 - val_loss: 0.3498 - val_accuracy: 0.6852 - val_f1_score: 0.6735 - lr: 0.0010
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1879 - accuracy: 0.8677 - f1_score: 0.8669
# Epoch 39: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1874 - accuracy: 0.8683 - f1_score: 0.8677 - val_loss: 0.3597 - val_accuracy: 0.6944 - val_f1_score: 0.6681 - lr: 0.0010
# Epoch 40/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2000 - accuracy: 0.8527 - f1_score: 0.8522
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 40: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1939 - accuracy: 0.8583 - f1_score: 0.8583 - val_loss: 0.3670 - val_accuracy: 0.6821 - val_f1_score: 0.6599 - lr: 0.0010
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.8583 - f1_score: 0.8562
# Epoch 41: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1934 - accuracy: 0.8583 - f1_score: 0.8562 - val_loss: 0.3636 - val_accuracy: 0.6821 - val_f1_score: 0.6732 - lr: 5.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.8733 - f1_score: 0.8728
# Epoch 42: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1771 - accuracy: 0.8733 - f1_score: 0.8728 - val_loss: 0.3591 - val_accuracy: 0.6790 - val_f1_score: 0.6609 - lr: 5.0000e-04
# Epoch 43/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1800 - accuracy: 0.8724 - f1_score: 0.8720
# Epoch 43: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1838 - accuracy: 0.8673 - f1_score: 0.8655 - val_loss: 0.3566 - val_accuracy: 0.6883 - val_f1_score: 0.6248 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1587 - accuracy: 0.8875 - f1_score: 0.8870
# Epoch 44: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1598 - accuracy: 0.8882 - f1_score: 0.8881 - val_loss: 0.3606 - val_accuracy: 0.6852 - val_f1_score: 0.6669 - lr: 5.0000e-04
# Epoch 45/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1323 - accuracy: 0.8906 - f1_score: 0.8904
# Epoch 45: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1788 - accuracy: 0.8653 - f1_score: 0.8628 - val_loss: 0.3597 - val_accuracy: 0.6821 - val_f1_score: 0.6665 - lr: 5.0000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.8687 - f1_score: 0.8682
# Epoch 46: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.8693 - f1_score: 0.8689 - val_loss: 0.3615 - val_accuracy: 0.6790 - val_f1_score: 0.6214 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.8760 - f1_score: 0.8755
# Epoch 47: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1703 - accuracy: 0.8772 - f1_score: 0.8773 - val_loss: 0.3671 - val_accuracy: 0.6821 - val_f1_score: 0.6207 - lr: 5.0000e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1630 - accuracy: 0.8906 - f1_score: 0.8900
# Epoch 48: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1668 - accuracy: 0.8882 - f1_score: 0.8865 - val_loss: 0.3696 - val_accuracy: 0.6698 - val_f1_score: 0.6175 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1681 - accuracy: 0.8792 - f1_score: 0.8780
# Epoch 49: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1673 - accuracy: 0.8812 - f1_score: 0.8811 - val_loss: 0.3688 - val_accuracy: 0.6759 - val_f1_score: 0.6600 - lr: 5.0000e-04
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1669 - accuracy: 0.8694 - f1_score: 0.8692
# Epoch 50: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.8743 - f1_score: 0.8746 - val_loss: 0.3631 - val_accuracy: 0.6852 - val_f1_score: 0.6631 - lr: 5.0000e-04
# Epoch 51/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1732 - accuracy: 0.8761 - f1_score: 0.8741
# Epoch 51: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1711 - accuracy: 0.8772 - f1_score: 0.8766 - val_loss: 0.3654 - val_accuracy: 0.6790 - val_f1_score: 0.6534 - lr: 5.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.8892 - f1_score: 0.8872
# Epoch 52: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.8892 - f1_score: 0.8872 - val_loss: 0.3686 - val_accuracy: 0.6728 - val_f1_score: 0.6040 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1618 - accuracy: 0.8792 - f1_score: 0.8789
# Epoch 53: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1639 - accuracy: 0.8782 - f1_score: 0.8774 - val_loss: 0.3689 - val_accuracy: 0.6667 - val_f1_score: 0.6192 - lr: 5.0000e-04
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.8962 - f1_score: 0.8958
# Epoch 54: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1444 - accuracy: 0.8962 - f1_score: 0.8958 - val_loss: 0.3670 - val_accuracy: 0.6790 - val_f1_score: 0.6242 - lr: 5.0000e-04
# Epoch 55/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.0767 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 55: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1608 - accuracy: 0.8862 - f1_score: 0.8855 - val_loss: 0.3701 - val_accuracy: 0.6667 - val_f1_score: 0.6269 - lr: 5.0000e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1527 - accuracy: 0.8917 - f1_score: 0.8908
# Epoch 56: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1525 - accuracy: 0.8912 - f1_score: 0.8899 - val_loss: 0.3698 - val_accuracy: 0.6759 - val_f1_score: 0.6343 - lr: 5.0000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1495 - accuracy: 0.8938 - f1_score: 0.8931
# Epoch 57: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 0.8942 - f1_score: 0.8938 - val_loss: 0.3671 - val_accuracy: 0.6790 - val_f1_score: 0.6261 - lr: 5.0000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1604 - accuracy: 0.8802 - f1_score: 0.8787
# Epoch 58: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1628 - accuracy: 0.8792 - f1_score: 0.8773 - val_loss: 0.3681 - val_accuracy: 0.6821 - val_f1_score: 0.6135 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1411 - accuracy: 0.9031 - f1_score: 0.9024
# Epoch 59: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1400 - accuracy: 0.9032 - f1_score: 0.9025 - val_loss: 0.3595 - val_accuracy: 0.6852 - val_f1_score: 0.6700 - lr: 5.0000e-04
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.8962 - f1_score: 0.8946
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 60: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1445 - accuracy: 0.8962 - f1_score: 0.8946 - val_loss: 0.3564 - val_accuracy: 0.6852 - val_f1_score: 0.6676 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1333 - accuracy: 0.9125 - f1_score: 0.9121
# Epoch 61: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1361 - accuracy: 0.9082 - f1_score: 0.9054 - val_loss: 0.3572 - val_accuracy: 0.6821 - val_f1_score: 0.6655 - lr: 2.5000e-04
# Epoch 62/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1358 - accuracy: 0.9038 - f1_score: 0.9033
# Epoch 62: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1347 - accuracy: 0.9042 - f1_score: 0.9027 - val_loss: 0.3560 - val_accuracy: 0.6883 - val_f1_score: 0.6698 - lr: 2.5000e-04
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.8932 - f1_score: 0.8938
# Epoch 63: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1542 - accuracy: 0.8932 - f1_score: 0.8938 - val_loss: 0.3548 - val_accuracy: 0.6914 - val_f1_score: 0.6820 - lr: 2.5000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1358 - accuracy: 0.9042 - f1_score: 0.9037
# Epoch 64: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1353 - accuracy: 0.9052 - f1_score: 0.9052 - val_loss: 0.3548 - val_accuracy: 0.6944 - val_f1_score: 0.6817 - lr: 2.5000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1266 - accuracy: 0.9104 - f1_score: 0.9099
# Epoch 65: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1241 - accuracy: 0.9112 - f1_score: 0.9111 - val_loss: 0.3589 - val_accuracy: 0.6944 - val_f1_score: 0.6830 - lr: 2.5000e-04
# Epoch 66/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1417 - accuracy: 0.9040 - f1_score: 0.9031
# Epoch 66: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.9012 - f1_score: 0.8984 - val_loss: 0.3614 - val_accuracy: 0.6852 - val_f1_score: 0.6763 - lr: 2.5000e-04
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9082 - f1_score: 0.9083
# Epoch 67: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1263 - accuracy: 0.9082 - f1_score: 0.9083 - val_loss: 0.3581 - val_accuracy: 0.6944 - val_f1_score: 0.6827 - lr: 2.5000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1346 - accuracy: 0.9104 - f1_score: 0.9091
# Epoch 68: val_f1_score did not improve from 0.68298
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1349 - accuracy: 0.9112 - f1_score: 0.9103 - val_loss: 0.3585 - val_accuracy: 0.6914 - val_f1_score: 0.6813 - lr: 2.5000e-04
# Epoch 69/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1454 - accuracy: 0.8917 - f1_score: 0.8910
# Epoch 69: val_f1_score improved from 0.68298 to 0.68424, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1433 - accuracy: 0.8912 - f1_score: 0.8908 - val_loss: 0.3577 - val_accuracy: 0.6975 - val_f1_score: 0.6842 - lr: 2.5000e-04
# Epoch 70/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1321 - accuracy: 0.9018 - f1_score: 0.9009
# Epoch 70: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.8932 - f1_score: 0.8893 - val_loss: 0.3589 - val_accuracy: 0.6944 - val_f1_score: 0.6796 - lr: 2.5000e-04
# Epoch 71/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1266 - accuracy: 0.9183 - f1_score: 0.9180
# Epoch 71: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1278 - accuracy: 0.9152 - f1_score: 0.9147 - val_loss: 0.3578 - val_accuracy: 0.6852 - val_f1_score: 0.6737 - lr: 2.5000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1254 - accuracy: 0.9115 - f1_score: 0.9111
# Epoch 72: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1263 - accuracy: 0.9102 - f1_score: 0.9092 - val_loss: 0.3596 - val_accuracy: 0.6883 - val_f1_score: 0.6758 - lr: 2.5000e-04
# Epoch 73/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1303 - accuracy: 0.9062 - f1_score: 0.9054
# Epoch 73: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1340 - accuracy: 0.9042 - f1_score: 0.9038 - val_loss: 0.3658 - val_accuracy: 0.6852 - val_f1_score: 0.6700 - lr: 2.5000e-04
# Epoch 74/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1357 - accuracy: 0.9018 - f1_score: 0.9007
# Epoch 74: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1346 - accuracy: 0.9042 - f1_score: 0.9030 - val_loss: 0.3669 - val_accuracy: 0.6883 - val_f1_score: 0.6768 - lr: 2.5000e-04
# Epoch 75/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9052 - f1_score: 0.9058
# Epoch 75: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1232 - accuracy: 0.9052 - f1_score: 0.9058 - val_loss: 0.3644 - val_accuracy: 0.6883 - val_f1_score: 0.6784 - lr: 2.5000e-04
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9002 - f1_score: 0.8983
# Epoch 76: val_f1_score did not improve from 0.68424
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1391 - accuracy: 0.9002 - f1_score: 0.8983 - val_loss: 0.3630 - val_accuracy: 0.6883 - val_f1_score: 0.6786 - lr: 2.5000e-04
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9042 - f1_score: 0.9019
# Epoch 77: val_f1_score improved from 0.68424 to 0.68754, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1325 - accuracy: 0.9042 - f1_score: 0.9019 - val_loss: 0.3572 - val_accuracy: 0.6975 - val_f1_score: 0.6875 - lr: 2.5000e-04
# Epoch 78/10000
# 10/16 [=================>............] - ETA: 0s - loss: 0.1388 - accuracy: 0.8969 - f1_score: 0.8964
# Epoch 78: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1305 - accuracy: 0.9062 - f1_score: 0.9040 - val_loss: 0.3585 - val_accuracy: 0.6883 - val_f1_score: 0.6811 - lr: 2.5000e-04
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9082 - f1_score: 0.9063
# Epoch 79: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1295 - accuracy: 0.9082 - f1_score: 0.9063 - val_loss: 0.3621 - val_accuracy: 0.6883 - val_f1_score: 0.6774 - lr: 2.5000e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1226 - accuracy: 0.9177 - f1_score: 0.9173
# Epoch 80: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9162 - f1_score: 0.9150 - val_loss: 0.3610 - val_accuracy: 0.6883 - val_f1_score: 0.6749 - lr: 2.5000e-04
# Epoch 81/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1179 - accuracy: 0.9062 - f1_score: 0.9062
# Epoch 81: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1187 - accuracy: 0.9122 - f1_score: 0.9100 - val_loss: 0.3651 - val_accuracy: 0.6852 - val_f1_score: 0.6728 - lr: 2.5000e-04
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9202 - f1_score: 0.9196
# Epoch 82: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1168 - accuracy: 0.9202 - f1_score: 0.9196 - val_loss: 0.3647 - val_accuracy: 0.6821 - val_f1_score: 0.6694 - lr: 2.5000e-04
# Epoch 83/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1103 - accuracy: 0.9263 - f1_score: 0.9260
# Epoch 83: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1122 - accuracy: 0.9232 - f1_score: 0.9224 - val_loss: 0.3646 - val_accuracy: 0.6852 - val_f1_score: 0.6643 - lr: 2.5000e-04
# Epoch 84/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1234 - accuracy: 0.9129 - f1_score: 0.9126
# Epoch 84: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1227 - accuracy: 0.9132 - f1_score: 0.9120 - val_loss: 0.3605 - val_accuracy: 0.6944 - val_f1_score: 0.6769 - lr: 2.5000e-04
# Epoch 85/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1227 - accuracy: 0.9062 - f1_score: 0.9057
# Epoch 85: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1181 - accuracy: 0.9132 - f1_score: 0.9125 - val_loss: 0.3618 - val_accuracy: 0.6914 - val_f1_score: 0.6727 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0999 - accuracy: 0.9302 - f1_score: 0.9298
# Epoch 86: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1038 - accuracy: 0.9261 - f1_score: 0.9236 - val_loss: 0.3648 - val_accuracy: 0.6852 - val_f1_score: 0.6700 - lr: 2.5000e-04
# Epoch 87/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0995 - accuracy: 0.9263 - f1_score: 0.9261
# Epoch 87: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.9222 - f1_score: 0.9225 - val_loss: 0.3665 - val_accuracy: 0.6821 - val_f1_score: 0.6676 - lr: 2.5000e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1347 - accuracy: 0.9073 - f1_score: 0.9066
# Epoch 88: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1333 - accuracy: 0.9072 - f1_score: 0.9064 - val_loss: 0.3703 - val_accuracy: 0.6852 - val_f1_score: 0.6686 - lr: 2.5000e-04
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9222 - f1_score: 0.9201
# Epoch 89: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1114 - accuracy: 0.9222 - f1_score: 0.9201 - val_loss: 0.3697 - val_accuracy: 0.6790 - val_f1_score: 0.6516 - lr: 2.5000e-04
# Epoch 90/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0985 - accuracy: 0.9286 - f1_score: 0.9284
# Epoch 90: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1021 - accuracy: 0.9242 - f1_score: 0.9235 - val_loss: 0.3721 - val_accuracy: 0.6790 - val_f1_score: 0.6568 - lr: 2.5000e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1279 - accuracy: 0.9135 - f1_score: 0.9132
# Epoch 91: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1305 - accuracy: 0.9122 - f1_score: 0.9112 - val_loss: 0.3769 - val_accuracy: 0.6790 - val_f1_score: 0.6638 - lr: 2.5000e-04
# Epoch 92/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1115 - accuracy: 0.9207 - f1_score: 0.9202
# Epoch 92: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1164 - accuracy: 0.9162 - f1_score: 0.9148 - val_loss: 0.3749 - val_accuracy: 0.6790 - val_f1_score: 0.6673 - lr: 2.5000e-04
# Epoch 93/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1106 - accuracy: 0.9162 - f1_score: 0.9149
# Epoch 93: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1130 - accuracy: 0.9162 - f1_score: 0.9155 - val_loss: 0.3750 - val_accuracy: 0.6790 - val_f1_score: 0.6699 - lr: 2.5000e-04
# Epoch 94/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1052 - accuracy: 0.9185 - f1_score: 0.9177
# Epoch 94: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 0.9172 - f1_score: 0.9160 - val_loss: 0.3757 - val_accuracy: 0.6728 - val_f1_score: 0.6596 - lr: 2.5000e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1115 - accuracy: 0.9208 - f1_score: 0.9204
# Epoch 95: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1129 - accuracy: 0.9202 - f1_score: 0.9194 - val_loss: 0.3743 - val_accuracy: 0.6821 - val_f1_score: 0.6699 - lr: 2.5000e-04
# Epoch 96/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1110 - accuracy: 0.9252 - f1_score: 0.9246
# Epoch 96: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1163 - accuracy: 0.9212 - f1_score: 0.9211 - val_loss: 0.3772 - val_accuracy: 0.6852 - val_f1_score: 0.6737 - lr: 2.5000e-04
# Epoch 97/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1093 - accuracy: 0.9219 - f1_score: 0.9214
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 97: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1115 - accuracy: 0.9212 - f1_score: 0.9204 - val_loss: 0.3738 - val_accuracy: 0.6821 - val_f1_score: 0.6704 - lr: 2.5000e-04
# Epoch 98/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9082 - f1_score: 0.9051
# Epoch 98: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1248 - accuracy: 0.9082 - f1_score: 0.9051 - val_loss: 0.3707 - val_accuracy: 0.6821 - val_f1_score: 0.6677 - lr: 1.2500e-04
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9162 - f1_score: 0.9160
# Epoch 99: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.9162 - f1_score: 0.9160 - val_loss: 0.3708 - val_accuracy: 0.6883 - val_f1_score: 0.6720 - lr: 1.2500e-04
# Epoch 100/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0949 - accuracy: 0.9397 - f1_score: 0.9391
# Epoch 100: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.9381 - f1_score: 0.9378 - val_loss: 0.3712 - val_accuracy: 0.6852 - val_f1_score: 0.6699 - lr: 1.2500e-04
# Epoch 101/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1038 - accuracy: 0.9291 - f1_score: 0.9286
# Epoch 101: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1144 - accuracy: 0.9232 - f1_score: 0.9223 - val_loss: 0.3751 - val_accuracy: 0.6883 - val_f1_score: 0.6720 - lr: 1.2500e-04
# Epoch 102/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1052 - accuracy: 0.9243 - f1_score: 0.9238
# Epoch 102: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.9222 - f1_score: 0.9219 - val_loss: 0.3759 - val_accuracy: 0.6944 - val_f1_score: 0.6762 - lr: 1.2500e-04
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9271 - f1_score: 0.9271
# Epoch 103: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.9271 - f1_score: 0.9271 - val_loss: 0.3759 - val_accuracy: 0.6975 - val_f1_score: 0.6798 - lr: 1.2500e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1085 - accuracy: 0.9292 - f1_score: 0.9285
# Epoch 104: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9291 - f1_score: 0.9284 - val_loss: 0.3758 - val_accuracy: 0.6944 - val_f1_score: 0.6778 - lr: 1.2500e-04
# Epoch 105/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1100 - accuracy: 0.9219 - f1_score: 0.9219
# Epoch 105: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1156 - accuracy: 0.9212 - f1_score: 0.9177 - val_loss: 0.3735 - val_accuracy: 0.6975 - val_f1_score: 0.6798 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0989 - accuracy: 0.9365 - f1_score: 0.9359
# Epoch 106: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9381 - f1_score: 0.9384 - val_loss: 0.3735 - val_accuracy: 0.6821 - val_f1_score: 0.6297 - lr: 1.2500e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1029 - accuracy: 0.9292 - f1_score: 0.9287
# Epoch 107: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1032 - accuracy: 0.9291 - f1_score: 0.9287 - val_loss: 0.3758 - val_accuracy: 0.6821 - val_f1_score: 0.6694 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0893 - accuracy: 0.9344 - f1_score: 0.9337
# Epoch 108: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0893 - accuracy: 0.9341 - f1_score: 0.9334 - val_loss: 0.3766 - val_accuracy: 0.6790 - val_f1_score: 0.6621 - lr: 1.2500e-04
# Epoch 109/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0979 - accuracy: 0.9304 - f1_score: 0.9301
# Epoch 109: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9222 - f1_score: 0.9214 - val_loss: 0.3756 - val_accuracy: 0.6790 - val_f1_score: 0.6620 - lr: 1.2500e-04
# Epoch 110/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1608 - accuracy: 0.8594 - f1_score: 0.8577
# Epoch 110: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1029 - accuracy: 0.9251 - f1_score: 0.9247 - val_loss: 0.3743 - val_accuracy: 0.6852 - val_f1_score: 0.6714 - lr: 1.2500e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1147 - accuracy: 0.9177 - f1_score: 0.9172
# Epoch 111: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1136 - accuracy: 0.9192 - f1_score: 0.9194 - val_loss: 0.3720 - val_accuracy: 0.6852 - val_f1_score: 0.6714 - lr: 1.2500e-04
# Epoch 112/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0847 - accuracy: 0.9399 - f1_score: 0.9396
# Epoch 112: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0922 - accuracy: 0.9361 - f1_score: 0.9341 - val_loss: 0.3712 - val_accuracy: 0.6914 - val_f1_score: 0.6757 - lr: 1.2500e-04
# Epoch 113/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1048 - accuracy: 0.9310 - f1_score: 0.9303
# Epoch 113: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1036 - accuracy: 0.9291 - f1_score: 0.9270 - val_loss: 0.3729 - val_accuracy: 0.6975 - val_f1_score: 0.6827 - lr: 1.2500e-04
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1159 - accuracy: 0.9198 - f1_score: 0.9186
# Epoch 114: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1150 - accuracy: 0.9202 - f1_score: 0.9192 - val_loss: 0.3743 - val_accuracy: 0.6975 - val_f1_score: 0.6800 - lr: 1.2500e-04
# Epoch 115/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9311 - f1_score: 0.9296
# Epoch 115: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1077 - accuracy: 0.9311 - f1_score: 0.9296 - val_loss: 0.3773 - val_accuracy: 0.6944 - val_f1_score: 0.6725 - lr: 1.2500e-04
# Epoch 116/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1109 - accuracy: 0.9230 - f1_score: 0.9218
# Epoch 116: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.9212 - f1_score: 0.9198 - val_loss: 0.3765 - val_accuracy: 0.6914 - val_f1_score: 0.6723 - lr: 1.2500e-04
# Epoch 117/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1016 - accuracy: 0.9291 - f1_score: 0.9287
# Epoch 117: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 117: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1107 - accuracy: 0.9251 - f1_score: 0.9221 - val_loss: 0.3753 - val_accuracy: 0.7037 - val_f1_score: 0.6798 - lr: 1.2500e-04
# Epoch 118/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0994 - accuracy: 0.9279 - f1_score: 0.9274
# Epoch 118: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0978 - accuracy: 0.9301 - f1_score: 0.9301 - val_loss: 0.3741 - val_accuracy: 0.7037 - val_f1_score: 0.6827 - lr: 6.2500e-05
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1005 - accuracy: 0.9312 - f1_score: 0.9309
# Epoch 119: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1003 - accuracy: 0.9311 - f1_score: 0.9307 - val_loss: 0.3746 - val_accuracy: 0.6975 - val_f1_score: 0.6825 - lr: 6.2500e-05
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0999 - accuracy: 0.9271 - f1_score: 0.9265
# Epoch 120: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1014 - accuracy: 0.9271 - f1_score: 0.9267 - val_loss: 0.3734 - val_accuracy: 0.7037 - val_f1_score: 0.6868 - lr: 6.2500e-05
# Epoch 121/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0918 - accuracy: 0.9375 - f1_score: 0.9370
# Epoch 121: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0943 - accuracy: 0.9381 - f1_score: 0.9383 - val_loss: 0.3736 - val_accuracy: 0.7037 - val_f1_score: 0.6868 - lr: 6.2500e-05
# Epoch 122/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1078 - accuracy: 0.9193 - f1_score: 0.9189
# Epoch 122: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1060 - accuracy: 0.9212 - f1_score: 0.9211 - val_loss: 0.3741 - val_accuracy: 0.6944 - val_f1_score: 0.6761 - lr: 6.2500e-05
# Epoch 123/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0847 - accuracy: 0.9453 - f1_score: 0.9451
# Epoch 123: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0887 - accuracy: 0.9421 - f1_score: 0.9411 - val_loss: 0.3747 - val_accuracy: 0.6914 - val_f1_score: 0.6702 - lr: 6.2500e-05
# Epoch 124/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1034 - accuracy: 0.9271 - f1_score: 0.9262
# Epoch 124: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1027 - accuracy: 0.9301 - f1_score: 0.9298 - val_loss: 0.3754 - val_accuracy: 0.6914 - val_f1_score: 0.6722 - lr: 6.2500e-05
# Epoch 125/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0972 - accuracy: 0.9315 - f1_score: 0.9310
# Epoch 125: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1058 - accuracy: 0.9242 - f1_score: 0.9235 - val_loss: 0.3760 - val_accuracy: 0.6914 - val_f1_score: 0.6722 - lr: 6.2500e-05
# Epoch 126/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0930 - accuracy: 0.9353 - f1_score: 0.9347
# Epoch 126: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0965 - accuracy: 0.9321 - f1_score: 0.9299 - val_loss: 0.3766 - val_accuracy: 0.6914 - val_f1_score: 0.6741 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0835 - accuracy: 0.9333 - f1_score: 0.9331
# Epoch 127: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0874 - accuracy: 0.9291 - f1_score: 0.9268 - val_loss: 0.3771 - val_accuracy: 0.6883 - val_f1_score: 0.6719 - lr: 6.2500e-05
# Epoch 128/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1081 - accuracy: 0.9241 - f1_score: 0.9227
# Epoch 128: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1045 - accuracy: 0.9261 - f1_score: 0.9260 - val_loss: 0.3774 - val_accuracy: 0.6914 - val_f1_score: 0.6741 - lr: 6.2500e-05
# Epoch 129/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0951 - accuracy: 0.9349 - f1_score: 0.9343
# Epoch 129: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0937 - accuracy: 0.9341 - f1_score: 0.9324 - val_loss: 0.3772 - val_accuracy: 0.6944 - val_f1_score: 0.6766 - lr: 6.2500e-05
# Epoch 130/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1027 - accuracy: 0.9297 - f1_score: 0.9287
# Epoch 130: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1033 - accuracy: 0.9281 - f1_score: 0.9267 - val_loss: 0.3771 - val_accuracy: 0.6944 - val_f1_score: 0.6746 - lr: 6.2500e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0978 - accuracy: 0.9323 - f1_score: 0.9318
# Epoch 131: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0962 - accuracy: 0.9331 - f1_score: 0.9331 - val_loss: 0.3764 - val_accuracy: 0.6975 - val_f1_score: 0.6782 - lr: 6.2500e-05
# Epoch 132/10000
# 10/16 [=================>............] - ETA: 0s - loss: 0.0822 - accuracy: 0.9500 - f1_score: 0.9499
# Epoch 132: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0875 - accuracy: 0.9471 - f1_score: 0.9475 - val_loss: 0.3762 - val_accuracy: 0.7006 - val_f1_score: 0.6853 - lr: 6.2500e-05
# Epoch 133/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1108 - accuracy: 0.9208 - f1_score: 0.9204
# ...
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0926 - accuracy: 0.9401 - f1_score: 0.9405 - val_loss: 0.3762 - val_accuracy: 0.7006 - val_f1_score: 0.6810 - lr: 6.2500e-05
# Epoch 135/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0823 - accuracy: 0.9442 - f1_score: 0.9438
# Epoch 135: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0831 - accuracy: 0.9421 - f1_score: 0.9403 - val_loss: 0.3755 - val_accuracy: 0.6975 - val_f1_score: 0.6765 - lr: 6.2500e-05
# Epoch 136/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0813 - accuracy: 0.9386 - f1_score: 0.9382
# Epoch 136: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9381 - f1_score: 0.9376 - val_loss: 0.3742 - val_accuracy: 0.6914 - val_f1_score: 0.6740 - lr: 6.2500e-05
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0958 - accuracy: 0.9333 - f1_score: 0.9326
# Epoch 137: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 137: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0965 - accuracy: 0.9321 - f1_score: 0.9307 - val_loss: 0.3751 - val_accuracy: 0.6914 - val_f1_score: 0.6722 - lr: 6.2500e-05
# Epoch 138/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0814 - accuracy: 0.9483 - f1_score: 0.9480
# Epoch 138: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0840 - accuracy: 0.9451 - f1_score: 0.9449 - val_loss: 0.3754 - val_accuracy: 0.6944 - val_f1_score: 0.6761 - lr: 3.1250e-05
# Epoch 139/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0756 - accuracy: 0.9576 - f1_score: 0.9573
# Epoch 139: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 0.9541 - f1_score: 0.9532 - val_loss: 0.3758 - val_accuracy: 0.6914 - val_f1_score: 0.6740 - lr: 3.1250e-05
# Epoch 140/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1099 - accuracy: 0.9231 - f1_score: 0.9223
# Epoch 140: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1077 - accuracy: 0.9232 - f1_score: 0.9225 - val_loss: 0.3762 - val_accuracy: 0.6914 - val_f1_score: 0.6740 - lr: 3.1250e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0865 - accuracy: 0.9375 - f1_score: 0.9371
# Epoch 141: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0890 - accuracy: 0.9361 - f1_score: 0.9350 - val_loss: 0.3770 - val_accuracy: 0.6975 - val_f1_score: 0.6805 - lr: 3.1250e-05
# Epoch 142/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0740 - accuracy: 0.9542 - f1_score: 0.9538
# Epoch 142: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9471 - f1_score: 0.9447 - val_loss: 0.3769 - val_accuracy: 0.6944 - val_f1_score: 0.6785 - lr: 3.1250e-05
# Epoch 143/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1036 - accuracy: 0.9207 - f1_score: 0.9198
# Epoch 143: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0969 - accuracy: 0.9261 - f1_score: 0.9270 - val_loss: 0.3775 - val_accuracy: 0.6944 - val_f1_score: 0.6761 - lr: 3.1250e-05
# Epoch 144/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0868 - accuracy: 0.9440 - f1_score: 0.9437
# Epoch 144: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0903 - accuracy: 0.9411 - f1_score: 0.9400 - val_loss: 0.3768 - val_accuracy: 0.6883 - val_f1_score: 0.6701 - lr: 3.1250e-05
# Epoch 145/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1124 - accuracy: 0.9208 - f1_score: 0.9195
# Epoch 145: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1093 - accuracy: 0.9222 - f1_score: 0.9206 - val_loss: 0.3769 - val_accuracy: 0.6914 - val_f1_score: 0.6722 - lr: 3.1250e-05
# Epoch 146/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1039 - accuracy: 0.9231 - f1_score: 0.9214
# Epoch 146: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1116 - accuracy: 0.9212 - f1_score: 0.9189 - val_loss: 0.3765 - val_accuracy: 0.6883 - val_f1_score: 0.6701 - lr: 3.1250e-05
# Epoch 147/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0929 - accuracy: 0.9342 - f1_score: 0.9339
# Epoch 147: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0944 - accuracy: 0.9331 - f1_score: 0.9323 - val_loss: 0.3773 - val_accuracy: 0.6883 - val_f1_score: 0.6701 - lr: 3.1250e-05
# Epoch 148/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1105 - accuracy: 0.9174 - f1_score: 0.9167
# Epoch 148: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.9202 - f1_score: 0.9192 - val_loss: 0.3779 - val_accuracy: 0.6914 - val_f1_score: 0.6723 - lr: 3.1250e-05
# Epoch 149/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1120 - accuracy: 0.9129 - f1_score: 0.9117
# Epoch 149: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1076 - accuracy: 0.9192 - f1_score: 0.9193 - val_loss: 0.3779 - val_accuracy: 0.6914 - val_f1_score: 0.6745 - lr: 3.1250e-05
# Epoch 150/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0943 - accuracy: 0.9336 - f1_score: 0.9331
# Epoch 150: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0905 - accuracy: 0.9361 - f1_score: 0.9369 - val_loss: 0.3775 - val_accuracy: 0.6883 - val_f1_score: 0.6701 - lr: 3.1250e-05
# Epoch 151/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0983 - accuracy: 0.9353 - f1_score: 0.9349
# Epoch 151: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1004 - accuracy: 0.9321 - f1_score: 0.9315 - val_loss: 0.3781 - val_accuracy: 0.6914 - val_f1_score: 0.6723 - lr: 3.1250e-05
# Epoch 152/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0892 - accuracy: 0.9396 - f1_score: 0.9390
# Epoch 152: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0889 - accuracy: 0.9401 - f1_score: 0.9397 - val_loss: 0.3795 - val_accuracy: 0.6883 - val_f1_score: 0.6683 - lr: 3.1250e-05
# Epoch 153/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9481 - f1_score: 0.9466
# Epoch 153: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0822 - accuracy: 0.9481 - f1_score: 0.9466 - val_loss: 0.3795 - val_accuracy: 0.6914 - val_f1_score: 0.6723 - lr: 3.1250e-05
# Epoch 154/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1033 - accuracy: 0.9302 - f1_score: 0.9294
# Epoch 154: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1021 - accuracy: 0.9311 - f1_score: 0.9308 - val_loss: 0.3789 - val_accuracy: 0.6944 - val_f1_score: 0.6743 - lr: 3.1250e-05
# Epoch 155/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0806 - accuracy: 0.9510 - f1_score: 0.9507
# Epoch 155: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0812 - accuracy: 0.9491 - f1_score: 0.9478 - val_loss: 0.3778 - val_accuracy: 0.6944 - val_f1_score: 0.6770 - lr: 3.1250e-05
# Epoch 156/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0847 - accuracy: 0.9471 - f1_score: 0.9466
# Epoch 156: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0818 - accuracy: 0.9501 - f1_score: 0.9497 - val_loss: 0.3781 - val_accuracy: 0.6944 - val_f1_score: 0.6793 - lr: 3.1250e-05
# Epoch 157/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0835 - accuracy: 0.9423 - f1_score: 0.9420
# Epoch 157: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 157: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0832 - accuracy: 0.9421 - f1_score: 0.9410 - val_loss: 0.3787 - val_accuracy: 0.6975 - val_f1_score: 0.6815 - lr: 3.1250e-05
# Epoch 158/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0861 - accuracy: 0.9447 - f1_score: 0.9443
# Epoch 158: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0789 - accuracy: 0.9501 - f1_score: 0.9508 - val_loss: 0.3790 - val_accuracy: 0.6975 - val_f1_score: 0.6815 - lr: 1.5625e-05
# Epoch 159/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0924 - accuracy: 0.9342 - f1_score: 0.9337
# Epoch 159: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0968 - accuracy: 0.9321 - f1_score: 0.9321 - val_loss: 0.3790 - val_accuracy: 0.6975 - val_f1_score: 0.6815 - lr: 1.5625e-05
# Epoch 160/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0931 - accuracy: 0.9344 - f1_score: 0.9341
# Epoch 160: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0931 - accuracy: 0.9341 - f1_score: 0.9337 - val_loss: 0.3791 - val_accuracy: 0.6975 - val_f1_score: 0.6815 - lr: 1.5625e-05
# Epoch 161/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0859 - accuracy: 0.9385 - f1_score: 0.9382
# Epoch 161: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0890 - accuracy: 0.9351 - f1_score: 0.9329 - val_loss: 0.3793 - val_accuracy: 0.6944 - val_f1_score: 0.6793 - lr: 1.5625e-05
# Epoch 162/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0950 - accuracy: 0.9375 - f1_score: 0.9368
# Epoch 162: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9341 - f1_score: 0.9318 - val_loss: 0.3801 - val_accuracy: 0.6944 - val_f1_score: 0.6793 - lr: 1.5625e-05
# Epoch 163/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0909 - accuracy: 0.9386 - f1_score: 0.9383
# Epoch 163: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0906 - accuracy: 0.9391 - f1_score: 0.9396 - val_loss: 0.3802 - val_accuracy: 0.6914 - val_f1_score: 0.6748 - lr: 1.5625e-05
# Epoch 164/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0799 - accuracy: 0.9453 - f1_score: 0.9451
# Epoch 164: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0804 - accuracy: 0.9441 - f1_score: 0.9445 - val_loss: 0.3803 - val_accuracy: 0.6944 - val_f1_score: 0.6772 - lr: 1.5625e-05
# Epoch 165/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1002 - accuracy: 0.9297 - f1_score: 0.9285
# Epoch 165: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0971 - accuracy: 0.9321 - f1_score: 0.9315 - val_loss: 0.3802 - val_accuracy: 0.6975 - val_f1_score: 0.6818 - lr: 1.5625e-05
# Epoch 166/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0841 - accuracy: 0.9406 - f1_score: 0.9402
# Epoch 166: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0850 - accuracy: 0.9401 - f1_score: 0.9394 - val_loss: 0.3794 - val_accuracy: 0.6975 - val_f1_score: 0.6819 - lr: 1.5625e-05
# Epoch 167/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0926 - accuracy: 0.9386 - f1_score: 0.9380
# Epoch 167: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0945 - accuracy: 0.9381 - f1_score: 0.9362 - val_loss: 0.3792 - val_accuracy: 0.6944 - val_f1_score: 0.6797 - lr: 1.5625e-05
# Epoch 168/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0857 - accuracy: 0.9442 - f1_score: 0.9440
# Epoch 168: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0934 - accuracy: 0.9381 - f1_score: 0.9355 - val_loss: 0.3798 - val_accuracy: 0.6975 - val_f1_score: 0.6818 - lr: 1.5625e-05
# Epoch 169/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0740 - accuracy: 0.9507 - f1_score: 0.9505
# Epoch 169: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0822 - accuracy: 0.9451 - f1_score: 0.9440 - val_loss: 0.3804 - val_accuracy: 0.6975 - val_f1_score: 0.6818 - lr: 1.5625e-05
# Epoch 170/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0815 - accuracy: 0.9453 - f1_score: 0.9446
# Epoch 170: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0830 - accuracy: 0.9451 - f1_score: 0.9451 - val_loss: 0.3804 - val_accuracy: 0.6944 - val_f1_score: 0.6797 - lr: 1.5625e-05
# Epoch 171/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9361 - f1_score: 0.9361
# Epoch 171: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.9361 - f1_score: 0.9361 - val_loss: 0.3803 - val_accuracy: 0.6914 - val_f1_score: 0.6751 - lr: 1.5625e-05
# Epoch 172/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0890 - accuracy: 0.9385 - f1_score: 0.9380
# Epoch 172: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0889 - accuracy: 0.9391 - f1_score: 0.9389 - val_loss: 0.3801 - val_accuracy: 0.6944 - val_f1_score: 0.6773 - lr: 1.5625e-05
# Epoch 173/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0830 - accuracy: 0.9417 - f1_score: 0.9414
# Epoch 173: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9411 - f1_score: 0.9405 - val_loss: 0.3801 - val_accuracy: 0.7037 - val_f1_score: 0.6861 - lr: 1.5625e-05
# Epoch 174/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0898 - accuracy: 0.9385 - f1_score: 0.9377
# Epoch 174: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.9401 - f1_score: 0.9401 - val_loss: 0.3801 - val_accuracy: 0.7006 - val_f1_score: 0.6815 - lr: 1.5625e-05
# Epoch 175/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9471 - f1_score: 0.9479
# Epoch 175: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9471 - f1_score: 0.9479 - val_loss: 0.3795 - val_accuracy: 0.6975 - val_f1_score: 0.6793 - lr: 1.5625e-05
# Epoch 176/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0910 - accuracy: 0.9406 - f1_score: 0.9401
# Epoch 176: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0883 - accuracy: 0.9431 - f1_score: 0.9439 - val_loss: 0.3793 - val_accuracy: 0.6975 - val_f1_score: 0.6793 - lr: 1.5625e-05
# Epoch 177/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0896 - accuracy: 0.9423 - f1_score: 0.9421Restoring model weights from the end of the best epoch: 77.
#
# Epoch 177: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 177: val_f1_score did not improve from 0.68754
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0913 - accuracy: 0.9401 - f1_score: 0.9401 - val_loss: 0.3793 - val_accuracy: 0.6944 - val_f1_score: 0.6754 - lr: 1.5625e-05
# Epoch 177: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               22016
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 200610 (783.63 KB)
# Trainable params: 198626 (775.88 KB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 1ms/step
# 0.6975308641975309

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6975308641975309
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.44      0.53      0.48        85
#            0       0.82      0.76      0.79       239
#
#     accuracy                           0.70       324
#    macro avg       0.63      0.64      0.63       324
# weighted avg       0.72      0.70      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 226 chiếm khoảng 69.75308641975309% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 45 chiếm khoảng 52.94117647058824% so với thực tế
