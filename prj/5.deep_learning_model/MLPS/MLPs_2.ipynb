# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model():
    input_shape =(42,1)
    learning_rate=0.0001

    bn_axis = -1
    step=32
    model = Sequential()
    model.add(Dense(512,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Thêm các lớp ẩn
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Lớp đầu ra với activation function 'sigmoid' cho bài toán phân lớp nhị phân
    model.add(Dense(2, activation='softmax'))
   



    model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


# data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
model=build_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7066 - accuracy: 0.4948 - f1_score: 0.4913
# Epoch 1: val_f1_score improved from -inf to 0.50351, saving model to best_model.h5
# 16/16 [==============================] - 2s 23ms/step - loss: 0.7088 - accuracy: 0.4950 - f1_score: 0.4918 - val_loss: 0.5206 - val_accuracy: 0.6235 - val_f1_score: 0.5035 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.5220 - f1_score: 0.5171
# Epoch 2: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6706 - accuracy: 0.5220 - f1_score: 0.5171 - val_loss: 0.5019 - val_accuracy: 0.7222 - val_f1_score: 0.4433 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6575 - accuracy: 0.5250 - f1_score: 0.5224
# Epoch 3: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6575 - accuracy: 0.5250 - f1_score: 0.5224 - val_loss: 0.5017 - val_accuracy: 0.7284 - val_f1_score: 0.4328 - lr: 0.0010
# Epoch 4/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6304 - accuracy: 0.5526 - f1_score: 0.5497
# Epoch 4: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6299 - accuracy: 0.5559 - f1_score: 0.5533 - val_loss: 0.4998 - val_accuracy: 0.7377 - val_f1_score: 0.4558 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6203 - accuracy: 0.5594 - f1_score: 0.5559
# Epoch 5: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6252 - accuracy: 0.5559 - f1_score: 0.5509 - val_loss: 0.5012 - val_accuracy: 0.7438 - val_f1_score: 0.4661 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.5778 - f1_score: 0.5757
# Epoch 6: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5977 - accuracy: 0.5778 - f1_score: 0.5757 - val_loss: 0.4954 - val_accuracy: 0.7407 - val_f1_score: 0.4720 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5630 - accuracy: 0.6098 - f1_score: 0.6074
# Epoch 7: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5630 - accuracy: 0.6098 - f1_score: 0.6074 - val_loss: 0.4865 - val_accuracy: 0.7377 - val_f1_score: 0.4785 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5384 - accuracy: 0.6292 - f1_score: 0.6272
# Epoch 8: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.6307 - f1_score: 0.6289 - val_loss: 0.4846 - val_accuracy: 0.7253 - val_f1_score: 0.4992 - lr: 0.0010
# Epoch 9/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5362 - accuracy: 0.6217 - f1_score: 0.6192
# Epoch 9: val_f1_score did not improve from 0.50351
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5269 - accuracy: 0.6317 - f1_score: 0.6318 - val_loss: 0.4851 - val_accuracy: 0.7346 - val_f1_score: 0.4905 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.6557 - f1_score: 0.6539
# Epoch 10: val_f1_score improved from 0.50351 to 0.50521, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4905 - accuracy: 0.6557 - f1_score: 0.6539 - val_loss: 0.4764 - val_accuracy: 0.7222 - val_f1_score: 0.5052 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4795 - accuracy: 0.6667 - f1_score: 0.6673
# Epoch 11: val_f1_score improved from 0.50521 to 0.52009, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4795 - accuracy: 0.6667 - f1_score: 0.6673 - val_loss: 0.4744 - val_accuracy: 0.7068 - val_f1_score: 0.5201 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4208 - accuracy: 0.7167 - f1_score: 0.7153
# Epoch 12: val_f1_score did not improve from 0.52009
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4263 - accuracy: 0.7136 - f1_score: 0.7107 - val_loss: 0.4648 - val_accuracy: 0.6883 - val_f1_score: 0.5152 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4014 - accuracy: 0.7156 - f1_score: 0.7143
# Epoch 13: val_f1_score improved from 0.52009 to 0.62014, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4117 - accuracy: 0.7106 - f1_score: 0.7067 - val_loss: 0.4594 - val_accuracy: 0.6944 - val_f1_score: 0.6201 - lr: 0.0010
# Epoch 14/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.4146 - accuracy: 0.7188 - f1_score: 0.7185
# Epoch 14: val_f1_score improved from 0.62014 to 0.62893, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3670 - accuracy: 0.7515 - f1_score: 0.7507 - val_loss: 0.4536 - val_accuracy: 0.7130 - val_f1_score: 0.6289 - lr: 0.0010
# Epoch 15/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.3647 - accuracy: 0.7514 - f1_score: 0.7507
# Epoch 15: val_f1_score improved from 0.62893 to 0.63413, saving model to best_model.h5
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3678 - accuracy: 0.7485 - f1_score: 0.7463 - val_loss: 0.4420 - val_accuracy: 0.7068 - val_f1_score: 0.6341 - lr: 0.0010
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3370 - accuracy: 0.7667 - f1_score: 0.7643
# Epoch 16: val_f1_score did not improve from 0.63413
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3339 - accuracy: 0.7695 - f1_score: 0.7681 - val_loss: 0.4281 - val_accuracy: 0.7006 - val_f1_score: 0.5996 - lr: 0.0010
# Epoch 17/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3202 - accuracy: 0.7801 - f1_score: 0.7792
# Epoch 17: val_f1_score did not improve from 0.63413
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3157 - accuracy: 0.7824 - f1_score: 0.7821 - val_loss: 0.4359 - val_accuracy: 0.7099 - val_f1_score: 0.6288 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.7894 - f1_score: 0.7898
# Epoch 18: val_f1_score improved from 0.63413 to 0.64968, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3152 - accuracy: 0.7894 - f1_score: 0.7898 - val_loss: 0.4249 - val_accuracy: 0.7160 - val_f1_score: 0.6497 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2973 - accuracy: 0.7958 - f1_score: 0.7950
# Epoch 19: val_f1_score did not improve from 0.64968
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2945 - accuracy: 0.7974 - f1_score: 0.7974 - val_loss: 0.3972 - val_accuracy: 0.7037 - val_f1_score: 0.6143 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2830 - accuracy: 0.8104 - f1_score: 0.8094
# Epoch 20: val_f1_score did not improve from 0.64968
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2834 - accuracy: 0.8104 - f1_score: 0.8094 - val_loss: 0.3878 - val_accuracy: 0.6759 - val_f1_score: 0.6202 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.7904 - f1_score: 0.7882
# Epoch 21: val_f1_score improved from 0.64968 to 0.67661, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3006 - accuracy: 0.7904 - f1_score: 0.7882 - val_loss: 0.3891 - val_accuracy: 0.7130 - val_f1_score: 0.6766 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2974 - accuracy: 0.7974 - f1_score: 0.7944
# Epoch 22: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.7974 - f1_score: 0.7944 - val_loss: 0.3923 - val_accuracy: 0.7037 - val_f1_score: 0.6730 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8084 - f1_score: 0.8085
# Epoch 23: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2795 - accuracy: 0.8084 - f1_score: 0.8085 - val_loss: 0.3947 - val_accuracy: 0.6852 - val_f1_score: 0.6352 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2684 - accuracy: 0.8125 - f1_score: 0.8114
# Epoch 24: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2660 - accuracy: 0.8154 - f1_score: 0.8156 - val_loss: 0.3879 - val_accuracy: 0.6636 - val_f1_score: 0.6312 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.8204 - f1_score: 0.8213
# Epoch 25: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2602 - accuracy: 0.8204 - f1_score: 0.8213 - val_loss: 0.3737 - val_accuracy: 0.7068 - val_f1_score: 0.6521 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.8373 - f1_score: 0.8371
# Epoch 26: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2387 - accuracy: 0.8373 - f1_score: 0.8371 - val_loss: 0.3716 - val_accuracy: 0.7006 - val_f1_score: 0.6452 - lr: 0.0010
# Epoch 27/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2457 - accuracy: 0.8337 - f1_score: 0.8329
# Epoch 27: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2420 - accuracy: 0.8363 - f1_score: 0.8366 - val_loss: 0.3730 - val_accuracy: 0.7037 - val_f1_score: 0.6467 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2300 - accuracy: 0.8469 - f1_score: 0.8461
# Epoch 28: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2326 - accuracy: 0.8453 - f1_score: 0.8437 - val_loss: 0.3801 - val_accuracy: 0.7037 - val_f1_score: 0.6345 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2477 - accuracy: 0.8313 - f1_score: 0.8306
# Epoch 29: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2481 - accuracy: 0.8313 - f1_score: 0.8308 - val_loss: 0.3918 - val_accuracy: 0.6852 - val_f1_score: 0.6277 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2273 - accuracy: 0.8417 - f1_score: 0.8408
# Epoch 30: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2298 - accuracy: 0.8383 - f1_score: 0.8358 - val_loss: 0.3912 - val_accuracy: 0.6667 - val_f1_score: 0.6335 - lr: 0.0010
# Epoch 31/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2411 - accuracy: 0.8292 - f1_score: 0.8282
# Epoch 31: val_f1_score did not improve from 0.67661
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2413 - accuracy: 0.8313 - f1_score: 0.8299 - val_loss: 0.3691 - val_accuracy: 0.6852 - val_f1_score: 0.6451 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.8353 - f1_score: 0.8325
# Epoch 32: val_f1_score improved from 0.67661 to 0.71387, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2316 - accuracy: 0.8353 - f1_score: 0.8325 - val_loss: 0.3466 - val_accuracy: 0.7037 - val_f1_score: 0.7139 - lr: 0.0010
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.8323 - f1_score: 0.8319
# Epoch 33: val_f1_score did not improve from 0.71387
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.8323 - f1_score: 0.8319 - val_loss: 0.3442 - val_accuracy: 0.7068 - val_f1_score: 0.6764 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2149 - accuracy: 0.8542 - f1_score: 0.8536
# Epoch 34: val_f1_score improved from 0.71387 to 0.72344, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2207 - accuracy: 0.8503 - f1_score: 0.8475 - val_loss: 0.3387 - val_accuracy: 0.7160 - val_f1_score: 0.7234 - lr: 0.0010
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.8204 - f1_score: 0.8182
# Epoch 35: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2544 - accuracy: 0.8204 - f1_score: 0.8182 - val_loss: 0.4024 - val_accuracy: 0.7068 - val_f1_score: 0.6601 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2275 - accuracy: 0.8406 - f1_score: 0.8393
# Epoch 36: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2263 - accuracy: 0.8403 - f1_score: 0.8386 - val_loss: 0.3902 - val_accuracy: 0.7099 - val_f1_score: 0.6346 - lr: 0.0010
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2093 - accuracy: 0.8573 - f1_score: 0.8561
# Epoch 37: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2075 - accuracy: 0.8593 - f1_score: 0.8591 - val_loss: 0.3958 - val_accuracy: 0.7006 - val_f1_score: 0.6237 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2053 - accuracy: 0.8604 - f1_score: 0.8597
# Epoch 38: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2059 - accuracy: 0.8593 - f1_score: 0.8580 - val_loss: 0.3512 - val_accuracy: 0.7099 - val_f1_score: 0.6623 - lr: 0.0010
# Epoch 39/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2114 - accuracy: 0.8516 - f1_score: 0.8508
# Epoch 39: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2101 - accuracy: 0.8513 - f1_score: 0.8517 - val_loss: 0.3650 - val_accuracy: 0.6852 - val_f1_score: 0.6158 - lr: 0.0010
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2165 - accuracy: 0.8448 - f1_score: 0.8436
# Epoch 40: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2196 - accuracy: 0.8433 - f1_score: 0.8412 - val_loss: 0.3548 - val_accuracy: 0.7130 - val_f1_score: 0.6662 - lr: 0.0010
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1982 - accuracy: 0.8615 - f1_score: 0.8605
# Epoch 41: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1979 - accuracy: 0.8613 - f1_score: 0.8603 - val_loss: 0.3616 - val_accuracy: 0.7160 - val_f1_score: 0.6925 - lr: 0.0010
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.8713 - f1_score: 0.8692
# Epoch 42: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1870 - accuracy: 0.8713 - f1_score: 0.8692 - val_loss: 0.3475 - val_accuracy: 0.7130 - val_f1_score: 0.7102 - lr: 0.0010
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2154 - accuracy: 0.8542 - f1_score: 0.8531
# Epoch 43: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2127 - accuracy: 0.8543 - f1_score: 0.8534 - val_loss: 0.3672 - val_accuracy: 0.7068 - val_f1_score: 0.6953 - lr: 0.0010
# Epoch 44/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1986 - accuracy: 0.8583 - f1_score: 0.8574
# Epoch 44: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2006 - accuracy: 0.8553 - f1_score: 0.8528 - val_loss: 0.3597 - val_accuracy: 0.6883 - val_f1_score: 0.6888 - lr: 0.0010
# Epoch 45/10000
# 10/16 [=================>............] - ETA: 0s - loss: 0.1997 - accuracy: 0.8547 - f1_score: 0.8532
# Epoch 45: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2216 - accuracy: 0.8463 - f1_score: 0.8452 - val_loss: 0.3707 - val_accuracy: 0.6914 - val_f1_score: 0.6892 - lr: 0.0010
# Epoch 46/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1966 - accuracy: 0.8638 - f1_score: 0.8631
# Epoch 46: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1909 - accuracy: 0.8673 - f1_score: 0.8668 - val_loss: 0.3833 - val_accuracy: 0.6821 - val_f1_score: 0.6359 - lr: 0.0010
# Epoch 47/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1856 - accuracy: 0.8728 - f1_score: 0.8717
# Epoch 47: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1885 - accuracy: 0.8693 - f1_score: 0.8669 - val_loss: 0.3586 - val_accuracy: 0.7037 - val_f1_score: 0.7017 - lr: 0.0010
# Epoch 48/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1937 - accuracy: 0.8594 - f1_score: 0.8584
# Epoch 48: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1962 - accuracy: 0.8593 - f1_score: 0.8587 - val_loss: 0.3746 - val_accuracy: 0.7099 - val_f1_score: 0.6861 - lr: 0.0010
# Epoch 49/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2157 - accuracy: 0.8482 - f1_score: 0.8468
# Epoch 49: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2108 - accuracy: 0.8513 - f1_score: 0.8501 - val_loss: 0.4165 - val_accuracy: 0.7191 - val_f1_score: 0.6445 - lr: 0.0010
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1986 - accuracy: 0.8571 - f1_score: 0.8560
# Epoch 50: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1943 - accuracy: 0.8593 - f1_score: 0.8597 - val_loss: 0.4033 - val_accuracy: 0.7191 - val_f1_score: 0.6536 - lr: 0.0010
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1891 - accuracy: 0.8708 - f1_score: 0.8691
# Epoch 51: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1889 - accuracy: 0.8703 - f1_score: 0.8683 - val_loss: 0.4040 - val_accuracy: 0.7160 - val_f1_score: 0.6590 - lr: 0.0010
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1918 - accuracy: 0.8646 - f1_score: 0.8640
# Epoch 52: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1969 - accuracy: 0.8603 - f1_score: 0.8573 - val_loss: 0.3852 - val_accuracy: 0.7253 - val_f1_score: 0.6784 - lr: 0.0010
# Epoch 53/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1895 - accuracy: 0.8694 - f1_score: 0.8682
# Epoch 53: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.8623 - f1_score: 0.8598 - val_loss: 0.3924 - val_accuracy: 0.7191 - val_f1_score: 0.6738 - lr: 0.0010
# Epoch 54/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1812 - accuracy: 0.8750 - f1_score: 0.8741
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 54: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1754 - accuracy: 0.8802 - f1_score: 0.8804 - val_loss: 0.3722 - val_accuracy: 0.7222 - val_f1_score: 0.6925 - lr: 0.0010
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1618 - accuracy: 0.8875 - f1_score: 0.8871
# Epoch 55: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1640 - accuracy: 0.8872 - f1_score: 0.8866 - val_loss: 0.3702 - val_accuracy: 0.7037 - val_f1_score: 0.6855 - lr: 5.0000e-04
# Epoch 56/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1712 - accuracy: 0.8806 - f1_score: 0.8801
# Epoch 56: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1713 - accuracy: 0.8792 - f1_score: 0.8772 - val_loss: 0.3771 - val_accuracy: 0.6883 - val_f1_score: 0.6729 - lr: 5.0000e-04
# Epoch 57/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1706 - accuracy: 0.8789 - f1_score: 0.8778
# Epoch 57: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1856 - accuracy: 0.8693 - f1_score: 0.8679 - val_loss: 0.3825 - val_accuracy: 0.6944 - val_f1_score: 0.6755 - lr: 5.0000e-04
# Epoch 58/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1830 - accuracy: 0.8694 - f1_score: 0.8685
# Epoch 58: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.8673 - f1_score: 0.8666 - val_loss: 0.3895 - val_accuracy: 0.7037 - val_f1_score: 0.6718 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1722 - accuracy: 0.8833 - f1_score: 0.8822
# Epoch 59: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1724 - accuracy: 0.8842 - f1_score: 0.8832 - val_loss: 0.3778 - val_accuracy: 0.7037 - val_f1_score: 0.6834 - lr: 5.0000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1705 - accuracy: 0.8760 - f1_score: 0.8752
# Epoch 60: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1729 - accuracy: 0.8743 - f1_score: 0.8724 - val_loss: 0.3651 - val_accuracy: 0.7037 - val_f1_score: 0.6953 - lr: 5.0000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1775 - accuracy: 0.8771 - f1_score: 0.8764
# Epoch 61: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1751 - accuracy: 0.8782 - f1_score: 0.8782 - val_loss: 0.3562 - val_accuracy: 0.7130 - val_f1_score: 0.6993 - lr: 5.0000e-04
# Epoch 62/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.8862 - f1_score: 0.8859
# Epoch 62: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1646 - accuracy: 0.8862 - f1_score: 0.8859 - val_loss: 0.3697 - val_accuracy: 0.7099 - val_f1_score: 0.6914 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1605 - accuracy: 0.8865 - f1_score: 0.8857
# Epoch 63: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1611 - accuracy: 0.8862 - f1_score: 0.8851 - val_loss: 0.3863 - val_accuracy: 0.6883 - val_f1_score: 0.6731 - lr: 5.0000e-04
# Epoch 64/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1527 - accuracy: 0.8942 - f1_score: 0.8939
# Epoch 64: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1531 - accuracy: 0.8962 - f1_score: 0.8969 - val_loss: 0.3865 - val_accuracy: 0.6944 - val_f1_score: 0.6725 - lr: 5.0000e-04
# Epoch 65/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1733 - accuracy: 0.8795 - f1_score: 0.8788
# Epoch 65: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1707 - accuracy: 0.8812 - f1_score: 0.8816 - val_loss: 0.3912 - val_accuracy: 0.6852 - val_f1_score: 0.6611 - lr: 5.0000e-04
# Epoch 66/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1778 - accuracy: 0.8728 - f1_score: 0.8720
# Epoch 66: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1724 - accuracy: 0.8772 - f1_score: 0.8776 - val_loss: 0.3912 - val_accuracy: 0.6883 - val_f1_score: 0.6702 - lr: 5.0000e-04
# Epoch 67/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1738 - accuracy: 0.8817 - f1_score: 0.8804
# Epoch 67: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1748 - accuracy: 0.8792 - f1_score: 0.8764 - val_loss: 0.3912 - val_accuracy: 0.7068 - val_f1_score: 0.6738 - lr: 5.0000e-04
# Epoch 68/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1476 - accuracy: 0.8949 - f1_score: 0.8943
# Epoch 68: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1419 - accuracy: 0.9002 - f1_score: 0.8997 - val_loss: 0.3817 - val_accuracy: 0.7160 - val_f1_score: 0.6913 - lr: 5.0000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1780 - accuracy: 0.8771 - f1_score: 0.8760
# Epoch 69: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1736 - accuracy: 0.8802 - f1_score: 0.8807 - val_loss: 0.3765 - val_accuracy: 0.7006 - val_f1_score: 0.6862 - lr: 5.0000e-04
# Epoch 70/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1481 - accuracy: 0.8940 - f1_score: 0.8931
# Epoch 70: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1529 - accuracy: 0.8902 - f1_score: 0.8875 - val_loss: 0.3690 - val_accuracy: 0.7099 - val_f1_score: 0.6947 - lr: 5.0000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1648 - accuracy: 0.8823 - f1_score: 0.8815
# Epoch 71: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.8812 - f1_score: 0.8799 - val_loss: 0.3757 - val_accuracy: 0.6975 - val_f1_score: 0.6844 - lr: 5.0000e-04
# Epoch 72/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1754 - accuracy: 0.8783 - f1_score: 0.8775
# Epoch 72: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1679 - accuracy: 0.8842 - f1_score: 0.8834 - val_loss: 0.3853 - val_accuracy: 0.6821 - val_f1_score: 0.6747 - lr: 5.0000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1802 - accuracy: 0.8729 - f1_score: 0.8719
# Epoch 73: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.8723 - f1_score: 0.8709 - val_loss: 0.3849 - val_accuracy: 0.6883 - val_f1_score: 0.6747 - lr: 5.0000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1674 - accuracy: 0.8844 - f1_score: 0.8835
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 74: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1662 - accuracy: 0.8852 - f1_score: 0.8848 - val_loss: 0.3863 - val_accuracy: 0.6975 - val_f1_score: 0.6724 - lr: 5.0000e-04
# Epoch 75/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1629 - accuracy: 0.8895 - f1_score: 0.8884
# Epoch 75: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1608 - accuracy: 0.8902 - f1_score: 0.8879 - val_loss: 0.3888 - val_accuracy: 0.6975 - val_f1_score: 0.6724 - lr: 2.5000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1460 - accuracy: 0.8969 - f1_score: 0.8965
# Epoch 76: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1492 - accuracy: 0.8942 - f1_score: 0.8926 - val_loss: 0.3857 - val_accuracy: 0.6975 - val_f1_score: 0.6760 - lr: 2.5000e-04
# Epoch 77/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1502 - accuracy: 0.8951 - f1_score: 0.8943
# Epoch 77: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.8932 - f1_score: 0.8911 - val_loss: 0.3867 - val_accuracy: 0.6852 - val_f1_score: 0.6673 - lr: 2.5000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1454 - accuracy: 0.8958 - f1_score: 0.8950
# Epoch 78: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1452 - accuracy: 0.8962 - f1_score: 0.8956 - val_loss: 0.3826 - val_accuracy: 0.6944 - val_f1_score: 0.6739 - lr: 2.5000e-04
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.8962 - f1_score: 0.8970
# Epoch 79: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1493 - accuracy: 0.8962 - f1_score: 0.8970 - val_loss: 0.3783 - val_accuracy: 0.6944 - val_f1_score: 0.6777 - lr: 2.5000e-04
# Epoch 80/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1423 - accuracy: 0.9010 - f1_score: 0.9003
# Epoch 80: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1394 - accuracy: 0.9052 - f1_score: 0.9051 - val_loss: 0.3775 - val_accuracy: 0.7037 - val_f1_score: 0.6840 - lr: 2.5000e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1325 - accuracy: 0.9094 - f1_score: 0.9089
# Epoch 81: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1297 - accuracy: 0.9112 - f1_score: 0.9116 - val_loss: 0.3767 - val_accuracy: 0.6975 - val_f1_score: 0.6796 - lr: 2.5000e-04
# Epoch 82/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1273 - accuracy: 0.9118 - f1_score: 0.9110
# Epoch 82: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1286 - accuracy: 0.9102 - f1_score: 0.9099 - val_loss: 0.3775 - val_accuracy: 0.7006 - val_f1_score: 0.6845 - lr: 2.5000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1495 - accuracy: 0.8969 - f1_score: 0.8957
# Epoch 83: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1487 - accuracy: 0.8972 - f1_score: 0.8962 - val_loss: 0.3787 - val_accuracy: 0.6944 - val_f1_score: 0.6799 - lr: 2.5000e-04
# Epoch 84/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1297 - accuracy: 0.9096 - f1_score: 0.9090
# Epoch 84: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.9052 - f1_score: 0.9040 - val_loss: 0.3769 - val_accuracy: 0.7068 - val_f1_score: 0.6859 - lr: 2.5000e-04
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.8932 - f1_score: 0.8913
# Epoch 85: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1479 - accuracy: 0.8932 - f1_score: 0.8913 - val_loss: 0.3738 - val_accuracy: 0.7099 - val_f1_score: 0.6832 - lr: 2.5000e-04
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.8842 - f1_score: 0.8837
# Epoch 86: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1632 - accuracy: 0.8842 - f1_score: 0.8837 - val_loss: 0.3644 - val_accuracy: 0.7068 - val_f1_score: 0.6923 - lr: 2.5000e-04
# Epoch 87/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1438 - accuracy: 0.8973 - f1_score: 0.8969
# Epoch 87: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1478 - accuracy: 0.8962 - f1_score: 0.8954 - val_loss: 0.3665 - val_accuracy: 0.7130 - val_f1_score: 0.6997 - lr: 2.5000e-04
# Epoch 88/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1420 - accuracy: 0.8978 - f1_score: 0.8972
# Epoch 88: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1458 - accuracy: 0.8962 - f1_score: 0.8953 - val_loss: 0.3796 - val_accuracy: 0.6975 - val_f1_score: 0.6774 - lr: 2.5000e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1348 - accuracy: 0.9062 - f1_score: 0.9058
# Epoch 89: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1315 - accuracy: 0.9082 - f1_score: 0.9087 - val_loss: 0.3807 - val_accuracy: 0.7068 - val_f1_score: 0.6804 - lr: 2.5000e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1357 - accuracy: 0.9021 - f1_score: 0.9013
# Epoch 90: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9022 - f1_score: 0.9015 - val_loss: 0.3870 - val_accuracy: 0.6883 - val_f1_score: 0.6695 - lr: 2.5000e-04
# Epoch 91/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1364 - accuracy: 0.9038 - f1_score: 0.9030
# Epoch 91: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1301 - accuracy: 0.9082 - f1_score: 0.9084 - val_loss: 0.3778 - val_accuracy: 0.7006 - val_f1_score: 0.6861 - lr: 2.5000e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1220 - accuracy: 0.9146 - f1_score: 0.9141
# Epoch 92: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1249 - accuracy: 0.9132 - f1_score: 0.9120 - val_loss: 0.3712 - val_accuracy: 0.7037 - val_f1_score: 0.6884 - lr: 2.5000e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1303 - accuracy: 0.9052 - f1_score: 0.9050
# Epoch 93: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1300 - accuracy: 0.9052 - f1_score: 0.9047 - val_loss: 0.3778 - val_accuracy: 0.6975 - val_f1_score: 0.6840 - lr: 2.5000e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1420 - accuracy: 0.8990 - f1_score: 0.8979
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 94: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1420 - accuracy: 0.8992 - f1_score: 0.8982 - val_loss: 0.3806 - val_accuracy: 0.6944 - val_f1_score: 0.6799 - lr: 2.5000e-04
# Epoch 95/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1361 - accuracy: 0.9062 - f1_score: 0.9056
# Epoch 95: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9062 - f1_score: 0.9029 - val_loss: 0.3804 - val_accuracy: 0.6883 - val_f1_score: 0.6723 - lr: 1.2500e-04
# Epoch 96/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1604 - accuracy: 0.8894 - f1_score: 0.8886
# Epoch 96: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1584 - accuracy: 0.8902 - f1_score: 0.8908 - val_loss: 0.3773 - val_accuracy: 0.6883 - val_f1_score: 0.6759 - lr: 1.2500e-04
# Epoch 97/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9052 - f1_score: 0.9044
# Epoch 97: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1362 - accuracy: 0.9052 - f1_score: 0.9044 - val_loss: 0.3789 - val_accuracy: 0.6883 - val_f1_score: 0.6759 - lr: 1.2500e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1491 - accuracy: 0.8938 - f1_score: 0.8927
# Epoch 98: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1501 - accuracy: 0.8922 - f1_score: 0.8905 - val_loss: 0.3798 - val_accuracy: 0.6883 - val_f1_score: 0.6759 - lr: 1.2500e-04
# Epoch 99/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1373 - accuracy: 0.9040 - f1_score: 0.9033
# Epoch 99: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1421 - accuracy: 0.9022 - f1_score: 0.9004 - val_loss: 0.3789 - val_accuracy: 0.6883 - val_f1_score: 0.6759 - lr: 1.2500e-04
# Epoch 100/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1360 - accuracy: 0.9075 - f1_score: 0.9066
# Epoch 100: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9072 - f1_score: 0.9064 - val_loss: 0.3779 - val_accuracy: 0.6914 - val_f1_score: 0.6780 - lr: 1.2500e-04
# Epoch 101/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1210 - accuracy: 0.9174 - f1_score: 0.9171
# Epoch 101: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1160 - accuracy: 0.9212 - f1_score: 0.9215 - val_loss: 0.3794 - val_accuracy: 0.6914 - val_f1_score: 0.6780 - lr: 1.2500e-04
# Epoch 102/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1289 - accuracy: 0.9074 - f1_score: 0.9068
# Epoch 102: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1308 - accuracy: 0.9052 - f1_score: 0.9026 - val_loss: 0.3769 - val_accuracy: 0.6975 - val_f1_score: 0.6823 - lr: 1.2500e-04
# Epoch 103/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1337 - accuracy: 0.9029 - f1_score: 0.9016
# Epoch 103: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1309 - accuracy: 0.9052 - f1_score: 0.9043 - val_loss: 0.3744 - val_accuracy: 0.7006 - val_f1_score: 0.6844 - lr: 1.2500e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1305 - accuracy: 0.9104 - f1_score: 0.9099
# Epoch 104: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1293 - accuracy: 0.9112 - f1_score: 0.9109 - val_loss: 0.3746 - val_accuracy: 0.7006 - val_f1_score: 0.6844 - lr: 1.2500e-04
# Epoch 105/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1357 - accuracy: 0.9075 - f1_score: 0.9067
# Epoch 105: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1356 - accuracy: 0.9062 - f1_score: 0.9054 - val_loss: 0.3725 - val_accuracy: 0.7006 - val_f1_score: 0.6844 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1363 - accuracy: 0.9052 - f1_score: 0.9047
# Epoch 106: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1339 - accuracy: 0.9072 - f1_score: 0.9077 - val_loss: 0.3733 - val_accuracy: 0.7006 - val_f1_score: 0.6844 - lr: 1.2500e-04
# Epoch 107/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1298 - accuracy: 0.9107 - f1_score: 0.9098
# Epoch 107: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1294 - accuracy: 0.9112 - f1_score: 0.9094 - val_loss: 0.3732 - val_accuracy: 0.7006 - val_f1_score: 0.6844 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1321 - accuracy: 0.9083 - f1_score: 0.9074
# Epoch 108: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9102 - f1_score: 0.9102 - val_loss: 0.3741 - val_accuracy: 0.7037 - val_f1_score: 0.6867 - lr: 1.2500e-04
# Epoch 109/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1409 - accuracy: 0.9050 - f1_score: 0.9033
# Epoch 109: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1366 - accuracy: 0.9062 - f1_score: 0.9052 - val_loss: 0.3739 - val_accuracy: 0.7099 - val_f1_score: 0.6893 - lr: 1.2500e-04
# Epoch 110/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1226 - accuracy: 0.9147 - f1_score: 0.9141
# Epoch 110: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.9192 - f1_score: 0.9194 - val_loss: 0.3697 - val_accuracy: 0.7130 - val_f1_score: 0.6917 - lr: 1.2500e-04
# Epoch 111/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1218 - accuracy: 0.9141 - f1_score: 0.9134
# Epoch 111: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1203 - accuracy: 0.9152 - f1_score: 0.9153 - val_loss: 0.3711 - val_accuracy: 0.7068 - val_f1_score: 0.6854 - lr: 1.2500e-04
# Epoch 112/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1341 - accuracy: 0.9102 - f1_score: 0.9096
# Epoch 112: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1383 - accuracy: 0.9052 - f1_score: 0.9035 - val_loss: 0.3745 - val_accuracy: 0.7006 - val_f1_score: 0.6824 - lr: 1.2500e-04
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1285 - accuracy: 0.9083 - f1_score: 0.9078
# Epoch 113: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1294 - accuracy: 0.9072 - f1_score: 0.9062 - val_loss: 0.3766 - val_accuracy: 0.7006 - val_f1_score: 0.6790 - lr: 1.2500e-04
# Epoch 114/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1298 - accuracy: 0.9085 - f1_score: 0.9075
# Epoch 114: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 114: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1287 - accuracy: 0.9102 - f1_score: 0.9090 - val_loss: 0.3780 - val_accuracy: 0.6944 - val_f1_score: 0.6746 - lr: 1.2500e-04
# Epoch 115/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1234 - accuracy: 0.9085 - f1_score: 0.9079
# Epoch 115: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1289 - accuracy: 0.9052 - f1_score: 0.9036 - val_loss: 0.3782 - val_accuracy: 0.6975 - val_f1_score: 0.6785 - lr: 6.2500e-05
# Epoch 116/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1474 - accuracy: 0.8942 - f1_score: 0.8932
# Epoch 116: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.8932 - f1_score: 0.8931 - val_loss: 0.3772 - val_accuracy: 0.7006 - val_f1_score: 0.6808 - lr: 6.2500e-05
# Epoch 117/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1322 - accuracy: 0.9040 - f1_score: 0.9035
# Epoch 117: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1302 - accuracy: 0.9062 - f1_score: 0.9060 - val_loss: 0.3764 - val_accuracy: 0.7006 - val_f1_score: 0.6808 - lr: 6.2500e-05
# Epoch 118/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1376 - accuracy: 0.9051 - f1_score: 0.9042
# Epoch 118: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1370 - accuracy: 0.9052 - f1_score: 0.9048 - val_loss: 0.3766 - val_accuracy: 0.7006 - val_f1_score: 0.6808 - lr: 6.2500e-05
# Epoch 119/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9002 - f1_score: 0.8977
# Epoch 119: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1448 - accuracy: 0.9002 - f1_score: 0.8977 - val_loss: 0.3752 - val_accuracy: 0.7006 - val_f1_score: 0.6808 - lr: 6.2500e-05
# Epoch 120/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1244 - accuracy: 0.9176 - f1_score: 0.9171
# Epoch 120: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1224 - accuracy: 0.9172 - f1_score: 0.9170 - val_loss: 0.3729 - val_accuracy: 0.7037 - val_f1_score: 0.6846 - lr: 6.2500e-05
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1418 - accuracy: 0.9042 - f1_score: 0.9032
# Epoch 121: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9072 - f1_score: 0.9077 - val_loss: 0.3720 - val_accuracy: 0.7037 - val_f1_score: 0.6846 - lr: 6.2500e-05
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.8942 - f1_score: 0.8927
# Epoch 122: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1483 - accuracy: 0.8942 - f1_score: 0.8927 - val_loss: 0.3712 - val_accuracy: 0.7068 - val_f1_score: 0.6904 - lr: 6.2500e-05
# Epoch 123/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.8972 - f1_score: 0.8951
# Epoch 123: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1510 - accuracy: 0.8972 - f1_score: 0.8951 - val_loss: 0.3696 - val_accuracy: 0.7068 - val_f1_score: 0.6923 - lr: 6.2500e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1373 - accuracy: 0.9031 - f1_score: 0.9025
# Epoch 124: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9032 - f1_score: 0.9026 - val_loss: 0.3702 - val_accuracy: 0.7068 - val_f1_score: 0.6923 - lr: 6.2500e-05
# Epoch 125/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9002 - f1_score: 0.8978
# Epoch 125: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1419 - accuracy: 0.9002 - f1_score: 0.8978 - val_loss: 0.3696 - val_accuracy: 0.7130 - val_f1_score: 0.6969 - lr: 6.2500e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.9052 - f1_score: 0.9047
# Epoch 126: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9072 - f1_score: 0.9076 - val_loss: 0.3704 - val_accuracy: 0.7068 - val_f1_score: 0.6888 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1254 - accuracy: 0.9125 - f1_score: 0.9120
# Epoch 127: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1265 - accuracy: 0.9122 - f1_score: 0.9114 - val_loss: 0.3713 - val_accuracy: 0.7068 - val_f1_score: 0.6888 - lr: 6.2500e-05
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9072 - f1_score: 0.9060
# Epoch 128: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1366 - accuracy: 0.9072 - f1_score: 0.9060 - val_loss: 0.3701 - val_accuracy: 0.7037 - val_f1_score: 0.6866 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1378 - accuracy: 0.9021 - f1_score: 0.9013
# Epoch 129: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1387 - accuracy: 0.9022 - f1_score: 0.9015 - val_loss: 0.3697 - val_accuracy: 0.7037 - val_f1_score: 0.6866 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1258 - accuracy: 0.9104 - f1_score: 0.9100
# Epoch 130: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9072 - f1_score: 0.9050 - val_loss: 0.3701 - val_accuracy: 0.7068 - val_f1_score: 0.6889 - lr: 6.2500e-05
# Epoch 131/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1316 - accuracy: 0.9077 - f1_score: 0.9067
# Epoch 131: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1317 - accuracy: 0.9112 - f1_score: 0.9111 - val_loss: 0.3701 - val_accuracy: 0.7068 - val_f1_score: 0.6889 - lr: 6.2500e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1318 - accuracy: 0.9083 - f1_score: 0.9075
# Epoch 132: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1286 - accuracy: 0.9112 - f1_score: 0.9118 - val_loss: 0.3690 - val_accuracy: 0.7037 - val_f1_score: 0.6865 - lr: 6.2500e-05
# Epoch 133/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1297 - accuracy: 0.9099 - f1_score: 0.9092
# Epoch 133: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1282 - accuracy: 0.9102 - f1_score: 0.9087 - val_loss: 0.3676 - val_accuracy: 0.7068 - val_f1_score: 0.6922 - lr: 6.2500e-05
# Epoch 134/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1217 - accuracy: 0.9219 - f1_score: 0.9217Restoring model weights from the end of the best epoch: 34.
#
# Epoch 134: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 134: val_f1_score did not improve from 0.72344
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1250 - accuracy: 0.9132 - f1_score: 0.9126 - val_loss: 0.3671 - val_accuracy: 0.7068 - val_f1_score: 0.6922 - lr: 6.2500e-05
# Epoch 134: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               22016
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 200610 (783.63 KB)
# Trainable params: 198626 (775.88 KB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 810us/step
# 0.7160493827160493

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7160493827160493
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.47      0.68      0.56        85
#            0       0.87      0.73      0.79       239
#
#     accuracy                           0.72       324
#    macro avg       0.67      0.71      0.67       324
# weighted avg       0.76      0.72      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 232 chiếm khoảng 71.60493827160494% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 58 chiếm khoảng 68.23529411764706% so với thực tế
