# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model():
    input_shape =(42,1)
    learning_rate=0.0001

    bn_axis = -1
    step=32
    model = Sequential()
    model.add(Dense(512,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Thêm các lớp ẩn
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # Lớp đầu ra với activation function 'sigmoid' cho bài toán phân lớp nhị phân
    model.add(Dense(2, activation='softmax'))
   



    model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    # model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


# data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
model=build_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
#  1/16 [>.............................] - ETA: 29s - loss: 0.7171 - accuracy: 0.4531 - f1_score: 0.4519
# Epoch 1: val_f1_score improved from -inf to 0.42295, saving model to best_model.h5
# 16/16 [==============================] - 2s 23ms/step - loss: 0.6979 - accuracy: 0.5020 - f1_score: 0.5013 - val_loss: 0.3660 - val_accuracy: 0.7315 - val_f1_score: 0.4230 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6589 - accuracy: 0.5259 - f1_score: 0.5228
# Epoch 2: val_f1_score improved from 0.42295 to 0.47914, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6589 - accuracy: 0.5259 - f1_score: 0.5228 - val_loss: 0.3934 - val_accuracy: 0.7284 - val_f1_score: 0.4791 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6455 - accuracy: 0.5479 - f1_score: 0.5452
# Epoch 3: val_f1_score improved from 0.47914 to 0.48916, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6468 - accuracy: 0.5469 - f1_score: 0.5439 - val_loss: 0.3844 - val_accuracy: 0.7130 - val_f1_score: 0.4892 - lr: 0.0010
# Epoch 4/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.6086 - accuracy: 0.5000 - f1_score: 0.4995
# Epoch 4: val_f1_score improved from 0.48916 to 0.49263, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6488 - accuracy: 0.5319 - f1_score: 0.5311 - val_loss: 0.3465 - val_accuracy: 0.7160 - val_f1_score: 0.4926 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6283 - accuracy: 0.5573 - f1_score: 0.5555
# Epoch 5: val_f1_score did not improve from 0.49263
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6262 - accuracy: 0.5599 - f1_score: 0.5592 - val_loss: 0.3184 - val_accuracy: 0.7191 - val_f1_score: 0.4830 - lr: 0.0010
# Epoch 6/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.7141 - accuracy: 0.5312 - f1_score: 0.5238
# Epoch 6: val_f1_score did not improve from 0.49263
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6027 - accuracy: 0.5649 - f1_score: 0.5648 - val_loss: 0.2955 - val_accuracy: 0.7346 - val_f1_score: 0.4873 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5616 - accuracy: 0.6000 - f1_score: 0.5969
# Epoch 7: val_f1_score improved from 0.49263 to 0.49374, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5660 - accuracy: 0.5938 - f1_score: 0.5877 - val_loss: 0.2919 - val_accuracy: 0.7222 - val_f1_score: 0.4937 - lr: 0.0010
# Epoch 8/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5526 - accuracy: 0.6172 - f1_score: 0.6112
# Epoch 8: val_f1_score improved from 0.49374 to 0.53494, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5456 - accuracy: 0.6168 - f1_score: 0.6115 - val_loss: 0.2905 - val_accuracy: 0.7377 - val_f1_score: 0.5349 - lr: 0.0010
# Epoch 9/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.5748 - accuracy: 0.6406 - f1_score: 0.6297
# Epoch 9: val_f1_score improved from 0.53494 to 0.53974, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4939 - accuracy: 0.6677 - f1_score: 0.6626 - val_loss: 0.3017 - val_accuracy: 0.7160 - val_f1_score: 0.5397 - lr: 0.0010
# Epoch 10/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.4708 - accuracy: 0.6719 - f1_score: 0.6679
# Epoch 10: val_f1_score improved from 0.53974 to 0.54065, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4662 - accuracy: 0.6707 - f1_score: 0.6706 - val_loss: 0.3079 - val_accuracy: 0.7006 - val_f1_score: 0.5406 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.7226 - f1_score: 0.7196
# Epoch 11: val_f1_score improved from 0.54065 to 0.56594, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4215 - accuracy: 0.7226 - f1_score: 0.7196 - val_loss: 0.3010 - val_accuracy: 0.7130 - val_f1_score: 0.5659 - lr: 0.0010
# Epoch 12/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.4672 - accuracy: 0.6662 - f1_score: 0.6628
# Epoch 12: val_f1_score did not improve from 0.56594
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4402 - accuracy: 0.6906 - f1_score: 0.6876 - val_loss: 0.3127 - val_accuracy: 0.6883 - val_f1_score: 0.5421 - lr: 0.0010
# Epoch 13/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3635 - accuracy: 0.7533 - f1_score: 0.7518
# Epoch 13: val_f1_score improved from 0.56594 to 0.64850, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3609 - accuracy: 0.7545 - f1_score: 0.7517 - val_loss: 0.3138 - val_accuracy: 0.6944 - val_f1_score: 0.6485 - lr: 0.0010
# Epoch 14/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3698 - accuracy: 0.7380 - f1_score: 0.7364
# Epoch 14: val_f1_score did not improve from 0.64850
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3776 - accuracy: 0.7345 - f1_score: 0.7291 - val_loss: 0.2992 - val_accuracy: 0.7037 - val_f1_score: 0.5510 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.7645 - f1_score: 0.7638
# Epoch 15: val_f1_score improved from 0.64850 to 0.65147, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3536 - accuracy: 0.7645 - f1_score: 0.7638 - val_loss: 0.3060 - val_accuracy: 0.7006 - val_f1_score: 0.6515 - lr: 0.0010
# Epoch 16/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3522 - accuracy: 0.7692 - f1_score: 0.7666
# Epoch 16: val_f1_score did not improve from 0.65147
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3430 - accuracy: 0.7764 - f1_score: 0.7738 - val_loss: 0.3058 - val_accuracy: 0.6914 - val_f1_score: 0.6023 - lr: 0.0010
# Epoch 17/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1530 - accuracy: 0.9219 - f1_score: 0.9219
# Epoch 17: val_f1_score did not improve from 0.65147
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3253 - accuracy: 0.7725 - f1_score: 0.7706 - val_loss: 0.3043 - val_accuracy: 0.7037 - val_f1_score: 0.6187 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.7864 - f1_score: 0.7832
# Epoch 18: val_f1_score did not improve from 0.65147
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3160 - accuracy: 0.7864 - f1_score: 0.7832 - val_loss: 0.3063 - val_accuracy: 0.6975 - val_f1_score: 0.6296 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8144 - f1_score: 0.8128
# Epoch 19: val_f1_score improved from 0.65147 to 0.66231, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2803 - accuracy: 0.8144 - f1_score: 0.8128 - val_loss: 0.3113 - val_accuracy: 0.6944 - val_f1_score: 0.6623 - lr: 0.0010
# Epoch 20/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2882 - accuracy: 0.8058 - f1_score: 0.8041
# Epoch 20: val_f1_score improved from 0.66231 to 0.66945, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2848 - accuracy: 0.8074 - f1_score: 0.8073 - val_loss: 0.3168 - val_accuracy: 0.6883 - val_f1_score: 0.6694 - lr: 0.0010
# Epoch 21/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3024 - accuracy: 0.7879 - f1_score: 0.7864
# Epoch 21: val_f1_score did not improve from 0.66945
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2930 - accuracy: 0.7974 - f1_score: 0.7977 - val_loss: 0.3246 - val_accuracy: 0.6759 - val_f1_score: 0.6664 - lr: 0.0010
# Epoch 22/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2700 - accuracy: 0.8125 - f1_score: 0.8108
# Epoch 22: val_f1_score improved from 0.66945 to 0.67310, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2795 - accuracy: 0.8104 - f1_score: 0.8099 - val_loss: 0.3413 - val_accuracy: 0.6698 - val_f1_score: 0.6731 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2530 - accuracy: 0.8313 - f1_score: 0.8307
# Epoch 23: val_f1_score did not improve from 0.67310
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2542 - accuracy: 0.8303 - f1_score: 0.8293 - val_loss: 0.3508 - val_accuracy: 0.6574 - val_f1_score: 0.6368 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2639 - accuracy: 0.8188 - f1_score: 0.8183
# Epoch 24: val_f1_score did not improve from 0.67310
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2663 - accuracy: 0.8184 - f1_score: 0.8175 - val_loss: 0.3548 - val_accuracy: 0.6481 - val_f1_score: 0.6311 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2510 - accuracy: 0.8240 - f1_score: 0.8229
# Epoch 25: val_f1_score did not improve from 0.67310
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2499 - accuracy: 0.8253 - f1_score: 0.8250 - val_loss: 0.3733 - val_accuracy: 0.6296 - val_f1_score: 0.6194 - lr: 0.0010
# Epoch 26/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2592 - accuracy: 0.8203 - f1_score: 0.8196
# Epoch 26: val_f1_score did not improve from 0.67310
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2550 - accuracy: 0.8244 - f1_score: 0.8239 - val_loss: 0.3381 - val_accuracy: 0.6636 - val_f1_score: 0.6358 - lr: 0.0010
# Epoch 27/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1914 - accuracy: 0.8594 - f1_score: 0.8593
# Epoch 27: val_f1_score did not improve from 0.67310
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2449 - accuracy: 0.8323 - f1_score: 0.8316 - val_loss: 0.3221 - val_accuracy: 0.6852 - val_f1_score: 0.6209 - lr: 0.0010
# Epoch 28/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2119 - accuracy: 0.8438 - f1_score: 0.8436
# Epoch 28: val_f1_score improved from 0.67310 to 0.68256, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2456 - accuracy: 0.8253 - f1_score: 0.8226 - val_loss: 0.3014 - val_accuracy: 0.7037 - val_f1_score: 0.6826 - lr: 0.0010
# Epoch 29/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.2346 - accuracy: 0.8423 - f1_score: 0.8417
# Epoch 29: val_f1_score improved from 0.68256 to 0.70332, saving model to best_model.h5
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2346 - accuracy: 0.8383 - f1_score: 0.8370 - val_loss: 0.2919 - val_accuracy: 0.7068 - val_f1_score: 0.7033 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2345 - accuracy: 0.8438 - f1_score: 0.8423
# Epoch 30: val_f1_score did not improve from 0.70332
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2363 - accuracy: 0.8423 - f1_score: 0.8402 - val_loss: 0.3383 - val_accuracy: 0.6667 - val_f1_score: 0.6450 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.8463 - f1_score: 0.8453
# Epoch 31: val_f1_score did not improve from 0.70332
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2287 - accuracy: 0.8463 - f1_score: 0.8453 - val_loss: 0.3070 - val_accuracy: 0.6914 - val_f1_score: 0.7026 - lr: 0.0010
# Epoch 32/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2202 - accuracy: 0.8424 - f1_score: 0.8418
# Epoch 32: val_f1_score improved from 0.70332 to 0.71901, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2237 - accuracy: 0.8423 - f1_score: 0.8429 - val_loss: 0.2845 - val_accuracy: 0.7253 - val_f1_score: 0.7190 - lr: 0.0010
# Epoch 33/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2119 - accuracy: 0.8560 - f1_score: 0.8551
# Epoch 33: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2167 - accuracy: 0.8523 - f1_score: 0.8499 - val_loss: 0.2962 - val_accuracy: 0.7068 - val_f1_score: 0.6835 - lr: 0.0010
# Epoch 34/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2120 - accuracy: 0.8493 - f1_score: 0.8479
# Epoch 34: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2150 - accuracy: 0.8433 - f1_score: 0.8408 - val_loss: 0.3047 - val_accuracy: 0.6944 - val_f1_score: 0.6668 - lr: 0.0010
# Epoch 35/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2129 - accuracy: 0.8516 - f1_score: 0.8506
# Epoch 35: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.8533 - f1_score: 0.8538 - val_loss: 0.3047 - val_accuracy: 0.6914 - val_f1_score: 0.6341 - lr: 0.0010
# Epoch 36/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2172 - accuracy: 0.8450 - f1_score: 0.8438
# Epoch 36: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2205 - accuracy: 0.8413 - f1_score: 0.8375 - val_loss: 0.3152 - val_accuracy: 0.6821 - val_f1_score: 0.5990 - lr: 0.0010
# Epoch 37/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2080 - accuracy: 0.8522 - f1_score: 0.8511
# Epoch 37: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2100 - accuracy: 0.8513 - f1_score: 0.8509 - val_loss: 0.3208 - val_accuracy: 0.6883 - val_f1_score: 0.6226 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2214 - accuracy: 0.8396 - f1_score: 0.8384
# Epoch 38: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2218 - accuracy: 0.8393 - f1_score: 0.8380 - val_loss: 0.3178 - val_accuracy: 0.6852 - val_f1_score: 0.6321 - lr: 0.0010
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.8533 - f1_score: 0.8521
# Epoch 39: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2046 - accuracy: 0.8533 - f1_score: 0.8521 - val_loss: 0.2901 - val_accuracy: 0.7160 - val_f1_score: 0.6897 - lr: 0.0010
# Epoch 40/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2230 - accuracy: 0.8426 - f1_score: 0.8418
# Epoch 40: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2220 - accuracy: 0.8423 - f1_score: 0.8418 - val_loss: 0.2937 - val_accuracy: 0.7099 - val_f1_score: 0.6860 - lr: 0.0010
# Epoch 41/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2226 - accuracy: 0.8449 - f1_score: 0.8444
# Epoch 41: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2184 - accuracy: 0.8483 - f1_score: 0.8484 - val_loss: 0.3072 - val_accuracy: 0.6944 - val_f1_score: 0.6554 - lr: 0.0010
# Epoch 42/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.2149 - accuracy: 0.8494 - f1_score: 0.8484
# Epoch 42: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2160 - accuracy: 0.8483 - f1_score: 0.8486 - val_loss: 0.3044 - val_accuracy: 0.7006 - val_f1_score: 0.6548 - lr: 0.0010
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1996 - accuracy: 0.8562 - f1_score: 0.8552
# Epoch 43: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1986 - accuracy: 0.8573 - f1_score: 0.8568 - val_loss: 0.3202 - val_accuracy: 0.6790 - val_f1_score: 0.6478 - lr: 0.0010
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2123 - accuracy: 0.8458 - f1_score: 0.8453
# Epoch 44: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2095 - accuracy: 0.8493 - f1_score: 0.8505 - val_loss: 0.3246 - val_accuracy: 0.6790 - val_f1_score: 0.6550 - lr: 0.0010
# Epoch 45/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2106 - accuracy: 0.8504 - f1_score: 0.8489
# Epoch 45: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2006 - accuracy: 0.8583 - f1_score: 0.8589 - val_loss: 0.3242 - val_accuracy: 0.6728 - val_f1_score: 0.6696 - lr: 0.0010
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2055 - accuracy: 0.8521 - f1_score: 0.8510
# Epoch 46: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2005 - accuracy: 0.8553 - f1_score: 0.8559 - val_loss: 0.3396 - val_accuracy: 0.6667 - val_f1_score: 0.6375 - lr: 0.0010
# Epoch 47/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2152 - accuracy: 0.8594 - f1_score: 0.8577
# Epoch 47: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1897 - accuracy: 0.8703 - f1_score: 0.8687 - val_loss: 0.3178 - val_accuracy: 0.6883 - val_f1_score: 0.6882 - lr: 0.0010
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1942 - accuracy: 0.8677 - f1_score: 0.8667
# Epoch 48: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1913 - accuracy: 0.8703 - f1_score: 0.8706 - val_loss: 0.3320 - val_accuracy: 0.6667 - val_f1_score: 0.6396 - lr: 0.0010
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1967 - accuracy: 0.8604 - f1_score: 0.8600
# Epoch 49: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1942 - accuracy: 0.8623 - f1_score: 0.8627 - val_loss: 0.3216 - val_accuracy: 0.6759 - val_f1_score: 0.6594 - lr: 0.0010
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1850 - accuracy: 0.8705 - f1_score: 0.8694
# Epoch 50: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1958 - accuracy: 0.8623 - f1_score: 0.8590 - val_loss: 0.3208 - val_accuracy: 0.6728 - val_f1_score: 0.6558 - lr: 0.0010
# Epoch 51/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2045 - accuracy: 0.8516 - f1_score: 0.8497
# Epoch 51: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.8563 - f1_score: 0.8557 - val_loss: 0.3212 - val_accuracy: 0.6852 - val_f1_score: 0.6367 - lr: 0.0010
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1939 - accuracy: 0.8677 - f1_score: 0.8667
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 52: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.8673 - f1_score: 0.8661 - val_loss: 0.3186 - val_accuracy: 0.6759 - val_f1_score: 0.6512 - lr: 0.0010
# Epoch 53/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1998 - accuracy: 0.8571 - f1_score: 0.8552
# Epoch 53: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1983 - accuracy: 0.8593 - f1_score: 0.8586 - val_loss: 0.3121 - val_accuracy: 0.6914 - val_f1_score: 0.6656 - lr: 5.0000e-04
# Epoch 54/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1790 - accuracy: 0.8761 - f1_score: 0.8750
# Epoch 54: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1794 - accuracy: 0.8762 - f1_score: 0.8742 - val_loss: 0.3055 - val_accuracy: 0.6944 - val_f1_score: 0.6748 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1801 - accuracy: 0.8740 - f1_score: 0.8736
# Epoch 55: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 0.8743 - f1_score: 0.8740 - val_loss: 0.3037 - val_accuracy: 0.6944 - val_f1_score: 0.6691 - lr: 5.0000e-04
# Epoch 56/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1656 - accuracy: 0.8828 - f1_score: 0.8824
# Epoch 56: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1734 - accuracy: 0.8772 - f1_score: 0.8769 - val_loss: 0.3087 - val_accuracy: 0.6852 - val_f1_score: 0.6652 - lr: 5.0000e-04
# Epoch 57/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.1582 - accuracy: 0.8889 - f1_score: 0.8884
# Epoch 57: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1736 - accuracy: 0.8752 - f1_score: 0.8744 - val_loss: 0.3049 - val_accuracy: 0.7006 - val_f1_score: 0.6842 - lr: 5.0000e-04
# Epoch 58/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.8733 - f1_score: 0.8723
# Epoch 58: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.8733 - f1_score: 0.8723 - val_loss: 0.3060 - val_accuracy: 0.6883 - val_f1_score: 0.6706 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1861 - accuracy: 0.8656 - f1_score: 0.8650
# Epoch 59: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1868 - accuracy: 0.8653 - f1_score: 0.8643 - val_loss: 0.3015 - val_accuracy: 0.7006 - val_f1_score: 0.6863 - lr: 5.0000e-04
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.8902 - f1_score: 0.8903
# Epoch 60: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.8902 - f1_score: 0.8903 - val_loss: 0.3179 - val_accuracy: 0.6790 - val_f1_score: 0.6632 - lr: 5.0000e-04
# Epoch 61/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1633 - accuracy: 0.8806 - f1_score: 0.8797
# Epoch 61: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1637 - accuracy: 0.8812 - f1_score: 0.8813 - val_loss: 0.3184 - val_accuracy: 0.6821 - val_f1_score: 0.6552 - lr: 5.0000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1745 - accuracy: 0.8740 - f1_score: 0.8733
# Epoch 62: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1714 - accuracy: 0.8762 - f1_score: 0.8768 - val_loss: 0.3205 - val_accuracy: 0.6759 - val_f1_score: 0.6467 - lr: 5.0000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1655 - accuracy: 0.8823 - f1_score: 0.8816
# Epoch 63: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.8802 - f1_score: 0.8786 - val_loss: 0.3176 - val_accuracy: 0.6821 - val_f1_score: 0.6556 - lr: 5.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.8822 - f1_score: 0.8830
# Epoch 64: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1634 - accuracy: 0.8822 - f1_score: 0.8830 - val_loss: 0.3110 - val_accuracy: 0.6852 - val_f1_score: 0.6221 - lr: 5.0000e-04
# Epoch 65/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1767 - accuracy: 0.8739 - f1_score: 0.8724
# Epoch 65: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1714 - accuracy: 0.8772 - f1_score: 0.8764 - val_loss: 0.3079 - val_accuracy: 0.6944 - val_f1_score: 0.6440 - lr: 5.0000e-04
# Epoch 66/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1479 - accuracy: 0.8940 - f1_score: 0.8936
# Epoch 66: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1536 - accuracy: 0.8902 - f1_score: 0.8902 - val_loss: 0.3060 - val_accuracy: 0.6975 - val_f1_score: 0.6523 - lr: 5.0000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1722 - accuracy: 0.8813 - f1_score: 0.8803
# Epoch 67: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.8822 - f1_score: 0.8818 - val_loss: 0.2997 - val_accuracy: 0.7006 - val_f1_score: 0.6837 - lr: 5.0000e-04
# Epoch 68/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2101 - accuracy: 0.8594 - f1_score: 0.8593
# Epoch 68: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1641 - accuracy: 0.8882 - f1_score: 0.8859 - val_loss: 0.3022 - val_accuracy: 0.6975 - val_f1_score: 0.6625 - lr: 5.0000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1493 - accuracy: 0.8938 - f1_score: 0.8931
# Epoch 69: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1532 - accuracy: 0.8902 - f1_score: 0.8875 - val_loss: 0.2996 - val_accuracy: 0.7037 - val_f1_score: 0.6854 - lr: 5.0000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1527 - accuracy: 0.8948 - f1_score: 0.8939
# Epoch 70: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.8972 - f1_score: 0.8976 - val_loss: 0.3065 - val_accuracy: 0.6975 - val_f1_score: 0.6809 - lr: 5.0000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1616 - accuracy: 0.8875 - f1_score: 0.8866
# Epoch 71: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.8862 - f1_score: 0.8847 - val_loss: 0.3207 - val_accuracy: 0.6759 - val_f1_score: 0.6482 - lr: 5.0000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1451 - accuracy: 0.9000 - f1_score: 0.8993
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 72: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1511 - accuracy: 0.8962 - f1_score: 0.8935 - val_loss: 0.3175 - val_accuracy: 0.6821 - val_f1_score: 0.6538 - lr: 5.0000e-04
# Epoch 73/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1501 - accuracy: 0.8906 - f1_score: 0.8902
# Epoch 73: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1574 - accuracy: 0.8862 - f1_score: 0.8830 - val_loss: 0.3174 - val_accuracy: 0.6790 - val_f1_score: 0.6520 - lr: 2.5000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1613 - accuracy: 0.8885 - f1_score: 0.8874
# Epoch 74: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1569 - accuracy: 0.8912 - f1_score: 0.8915 - val_loss: 0.3122 - val_accuracy: 0.6914 - val_f1_score: 0.6627 - lr: 2.5000e-04
# Epoch 75/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1490 - accuracy: 0.8906 - f1_score: 0.8894
# Epoch 75: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1550 - accuracy: 0.8882 - f1_score: 0.8853 - val_loss: 0.3140 - val_accuracy: 0.6914 - val_f1_score: 0.6580 - lr: 2.5000e-04
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.8792 - f1_score: 0.8778
# Epoch 76: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1663 - accuracy: 0.8792 - f1_score: 0.8778 - val_loss: 0.3153 - val_accuracy: 0.6821 - val_f1_score: 0.6480 - lr: 2.5000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1505 - accuracy: 0.8927 - f1_score: 0.8918
# Epoch 77: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1495 - accuracy: 0.8932 - f1_score: 0.8926 - val_loss: 0.3244 - val_accuracy: 0.6728 - val_f1_score: 0.6456 - lr: 2.5000e-04
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1405 - accuracy: 0.9042 - f1_score: 0.9033
# Epoch 78: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9052 - f1_score: 0.9049 - val_loss: 0.3249 - val_accuracy: 0.6728 - val_f1_score: 0.6478 - lr: 2.5000e-04
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.8842 - f1_score: 0.8825
# Epoch 79: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1591 - accuracy: 0.8842 - f1_score: 0.8825 - val_loss: 0.3234 - val_accuracy: 0.6728 - val_f1_score: 0.6578 - lr: 2.5000e-04
# Epoch 80/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1417 - accuracy: 0.8984 - f1_score: 0.8980
# Epoch 80: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1465 - accuracy: 0.8942 - f1_score: 0.8935 - val_loss: 0.3232 - val_accuracy: 0.6790 - val_f1_score: 0.6713 - lr: 2.5000e-04
# Epoch 81/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.8992 - f1_score: 0.8980
# Epoch 81: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1446 - accuracy: 0.8992 - f1_score: 0.8980 - val_loss: 0.3130 - val_accuracy: 0.6821 - val_f1_score: 0.6712 - lr: 2.5000e-04
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9002 - f1_score: 0.8990
# Epoch 82: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1400 - accuracy: 0.9002 - f1_score: 0.8990 - val_loss: 0.3108 - val_accuracy: 0.6852 - val_f1_score: 0.6682 - lr: 2.5000e-04
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9052 - f1_score: 0.9056
# Epoch 83: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1377 - accuracy: 0.9052 - f1_score: 0.9056 - val_loss: 0.3113 - val_accuracy: 0.6914 - val_f1_score: 0.6685 - lr: 2.5000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1407 - accuracy: 0.9052 - f1_score: 0.9046
# Epoch 84: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1402 - accuracy: 0.9042 - f1_score: 0.9029 - val_loss: 0.3075 - val_accuracy: 0.6944 - val_f1_score: 0.6723 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1586 - accuracy: 0.8875 - f1_score: 0.8864
# Epoch 85: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1585 - accuracy: 0.8872 - f1_score: 0.8860 - val_loss: 0.3059 - val_accuracy: 0.6914 - val_f1_score: 0.6617 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1414 - accuracy: 0.8990 - f1_score: 0.8984
# Epoch 86: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1412 - accuracy: 0.8982 - f1_score: 0.8972 - val_loss: 0.3058 - val_accuracy: 0.6914 - val_f1_score: 0.6639 - lr: 2.5000e-04
# Epoch 87/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1413 - accuracy: 0.9020 - f1_score: 0.9015
# Epoch 87: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1481 - accuracy: 0.8972 - f1_score: 0.8960 - val_loss: 0.3032 - val_accuracy: 0.6975 - val_f1_score: 0.6836 - lr: 2.5000e-04
# Epoch 88/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9022 - f1_score: 0.9015
# Epoch 88: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1386 - accuracy: 0.9022 - f1_score: 0.9015 - val_loss: 0.3068 - val_accuracy: 0.6883 - val_f1_score: 0.6679 - lr: 2.5000e-04
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.8962 - f1_score: 0.8927
# Epoch 89: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1452 - accuracy: 0.8962 - f1_score: 0.8927 - val_loss: 0.3071 - val_accuracy: 0.6914 - val_f1_score: 0.6700 - lr: 2.5000e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1505 - accuracy: 0.8927 - f1_score: 0.8918
# Epoch 90: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.8962 - f1_score: 0.8970 - val_loss: 0.3028 - val_accuracy: 0.7006 - val_f1_score: 0.6890 - lr: 2.5000e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9002 - f1_score: 0.9006
# Epoch 91: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1421 - accuracy: 0.9002 - f1_score: 0.9006 - val_loss: 0.2974 - val_accuracy: 0.7068 - val_f1_score: 0.6937 - lr: 2.5000e-04
# Epoch 92/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1451 - accuracy: 0.9014 - f1_score: 0.9001
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 92: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 0.9012 - f1_score: 0.9005 - val_loss: 0.3042 - val_accuracy: 0.7037 - val_f1_score: 0.6777 - lr: 2.5000e-04
# Epoch 93/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1284 - accuracy: 0.9102 - f1_score: 0.9097
# Epoch 93: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1353 - accuracy: 0.9032 - f1_score: 0.9038 - val_loss: 0.3081 - val_accuracy: 0.6914 - val_f1_score: 0.6656 - lr: 1.2500e-04
# Epoch 94/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1273 - accuracy: 0.9129 - f1_score: 0.9126
# Epoch 94: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1291 - accuracy: 0.9112 - f1_score: 0.9117 - val_loss: 0.3097 - val_accuracy: 0.6914 - val_f1_score: 0.6766 - lr: 1.2500e-04
# Epoch 95/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1184 - accuracy: 0.9185 - f1_score: 0.9177
# Epoch 95: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.9142 - f1_score: 0.9116 - val_loss: 0.3100 - val_accuracy: 0.6883 - val_f1_score: 0.6744 - lr: 1.2500e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1337 - accuracy: 0.9042 - f1_score: 0.9035
# Epoch 96: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1306 - accuracy: 0.9062 - f1_score: 0.9065 - val_loss: 0.3149 - val_accuracy: 0.6883 - val_f1_score: 0.6754 - lr: 1.2500e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1194 - accuracy: 0.9156 - f1_score: 0.9153
# Epoch 97: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1231 - accuracy: 0.9132 - f1_score: 0.9117 - val_loss: 0.3132 - val_accuracy: 0.6883 - val_f1_score: 0.6756 - lr: 1.2500e-04
# Epoch 98/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1145 - accuracy: 0.9219 - f1_score: 0.9214
# Epoch 98: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1173 - accuracy: 0.9172 - f1_score: 0.9172 - val_loss: 0.3123 - val_accuracy: 0.6944 - val_f1_score: 0.6830 - lr: 1.2500e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1200 - accuracy: 0.9167 - f1_score: 0.9163
# Epoch 99: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1198 - accuracy: 0.9162 - f1_score: 0.9155 - val_loss: 0.3124 - val_accuracy: 0.6914 - val_f1_score: 0.6780 - lr: 1.2500e-04
# Epoch 100/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1347 - accuracy: 0.9049 - f1_score: 0.9043
# Epoch 100: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1281 - accuracy: 0.9102 - f1_score: 0.9099 - val_loss: 0.3111 - val_accuracy: 0.6975 - val_f1_score: 0.6822 - lr: 1.2500e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1368 - accuracy: 0.9021 - f1_score: 0.9017
# Epoch 101: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9022 - f1_score: 0.9019 - val_loss: 0.3103 - val_accuracy: 0.6944 - val_f1_score: 0.6800 - lr: 1.2500e-04
# Epoch 102/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1439 - accuracy: 0.9002 - f1_score: 0.8991
# Epoch 102: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1399 - accuracy: 0.9042 - f1_score: 0.9048 - val_loss: 0.3100 - val_accuracy: 0.6914 - val_f1_score: 0.6717 - lr: 1.2500e-04
# Epoch 103/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1416 - accuracy: 0.9002 - f1_score: 0.8997
# Epoch 103: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9052 - f1_score: 0.9047 - val_loss: 0.3186 - val_accuracy: 0.6821 - val_f1_score: 0.6636 - lr: 1.2500e-04
# Epoch 104/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1244 - accuracy: 0.9135 - f1_score: 0.9128
# Epoch 104: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1307 - accuracy: 0.9062 - f1_score: 0.9038 - val_loss: 0.3208 - val_accuracy: 0.6852 - val_f1_score: 0.6660 - lr: 1.2500e-04
# Epoch 105/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1143 - accuracy: 0.9208 - f1_score: 0.9202
# Epoch 105: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1143 - accuracy: 0.9212 - f1_score: 0.9207 - val_loss: 0.3214 - val_accuracy: 0.6821 - val_f1_score: 0.6638 - lr: 1.2500e-04
# Epoch 106/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.1372 - accuracy: 0.8906 - f1_score: 0.8893
# Epoch 106: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1335 - accuracy: 0.9072 - f1_score: 0.9066 - val_loss: 0.3153 - val_accuracy: 0.6883 - val_f1_score: 0.6775 - lr: 1.2500e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1264 - accuracy: 0.9115 - f1_score: 0.9111
# Epoch 107: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1267 - accuracy: 0.9112 - f1_score: 0.9107 - val_loss: 0.3122 - val_accuracy: 0.6852 - val_f1_score: 0.6761 - lr: 1.2500e-04
# Epoch 108/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1354 - accuracy: 0.9051 - f1_score: 0.9040
# Epoch 108: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1325 - accuracy: 0.9072 - f1_score: 0.9056 - val_loss: 0.3092 - val_accuracy: 0.6944 - val_f1_score: 0.6829 - lr: 1.2500e-04
# Epoch 109/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1303 - accuracy: 0.9111 - f1_score: 0.9103
# Epoch 109: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1293 - accuracy: 0.9102 - f1_score: 0.9093 - val_loss: 0.3055 - val_accuracy: 0.6914 - val_f1_score: 0.6789 - lr: 1.2500e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1234 - accuracy: 0.9135 - f1_score: 0.9131
# Epoch 110: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1197 - accuracy: 0.9162 - f1_score: 0.9170 - val_loss: 0.3080 - val_accuracy: 0.6914 - val_f1_score: 0.6789 - lr: 1.2500e-04
# Epoch 111/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1222 - accuracy: 0.9129 - f1_score: 0.9122
# Epoch 111: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1279 - accuracy: 0.9082 - f1_score: 0.9058 - val_loss: 0.3108 - val_accuracy: 0.6883 - val_f1_score: 0.6766 - lr: 1.2500e-04
# Epoch 112/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1283 - accuracy: 0.9107 - f1_score: 0.9098
# Epoch 112: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 112: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1284 - accuracy: 0.9102 - f1_score: 0.9087 - val_loss: 0.3096 - val_accuracy: 0.6883 - val_f1_score: 0.6766 - lr: 1.2500e-04
# Epoch 113/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1298 - accuracy: 0.9099 - f1_score: 0.9086
# Epoch 113: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9122 - f1_score: 0.9119 - val_loss: 0.3098 - val_accuracy: 0.6914 - val_f1_score: 0.6789 - lr: 6.2500e-05
# Epoch 114/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1311 - accuracy: 0.9085 - f1_score: 0.9079
# Epoch 114: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1282 - accuracy: 0.9102 - f1_score: 0.9110 - val_loss: 0.3089 - val_accuracy: 0.6914 - val_f1_score: 0.6789 - lr: 6.2500e-05
# Epoch 115/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1285 - accuracy: 0.9074 - f1_score: 0.9067
# Epoch 115: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1318 - accuracy: 0.9052 - f1_score: 0.9030 - val_loss: 0.3093 - val_accuracy: 0.6883 - val_f1_score: 0.6738 - lr: 6.2500e-05
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1152 - accuracy: 0.9187 - f1_score: 0.9183
# Epoch 116: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1215 - accuracy: 0.9142 - f1_score: 0.9112 - val_loss: 0.3083 - val_accuracy: 0.6914 - val_f1_score: 0.6759 - lr: 6.2500e-05
# Epoch 117/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1200 - accuracy: 0.9174 - f1_score: 0.9172
# Epoch 117: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1215 - accuracy: 0.9152 - f1_score: 0.9145 - val_loss: 0.3097 - val_accuracy: 0.6914 - val_f1_score: 0.6759 - lr: 6.2500e-05
# Epoch 118/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9122 - f1_score: 0.9113
# Epoch 118: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9122 - f1_score: 0.9113 - val_loss: 0.3097 - val_accuracy: 0.6914 - val_f1_score: 0.6759 - lr: 6.2500e-05
# Epoch 119/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9112 - f1_score: 0.9106
# Epoch 119: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1246 - accuracy: 0.9112 - f1_score: 0.9106 - val_loss: 0.3098 - val_accuracy: 0.6883 - val_f1_score: 0.6738 - lr: 6.2500e-05
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1238 - accuracy: 0.9125 - f1_score: 0.9116
# Epoch 120: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1241 - accuracy: 0.9122 - f1_score: 0.9112 - val_loss: 0.3107 - val_accuracy: 0.6975 - val_f1_score: 0.6805 - lr: 6.2500e-05
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1341 - accuracy: 0.9052 - f1_score: 0.9035
# Epoch 121: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1310 - accuracy: 0.9072 - f1_score: 0.9065 - val_loss: 0.3104 - val_accuracy: 0.6914 - val_f1_score: 0.6705 - lr: 6.2500e-05
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1125 - accuracy: 0.9177 - f1_score: 0.9174
# Epoch 122: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1119 - accuracy: 0.9172 - f1_score: 0.9165 - val_loss: 0.3116 - val_accuracy: 0.6914 - val_f1_score: 0.6691 - lr: 6.2500e-05
# Epoch 123/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1466 - accuracy: 0.8973 - f1_score: 0.8961
# Epoch 123: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 0.8982 - f1_score: 0.8978 - val_loss: 0.3133 - val_accuracy: 0.6821 - val_f1_score: 0.6559 - lr: 6.2500e-05
# Epoch 124/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1342 - accuracy: 0.9049 - f1_score: 0.9046
# Epoch 124: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1332 - accuracy: 0.9052 - f1_score: 0.9053 - val_loss: 0.3139 - val_accuracy: 0.6852 - val_f1_score: 0.6564 - lr: 6.2500e-05
# Epoch 125/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1386 - accuracy: 0.9040 - f1_score: 0.9031
# Epoch 125: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9102 - f1_score: 0.9103 - val_loss: 0.3140 - val_accuracy: 0.6821 - val_f1_score: 0.6584 - lr: 6.2500e-05
# Epoch 126/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1243 - accuracy: 0.9096 - f1_score: 0.9093
# Epoch 126: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1205 - accuracy: 0.9132 - f1_score: 0.9137 - val_loss: 0.3135 - val_accuracy: 0.6883 - val_f1_score: 0.6649 - lr: 6.2500e-05
# Epoch 127/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9132 - f1_score: 0.9127
# Epoch 127: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 0.9132 - f1_score: 0.9127 - val_loss: 0.3111 - val_accuracy: 0.6852 - val_f1_score: 0.6636 - lr: 6.2500e-05
# Epoch 128/10000
#  1/16 [>.............................] - ETA: 0s - loss: 0.2098 - accuracy: 0.8750 - f1_score: 0.8719
# Epoch 128: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1413 - accuracy: 0.9032 - f1_score: 0.9031 - val_loss: 0.3120 - val_accuracy: 0.6883 - val_f1_score: 0.6658 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1144 - accuracy: 0.9208 - f1_score: 0.9202
# Epoch 129: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1142 - accuracy: 0.9212 - f1_score: 0.9207 - val_loss: 0.3103 - val_accuracy: 0.6914 - val_f1_score: 0.6696 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1416 - accuracy: 0.9021 - f1_score: 0.9013
# Epoch 130: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1367 - accuracy: 0.9052 - f1_score: 0.9060 - val_loss: 0.3100 - val_accuracy: 0.6914 - val_f1_score: 0.6710 - lr: 6.2500e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1244 - accuracy: 0.9115 - f1_score: 0.9108
# Epoch 131: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1230 - accuracy: 0.9122 - f1_score: 0.9118 - val_loss: 0.3101 - val_accuracy: 0.6883 - val_f1_score: 0.6674 - lr: 6.2500e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1282 - accuracy: 0.9052 - f1_score: 0.9047Restoring model weights from the end of the best epoch: 32.
#
# Epoch 132: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 132: val_f1_score did not improve from 0.71901
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1265 - accuracy: 0.9062 - f1_score: 0.9062 - val_loss: 0.3077 - val_accuracy: 0.6914 - val_f1_score: 0.6717 - lr: 6.2500e-05
# Epoch 132: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               22016
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 200610 (783.63 KB)
# Trainable params: 198626 (775.88 KB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 830us/step
# 0.7253086419753086

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7253086419753086
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.48      0.59      0.53        85
#            0       0.84      0.77      0.81       239
#
#     accuracy                           0.73       324
#    macro avg       0.66      0.68      0.67       324
# weighted avg       0.75      0.73      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 235 chiếm khoảng 72.53086419753086% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 50 chiếm khoảng 58.82352941176471% so với thực tế
