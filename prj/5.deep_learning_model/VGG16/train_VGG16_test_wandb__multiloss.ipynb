# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#
#  global_average_pooling1d (  (None, 1024)              0
#  GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19622530 (74.85 MB)
# Trainable params: 19622530 (74.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Set data order
data_order = 8

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.5100 - f1_score: 0.3651
# Epoch 1: val_f1_score improved from -inf to 0.45949, saving model to best_model.hdf5
# 16/16 [==============================] - 204s 6s/step - loss: 0.5034 - accuracy: 0.5100 - f1_score: 0.3651 - val_loss: 0.3741 - val_accuracy: 0.6914 - val_f1_score: 0.4595 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.5529 - f1_score: 0.5042
# Epoch 2: val_f1_score improved from 0.45949 to 0.48742, saving model to best_model.hdf5
# 16/16 [==============================] - 65s 4s/step - loss: 0.4934 - accuracy: 0.5529 - f1_score: 0.5042 - val_loss: 0.3677 - val_accuracy: 0.5957 - val_f1_score: 0.4874 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4222 - accuracy: 0.6627 - f1_score: 0.6526
# Epoch 3: val_f1_score improved from 0.48742 to 0.59628, saving model to best_model.hdf5
# 16/16 [==============================] - 64s 4s/step - loss: 0.4222 - accuracy: 0.6627 - f1_score: 0.6526 - val_loss: 0.3331 - val_accuracy: 0.6790 - val_f1_score: 0.5963 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.6936 - f1_score: 0.6686
# Epoch 4: val_f1_score did not improve from 0.59628
# 16/16 [==============================] - 63s 4s/step - loss: 0.3952 - accuracy: 0.6936 - f1_score: 0.6686 - val_loss: 0.3313 - val_accuracy: 0.7315 - val_f1_score: 0.5192 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.7615 - f1_score: 0.7529
# Epoch 5: val_f1_score did not improve from 0.59628
# 16/16 [==============================] - 66s 4s/step - loss: 0.3262 - accuracy: 0.7615 - f1_score: 0.7529 - val_loss: 0.3144 - val_accuracy: 0.7377 - val_f1_score: 0.5877 - lr: 1.0000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.7974 - f1_score: 0.7965
# Epoch 6: val_f1_score did not improve from 0.59628
# 16/16 [==============================] - 61s 4s/step - loss: 0.2792 - accuracy: 0.7974 - f1_score: 0.7965 - val_loss: 0.3040 - val_accuracy: 0.7315 - val_f1_score: 0.5777 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.8204 - f1_score: 0.8171
# Epoch 7: val_f1_score improved from 0.59628 to 0.67598, saving model to best_model.hdf5
# 16/16 [==============================] - 69s 4s/step - loss: 0.2480 - accuracy: 0.8204 - f1_score: 0.8171 - val_loss: 0.3208 - val_accuracy: 0.6914 - val_f1_score: 0.6760 - lr: 1.0000e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.8194 - f1_score: 0.8161
# Epoch 8: val_f1_score did not improve from 0.67598
# 16/16 [==============================] - 65s 4s/step - loss: 0.2355 - accuracy: 0.8194 - f1_score: 0.8161 - val_loss: 0.3241 - val_accuracy: 0.7068 - val_f1_score: 0.6634 - lr: 1.0000e-04
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.8383 - f1_score: 0.8373
# Epoch 9: val_f1_score improved from 0.67598 to 0.68375, saving model to best_model.hdf5
# 16/16 [==============================] - 65s 4s/step - loss: 0.2152 - accuracy: 0.8383 - f1_score: 0.8373 - val_loss: 0.3016 - val_accuracy: 0.7253 - val_f1_score: 0.6837 - lr: 1.0000e-04
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.8463 - f1_score: 0.8438
# Epoch 10: val_f1_score did not improve from 0.68375
# 16/16 [==============================] - 67s 4s/step - loss: 0.2070 - accuracy: 0.8463 - f1_score: 0.8438 - val_loss: 0.3228 - val_accuracy: 0.7006 - val_f1_score: 0.6506 - lr: 1.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.8892 - f1_score: 0.8882
# Epoch 11: val_f1_score improved from 0.68375 to 0.71215, saving model to best_model.hdf5
# 16/16 [==============================] - 65s 4s/step - loss: 0.1549 - accuracy: 0.8892 - f1_score: 0.8882 - val_loss: 0.3252 - val_accuracy: 0.7130 - val_f1_score: 0.7121 - lr: 1.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.8842 - f1_score: 0.8818
# Epoch 12: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 62s 4s/step - loss: 0.1558 - accuracy: 0.8842 - f1_score: 0.8818 - val_loss: 0.3358 - val_accuracy: 0.7037 - val_f1_score: 0.6564 - lr: 1.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9002 - f1_score: 0.8983
# Epoch 13: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 65s 4s/step - loss: 0.1403 - accuracy: 0.9002 - f1_score: 0.8983 - val_loss: 0.3407 - val_accuracy: 0.7377 - val_f1_score: 0.6522 - lr: 1.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.8683 - f1_score: 0.8628
# Epoch 14: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 67s 4s/step - loss: 0.1810 - accuracy: 0.8683 - f1_score: 0.8628 - val_loss: 0.3005 - val_accuracy: 0.7377 - val_f1_score: 0.5924 - lr: 1.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.8982 - f1_score: 0.8981
# Epoch 15: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 60s 4s/step - loss: 0.1403 - accuracy: 0.8982 - f1_score: 0.8981 - val_loss: 0.3292 - val_accuracy: 0.7160 - val_f1_score: 0.7098 - lr: 1.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9271 - f1_score: 0.9245
# Epoch 16: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 65s 4s/step - loss: 0.1097 - accuracy: 0.9271 - f1_score: 0.9245 - val_loss: 0.3110 - val_accuracy: 0.7284 - val_f1_score: 0.7033 - lr: 1.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9202 - f1_score: 0.9194
# Epoch 17: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.1065 - accuracy: 0.9202 - f1_score: 0.9194 - val_loss: 0.3252 - val_accuracy: 0.7160 - val_f1_score: 0.6991 - lr: 1.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9391 - f1_score: 0.9396
# Epoch 18: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0889 - accuracy: 0.9391 - f1_score: 0.9396 - val_loss: 0.3250 - val_accuracy: 0.6914 - val_f1_score: 0.6887 - lr: 1.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9381 - f1_score: 0.9373
# Epoch 19: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0870 - accuracy: 0.9381 - f1_score: 0.9373 - val_loss: 0.3541 - val_accuracy: 0.7160 - val_f1_score: 0.6817 - lr: 1.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9461 - f1_score: 0.9441
# Epoch 20: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 64s 4s/step - loss: 0.0806 - accuracy: 0.9461 - f1_score: 0.9441 - val_loss: 0.3612 - val_accuracy: 0.7068 - val_f1_score: 0.6612 - lr: 1.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9461 - f1_score: 0.9449
# Epoch 21: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 64s 4s/step - loss: 0.0789 - accuracy: 0.9461 - f1_score: 0.9449 - val_loss: 0.3647 - val_accuracy: 0.7191 - val_f1_score: 0.6485 - lr: 1.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9251 - f1_score: 0.9206
# Epoch 22: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 62s 4s/step - loss: 0.1040 - accuracy: 0.9251 - f1_score: 0.9206 - val_loss: 0.3543 - val_accuracy: 0.7284 - val_f1_score: 0.6489 - lr: 1.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9381 - f1_score: 0.9355
# Epoch 23: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 61s 4s/step - loss: 0.0849 - accuracy: 0.9381 - f1_score: 0.9355 - val_loss: 0.3374 - val_accuracy: 0.7037 - val_f1_score: 0.7074 - lr: 1.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9501 - f1_score: 0.9502
# Epoch 24: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.0694 - accuracy: 0.9501 - f1_score: 0.9502 - val_loss: 0.3497 - val_accuracy: 0.7284 - val_f1_score: 0.6643 - lr: 1.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9601 - f1_score: 0.9584
# Epoch 25: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 65s 4s/step - loss: 0.0573 - accuracy: 0.9601 - f1_score: 0.9584 - val_loss: 0.3815 - val_accuracy: 0.7222 - val_f1_score: 0.6520 - lr: 1.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9701 - f1_score: 0.9688
# Epoch 26: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 64s 4s/step - loss: 0.0434 - accuracy: 0.9701 - f1_score: 0.9688 - val_loss: 0.3869 - val_accuracy: 0.7160 - val_f1_score: 0.6314 - lr: 1.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9760 - f1_score: 0.9755
# Epoch 27: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.0387 - accuracy: 0.9760 - f1_score: 0.9755 - val_loss: 0.3687 - val_accuracy: 0.6883 - val_f1_score: 0.6616 - lr: 1.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9800 - f1_score: 0.9787
# Epoch 28: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 64s 4s/step - loss: 0.0342 - accuracy: 0.9800 - f1_score: 0.9787 - val_loss: 0.3333 - val_accuracy: 0.7438 - val_f1_score: 0.6903 - lr: 1.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9840 - f1_score: 0.9843
# Epoch 29: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 67s 4s/step - loss: 0.0263 - accuracy: 0.9840 - f1_score: 0.9843 - val_loss: 0.3616 - val_accuracy: 0.7315 - val_f1_score: 0.7057 - lr: 1.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9750 - f1_score: 0.9747
# Epoch 30: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 64s 4s/step - loss: 0.0346 - accuracy: 0.9750 - f1_score: 0.9747 - val_loss: 0.3971 - val_accuracy: 0.7068 - val_f1_score: 0.6508 - lr: 1.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9850 - f1_score: 0.9840
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 31: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 62s 4s/step - loss: 0.0248 - accuracy: 0.9850 - f1_score: 0.9840 - val_loss: 0.4146 - val_accuracy: 0.7068 - val_f1_score: 0.6473 - lr: 1.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9770 - f1_score: 0.9762
# Epoch 32: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.0299 - accuracy: 0.9770 - f1_score: 0.9762 - val_loss: 0.3882 - val_accuracy: 0.7284 - val_f1_score: 0.6571 - lr: 5.0000e-05
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9850 - f1_score: 0.9844
# Epoch 33: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0221 - accuracy: 0.9850 - f1_score: 0.9844 - val_loss: 0.4167 - val_accuracy: 0.7284 - val_f1_score: 0.6341 - lr: 5.0000e-05
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9830 - f1_score: 0.9825
# Epoch 34: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0216 - accuracy: 0.9830 - f1_score: 0.9825 - val_loss: 0.3695 - val_accuracy: 0.7500 - val_f1_score: 0.6956 - lr: 5.0000e-05
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9930 - f1_score: 0.9931
# Epoch 35: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0123 - accuracy: 0.9930 - f1_score: 0.9931 - val_loss: 0.4103 - val_accuracy: 0.7037 - val_f1_score: 0.6451 - lr: 5.0000e-05
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 36: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.0070 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.3804 - val_accuracy: 0.7315 - val_f1_score: 0.7045 - lr: 5.0000e-05
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9960 - f1_score: 0.9961
# Epoch 37: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 60s 4s/step - loss: 0.0062 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3974 - val_accuracy: 0.7284 - val_f1_score: 0.6795 - lr: 5.0000e-05
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9910 - f1_score: 0.9910
# Epoch 38: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 63s 4s/step - loss: 0.0107 - accuracy: 0.9910 - f1_score: 0.9910 - val_loss: 0.4033 - val_accuracy: 0.7222 - val_f1_score: 0.6806 - lr: 5.0000e-05
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9960 - f1_score: 0.9961
# Epoch 39: val_f1_score did not improve from 0.71215
# 16/16 [==============================] - 66s 4s/step - loss: 0.0070 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.4044 - val_accuracy: 0.7099 - val_f1_score: 0.6709 - lr: 5.0000e-05
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 40: val_f1_score did not improve from 0.71215
# 16/16 [==============================] -