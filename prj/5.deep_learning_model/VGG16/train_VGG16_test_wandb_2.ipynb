# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#
#  global_average_pooling1d (  (None, 1024)              0
#  GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19622530 (74.85 MB)
# Trainable params: 19622530 (74.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Set data order
data_order = 8

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.5020 - f1_score: 0.3451
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.hdf5
# 16/16 [==============================] - 66s 3s/step - loss: 0.0602 - accuracy: 0.5020 - f1_score: 0.3451 - val_loss: 0.0421 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.5579 - f1_score: 0.4694
# Epoch 2: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 42s 3s/step - loss: 0.0597 - accuracy: 0.5579 - f1_score: 0.4694 - val_loss: 0.0406 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.5838 - f1_score: 0.5002
# Epoch 3: val_f1_score improved from 0.42467 to 0.45879, saving model to best_model.hdf5
# 16/16 [==============================] - 43s 3s/step - loss: 0.0583 - accuracy: 0.5838 - f1_score: 0.5002 - val_loss: 0.0378 - val_accuracy: 0.7222 - val_f1_score: 0.4588 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.7046 - f1_score: 0.6902
# Epoch 4: val_f1_score did not improve from 0.45879
# 16/16 [==============================] - 52s 3s/step - loss: 0.0507 - accuracy: 0.7046 - f1_score: 0.6902 - val_loss: 0.0578 - val_accuracy: 0.3796 - val_f1_score: 0.3397 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.7246 - f1_score: 0.7083
# Epoch 5: val_f1_score improved from 0.45879 to 0.66214, saving model to best_model.hdf5
# 16/16 [==============================] - 52s 3s/step - loss: 0.0461 - accuracy: 0.7246 - f1_score: 0.7083 - val_loss: 0.0418 - val_accuracy: 0.6667 - val_f1_score: 0.6621 - lr: 1.0000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.8054 - f1_score: 0.7968
# Epoch 6: val_f1_score improved from 0.66214 to 0.70324, saving model to best_model.hdf5
# 16/16 [==============================] - 68s 4s/step - loss: 0.0391 - accuracy: 0.8054 - f1_score: 0.7968 - val_loss: 0.0505 - val_accuracy: 0.6883 - val_f1_score: 0.7032 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.8184 - f1_score: 0.8154
# Epoch 7: val_f1_score did not improve from 0.70324
# 16/16 [==============================] - 59s 4s/step - loss: 0.0378 - accuracy: 0.8184 - f1_score: 0.8154 - val_loss: 0.0423 - val_accuracy: 0.6944 - val_f1_score: 0.6754 - lr: 1.0000e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.8463 - f1_score: 0.8437
# Epoch 8: val_f1_score did not improve from 0.70324
# 16/16 [==============================] - 64s 4s/step - loss: 0.0317 - accuracy: 0.8463 - f1_score: 0.8437 - val_loss: 0.0420 - val_accuracy: 0.7037 - val_f1_score: 0.6559 - lr: 1.0000e-04
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.8882 - f1_score: 0.8885
# Epoch 9: val_f1_score did not improve from 0.70324
# 16/16 [==============================] - 65s 4s/step - loss: 0.0251 - accuracy: 0.8882 - f1_score: 0.8885 - val_loss: 0.0477 - val_accuracy: 0.7315 - val_f1_score: 0.6842 - lr: 1.0000e-04
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.8892 - f1_score: 0.8874
# Epoch 10: val_f1_score did not improve from 0.70324
# 16/16 [==============================] - 78s 5s/step - loss: 0.0260 - accuracy: 0.8892 - f1_score: 0.8874 - val_loss: 0.0472 - val_accuracy: 0.7222 - val_f1_score: 0.6598 - lr: 1.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9152 - f1_score: 0.9139
# Epoch 11: val_f1_score did not improve from 0.70324
# 16/16 [==============================] - 65s 4s/step - loss: 0.0193 - accuracy: 0.9152 - f1_score: 0.9139 - val_loss: 0.0616 - val_accuracy: 0.6543 - val_f1_score: 0.6699 - lr: 1.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9411 - f1_score: 0.9403
# Epoch 12: val_f1_score improved from 0.70324 to 0.70872, saving model to best_model.hdf5
# 16/16 [==============================] - 67s 4s/step - loss: 0.0161 - accuracy: 0.9411 - f1_score: 0.9403 - val_loss: 0.0787 - val_accuracy: 0.7006 - val_f1_score: 0.7087 - lr: 1.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9461 - f1_score: 0.9427
# Epoch 13: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0136 - accuracy: 0.9461 - f1_score: 0.9427 - val_loss: 0.0887 - val_accuracy: 0.7346 - val_f1_score: 0.6493 - lr: 1.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.8802 - f1_score: 0.8751
# Epoch 14: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 62s 4s/step - loss: 0.0263 - accuracy: 0.8802 - f1_score: 0.8751 - val_loss: 0.0454 - val_accuracy: 0.7006 - val_f1_score: 0.6922 - lr: 1.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9341 - f1_score: 0.9310
# Epoch 15: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 0.0168 - accuracy: 0.9341 - f1_score: 0.9310 - val_loss: 0.0559 - val_accuracy: 0.7222 - val_f1_score: 0.6852 - lr: 1.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9441 - f1_score: 0.9441
# Epoch 16: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0133 - accuracy: 0.9441 - f1_score: 0.9441 - val_loss: 0.0735 - val_accuracy: 0.7346 - val_f1_score: 0.6743 - lr: 1.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9551 - f1_score: 0.9550
# Epoch 17: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 62s 4s/step - loss: 0.0101 - accuracy: 0.9551 - f1_score: 0.9550 - val_loss: 0.0779 - val_accuracy: 0.7346 - val_f1_score: 0.6904 - lr: 1.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9790 - f1_score: 0.9787
# Epoch 18: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 62s 4s/step - loss: 0.0062 - accuracy: 0.9790 - f1_score: 0.9787 - val_loss: 0.1004 - val_accuracy: 0.6944 - val_f1_score: 0.6798 - lr: 1.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9770 - f1_score: 0.9761
# Epoch 19: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0051 - accuracy: 0.9770 - f1_score: 0.9761 - val_loss: 0.1028 - val_accuracy: 0.7315 - val_f1_score: 0.6829 - lr: 1.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9830 - f1_score: 0.9832
# Epoch 20: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0041 - accuracy: 0.9830 - f1_score: 0.9832 - val_loss: 0.1179 - val_accuracy: 0.7191 - val_f1_score: 0.6849 - lr: 1.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9880 - f1_score: 0.9864
# Epoch 21: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 63s 4s/step - loss: 0.0034 - accuracy: 0.9880 - f1_score: 0.9864 - val_loss: 0.1436 - val_accuracy: 0.6667 - val_f1_score: 0.6731 - lr: 1.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9561 - f1_score: 0.9566
# Epoch 22: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 0.0104 - accuracy: 0.9561 - f1_score: 0.9566 - val_loss: 0.0818 - val_accuracy: 0.7315 - val_f1_score: 0.7043 - lr: 1.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9880 - f1_score: 0.9882
# Epoch 23: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0028 - accuracy: 0.9880 - f1_score: 0.9882 - val_loss: 0.1675 - val_accuracy: 0.7315 - val_f1_score: 0.6998 - lr: 1.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9631 - f1_score: 0.9621
# Epoch 24: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 72s 4s/step - loss: 0.0149 - accuracy: 0.9631 - f1_score: 0.9621 - val_loss: 0.0489 - val_accuracy: 0.6975 - val_f1_score: 0.6776 - lr: 1.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9481 - f1_score: 0.9462
# Epoch 25: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 62s 4s/step - loss: 0.0149 - accuracy: 0.9481 - f1_score: 0.9462 - val_loss: 0.0769 - val_accuracy: 0.7191 - val_f1_score: 0.7029 - lr: 1.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9910 - f1_score: 0.9910
# Epoch 26: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 0.0024 - accuracy: 0.9910 - f1_score: 0.9910 - val_loss: 0.1734 - val_accuracy: 0.7130 - val_f1_score: 0.6646 - lr: 1.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9900 - f1_score: 0.9883
# Epoch 27: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 0.0030 - accuracy: 0.9900 - f1_score: 0.9883 - val_loss: 0.2000 - val_accuracy: 0.7191 - val_f1_score: 0.6563 - lr: 1.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9421 - f1_score: 0.9411
# Epoch 28: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 63s 4s/step - loss: 0.0149 - accuracy: 0.9421 - f1_score: 0.9411 - val_loss: 0.0491 - val_accuracy: 0.7253 - val_f1_score: 0.6901 - lr: 1.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9701 - f1_score: 0.9703
# Epoch 29: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 69s 4s/step - loss: 0.0094 - accuracy: 0.9701 - f1_score: 0.9703 - val_loss: 0.1135 - val_accuracy: 0.7068 - val_f1_score: 0.6527 - lr: 1.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9940 - f1_score: 0.9941
# Epoch 30: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 61s 4s/step - loss: 0.0018 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.1740 - val_accuracy: 0.7037 - val_f1_score: 0.6496 - lr: 1.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9900 - f1_score: 0.9895
# Epoch 31: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 0.0019 - accuracy: 0.9900 - f1_score: 0.9895 - val_loss: 0.1827 - val_accuracy: 0.6883 - val_f1_score: 0.6485 - lr: 1.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9930 - f1_score: 0.9930
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 32: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 0.0027 - accuracy: 0.9930 - f1_score: 0.9930 - val_loss: 0.1949 - val_accuracy: 0.7191 - val_f1_score: 0.6539 - lr: 1.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9760 - f1_score: 0.9754
# Epoch 33: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 0.0059 - accuracy: 0.9760 - f1_score: 0.9754 - val_loss: 0.1526 - val_accuracy: 0.7160 - val_f1_score: 0.6824 - lr: 5.0000e-05
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9930 - f1_score: 0.9931
# Epoch 34: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 0.0017 - accuracy: 0.9930 - f1_score: 0.9931 - val_loss: 0.1302 - val_accuracy: 0.7160 - val_f1_score: 0.6794 - lr: 5.0000e-05
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.9865e-04 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 35: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 63s 4s/step - loss: 5.9865e-04 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.1346 - val_accuracy: 0.7253 - val_f1_score: 0.6888 - lr: 5.0000e-05
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.5634e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 36: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 1.5634e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.7253 - val_f1_score: 0.6951 - lr: 5.0000e-05
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 8.9163e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 37: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 64s 4s/step - loss: 8.9163e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.7315 - val_f1_score: 0.6999 - lr: 5.0000e-05
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.6157e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 38: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 5.6157e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1643 - val_accuracy: 0.7284 - val_f1_score: 0.6978 - lr: 5.0000e-05
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.0665e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 39: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 4.0665e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2737e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 40: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 63s 4s/step - loss: 3.2737e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1742 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.7396e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 41: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 60s 4s/step - loss: 2.7396e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.2937e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 42: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 2.2937e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.0130e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 43: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 68s 4s/step - loss: 2.0130e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1850 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.7587e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 44: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 66s 4s/step - loss: 1.7587e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.7315 - val_f1_score: 0.7015 - lr: 5.0000e-05
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.5899e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 45: val_f1_score did not improve from 0.70872
# 16/16 [==============================] - 65s 4s/step - loss: 1.5899e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0