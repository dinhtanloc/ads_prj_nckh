# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0
    f1_weight = 0.2
    dice_weight = 0.8

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#
#  global_average_pooling1d_1   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Set data order
data_order = 8

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5020 - f1_score: 0.3343
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.hdf5
# 16/16 [==============================] - 27s 2s/step - loss: 0.6916 - accuracy: 0.5020 - f1_score: 0.3343 - val_loss: 0.4729 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6691 - accuracy: 0.5289 - f1_score: 0.4102
# Epoch 2: val_f1_score improved from 0.42467 to 0.46404, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.6691 - accuracy: 0.5289 - f1_score: 0.4102 - val_loss: 0.3828 - val_accuracy: 0.6821 - val_f1_score: 0.4640 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.6297 - f1_score: 0.5913
# Epoch 3: val_f1_score improved from 0.46404 to 0.50978, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.5367 - accuracy: 0.6297 - f1_score: 0.5913 - val_loss: 0.4893 - val_accuracy: 0.5247 - val_f1_score: 0.5098 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.6786 - f1_score: 0.6649
# Epoch 4: val_f1_score improved from 0.50978 to 0.61887, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.4483 - accuracy: 0.6786 - f1_score: 0.6649 - val_loss: 0.3284 - val_accuracy: 0.7037 - val_f1_score: 0.6189 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.7076 - f1_score: 0.6939
# Epoch 5: val_f1_score improved from 0.61887 to 0.64136, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.4216 - accuracy: 0.7076 - f1_score: 0.6939 - val_loss: 0.4019 - val_accuracy: 0.6080 - val_f1_score: 0.6414 - lr: 1.0000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.7555 - f1_score: 0.7512
# Epoch 6: val_f1_score improved from 0.64136 to 0.66031, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.3452 - accuracy: 0.7555 - f1_score: 0.7512 - val_loss: 0.3606 - val_accuracy: 0.6512 - val_f1_score: 0.6603 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.7884 - f1_score: 0.7848
# Epoch 7: val_f1_score did not improve from 0.66031
# 16/16 [==============================] - 25s 2s/step - loss: 0.2906 - accuracy: 0.7884 - f1_score: 0.7848 - val_loss: 0.3317 - val_accuracy: 0.6821 - val_f1_score: 0.6445 - lr: 1.0000e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.7994 - f1_score: 0.7974
# Epoch 8: val_f1_score did not improve from 0.66031
# 16/16 [==============================] - 24s 1s/step - loss: 0.2801 - accuracy: 0.7994 - f1_score: 0.7974 - val_loss: 0.3293 - val_accuracy: 0.6975 - val_f1_score: 0.6190 - lr: 1.0000e-04
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.7395 - f1_score: 0.7210
# Epoch 9: val_f1_score did not improve from 0.66031
# 16/16 [==============================] - 24s 2s/step - loss: 0.3696 - accuracy: 0.7395 - f1_score: 0.7210 - val_loss: 0.4966 - val_accuracy: 0.5062 - val_f1_score: 0.5765 - lr: 1.0000e-04
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.7455 - f1_score: 0.7344
# Epoch 10: val_f1_score improved from 0.66031 to 0.68551, saving model to best_model.hdf5
# 16/16 [==============================] - 26s 2s/step - loss: 0.3603 - accuracy: 0.7455 - f1_score: 0.7344 - val_loss: 0.3283 - val_accuracy: 0.6790 - val_f1_score: 0.6855 - lr: 1.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.7804 - f1_score: 0.7756
# Epoch 11: val_f1_score did not improve from 0.68551
# 16/16 [==============================] - 23s 1s/step - loss: 0.3064 - accuracy: 0.7804 - f1_score: 0.7756 - val_loss: 0.3260 - val_accuracy: 0.6883 - val_f1_score: 0.6801 - lr: 1.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.8244 - f1_score: 0.8212
# Epoch 12: val_f1_score improved from 0.68551 to 0.69634, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.2470 - accuracy: 0.8244 - f1_score: 0.8212 - val_loss: 0.2841 - val_accuracy: 0.7346 - val_f1_score: 0.6963 - lr: 1.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.7994 - f1_score: 0.7981
# Epoch 13: val_f1_score did not improve from 0.69634
# 16/16 [==============================] - 26s 2s/step - loss: 0.2772 - accuracy: 0.7994 - f1_score: 0.7981 - val_loss: 0.3173 - val_accuracy: 0.6944 - val_f1_score: 0.6894 - lr: 1.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.8204 - f1_score: 0.8183
# Epoch 14: val_f1_score did not improve from 0.69634
# 16/16 [==============================] - 25s 2s/step - loss: 0.2501 - accuracy: 0.8204 - f1_score: 0.8183 - val_loss: 0.4604 - val_accuracy: 0.5432 - val_f1_score: 0.5196 - lr: 1.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.7285 - f1_score: 0.7137
# Epoch 15: val_f1_score did not improve from 0.69634
# 16/16 [==============================] - 26s 2s/step - loss: 0.3776 - accuracy: 0.7285 - f1_score: 0.7137 - val_loss: 0.3271 - val_accuracy: 0.6883 - val_f1_score: 0.6757 - lr: 1.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.8124 - f1_score: 0.8097
# Epoch 16: val_f1_score did not improve from 0.69634
# 16/16 [==============================] - 26s 2s/step - loss: 0.2626 - accuracy: 0.8124 - f1_score: 0.8097 - val_loss: 0.3320 - val_accuracy: 0.6759 - val_f1_score: 0.6755 - lr: 1.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.8353 - f1_score: 0.8347
# Epoch 17: val_f1_score improved from 0.69634 to 0.69856, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.2322 - accuracy: 0.8353 - f1_score: 0.8347 - val_loss: 0.3167 - val_accuracy: 0.6883 - val_f1_score: 0.6986 - lr: 1.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.8184 - f1_score: 0.8147
# Epoch 18: val_f1_score improved from 0.69856 to 0.71469, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.2474 - accuracy: 0.8184 - f1_score: 0.8147 - val_loss: 0.2694 - val_accuracy: 0.7500 - val_f1_score: 0.7147 - lr: 1.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.7844 - f1_score: 0.7750
# Epoch 19: val_f1_score did not improve from 0.71469
# 16/16 [==============================] - 23s 1s/step - loss: 0.3027 - accuracy: 0.7844 - f1_score: 0.7750 - val_loss: 0.4518 - val_accuracy: 0.5463 - val_f1_score: 0.5310 - lr: 1.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.7874 - f1_score: 0.7816
# Epoch 20: val_f1_score did not improve from 0.71469
# 16/16 [==============================] - 24s 1s/step - loss: 0.2973 - accuracy: 0.7874 - f1_score: 0.7816 - val_loss: 0.2867 - val_accuracy: 0.7315 - val_f1_score: 0.7095 - lr: 1.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.7984 - f1_score: 0.7924
# Epoch 21: val_f1_score did not improve from 0.71469
# 16/16 [==============================] - 23s 1s/step - loss: 0.2804 - accuracy: 0.7984 - f1_score: 0.7924 - val_loss: 0.2942 - val_accuracy: 0.7346 - val_f1_score: 0.6527 - lr: 1.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.7894 - f1_score: 0.7844
# Epoch 22: val_f1_score did not improve from 0.71469
# 16/16 [==============================] - 24s 1s/step - loss: 0.2918 - accuracy: 0.7894 - f1_score: 0.7844 - val_loss: 0.3719 - val_accuracy: 0.6358 - val_f1_score: 0.6649 - lr: 1.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.7754 - f1_score: 0.7679
# Epoch 23: val_f1_score improved from 0.71469 to 0.72141, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 1s/step - loss: 0.3130 - accuracy: 0.7754 - f1_score: 0.7679 - val_loss: 0.2782 - val_accuracy: 0.7346 - val_f1_score: 0.7214 - lr: 1.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.8134 - f1_score: 0.8107
# Epoch 24: val_f1_score did not improve from 0.72141
# 16/16 [==============================] - 23s 1s/step - loss: 0.2593 - accuracy: 0.8134 - f1_score: 0.8107 - val_loss: 0.3154 - val_accuracy: 0.6914 - val_f1_score: 0.7089 - lr: 1.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8224 - f1_score: 0.8144
# Epoch 25: val_f1_score did not improve from 0.72141
# 16/16 [==============================] - 24s 1s/step - loss: 0.2496 - accuracy: 0.8224 - f1_score: 0.8144 - val_loss: 0.2633 - val_accuracy: 0.7531 - val_f1_score: 0.7147 - lr: 1.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8114 - f1_score: 0.8106
# Epoch 26: val_f1_score did not improve from 0.72141
# 16/16 [==============================] - 24s 1s/step - loss: 0.2637 - accuracy: 0.8114 - f1_score: 0.8106 - val_loss: 0.4045 - val_accuracy: 0.6019 - val_f1_score: 0.6469 - lr: 1.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3260 - accuracy: 0.7665 - f1_score: 0.7590
# Epoch 27: val_f1_score improved from 0.72141 to 0.73552, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.3260 - accuracy: 0.7665 - f1_score: 0.7590 - val_loss: 0.2661 - val_accuracy: 0.7438 - val_f1_score: 0.7355 - lr: 1.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.7864 - f1_score: 0.7815
# Epoch 28: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 23s 1s/step - loss: 0.2931 - accuracy: 0.7864 - f1_score: 0.7815 - val_loss: 0.4546 - val_accuracy: 0.5494 - val_f1_score: 0.6095 - lr: 1.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.7505 - f1_score: 0.7423
# Epoch 29: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 24s 1s/step - loss: 0.3452 - accuracy: 0.7505 - f1_score: 0.7423 - val_loss: 0.4413 - val_accuracy: 0.5648 - val_f1_score: 0.5743 - lr: 1.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.7715 - f1_score: 0.7631
# Epoch 30: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 25s 2s/step - loss: 0.3201 - accuracy: 0.7715 - f1_score: 0.7631 - val_loss: 0.3628 - val_accuracy: 0.6420 - val_f1_score: 0.6663 - lr: 1.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.7824 - f1_score: 0.7811
# Epoch 31: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 25s 2s/step - loss: 0.3007 - accuracy: 0.7824 - f1_score: 0.7811 - val_loss: 0.3052 - val_accuracy: 0.7191 - val_f1_score: 0.6625 - lr: 1.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3256 - accuracy: 0.7665 - f1_score: 0.7574
# Epoch 32: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 24s 1s/step - loss: 0.3256 - accuracy: 0.7665 - f1_score: 0.7574 - val_loss: 0.4430 - val_accuracy: 0.5586 - val_f1_score: 0.6140 - lr: 1.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.7595 - f1_score: 0.7482
# Epoch 33: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 24s 2s/step - loss: 0.3353 - accuracy: 0.7595 - f1_score: 0.7482 - val_loss: 0.2880 - val_accuracy: 0.7315 - val_f1_score: 0.6908 - lr: 1.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.7465 - f1_score: 0.7350
# Epoch 34: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 25s 2s/step - loss: 0.3547 - accuracy: 0.7465 - f1_score: 0.7350 - val_loss: 0.2936 - val_accuracy: 0.7315 - val_f1_score: 0.5747 - lr: 1.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.7445 - f1_score: 0.7360
# Epoch 35: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 24s 1s/step - loss: 0.3547 - accuracy: 0.7445 - f1_score: 0.7360 - val_loss: 0.3712 - val_accuracy: 0.6358 - val_f1_score: 0.5947 - lr: 1.0000e-04
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.7774 - f1_score: 0.7766
# Epoch 36: val_f1_score did not improve from 0.73552
# 16/16 [==============================] - 24s 2s/step - loss: 0.3068 - accuracy: 0.7774 - f1_score: 0.7766 - val_loss: 0.3144 - val_accuracy: 0.6975 - val_f1_score: 0.6575 - lr: 1.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.8064 - f1_score: 0.8036
# Epoch 37: val_f1_score improved from 0.73552 to 0.74845, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.2644 - accuracy: 0.8064 - f1_score: 0.8036 - val_loss: 0.2697 - val_accuracy: 0.7469 - val_f1_score: 0.7484 - lr: 1.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.8224 - f1_score: 0.8192
# Epoch 38: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2440 - accuracy: 0.8224 - f1_score: 0.8192 - val_loss: 0.2657 - val_accuracy: 0.7469 - val_f1_score: 0.7409 - lr: 1.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.8373 - f1_score: 0.8326
# Epoch 39: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2277 - accuracy: 0.8373 - f1_score: 0.8326 - val_loss: 0.3393 - val_accuracy: 0.6667 - val_f1_score: 0.6506 - lr: 1.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8084 - f1_score: 0.8056
# Epoch 40: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2663 - accuracy: 0.8084 - f1_score: 0.8056 - val_loss: 0.2761 - val_accuracy: 0.7346 - val_f1_score: 0.7272 - lr: 1.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.8323 - f1_score: 0.8294
# Epoch 41: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2314 - accuracy: 0.8323 - f1_score: 0.8294 - val_loss: 0.2571 - val_accuracy: 0.7623 - val_f1_score: 0.6307 - lr: 1.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.8164 - f1_score: 0.8127
# Epoch 42: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2566 - accuracy: 0.8164 - f1_score: 0.8127 - val_loss: 0.2522 - val_accuracy: 0.7654 - val_f1_score: 0.7235 - lr: 1.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.7695 - f1_score: 0.7557
# Epoch 43: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.3239 - accuracy: 0.7695 - f1_score: 0.7557 - val_loss: 0.4191 - val_accuracy: 0.5864 - val_f1_score: 0.5982 - lr: 1.0000e-04
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.7695 - f1_score: 0.7659
# Epoch 44: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.3161 - accuracy: 0.7695 - f1_score: 0.7659 - val_loss: 0.2488 - val_accuracy: 0.7716 - val_f1_score: 0.6390 - lr: 1.0000e-04
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2908 - accuracy: 0.7924 - f1_score: 0.7892
# Epoch 45: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2908 - accuracy: 0.7924 - f1_score: 0.7892 - val_loss: 0.2559 - val_accuracy: 0.7562 - val_f1_score: 0.7469 - lr: 1.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.8144 - f1_score: 0.8121
# Epoch 46: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2567 - accuracy: 0.8144 - f1_score: 0.8121 - val_loss: 0.2756 - val_accuracy: 0.7315 - val_f1_score: 0.7362 - lr: 1.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.8194 - f1_score: 0.8133
# Epoch 47: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2526 - accuracy: 0.8194 - f1_score: 0.8133 - val_loss: 0.2632 - val_accuracy: 0.7562 - val_f1_score: 0.7164 - lr: 1.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.6467 - f1_score: 0.5899
# Epoch 48: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.5088 - accuracy: 0.6467 - f1_score: 0.5899 - val_loss: 0.3224 - val_accuracy: 0.7346 - val_f1_score: 0.4469 - lr: 1.0000e-04
# Epoch 49/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5242 - accuracy: 0.6377 - f1_score: 0.5846
# Epoch 49: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.5242 - accuracy: 0.6377 - f1_score: 0.5846 - val_loss: 0.3033 - val_accuracy: 0.7130 - val_f1_score: 0.6413 - lr: 1.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.7545 - f1_score: 0.7446
# Epoch 50: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3473 - accuracy: 0.7545 - f1_score: 0.7446 - val_loss: 0.3177 - val_accuracy: 0.7284 - val_f1_score: 0.5755 - lr: 1.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6815 - accuracy: 0.5359 - f1_score: 0.4057
# Epoch 51: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.6815 - accuracy: 0.5359 - f1_score: 0.4057 - val_loss: 0.3204 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.5090 - f1_score: 0.3512
# Epoch 52: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.7279 - accuracy: 0.5090 - f1_score: 0.3512 - val_loss: 0.3204 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 53/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.5190 - f1_score: 0.3717
# Epoch 53: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.7092 - accuracy: 0.5190 - f1_score: 0.3717 - val_loss: 0.3153 - val_accuracy: 0.7407 - val_f1_score: 0.4555 - lr: 1.0000e-04
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.5599 - f1_score: 0.4647
# Epoch 54: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.6400 - accuracy: 0.5599 - f1_score: 0.4647 - val_loss: 0.3578 - val_accuracy: 0.6574 - val_f1_score: 0.5687 - lr: 1.0000e-04
# Epoch 55/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6040 - accuracy: 0.5749 - f1_score: 0.4965
# Epoch 55: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.6040 - accuracy: 0.5749 - f1_score: 0.4965 - val_loss: 0.7203 - val_accuracy: 0.2870 - val_f1_score: 0.2398 - lr: 1.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.5259 - f1_score: 0.3891
# Epoch 56: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.6900 - accuracy: 0.5259 - f1_score: 0.3891 - val_loss: 0.6980 - val_accuracy: 0.3086 - val_f1_score: 0.2633 - lr: 1.0000e-04
# Epoch 57/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6431 - accuracy: 0.5569 - f1_score: 0.4486
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 57: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.6431 - accuracy: 0.5569 - f1_score: 0.4486 - val_loss: 0.6812 - val_accuracy: 0.3241 - val_f1_score: 0.2825 - lr: 1.0000e-04
# Epoch 58/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6279 - accuracy: 0.5619 - f1_score: 0.4719
# Epoch 58: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.6279 - accuracy: 0.5619 - f1_score: 0.4719 - val_loss: 0.5511 - val_accuracy: 0.4506 - val_f1_score: 0.4066 - lr: 5.0000e-05
# Epoch 59/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5339 - accuracy: 0.6148 - f1_score: 0.6010
# Epoch 59: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.5339 - accuracy: 0.6148 - f1_score: 0.6010 - val_loss: 0.3817 - val_accuracy: 0.6265 - val_f1_score: 0.5745 - lr: 5.0000e-05
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.6577 - f1_score: 0.6477
# Epoch 60: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.4775 - accuracy: 0.6577 - f1_score: 0.6477 - val_loss: 0.3042 - val_accuracy: 0.7191 - val_f1_score: 0.5718 - lr: 5.0000e-05
# Epoch 61/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4193 - accuracy: 0.6976 - f1_score: 0.6887
# Epoch 61: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.4193 - accuracy: 0.6976 - f1_score: 0.6887 - val_loss: 0.4473 - val_accuracy: 0.5556 - val_f1_score: 0.5355 - lr: 5.0000e-05
# Epoch 62/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4832 - accuracy: 0.6527 - f1_score: 0.6341
# Epoch 62: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.4832 - accuracy: 0.6527 - f1_score: 0.6341 - val_loss: 0.5007 - val_accuracy: 0.5000 - val_f1_score: 0.4940 - lr: 5.0000e-05
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5047 - accuracy: 0.6407 - f1_score: 0.6052
# Epoch 63: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 27s 2s/step - loss: 0.5047 - accuracy: 0.6407 - f1_score: 0.6052 - val_loss: 0.4922 - val_accuracy: 0.5093 - val_f1_score: 0.5013 - lr: 5.0000e-05
# Epoch 64/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 0.7325 - f1_score: 0.7192
# Epoch 64: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.3736 - accuracy: 0.7325 - f1_score: 0.7192 - val_loss: 0.3544 - val_accuracy: 0.6543 - val_f1_score: 0.6800 - lr: 5.0000e-05
# Epoch 65/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.7695 - f1_score: 0.7657
# Epoch 65: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.3160 - accuracy: 0.7695 - f1_score: 0.7657 - val_loss: 0.2826 - val_accuracy: 0.7315 - val_f1_score: 0.7104 - lr: 5.0000e-05
# Epoch 66/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.7725 - f1_score: 0.7662
# Epoch 66: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3183 - accuracy: 0.7725 - f1_score: 0.7662 - val_loss: 0.2953 - val_accuracy: 0.7160 - val_f1_score: 0.7106 - lr: 5.0000e-05
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.7834 - f1_score: 0.7817
# Epoch 67: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3000 - accuracy: 0.7834 - f1_score: 0.7817 - val_loss: 0.3032 - val_accuracy: 0.7068 - val_f1_score: 0.7037 - lr: 5.0000e-05
# Epoch 68/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.7854 - f1_score: 0.7834
# Epoch 68: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3009 - accuracy: 0.7854 - f1_score: 0.7834 - val_loss: 0.2813 - val_accuracy: 0.7315 - val_f1_score: 0.7157 - lr: 5.0000e-05
# Epoch 69/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.7844 - f1_score: 0.7806
# Epoch 69: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3014 - accuracy: 0.7844 - f1_score: 0.7806 - val_loss: 0.3043 - val_accuracy: 0.7068 - val_f1_score: 0.7066 - lr: 5.0000e-05
# Epoch 70/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.8024 - f1_score: 0.7987
# Epoch 70: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2750 - accuracy: 0.8024 - f1_score: 0.7987 - val_loss: 0.3425 - val_accuracy: 0.6667 - val_f1_score: 0.6825 - lr: 5.0000e-05
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.8024 - f1_score: 0.7992
# Epoch 71: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2775 - accuracy: 0.8024 - f1_score: 0.7992 - val_loss: 0.3456 - val_accuracy: 0.6636 - val_f1_score: 0.6768 - lr: 5.0000e-05
# Epoch 72/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.8054 - f1_score: 0.8017
# Epoch 72: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2707 - accuracy: 0.8054 - f1_score: 0.8017 - val_loss: 0.3606 - val_accuracy: 0.6481 - val_f1_score: 0.6664 - lr: 5.0000e-05
# Epoch 73/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.7754 - f1_score: 0.7728
# Epoch 73: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.3113 - accuracy: 0.7754 - f1_score: 0.7728 - val_loss: 0.4105 - val_accuracy: 0.5957 - val_f1_score: 0.6358 - lr: 5.0000e-05
# Epoch 74/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3216 - accuracy: 0.7685 - f1_score: 0.7667
# Epoch 74: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3216 - accuracy: 0.7685 - f1_score: 0.7667 - val_loss: 0.3525 - val_accuracy: 0.6605 - val_f1_score: 0.6606 - lr: 5.0000e-05
# Epoch 75/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.7754 - f1_score: 0.7716
# Epoch 75: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3136 - accuracy: 0.7754 - f1_score: 0.7716 - val_loss: 0.4048 - val_accuracy: 0.6019 - val_f1_score: 0.5944 - lr: 5.0000e-05
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.7305 - f1_score: 0.7251
# Epoch 76: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3731 - accuracy: 0.7305 - f1_score: 0.7251 - val_loss: 0.4411 - val_accuracy: 0.5617 - val_f1_score: 0.5754 - lr: 5.0000e-05
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.7196 - f1_score: 0.7133
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 77: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3882 - accuracy: 0.7196 - f1_score: 0.7133 - val_loss: 0.4118 - val_accuracy: 0.5926 - val_f1_score: 0.5964 - lr: 5.0000e-05
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.7405 - f1_score: 0.7360
# Epoch 78: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3582 - accuracy: 0.7405 - f1_score: 0.7360 - val_loss: 0.4003 - val_accuracy: 0.6049 - val_f1_score: 0.6040 - lr: 2.5000e-05
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.7226 - f1_score: 0.7141
# Epoch 79: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3859 - accuracy: 0.7226 - f1_score: 0.7141 - val_loss: 0.4000 - val_accuracy: 0.6049 - val_f1_score: 0.6041 - lr: 2.5000e-05
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3272 - accuracy: 0.7635 - f1_score: 0.7640
# Epoch 80: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3272 - accuracy: 0.7635 - f1_score: 0.7640 - val_loss: 0.3495 - val_accuracy: 0.6698 - val_f1_score: 0.6397 - lr: 2.5000e-05
# Epoch 81/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3206 - accuracy: 0.7705 - f1_score: 0.7676
# Epoch 81: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.3206 - accuracy: 0.7705 - f1_score: 0.7676 - val_loss: 0.3482 - val_accuracy: 0.6636 - val_f1_score: 0.6258 - lr: 2.5000e-05
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.7924 - f1_score: 0.7913
# Epoch 82: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2877 - accuracy: 0.7924 - f1_score: 0.7913 - val_loss: 0.3761 - val_accuracy: 0.6296 - val_f1_score: 0.6220 - lr: 2.5000e-05
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.7894 - f1_score: 0.7874
# Epoch 83: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2931 - accuracy: 0.7894 - f1_score: 0.7874 - val_loss: 0.3817 - val_accuracy: 0.6235 - val_f1_score: 0.6187 - lr: 2.5000e-05
# Epoch 84/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.7884 - f1_score: 0.7846
# Epoch 84: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.2922 - accuracy: 0.7884 - f1_score: 0.7846 - val_loss: 0.3749 - val_accuracy: 0.6296 - val_f1_score: 0.6232 - lr: 2.5000e-05
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.7944 - f1_score: 0.7918
# Epoch 85: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2871 - accuracy: 0.7944 - f1_score: 0.7918 - val_loss: 0.4020 - val_accuracy: 0.6019 - val_f1_score: 0.6044 - lr: 2.5000e-05
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3168 - accuracy: 0.7725 - f1_score: 0.7648
# Epoch 86: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.3168 - accuracy: 0.7725 - f1_score: 0.7648 - val_loss: 0.3559 - val_accuracy: 0.6512 - val_f1_score: 0.6337 - lr: 2.5000e-05
# Epoch 87/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.8144 - f1_score: 0.8109
# Epoch 87: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2579 - accuracy: 0.8144 - f1_score: 0.8109 - val_loss: 0.3407 - val_accuracy: 0.6698 - val_f1_score: 0.6776 - lr: 2.5000e-05
# Epoch 88/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.8164 - f1_score: 0.8163
# Epoch 88: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2566 - accuracy: 0.8164 - f1_score: 0.8163 - val_loss: 0.3119 - val_accuracy: 0.7037 - val_f1_score: 0.6959 - lr: 2.5000e-05
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.8224 - f1_score: 0.8219
# Epoch 89: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2466 - accuracy: 0.8224 - f1_score: 0.8219 - val_loss: 0.3376 - val_accuracy: 0.6728 - val_f1_score: 0.6794 - lr: 2.5000e-05
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.8224 - f1_score: 0.8230
# Epoch 90: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.2503 - accuracy: 0.8224 - f1_score: 0.8230 - val_loss: 0.2925 - val_accuracy: 0.7222 - val_f1_score: 0.7033 - lr: 2.5000e-05
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.8214 - f1_score: 0.8188
# Epoch 91: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2489 - accuracy: 0.8214 - f1_score: 0.8188 - val_loss: 0.2892 - val_accuracy: 0.7253 - val_f1_score: 0.7069 - lr: 2.5000e-05
# Epoch 92/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.8253 - f1_score: 0.8223
# Epoch 92: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2445 - accuracy: 0.8253 - f1_score: 0.8223 - val_loss: 0.2916 - val_accuracy: 0.7222 - val_f1_score: 0.7100 - lr: 2.5000e-05
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2506 - accuracy: 0.8204 - f1_score: 0.8171
# Epoch 93: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2506 - accuracy: 0.8204 - f1_score: 0.8171 - val_loss: 0.3027 - val_accuracy: 0.7130 - val_f1_score: 0.6983 - lr: 2.5000e-05
# Epoch 94/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.8144 - f1_score: 0.8117
# Epoch 94: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2578 - accuracy: 0.8144 - f1_score: 0.8117 - val_loss: 0.2987 - val_accuracy: 0.7222 - val_f1_score: 0.6774 - lr: 2.5000e-05
# Epoch 95/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3035 - accuracy: 0.7814 - f1_score: 0.7752
# Epoch 95: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.3035 - accuracy: 0.7814 - f1_score: 0.7752 - val_loss: 0.3217 - val_accuracy: 0.7037 - val_f1_score: 0.5476 - lr: 2.5000e-05
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.7685 - f1_score: 0.7614
# Epoch 96: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.3252 - accuracy: 0.7685 - f1_score: 0.7614 - val_loss: 0.3077 - val_accuracy: 0.7130 - val_f1_score: 0.6707 - lr: 2.5000e-05
# Epoch 97/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.8094 - f1_score: 0.8066
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 97: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2668 - accuracy: 0.8094 - f1_score: 0.8066 - val_loss: 0.3161 - val_accuracy: 0.6975 - val_f1_score: 0.6875 - lr: 2.5000e-05
# Epoch 98/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8104 - f1_score: 0.8086
# Epoch 98: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2630 - accuracy: 0.8104 - f1_score: 0.8086 - val_loss: 0.3208 - val_accuracy: 0.6914 - val_f1_score: 0.6870 - lr: 1.2500e-05
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.8124 - f1_score: 0.8109
# Epoch 99: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2608 - accuracy: 0.8124 - f1_score: 0.8109 - val_loss: 0.3204 - val_accuracy: 0.6914 - val_f1_score: 0.6870 - lr: 1.2500e-05
# Epoch 100/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.8084 - f1_score: 0.8054
# Epoch 100: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2665 - accuracy: 0.8084 - f1_score: 0.8054 - val_loss: 0.3290 - val_accuracy: 0.6883 - val_f1_score: 0.6603 - lr: 1.2500e-05
# Epoch 101/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.8074 - f1_score: 0.8060
# Epoch 101: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2687 - accuracy: 0.8074 - f1_score: 0.8060 - val_loss: 0.3276 - val_accuracy: 0.6883 - val_f1_score: 0.6568 - lr: 1.2500e-05
# Epoch 102/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8084 - f1_score: 0.8057
# Epoch 102: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2656 - accuracy: 0.8084 - f1_score: 0.8057 - val_loss: 0.3173 - val_accuracy: 0.7006 - val_f1_score: 0.6745 - lr: 1.2500e-05
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.8124 - f1_score: 0.8052
# Epoch 103: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 26s 2s/step - loss: 0.2611 - accuracy: 0.8124 - f1_score: 0.8052 - val_loss: 0.3097 - val_accuracy: 0.7037 - val_f1_score: 0.6981 - lr: 1.2500e-05
# Epoch 104/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8134 - f1_score: 0.8102
# Epoch 104: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2601 - accuracy: 0.8134 - f1_score: 0.8102 - val_loss: 0.3171 - val_accuracy: 0.6944 - val_f1_score: 0.6840 - lr: 1.2500e-05
# Epoch 105/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.8194 - f1_score: 0.8158
# Epoch 105: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2521 - accuracy: 0.8194 - f1_score: 0.8158 - val_loss: 0.3119 - val_accuracy: 0.7006 - val_f1_score: 0.6957 - lr: 1.2500e-05
# Epoch 106/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.8214 - f1_score: 0.8183
# Epoch 106: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2485 - accuracy: 0.8214 - f1_score: 0.8183 - val_loss: 0.3074 - val_accuracy: 0.7037 - val_f1_score: 0.7034 - lr: 1.2500e-05
# Epoch 107/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.8204 - f1_score: 0.8171
# Epoch 107: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2505 - accuracy: 0.8204 - f1_score: 0.8171 - val_loss: 0.3134 - val_accuracy: 0.6975 - val_f1_score: 0.6992 - lr: 1.2500e-05
# Epoch 108/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.8204 - f1_score: 0.8184
# Epoch 108: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2501 - accuracy: 0.8204 - f1_score: 0.8184 - val_loss: 0.3134 - val_accuracy: 0.6975 - val_f1_score: 0.6992 - lr: 1.2500e-05
# Epoch 109/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.8214 - f1_score: 0.8218
# Epoch 109: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2476 - accuracy: 0.8214 - f1_score: 0.8218 - val_loss: 0.3093 - val_accuracy: 0.7037 - val_f1_score: 0.7009 - lr: 1.2500e-05
# Epoch 110/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.8214 - f1_score: 0.8204
# Epoch 110: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 25s 2s/step - loss: 0.2490 - accuracy: 0.8214 - f1_score: 0.8204 - val_loss: 0.3153 - val_accuracy: 0.6975 - val_f1_score: 0.6915 - lr: 1.2500e-05
# Epoch 111/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8224 - f1_score: 0.8205
# Epoch 111: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2482 - accuracy: 0.8224 - f1_score: 0.8205 - val_loss: 0.3110 - val_accuracy: 0.7006 - val_f1_score: 0.6991 - lr: 1.2500e-05
# Epoch 112/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.8244 - f1_score: 0.8202
# Epoch 112: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2437 - accuracy: 0.8244 - f1_score: 0.8202 - val_loss: 0.3074 - val_accuracy: 0.7037 - val_f1_score: 0.7034 - lr: 1.2500e-05
# Epoch 113/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.8194 - f1_score: 0.8158
# Epoch 113: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 27s 2s/step - loss: 0.2500 - accuracy: 0.8194 - f1_score: 0.8158 - val_loss: 0.3109 - val_accuracy: 0.7006 - val_f1_score: 0.6991 - lr: 1.2500e-05
# Epoch 114/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.8273 - f1_score: 0.8255
# Epoch 114: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 27s 2s/step - loss: 0.2418 - accuracy: 0.8273 - f1_score: 0.8255 - val_loss: 0.3138 - val_accuracy: 0.6975 - val_f1_score: 0.6952 - lr: 1.2500e-05
# Epoch 115/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.8263 - f1_score: 0.8219
# Epoch 115: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2413 - accuracy: 0.8263 - f1_score: 0.8219 - val_loss: 0.3066 - val_accuracy: 0.7037 - val_f1_score: 0.7058 - lr: 1.2500e-05
# Epoch 116/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2365 - accuracy: 0.8293 - f1_score: 0.8269
# Epoch 116: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2365 - accuracy: 0.8293 - f1_score: 0.8269 - val_loss: 0.2982 - val_accuracy: 0.7130 - val_f1_score: 0.7098 - lr: 1.2500e-05
# Epoch 117/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.8303 - f1_score: 0.8255
# Epoch 117: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 117: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2347 - accuracy: 0.8303 - f1_score: 0.8255 - val_loss: 0.2966 - val_accuracy: 0.7160 - val_f1_score: 0.7119 - lr: 1.2500e-05
# Epoch 118/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8303 - f1_score: 0.8233
# Epoch 118: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2390 - accuracy: 0.8303 - f1_score: 0.8233 - val_loss: 0.2973 - val_accuracy: 0.7130 - val_f1_score: 0.7083 - lr: 6.2500e-06
# Epoch 119/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.8313 - f1_score: 0.8292
# Epoch 119: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2352 - accuracy: 0.8313 - f1_score: 0.8292 - val_loss: 0.2986 - val_accuracy: 0.7130 - val_f1_score: 0.7083 - lr: 6.2500e-06
# Epoch 120/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.8313 - f1_score: 0.8264
# Epoch 120: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2374 - accuracy: 0.8313 - f1_score: 0.8264 - val_loss: 0.3043 - val_accuracy: 0.7068 - val_f1_score: 0.6999 - lr: 6.2500e-06
# Epoch 121/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.8323 - f1_score: 0.8292
# Epoch 121: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2333 - accuracy: 0.8323 - f1_score: 0.8292 - val_loss: 0.3023 - val_accuracy: 0.7068 - val_f1_score: 0.6999 - lr: 6.2500e-06
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.8323 - f1_score: 0.8316
# Epoch 122: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 2s/step - loss: 0.2346 - accuracy: 0.8323 - f1_score: 0.8316 - val_loss: 0.2976 - val_accuracy: 0.7130 - val_f1_score: 0.7114 - lr: 6.2500e-06
# Epoch 123/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.8323 - f1_score: 0.8281
# Epoch 123: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2341 - accuracy: 0.8323 - f1_score: 0.8281 - val_loss: 0.2974 - val_accuracy: 0.7160 - val_f1_score: 0.7117 - lr: 6.2500e-06
# Epoch 124/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.8333 - f1_score: 0.8281
# Epoch 124: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2337 - accuracy: 0.8333 - f1_score: 0.8281 - val_loss: 0.2966 - val_accuracy: 0.7160 - val_f1_score: 0.7117 - lr: 6.2500e-06
# Epoch 125/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.8333 - f1_score: 0.8303
# Epoch 125: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2303 - accuracy: 0.8333 - f1_score: 0.8303 - val_loss: 0.2967 - val_accuracy: 0.7160 - val_f1_score: 0.7117 - lr: 6.2500e-06
# Epoch 126/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.8333 - f1_score: 0.8293
# Epoch 126: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2306 - accuracy: 0.8333 - f1_score: 0.8293 - val_loss: 0.2971 - val_accuracy: 0.7160 - val_f1_score: 0.7117 - lr: 6.2500e-06
# Epoch 127/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.8333 - f1_score: 0.8322
# Epoch 127: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2316 - accuracy: 0.8333 - f1_score: 0.8322 - val_loss: 0.2989 - val_accuracy: 0.7130 - val_f1_score: 0.7073 - lr: 6.2500e-06
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.8343 - f1_score: 0.8332
# Epoch 128: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2322 - accuracy: 0.8343 - f1_score: 0.8332 - val_loss: 0.3018 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 129/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.8343 - f1_score: 0.8329
# Epoch 129: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2318 - accuracy: 0.8343 - f1_score: 0.8329 - val_loss: 0.3021 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 130/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.8343 - f1_score: 0.8316
# Epoch 130: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2298 - accuracy: 0.8343 - f1_score: 0.8316 - val_loss: 0.3022 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 131/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.8343 - f1_score: 0.8328
# Epoch 131: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2288 - accuracy: 0.8343 - f1_score: 0.8328 - val_loss: 0.3023 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 132/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.8343 - f1_score: 0.8303
# Epoch 132: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2315 - accuracy: 0.8343 - f1_score: 0.8303 - val_loss: 0.3023 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.8343 - f1_score: 0.8292
# Epoch 133: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 24s 1s/step - loss: 0.2320 - accuracy: 0.8343 - f1_score: 0.8292 - val_loss: 0.3024 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 134/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.8343 - f1_score: 0.8338
# Epoch 134: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2302 - accuracy: 0.8343 - f1_score: 0.8338 - val_loss: 0.3024 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 135/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.8343 - f1_score: 0.8331
# Epoch 135: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2307 - accuracy: 0.8343 - f1_score: 0.8331 - val_loss: 0.3024 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 136/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.8343 - f1_score: 0.8338
# Epoch 136: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2316 - accuracy: 0.8343 - f1_score: 0.8338 - val_loss: 0.3024 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 137/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.8343 - f1_score: 0.8348Restoring model weights from the end of the best epoch: 37.
#
# Epoch 137: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 137: val_f1_score did not improve from 0.74845
# 16/16 [==============================] - 23s 1s/step - loss: 0.2329 - accuracy: 0.8343 - f1_score: 0.8348 - val_loss: 0.3025 - val_accuracy: 0.7099 - val_f1_score: 0.7021 - lr: 6.2500e-06
# Epoch 137: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 28ms/step
# 0.7469135802469136

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7469135802469136
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.51      0.68      0.59        85
#            0       0.87      0.77      0.82       239
#
#     accuracy                           0.75       324
#    macro avg       0.69      0.73      0.70       324
# weighted avg       0.78      0.75      0.76       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 242 chiếm khoảng 74.69135802469135% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 58 chiếm khoảng 68.23529411764706% so với thực tế
