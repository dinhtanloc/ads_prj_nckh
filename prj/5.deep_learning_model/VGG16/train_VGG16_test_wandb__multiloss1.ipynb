# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0
    f1_weight = 0.2
    dice_weight = 0.8

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=learning_rate), loss=multi_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#
#  global_average_pooling1d (G  (None, 1024)             0
#  lobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Set data order
data_order = 8

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.5120 - f1_score: 0.3634
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.hdf5
# 16/16 [==============================] - 32s 2s/step - loss: 0.6943 - accuracy: 0.5120 - f1_score: 0.3634 - val_loss: 0.5033 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5070 - f1_score: 0.3622
# Epoch 2: val_f1_score improved from 0.42467 to 0.46811, saving model to best_model.hdf5
# 16/16 [==============================] - 28s 2s/step - loss: 0.6871 - accuracy: 0.5070 - f1_score: 0.3622 - val_loss: 0.4857 - val_accuracy: 0.5957 - val_f1_score: 0.4681 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6375 - accuracy: 0.5719 - f1_score: 0.5282
# Epoch 3: val_f1_score improved from 0.46811 to 0.53877, saving model to best_model.hdf5
# 16/16 [==============================] - 26s 2s/step - loss: 0.6375 - accuracy: 0.5719 - f1_score: 0.5282 - val_loss: 0.3896 - val_accuracy: 0.6605 - val_f1_score: 0.5388 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4558 - accuracy: 0.6946 - f1_score: 0.6846
# Epoch 4: val_f1_score improved from 0.53877 to 0.56654, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.4558 - accuracy: 0.6946 - f1_score: 0.6846 - val_loss: 0.3924 - val_accuracy: 0.6358 - val_f1_score: 0.5665 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.7126 - f1_score: 0.6953
# Epoch 5: val_f1_score improved from 0.56654 to 0.65911, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.4096 - accuracy: 0.7126 - f1_score: 0.6953 - val_loss: 0.3260 - val_accuracy: 0.7068 - val_f1_score: 0.6591 - lr: 1.0000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4376 - accuracy: 0.6886 - f1_score: 0.6724
# Epoch 6: val_f1_score did not improve from 0.65911
# 16/16 [==============================] - 25s 2s/step - loss: 0.4376 - accuracy: 0.6886 - f1_score: 0.6724 - val_loss: 0.4614 - val_accuracy: 0.5401 - val_f1_score: 0.4724 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.7665 - f1_score: 0.7595
# Epoch 7: val_f1_score did not improve from 0.65911
# 16/16 [==============================] - 25s 2s/step - loss: 0.3379 - accuracy: 0.7665 - f1_score: 0.7595 - val_loss: 0.4622 - val_accuracy: 0.5432 - val_f1_score: 0.5967 - lr: 1.0000e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.7295 - f1_score: 0.7101
# Epoch 8: val_f1_score improved from 0.65911 to 0.66417, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.3876 - accuracy: 0.7295 - f1_score: 0.7101 - val_loss: 0.3574 - val_accuracy: 0.6636 - val_f1_score: 0.6642 - lr: 1.0000e-04
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.7864 - f1_score: 0.7791
# Epoch 9: val_f1_score did not improve from 0.66417
# 16/16 [==============================] - 25s 2s/step - loss: 0.2970 - accuracy: 0.7864 - f1_score: 0.7791 - val_loss: 0.3903 - val_accuracy: 0.6265 - val_f1_score: 0.6593 - lr: 1.0000e-04
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.8014 - f1_score: 0.7965
# Epoch 10: val_f1_score improved from 0.66417 to 0.69433, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.2787 - accuracy: 0.8014 - f1_score: 0.7965 - val_loss: 0.3040 - val_accuracy: 0.7315 - val_f1_score: 0.6943 - lr: 1.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.7814 - f1_score: 0.7736
# Epoch 11: val_f1_score did not improve from 0.69433
# 16/16 [==============================] - 24s 2s/step - loss: 0.3024 - accuracy: 0.7814 - f1_score: 0.7736 - val_loss: 0.3643 - val_accuracy: 0.6574 - val_f1_score: 0.6552 - lr: 1.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.7774 - f1_score: 0.7729
# Epoch 12: val_f1_score did not improve from 0.69433
# 16/16 [==============================] - 24s 2s/step - loss: 0.3113 - accuracy: 0.7774 - f1_score: 0.7729 - val_loss: 0.3597 - val_accuracy: 0.6605 - val_f1_score: 0.6678 - lr: 1.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.7914 - f1_score: 0.7820
# Epoch 13: val_f1_score did not improve from 0.69433
# 16/16 [==============================] - 24s 1s/step - loss: 0.2935 - accuracy: 0.7914 - f1_score: 0.7820 - val_loss: 0.4443 - val_accuracy: 0.5648 - val_f1_score: 0.6201 - lr: 1.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.7934 - f1_score: 0.7881
# Epoch 14: val_f1_score did not improve from 0.69433
# 16/16 [==============================] - 24s 2s/step - loss: 0.2880 - accuracy: 0.7934 - f1_score: 0.7881 - val_loss: 0.3165 - val_accuracy: 0.7006 - val_f1_score: 0.6917 - lr: 1.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.8204 - f1_score: 0.8183
# Epoch 15: val_f1_score did not improve from 0.69433
# 16/16 [==============================] - 25s 2s/step - loss: 0.2492 - accuracy: 0.8204 - f1_score: 0.8183 - val_loss: 0.3313 - val_accuracy: 0.6883 - val_f1_score: 0.6883 - lr: 1.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.8194 - f1_score: 0.8170
# Epoch 16: val_f1_score improved from 0.69433 to 0.69622, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.2519 - accuracy: 0.8194 - f1_score: 0.8170 - val_loss: 0.3316 - val_accuracy: 0.6852 - val_f1_score: 0.6962 - lr: 1.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.8104 - f1_score: 0.8078
# Epoch 17: val_f1_score improved from 0.69622 to 0.69637, saving model to best_model.hdf5
# 16/16 [==============================] - 25s 2s/step - loss: 0.2703 - accuracy: 0.8104 - f1_score: 0.8078 - val_loss: 0.3075 - val_accuracy: 0.7130 - val_f1_score: 0.6964 - lr: 1.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.7884 - f1_score: 0.7823
# Epoch 18: val_f1_score did not improve from 0.69637
# 16/16 [==============================] - 26s 2s/step - loss: 0.2988 - accuracy: 0.7884 - f1_score: 0.7823 - val_loss: 0.3680 - val_accuracy: 0.6451 - val_f1_score: 0.6645 - lr: 1.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.7864 - f1_score: 0.7848
# Epoch 19: val_f1_score did not improve from 0.69637
# 16/16 [==============================] - 28s 2s/step - loss: 0.2982 - accuracy: 0.7864 - f1_score: 0.7848 - val_loss: 0.4003 - val_accuracy: 0.6080 - val_f1_score: 0.6489 - lr: 1.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3150 - accuracy: 0.7764 - f1_score: 0.7676
# Epoch 20: val_f1_score improved from 0.69637 to 0.71320, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 2s/step - loss: 0.3150 - accuracy: 0.7764 - f1_score: 0.7676 - val_loss: 0.2919 - val_accuracy: 0.7284 - val_f1_score: 0.7132 - lr: 1.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8253 - f1_score: 0.8203
# Epoch 21: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2444 - accuracy: 0.8253 - f1_score: 0.8203 - val_loss: 0.2978 - val_accuracy: 0.7284 - val_f1_score: 0.7077 - lr: 1.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.8393 - f1_score: 0.8337
# Epoch 22: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2283 - accuracy: 0.8393 - f1_score: 0.8337 - val_loss: 0.3037 - val_accuracy: 0.7130 - val_f1_score: 0.7038 - lr: 1.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.8453 - f1_score: 0.8420
# Epoch 23: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2172 - accuracy: 0.8453 - f1_score: 0.8420 - val_loss: 0.3193 - val_accuracy: 0.6944 - val_f1_score: 0.7057 - lr: 1.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.8433 - f1_score: 0.8401
# Epoch 24: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2170 - accuracy: 0.8433 - f1_score: 0.8401 - val_loss: 0.3168 - val_accuracy: 0.6975 - val_f1_score: 0.7010 - lr: 1.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8204 - f1_score: 0.8218
# Epoch 25: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2482 - accuracy: 0.8204 - f1_score: 0.8218 - val_loss: 0.3052 - val_accuracy: 0.7130 - val_f1_score: 0.6201 - lr: 1.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.8194 - f1_score: 0.8152
# Epoch 26: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2552 - accuracy: 0.8194 - f1_score: 0.8152 - val_loss: 0.3009 - val_accuracy: 0.7253 - val_f1_score: 0.5990 - lr: 1.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.8054 - f1_score: 0.8002
# Epoch 27: val_f1_score did not improve from 0.71320
# 16/16 [==============================] - 23s 1s/step - loss: 0.2714 - accuracy: 0.8054 - f1_score: 0.8002 - val_loss: 0.4726 - val_accuracy: 0.5278 - val_f1_score: 0.4689 - lr: 1.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.7605 - f1_score: 0.7462
# Epoch 28: val_f1_score improved from 0.71320 to 0.73540, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 1s/step - loss: 0.3393 - accuracy: 0.7605 - f1_score: 0.7462 - val_loss: 0.2633 - val_accuracy: 0.7562 - val_f1_score: 0.7354 - lr: 1.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.8214 - f1_score: 0.8172
# Epoch 29: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2474 - accuracy: 0.8214 - f1_score: 0.8172 - val_loss: 0.2711 - val_accuracy: 0.7469 - val_f1_score: 0.7334 - lr: 1.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.8373 - f1_score: 0.8346
# Epoch 30: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2261 - accuracy: 0.8373 - f1_score: 0.8346 - val_loss: 0.2724 - val_accuracy: 0.7562 - val_f1_score: 0.7226 - lr: 1.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.8034 - f1_score: 0.7967
# Epoch 31: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 24s 1s/step - loss: 0.2719 - accuracy: 0.8034 - f1_score: 0.7967 - val_loss: 0.3339 - val_accuracy: 0.6790 - val_f1_score: 0.6971 - lr: 1.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.8244 - f1_score: 0.8203
# Epoch 32: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2435 - accuracy: 0.8244 - f1_score: 0.8203 - val_loss: 0.2931 - val_accuracy: 0.7438 - val_f1_score: 0.5882 - lr: 1.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8124 - f1_score: 0.8081
# Epoch 33: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2646 - accuracy: 0.8124 - f1_score: 0.8081 - val_loss: 0.2926 - val_accuracy: 0.7191 - val_f1_score: 0.7292 - lr: 1.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.7425 - f1_score: 0.7313
# Epoch 34: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.3612 - accuracy: 0.7425 - f1_score: 0.7313 - val_loss: 0.3228 - val_accuracy: 0.7191 - val_f1_score: 0.5504 - lr: 1.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.7405 - f1_score: 0.7289
# Epoch 35: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.3641 - accuracy: 0.7405 - f1_score: 0.7289 - val_loss: 0.4142 - val_accuracy: 0.5895 - val_f1_score: 0.5954 - lr: 1.0000e-04
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.8244 - f1_score: 0.8195
# Epoch 36: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2443 - accuracy: 0.8244 - f1_score: 0.8195 - val_loss: 0.3315 - val_accuracy: 0.6883 - val_f1_score: 0.6775 - lr: 1.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.7954 - f1_score: 0.7949
# Epoch 37: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2812 - accuracy: 0.7954 - f1_score: 0.7949 - val_loss: 0.3794 - val_accuracy: 0.6296 - val_f1_score: 0.6227 - lr: 1.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.7824 - f1_score: 0.7745
# Epoch 38: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.3026 - accuracy: 0.7824 - f1_score: 0.7745 - val_loss: 0.3673 - val_accuracy: 0.6420 - val_f1_score: 0.6334 - lr: 1.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.8313 - f1_score: 0.8301
# Epoch 39: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2347 - accuracy: 0.8313 - f1_score: 0.8301 - val_loss: 0.3003 - val_accuracy: 0.7222 - val_f1_score: 0.7002 - lr: 1.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.7844 - f1_score: 0.7718
# Epoch 40: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2994 - accuracy: 0.7844 - f1_score: 0.7718 - val_loss: 0.6036 - val_accuracy: 0.3981 - val_f1_score: 0.3584 - lr: 1.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5662 - accuracy: 0.6068 - f1_score: 0.5380
# Epoch 41: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.5662 - accuracy: 0.6068 - f1_score: 0.5380 - val_loss: 0.5548 - val_accuracy: 0.4475 - val_f1_score: 0.4029 - lr: 1.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.7585 - f1_score: 0.7484
# Epoch 42: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 24s 2s/step - loss: 0.3350 - accuracy: 0.7585 - f1_score: 0.7484 - val_loss: 0.2710 - val_accuracy: 0.7500 - val_f1_score: 0.7283 - lr: 1.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.8034 - f1_score: 0.8008
# Epoch 43: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2751 - accuracy: 0.8034 - f1_score: 0.8008 - val_loss: 0.2765 - val_accuracy: 0.7407 - val_f1_score: 0.7267 - lr: 1.0000e-04
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.8273 - f1_score: 0.8256
# Epoch 44: val_f1_score did not improve from 0.73540
# 16/16 [==============================] - 23s 1s/step - loss: 0.2399 - accuracy: 0.8273 - f1_score: 0.8256 - val_loss: 0.2964 - val_accuracy: 0.7222 - val_f1_score: 0.7179 - lr: 1.0000e-04
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.8263 - f1_score: 0.8251
# Epoch 45: val_f1_score improved from 0.73540 to 0.73746, saving model to best_model.hdf5
# 16/16 [==============================] - 24s 1s/step - loss: 0.2392 - accuracy: 0.8263 - f1_score: 0.8251 - val_loss: 0.2695 - val_accuracy: 0.7469 - val_f1_score: 0.7375 - lr: 1.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.8413 - f1_score: 0.8403
# Epoch 46: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2208 - accuracy: 0.8413 - f1_score: 0.8403 - val_loss: 0.3136 - val_accuracy: 0.7006 - val_f1_score: 0.7066 - lr: 1.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8084 - f1_score: 0.8082
# Epoch 47: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2670 - accuracy: 0.8084 - f1_score: 0.8082 - val_loss: 0.2822 - val_accuracy: 0.7346 - val_f1_score: 0.7290 - lr: 1.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.7725 - f1_score: 0.7618
# Epoch 48: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3200 - accuracy: 0.7725 - f1_score: 0.7618 - val_loss: 0.2800 - val_accuracy: 0.7469 - val_f1_score: 0.7062 - lr: 1.0000e-04
# Epoch 49/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.8184 - f1_score: 0.8138
# Epoch 49: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2544 - accuracy: 0.8184 - f1_score: 0.8138 - val_loss: 0.3149 - val_accuracy: 0.7006 - val_f1_score: 0.7038 - lr: 1.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8194 - f1_score: 0.8165
# Epoch 50: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2525 - accuracy: 0.8194 - f1_score: 0.8165 - val_loss: 0.3048 - val_accuracy: 0.7222 - val_f1_score: 0.6937 - lr: 1.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.7555 - f1_score: 0.7458
# Epoch 51: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3429 - accuracy: 0.7555 - f1_score: 0.7458 - val_loss: 0.5243 - val_accuracy: 0.4784 - val_f1_score: 0.4299 - lr: 1.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.7615 - f1_score: 0.7555
# Epoch 52: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3332 - accuracy: 0.7615 - f1_score: 0.7555 - val_loss: 0.3889 - val_accuracy: 0.6204 - val_f1_score: 0.6536 - lr: 1.0000e-04
# Epoch 53/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.7964 - f1_score: 0.7951
# Epoch 53: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2833 - accuracy: 0.7964 - f1_score: 0.7951 - val_loss: 0.2983 - val_accuracy: 0.7191 - val_f1_score: 0.7118 - lr: 1.0000e-04
# Epoch 54/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3602 - accuracy: 0.7425 - f1_score: 0.7340
# Epoch 54: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3602 - accuracy: 0.7425 - f1_score: 0.7340 - val_loss: 0.4697 - val_accuracy: 0.5340 - val_f1_score: 0.5181 - lr: 1.0000e-04
# Epoch 55/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.7555 - f1_score: 0.7489
# Epoch 55: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3386 - accuracy: 0.7555 - f1_score: 0.7489 - val_loss: 0.3052 - val_accuracy: 0.7068 - val_f1_score: 0.7190 - lr: 1.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.7944 - f1_score: 0.7885
# Epoch 56: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.2880 - accuracy: 0.7944 - f1_score: 0.7885 - val_loss: 0.3154 - val_accuracy: 0.6975 - val_f1_score: 0.7144 - lr: 1.0000e-04
# Epoch 57/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.7764 - f1_score: 0.7722
# Epoch 57: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3117 - accuracy: 0.7764 - f1_score: 0.7722 - val_loss: 0.3333 - val_accuracy: 0.6821 - val_f1_score: 0.6900 - lr: 1.0000e-04
# Epoch 58/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.7804 - f1_score: 0.7780
# Epoch 58: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.3067 - accuracy: 0.7804 - f1_score: 0.7780 - val_loss: 0.3299 - val_accuracy: 0.6852 - val_f1_score: 0.6861 - lr: 1.0000e-04
# Epoch 59/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5296 - accuracy: 0.6347 - f1_score: 0.5803
# Epoch 59: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.5296 - accuracy: 0.6347 - f1_score: 0.5803 - val_loss: 0.3599 - val_accuracy: 0.7222 - val_f1_score: 0.4424 - lr: 1.0000e-04
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7295 - accuracy: 0.5190 - f1_score: 0.3715
# Epoch 60: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7295 - accuracy: 0.5190 - f1_score: 0.3715 - val_loss: 0.3565 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 61/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.5060 - f1_score: 0.3462
# Epoch 61: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7542 - accuracy: 0.5060 - f1_score: 0.3462 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 62/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3542
# Epoch 62: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3542 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.5100 - f1_score: 0.3540
# Epoch 63: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7473 - accuracy: 0.5100 - f1_score: 0.3540 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7481 - accuracy: 0.5100 - f1_score: 0.3548
# Epoch 64: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7481 - accuracy: 0.5100 - f1_score: 0.3548 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 65/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7491 - accuracy: 0.5100 - f1_score: 0.3541
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 65: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7491 - accuracy: 0.5100 - f1_score: 0.3541 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 66/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7453 - accuracy: 0.5100 - f1_score: 0.3565
# Epoch 66: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7453 - accuracy: 0.5100 - f1_score: 0.3565 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 67/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3543
# Epoch 67: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3543 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 68/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3552
# Epoch 68: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3552 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 69/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7494 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 69: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7494 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 70/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3557
# Epoch 70: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3557 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.5100 - f1_score: 0.3577
# Epoch 71: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7464 - accuracy: 0.5100 - f1_score: 0.3577 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 72/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3572
# Epoch 72: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3572 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 73/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7488 - accuracy: 0.5100 - f1_score: 0.3535
# Epoch 73: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7488 - accuracy: 0.5100 - f1_score: 0.3535 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 74/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7526 - accuracy: 0.5100 - f1_score: 0.3557
# Epoch 74: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7526 - accuracy: 0.5100 - f1_score: 0.3557 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 75/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 75: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7474 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7465 - accuracy: 0.5100 - f1_score: 0.3542
# Epoch 76: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7465 - accuracy: 0.5100 - f1_score: 0.3542 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7479 - accuracy: 0.5100 - f1_score: 0.3546
# Epoch 77: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7479 - accuracy: 0.5100 - f1_score: 0.3546 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3572
# Epoch 78: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3572 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 79/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3543
# Epoch 79: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3543 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7503 - accuracy: 0.5100 - f1_score: 0.3520
# Epoch 80: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7503 - accuracy: 0.5100 - f1_score: 0.3520 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 81/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.5100 - f1_score: 0.3559
# Epoch 81: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7498 - accuracy: 0.5100 - f1_score: 0.3559 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 82/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7496 - accuracy: 0.5100 - f1_score: 0.3579
# Epoch 82: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7496 - accuracy: 0.5100 - f1_score: 0.3579 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3532
# Epoch 83: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3532 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 84/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7553 - accuracy: 0.5100 - f1_score: 0.3508
# Epoch 84: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7553 - accuracy: 0.5100 - f1_score: 0.3508 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7503 - accuracy: 0.5100 - f1_score: 0.3542
# Epoch 85: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 85: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 25s 2s/step - loss: 0.7503 - accuracy: 0.5100 - f1_score: 0.3542 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 5.0000e-05
# Epoch 86/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.5100 - f1_score: 0.3554
# Epoch 86: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7460 - accuracy: 0.5100 - f1_score: 0.3554 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 87/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.5100 - f1_score: 0.3552
# Epoch 87: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7460 - accuracy: 0.5100 - f1_score: 0.3552 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 88/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3561
# Epoch 88: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3561 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 89/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7487 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 89: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7487 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3547
# Epoch 90: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3547 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7465 - accuracy: 0.5100 - f1_score: 0.3549
# Epoch 91: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7465 - accuracy: 0.5100 - f1_score: 0.3549 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 92/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7462 - accuracy: 0.5100 - f1_score: 0.3530
# Epoch 92: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7462 - accuracy: 0.5100 - f1_score: 0.3530 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7486 - accuracy: 0.5100 - f1_score: 0.3556
# Epoch 93: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 24s 1s/step - loss: 0.7486 - accuracy: 0.5100 - f1_score: 0.3556 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 94/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.5100 - f1_score: 0.3564
# Epoch 94: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7464 - accuracy: 0.5100 - f1_score: 0.3564 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 95/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7481 - accuracy: 0.5100 - f1_score: 0.3591
# Epoch 95: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7481 - accuracy: 0.5100 - f1_score: 0.3591 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 96/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.5100 - f1_score: 0.3543
# Epoch 96: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7498 - accuracy: 0.5100 - f1_score: 0.3543 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 97/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7495 - accuracy: 0.5100 - f1_score: 0.3568
# Epoch 97: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7495 - accuracy: 0.5100 - f1_score: 0.3568 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 98/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3547
# Epoch 98: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3547 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 99/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 99: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 25s 2s/step - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 100/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7475 - accuracy: 0.5100 - f1_score: 0.3569
# Epoch 100: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7475 - accuracy: 0.5100 - f1_score: 0.3569 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 101/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7489 - accuracy: 0.5100 - f1_score: 0.3535
# Epoch 101: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7489 - accuracy: 0.5100 - f1_score: 0.3535 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 102/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7531 - accuracy: 0.5100 - f1_score: 0.3512
# Epoch 102: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7531 - accuracy: 0.5100 - f1_score: 0.3512 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3531
# Epoch 103: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7492 - accuracy: 0.5100 - f1_score: 0.3531 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 104/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7563 - accuracy: 0.5100 - f1_score: 0.3496
# Epoch 104: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7563 - accuracy: 0.5100 - f1_score: 0.3496 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 105/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3551
# Epoch 105: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 105: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3551 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 2.5000e-05
# Epoch 106/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7457 - accuracy: 0.5100 - f1_score: 0.3556
# Epoch 106: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7457 - accuracy: 0.5100 - f1_score: 0.3556 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 107/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3560
# Epoch 107: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3560 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 108/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7466 - accuracy: 0.5100 - f1_score: 0.3561
# Epoch 108: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7466 - accuracy: 0.5100 - f1_score: 0.3561 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 109/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.5100 - f1_score: 0.3545
# Epoch 109: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7473 - accuracy: 0.5100 - f1_score: 0.3545 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 110/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3564
# Epoch 110: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3564 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 111/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7500 - accuracy: 0.5100 - f1_score: 0.3557
# Epoch 111: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 24s 2s/step - loss: 0.7500 - accuracy: 0.5100 - f1_score: 0.3557 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 112/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7455 - accuracy: 0.5100 - f1_score: 0.3561
# Epoch 112: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7455 - accuracy: 0.5100 - f1_score: 0.3561 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 113/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7504 - accuracy: 0.5100 - f1_score: 0.3562
# Epoch 113: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7504 - accuracy: 0.5100 - f1_score: 0.3562 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 114/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.5100 - f1_score: 0.3572
# Epoch 114: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7474 - accuracy: 0.5100 - f1_score: 0.3572 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 115/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 115: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 116/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7475 - accuracy: 0.5100 - f1_score: 0.3560
# Epoch 116: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7475 - accuracy: 0.5100 - f1_score: 0.3560 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 117/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3552
# Epoch 117: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3552 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 118/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7463 - accuracy: 0.5100 - f1_score: 0.3564
# Epoch 118: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7463 - accuracy: 0.5100 - f1_score: 0.3564 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 119/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.5100 - f1_score: 0.3539
# Epoch 119: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7557 - accuracy: 0.5100 - f1_score: 0.3539 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 120/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7455 - accuracy: 0.5100 - f1_score: 0.3559
# Epoch 120: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7455 - accuracy: 0.5100 - f1_score: 0.3559 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 121/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3568
# Epoch 121: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3568 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7462 - accuracy: 0.5100 - f1_score: 0.3546
# Epoch 122: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7462 - accuracy: 0.5100 - f1_score: 0.3546 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 123/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7449 - accuracy: 0.5100 - f1_score: 0.3559
# Epoch 123: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7449 - accuracy: 0.5100 - f1_score: 0.3559 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 124/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7466 - accuracy: 0.5100 - f1_score: 0.3544
# Epoch 124: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 24s 2s/step - loss: 0.7466 - accuracy: 0.5100 - f1_score: 0.3544 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 125/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7459 - accuracy: 0.5100 - f1_score: 0.3569
# Epoch 125: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 125: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7459 - accuracy: 0.5100 - f1_score: 0.3569 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 1.2500e-05
# Epoch 126/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3538
# Epoch 126: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3538 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 127/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7513 - accuracy: 0.5100 - f1_score: 0.3525
# Epoch 127: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7513 - accuracy: 0.5100 - f1_score: 0.3525 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7523 - accuracy: 0.5100 - f1_score: 0.3541
# Epoch 128: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7523 - accuracy: 0.5100 - f1_score: 0.3541 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 129/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7502 - accuracy: 0.5100 - f1_score: 0.3559
# Epoch 129: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7502 - accuracy: 0.5100 - f1_score: 0.3559 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 130/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3558
# Epoch 130: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 24s 1s/step - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3558 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 131/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3545
# Epoch 131: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3545 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 132/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7500 - accuracy: 0.5100 - f1_score: 0.3560
# Epoch 132: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7500 - accuracy: 0.5100 - f1_score: 0.3560 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7453 - accuracy: 0.5100 - f1_score: 0.3562
# Epoch 133: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7453 - accuracy: 0.5100 - f1_score: 0.3562 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 134/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3555
# Epoch 134: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7471 - accuracy: 0.5100 - f1_score: 0.3555 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 135/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7491 - accuracy: 0.5100 - f1_score: 0.3535
# Epoch 135: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7491 - accuracy: 0.5100 - f1_score: 0.3535 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 136/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3543
# Epoch 136: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3543 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 137/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3553
# Epoch 137: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7472 - accuracy: 0.5100 - f1_score: 0.3553 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 138/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3564
# Epoch 138: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7470 - accuracy: 0.5100 - f1_score: 0.3564 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 139/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7450 - accuracy: 0.5100 - f1_score: 0.3569
# Epoch 139: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7450 - accuracy: 0.5100 - f1_score: 0.3569 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 140/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3546
# Epoch 140: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7476 - accuracy: 0.5100 - f1_score: 0.3546 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 141/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3574
# Epoch 141: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7468 - accuracy: 0.5100 - f1_score: 0.3574 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 142/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3559
# Epoch 142: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7484 - accuracy: 0.5100 - f1_score: 0.3559 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 143/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7501 - accuracy: 0.5100 - f1_score: 0.3571
# Epoch 143: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7501 - accuracy: 0.5100 - f1_score: 0.3571 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 144/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3555
# Epoch 144: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7467 - accuracy: 0.5100 - f1_score: 0.3555 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 145/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7480 - accuracy: 0.5100 - f1_score: 0.3571Restoring model weights from the end of the best epoch: 45.
#
# Epoch 145: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 145: val_f1_score did not improve from 0.73746
# 16/16 [==============================] - 23s 1s/step - loss: 0.7480 - accuracy: 0.5100 - f1_score: 0.3571 - val_loss: 0.3510 - val_accuracy: 0.7407 - val_f1_score: 0.4341 - lr: 6.2500e-06
# Epoch 145: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 28ms/step
# 0.7469135802469136

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7469135802469136
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.51      0.61      0.56        85
#            0       0.85      0.79      0.82       239
#
#     accuracy                           0.75       324
#    macro avg       0.68      0.70      0.69       324
# weighted avg       0.76      0.75      0.75       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 242 chiếm khoảng 74.69135802469135% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 52 chiếm khoảng 61.1764705882353% so với thực tế
