# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#
#  global_average_pooling1d (  (None, 1024)              0
#  GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19622530 (74.85 MB)
# Trainable params: 19622530 (74.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Set data order
data_order = 5

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.3110 - f1_score: 0.2372
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.hdf5
# 11/11 [==============================] - 13s 1s/step - loss: 0.6954 - accuracy: 0.3110 - f1_score: 0.2372 - val_loss: 0.6831 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 2/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.7637 - f1_score: 0.4385
# Epoch 2: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 10s 896ms/step - loss: 0.6934 - accuracy: 0.7637 - f1_score: 0.4385 - val_loss: 0.6873 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 3/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.7637 - f1_score: 0.4322
# Epoch 3: val_f1_score did not improve from 0.42467
# 11/11 [==============================] - 11s 982ms/step - loss: 0.6933 - accuracy: 0.7637 - f1_score: 0.4322 - val_loss: 0.6858 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 1.0000e-04
# Epoch 4/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.7637 - f1_score: 0.4310
# Epoch 4: val_f1_score improved from 0.42467 to 0.47196, saving model to best_model.hdf5
# 11/11 [==============================] - 11s 1s/step - loss: 0.6918 - accuracy: 0.7637 - f1_score: 0.4310 - val_loss: 0.6830 - val_accuracy: 0.7253 - val_f1_score: 0.4720 - lr: 1.0000e-04
# Epoch 5/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.6814 - f1_score: 0.5427
# Epoch 5: val_f1_score improved from 0.47196 to 0.53043, saving model to best_model.hdf5
# 11/11 [==============================] - 12s 1s/step - loss: 0.6865 - accuracy: 0.6814 - f1_score: 0.5427 - val_loss: 0.6496 - val_accuracy: 0.7130 - val_f1_score: 0.5304 - lr: 1.0000e-04
# Epoch 6/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.6723 - f1_score: 0.5503
# Epoch 6: val_f1_score did not improve from 0.53043
# 11/11 [==============================] - 11s 1s/step - loss: 0.6666 - accuracy: 0.6723 - f1_score: 0.5503 - val_loss: 0.7492 - val_accuracy: 0.3673 - val_f1_score: 0.3292 - lr: 1.0000e-04
# Epoch 7/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.5823 - f1_score: 0.5574
# Epoch 7: val_f1_score did not improve from 0.53043
# 11/11 [==============================] - 12s 1s/step - loss: 0.6354 - accuracy: 0.5823 - f1_score: 0.5574 - val_loss: 0.7374 - val_accuracy: 0.5062 - val_f1_score: 0.4990 - lr: 1.0000e-04
# Epoch 8/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.6753 - f1_score: 0.6386
# Epoch 8: val_f1_score improved from 0.53043 to 0.67716, saving model to best_model.hdf5
# 11/11 [==============================] - 16s 1s/step - loss: 0.5771 - accuracy: 0.6753 - f1_score: 0.6386 - val_loss: 0.5810 - val_accuracy: 0.6944 - val_f1_score: 0.6772 - lr: 1.0000e-04
# Epoch 9/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.7576 - f1_score: 0.6995
# Epoch 9: val_f1_score did not improve from 0.67716
# 11/11 [==============================] - 20s 2s/step - loss: 0.5196 - accuracy: 0.7576 - f1_score: 0.6995 - val_loss: 0.8846 - val_accuracy: 0.5833 - val_f1_score: 0.5903 - lr: 1.0000e-04
# Epoch 10/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7454 - f1_score: 0.6941
# Epoch 10: val_f1_score improved from 0.67716 to 0.70736, saving model to best_model.hdf5
# 11/11 [==============================] - 19s 2s/step - loss: 0.4996 - accuracy: 0.7454 - f1_score: 0.6941 - val_loss: 0.5945 - val_accuracy: 0.7222 - val_f1_score: 0.7074 - lr: 1.0000e-04
# Epoch 11/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4452 - accuracy: 0.8140 - f1_score: 0.7780
# Epoch 11: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 22s 2s/step - loss: 0.4452 - accuracy: 0.8140 - f1_score: 0.7780 - val_loss: 0.7306 - val_accuracy: 0.6728 - val_f1_score: 0.6795 - lr: 1.0000e-04
# Epoch 12/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.8079 - f1_score: 0.7779
# Epoch 12: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 26s 2s/step - loss: 0.4150 - accuracy: 0.8079 - f1_score: 0.7779 - val_loss: 0.5885 - val_accuracy: 0.7037 - val_f1_score: 0.5952 - lr: 1.0000e-04
# Epoch 13/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8155 - f1_score: 0.7799
# Epoch 13: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 25s 2s/step - loss: 0.4265 - accuracy: 0.8155 - f1_score: 0.7799 - val_loss: 0.7515 - val_accuracy: 0.6728 - val_f1_score: 0.6807 - lr: 1.0000e-04
# Epoch 14/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3495 - accuracy: 0.8338 - f1_score: 0.8071
# Epoch 14: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 26s 2s/step - loss: 0.3495 - accuracy: 0.8338 - f1_score: 0.8071 - val_loss: 0.7423 - val_accuracy: 0.6821 - val_f1_score: 0.6892 - lr: 1.0000e-04
# Epoch 15/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.8598 - f1_score: 0.8237
# Epoch 15: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 27s 2s/step - loss: 0.3122 - accuracy: 0.8598 - f1_score: 0.8237 - val_loss: 0.8186 - val_accuracy: 0.6790 - val_f1_score: 0.6760 - lr: 1.0000e-04
# Epoch 16/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8750 - f1_score: 0.8281
# Epoch 16: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 28s 3s/step - loss: 0.3059 - accuracy: 0.8750 - f1_score: 0.8281 - val_loss: 1.1561 - val_accuracy: 0.5463 - val_f1_score: 0.5678 - lr: 1.0000e-04
# Epoch 17/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.8338 - f1_score: 0.8083
# Epoch 17: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 33s 3s/step - loss: 0.3257 - accuracy: 0.8338 - f1_score: 0.8083 - val_loss: 0.8086 - val_accuracy: 0.7068 - val_f1_score: 0.5758 - lr: 1.0000e-04
# Epoch 18/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8140 - f1_score: 0.7718
# Epoch 18: val_f1_score did not improve from 0.70736
# 11/11 [==============================] - 32s 3s/step - loss: 0.4137 - accuracy: 0.8140 - f1_score: 0.7718 - val_loss: 0.5703 - val_accuracy: 0.7222 - val_f1_score: 0.6872 - lr: 1.0000e-04
# Epoch 19/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8125 - f1_score: 0.7893
# Epoch 19: val_f1_score improved from 0.70736 to 0.71636, saving model to best_model.hdf5
# 11/11 [==============================] - 36s 3s/step - loss: 0.3603 - accuracy: 0.8125 - f1_score: 0.7893 - val_loss: 0.6687 - val_accuracy: 0.7377 - val_f1_score: 0.7164 - lr: 1.0000e-04
# Epoch 20/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.8902 - f1_score: 0.8563
# Epoch 20: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 0.2396 - accuracy: 0.8902 - f1_score: 0.8563 - val_loss: 1.0335 - val_accuracy: 0.7068 - val_f1_score: 0.6402 - lr: 1.0000e-04
# Epoch 21/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.8963 - f1_score: 0.8690
# Epoch 21: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 0.2495 - accuracy: 0.8963 - f1_score: 0.8690 - val_loss: 0.8388 - val_accuracy: 0.6728 - val_f1_score: 0.6491 - lr: 1.0000e-04
# Epoch 22/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8720 - f1_score: 0.8443
# Epoch 22: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 0.2607 - accuracy: 0.8720 - f1_score: 0.8443 - val_loss: 1.0141 - val_accuracy: 0.6636 - val_f1_score: 0.6814 - lr: 1.0000e-04
# Epoch 23/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9162 - f1_score: 0.8560
# Epoch 23: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 0.1987 - accuracy: 0.9162 - f1_score: 0.8560 - val_loss: 1.0018 - val_accuracy: 0.6574 - val_f1_score: 0.6440 - lr: 1.0000e-04
# Epoch 24/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9512 - f1_score: 0.9412
# Epoch 24: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 43s 4s/step - loss: 0.1198 - accuracy: 0.9512 - f1_score: 0.9412 - val_loss: 1.5090 - val_accuracy: 0.7377 - val_f1_score: 0.6769 - lr: 1.0000e-04
# Epoch 25/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9421 - f1_score: 0.9259
# Epoch 25: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 0.1613 - accuracy: 0.9421 - f1_score: 0.9259 - val_loss: 1.2548 - val_accuracy: 0.6451 - val_f1_score: 0.6629 - lr: 1.0000e-04
# Epoch 26/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8521 - f1_score: 0.8141
# Epoch 26: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 45s 4s/step - loss: 0.3315 - accuracy: 0.8521 - f1_score: 0.8141 - val_loss: 0.8400 - val_accuracy: 0.5648 - val_f1_score: 0.6200 - lr: 1.0000e-04
# Epoch 27/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8445 - f1_score: 0.8228
# Epoch 27: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 46s 4s/step - loss: 0.3332 - accuracy: 0.8445 - f1_score: 0.8228 - val_loss: 0.9816 - val_accuracy: 0.6173 - val_f1_score: 0.6535 - lr: 1.0000e-04
# Epoch 28/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.8506 - f1_score: 0.8285
# Epoch 28: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 0.2882 - accuracy: 0.8506 - f1_score: 0.8285 - val_loss: 0.8373 - val_accuracy: 0.6914 - val_f1_score: 0.6648 - lr: 1.0000e-04
# Epoch 29/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9375 - f1_score: 0.9095
# Epoch 29: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 0.1456 - accuracy: 0.9375 - f1_score: 0.9095 - val_loss: 1.1974 - val_accuracy: 0.6975 - val_f1_score: 0.6645 - lr: 1.0000e-04
# Epoch 30/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9543 - f1_score: 0.9359
# Epoch 30: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 0.1127 - accuracy: 0.9543 - f1_score: 0.9359 - val_loss: 1.2187 - val_accuracy: 0.6975 - val_f1_score: 0.6586 - lr: 1.0000e-04
# Epoch 31/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9832 - f1_score: 0.9781
# Epoch 31: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 0.0512 - accuracy: 0.9832 - f1_score: 0.9781 - val_loss: 1.5257 - val_accuracy: 0.7253 - val_f1_score: 0.7020 - lr: 1.0000e-04
# Epoch 32/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9848 - f1_score: 0.9814
# Epoch 32: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 0.0385 - accuracy: 0.9848 - f1_score: 0.9814 - val_loss: 2.0505 - val_accuracy: 0.7284 - val_f1_score: 0.6484 - lr: 1.0000e-04
# Epoch 33/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9802 - f1_score: 0.9753
# Epoch 33: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 0.0415 - accuracy: 0.9802 - f1_score: 0.9753 - val_loss: 1.7637 - val_accuracy: 0.7377 - val_f1_score: 0.7057 - lr: 1.0000e-04
# Epoch 34/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9634 - f1_score: 0.9455
# Epoch 34: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 0.0891 - accuracy: 0.9634 - f1_score: 0.9455 - val_loss: 1.5854 - val_accuracy: 0.6512 - val_f1_score: 0.6651 - lr: 1.0000e-04
# Epoch 35/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9223 - f1_score: 0.9070
# Epoch 35: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 0.1581 - accuracy: 0.9223 - f1_score: 0.9070 - val_loss: 1.1519 - val_accuracy: 0.6852 - val_f1_score: 0.6511 - lr: 1.0000e-04
# Epoch 36/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9665 - f1_score: 0.9571
# Epoch 36: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 0.0874 - accuracy: 0.9665 - f1_score: 0.9571 - val_loss: 1.2919 - val_accuracy: 0.7315 - val_f1_score: 0.7097 - lr: 1.0000e-04
# Epoch 37/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9817 - f1_score: 0.9786
# Epoch 37: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 0.0514 - accuracy: 0.9817 - f1_score: 0.9786 - val_loss: 1.5531 - val_accuracy: 0.7191 - val_f1_score: 0.6773 - lr: 1.0000e-04
# Epoch 38/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9970 - f1_score: 0.9967
# Epoch 38: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 0.0196 - accuracy: 0.9970 - f1_score: 0.9967 - val_loss: 2.0666 - val_accuracy: 0.7191 - val_f1_score: 0.6833 - lr: 1.0000e-04
# Epoch 39/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985 - f1_score: 0.9984
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 39: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 0.0035 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 2.2511 - val_accuracy: 0.7130 - val_f1_score: 0.6697 - lr: 1.0000e-04
# Epoch 40/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 40: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3383 - val_accuracy: 0.7191 - val_f1_score: 0.6755 - lr: 5.0000e-05
# Epoch 41/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.4850e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 41: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 5.4850e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4136 - val_accuracy: 0.7222 - val_f1_score: 0.6926 - lr: 5.0000e-05
# Epoch 42/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.0097e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 42: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 6.0097e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4869 - val_accuracy: 0.7191 - val_f1_score: 0.6874 - lr: 5.0000e-05
# Epoch 43/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.8633e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 43: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 3.8633e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5609 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 44/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.0014e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 44: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 3.0014e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6143 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 45/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.5535e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 45: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.5535e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6552 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 46/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.2421e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 46: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.2421e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.6913 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 47/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0004e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 47: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.0004e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7226 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 48/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.7868e-04 - accuracy: 1.0000 - f1_score: 0.9545
# Epoch 48: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 1.7868e-04 - accuracy: 1.0000 - f1_score: 0.9545 - val_loss: 2.7523 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 49/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.6095e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 49: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 37s 3s/step - loss: 1.6095e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.7806 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 50/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.4504e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 50: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 1.4504e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8110 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 51/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.3124e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 51: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 1.3124e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8420 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 52/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.1894e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 52: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 1.1894e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.8706 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 53/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.0787e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 1.0787e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9011 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 54/10000
# 11/11 [==============================] - ETA: 0s - loss: 9.8357e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 9.8357e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9294 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 55/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.9965e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 55: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 8.9965e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9557 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 56/10000
# 11/11 [==============================] - ETA: 0s - loss: 8.2896e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 56: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 8.2896e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.9830 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 57/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.6041e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 57: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 7.6041e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.0088 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 58/10000
# 11/11 [==============================] - ETA: 0s - loss: 7.0289e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 58: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 7.0289e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.0355 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 5.0000e-05
# Epoch 59/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.4769e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 59: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 59: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 6.4769e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.0624 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 5.0000e-05
# Epoch 60/10000
# 11/11 [==============================] - ETA: 0s - loss: 6.0733e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 60: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 6.0733e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.0750 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 61/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.8458e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 61: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 5.8458e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.0877 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 62/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.6096e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 62: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 5.6096e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1010 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 63/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.4031e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 63: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 5.4031e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1147 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 64/10000
# 11/11 [==============================] - ETA: 0s - loss: 5.1820e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 64: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 37s 3s/step - loss: 5.1820e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1275 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 65/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.9985e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 65: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 4.9985e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1406 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 66/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.8071e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 66: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 4.8071e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1534 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 67/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.6221e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 67: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 4.6221e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1660 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 68/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.4560e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 68: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 4.4560e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1785 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 69/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.2924e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 69: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 43s 4s/step - loss: 4.2924e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.1908 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 70/10000
# 11/11 [==============================] - ETA: 0s - loss: 4.1369e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 70: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 4.1369e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2036 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 2.5000e-05
# Epoch 71/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.9860e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 3.9860e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2159 - val_accuracy: 0.7130 - val_f1_score: 0.6735 - lr: 2.5000e-05
# Epoch 72/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.8477e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 72: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 3.8477e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2283 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 73/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.7111e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 73: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 3.7111e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2405 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 74/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.5807e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 74: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 3.5807e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2525 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 75/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.4623e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 75: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 43s 4s/step - loss: 3.4623e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2645 - val_accuracy: 0.7160 - val_f1_score: 0.6755 - lr: 2.5000e-05
# Epoch 76/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.3429e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 76: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 3.3429e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2763 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 2.5000e-05
# Epoch 77/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.2224e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 77: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 3.2224e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.2885 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 2.5000e-05
# Epoch 78/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.1178e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 78: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 3.1178e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3004 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 2.5000e-05
# Epoch 79/10000
# 11/11 [==============================] - ETA: 0s - loss: 3.0122e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 79: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 3.0122e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3119 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 2.5000e-05
# Epoch 80/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.9306e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 80: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.9306e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3178 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 81/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.8838e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 81: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.8838e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3234 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 82/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.8378e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 82: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 2.8378e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3296 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 83/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.7877e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 83: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.7877e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3352 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 84/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.7433e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 84: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 2.7433e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3411 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 85/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.6959e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 85: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 2.6959e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3468 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 86/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.6514e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 86: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 2.6514e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3531 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 87/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.6039e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 87: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 2.6039e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3594 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 88/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.5578e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 88: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 2.5578e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3654 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 89/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.5154e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 89: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.5154e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3712 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 90/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.4747e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 90: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 44s 4s/step - loss: 2.4747e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3769 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 91/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.4328e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 38s 3s/step - loss: 2.4328e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3827 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 92/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.3933e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 92: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 3s/step - loss: 2.3933e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3884 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 93/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.3537e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.3537e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.3941 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 94/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.3144e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 94: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 2.3144e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4000 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 95/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.2779e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 95: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 2.2779e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4063 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 96/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.2378e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 96: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 2.2378e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4123 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 97/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.2020e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 97: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 2.2020e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4178 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 98/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.1670e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 98: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 2.1670e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4232 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 99/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.1328e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 99: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 99: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.1328e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4289 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 1.2500e-05
# Epoch 100/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.1060e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 100: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 2.1060e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4317 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 101/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0900e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 101: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 2.0900e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4345 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 102/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0732e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 102: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 2.0732e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4373 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 103/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0565e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 103: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 2.0565e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4402 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 104/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0409e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 104: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.0409e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4429 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 105/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0251e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 105: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 2.0251e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4455 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 106/10000
# 11/11 [==============================] - ETA: 0s - loss: 2.0107e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 106: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 39s 4s/step - loss: 2.0107e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4482 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 107/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9951e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 107: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 1.9951e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4507 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 108/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9802e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 108: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 1.9802e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4533 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 109/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9651e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 109: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 1.9651e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4560 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 110/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9512e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 110: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 1.9512e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4588 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 111/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9353e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 111: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 44s 4s/step - loss: 1.9353e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4615 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 112/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9201e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 112: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 1.9201e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4642 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 113/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.9056e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 1.9056e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4673 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 114/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8900e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 114: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 41s 4s/step - loss: 1.8900e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4701 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 115/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8743e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 115: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 44s 4s/step - loss: 1.8743e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4728 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 116/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8606e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 116: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 40s 4s/step - loss: 1.8606e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4755 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 117/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8458e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 117: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 1.8458e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4782 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 118/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8322e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 118: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 42s 4s/step - loss: 1.8322e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4809 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 119/10000
# 11/11 [==============================] - ETA: 0s - loss: 1.8184e-05 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 19.
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 119: val_f1_score did not improve from 0.71636
# 11/11 [==============================] - 43s 4s/step - loss: 1.8184e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 3.4838 - val_accuracy: 0.7191 - val_f1_score: 0.6776 - lr: 6.2500e-06
# Epoch 119: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 9s 80ms/step
# 0.7376543209876543

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7376543209876543
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.50      0.58      0.54        85
#            0       0.84      0.79      0.82       239
#
#     accuracy                           0.74       324
#    macro avg       0.67      0.69      0.68       324
# weighted avg       0.75      0.74      0.74       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 239 chiếm khoảng 73.76543209876543% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 49 chiếm khoảng 57.647058823529406% so với thực tế
