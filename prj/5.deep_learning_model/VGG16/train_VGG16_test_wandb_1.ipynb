# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# wandb.init(project="ads_nckh_fraud_detection")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
from tensorflow.keras.optimizers.legacy import Adam
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
import tensorflow as tf
input_shape =(42,1)
x_input = Input(shape=input_shape)
dense_units = 1024
learning_rate = 0.0001
kernel_size =3
filter_size=128


# Block 1
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv1')(x_input)
x = Conv1D(filter_size, kernel_size, activation='relu', padding='same', name='block1_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

# Block 2
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
x = Conv1D(filter_size*2, kernel_size, activation='relu', padding='same', name='block2_conv2')(x)
x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

# Block 3
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv1')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv2')(x)
x = Conv1D(filter_size*4, kernel_size, activation='relu', padding='same', name='block3_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

# Block 4
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block4_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

# Block 5
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv1')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv2')(x)
x = Conv1D(filter_size*8, kernel_size, activation='relu', padding='same', name='block5_conv3')(x)
x = MaxPooling1D(2, strides=2, name='block5_pool')(x)

# x = Flatten(name='flatten')(x)
# x = Dense(dense_units, activation='relu', name='fc1')(x)
# x = Dense(dense_units, activation='relu', name='fc2')(x)
# x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

x = GlobalAveragePooling1D()(x)
# x = GlobalMaxPooling1D()(x)
x = Dense(2, activation='softmax', name='predictions')(x)  # Sigmoid for binary classification

# Create model.
model = Model(x_input, x, name='vgg16')
# model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 42, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 5, 512)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 1024)           1573888
#
#  block4_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block4_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 2, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 1, 1024)           0
#  global_average_pooling1d (  (None, 1024)              0
#  GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19622530 (74.85 MB)
# Trainable params: 19622530 (74.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Set data order
data_order = 8

# %%
print(dict_data[data_order][1].dtype)
# Out:
# float64

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.8318 - accuracy: 0.4980 - f1_score: 0.3424
# Epoch 1: val_f1_score improved from -inf to 0.20537, saving model to best_model.hdf5
# 16/16 [==============================] - 43s 2s/step - loss: 0.8318 - accuracy: 0.4980 - f1_score: 0.3424 - val_loss: 1.1695 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7989 - accuracy: 0.5000 - f1_score: 0.3317
# Epoch 2: val_f1_score did not improve from 0.20537
# 16/16 [==============================] - 30s 2s/step - loss: 0.7989 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 1.2800 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7690 - accuracy: 0.5000 - f1_score: 0.3319
# Epoch 3: val_f1_score did not improve from 0.20537
# 16/16 [==============================] - 40s 2s/step - loss: 0.7690 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 1.0917 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.5000 - f1_score: 0.3321
# Epoch 4: val_f1_score did not improve from 0.20537
# 16/16 [==============================] - 38s 2s/step - loss: 0.7520 - accuracy: 0.5000 - f1_score: 0.3321 - val_loss: 1.0331 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.5000 - f1_score: 0.3328
# Epoch 5: val_f1_score did not improve from 0.20537
# 16/16 [==============================] - 41s 3s/step - loss: 0.6906 - accuracy: 0.5000 - f1_score: 0.3328 - val_loss: 1.3474 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.0000e-04
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5672 - accuracy: 0.5788 - f1_score: 0.4726
# Epoch 6: val_f1_score improved from 0.20537 to 0.61188, saving model to best_model.hdf5
# 16/16 [==============================] - 50s 3s/step - loss: 0.5672 - accuracy: 0.5788 - f1_score: 0.4726 - val_loss: 0.9978 - val_accuracy: 0.5556 - val_f1_score: 0.6119 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5343 - accuracy: 0.7814 - f1_score: 0.7714
# Epoch 7: val_f1_score did not improve from 0.61188
# 16/16 [==============================] - 49s 3s/step - loss: 0.5343 - accuracy: 0.7814 - f1_score: 0.7714 - val_loss: 0.9792 - val_accuracy: 0.4877 - val_f1_score: 0.4827 - lr: 1.0000e-04
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.7685 - f1_score: 0.7533
# Epoch 8: val_f1_score improved from 0.61188 to 0.65547, saving model to best_model.hdf5
# 16/16 [==============================] - 58s 4s/step - loss: 0.4659 - accuracy: 0.7685 - f1_score: 0.7533 - val_loss: 0.6859 - val_accuracy: 0.6667 - val_f1_score: 0.6555 - lr: 1.0000e-04
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8393 - f1_score: 0.8342
# Epoch 9: val_f1_score improved from 0.65547 to 0.67139, saving model to best_model.hdf5
# 16/16 [==============================] - 62s 4s/step - loss: 0.3728 - accuracy: 0.8393 - f1_score: 0.8342 - val_loss: 0.8358 - val_accuracy: 0.6636 - val_f1_score: 0.6714 - lr: 1.0000e-04
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3646 - accuracy: 0.8533 - f1_score: 0.8485
# Epoch 10: val_f1_score did not improve from 0.67139
# 16/16 [==============================] - 63s 4s/step - loss: 0.3646 - accuracy: 0.8533 - f1_score: 0.8485 - val_loss: 0.6163 - val_accuracy: 0.6698 - val_f1_score: 0.6447 - lr: 1.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.8533 - f1_score: 0.8488
# Epoch 11: val_f1_score did not improve from 0.67139
# 16/16 [==============================] - 62s 4s/step - loss: 0.3130 - accuracy: 0.8533 - f1_score: 0.8488 - val_loss: 0.8281 - val_accuracy: 0.7037 - val_f1_score: 0.6436 - lr: 1.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8453 - f1_score: 0.8379
# Epoch 12: val_f1_score did not improve from 0.67139
# 16/16 [==============================] - 68s 4s/step - loss: 0.3706 - accuracy: 0.8453 - f1_score: 0.8379 - val_loss: 0.7877 - val_accuracy: 0.6296 - val_f1_score: 0.6528 - lr: 1.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.8812 - f1_score: 0.8747
# Epoch 13: val_f1_score improved from 0.67139 to 0.67153, saving model to best_model.hdf5
# 16/16 [==============================] - 72s 4s/step - loss: 0.2667 - accuracy: 0.8812 - f1_score: 0.8747 - val_loss: 0.9383 - val_accuracy: 0.6605 - val_f1_score: 0.6715 - lr: 1.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9162 - f1_score: 0.9133
# Epoch 14: val_f1_score did not improve from 0.67153
# 16/16 [==============================] - 61s 4s/step - loss: 0.2156 - accuracy: 0.9162 - f1_score: 0.9133 - val_loss: 0.9840 - val_accuracy: 0.6574 - val_f1_score: 0.6683 - lr: 1.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9242 - f1_score: 0.9230
# Epoch 15: val_f1_score did not improve from 0.67153
# 16/16 [==============================] - 61s 4s/step - loss: 0.1786 - accuracy: 0.9242 - f1_score: 0.9230 - val_loss: 1.1546 - val_accuracy: 0.6420 - val_f1_score: 0.6536 - lr: 1.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9152 - f1_score: 0.9120
# Epoch 16: val_f1_score improved from 0.67153 to 0.67675, saving model to best_model.hdf5
# 16/16 [==============================] - 63s 4s/step - loss: 0.1972 - accuracy: 0.9152 - f1_score: 0.9120 - val_loss: 0.9789 - val_accuracy: 0.6914 - val_f1_score: 0.6768 - lr: 1.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1779 - accuracy: 0.9351 - f1_score: 0.9339
# Epoch 17: val_f1_score improved from 0.67675 to 0.70299, saving model to best_model.hdf5
# 16/16 [==============================] - 66s 4s/step - loss: 0.1779 - accuracy: 0.9351 - f1_score: 0.9339 - val_loss: 1.0959 - val_accuracy: 0.7130 - val_f1_score: 0.7030 - lr: 1.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9461 - f1_score: 0.9443
# Epoch 18: val_f1_score improved from 0.70299 to 0.70748, saving model to best_model.hdf5
# 16/16 [==============================] - 64s 4s/step - loss: 0.1239 - accuracy: 0.9461 - f1_score: 0.9443 - val_loss: 1.1762 - val_accuracy: 0.7222 - val_f1_score: 0.7075 - lr: 1.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9591 - f1_score: 0.9554
# Epoch 19: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 59s 4s/step - loss: 0.1239 - accuracy: 0.9591 - f1_score: 0.9554 - val_loss: 1.0646 - val_accuracy: 0.7006 - val_f1_score: 0.6936 - lr: 1.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9451 - f1_score: 0.9438
# Epoch 20: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 60s 4s/step - loss: 0.1336 - accuracy: 0.9451 - f1_score: 0.9438 - val_loss: 1.3442 - val_accuracy: 0.6389 - val_f1_score: 0.6645 - lr: 1.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9770 - f1_score: 0.9767
# Epoch 21: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 62s 4s/step - loss: 0.0651 - accuracy: 0.9770 - f1_score: 0.9767 - val_loss: 1.6649 - val_accuracy: 0.7222 - val_f1_score: 0.6650 - lr: 1.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9511 - f1_score: 0.9502
# Epoch 22: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.1374 - accuracy: 0.9511 - f1_score: 0.9502 - val_loss: 0.9891 - val_accuracy: 0.7130 - val_f1_score: 0.6814 - lr: 1.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9611 - f1_score: 0.9612
# Epoch 23: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 59s 4s/step - loss: 0.1020 - accuracy: 0.9611 - f1_score: 0.9612 - val_loss: 1.4361 - val_accuracy: 0.6914 - val_f1_score: 0.6903 - lr: 1.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9731 - f1_score: 0.9724
# Epoch 24: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 59s 4s/step - loss: 0.0602 - accuracy: 0.9731 - f1_score: 0.9724 - val_loss: 1.5723 - val_accuracy: 0.6975 - val_f1_score: 0.6820 - lr: 1.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9741 - f1_score: 0.9742
# Epoch 25: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 60s 4s/step - loss: 0.0589 - accuracy: 0.9741 - f1_score: 0.9742 - val_loss: 1.3427 - val_accuracy: 0.7284 - val_f1_score: 0.6818 - lr: 1.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9721 - f1_score: 0.9722
# Epoch 26: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 58s 4s/step - loss: 0.0694 - accuracy: 0.9721 - f1_score: 0.9722 - val_loss: 1.3924 - val_accuracy: 0.6512 - val_f1_score: 0.6635 - lr: 1.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9750 - f1_score: 0.9749
# Epoch 27: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 58s 4s/step - loss: 0.0613 - accuracy: 0.9750 - f1_score: 0.9749 - val_loss: 1.4245 - val_accuracy: 0.7037 - val_f1_score: 0.6782 - lr: 1.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9950 - f1_score: 0.9950
# Epoch 28: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 63s 4s/step - loss: 0.0156 - accuracy: 0.9950 - f1_score: 0.9950 - val_loss: 1.7683 - val_accuracy: 0.7284 - val_f1_score: 0.6928 - lr: 1.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9980 - f1_score: 0.9975
# Epoch 29: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 60s 4s/step - loss: 0.0063 - accuracy: 0.9980 - f1_score: 0.9975 - val_loss: 2.0383 - val_accuracy: 0.7253 - val_f1_score: 0.6996 - lr: 1.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9930 - f1_score: 0.9930
# Epoch 30: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 57s 4s/step - loss: 0.0286 - accuracy: 0.9930 - f1_score: 0.9930 - val_loss: 2.2421 - val_accuracy: 0.7407 - val_f1_score: 0.6691 - lr: 1.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9401 - f1_score: 0.9382
# Epoch 31: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 62s 4s/step - loss: 0.1694 - accuracy: 0.9401 - f1_score: 0.9382 - val_loss: 1.3329 - val_accuracy: 0.5833 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9471 - f1_score: 0.9454
# Epoch 32: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.1294 - accuracy: 0.9471 - f1_score: 0.9454 - val_loss: 1.0133 - val_accuracy: 0.7253 - val_f1_score: 0.7075 - lr: 1.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9820 - f1_score: 0.9822
# Epoch 33: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 62s 4s/step - loss: 0.0555 - accuracy: 0.9820 - f1_score: 0.9822 - val_loss: 1.5107 - val_accuracy: 0.7068 - val_f1_score: 0.6925 - lr: 1.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9860 - f1_score: 0.9856
# Epoch 34: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.0295 - accuracy: 0.9860 - f1_score: 0.9856 - val_loss: 1.5714 - val_accuracy: 0.6975 - val_f1_score: 0.6631 - lr: 1.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9920 - f1_score: 0.9922
# Epoch 35: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.0174 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 2.0014 - val_accuracy: 0.6975 - val_f1_score: 0.6801 - lr: 1.0000e-04
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 36: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.0080 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.2390 - val_accuracy: 0.6852 - val_f1_score: 0.6426 - lr: 1.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 37: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 63s 4s/step - loss: 0.0062 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.4268 - val_accuracy: 0.6883 - val_f1_score: 0.6409 - lr: 1.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9960 - f1_score: 0.9960
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 38: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 63s 4s/step - loss: 0.0167 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 2.3252 - val_accuracy: 0.7006 - val_f1_score: 0.6860 - lr: 1.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 39: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 61s 4s/step - loss: 0.0097 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 1.9401 - val_accuracy: 0.7130 - val_f1_score: 0.6683 - lr: 5.0000e-05
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 40: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 59s 4s/step - loss: 0.0054 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.1966 - val_accuracy: 0.6790 - val_f1_score: 0.6778 - lr: 5.0000e-05
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 41: val_f1_score did not improve from 0.70748
# 16/16 [==============================] - 62s 4s/step - loss: 0.0037 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 2.1106 - val_accuracy: 0.7191 - val_f1_score: 0.6622 - lr: 5.0000e-05
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9830 - f1_score: 0.9827
# Epoch 42: val_f1_score did not improve from 0.70748
# 16/16 [==============================] -