# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
# Out:
# d:\ICIT

# %%
from libs.lib import *
print(tf.__version__)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]
# if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
#   os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
#Set data order
data_order = 5

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder(sparse=False)
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(f'{scaler}: {type}')
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# Standard_Label: basic
# (656, 42) (656, 2) (324, 42) (324, 2)
# Standard_Label: class_dict_weight
# (656, 42) (656, 2) (324, 42) (324, 2)
# Standard_Label: Oversampling
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# Standard_Label: SMOTE
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# Standard_Label: Undersampling
# (355, 42) (355, 2) (324, 42) (324, 2)
# MinMax_Label: basic
# (656, 42) (656, 2) (324, 42) (324, 2)
# MinMax_Label: class_dict_weight
# (656, 42) (656, 2) (324, 42) (324, 2)
# MinMax_Label: Oversampling
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# MinMax_Label: SMOTE
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# MinMax_Label: Undersampling
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder(sparse=False)
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels

x_train=dict_data[data_order][0]
x_test=dict_data[data_order][2]
# y_train_onehot=oneHot(dict_data[data_order][1])
# y_test_onehot=oneHot(dict_data[data_order][3])
y_train=dict_data[data_order][1]
y_test=dict_data[data_order][3]

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)

# %%
x_train.shape
# Out:
# (656, 42)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from scipy.stats import uniform

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    y_pred = tf.round(y_pred)
    f1 = f1_score(y_true, y_pred, average='micro')
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def dice_coef_9cat(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=10)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

def dice_coef_9cat_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef_9cat(y_true, y_pred)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from tensorflow.keras import regularizers
from tabnet_keras.models import TabNetClassifier

# Định nghĩa tham số regularization
l2_reg = 0.01

learning_rate=0.1
tabnet_params = {
    "decision_dim": 16,
    "attention_dim": 16,
    "n_steps": 3,
    "n_shared_glus": 2,
    "n_dependent_glus": 2,
    "relaxation_factor": 1.3,
    "epsilon": 1e-15,
    "momentum": 0.98,
    "mask_type": "softmax", # can be 'sparsemax' or 'softmax'
    "lambda_sparse": 1e-3, 
    "virtual_batch_splits": 8 #number of splits for ghost batch normalization, ideally should evenly divide the batch_size
}



### Classification
model = TabNetClassifier(n_classes = 2, out_activation = 'softmax', **tabnet_params)
# model = TabNetClassifier(n_classes = 2, out_activation = 'softmax', 
#     kernel_regularizer=l2(0.01), **tabnet_params)
# model.compile(loss = 'categorical_crossentropy', optimizer = )
# model.fit(x_train, y_train, epochs = 100, batch_size = 1024)
# model.add(tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',,f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',,f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_9cat_loss, metrics=['accuracy',,f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=70,
    verbose=1,
    restore_best_weights=True,
)

# checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5",monitor='val_accuracy', verbose = 1, save_best_only=True)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=30,
    min_lr=0.000001,
    verbose=1,
)

# %%
model.fit(x=x_train, y=y_train,
          validation_data=(x_test, y_test),
          batch_size=32,
          epochs=1200,
          callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/1200
# 21/21 [==============================] - 46s 42ms/step - loss: 0.6168 - accuracy: 0.7348 - f1_score: 0.7351 - val_loss: 1.0080 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 2/1200
# 21/21 [==============================] - 0s 10ms/step - loss: 0.5668 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.6426 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 3/1200
# 21/21 [==============================] - 0s 10ms/step - loss: 0.5581 - accuracy: 0.7637 - f1_score: 0.7589 - val_loss: 0.5957 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 4/1200
# 21/21 [==============================] - 0s 10ms/step - loss: 0.5760 - accuracy: 0.7637 - f1_score: 0.7679 - val_loss: 0.6237 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 5/1200
# 21/21 [==============================] - 0s 11ms/step - loss: 0.5729 - accuracy: 0.7637 - f1_score: 0.7664 - val_loss: 0.6785 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 6/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5829 - accuracy: 0.7637 - f1_score: 0.7604 - val_loss: 0.5810 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 7/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5756 - accuracy: 0.7637 - f1_score: 0.7679 - val_loss: 0.6622 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 8/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5818 - accuracy: 0.7622 - f1_score: 0.7619 - val_loss: 0.5717 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 9/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5489 - accuracy: 0.7637 - f1_score: 0.7649 - val_loss: 0.5598 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 10/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5578 - accuracy: 0.7637 - f1_score: 0.7619 - val_loss: 0.5792 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 11/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5617 - accuracy: 0.7652 - f1_score: 0.7664 - val_loss: 0.5659 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 12/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5575 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.6502 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 13/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5593 - accuracy: 0.7637 - f1_score: 0.7664 - val_loss: 0.6039 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 14/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5497 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5833 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 15/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5513 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5861 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 16/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5673 - accuracy: 0.7637 - f1_score: 0.7693 - val_loss: 0.5881 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 17/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5502 - accuracy: 0.7637 - f1_score: 0.7649 - val_loss: 0.5543 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 18/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5549 - accuracy: 0.7637 - f1_score: 0.7649 - val_loss: 0.5552 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 19/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5361 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5779 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 20/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5547 - accuracy: 0.7637 - f1_score: 0.7604 - val_loss: 0.5633 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 21/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5477 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5744 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 22/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5391 - accuracy: 0.7637 - f1_score: 0.7679 - val_loss: 0.5589 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 23/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5440 - accuracy: 0.7637 - f1_score: 0.7619 - val_loss: 0.5436 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 24/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5471 - accuracy: 0.7637 - f1_score: 0.7664 - val_loss: 0.5537 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 25/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5334 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5553 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 26/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5425 - accuracy: 0.7637 - f1_score: 0.7634 - val_loss: 0.5711 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 27/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5488 - accuracy: 0.7637 - f1_score: 0.7679 - val_loss: 0.5864 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 28/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5538 - accuracy: 0.7637 - f1_score: 0.7664 - val_loss: 0.5768 - val_accuracy: 0.7377 - val_f1_score: 0.7386 - lr: 0.1000
# Epoch 29/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.
1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4447 - accuracy: 0.7652 - f1_score: 0.7660 - val_loss: 0.4743 - val_accuracy: 0.7747 - val_f1_score: 0.7909 - lr: 0.0250
# Epoch 118/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4474 - accuracy: 0.7759 - f1_score: 0.7700 - val_loss: 0.4753 - val_accuracy: 0.7747 - val_f1_score: 0.7882 - lr: 0.0250
# Epoch 119/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4518 - accuracy: 0.7912 - f1_score: 0.7900 - val_loss: 0.4735 - val_accuracy: 0.7870 - val_f1_score: 0.7985 - lr: 0.0250
# Epoch 120/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4438 - accuracy: 0.8034 - f1_score: 0.7993 - val_loss: 0.4755 - val_accuracy: 0.7778 - val_f1_score: 0.7925 - lr: 0.0250
# Epoch 121/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4551 - accuracy: 0.8003 - f1_score: 0.8006 - val_loss: 0.4636 - val_accuracy: 0.7932 - val_f1_score: 0.8097 - lr: 0.0250
# Epoch 122/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4437 - accuracy: 0.8155 - f1_score: 0.8170 - val_loss: 0.4753 - val_accuracy: 0.7932 - val_f1_score: 0.8097 - lr: 0.0250
# Epoch 123/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4401 - accuracy: 0.8095 - f1_score: 0.8125 - val_loss: 0.4694 - val_accuracy: 0.7932 - val_f1_score: 0.8097 - lr: 0.0250
# Epoch 124/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4446 - accuracy: 0.8095 - f1_score: 0.8110 - val_loss: 0.4707 - val_accuracy: 0.7932 - val_f1_score: 0.8097 - lr: 0.0250
# Epoch 125/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4502 - accuracy: 0.8018 - f1_score: 0.8006 - val_loss: 0.4725 - val_accuracy: 0.7932 - val_f1_score: 0.8097 - lr: 0.0250
# Epoch 126/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4393 - accuracy: 0.8216 - f1_score: 0.8244 - val_loss: 0.4761 - val_accuracy: 0.7901 - val_f1_score: 0.8068 - lr: 0.0250
# Epoch 127/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4260 - accuracy: 0.8049 - f1_score: 0.8051 - val_loss: 0.4732 - val_accuracy: 0.7901 - val_f1_score: 0.8068 - lr: 0.0250
# Epoch 128/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4238 - accuracy: 0.8247 - f1_score: 0.8214 - val_loss: 0.5014 - val_accuracy: 0.7778 - val_f1_score: 0.7955 - lr: 0.0250
# Epoch 129/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4303 - accuracy: 0.8216 - f1_score: 0.8214 - val_loss: 0.5117 - val_accuracy: 0.7438 - val_f1_score: 0.7642 - lr: 0.0250
# Epoch 130/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4520 - accuracy: 0.8049 - f1_score: 0.8036 - val_loss: 0.4788 - val_accuracy: 0.7870 - val_f1_score: 0.8040 - lr: 0.0250
# Epoch 131/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4474 - accuracy: 0.8079 - f1_score: 0.8080 - val_loss: 0.4684 - val_accuracy: 0.7963 - val_f1_score: 0.8125 - lr: 0.0250
# Epoch 132/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4293 - accuracy: 0.8079 - f1_score: 0.8095 - val_loss: 0.4717 - val_accuracy: 0.7901 - val_f1_score: 0.8068 - lr: 0.0250
# Epoch 133/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4457 - accuracy: 0.8201 - f1_score: 0.8229 - val_loss: 0.4778 - val_accuracy: 0.7870 - val_f1_score: 0.8040 - lr: 0.0250
# Epoch 134/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4392 - accuracy: 0.8064 - f1_score: 0.8065 - val_loss: 0.4764 - val_accuracy: 0.7870 - val_f1_score: 0.8040 - lr: 0.0250
# Epoch 135/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.

# 21/21 [==============================] - 0s 19ms/step - loss: 0.4222 - accuracy: 0.8186 - f1_score: 0.8199 - val_loss: 0.4796 - val_accuracy: 0.7778 - val_f1_score: 0.7955 - lr: 0.0125
# Epoch 172/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4329 - accuracy: 0.8277 - f1_score: 0.8274 - val_loss: 0.4860 - val_accuracy: 0.7778 - val_f1_score: 0.7955 - lr: 0.0125
# Epoch 173/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4172 - accuracy: 0.8399 - f1_score: 0.8378 - val_loss: 0.4877 - val_accuracy: 0.7654 - val_f1_score: 0.7841 - lr: 0.0125
# Epoch 174/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4330 - accuracy: 0.8232 - f1_score: 0.8259 - val_loss: 0.4903 - val_accuracy: 0.7716 - val_f1_score: 0.7898 - lr: 0.0125
# Epoch 175/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4311 - accuracy: 0.8171 - f1_score: 0.8155 - val_loss: 0.4893 - val_accuracy: 0.7716 - val_f1_score: 0.7898 - lr: 0.0125
# Epoch 176/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4314 - accuracy: 0.8232 - f1_score: 0.8199 - val_loss: 0.5048 - val_accuracy: 0.7623 - val_f1_score: 0.7812 - lr: 0.0125
# Epoch 177/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4143 - accuracy: 0.8338 - f1_score: 0.8363 - val_loss: 0.5060 - val_accuracy: 0.7654 - val_f1_score: 0.7841 - lr: 0.0125
# Epoch 178/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4252 - accuracy: 0.8262 - f1_score: 0.8244 - val_loss: 0.5076 - val_accuracy: 0.7654 - val_f1_score: 0.7841 - lr: 0.0125
# Epoch 179/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4248 - accuracy: 0.8277 - f1_score: 0.8274 - val_loss: 0.5105 - val_accuracy: 0.7623 - val_f1_score: 0.7812 - lr: 0.0125
# Epoch 180/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4176 - accuracy: 0.8323 - f1_score: 0.8318 - val_loss: 0.5086 - val_accuracy: 0.7685 - val_f1_score: 0.7869 - lr: 0.0125
# Epoch 181/1200
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4079 - accuracy: 0.8262 - f1_score: 0.8259 - val_loss: 0.5161 - val_accuracy: 0.7623 - val_f1_score: 0.7812 - lr: 0.0125
# Epoch 182/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4219 - accuracy: 0.8293 - f1_score: 0.8304 - val_loss: 0.5106 - val_accuracy: 0.7593 - val_f1_score: 0.7784 - lr: 0.0125
# Epoch 183/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4251 - accuracy: 0.8338 - f1_score: 0.8333 - val_loss: 0.5076 - val_accuracy: 0.7623 - val_f1_score: 0.7812 - lr: 0.0125
# Epoch 184/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4265 - accuracy: 0.8277 - f1_score: 0.8229 - val_loss: 0.5080 - val_accuracy: 0.7562 - val_f1_score: 0.7756 - lr: 0.0125
# Epoch 185/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4127 - accuracy: 0.8338 - f1_score: 0.8348 - val_loss: 0.5006 - val_accuracy: 0.7747 - val_f1_score: 0.7926 - lr: 0.0125
# Epoch 186/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4068 - accuracy: 0.8415 - f1_score: 0.8408 - val_loss: 0.4935 - val_accuracy: 0.7778 - val_f1_score: 0.7955 - lr: 0.0125
# Epoch 187/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4235 - accuracy: 0.8308 - f1_score: 0.8333 - val_loss: 0.4953 - val_accuracy: 0.7716 - val_f1_score: 0.7898 - lr: 0.0125
# Epoch 188/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4280 - accuracy: 0.8293 - f1_score: 0.8289 - val_loss: 0.5724 - val_accuracy: 0.6080 - val_f1_score: 0.6193 - lr: 0.0125
# Epoch 189/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4188 - accuracy: 0.8384 - f1_score: 0.8408 - val_loss: 0.5272 - val_accuracy: 0.7377 - val_f1_score: 0.7585 - lr: 0.0125
# Epoch 190/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4244 - accuracy: 0.8369 - f1_score: 0.8378 - val_loss: 0.5235 - val_accuracy: 0.7469 - val_f1_score: 0.7670 - lr: 0.0125
# Epoch 191/1200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.4176 - accuracy: 0.8250 - f1_score: 0.8250
# Epoch 191: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4181 - accuracy: 0.8262 - f1_score: 0.8274 - val_loss: 0.5144 - val_accuracy: 0.7593 - val_f1_score: 0.7784 - lr: 0.0125
# Epoch 192/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4318 - accuracy: 0.8155 - f1_score: 0.8170 - val_loss: 0.5157 - val_accuracy: 0.7500 - val_f1_score: 0.7699 - lr: 0.0063
# Epoch 193/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4217 - accuracy: 0.8262 - f1_score: 0.8214 - val_loss: 0.5176 - val_accuracy: 0.7500 - val_f1_score: 0.7699 - lr: 0.0063
# Epoch 194/1200
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4268 - accuracy: 0.8171 - f1_score: 0.8185 - val_loss: 0.5143 - val_accuracy: 0.7500 - val_f1_score: 0.7699 - lr: 0.0063
# Epoch 195/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4251 - accuracy: 0.8216 - f1_score: 0.8214 - val_loss: 0.5107 - val_accuracy: 0.7562 - val_f1_score: 0.7756 - lr: 0.0063
# Epoch 196/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4132 - accuracy: 0.8338 - f1_score: 0.8333 - val_loss: 0.5068 - val_accuracy: 0.7654 - val_f1_score: 0.7841 - lr: 0.0063
# Epoch 197/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4116 - accuracy: 0.8308 - f1_score: 0.8333 - val_loss: 0.5107 - val_accuracy: 0.7593 - val_f1_score: 0.7784 - lr: 0.0063
# Epoch 198/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4109 - accuracy: 0.8369 - f1_score: 0.8393 - val_loss: 0.5100 - val_accuracy: 0.7654 - val_f1_score: 0.7841 - lr: 0.0063
# Epoch 199/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4109 - accuracy: 0.8308 - f1_score: 0.8259 - val_loss: 0.5194 - val_accuracy: 0.7562 - val_f1_score: 0.7756 - lr: 0.0063
# Epoch 200/1200
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4140 - accuracy: 0.8323 - f1_score: 0.8304 - val_loss: 0.5117 - val_accuracy: 0.7623 - val_f1_score: 0.7812 - lr: 0.0063
# Epoch 201/1200
# 21/21 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8140 - f1_score: 0.8140Restoring model weights from the end of the best epoch: 131.
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4360 - accuracy: 0.8140 - f1_score: 0.8140 - val_loss: 0.5099 - val_accuracy: 0.7593 - val_f1_score: 0.7784 - lr: 0.0063
# Epoch 201: early stopping

# %%
model.summary()
# Out:
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnc  multiple                  27904
#  oder)
#
#  classifier (Dense)          multiple                  32
#
# =================================================================
# Total params: 27936 (109.12 KB)
# Trainable params: 25552 (99.81 KB)
# Non-trainable params: 2384 (9.31 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 0.7962962962962963

# %%
model.save_weights("tabnet_fraud2.h5")

# %%
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7962962962962963
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.61      0.64      0.62        85
#            0       0.87      0.85      0.86       239
#
#     accuracy                           0.80       324
#    macro avg       0.74      0.74      0.74       324
# weighted avg       0.80      0.80      0.80       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 258 chiếm khoảng 79.62962962962963% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 54 chiếm khoảng 63.52941176470588% so với thực tế
