# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K
from sklearn.metrics import make_scorer

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score
f1_scorer = make_scorer(f1_score, average='macro')

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_loss',  # Theo dõi val_loss
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV

from scikeras.wrappers import KerasClassifier 

lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.0001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d_8 (ZeroPadd  (None, 44, 1)                0         ['input_9[0][0]']
#  ing1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d_8[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation_104 (Activation  (None, 22, 64)               0         ['bn_conv1[0][0]']
#  )
#
#  max_pooling1d_8 (MaxPoolin  (None, 10, 64)               0         ['activation_104[0][0]']
#  g1D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 32)               2080      ['max_pooling1d_8[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 32)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_105 (Activation  (None, 10, 32)               0         ['bn2a_branch2a[0][0]']
#  )
#
#  res2a_branch2b (Conv1D)     (None, 10, 32)               3104      ['activation_105[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 32)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_106 (Activation  (None, 10, 32)               0         ['bn2a_branch2b[0][0]']
#  )
#
#  res2a_branch2c (Conv1D)     (None, 10, 96)               3168      ['activation_106[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 96)               6240      ['max_pooling1d_8[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 96)               40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 96)               40        ['res2a_branch1[0][0]']
#  zation)
#
#  add_32 (Add)                (None, 10, 96)               0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_107 (Activation  (None, 10, 96)               0         ['add_32[0][0]']
#  )
#
#  res3a_branch2a (Conv1D)     (None, 5, 96)                9312      ['activation_107[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 96)                20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_108 (Activation  (None, 5, 96)                0         ['bn3a_branch2a[0][0]']
#  )
#
#  res3a_branch2b (Conv1D)     (None, 5, 96)                27744     ['activation_108[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 96)                20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_109 (Activation  (None, 5, 96)                0         ['bn3a_branch2b[0][0]']
#  )
#
#  res3a_branch2c (Conv1D)     (None, 5, 192)               18624     ['activation_109[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 192)               18624     ['activation_107[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 192)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 192)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_33 (Add)                (None, 5, 192)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_110 (Activation  (None, 5, 192)               0         ['add_33[0][0]']
#  )
#
#  res4a_branch2a (Conv1D)     (None, 3, 192)               37056     ['activation_110[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 3, 192)               12        ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_111 (Activation  (None, 3, 192)               0         ['bn4a_branch2a[0][0]']
#  )
#
#  res4a_branch2b (Conv1D)     (None, 3, 192)               110784    ['activation_111[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 3, 192)               12        ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_112 (Activation  (None, 3, 192)               0         ['bn4a_branch2b[0][0]']
#  )
#
#  res4a_branch2c (Conv1D)     (None, 3, 256)               49408     ['activation_112[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 3, 256)               49408     ['activation_110[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 3, 256)               12        ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 3, 256)               12        ['res4a_branch1[0][0]']
#  zation)
#
#  add_34 (Add)                (None, 3, 256)               0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_113 (Activation  (None, 3, 256)               0         ['add_34[0][0]']
#  )
#
#  res5a_branch2a (Conv1D)     (None, 2, 256)               65792     ['activation_113[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 2, 256)               8         ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_114 (Activation  (None, 2, 256)               0         ['bn5a_branch2a[0][0]']
#  )
#
#  res5a_branch2b (Conv1D)     (None, 2, 256)               196864    ['activation_114[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 2, 256)               8         ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_115 (Activation  (None, 2, 256)               0         ['bn5a_branch2b[0][0]']
#  )
#
#  res5a_branch2c (Conv1D)     (None, 2, 384)               98688     ['activation_115[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 2, 384)               98688     ['activation_113[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 2, 384)               8         ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 2, 384)               8         ['res5a_branch1[0][0]']
#  zation)
#
#  add_35 (Add)                (None, 2, 384)               0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_116 (Activation  (None, 2, 384)               0         ['add_35[0][0]']
#  )
#
#  global_average_pooling1d_8  (None, 384)                  0         ['activation_116[0][0]']
#   (GlobalAveragePooling1D)
#
#  fc1000 (Dense)              (None, 2)                    770       ['global_average_pooling1d_8[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 797442 (3.04 MB)
# Trainable params: 797154 (3.04 MB)
# Non-trainable params: 288 (1.12 KB)
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7033 - accuracy: 0.4944 - f1_score: 0.4944
# Epoch 1: val_loss improved from inf to 0.26318, saving model to best_model.h5
# 16/16 [==============================] - 7s 53ms/step - loss: 0.7022 - accuracy: 0.4950 - f1_score: 0.4951 - val_loss: 0.2632 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 2/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6979 - accuracy: 0.4988 - f1_score: 0.4988
# Epoch 2: val_loss improved from 0.26318 to 0.26246, saving model to best_model.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6951 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6975 - accuracy: 0.4988 - f1_score: 0.4988
# Epoch 3: val_loss improved from 0.26246 to 0.26243, saving model to best_model.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6949 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.2624 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6968 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 4: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6964 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.2625 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6740 - accuracy: 0.5125 - f1_score: 0.5125
# Epoch 5: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6706 - accuracy: 0.5180 - f1_score: 0.5206 - val_loss: 0.7305 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 6/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6938 - accuracy: 0.4940 - f1_score: 0.4940
# Epoch 6: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6895 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 7/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6853 - accuracy: 0.4940 - f1_score: 0.4940
# Epoch 7: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6828 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 8/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6923 - accuracy: 0.4955 - f1_score: 0.4955
# Epoch 8: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6840 - accuracy: 0.5000 - f1_score: 0.5026
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6840 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6878 - accuracy: 0.4990 - f1_score: 0.4990
# Epoch 10: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6873 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 11/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6953 - accuracy: 0.4911 - f1_score: 0.4911
# Epoch 11: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6887 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.5000 - f1_score: 0.5005
# Epoch 12: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6867 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 13/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6907 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 13: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6916 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 14/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6800 - accuracy: 0.5120 - f1_score: 0.5120
# Epoch 14: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6873 - accuracy: 0.5000 - f1_score: 0.4974 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 15/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6963 - accuracy: 0.4904 - f1_score: 0.4904
# Epoch 15: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6896 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6906 - accuracy: 0.4967 - f1_score: 0.4967
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 17/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6844 - accuracy: 0.5045 - f1_score: 0.5045
# Epoch 17: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 18/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6882 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 18: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6902 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 19/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6945 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 19: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6898 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 20/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6848 - accuracy: 0.5024 - f1_score: 0.5024
# Epoch 20: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6872 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 21/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6873 - accuracy: 0.5024 - f1_score: 0.5024
# Epoch 21: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6884 - accuracy: 0.5000 - f1_score: 0.4974 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 22/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6884 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 22: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 23/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6830 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 23: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6856 - accuracy: 0.5000 - f1_score: 0.4974 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 2.5000e-04
# Epoch 24/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6834 - accuracy: 0.5084 - f1_score: 0.5084
# Epoch 24: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 25/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6844 - accuracy: 0.5060 - f1_score: 0.5060
# Epoch 25: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.5000 - f1_score: 0.4995
# Epoch 26: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6888 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 27/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6808 - accuracy: 0.5033 - f1_score: 0.5033
# Epoch 27: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6836 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 28/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6881 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 28: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6865 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 29/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6724 - accuracy: 0.5180 - f1_score: 0.5180
# Epoch 29: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6829 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 30/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6903 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 30: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6864 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.2500e-04
# Epoch 31/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6852 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 31: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6871 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 32/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6846 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 32: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 33/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6811 - accuracy: 0.5072 - f1_score: 0.5072
# Epoch 33: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6866 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 34/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6860 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 34: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6854 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 35/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6911 - accuracy: 0.4904 - f1_score: 0.4904
# Epoch 35: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6850 - accuracy: 0.5000 - f1_score: 0.5020 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 36/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 36: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 18ms/step - loss: 0.6894 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 37/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6855 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 37: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 6.2500e-05
# Epoch 38/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6886 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 38: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6848 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 39/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6925 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 39: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6881 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 40/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6909 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 40: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6906 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 41/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6863 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 41: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6888 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 42/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6871 - accuracy: 0.4989 - f1_score: 0.4989
# Epoch 42: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 43/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6846 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 43: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6855 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 44/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6871 - accuracy: 0.5024 - f1_score: 0.5024
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 44: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.1250e-05
# Epoch 45/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6819 - accuracy: 0.5072 - f1_score: 0.5072
# Epoch 45: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6873 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 46/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6897 - accuracy: 0.4976 - f1_score: 0.4976
# Epoch 46: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 47/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6902 - accuracy: 0.4967 - f1_score: 0.4967
# Epoch 47: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6883 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 48/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6834 - accuracy: 0.5045 - f1_score: 0.5045
# Epoch 48: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6866 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 49/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6774 - accuracy: 0.5036 - f1_score: 0.5036
# Epoch 49: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6815 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 50/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6848 - accuracy: 0.5048 - f1_score: 0.5048
# Epoch 50: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 51/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6873 - accuracy: 0.4976 - f1_score: 0.4976
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 51: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6866 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.5625e-05
# Epoch 52/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6851 - accuracy: 0.5072 - f1_score: 0.5072
# Epoch 52: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6894 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 53/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6952 - accuracy: 0.4880 - f1_score: 0.4880
# Epoch 53: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6864 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 54/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6869 - accuracy: 0.4955 - f1_score: 0.4955
# Epoch 54: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6843 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 55/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6902 - accuracy: 0.4940 - f1_score: 0.4940
# Epoch 55: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6866 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 56/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6874 - accuracy: 0.4988 - f1_score: 0.4988
# Epoch 56: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 57/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 57: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6893 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 58/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6844 - accuracy: 0.5084 - f1_score: 0.5084
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 58: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6892 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 7.8125e-06
# Epoch 59/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6920 - accuracy: 0.4964 - f1_score: 0.4964
# Epoch 59: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6896 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 60/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6924 - accuracy: 0.4967 - f1_score: 0.4967
# Epoch 60: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6903 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 61/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6902 - accuracy: 0.4964 - f1_score: 0.4964
# Epoch 61: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 62/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6911 - accuracy: 0.4952 - f1_score: 0.4952
# Epoch 62: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 63/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 63: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 64/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6852 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 64: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6851 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 65/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6907 - accuracy: 0.4944 - f1_score: 0.4944
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 65: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6858 - accuracy: 0.5000 - f1_score: 0.5036 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 3.9063e-06
# Epoch 66/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6857 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 66: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 67/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.7003 - accuracy: 0.4808 - f1_score: 0.4808
# Epoch 67: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6860 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 68/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 68: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6887 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 69/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6841 - accuracy: 0.5060 - f1_score: 0.5060
# Epoch 69: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 70/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6935 - accuracy: 0.4909 - f1_score: 0.4909
# Epoch 70: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 71/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6926 - accuracy: 0.4911 - f1_score: 0.4911
# Epoch 71: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6846 - accuracy: 0.5000 - f1_score: 0.5046 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 72/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6806 - accuracy: 0.5096 - f1_score: 0.5096
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 72: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6861 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.9531e-06
# Epoch 73/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6901 - accuracy: 0.4952 - f1_score: 0.4952
# Epoch 73: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 74/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.4952 - f1_score: 0.4952
# Epoch 74: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6888 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 75/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6903 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 75: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6865 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 76/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6875 - accuracy: 0.4976 - f1_score: 0.4976
# Epoch 76: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6859 - accuracy: 0.5000 - f1_score: 0.4985 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 77/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.4974
# Epoch 77: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.4974 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 78/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6849 - accuracy: 0.5060 - f1_score: 0.5060
# Epoch 78: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6874 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 79/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6842 - accuracy: 0.5045 - f1_score: 0.5045
# Epoch 79: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 80/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6872 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 80: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6868 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 81/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6937 - accuracy: 0.4933 - f1_score: 0.4933
# Epoch 81: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 82/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6885 - accuracy: 0.4976 - f1_score: 0.4976
# Epoch 82: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 83/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6979 - accuracy: 0.4856 - f1_score: 0.4856
# Epoch 83: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6858 - accuracy: 0.5021 - f1_score: 0.5021
# Epoch 84: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 18ms/step - loss: 0.6872 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 85/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6891 - accuracy: 0.5000 - f1_score: 0.5000
# Epoch 85: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 86/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6876 - accuracy: 0.5024 - f1_score: 0.5024
# Epoch 86: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6881 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 87/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6944 - accuracy: 0.4922 - f1_score: 0.4922
# Epoch 87: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.5036 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 88/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6850 - accuracy: 0.5022 - f1_score: 0.5022
# Epoch 88: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 89/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6940 - accuracy: 0.4880 - f1_score: 0.4880
# Epoch 89: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6860 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 90/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6966 - accuracy: 0.4892 - f1_score: 0.4892
# Epoch 90: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 91/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6854 - accuracy: 0.5052 - f1_score: 0.5052
# Epoch 91: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6891 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 92/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6858 - accuracy: 0.5012 - f1_score: 0.5012
# Epoch 92: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6873 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 93/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6792 - accuracy: 0.5120 - f1_score: 0.5120
# Epoch 93: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6867 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 94/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6895 - accuracy: 0.4964 - f1_score: 0.4964
# Epoch 94: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 95/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6912 - accuracy: 0.4940 - f1_score: 0.4940
# Epoch 95: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 96/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6908 - accuracy: 0.4940 - f1_score: 0.4940
# Epoch 96: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 97/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6854 - accuracy: 0.4916 - f1_score: 0.4916
# Epoch 97: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6811 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 98/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.5015
# Epoch 98: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 99/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6888 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 99: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6820 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 100/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6894 - accuracy: 0.4928 - f1_score: 0.4928
# Epoch 100: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6849 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 101/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6840 - accuracy: 0.5060 - f1_score: 0.5060
# Epoch 101: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 102/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6905 - accuracy: 0.4964 - f1_score: 0.4964Restoring model weights from the end of the best epoch: 2.
#
# Epoch 102: val_loss did not improve from 0.26243
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 1.0000e-06
# Epoch 102: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 3ms/step
# 0.7376543209876543

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7376543209876543
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        85
#            0       0.74      1.00      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.37      0.50      0.42       324
# weighted avg       0.54      0.74      0.63       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 239 chiếm khoảng 73.76543209876543% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 0 chiếm khoảng 0.0% so với thực tế
