# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_accuracy',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_12[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_13[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_14[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_12[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_15 (Activation)     (None, 3, 256)       0           ['add_4[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_15[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_16[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_17[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_15[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_5 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_18 (Activation)     (None, 2, 384)       0           ['add_5[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_18[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 816,434
# Trainable params: 816,026
# Non-trainable params: 408
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7196 - accuracy: 0.5542 - f1_score: 0.4788
# Epoch 1: val_accuracy improved from -inf to 0.73765, saving model to best_model.h5
# 16/16 [==============================] - 9s 105ms/step - loss: 0.7110 - accuracy: 0.5549 - f1_score: 0.4830 - val_loss: 0.5750 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5272 - accuracy: 0.6667 - f1_score: 0.6548
# Epoch 2: val_accuracy improved from 0.73765 to 0.74074, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.5238 - accuracy: 0.6667 - f1_score: 0.6554 - val_loss: 0.5656 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4325 - accuracy: 0.7052 - f1_score: 0.6979
# Epoch 3: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4323 - accuracy: 0.7016 - f1_score: 0.6924 - val_loss: 0.5405 - val_accuracy: 0.7377 - val_f1_score: 0.4653 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4137 - accuracy: 0.7115 - f1_score: 0.7035
# Epoch 4: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 0s 31ms/step - loss: 0.4139 - accuracy: 0.7116 - f1_score: 0.7031 - val_loss: 0.5466 - val_accuracy: 0.7346 - val_f1_score: 0.4543 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3566 - accuracy: 0.7458 - f1_score: 0.7423
# Epoch 5: val_accuracy improved from 0.74074 to 0.74383, saving model to best_model.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.3593 - accuracy: 0.7445 - f1_score: 0.7405 - val_loss: 0.5221 - val_accuracy: 0.7438 - val_f1_score: 0.4762 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2971 - accuracy: 0.7865 - f1_score: 0.7850
# Epoch 6: val_accuracy did not improve from 0.74383
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2995 - accuracy: 0.7844 - f1_score: 0.7820 - val_loss: 0.5027 - val_accuracy: 0.7377 - val_f1_score: 0.4901 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3200 - accuracy: 0.7698 - f1_score: 0.7677
# Epoch 7: val_accuracy improved from 0.74383 to 0.75000, saving model to best_model.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3235 - accuracy: 0.7685 - f1_score: 0.7658 - val_loss: 0.4515 - val_accuracy: 0.7500 - val_f1_score: 0.5334 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.7505 - f1_score: 0.7494
# Epoch 8: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.3497 - accuracy: 0.7505 - f1_score: 0.7494 - val_loss: 0.5267 - val_accuracy: 0.7438 - val_f1_score: 0.4671 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3367 - accuracy: 0.7604 - f1_score: 0.7574
# Epoch 9: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3324 - accuracy: 0.7635 - f1_score: 0.7621 - val_loss: 0.5611 - val_accuracy: 0.7377 - val_f1_score: 0.4355 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3149 - accuracy: 0.7771 - f1_score: 0.7754
# Epoch 10: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3121 - accuracy: 0.7794 - f1_score: 0.7790 - val_loss: 0.4958 - val_accuracy: 0.7346 - val_f1_score: 0.4926 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3054 - accuracy: 0.7812 - f1_score: 0.7779
# Epoch 11: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3128 - accuracy: 0.7764 - f1_score: 0.7708 - val_loss: 0.5196 - val_accuracy: 0.7222 - val_f1_score: 0.4704 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3054 - accuracy: 0.7802 - f1_score: 0.7769
# Epoch 12: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3035 - accuracy: 0.7824 - f1_score: 0.7801 - val_loss: 0.4059 - val_accuracy: 0.6296 - val_f1_score: 0.5539 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2781 - accuracy: 0.8000 - f1_score: 0.7970
# Epoch 13: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2817 - accuracy: 0.7974 - f1_score: 0.7933 - val_loss: 0.5440 - val_accuracy: 0.7407 - val_f1_score: 0.4528 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2725 - accuracy: 0.8073 - f1_score: 0.8053
# Epoch 14: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2697 - accuracy: 0.8074 - f1_score: 0.8055 - val_loss: 0.4899 - val_accuracy: 0.7407 - val_f1_score: 0.4919 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2560 - accuracy: 0.8188 - f1_score: 0.8174
# Epoch 15: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2530 - accuracy: 0.8204 - f1_score: 0.8199 - val_loss: 0.4344 - val_accuracy: 0.7315 - val_f1_score: 0.5439 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2430 - accuracy: 0.8271 - f1_score: 0.8257
# Epoch 16: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2402 - accuracy: 0.8293 - f1_score: 0.8291 - val_loss: 0.4528 - val_accuracy: 0.7377 - val_f1_score: 0.5279 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2731 - accuracy: 0.8052 - f1_score: 0.8037
# Epoch 17: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2708 - accuracy: 0.8064 - f1_score: 0.8055 - val_loss: 0.3903 - val_accuracy: 0.6451 - val_f1_score: 0.5700 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2925 - accuracy: 0.7937 - f1_score: 0.7897
# Epoch 18: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2904 - accuracy: 0.7954 - f1_score: 0.7924 - val_loss: 0.3761 - val_accuracy: 0.6605 - val_f1_score: 0.5558 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2697 - accuracy: 0.8083 - f1_score: 0.8068
# Epoch 19: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2723 - accuracy: 0.8074 - f1_score: 0.8053 - val_loss: 0.4590 - val_accuracy: 0.7407 - val_f1_score: 0.5231 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2635 - accuracy: 0.8115 - f1_score: 0.8106
# Epoch 20: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2623 - accuracy: 0.8124 - f1_score: 0.8119 - val_loss: 0.4033 - val_accuracy: 0.7130 - val_f1_score: 0.5713 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2489 - accuracy: 0.8229 - f1_score: 0.8220
# Epoch 21: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2456 - accuracy: 0.8253 - f1_score: 0.8256 - val_loss: 0.4523 - val_accuracy: 0.6944 - val_f1_score: 0.5223 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2411 - accuracy: 0.8281 - f1_score: 0.8274
# Epoch 22: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2405 - accuracy: 0.8293 - f1_score: 0.8291 - val_loss: 0.3720 - val_accuracy: 0.7315 - val_f1_score: 0.5963 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2378 - accuracy: 0.8302 - f1_score: 0.8290
# Epoch 23: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2335 - accuracy: 0.8333 - f1_score: 0.8336 - val_loss: 0.3719 - val_accuracy: 0.7438 - val_f1_score: 0.6004 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2445 - accuracy: 0.8240 - f1_score: 0.8221
# Epoch 24: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2406 - accuracy: 0.8273 - f1_score: 0.8272 - val_loss: 0.3500 - val_accuracy: 0.7068 - val_f1_score: 0.6130 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2402 - accuracy: 0.8302 - f1_score: 0.8284
# Epoch 25: val_accuracy did not improve from 0.75000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2355 - accuracy: 0.8333 - f1_score: 0.8332 - val_loss: 0.3466 - val_accuracy: 0.7130 - val_f1_score: 0.6222 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2058 - accuracy: 0.8531 - f1_score: 0.8522
# Epoch 26: val_accuracy improved from 0.75000 to 0.75617, saving model to best_model.h5
# 16/16 [==============================] - 1s 51ms/step - loss: 0.2037 - accuracy: 0.8543 - f1_score: 0.8539 - val_loss: 0.3371 - val_accuracy: 0.7562 - val_f1_score: 0.6306 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2128 - accuracy: 0.8490 - f1_score: 0.8477
# Epoch 27: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2164 - accuracy: 0.8463 - f1_score: 0.8438 - val_loss: 0.4483 - val_accuracy: 0.5710 - val_f1_score: 0.5186 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2598 - accuracy: 0.8115 - f1_score: 0.8099
# Epoch 28: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2549 - accuracy: 0.8154 - f1_score: 0.8158 - val_loss: 0.3934 - val_accuracy: 0.6543 - val_f1_score: 0.5599 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2409 - accuracy: 0.8250 - f1_score: 0.8236
# Epoch 29: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2408 - accuracy: 0.8253 - f1_score: 0.8242 - val_loss: 0.4892 - val_accuracy: 0.7253 - val_f1_score: 0.5051 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2353 - accuracy: 0.8302 - f1_score: 0.8283
# Epoch 30: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2332 - accuracy: 0.8313 - f1_score: 0.8299 - val_loss: 0.4826 - val_accuracy: 0.7284 - val_f1_score: 0.5046 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2101 - accuracy: 0.8510 - f1_score: 0.8498
# Epoch 31: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2155 - accuracy: 0.8473 - f1_score: 0.8442 - val_loss: 0.3451 - val_accuracy: 0.7500 - val_f1_score: 0.6226 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.8443 - f1_score: 0.8432
# Epoch 32: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2192 - accuracy: 0.8443 - f1_score: 0.8432 - val_loss: 0.4398 - val_accuracy: 0.7284 - val_f1_score: 0.5394 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2269 - accuracy: 0.8385 - f1_score: 0.8375
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 33: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2289 - accuracy: 0.8363 - f1_score: 0.8342 - val_loss: 0.4023 - val_accuracy: 0.7346 - val_f1_score: 0.5695 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2317 - accuracy: 0.8344 - f1_score: 0.8331
# Epoch 34: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2374 - accuracy: 0.8303 - f1_score: 0.8272 - val_loss: 0.4318 - val_accuracy: 0.7377 - val_f1_score: 0.5503 - lr: 5.0000e-04
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2159 - accuracy: 0.8458 - f1_score: 0.8449
# Epoch 35: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2156 - accuracy: 0.8453 - f1_score: 0.8439 - val_loss: 0.4262 - val_accuracy: 0.7284 - val_f1_score: 0.5512 - lr: 5.0000e-04
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2236 - accuracy: 0.8417 - f1_score: 0.8398
# Epoch 36: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2207 - accuracy: 0.8433 - f1_score: 0.8423 - val_loss: 0.4150 - val_accuracy: 0.7253 - val_f1_score: 0.5605 - lr: 5.0000e-04
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1903 - accuracy: 0.8646 - f1_score: 0.8631
# Epoch 37: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 31ms/step - loss: 0.1916 - accuracy: 0.8643 - f1_score: 0.8626 - val_loss: 0.3800 - val_accuracy: 0.6698 - val_f1_score: 0.5920 - lr: 5.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1863 - accuracy: 0.8693 - f1_score: 0.8699
# Epoch 38: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1863 - accuracy: 0.8693 - f1_score: 0.8699 - val_loss: 0.3530 - val_accuracy: 0.7099 - val_f1_score: 0.6153 - lr: 5.0000e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1758 - accuracy: 0.8771 - f1_score: 0.8761
# Epoch 39: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1773 - accuracy: 0.8762 - f1_score: 0.8748 - val_loss: 0.4219 - val_accuracy: 0.6080 - val_f1_score: 0.5400 - lr: 5.0000e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1720 - accuracy: 0.8792 - f1_score: 0.8783
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 40: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1717 - accuracy: 0.8792 - f1_score: 0.8785 - val_loss: 0.3559 - val_accuracy: 0.7037 - val_f1_score: 0.6138 - lr: 5.0000e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1684 - accuracy: 0.8781 - f1_score: 0.8767
# Epoch 41: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1670 - accuracy: 0.8792 - f1_score: 0.8784 - val_loss: 0.3668 - val_accuracy: 0.6944 - val_f1_score: 0.6057 - lr: 2.5000e-04
# Epoch 42/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1778 - accuracy: 0.8729 - f1_score: 0.8703
# Epoch 42: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1804 - accuracy: 0.8733 - f1_score: 0.8702 - val_loss: 0.3779 - val_accuracy: 0.6728 - val_f1_score: 0.5935 - lr: 2.5000e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.8771 - f1_score: 0.8760
# Epoch 43: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1715 - accuracy: 0.8772 - f1_score: 0.8763 - val_loss: 0.3944 - val_accuracy: 0.6420 - val_f1_score: 0.5606 - lr: 2.5000e-04
# Epoch 44/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1600 - accuracy: 0.8850 - f1_score: 0.8844
# Epoch 44: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1557 - accuracy: 0.8892 - f1_score: 0.8890 - val_loss: 0.3748 - val_accuracy: 0.6790 - val_f1_score: 0.5941 - lr: 2.5000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1644 - accuracy: 0.8833 - f1_score: 0.8827
# Epoch 45: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1642 - accuracy: 0.8832 - f1_score: 0.8826 - val_loss: 0.4029 - val_accuracy: 0.6389 - val_f1_score: 0.5671 - lr: 2.5000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1604 - accuracy: 0.8844 - f1_score: 0.8838
# Epoch 46: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1577 - accuracy: 0.8862 - f1_score: 0.8865 - val_loss: 0.3849 - val_accuracy: 0.6852 - val_f1_score: 0.5877 - lr: 2.5000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1515 - accuracy: 0.8917 - f1_score: 0.8905
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 47: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1508 - accuracy: 0.8922 - f1_score: 0.8914 - val_loss: 0.3547 - val_accuracy: 0.7130 - val_f1_score: 0.6132 - lr: 2.5000e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1476 - accuracy: 0.8927 - f1_score: 0.8923
# Epoch 48: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1486 - accuracy: 0.8922 - f1_score: 0.8916 - val_loss: 0.3627 - val_accuracy: 0.7284 - val_f1_score: 0.6041 - lr: 1.2500e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1519 - accuracy: 0.8917 - f1_score: 0.8912
# Epoch 49: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1508 - accuracy: 0.8912 - f1_score: 0.8902 - val_loss: 0.3854 - val_accuracy: 0.7160 - val_f1_score: 0.5760 - lr: 1.2500e-04
# Epoch 50/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1546 - accuracy: 0.8885 - f1_score: 0.8870
# Epoch 50: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 31ms/step - loss: 0.1539 - accuracy: 0.8892 - f1_score: 0.8881 - val_loss: 0.3525 - val_accuracy: 0.7377 - val_f1_score: 0.6148 - lr: 1.2500e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1511 - accuracy: 0.8917 - f1_score: 0.8912
# Epoch 51: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1517 - accuracy: 0.8912 - f1_score: 0.8906 - val_loss: 0.3587 - val_accuracy: 0.7407 - val_f1_score: 0.6129 - lr: 1.2500e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1543 - accuracy: 0.8906 - f1_score: 0.8896
# Epoch 52: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1505 - accuracy: 0.8932 - f1_score: 0.8935 - val_loss: 0.3375 - val_accuracy: 0.7377 - val_f1_score: 0.6291 - lr: 1.2500e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1379 - accuracy: 0.9000 - f1_score: 0.8997
# Epoch 53: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1397 - accuracy: 0.8982 - f1_score: 0.8967 - val_loss: 0.3403 - val_accuracy: 0.7346 - val_f1_score: 0.6271 - lr: 1.2500e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1521 - accuracy: 0.8906 - f1_score: 0.8895
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 54: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1500 - accuracy: 0.8922 - f1_score: 0.8919 - val_loss: 0.3488 - val_accuracy: 0.7099 - val_f1_score: 0.6180 - lr: 1.2500e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1485 - accuracy: 0.8917 - f1_score: 0.8906
# Epoch 55: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1465 - accuracy: 0.8932 - f1_score: 0.8930 - val_loss: 0.3544 - val_accuracy: 0.7099 - val_f1_score: 0.6093 - lr: 6.2500e-05
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1336 - accuracy: 0.9062 - f1_score: 0.9054
# Epoch 56: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1359 - accuracy: 0.9042 - f1_score: 0.9022 - val_loss: 0.3417 - val_accuracy: 0.7315 - val_f1_score: 0.6252 - lr: 6.2500e-05
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1415 - accuracy: 0.8990 - f1_score: 0.8977
# Epoch 57: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1418 - accuracy: 0.8992 - f1_score: 0.8980 - val_loss: 0.3397 - val_accuracy: 0.7346 - val_f1_score: 0.6226 - lr: 6.2500e-05
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1311 - accuracy: 0.9073 - f1_score: 0.9064
# Epoch 58: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1345 - accuracy: 0.9042 - f1_score: 0.9018 - val_loss: 0.3435 - val_accuracy: 0.7500 - val_f1_score: 0.6203 - lr: 6.2500e-05
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1347 - accuracy: 0.9062 - f1_score: 0.9049
# Epoch 59: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1334 - accuracy: 0.9072 - f1_score: 0.9063 - val_loss: 0.3472 - val_accuracy: 0.7531 - val_f1_score: 0.6229 - lr: 6.2500e-05
# Epoch 60/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9062 - f1_score: 0.9059
# Epoch 60: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1324 - accuracy: 0.9062 - f1_score: 0.9059 - val_loss: 0.3322 - val_accuracy: 0.7469 - val_f1_score: 0.6262 - lr: 6.2500e-05
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1246 - accuracy: 0.9115 - f1_score: 0.9108
# Epoch 61: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1274 - accuracy: 0.9092 - f1_score: 0.9074 - val_loss: 0.3273 - val_accuracy: 0.7531 - val_f1_score: 0.6380 - lr: 6.2500e-05
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1469 - accuracy: 0.8958 - f1_score: 0.8943
# Epoch 62: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1433 - accuracy: 0.8982 - f1_score: 0.8979 - val_loss: 0.3298 - val_accuracy: 0.7531 - val_f1_score: 0.6386 - lr: 6.2500e-05
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1520 - accuracy: 0.8938 - f1_score: 0.8917
# Epoch 63: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1527 - accuracy: 0.8932 - f1_score: 0.8910 - val_loss: 0.3316 - val_accuracy: 0.7500 - val_f1_score: 0.6359 - lr: 6.2500e-05
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1381 - accuracy: 0.9021 - f1_score: 0.9011
# Epoch 64: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1366 - accuracy: 0.9032 - f1_score: 0.9028 - val_loss: 0.3299 - val_accuracy: 0.7438 - val_f1_score: 0.6298 - lr: 6.2500e-05
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1520 - accuracy: 0.8917 - f1_score: 0.8899
# Epoch 65: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1514 - accuracy: 0.8922 - f1_score: 0.8908 - val_loss: 0.3271 - val_accuracy: 0.7500 - val_f1_score: 0.6357 - lr: 6.2500e-05
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1350 - accuracy: 0.9042 - f1_score: 0.9034
# Epoch 66: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1337 - accuracy: 0.9052 - f1_score: 0.9050 - val_loss: 0.3382 - val_accuracy: 0.7469 - val_f1_score: 0.6199 - lr: 6.2500e-05
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1370 - accuracy: 0.9021 - f1_score: 0.9005
# Epoch 67: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1356 - accuracy: 0.9032 - f1_score: 0.9022 - val_loss: 0.3384 - val_accuracy: 0.7531 - val_f1_score: 0.6313 - lr: 6.2500e-05
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1310 - accuracy: 0.9062 - f1_score: 0.9055
# Epoch 68: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1310 - accuracy: 0.9062 - f1_score: 0.9054 - val_loss: 0.3431 - val_accuracy: 0.7531 - val_f1_score: 0.6195 - lr: 6.2500e-05
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1272 - accuracy: 0.9094 - f1_score: 0.9088
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 69: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1266 - accuracy: 0.9102 - f1_score: 0.9100 - val_loss: 0.3272 - val_accuracy: 0.7531 - val_f1_score: 0.6310 - lr: 6.2500e-05
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1324 - accuracy: 0.9062 - f1_score: 0.9053
# Epoch 70: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1283 - accuracy: 0.9092 - f1_score: 0.9098 - val_loss: 0.3279 - val_accuracy: 0.7531 - val_f1_score: 0.6330 - lr: 3.1250e-05
# Epoch 71/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1235 - accuracy: 0.9129 - f1_score: 0.9125
# Epoch 71: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1246 - accuracy: 0.9122 - f1_score: 0.9111 - val_loss: 0.3331 - val_accuracy: 0.7469 - val_f1_score: 0.6270 - lr: 3.1250e-05
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1382 - accuracy: 0.9021 - f1_score: 0.9009
# Epoch 72: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1394 - accuracy: 0.9002 - f1_score: 0.8980 - val_loss: 0.3372 - val_accuracy: 0.7407 - val_f1_score: 0.6220 - lr: 3.1250e-05
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1328 - accuracy: 0.9062 - f1_score: 0.9050
# Epoch 73: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1311 - accuracy: 0.9072 - f1_score: 0.9064 - val_loss: 0.3434 - val_accuracy: 0.7469 - val_f1_score: 0.6215 - lr: 3.1250e-05
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1244 - accuracy: 0.9104 - f1_score: 0.9096
# Epoch 74: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1247 - accuracy: 0.9102 - f1_score: 0.9093 - val_loss: 0.3407 - val_accuracy: 0.7500 - val_f1_score: 0.6236 - lr: 3.1250e-05
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1348 - accuracy: 0.9042 - f1_score: 0.9026
# Epoch 75: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1333 - accuracy: 0.9052 - f1_score: 0.9042 - val_loss: 0.3423 - val_accuracy: 0.7438 - val_f1_score: 0.6191 - lr: 3.1250e-05
# Epoch 76/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1145 - accuracy: 0.9185 - f1_score: 0.9181
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 76: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1266 - accuracy: 0.9092 - f1_score: 0.9075 - val_loss: 0.3353 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.1250e-05
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1292 - accuracy: 0.9073 - f1_score: 0.9064
# Epoch 77: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1238 - accuracy: 0.9112 - f1_score: 0.9123 - val_loss: 0.3357 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.5625e-05
# Epoch 78/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1329 - accuracy: 0.9042 - f1_score: 0.9031
# Epoch 78: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1357 - accuracy: 0.9012 - f1_score: 0.8980 - val_loss: 0.3347 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 1.5625e-05
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1286 - accuracy: 0.9083 - f1_score: 0.9071
# Epoch 79: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1356 - accuracy: 0.9042 - f1_score: 0.9009 - val_loss: 0.3355 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 1.5625e-05
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1259 - accuracy: 0.9083 - f1_score: 0.9077
# Epoch 80: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1313 - accuracy: 0.9042 - f1_score: 0.9015 - val_loss: 0.3358 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 1.5625e-05
# Epoch 81/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1272 - accuracy: 0.9085 - f1_score: 0.9077
# Epoch 81: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1343 - accuracy: 0.9032 - f1_score: 0.9008 - val_loss: 0.3346 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 1.5625e-05
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1313 - accuracy: 0.9062 - f1_score: 0.9053
# Epoch 82: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1340 - accuracy: 0.9042 - f1_score: 0.9023 - val_loss: 0.3344 - val_accuracy: 0.7500 - val_f1_score: 0.6326 - lr: 1.5625e-05
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1279 - accuracy: 0.9094 - f1_score: 0.9084
# Epoch 83: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 83: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1266 - accuracy: 0.9102 - f1_score: 0.9096 - val_loss: 0.3350 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 1.5625e-05
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1322 - accuracy: 0.9062 - f1_score: 0.9052
# Epoch 84: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1333 - accuracy: 0.9052 - f1_score: 0.9036 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 7.8125e-06
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1225 - accuracy: 0.9135 - f1_score: 0.9128
# Epoch 85: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1241 - accuracy: 0.9122 - f1_score: 0.9108 - val_loss: 0.3344 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 7.8125e-06
# Epoch 86/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1208 - accuracy: 0.9118 - f1_score: 0.9112
# Epoch 86: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1228 - accuracy: 0.9112 - f1_score: 0.9099 - val_loss: 0.3352 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 7.8125e-06
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1325 - accuracy: 0.9042 - f1_score: 0.9030
# Epoch 87: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1284 - accuracy: 0.9072 - f1_score: 0.9076 - val_loss: 0.3341 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 7.8125e-06
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1310 - accuracy: 0.9062 - f1_score: 0.9043
# Epoch 88: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1322 - accuracy: 0.9052 - f1_score: 0.9028 - val_loss: 0.3329 - val_accuracy: 0.7469 - val_f1_score: 0.6298 - lr: 7.8125e-06
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1379 - accuracy: 0.9010 - f1_score: 0.9000
# Epoch 89: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1338 - accuracy: 0.9042 - f1_score: 0.9048 - val_loss: 0.3351 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 7.8125e-06
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1248 - accuracy: 0.9115 - f1_score: 0.9105
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 90: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1261 - accuracy: 0.9102 - f1_score: 0.9086 - val_loss: 0.3354 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 7.8125e-06
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1257 - accuracy: 0.9115 - f1_score: 0.9108
# Epoch 91: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1254 - accuracy: 0.9122 - f1_score: 0.9117 - val_loss: 0.3356 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1384 - accuracy: 0.9021 - f1_score: 0.9013
# Epoch 92: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1383 - accuracy: 0.9022 - f1_score: 0.9015 - val_loss: 0.3353 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1319 - accuracy: 0.9052 - f1_score: 0.9038
# Epoch 93: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1337 - accuracy: 0.9042 - f1_score: 0.9024 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1336 - accuracy: 0.9042 - f1_score: 0.9034
# Epoch 94: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1299 - accuracy: 0.9072 - f1_score: 0.9079 - val_loss: 0.3352 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1342 - accuracy: 0.9031 - f1_score: 0.9016
# Epoch 95: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1355 - accuracy: 0.9022 - f1_score: 0.9003 - val_loss: 0.3353 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1346 - accuracy: 0.9021 - f1_score: 0.9006
# Epoch 96: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1316 - accuracy: 0.9042 - f1_score: 0.9038 - val_loss: 0.3354 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1307 - accuracy: 0.9042 - f1_score: 0.9031
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 97: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1266 - accuracy: 0.9072 - f1_score: 0.9077 - val_loss: 0.3347 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 3.9063e-06
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1295 - accuracy: 0.9073 - f1_score: 0.9061
# Epoch 98: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1255 - accuracy: 0.9102 - f1_score: 0.9105 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1301 - accuracy: 0.9073 - f1_score: 0.9065
# Epoch 99: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1280 - accuracy: 0.9092 - f1_score: 0.9093 - val_loss: 0.3347 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1482 - accuracy: 0.8948 - f1_score: 0.8929
# Epoch 100: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1448 - accuracy: 0.8972 - f1_score: 0.8966 - val_loss: 0.3346 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1317 - accuracy: 0.9073 - f1_score: 0.9060
# Epoch 101: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1311 - accuracy: 0.9072 - f1_score: 0.9055 - val_loss: 0.3347 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1501 - accuracy: 0.8958 - f1_score: 0.8942
# Epoch 102: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1476 - accuracy: 0.8972 - f1_score: 0.8963 - val_loss: 0.3346 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1257 - accuracy: 0.9125 - f1_score: 0.9119
# Epoch 103: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1272 - accuracy: 0.9112 - f1_score: 0.9100 - val_loss: 0.3350 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1422 - accuracy: 0.8979 - f1_score: 0.8968
# Epoch 104: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 104: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1401 - accuracy: 0.8992 - f1_score: 0.8988 - val_loss: 0.3352 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.9531e-06
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1333 - accuracy: 0.9052 - f1_score: 0.9042
# Epoch 105: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1352 - accuracy: 0.9042 - f1_score: 0.9026 - val_loss: 0.3350 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1186 - accuracy: 0.9146 - f1_score: 0.9140
# Epoch 106: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1190 - accuracy: 0.9142 - f1_score: 0.9134 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1395 - accuracy: 0.9010 - f1_score: 0.8994
# Epoch 107: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1357 - accuracy: 0.9042 - f1_score: 0.9041 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1297 - accuracy: 0.9083 - f1_score: 0.9070
# Epoch 108: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1339 - accuracy: 0.9052 - f1_score: 0.9024 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1332 - accuracy: 0.9031 - f1_score: 0.9020
# Epoch 109: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1315 - accuracy: 0.9042 - f1_score: 0.9036 - val_loss: 0.3349 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 110/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1442 - accuracy: 0.8973 - f1_score: 0.8959
# Epoch 110: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1343 - accuracy: 0.9042 - f1_score: 0.9044 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1315 - accuracy: 0.9042 - f1_score: 0.9032
# Epoch 111: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1260 - accuracy: 0.9082 - f1_score: 0.9092 - val_loss: 0.3350 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1231 - accuracy: 0.9135 - f1_score: 0.9127
# Epoch 112: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1251 - accuracy: 0.9122 - f1_score: 0.9106 - val_loss: 0.3350 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1301 - accuracy: 0.9073 - f1_score: 0.9066
# Epoch 113: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1324 - accuracy: 0.9072 - f1_score: 0.9058 - val_loss: 0.3347 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1252 - accuracy: 0.9125 - f1_score: 0.9112
# Epoch 114: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1281 - accuracy: 0.9102 - f1_score: 0.9078 - val_loss: 0.3348 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 115/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1350 - accuracy: 0.9029 - f1_score: 0.9013
# Epoch 115: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1280 - accuracy: 0.9082 - f1_score: 0.9082 - val_loss: 0.3347 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1214 - accuracy: 0.9135 - f1_score: 0.9127
# Epoch 116: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1250 - accuracy: 0.9112 - f1_score: 0.9091 - val_loss: 0.3345 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1255 - accuracy: 0.9094 - f1_score: 0.9088
# Epoch 117: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1237 - accuracy: 0.9112 - f1_score: 0.9114 - val_loss: 0.3344 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1221 - accuracy: 0.9156 - f1_score: 0.9147
# Epoch 118: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1221 - accuracy: 0.9152 - f1_score: 0.9140 - val_loss: 0.3345 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1350 - accuracy: 0.9031 - f1_score: 0.9025
# Epoch 119: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1325 - accuracy: 0.9052 - f1_score: 0.9055 - val_loss: 0.3345 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1284 - accuracy: 0.9083 - f1_score: 0.9077
# Epoch 120: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1260 - accuracy: 0.9102 - f1_score: 0.9105 - val_loss: 0.3344 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1302 - accuracy: 0.9083 - f1_score: 0.9076
# Epoch 121: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1322 - accuracy: 0.9062 - f1_score: 0.9041 - val_loss: 0.3345 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1287 - accuracy: 0.9083 - f1_score: 0.9068
# Epoch 122: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1286 - accuracy: 0.9082 - f1_score: 0.9066 - val_loss: 0.3345 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1265 - accuracy: 0.9115 - f1_score: 0.9106
# Epoch 123: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1238 - accuracy: 0.9132 - f1_score: 0.9132 - val_loss: 0.3344 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1208 - accuracy: 0.9156 - f1_score: 0.9150
# Epoch 124: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1210 - accuracy: 0.9152 - f1_score: 0.9143 - val_loss: 0.3343 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1291 - accuracy: 0.9073 - f1_score: 0.9059
# Epoch 125: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1281 - accuracy: 0.9082 - f1_score: 0.9073 - val_loss: 0.3341 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1285 - accuracy: 0.9094 - f1_score: 0.9086
# Epoch 126: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1266 - accuracy: 0.9102 - f1_score: 0.9098 - val_loss: 0.3343 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1308 - accuracy: 0.9062 - f1_score: 0.9048
# Epoch 127: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1336 - accuracy: 0.9052 - f1_score: 0.9031 - val_loss: 0.3342 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1344 - accuracy: 0.9062 - f1_score: 0.9049
# Epoch 128: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1350 - accuracy: 0.9052 - f1_score: 0.9032 - val_loss: 0.3344 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 129/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9102 - f1_score: 0.9100
# Epoch 129: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1252 - accuracy: 0.9102 - f1_score: 0.9100 - val_loss: 0.3342 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1305 - accuracy: 0.9073 - f1_score: 0.9064
# Epoch 130: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1320 - accuracy: 0.9062 - f1_score: 0.9048 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 131/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9112 - f1_score: 0.9112
# Epoch 131: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1239 - accuracy: 0.9112 - f1_score: 0.9112 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1322 - accuracy: 0.9083 - f1_score: 0.9067
# Epoch 132: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1323 - accuracy: 0.9082 - f1_score: 0.9066 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 133/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1242 - accuracy: 0.9125 - f1_score: 0.9118
# Epoch 133: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1243 - accuracy: 0.9122 - f1_score: 0.9113 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 134/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1196 - accuracy: 0.9135 - f1_score: 0.9128
# Epoch 134: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1176 - accuracy: 0.9152 - f1_score: 0.9152 - val_loss: 0.3339 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 135/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1187 - accuracy: 0.9146 - f1_score: 0.9134
# Epoch 135: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1225 - accuracy: 0.9122 - f1_score: 0.9098 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 136/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1426 - accuracy: 0.8990 - f1_score: 0.8973
# Epoch 136: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1394 - accuracy: 0.9012 - f1_score: 0.9008 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1277 - accuracy: 0.9083 - f1_score: 0.9070
# Epoch 137: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1269 - accuracy: 0.9092 - f1_score: 0.9083 - val_loss: 0.3341 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1212 - accuracy: 0.9135 - f1_score: 0.9129
# Epoch 138: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1195 - accuracy: 0.9152 - f1_score: 0.9153 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1255 - accuracy: 0.9125 - f1_score: 0.9111
# Epoch 139: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1266 - accuracy: 0.9112 - f1_score: 0.9092 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 140/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1238 - accuracy: 0.9115 - f1_score: 0.9104
# Epoch 140: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1278 - accuracy: 0.9082 - f1_score: 0.9048 - val_loss: 0.3340 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1208 - accuracy: 0.9125 - f1_score: 0.9118
# Epoch 141: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1233 - accuracy: 0.9122 - f1_score: 0.9109 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 142/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1370 - accuracy: 0.9042 - f1_score: 0.9032
# Epoch 142: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1353 - accuracy: 0.9052 - f1_score: 0.9048 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1160 - accuracy: 0.9167 - f1_score: 0.9160
# Epoch 143: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1197 - accuracy: 0.9142 - f1_score: 0.9123 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1229 - accuracy: 0.9135 - f1_score: 0.9131
# Epoch 144: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1247 - accuracy: 0.9112 - f1_score: 0.9088 - val_loss: 0.3341 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 145/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1232 - accuracy: 0.9125 - f1_score: 0.9115
# Epoch 145: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1224 - accuracy: 0.9132 - f1_score: 0.9126 - val_loss: 0.3342 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 146/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9122 - f1_score: 0.9130
# Epoch 146: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1228 - accuracy: 0.9122 - f1_score: 0.9130 - val_loss: 0.3341 - val_accuracy: 0.7438 - val_f1_score: 0.6273 - lr: 1.0000e-06
# Epoch 147/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1309 - accuracy: 0.9073 - f1_score: 0.9062
# Epoch 147: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1297 - accuracy: 0.9082 - f1_score: 0.9076 - val_loss: 0.3338 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 148/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1425 - accuracy: 0.8990 - f1_score: 0.8971
# Epoch 148: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1406 - accuracy: 0.9002 - f1_score: 0.8990 - val_loss: 0.3338 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 149/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1246 - accuracy: 0.9125 - f1_score: 0.9112
# Epoch 149: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1220 - accuracy: 0.9142 - f1_score: 0.9137 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 150/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1266 - accuracy: 0.9104 - f1_score: 0.9095
# Epoch 150: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1259 - accuracy: 0.9112 - f1_score: 0.9106 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 151/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1334 - accuracy: 0.9021 - f1_score: 0.9005
# Epoch 151: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1374 - accuracy: 0.9002 - f1_score: 0.8975 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 152/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1305 - accuracy: 0.9083 - f1_score: 0.9074
# Epoch 152: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1294 - accuracy: 0.9092 - f1_score: 0.9087 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 153/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1264 - accuracy: 0.9094 - f1_score: 0.9079
# Epoch 153: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1243 - accuracy: 0.9112 - f1_score: 0.9107 - val_loss: 0.3340 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 154/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1285 - accuracy: 0.9083 - f1_score: 0.9076
# Epoch 154: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1302 - accuracy: 0.9072 - f1_score: 0.9059 - val_loss: 0.3341 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 155/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1270 - accuracy: 0.9085 - f1_score: 0.9080
# Epoch 155: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1278 - accuracy: 0.9082 - f1_score: 0.9081 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 156/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1240 - accuracy: 0.9125 - f1_score: 0.9118
# Epoch 156: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1201 - accuracy: 0.9152 - f1_score: 0.9159 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 157/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1201 - accuracy: 0.9156 - f1_score: 0.9150
# Epoch 157: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1249 - accuracy: 0.9132 - f1_score: 0.9110 - val_loss: 0.3336 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 158/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1323 - accuracy: 0.9062 - f1_score: 0.9049
# Epoch 158: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1275 - accuracy: 0.9092 - f1_score: 0.9092 - val_loss: 0.3338 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 159/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1291 - accuracy: 0.9083 - f1_score: 0.9072
# Epoch 159: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1294 - accuracy: 0.9082 - f1_score: 0.9071 - val_loss: 0.3337 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 160/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1308 - accuracy: 0.9052 - f1_score: 0.9046
# Epoch 160: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1282 - accuracy: 0.9062 - f1_score: 0.9059 - val_loss: 0.3339 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 161/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1207 - accuracy: 0.9125 - f1_score: 0.9116
# Epoch 161: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1213 - accuracy: 0.9122 - f1_score: 0.9112 - val_loss: 0.3338 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 162/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1273 - accuracy: 0.9083 - f1_score: 0.9078Restoring model weights from the end of the best epoch: 62.
#
# Epoch 162: val_accuracy did not improve from 0.75617
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1260 - accuracy: 0.9092 - f1_score: 0.9090 - val_loss: 0.3337 - val_accuracy: 0.7469 - val_f1_score: 0.6297 - lr: 1.0000e-06
# Epoch 162: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
check_model=resnet50
check_model.load_weights('best_model.h5')
check_model.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_12[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_13[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_14[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_12[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_15 (Activation)     (None, 3, 256)       0           ['add_4[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_15[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_16[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_17[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_15[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_5 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_18 (Activation)     (None, 2, 384)       0           ['add_5[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_18[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 816,434
# Trainable params: 816,026
# Non-trainable params: 408
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.7530864197530864

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 5ms/step
# 0.7561728395061729

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7561728395061729
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.54      0.48      0.51        85
#            0       0.82      0.85      0.84       239
#
#     accuracy                           0.76       324
#    macro avg       0.68      0.67      0.67       324
# weighted avg       0.75      0.76      0.75       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 244 chiếm khoảng 75.30864197530865% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 46 chiếm khoảng 54.11764705882353% so với thực tế
