# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_accuracy',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_12[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_13[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_14[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_12[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_15 (Activation)     (None, 3, 256)       0           ['add_4[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_15[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_16[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_17[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_15[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_5 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_18 (Activation)     (None, 2, 384)       0           ['add_5[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_18[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 816,434
# Trainable params: 816,026
# Non-trainable params: 408
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9255 - accuracy: 0.4875 - f1_score: 0.3273
# Epoch 1: val_accuracy improved from -inf to 0.73765, saving model to best_model.h5
# 16/16 [==============================] - 8s 103ms/step - loss: 0.9254 - accuracy: 0.4880 - f1_score: 0.3277 - val_loss: 0.5758 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7515 - accuracy: 0.5198 - f1_score: 0.4250
# Epoch 2: val_accuracy did not improve from 0.73765
# 16/16 [==============================] - 0s 31ms/step - loss: 0.7406 - accuracy: 0.5250 - f1_score: 0.4386 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6057 - accuracy: 0.6187 - f1_score: 0.6012
# Epoch 3: val_accuracy did not improve from 0.73765
# 16/16 [==============================] - 0s 29ms/step - loss: 0.6053 - accuracy: 0.6198 - f1_score: 0.6015 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5666 - accuracy: 0.6354 - f1_score: 0.6274
# Epoch 4: val_accuracy improved from 0.73765 to 0.74074, saving model to best_model.h5
# 16/16 [==============================] - 1s 50ms/step - loss: 0.5584 - accuracy: 0.6397 - f1_score: 0.6342 - val_loss: 0.5686 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5388 - accuracy: 0.6385 - f1_score: 0.6264
# Epoch 5: val_accuracy did not improve from 0.74074
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5368 - accuracy: 0.6397 - f1_score: 0.6285 - val_loss: 0.5673 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 6/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4102 - accuracy: 0.7109 - f1_score: 0.7064
# Epoch 6: val_accuracy improved from 0.74074 to 0.74691, saving model to best_model.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4157 - accuracy: 0.7076 - f1_score: 0.7039 - val_loss: 0.5440 - val_accuracy: 0.7469 - val_f1_score: 0.4593 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3740 - accuracy: 0.7323 - f1_score: 0.7304
# Epoch 7: val_accuracy did not improve from 0.74691
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3718 - accuracy: 0.7355 - f1_score: 0.7349 - val_loss: 0.4369 - val_accuracy: 0.6235 - val_f1_score: 0.6305 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3602 - accuracy: 0.7435 - f1_score: 0.7375
# Epoch 8: val_accuracy did not improve from 0.74691
# 16/16 [==============================] - 0s 29ms/step - loss: 0.3602 - accuracy: 0.7435 - f1_score: 0.7375 - val_loss: 0.4565 - val_accuracy: 0.7377 - val_f1_score: 0.5308 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3304 - accuracy: 0.7656 - f1_score: 0.7609
# Epoch 9: val_accuracy did not improve from 0.74691
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3265 - accuracy: 0.7685 - f1_score: 0.7654 - val_loss: 0.4778 - val_accuracy: 0.7377 - val_f1_score: 0.5084 - lr: 0.0010
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2664 - accuracy: 0.8062 - f1_score: 0.8051
# Epoch 10: val_accuracy did not improve from 0.74691
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2662 - accuracy: 0.8074 - f1_score: 0.8066 - val_loss: 0.4504 - val_accuracy: 0.7346 - val_f1_score: 0.5314 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2584 - accuracy: 0.8135 - f1_score: 0.8123
# Epoch 11: val_accuracy improved from 0.74691 to 0.75926, saving model to best_model.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2630 - accuracy: 0.8134 - f1_score: 0.8111 - val_loss: 0.3967 - val_accuracy: 0.7593 - val_f1_score: 0.5807 - lr: 0.0010
# Epoch 12/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2744 - accuracy: 0.8069 - f1_score: 0.8048
# Epoch 12: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2749 - accuracy: 0.8044 - f1_score: 0.8013 - val_loss: 0.5083 - val_accuracy: 0.7346 - val_f1_score: 0.4818 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2714 - accuracy: 0.8073 - f1_score: 0.8064
# Epoch 13: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2659 - accuracy: 0.8104 - f1_score: 0.8110 - val_loss: 0.4481 - val_accuracy: 0.7377 - val_f1_score: 0.5288 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2316 - accuracy: 0.8354 - f1_score: 0.8332
# Epoch 14: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2270 - accuracy: 0.8393 - f1_score: 0.8391 - val_loss: 0.5721 - val_accuracy: 0.7346 - val_f1_score: 0.4238 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2416 - accuracy: 0.8271 - f1_score: 0.8247
# Epoch 15: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2443 - accuracy: 0.8244 - f1_score: 0.8206 - val_loss: 0.3310 - val_accuracy: 0.7469 - val_f1_score: 0.6233 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2695 - accuracy: 0.8031 - f1_score: 0.8015
# Epoch 16: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2788 - accuracy: 0.7984 - f1_score: 0.7945 - val_loss: 0.3182 - val_accuracy: 0.7438 - val_f1_score: 0.6389 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2894 - accuracy: 0.7979 - f1_score: 0.7954
# Epoch 17: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2900 - accuracy: 0.7974 - f1_score: 0.7948 - val_loss: 0.4406 - val_accuracy: 0.7593 - val_f1_score: 0.5399 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2593 - accuracy: 0.8125 - f1_score: 0.8109
# Epoch 18: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2581 - accuracy: 0.8134 - f1_score: 0.8123 - val_loss: 0.3439 - val_accuracy: 0.7469 - val_f1_score: 0.6269 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2377 - accuracy: 0.8292 - f1_score: 0.8282
# Epoch 19: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2353 - accuracy: 0.8313 - f1_score: 0.8314 - val_loss: 0.3279 - val_accuracy: 0.7438 - val_f1_score: 0.6352 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2297 - accuracy: 0.8354 - f1_score: 0.8332
# Epoch 20: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2316 - accuracy: 0.8333 - f1_score: 0.8293 - val_loss: 0.5386 - val_accuracy: 0.7346 - val_f1_score: 0.4582 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2478 - accuracy: 0.8229 - f1_score: 0.8212
# Epoch 21: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 42ms/step - loss: 0.2454 - accuracy: 0.8253 - f1_score: 0.8248 - val_loss: 0.4202 - val_accuracy: 0.7377 - val_f1_score: 0.5558 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2321 - accuracy: 0.8344 - f1_score: 0.8334
# Epoch 22: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2334 - accuracy: 0.8333 - f1_score: 0.8319 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.8224 - f1_score: 0.8194
# Epoch 23: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 40ms/step - loss: 0.2498 - accuracy: 0.8224 - f1_score: 0.8194 - val_loss: 0.5551 - val_accuracy: 0.7284 - val_f1_score: 0.4422 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2250 - accuracy: 0.8365 - f1_score: 0.8357
# Epoch 24: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2249 - accuracy: 0.8373 - f1_score: 0.8369 - val_loss: 0.4637 - val_accuracy: 0.7315 - val_f1_score: 0.5186 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2257 - accuracy: 0.8375 - f1_score: 0.8366
# Epoch 25: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2301 - accuracy: 0.8353 - f1_score: 0.8334 - val_loss: 0.5422 - val_accuracy: 0.7346 - val_f1_score: 0.4543 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2168 - accuracy: 0.8458 - f1_score: 0.8453
# Epoch 26: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2151 - accuracy: 0.8473 - f1_score: 0.8476 - val_loss: 0.5347 - val_accuracy: 0.7253 - val_f1_score: 0.4599 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2323 - accuracy: 0.8344 - f1_score: 0.8331
# Epoch 27: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2321 - accuracy: 0.8353 - f1_score: 0.8344 - val_loss: 0.3100 - val_accuracy: 0.7500 - val_f1_score: 0.6334 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2488 - accuracy: 0.8208 - f1_score: 0.8189
# Epoch 28: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2458 - accuracy: 0.8224 - f1_score: 0.8212 - val_loss: 0.4264 - val_accuracy: 0.7500 - val_f1_score: 0.5510 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.8423 - f1_score: 0.8421
# Epoch 29: val_accuracy did not improve from 0.75926
# 16/16 [==============================] - 1s 37ms/step - loss: 0.2198 - accuracy: 0.8423 - f1_score: 0.8421 - val_loss: 0.4835 - val_accuracy: 0.7438 - val_f1_score: 0.5002 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2219 - accuracy: 0.8417 - f1_score: 0.8398
# Epoch 30: val_accuracy improved from 0.75926 to 0.76852, saving model to best_model.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2206 - accuracy: 0.8423 - f1_score: 0.8409 - val_loss: 0.3244 - val_accuracy: 0.7685 - val_f1_score: 0.6409 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2219 - accuracy: 0.8417 - f1_score: 0.8407
# Epoch 31: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2255 - accuracy: 0.8383 - f1_score: 0.8357 - val_loss: 0.3267 - val_accuracy: 0.7531 - val_f1_score: 0.6205 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2088 - accuracy: 0.8500 - f1_score: 0.8491
# Epoch 32: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s
val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1283 - accuracy: 0.9102 - f1_score: 0.9098 - val_loss: 0.3553 - val_accuracy: 0.7407 - val_f1_score: 0.5963 - lr: 5.0000e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1221 - accuracy: 0.9125 - f1_score: 0.9120
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 83: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1254 - accuracy: 0.9102 - f1_score: 0.9085 - val_loss: 0.3705 - val_accuracy: 0.7130 - val_f1_score: 0.5828 - lr: 5.0000e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1224 - accuracy: 0.9135 - f1_score: 0.9128
# Epoch 84: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1186 - accuracy: 0.9162 - f1_score: 0.9168 - val_loss: 0.3682 - val_accuracy: 0.7130 - val_f1_score: 0.5881 - lr: 2.5000e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1254 - accuracy: 0.9115 - f1_score: 0.9102
# Epoch 85: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1278 - accuracy: 0.9092 - f1_score: 0.9068 - val_loss: 0.3770 - val_accuracy: 0.7099 - val_f1_score: 0.5801 - lr: 2.5000e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1097 - accuracy: 0.9198 - f1_score: 0.9189
# Epoch 86: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1140 - accuracy: 0.9172 - f1_score: 0.9149 - val_loss: 0.3798 - val_accuracy: 0.7099 - val_f1_score: 0.5746 - lr: 2.5000e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1041 - accuracy: 0.9250 - f1_score: 0.9243
# Epoch 87: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1076 - accuracy: 0.9232 - f1_score: 0.9213 - val_loss: 0.3812 - val_accuracy: 0.7006 - val_f1_score: 0.5715 - lr: 2.5000e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1102 - accuracy: 0.9229 - f1_score: 0.9214
# Epoch 88: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1096 - accuracy: 0.9232 - f1_score: 0.9218 - val_loss: 0.3849 - val_accuracy: 0.7006 - val_f1_score: 0.5684 - lr: 2.5000e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1056 - accuracy: 0.9240 - f1_score: 0.9232
# Epoch 89: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1061 - accuracy: 0.9232 - f1_score: 0.9221 - val_loss: 0.3929 - val_accuracy: 0.7006 - val_f1_score: 0.5620 - lr: 2.5000e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1084 - accuracy: 0.9229 - f1_score: 0.9224
# Epoch 90: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1089 - accuracy: 0.9222 - f1_score: 0.9210 - val_loss: 0.3699 - val_accuracy: 0.7099 - val_f1_score: 0.5840 - lr: 2.5000e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1039 - accuracy: 0.9271 - f1_score: 0.9268
# Epoch 91: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0996 - accuracy: 0.9301 - f1_score: 0.9314 - val_loss: 0.3723 - val_accuracy: 0.7284 - val_f1_score: 0.5889 - lr: 2.5000e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1038 - accuracy: 0.9271 - f1_score: 0.9264
# Epoch 92: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1024 - accuracy: 0.9281 - f1_score: 0.9279 - val_loss: 0.3691 - val_accuracy: 0.7191 - val_f1_score: 0.5858 - lr: 2.5000e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1078 - accuracy: 0.9219 - f1_score: 0.9213
# Epoch 93: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1078 - accuracy: 0.9222 - f1_score: 0.9217 - val_loss: 0.3771 - val_accuracy: 0.6944 - val_f1_score: 0.5810 - lr: 2.5000e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1108 - accuracy: 0.9198 - f1_score: 0.9191
# Epoch 94: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.
10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0932 - accuracy: 0.9344 - f1_score: 0.9340
# Epoch 107: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0918 - accuracy: 0.9351 - f1_score: 0.9351 - val_loss: 0.4119 - val_accuracy: 0.6883 - val_f1_score: 0.5474 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1105 - accuracy: 0.9250 - f1_score: 0.9224
# Epoch 108: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1097 - accuracy: 0.9251 - f1_score: 0.9227 - val_loss: 0.4060 - val_accuracy: 0.6914 - val_f1_score: 0.5521 - lr: 1.2500e-04
# Epoch 109/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9371 - f1_score: 0.9346
# Epoch 109: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0879 - accuracy: 0.9371 - f1_score: 0.9346 - val_loss: 0.4086 - val_accuracy: 0.6975 - val_f1_score: 0.5508 - lr: 1.2500e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0863 - accuracy: 0.9385 - f1_score: 0.9379
# Epoch 110: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0853 - accuracy: 0.9391 - f1_score: 0.9388 - val_loss: 0.4065 - val_accuracy: 0.7037 - val_f1_score: 0.5550 - lr: 1.2500e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0895 - accuracy: 0.9385 - f1_score: 0.9376
# Epoch 111: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0921 - accuracy: 0.9361 - f1_score: 0.9340 - val_loss: 0.4109 - val_accuracy: 0.6883 - val_f1_score: 0.5477 - lr: 1.2500e-04
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1013 - accuracy: 0.9271 - f1_score: 0.9260
# Epoch 112: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1033 - accuracy: 0.9261 - f1_score: 0.9246 - val_loss: 0.4211 - val_accuracy: 0.6790 - val_f1_score: 0.5409 - lr: 1.2500e-04
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0848 - accuracy: 0.9385 - f1_score: 0.9381
# Epoch 113: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0881 - accuracy: 0.9361 - f1_score: 0.9346 - val_loss: 0.4180 - val_accuracy: 0.6852 - val_f1_score: 0.5452 - lr: 1.2500e-04
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0885 - accuracy: 0.9375 - f1_score: 0.9371
# Epoch 114: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0866 - accuracy: 0.9391 - f1_score: 0.9395 - val_loss: 0.4166 - val_accuracy: 0.6790 - val_f1_score: 0.5440 - lr: 1.2500e-04
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0906 - accuracy: 0.9365 - f1_score: 0.9350
# Epoch 115: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0908 - accuracy: 0.9361 - f1_score: 0.9346 - val_loss: 0.4080 - val_accuracy: 0.6852 - val_f1_score: 0.5530 - lr: 1.2500e-04
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0993 - accuracy: 0.9302 - f1_score: 0.9289
# Epoch 116: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0997 - accuracy: 0.9301 - f1_score: 0.9287 - val_loss: 0.4088 - val_accuracy: 0.6790 - val_f1_score: 0.5540 - lr: 1.2500e-04
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1000 - accuracy: 0.9281 - f1_score: 0.9270
# Epoch 117: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0958 - accuracy: 0.9311 - f1_score: 0.9315 - val_loss: 0.3959 - val_accuracy: 0.6759 - val_f1_score: 0.5621 - lr: 1.2500e-04
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0886 - accuracy: 0.9365 - f1_score: 0.9358
# Epoch 118: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0862 - accuracy: 0.9381 - f1_score: 0.9384 - val_loss: 0.3968 - val_accuracy: 0.6852 - val_f1_score: 0.5609 - lr: 1.2500e-04
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0945 - accuracy: 0.9344 - f1_score: 0.9327
# Epoch 119: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0943 - accuracy: 0.9341 - f1_score: 0.9320 - val_loss: 0.4041 - val_accuracy: 0.6975 - val_f1_score: 0.5468 - lr: 1.2500e-04
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0889 - accuracy: 0.9375 - f1_score: 0.9365
# Epoch 120: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0910 - accuracy: 0.9361 - f1_score: 0.9344 - val_loss: 0.4085 - val_accuracy: 0.6975 - val_f1_score: 0.5523 - lr: 1.2500e-04
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0859 - accuracy: 0.9385 - f1_score: 0.9376
# Epoch 121: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0881 - accuracy: 0.9371 - f1_score: 0.9354 - val_loss: 0.4075 - val_accuracy: 0.6821 - val_f1_score: 0.5524 - lr: 1.2500e-04
# Epoch 122/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9411 - f1_score: 0.9382
# Epoch 122: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0834 - accuracy: 0.9411 - f1_score: 0.9382 - val_loss: 0.4078 - val_accuracy: 0.6790 - val_f1_score: 0.5534 - lr: 1.2500e-04
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0977 - accuracy: 0.9302 - f1_score: 0.9291
# Epoch 123: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 123: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0950 - accuracy: 0.9321 - f1_score: 0.9321 - val_loss: 0.4063 - val_accuracy: 0.6667 - val_f1_score: 0.5522 - lr: 1.2500e-04
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0872 - accuracy: 0.9375 - f1_score: 0.9369
# Epoch 124: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0886 - accuracy: 0.9371 - f1_score: 0.9361 - val_loss: 0.4086 - val_accuracy: 0.6759 - val_f1_score: 0.5515 - lr: 6.2500e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0859 - accuracy: 0.9385 - f1_score: 0.9374
# Epoch 125: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0852 - accuracy: 0.9391 - f1_score: 0.9383 - val_loss: 0.4016 - val_accuracy: 0.6914 - val_f1_score: 0.5586 - lr: 6.2500e-05
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0960 - accuracy: 0.9333 - f1_score: 0.9321
# Epoch 126: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0962 - accuracy: 0.9331 - f1_score: 0.9319 - val_loss: 0.3993 - val_accuracy: 0.6790 - val_f1_score: 0.5570 - lr: 6.2500e-05
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0916 - accuracy: 0.9344 - f1_score: 0.9332
# Epoch 127: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0920 - accuracy: 0.9341 - f1_score: 0.9329 - val_loss: 0.3887 - val_accuracy: 0.6914 - val_f1_score: 0.5683 - lr: 6.2500e-05
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0940 - accuracy: 0.9333 - f1_score: 0.9319
# Epoch 128: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0958 - accuracy: 0.9321 - f1_score: 0.9300 - val_loss: 0.3826 - val_accuracy: 0.7006 - val_f1_score: 0.5728 - lr: 6.2500e-05
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0913 - accuracy: 0.9354 - f1_score: 0.9343
# Epoch 129: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0901 - accuracy: 0.9361 - f1_score: 0.9354 - val_loss: 0.3846 - val_accuracy: 0.6975 - val_f1_score: 0.5732 - lr: 6.2500e-05
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0827 - accuracy: 0.9406 - f1_score: 0.9403
# Epoch 130: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0807 - accuracy: 0.9421 - f1_score: 0.9426 - val_loss: 0.3819 - val_accuracy: 0.7006 - val_f1_score: 0.5751 - lr: 6.2500e-05
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0884 - accuracy: 0.9365 - f1_score: 0.9353
# Epoch 131: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0886 - accuracy: 0.9361 - f1_score: 0.9348 - val_loss: 0.3840 - val_accuracy: 0.7037 - val_f1_score: 0.5751 - lr: 6.2500e-05
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0930 - accuracy: 0.9344 - f1_score: 0.9330
# Epoch 132: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0919 - accuracy: 0.9351 - f1_score: 0.9342 - val_loss: 0.3843 - val_accuracy: 0.6975 - val_f1_score: 0.5729 - lr: 6.2500e-05
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9391 - f1_score: 0.9390
# Epoch 133: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0874 - accuracy: 0.9391 - f1_score: 0.9390 - val_loss: 0.3852 - val_accuracy: 0.6975 - val_f1_score: 0.5704 - lr: 6.2500e-05
# Epoch 134/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0805 - accuracy: 0.9427 - f1_score: 0.9422
# Epoch 134: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0786 - accuracy: 0.9441 - f1_score: 0.9443 - val_loss: 0.3863 - val_accuracy: 0.7037 - val_f1_score: 0.5748 - lr: 6.2500e-05
# Epoch 135/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0825 - accuracy: 0.9406 - f1_score: 0.9399
# Epoch 135: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0832 - accuracy: 0.9401 - f1_score: 0.9392 - val_loss: 0.3842 - val_accuracy: 0.7037 - val_f1_score: 0.5715 - lr: 6.2500e-05
# Epoch 136/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0863 - accuracy: 0.9396 - f1_score: 0.9388
# Epoch 136: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0858 - accuracy: 0.9401 - f1_score: 0.9395 - val_loss: 0.3876 - val_accuracy: 0.7037 - val_f1_score: 0.5658 - lr: 6.2500e-05
# Epoch 137/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0797 - accuracy: 0.9427 - f1_score: 0.9424
# Epoch 137: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0779 - accuracy: 0.9441 - f1_score: 0.9444 - val_loss: 0.3865 - val_accuracy: 0.7006 - val_f1_score: 0.5679 - lr: 6.2500e-05
# Epoch 138/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0780 - accuracy: 0.9448 - f1_score: 0.9445
# Epoch 138: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0778 - accuracy: 0.9451 - f1_score: 0.9450 - val_loss: 0.3857 - val_accuracy: 0.7037 - val_f1_score: 0.5715 - lr: 6.2500e-05
# Epoch 139/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0831 - accuracy: 0.9417 - f1_score: 0.9411
# Epoch 139: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0810 - accuracy: 0.9431 - f1_score: 0.9432 - val_loss: 0.3864 - val_accuracy: 0.7006 - val_f1_score: 0.5691 - lr: 6.2500e-05
# Epoch 140/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0786 - accuracy: 0.9438 - f1_score: 0.9426
# Epoch 140: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0782 - accuracy: 0.9441 - f1_score: 0.9432 - val_loss: 0.3873 - val_accuracy: 0.6975 - val_f1_score: 0.5669 - lr: 6.2500e-05
# Epoch 141/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0816 - accuracy: 0.9406 - f1_score: 0.9394
# Epoch 141: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0811 - accuracy: 0.9411 - f1_score: 0.9402 - val_loss: 0.3899 - val_accuracy: 0.6975 - val_f1_score: 0.5669 - lr: 6.2500e-05
# Epoch 142/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0782 - accuracy: 0.9438 - f1_score: 0.9430
# Epoch 142: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0776 - accuracy: 0.9441 - f1_score: 0.9436 - val_loss: 0.3922 - val_accuracy: 0.6944 - val_f1_score: 0.5633 - lr: 6.2500e-05
# Epoch 143/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0803 - accuracy: 0.9417 - f1_score: 0.9412Restoring model weights from the end of the best epoch: 43.
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 143: val_accuracy did not improve from 0.76852
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0843 - accuracy: 0.9401 - f1_score: 0.9382 - val_loss: 0.3945 - val_accuracy: 0.6944 - val_f1_score: 0.5620 - lr: 6.2500e-05
# Epoch 143: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
check_model=resnet50
check_model.load_weights('best_model.h5')
check_model.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_12[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_13[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_14[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_12[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_15 (Activation)     (None, 3, 256)       0           ['add_4[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_15[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_16[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_17[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_15[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_5 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_18 (Activation)     (None, 2, 384)       0           ['add_5[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_18[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 816,434
# Trainable params: 816,026
# Non-trainable params: 408
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 5ms/step
# 0.7685185185185185

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 5ms/step
# 0.7685185185185185

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7685185185185185
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.57      0.49      0.53        85
#            0       0.83      0.87      0.85       239
#
#     accuracy                           0.77       324
#    macro avg       0.70      0.68      0.69       324
# weighted avg       0.76      0.77      0.76       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 249 chiếm khoảng 76.85185185185185% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 42 chiếm khoảng 49.411764705882355% so với thực tế
