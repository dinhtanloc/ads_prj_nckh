# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Dense, LSTM, BatchNormalization, Dropout
from scikeras.wrappers import KerasClassifier 


def build_model(unit):
    model = Sequential()

    model.add(LSTM(units=unit, input_shape=(42,1), activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])


    return model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# Wrap Keras model so it can be used by scikit-learn
model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Define the grid of hyperparameters to search
param_grid = {
    'model__unit': [32, 64, 96,128,184,256,384,512],
 
}

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)

# # Load your data here
# # X_train, y_train = ...
# # X_val, y_val = ...

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %%
model = build_model(32)
lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=focal_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)


lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 128)               4224
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 8834 (34.51 KB)
# Trainable params: 8834 (34.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 1s 24ms/step - loss: 0.8334 - accuracy: 0.5130 - f1_score: 0.5132 - val_loss: 1.2579 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.7924 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 1.0350 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.7784 - accuracy: 0.5000 - f1_score: 0.4990 - val_loss: 1.1028 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.7722 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 1.0563 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7631 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 1.0548 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7354 - accuracy: 0.5070 - f1_score: 0.5084 - val_loss: 1.2636 - val_accuracy: 0.2654 - val_f1_score: 0.2630 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7515 - accuracy: 0.5210 - f1_score: 0.5185 - val_loss: 1.1196 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7381 - accuracy: 0.5000 - f1_score: 0.5000 - val_loss: 1.0476 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7243 - accuracy: 0.5042 - f1_score: 0.5042
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7249 - accuracy: 0.5000 - f1_score: 0.4980 - val_loss: 1.1135 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.7011 - accuracy: 0.5040 - f1_score: 0.5019 - val_loss: 0.9942 - val_accuracy: 0.2840 - val_f1_score: 0.3177 - lr: 5.0000e-04
# Epoch 11/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6818 - accuracy: 0.5369 - f1_score: 0.5356 - val_loss: 1.0378 - val_accuracy: 0.3302 - val_f1_score: 0.3568 - lr: 5.0000e-04
# Epoch 12/10000
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6683 - accuracy: 0.5848 - f1_score: 0.5835 - val_loss: 1.0362 - val_accuracy: 0.3673 - val_f1_score: 0.3880 - lr: 5.0000e-04
# Epoch 13/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6633 - accuracy: 0.6118 - f1_score: 0.6114 - val_loss: 1.0476 - val_accuracy: 0.3735 - val_f1_score: 0.3932 - lr: 5.0000e-04
# Epoch 14/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6659 - accuracy: 0.6128 - f1_score: 0.6134 - val_loss: 1.1615 - val_accuracy: 0.3117 - val_f1_score: 0.3411 - lr: 5.0000e-04
# Epoch 15/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6751 - accuracy: 0.5729 - f1_score: 0.5728 - val_loss: 0.9454 - val_accuracy: 0.4043 - val_f1_score: 0.4193 - lr: 5.0000e-04
# Epoch 16/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6597 - accuracy: 0.6018 - f1_score: 0.6001 - val_loss: 0.9214 - val_accuracy: 0.4475 - val_f1_score: 0.4557 - lr: 5.0000e-04
# Epoch 17/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6598 - accuracy: 0.6038 - f1_score: 0.6051 - val_loss: 0.9159 - val_accuracy: 0.4383 - val_f1_score: 0.4479 - lr: 5.0000e-04
# Epoch 18/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6545 - accuracy: 0.6098 - f1_score: 0.6069 - val_loss: 0.9262 - val_accuracy: 0.4506 - val_f1_score: 0.4583 - lr: 5.0000e-04
# Epoch 19/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6529 - accuracy: 0.6158 - f1_score: 0.6153 - val_loss: 0.9941 - val_accuracy: 0.3920 - val_f1_score: 0.4089 - lr: 5.0000e-04
# Epoch 20/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6559 - accuracy: 0.6088 - f1_score: 0.6085 - val_loss: 1.1148 - val_accuracy: 0.3549 - val_f1_score: 0.3776 - lr: 5.0000e-04
# Epoch 21/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6506 - accuracy: 0.6158 - f1_score: 0.6138 - val_loss: 1.0480 - val_accuracy: 0.3704 - val_f1_score: 0.3906 - lr: 5.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6478 - accuracy: 0.6028 - f1_score: 0.6021 - val_loss: 0.9668 - val_accuracy: 0.4043 - val_f1_score: 0.4193 - lr: 5.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6486 - accuracy: 0.6108 - f1_score: 0.6058 - val_loss: 1.1225 - val_accuracy: 0.3549 - val_f1_score: 0.3776 - lr: 5.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6431 - accuracy: 0.6387 - f1_score: 0.6398
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6431 - accuracy: 0.6387 - f1_score: 0.6398 - val_loss: 1.1168 - val_accuracy: 0.3580 - val_f1_score: 0.3802 - lr: 5.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6455 - accuracy: 0.6168 - f1_score: 0.6189 - val_loss: 0.9317 - val_accuracy: 0.4352 - val_f1_score: 0.4453 - lr: 2.5000e-04
# Epoch 26/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6392 - accuracy: 0.6118 - f1_score: 0.6104 - val_loss: 0.9328 - val_accuracy: 0.4228 - val_f1_score: 0.4349 - lr: 2.5000e-04
# Epoch 27/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6360 - accuracy: 0.6088 - f1_score: 0.6075 - val_loss: 0.9509 - val_accuracy: 0.4198 - val_f1_score: 0.4323 - lr: 2.5000e-04
# Epoch 28/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6377 - accuracy: 0.6307 - f1_score: 0.6284 - val_loss: 0.9982 - val_accuracy: 0.3981 - val_f1_score: 0.4141 - lr: 2.5000e-04
# Epoch 29/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6337 - accuracy: 0.6317 - f1_score: 0.6330 - val_loss: 0.9915 - val_accuracy: 0.4074 - val_f1_score: 0.4219 - lr: 2.5000e-04
# Epoch 30/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6337 - accuracy: 0.6228 - f1_score: 0.6242 - val_loss: 0.9720 - val_accuracy: 0.4105 - val_f1_score: 0.4245 - lr: 2.5000e-04
# Epoch 31/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6309 - accuracy: 0.6148 - f1_score: 0.6179 - val_loss: 0.9098 - val_accuracy: 0.4568 - val_f1_score: 0.4635 - lr: 2.5000e-04
# Epoch 32/10000
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6321 - accuracy: 0.6238 - f1_score: 0.6211 - val_loss: 0.9750 - val_accuracy: 0.4198 - val_f1_score: 0.4323 - lr: 2.5000e-04
# Epoch 33/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6388 - accuracy: 0.6098 - f1_score: 0.6105 - val_loss: 1.0009 - val_accuracy: 0.3889 - val_f1_score: 0.4062 - lr: 2.5000e-04
# Epoch 34/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6297 - accuracy: 0.6357 - f1_score: 0.6354 - val_loss: 0.9755 - val_accuracy: 0.4259 - val_f1_score: 0.4375 - lr: 2.5000e-04
# Epoch 35/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6278 - accuracy: 0.6287 - f1_score: 0.6316 - val_loss: 0.9277 - val_accuracy: 0.4444 - val_f1_score: 0.4531 - lr: 2.5000e-04
# Epoch 36/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6234 - accuracy: 0.6267 - f1_score: 0.6291 - val_loss: 0.9376 - val_accuracy: 0.4691 - val_f1_score: 0.4740 - lr: 2.5000e-04
# Epoch 37/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6227 - accuracy: 0.6257 - f1_score: 0.6246 - val_loss: 0.9073 - val_accuracy: 0.4722 - val_f1_score: 0.4766 - lr: 2.5000e-04
# Epoch 38/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6225 - accuracy: 0.6487 - f1_score: 0.6496 - val_loss: 1.0643 - val_accuracy: 0.3981 - val_f1_score: 0.4141 - lr: 2.5000e-04
# Epoch 39/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6312 - accuracy: 0.6228 - f1_score: 0.6206 - val_loss: 0.9218 - val_accuracy: 0.4352 - val_f1_score: 0.4453 - lr: 2.5000e-04
# Epoch 40/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6207 - accuracy: 0.6228 - f1_score: 0.6222 - val_loss: 0.9257 - val_accuracy: 0.4414 - val_f1_score: 0.4505 - lr: 2.5000e-04
# Epoch 41/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6180 - accuracy: 0.6357 - f1_score: 0.6333 - val_loss: 0.8809 - val_accuracy: 0.5062 - val_f1_score: 0.5443 - lr: 2.5000e-04
# Epoch 42/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6185 - accuracy: 0.6397 - f1_score: 0.6418 - val_loss: 1.0705 - val_accuracy: 0.4012 - val_f1_score: 0.3776 - lr: 2.5000e-04
# Epoch 43/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6218 - accuracy: 0.6387 - f1_score: 0.6398 - val_loss: 0.9869 - val_accuracy: 0.4290 - val_f1_score: 0.4401 - lr: 2.5000e-04
# Epoch 44/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6271 - accuracy: 0.6168 - f1_score: 0.6168 - val_loss: 0.9878 - val_accuracy: 0.4290 - val_f1_score: 0.4401 - lr: 2.5000e-04
# Epoch 45/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6149 - accuracy: 0.6108 - f1_score: 0.6115 - val_loss: 0.8393 - val_accuracy: 0.5154 - val_f1_score: 0.5521 - lr: 2.5000e-04
# Epoch 46/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6176 - accuracy: 0.6417 - f1_score: 0.6407 - val_loss: 0.9919 - val_accuracy: 0.4290 - val_f1_score: 0.4401 - lr: 2.5000e-04
# Epoch 47/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6165 - accuracy: 0.6357 - f1_score: 0.6364 - val_loss: 0.9936 - val_accuracy: 0.4290 - val_f1_score: 0.4401 - lr: 2.5000e-04
# Epoch 48/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6095 - accuracy: 0.6427 - f1_score: 0.6427 - val_loss: 0.9182 - val_accuracy: 0.4815 - val_f1_score: 0.4844 - lr: 2.5000e-04
# Epoch 49/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6084 - accuracy: 0.6337 - f1_score: 0.6355 - val_loss: 0.9042 - val_accuracy: 0.5000 - val_f1_score: 0.5000 - lr: 2.5000e-04
# Epoch 50/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6106 - accuracy: 0.6347 - f1_score: 0.6354 - val_loss: 0.9406 - val_accuracy: 0.4784 - val_f1_score: 0.4818 - lr: 2.5000e-04
# Epoch 51/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6146 - accuracy: 0.6487 - f1_score: 0.6486 - val_loss: 1.0346 - val_accuracy: 0.4105 - val_f1_score: 0.3854 - lr: 2.5000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6068 - accuracy: 0.6344 - f1_score: 0.6344
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6045 - accuracy: 0.6367 - f1_score: 0.6379 - val_loss: 0.8850 - val_accuracy: 0.4969 - val_f1_score: 0.4974 - lr: 2.5000e-04
# Epoch 53/10000
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6040 - accuracy: 0.6377 - f1_score: 0.6368 - val_loss: 0.9338 - val_accuracy: 0.4753 - val_f1_score: 0.4792 - lr: 1.2500e-04
# Epoch 54/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6030 - accuracy: 0.6457 - f1_score: 0.6446 - val_loss: 0.9496 - val_accuracy: 0.4753 - val_f1_score: 0.4792 - lr: 1.2500e-04
# Epoch 55/10000
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6016 - accuracy: 0.6397 - f1_score: 0.6372 - val_loss: 0.9064 - val_accuracy: 0.4907 - val_f1_score: 0.4922 - lr: 1.2500e-04
# Epoch 56/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6044 - accuracy: 0.6487 - f1_score: 0.6476 - val_loss: 0.9539 - val_accuracy: 0.4722 - val_f1_score: 0.4766 - lr: 1.2500e-04
# Epoch 57/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6029 - accuracy: 0.6427 - f1_score: 0.6432 - val_loss: 0.9492 - val_accuracy: 0.4722 - val_f1_score: 0.4766 - lr: 1.2500e-04
# Epoch 58/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6000 - accuracy: 0.6417 - f1_score: 0.6438 - val_loss: 0.9027 - val_accuracy: 0.4938 - val_f1_score: 0.4948 - lr: 1.2500e-04
# Epoch 59/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6084 - accuracy: 0.6302 - f1_score: 0.6302
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5990 - accuracy: 0.6447 - f1_score: 0.6436 - val_loss: 0.9400 - val_accuracy: 0.4846 - val_f1_score: 0.4870 - lr: 1.2500e-04
# Epoch 60/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5971 - accuracy: 0.6467 - f1_score: 0.6466 - val_loss: 0.9269 - val_accuracy: 0.4846 - val_f1_score: 0.4870 - lr: 6.2500e-05
# Epoch 61/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5971 - accuracy: 0.6477 - f1_score: 0.6461 - val_loss: 0.9288 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 6.2500e-05
# Epoch 62/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5968 - accuracy: 0.6437 - f1_score: 0.6437 - val_loss: 0.9305 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 6.2500e-05
# Epoch 63/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5964 - accuracy: 0.6457 - f1_score: 0.6431 - val_loss: 0.9333 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 6.2500e-05
# Epoch 64/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5959 - accuracy: 0.6467 - f1_score: 0.6492 - val_loss: 0.9283 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 6.2500e-05
# Epoch 65/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5962 - accuracy: 0.6437 - f1_score: 0.6437 - val_loss: 0.9220 - val_accuracy: 0.4907 - val_f1_score: 0.4922 - lr: 6.2500e-05
# Epoch 66/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.5884 - accuracy: 0.6441 - f1_score: 0.6441
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5955 - accuracy: 0.6497 - f1_score: 0.6475 - val_loss: 0.9294 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 6.2500e-05
# Epoch 67/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5945 - accuracy: 0.6477 - f1_score: 0.6481 - val_loss: 0.9317 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 68/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5945 - accuracy: 0.6457 - f1_score: 0.6472 - val_loss: 0.9365 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 69/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5943 - accuracy: 0.6447 - f1_score: 0.6431 - val_loss: 0.9337 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 70/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5938 - accuracy: 0.6457 - f1_score: 0.6482 - val_loss: 0.9269 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 71/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5944 - accuracy: 0.6517 - f1_score: 0.6520 - val_loss: 0.9341 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 72/10000
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5939 - accuracy: 0.6447 - f1_score: 0.6436 - val_loss: 0.9397 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 3.1250e-05
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6029 - accuracy: 0.6438 - f1_score: 0.6437
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5964 - accuracy: 0.6517 - f1_score: 0.6556 - val_loss: 0.9084 - val_accuracy: 0.4907 - val_f1_score: 0.4922 - lr: 3.1250e-05
# Epoch 74/10000
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5927 - accuracy: 0.6507 - f1_score: 0.6490 - val_loss: 0.9389 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 1.5625e-05
# Epoch 75/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.5802 - accuracy: 0.6458 - f1_score: 0.6458Restoring model weights from the end of the best epoch: 45.
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5932 - accuracy: 0.6437 - f1_score: 0.6437 - val_loss: 0.9402 - val_accuracy: 0.4877 - val_f1_score: 0.4896 - lr: 1.5625e-05
# Epoch 75: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 0.5154320987654321

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.5154320987654321
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.31      0.69      0.43        85
#            0       0.81      0.45      0.58       239
#
#     accuracy                           0.52       324
#    macro avg       0.56      0.57      0.50       324
# weighted avg       0.68      0.52      0.54       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 167 chiếm khoảng 51.54320987654321% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 59 chiếm khoảng 69.41176470588235% so với thực tế
