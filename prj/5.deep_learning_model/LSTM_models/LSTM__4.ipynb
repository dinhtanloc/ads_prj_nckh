# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
from keras.layers import Dense, LSTM, BatchNormalization, Dropout
# from scikeras.wrappers import KerasClassifier 


def build_model(unit):
    model = Sequential()

    model.add(LSTM(units=unit, input_shape=(42,1), activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(optimizer=Adam(lr=0.0001), loss=f1_loss, metrics=['accuracy',f1_score])


    return model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# # Wrap Keras model so it can be used by scikit-learn
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# # Define the grid of hyperparameters to search
# param_grid = {
#     'model__unit': [32, 64, 96,128,184,256,384,512],
 
# }

# # Create a scorer using make_scorer
# f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)

# # Load your data here
# # X_train, y_train = ...
# # X_val, y_val = ...

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
model=build_model(32)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 128)               4224
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 8834 (34.51 KB)
# Trainable params: 8834 (34.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6863 - accuracy: 0.5078 - f1_score: 0.3864
# Epoch 1: val_f1_score improved from -inf to 0.44772, saving model to best_model.hdf5
# 16/16 [==============================] - 2s 30ms/step - loss: 0.6928 - accuracy: 0.5020 - f1_score: 0.3936 - val_loss: 0.5280 - val_accuracy: 0.5062 - val_f1_score: 0.4477 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6897 - accuracy: 0.5312 - f1_score: 0.5277
# Epoch 2: val_f1_score improved from 0.44772 to 0.46394, saving model to best_model.hdf5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6845 - accuracy: 0.5359 - f1_score: 0.5325 - val_loss: 0.5146 - val_accuracy: 0.5556 - val_f1_score: 0.4639 - lr: 0.0010
# Epoch 3/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6456 - accuracy: 0.5781 - f1_score: 0.5555
# Epoch 3: val_f1_score improved from 0.46394 to 0.51662, saving model to best_model.hdf5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6450 - accuracy: 0.5788 - f1_score: 0.5561 - val_loss: 0.4972 - val_accuracy: 0.4969 - val_f1_score: 0.5166 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5609 - accuracy: 0.6385 - f1_score: 0.6218
# Epoch 4: val_f1_score did not improve from 0.51662
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5569 - accuracy: 0.6367 - f1_score: 0.6198 - val_loss: 0.5049 - val_accuracy: 0.5833 - val_f1_score: 0.4689 - lr: 0.0010
# Epoch 5/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5766 - accuracy: 0.6038 - f1_score: 0.5847
# Epoch 5: val_f1_score did not improve from 0.51662
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5874 - accuracy: 0.6088 - f1_score: 0.5806 - val_loss: 0.5549 - val_accuracy: 0.4475 - val_f1_score: 0.4509 - lr: 0.0010
# Epoch 6/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.5551 - accuracy: 0.6238 - f1_score: 0.6047
# Epoch 6: val_f1_score improved from 0.51662 to 0.52106, saving model to best_model.hdf5
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5646 - accuracy: 0.6178 - f1_score: 0.5972 - val_loss: 0.4806 - val_accuracy: 0.5494 - val_f1_score: 0.5211 - lr: 0.0010
# Epoch 7/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5458 - accuracy: 0.6194 - f1_score: 0.6076
# Epoch 7: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5476 - accuracy: 0.6178 - f1_score: 0.6049 - val_loss: 0.4901 - val_accuracy: 0.6296 - val_f1_score: 0.4860 - lr: 0.0010
# Epoch 8/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5328 - accuracy: 0.6328 - f1_score: 0.6194
# Epoch 8: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5426 - accuracy: 0.6267 - f1_score: 0.6116 - val_loss: 0.5137 - val_accuracy: 0.4938 - val_f1_score: 0.4851 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5494 - accuracy: 0.6198 - f1_score: 0.6046
# Epoch 9: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5472 - accuracy: 0.6208 - f1_score: 0.6066 - val_loss: 0.4977 - val_accuracy: 0.6111 - val_f1_score: 0.4771 - lr: 0.0010
# Epoch 10/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5343 - accuracy: 0.6138 - f1_score: 0.6099
# Epoch 10: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5298 - accuracy: 0.6198 - f1_score: 0.6157 - val_loss: 0.4848 - val_accuracy: 0.5617 - val_f1_score: 0.5127 - lr: 0.0010
# Epoch 11/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5076 - accuracy: 0.6429 - f1_score: 0.6361
# Epoch 11: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5056 - accuracy: 0.6457 - f1_score: 0.6417 - val_loss: 0.4975 - val_accuracy: 0.5833 - val_f1_score: 0.4783 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5197 - accuracy: 0.6375 - f1_score: 0.6323
# Epoch 12: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5195 - accuracy: 0.6347 - f1_score: 0.6261 - val_loss: 0.4852 - val_accuracy: 0.6420 - val_f1_score: 0.4889 - lr: 0.0010
# Epoch 13/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5025 - accuracy: 0.6451 - f1_score: 0.6390
# Epoch 13: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5062 - accuracy: 0.6447 - f1_score: 0.6369 - val_loss: 0.4870 - val_accuracy: 0.5463 - val_f1_score: 0.5103 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5324 - accuracy: 0.6302 - f1_score: 0.6174
# Epoch 14: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5351 - accuracy: 0.6267 - f1_score: 0.6110 - val_loss: 0.5056 - val_accuracy: 0.5926 - val_f1_score: 0.4663 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6202 - accuracy: 0.5958 - f1_score: 0.5541
# Epoch 15: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6175 - accuracy: 0.5938 - f1_score: 0.5529 - val_loss: 0.5560 - val_accuracy: 0.4475 - val_f1_score: 0.4511 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5694 - accuracy: 0.6156 - f1_score: 0.5872
# Epoch 16: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5719 - accuracy: 0.6138 - f1_score: 0.5860 - val_loss: 0.4588 - val_accuracy: 0.7099 - val_f1_score: 0.5129 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5780 - accuracy: 0.6042 - f1_score: 0.5828
# Epoch 17: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5779 - accuracy: 0.6048 - f1_score: 0.5829 - val_loss: 0.5175 - val_accuracy: 0.4938 - val_f1_score: 0.4838 - lr: 0.0010
# Epoch 18/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5377 - accuracy: 0.6272 - f1_score: 0.6131
# Epoch 18: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5420 - accuracy: 0.6248 - f1_score: 0.6089 - val_loss: 0.4920 - val_accuracy: 0.6204 - val_f1_score: 0.4803 - lr: 0.0010
# Epoch 19/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.5133 - accuracy: 0.6322 - f1_score: 0.6273
# Epoch 19: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5113 - accuracy: 0.6387 - f1_score: 0.6348 - val_loss: 0.4918 - val_accuracy: 0.5833 - val_f1_score: 0.4783 - lr: 0.0010
# Epoch 20/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5002 - accuracy: 0.6417 - f1_score: 0.6348
# Epoch 20: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5050 - accuracy: 0.6367 - f1_score: 0.6287 - val_loss: 0.4894 - val_accuracy: 0.6049 - val_f1_score: 0.4852 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5029 - accuracy: 0.6385 - f1_score: 0.6356
# Epoch 21: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5030 - accuracy: 0.6377 - f1_score: 0.6346 - val_loss: 0.4884 - val_accuracy: 0.5864 - val_f1_score: 0.4833 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4954 - accuracy: 0.6469 - f1_score: 0.6428
# Epoch 22: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5033 - accuracy: 0.6447 - f1_score: 0.6397 - val_loss: 0.4792 - val_accuracy: 0.6543 - val_f1_score: 0.4966 - lr: 0.0010
# Epoch 23/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4995 - accuracy: 0.6440 - f1_score: 0.6404
# Epoch 23: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4901 - accuracy: 0.6517 - f1_score: 0.6497 - val_loss: 0.4938 - val_accuracy: 0.5710 - val_f1_score: 0.4591 - lr: 0.0010
# Epoch 24/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5244 - accuracy: 0.6362 - f1_score: 0.6219
# Epoch 24: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5137 - accuracy: 0.6437 - f1_score: 0.6319 - val_loss: 0.4946 - val_accuracy: 0.5710 - val_f1_score: 0.4574 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5019 - accuracy: 0.6469 - f1_score: 0.6421
# Epoch 25: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5052 - accuracy: 0.6447 - f1_score: 0.6391 - val_loss: 0.4562 - val_accuracy: 0.6975 - val_f1_score: 0.5114 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5353 - accuracy: 0.6292 - f1_score: 0.6158
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 26: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5432 - accuracy: 0.6257 - f1_score: 0.6107 - val_loss: 0.5061 - val_accuracy: 0.5679 - val_f1_score: 0.4418 - lr: 0.0010
# Epoch 27/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5182 - accuracy: 0.6328 - f1_score: 0.6249
# Epoch 27: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5115 - accuracy: 0.6387 - f1_score: 0.6304 - val_loss: 0.4766 - val_accuracy: 0.5586 - val_f1_score: 0.5207 - lr: 5.0000e-04
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5148 - accuracy: 0.6427 - f1_score: 0.6312
# Epoch 28: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5131 - accuracy: 0.6427 - f1_score: 0.6319 - val_loss: 0.4921 - val_accuracy: 0.5741 - val_f1_score: 0.4635 - lr: 5.0000e-04
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5117 - accuracy: 0.6344 - f1_score: 0.6245
# Epoch 29: val_f1_score did not improve from 0.52106
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5137 - accuracy: 0.6347 - f1_score: 0.6253 - val_loss: 0.4920 - val_accuracy: 0.6111 - val_f1_score: 0.4809 - lr: 5.0000e-04
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5357 - accuracy: 0.6250 - f1_score: 0.6168
# Epoch 30: val_f1_score improved from 0.52106 to 0.52656, saving model to best_model.hdf5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5348 - accuracy: 0.6257 - f1_score: 0.6167 - val_loss: 0.4541 - val_accuracy: 0.7191 - val_f1_score: 0.5266 - lr: 5.0000e-04
# Epoch 31/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.5465 - accuracy: 0.6274 - f1_score: 0.6068
# Epoch 31: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5543 - accuracy: 0.6218 - f1_score: 0.6015 - val_loss: 0.4792 - val_accuracy: 0.6451 - val_f1_score: 0.4908 - lr: 5.0000e-04
# Epoch 32/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4918 - accuracy: 0.6484 - f1_score: 0.6444
# Epoch 32: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5031 - accuracy: 0.6437 - f1_score: 0.6344 - val_loss: 0.4887 - val_accuracy: 0.6235 - val_f1_score: 0.4882 - lr: 5.0000e-04
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5016 - accuracy: 0.6406 - f1_score: 0.6385
# Epoch 33: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5011 - accuracy: 0.6407 - f1_score: 0.6384 - val_loss: 0.4870 - val_accuracy: 0.6265 - val_f1_score: 0.4840 - lr: 5.0000e-04
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5029 - accuracy: 0.6385 - f1_score: 0.6364
# Epoch 34: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4998 - accuracy: 0.6417 - f1_score: 0.6409 - val_loss: 0.4905 - val_accuracy: 0.6080 - val_f1_score: 0.4797 - lr: 5.0000e-04
# Epoch 35/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4767 - accuracy: 0.6611 - f1_score: 0.6550
# Epoch 35: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4822 - accuracy: 0.6547 - f1_score: 0.6476 - val_loss: 0.4872 - val_accuracy: 0.6296 - val_f1_score: 0.4856 - lr: 5.0000e-04
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4978 - accuracy: 0.6469 - f1_score: 0.6434
# Epoch 36: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4945 - accuracy: 0.6487 - f1_score: 0.6463 - val_loss: 0.4934 - val_accuracy: 0.5988 - val_f1_score: 0.4601 - lr: 5.0000e-04
# Epoch 37/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4858 - accuracy: 0.6462 - f1_score: 0.6431
# Epoch 37: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4912 - accuracy: 0.6487 - f1_score: 0.6444 - val_loss: 0.4865 - val_accuracy: 0.6235 - val_f1_score: 0.4854 - lr: 5.0000e-04
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4868 - accuracy: 0.6469 - f1_score: 0.6452
# Epoch 38: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4860 - accuracy: 0.6487 - f1_score: 0.6471 - val_loss: 0.4908 - val_accuracy: 0.5772 - val_f1_score: 0.4608 - lr: 5.0000e-04
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5088 - accuracy: 0.6438 - f1_score: 0.6348
# Epoch 39: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5146 - accuracy: 0.6407 - f1_score: 0.6298 - val_loss: 0.4599 - val_accuracy: 0.7068 - val_f1_score: 0.5246 - lr: 5.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5213 - accuracy: 0.6387 - f1_score: 0.6252
# Epoch 40: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5213 - accuracy: 0.6387 - f1_score: 0.6252 - val_loss: 0.4857 - val_accuracy: 0.5895 - val_f1_score: 0.4832 - lr: 5.0000e-04
# Epoch 41/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.4747 - accuracy: 0.6580 - f1_score: 0.6541
# Epoch 41: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4898 - accuracy: 0.6487 - f1_score: 0.6427 - val_loss: 0.4733 - val_accuracy: 0.6173 - val_f1_score: 0.4956 - lr: 5.0000e-04
# Epoch 42/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4735 - accuracy: 0.6685 - f1_score: 0.6604
# Epoch 42: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4879 - accuracy: 0.6537 - f1_score: 0.6434 - val_loss: 0.4955 - val_accuracy: 0.5648 - val_f1_score: 0.4556 - lr: 5.0000e-04
# Epoch 43/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.4625 - accuracy: 0.6667 - f1_score: 0.6636
# Epoch 43: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4811 - accuracy: 0.6637 - f1_score: 0.6525 - val_loss: 0.4566 - val_accuracy: 0.6975 - val_f1_score: 0.5112 - lr: 5.0000e-04
# Epoch 44/10000
# 10/16 [=================>............] - ETA: 0s - loss: 0.5408 - accuracy: 0.6266 - f1_score: 0.6193
# Epoch 44: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5034 - accuracy: 0.6467 - f1_score: 0.6418 - val_loss: 0.4850 - val_accuracy: 0.5710 - val_f1_score: 0.4651 - lr: 5.0000e-04
# Epoch 45/10000
#  8/16 [==============>...............] - ETA: 0s - loss: 0.5042 - accuracy: 0.6562 - f1_score: 0.6397
# Epoch 45: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4979 - accuracy: 0.6527 - f1_score: 0.6424 - val_loss: 0.4905 - val_accuracy: 0.5710 - val_f1_score: 0.4581 - lr: 5.0000e-04
# Epoch 46/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4725 - accuracy: 0.6707 - f1_score: 0.6593
# Epoch 46: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5003 - accuracy: 0.6527 - f1_score: 0.6356 - val_loss: 0.4642 - val_accuracy: 0.7160 - val_f1_score: 0.5205 - lr: 5.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.6567 - f1_score: 0.6412
# Epoch 47: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5012 - accuracy: 0.6567 - f1_score: 0.6412 - val_loss: 0.4778 - val_accuracy: 0.5926 - val_f1_score: 0.4897 - lr: 5.0000e-04
# Epoch 48/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4842 - accuracy: 0.6518 - f1_score: 0.6480
# Epoch 48: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4768 - accuracy: 0.6577 - f1_score: 0.6550 - val_loss: 0.4629 - val_accuracy: 0.6605 - val_f1_score: 0.5059 - lr: 5.0000e-04
# Epoch 49/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4621 - accuracy: 0.6695 - f1_score: 0.6629
# Epoch 49: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4756 - accuracy: 0.6677 - f1_score: 0.6543 - val_loss: 0.4990 - val_accuracy: 0.5463 - val_f1_score: 0.5017 - lr: 5.0000e-04
# Epoch 50/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4999 - accuracy: 0.6540 - f1_score: 0.6402
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 50: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4914 - accuracy: 0.6577 - f1_score: 0.6470 - val_loss: 0.4819 - val_accuracy: 0.5864 - val_f1_score: 0.4882 - lr: 5.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4540 - accuracy: 0.6776 - f1_score: 0.6724
# Epoch 51: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4540 - accuracy: 0.6776 - f1_score: 0.6724 - val_loss: 0.4670 - val_accuracy: 0.6451 - val_f1_score: 0.4987 - lr: 2.5000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4620 - accuracy: 0.6802 - f1_score: 0.6753
# Epoch 52: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4577 - accuracy: 0.6796 - f1_score: 0.6740 - val_loss: 0.4790 - val_accuracy: 0.5895 - val_f1_score: 0.4926 - lr: 2.5000e-04
# Epoch 53/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4590 - accuracy: 0.6752 - f1_score: 0.6694
# Epoch 53: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4534 - accuracy: 0.6756 - f1_score: 0.6701 - val_loss: 0.4761 - val_accuracy: 0.5988 - val_f1_score: 0.4906 - lr: 2.5000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4733 - accuracy: 0.6604 - f1_score: 0.6574
# Epoch 54: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4680 - accuracy: 0.6637 - f1_score: 0.6607 - val_loss: 0.4568 - val_accuracy: 0.6728 - val_f1_score: 0.5137 - lr: 2.5000e-04
# Epoch 55/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4515 - accuracy: 0.6775 - f1_score: 0.6744
# Epoch 55: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4506 - accuracy: 0.6776 - f1_score: 0.6704 - val_loss: 0.4718 - val_accuracy: 0.6049 - val_f1_score: 0.5018 - lr: 2.5000e-04
# Epoch 56/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4447 - accuracy: 0.6886 - f1_score: 0.6799
# Epoch 56: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4528 - accuracy: 0.6806 - f1_score: 0.6718 - val_loss: 0.4566 - val_accuracy: 0.6574 - val_f1_score: 0.5113 - lr: 2.5000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4543 - accuracy: 0.6771 - f1_score: 0.6711
# Epoch 57: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4531 - accuracy: 0.6786 - f1_score: 0.6735 - val_loss: 0.4653 - val_accuracy: 0.6173 - val_f1_score: 0.5026 - lr: 2.5000e-04
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4619 - accuracy: 0.6729 - f1_score: 0.6654
# Epoch 58: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4521 - accuracy: 0.6796 - f1_score: 0.6759 - val_loss: 0.4681 - val_accuracy: 0.6358 - val_f1_score: 0.5001 - lr: 2.5000e-04
# Epoch 59/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4502 - accuracy: 0.6775 - f1_score: 0.6731
# Epoch 59: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4523 - accuracy: 0.6776 - f1_score: 0.6729 - val_loss: 0.4642 - val_accuracy: 0.6451 - val_f1_score: 0.5039 - lr: 2.5000e-04
# Epoch 60/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4423 - accuracy: 0.6853 - f1_score: 0.6808
# Epoch 60: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4458 - accuracy: 0.6836 - f1_score: 0.6769 - val_loss: 0.4719 - val_accuracy: 0.6111 - val_f1_score: 0.4969 - lr: 2.5000e-04
# Epoch 61/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4575 - accuracy: 0.6763 - f1_score: 0.6714
# Epoch 61: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4523 - accuracy: 0.6776 - f1_score: 0.6717 - val_loss: 0.4530 - val_accuracy: 0.6852 - val_f1_score: 0.5156 - lr: 2.5000e-04
# Epoch 62/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4386 - accuracy: 0.6886 - f1_score: 0.6827
# Epoch 62: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4370 - accuracy: 0.6896 - f1_score: 0.6850 - val_loss: 0.4793 - val_accuracy: 0.6019 - val_f1_score: 0.4908 - lr: 2.5000e-04
# Epoch 63/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4386 - accuracy: 0.6815 - f1_score: 0.6796
# Epoch 63: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4351 - accuracy: 0.6896 - f1_score: 0.6862 - val_loss: 0.4694 - val_accuracy: 0.6296 - val_f1_score: 0.4937 - lr: 2.5000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4467 - accuracy: 0.6823 - f1_score: 0.6776
# Epoch 64: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4507 - accuracy: 0.6776 - f1_score: 0.6709 - val_loss: 0.4558 - val_accuracy: 0.6759 - val_f1_score: 0.5157 - lr: 2.5000e-04
# Epoch 65/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4598 - accuracy: 0.6750 - f1_score: 0.6680
# Epoch 65: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4574 - accuracy: 0.6776 - f1_score: 0.6719 - val_loss: 0.4668 - val_accuracy: 0.6265 - val_f1_score: 0.5015 - lr: 2.5000e-04
# Epoch 66/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4639 - accuracy: 0.6731 - f1_score: 0.6616
# Epoch 66: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4558 - accuracy: 0.6796 - f1_score: 0.6727 - val_loss: 0.4534 - val_accuracy: 0.6852 - val_f1_score: 0.5146 - lr: 2.5000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4377 - accuracy: 0.6990 - f1_score: 0.6889
# Epoch 67: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4331 - accuracy: 0.6996 - f1_score: 0.6903 - val_loss: 0.4733 - val_accuracy: 0.6019 - val_f1_score: 0.4977 - lr: 2.5000e-04
# Epoch 68/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4463 - accuracy: 0.6853 - f1_score: 0.6791
# Epoch 68: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4434 - accuracy: 0.6866 - f1_score: 0.6785 - val_loss: 0.4740 - val_accuracy: 0.6080 - val_f1_score: 0.4945 - lr: 2.5000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4376 - accuracy: 0.6906 - f1_score: 0.6856
# Epoch 69: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4390 - accuracy: 0.6906 - f1_score: 0.6853 - val_loss: 0.4742 - val_accuracy: 0.6265 - val_f1_score: 0.4947 - lr: 2.5000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4204 - accuracy: 0.6990 - f1_score: 0.6975
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 70: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4160 - accuracy: 0.7016 - f1_score: 0.7009 - val_loss: 0.4623 - val_accuracy: 0.6420 - val_f1_score: 0.5040 - lr: 2.5000e-04
# Epoch 71/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.3717 - accuracy: 0.7326 - f1_score: 0.7298
# Epoch 71: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4236 - accuracy: 0.6986 - f1_score: 0.6950 - val_loss: 0.4443 - val_accuracy: 0.6821 - val_f1_score: 0.5245 - lr: 1.2500e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4330 - accuracy: 0.6938 - f1_score: 0.6904
# Epoch 72: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4275 - accuracy: 0.6966 - f1_score: 0.6947 - val_loss: 0.4617 - val_accuracy: 0.6481 - val_f1_score: 0.5077 - lr: 1.2500e-04
# Epoch 73/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.7026 - f1_score: 0.7020
# Epoch 73: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4146 - accuracy: 0.7026 - f1_score: 0.7020 - val_loss: 0.4518 - val_accuracy: 0.6636 - val_f1_score: 0.5130 - lr: 1.2500e-04
# Epoch 74/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4355 - accuracy: 0.6923 - f1_score: 0.6885
# Epoch 74: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4420 - accuracy: 0.6876 - f1_score: 0.6806 - val_loss: 0.4507 - val_accuracy: 0.6667 - val_f1_score: 0.5174 - lr: 1.2500e-04
# Epoch 75/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4151 - accuracy: 0.7020 - f1_score: 0.6970
# Epoch 75: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4219 - accuracy: 0.7036 - f1_score: 0.6981 - val_loss: 0.4637 - val_accuracy: 0.6420 - val_f1_score: 0.5040 - lr: 1.2500e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4220 - accuracy: 0.7021 - f1_score: 0.6983
# Epoch 76: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4163 - accuracy: 0.7056 - f1_score: 0.7037 - val_loss: 0.4705 - val_accuracy: 0.6327 - val_f1_score: 0.5001 - lr: 1.2500e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4341 - accuracy: 0.6948 - f1_score: 0.6892
# Epoch 77: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4248 - accuracy: 0.7016 - f1_score: 0.6997 - val_loss: 0.4652 - val_accuracy: 0.6389 - val_f1_score: 0.5020 - lr: 1.2500e-04
# Epoch 78/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4227 - accuracy: 0.7065 - f1_score: 0.7022
# Epoch 78: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4167 - accuracy: 0.7076 - f1_score: 0.7027 - val_loss: 0.4553 - val_accuracy: 0.6759 - val_f1_score: 0.5178 - lr: 1.2500e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4193 - accuracy: 0.6990 - f1_score: 0.6951
# Epoch 79: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4137 - accuracy: 0.7036 - f1_score: 0.7021 - val_loss: 0.4671 - val_accuracy: 0.6358 - val_f1_score: 0.5020 - lr: 1.2500e-04
# Epoch 80/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.4160 - accuracy: 0.7031 - f1_score: 0.7005
# Epoch 80: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4081 - accuracy: 0.7106 - f1_score: 0.7071 - val_loss: 0.4544 - val_accuracy: 0.6667 - val_f1_score: 0.5121 - lr: 1.2500e-04
# Epoch 81/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3987 - accuracy: 0.7132 - f1_score: 0.7101
# Epoch 81: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4096 - accuracy: 0.7066 - f1_score: 0.7032 - val_loss: 0.4681 - val_accuracy: 0.6358 - val_f1_score: 0.5020 - lr: 1.2500e-04
# Epoch 82/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4093 - accuracy: 0.7121 - f1_score: 0.7090
# Epoch 82: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4042 - accuracy: 0.7136 - f1_score: 0.7111 - val_loss: 0.4589 - val_accuracy: 0.6481 - val_f1_score: 0.5079 - lr: 1.2500e-04
# Epoch 83/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.7086 - f1_score: 0.7081
# Epoch 83: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4053 - accuracy: 0.7086 - f1_score: 0.7081 - val_loss: 0.4681 - val_accuracy: 0.6358 - val_f1_score: 0.5001 - lr: 1.2500e-04
# Epoch 84/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.7076 - f1_score: 0.7037
# Epoch 84: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4128 - accuracy: 0.7076 - f1_score: 0.7037 - val_loss: 0.4590 - val_accuracy: 0.6574 - val_f1_score: 0.5061 - lr: 1.2500e-04
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.7066 - f1_score: 0.7004
# Epoch 85: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4132 - accuracy: 0.7066 - f1_score: 0.7004 - val_loss: 0.4670 - val_accuracy: 0.6327 - val_f1_score: 0.5019 - lr: 1.2500e-04
# Epoch 86/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4290 - accuracy: 0.6975 - f1_score: 0.6942
# Epoch 86: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4160 - accuracy: 0.7056 - f1_score: 0.7043 - val_loss: 0.4627 - val_accuracy: 0.6451 - val_f1_score: 0.5079 - lr: 1.2500e-04
# Epoch 87/10000
#  8/16 [==============>...............] - ETA: 0s - loss: 0.4205 - accuracy: 0.6953 - f1_score: 0.6926
# Epoch 87: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4039 - accuracy: 0.7106 - f1_score: 0.7101 - val_loss: 0.4637 - val_accuracy: 0.6420 - val_f1_score: 0.5039 - lr: 1.2500e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4036 - accuracy: 0.7104 - f1_score: 0.7088
# Epoch 88: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4087 - accuracy: 0.7086 - f1_score: 0.7057 - val_loss: 0.4486 - val_accuracy: 0.6759 - val_f1_score: 0.5183 - lr: 1.2500e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4203 - accuracy: 0.7010 - f1_score: 0.6979
# Epoch 89: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4187 - accuracy: 0.7006 - f1_score: 0.6965 - val_loss: 0.4648 - val_accuracy: 0.6358 - val_f1_score: 0.5001 - lr: 1.2500e-04
# Epoch 90/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4119 - accuracy: 0.7115 - f1_score: 0.7052
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 90: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4129 - accuracy: 0.7126 - f1_score: 0.7101 - val_loss: 0.4678 - val_accuracy: 0.6296 - val_f1_score: 0.4982 - lr: 1.2500e-04
# Epoch 91/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4065 - accuracy: 0.7121 - f1_score: 0.7095
# Epoch 91: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4054 - accuracy: 0.7126 - f1_score: 0.7082 - val_loss: 0.4690 - val_accuracy: 0.6265 - val_f1_score: 0.4963 - lr: 6.2500e-05
# Epoch 92/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3940 - accuracy: 0.7163 - f1_score: 0.7131
# Epoch 92: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4061 - accuracy: 0.7106 - f1_score: 0.7083 - val_loss: 0.4595 - val_accuracy: 0.6574 - val_f1_score: 0.5141 - lr: 6.2500e-05
# Epoch 93/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4036 - accuracy: 0.7165 - f1_score: 0.7112
# Epoch 93: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4074 - accuracy: 0.7126 - f1_score: 0.7058 - val_loss: 0.4674 - val_accuracy: 0.6327 - val_f1_score: 0.5001 - lr: 6.2500e-05
# Epoch 94/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3963 - accuracy: 0.7175 - f1_score: 0.7146
# Epoch 94: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4010 - accuracy: 0.7136 - f1_score: 0.7104 - val_loss: 0.4645 - val_accuracy: 0.6327 - val_f1_score: 0.5019 - lr: 6.2500e-05
# Epoch 95/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4045 - accuracy: 0.7139 - f1_score: 0.7100
# Epoch 95: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4016 - accuracy: 0.7156 - f1_score: 0.7113 - val_loss: 0.4636 - val_accuracy: 0.6327 - val_f1_score: 0.5019 - lr: 6.2500e-05
# Epoch 96/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4077 - accuracy: 0.7091 - f1_score: 0.7041
# Epoch 96: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4064 - accuracy: 0.7116 - f1_score: 0.7052 - val_loss: 0.4660 - val_accuracy: 0.6481 - val_f1_score: 0.5029 - lr: 6.2500e-05
# Epoch 97/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4071 - accuracy: 0.7076 - f1_score: 0.7025
# Epoch 97: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4071 - accuracy: 0.7086 - f1_score: 0.7047 - val_loss: 0.4657 - val_accuracy: 0.6327 - val_f1_score: 0.5036 - lr: 6.2500e-05
# Epoch 98/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3959 - accuracy: 0.7127 - f1_score: 0.7111
# Epoch 98: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4030 - accuracy: 0.7106 - f1_score: 0.7086 - val_loss: 0.4668 - val_accuracy: 0.6420 - val_f1_score: 0.5011 - lr: 6.2500e-05
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4113 - accuracy: 0.7063 - f1_score: 0.7028
# Epoch 99: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4178 - accuracy: 0.7006 - f1_score: 0.6941 - val_loss: 0.4600 - val_accuracy: 0.6667 - val_f1_score: 0.5062 - lr: 6.2500e-05
# Epoch 100/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4018 - accuracy: 0.7091 - f1_score: 0.7062
# Epoch 100: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4100 - accuracy: 0.7066 - f1_score: 0.7066 - val_loss: 0.4636 - val_accuracy: 0.6481 - val_f1_score: 0.5029 - lr: 6.2500e-05
# Epoch 101/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3883 - accuracy: 0.7212 - f1_score: 0.7186
# Epoch 101: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4044 - accuracy: 0.7136 - f1_score: 0.7095 - val_loss: 0.4630 - val_accuracy: 0.6512 - val_f1_score: 0.5070 - lr: 6.2500e-05
# Epoch 102/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4114 - accuracy: 0.7065 - f1_score: 0.7025
# Epoch 102: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4029 - accuracy: 0.7126 - f1_score: 0.7106 - val_loss: 0.4636 - val_accuracy: 0.6481 - val_f1_score: 0.5051 - lr: 6.2500e-05
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.7056 - f1_score: 0.7003
# Epoch 103: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4132 - accuracy: 0.7056 - f1_score: 0.7003 - val_loss: 0.4588 - val_accuracy: 0.6667 - val_f1_score: 0.5085 - lr: 6.2500e-05
# Epoch 104/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3977 - accuracy: 0.7200 - f1_score: 0.7133
# Epoch 104: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4078 - accuracy: 0.7136 - f1_score: 0.7092 - val_loss: 0.4666 - val_accuracy: 0.6420 - val_f1_score: 0.5028 - lr: 6.2500e-05
# Epoch 105/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4020 - accuracy: 0.7115 - f1_score: 0.7095
# Epoch 105: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4009 - accuracy: 0.7126 - f1_score: 0.7103 - val_loss: 0.4654 - val_accuracy: 0.6358 - val_f1_score: 0.5025 - lr: 6.2500e-05
# Epoch 106/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4001 - accuracy: 0.7175 - f1_score: 0.7146
# Epoch 106: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4045 - accuracy: 0.7136 - f1_score: 0.7078 - val_loss: 0.4678 - val_accuracy: 0.6327 - val_f1_score: 0.4990 - lr: 6.2500e-05
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3981 - accuracy: 0.7146 - f1_score: 0.7114
# Epoch 107: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3990 - accuracy: 0.7136 - f1_score: 0.7101 - val_loss: 0.4670 - val_accuracy: 0.6327 - val_f1_score: 0.4991 - lr: 6.2500e-05
# Epoch 108/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3952 - accuracy: 0.7210 - f1_score: 0.7181
# Epoch 108: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4035 - accuracy: 0.7146 - f1_score: 0.7093 - val_loss: 0.4697 - val_accuracy: 0.6111 - val_f1_score: 0.4970 - lr: 6.2500e-05
# Epoch 109/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4116 - accuracy: 0.7103 - f1_score: 0.7073
# Epoch 109: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4036 - accuracy: 0.7136 - f1_score: 0.7113 - val_loss: 0.4669 - val_accuracy: 0.6265 - val_f1_score: 0.5040 - lr: 6.2500e-05
# Epoch 110/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4095 - accuracy: 0.7091 - f1_score: 0.7073
# Epoch 110: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 110: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3979 - accuracy: 0.7156 - f1_score: 0.7149 - val_loss: 0.4686 - val_accuracy: 0.6358 - val_f1_score: 0.4972 - lr: 6.2500e-05
# Epoch 111/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3891 - accuracy: 0.7175 - f1_score: 0.7151
# Epoch 111: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3998 - accuracy: 0.7126 - f1_score: 0.7107 - val_loss: 0.4684 - val_accuracy: 0.6296 - val_f1_score: 0.4973 - lr: 3.1250e-05
# Epoch 112/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3898 - accuracy: 0.7224 - f1_score: 0.7194
# Epoch 112: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3983 - accuracy: 0.7186 - f1_score: 0.7169 - val_loss: 0.4700 - val_accuracy: 0.6358 - val_f1_score: 0.4991 - lr: 3.1250e-05
# Epoch 113/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3981 - accuracy: 0.7151 - f1_score: 0.7122
# Epoch 113: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3977 - accuracy: 0.7166 - f1_score: 0.7136 - val_loss: 0.4714 - val_accuracy: 0.6358 - val_f1_score: 0.4991 - lr: 3.1250e-05
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4032 - accuracy: 0.7135 - f1_score: 0.7105
# Epoch 114: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3994 - accuracy: 0.7176 - f1_score: 0.7167 - val_loss: 0.4720 - val_accuracy: 0.6327 - val_f1_score: 0.4971 - lr: 3.1250e-05
# Epoch 115/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3898 - accuracy: 0.7243 - f1_score: 0.7215
# Epoch 115: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3991 - accuracy: 0.7166 - f1_score: 0.7129 - val_loss: 0.4734 - val_accuracy: 0.6296 - val_f1_score: 0.4952 - lr: 3.1250e-05
# Epoch 116/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4063 - accuracy: 0.7087 - f1_score: 0.7066
# Epoch 116: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4037 - accuracy: 0.7116 - f1_score: 0.7106 - val_loss: 0.4660 - val_accuracy: 0.6389 - val_f1_score: 0.5062 - lr: 3.1250e-05
# Epoch 117/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3975 - accuracy: 0.7165 - f1_score: 0.7137
# Epoch 117: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3974 - accuracy: 0.7176 - f1_score: 0.7144 - val_loss: 0.4688 - val_accuracy: 0.6451 - val_f1_score: 0.5030 - lr: 3.1250e-05
# Epoch 118/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3837 - accuracy: 0.7248 - f1_score: 0.7209
# Epoch 118: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4010 - accuracy: 0.7166 - f1_score: 0.7107 - val_loss: 0.4728 - val_accuracy: 0.6296 - val_f1_score: 0.4952 - lr: 3.1250e-05
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4008 - accuracy: 0.7167 - f1_score: 0.7161
# Epoch 119: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3957 - accuracy: 0.7196 - f1_score: 0.7190 - val_loss: 0.4699 - val_accuracy: 0.6358 - val_f1_score: 0.4989 - lr: 3.1250e-05
# Epoch 120/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3921 - accuracy: 0.7243 - f1_score: 0.7205
# Epoch 120: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3974 - accuracy: 0.7176 - f1_score: 0.7129 - val_loss: 0.4701 - val_accuracy: 0.6327 - val_f1_score: 0.4970 - lr: 3.1250e-05
# Epoch 121/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4076 - accuracy: 0.7139 - f1_score: 0.7113
# Epoch 121: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3979 - accuracy: 0.7176 - f1_score: 0.7140 - val_loss: 0.4691 - val_accuracy: 0.6327 - val_f1_score: 0.4990 - lr: 3.1250e-05
# Epoch 122/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3948 - accuracy: 0.7210 - f1_score: 0.7137
# Epoch 122: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3988 - accuracy: 0.7186 - f1_score: 0.7095 - val_loss: 0.4696 - val_accuracy: 0.6327 - val_f1_score: 0.4970 - lr: 3.1250e-05
# Epoch 123/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3993 - accuracy: 0.7175 - f1_score: 0.7143
# Epoch 123: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3952 - accuracy: 0.7216 - f1_score: 0.7179 - val_loss: 0.4723 - val_accuracy: 0.6296 - val_f1_score: 0.4952 - lr: 3.1250e-05
# Epoch 124/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3906 - accuracy: 0.7188 - f1_score: 0.7166
# Epoch 124: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3917 - accuracy: 0.7196 - f1_score: 0.7172 - val_loss: 0.4715 - val_accuracy: 0.6327 - val_f1_score: 0.4971 - lr: 3.1250e-05
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3994 - accuracy: 0.7167 - f1_score: 0.7131
# Epoch 125: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3964 - accuracy: 0.7186 - f1_score: 0.7160 - val_loss: 0.4679 - val_accuracy: 0.6358 - val_f1_score: 0.4989 - lr: 3.1250e-05
# Epoch 126/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.3881 - accuracy: 0.7240 - f1_score: 0.7210
# Epoch 126: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3995 - accuracy: 0.7166 - f1_score: 0.7125 - val_loss: 0.4628 - val_accuracy: 0.6543 - val_f1_score: 0.5052 - lr: 3.1250e-05
# Epoch 127/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3982 - accuracy: 0.7143 - f1_score: 0.7108
# Epoch 127: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3962 - accuracy: 0.7166 - f1_score: 0.7139 - val_loss: 0.4657 - val_accuracy: 0.6327 - val_f1_score: 0.5026 - lr: 3.1250e-05
# Epoch 128/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.7116 - f1_score: 0.7071
# Epoch 128: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4032 - accuracy: 0.7116 - f1_score: 0.7071 - val_loss: 0.4649 - val_accuracy: 0.6358 - val_f1_score: 0.5044 - lr: 3.1250e-05
# Epoch 129/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.4023 - accuracy: 0.7122 - f1_score: 0.7074
# Epoch 129: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4015 - accuracy: 0.7156 - f1_score: 0.7134 - val_loss: 0.4633 - val_accuracy: 0.6451 - val_f1_score: 0.5050 - lr: 3.1250e-05
# Epoch 130/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.3637 - accuracy: 0.7413 - f1_score: 0.7361Restoring model weights from the end of the best epoch: 30.
#
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 130: val_f1_score did not improve from 0.52656
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3995 - accuracy: 0.7136 - f1_score: 0.7105 - val_loss: 0.4633 - val_accuracy: 0.6451 - val_f1_score: 0.5050 - lr: 3.1250e-05
# Epoch 130: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
# check_model=resnet50
# check_model.load_weights('best_model.h5')
# check_model.summary()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 3ms/step
# 0.7191358024691358

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7191358024691358
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.42      0.20      0.27        85
#            0       0.76      0.90      0.83       239
#
#     accuracy                           0.72       324
#    macro avg       0.59      0.55      0.55       324
# weighted avg       0.67      0.72      0.68       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 233 chiếm khoảng 71.91358024691358% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 17 chiếm khoảng 20.0% so với thực tế
