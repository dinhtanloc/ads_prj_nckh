# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Dense, LSTM, BatchNormalization, Dropout
from scikeras.wrappers import KerasClassifier 


def build_model(unit):
    model = Sequential()

    model.add(LSTM(units=unit, input_shape=(42,1), activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])


    return model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# Wrap Keras model so it can be used by scikit-learn
model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Define the grid of hyperparameters to search
param_grid = {
    'model__unit': [32, 64, 96,128,184,256,384,512],
 
}

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)

# # Load your data here
# # X_train, y_train = ...
# # X_val, y_val = ...

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %%
model = build_model(64)
lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)


lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 17026 (66.51 KB)
# Trainable params: 17026 (66.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 1s 28ms/step - loss: 0.8254 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 1.0669 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.7789 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 1.0728 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7687 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 1.1325 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7633 - accuracy: 0.5000 - f1_score: 0.5020 - val_loss: 1.1618 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.7560 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 0.9492 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7245 - accuracy: 0.5070 - f1_score: 0.5079 - val_loss: 1.1192 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7116 - accuracy: 0.5180 - f1_score: 0.5166 - val_loss: 1.2002 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7473 - accuracy: 0.5000 - f1_score: 0.5010 - val_loss: 1.0439 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7383 - accuracy: 0.5000 - f1_score: 0.5026 - val_loss: 1.1167 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7115 - accuracy: 0.5000 - f1_score: 0.5005 - val_loss: 0.9387 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6674 - accuracy: 0.5709 - f1_score: 0.5729 - val_loss: 0.9802 - val_accuracy: 0.3395 - val_f1_score: 0.3255 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6397 - accuracy: 0.5729 - f1_score: 0.5769 - val_loss: 0.8449 - val_accuracy: 0.5278 - val_f1_score: 0.5234 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6334 - accuracy: 0.5998 - f1_score: 0.5982 - val_loss: 0.9205 - val_accuracy: 0.4691 - val_f1_score: 0.4349 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6320 - accuracy: 0.6028 - f1_score: 0.6047 - val_loss: 0.9617 - val_accuracy: 0.4537 - val_f1_score: 0.4219 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6427 - accuracy: 0.6058 - f1_score: 0.6097 - val_loss: 0.8217 - val_accuracy: 0.4506 - val_f1_score: 0.4583 - lr: 0.0010
# Epoch 16/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6427 - accuracy: 0.5978 - f1_score: 0.5983 - val_loss: 0.8877 - val_accuracy: 0.4846 - val_f1_score: 0.4479 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6176 - accuracy: 0.6218 - f1_score: 0.6202 - val_loss: 1.2025 - val_accuracy: 0.2840 - val_f1_score: 0.2786 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6265 - accuracy: 0.6128 - f1_score: 0.6104 - val_loss: 1.2341 - val_accuracy: 0.3426 - val_f1_score: 0.3281 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6095 - accuracy: 0.6387 - f1_score: 0.6419 - val_loss: 0.8669 - val_accuracy: 0.5278 - val_f1_score: 0.5625 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6058 - accuracy: 0.6737 - f1_score: 0.6735 - val_loss: 0.9828 - val_accuracy: 0.4105 - val_f1_score: 0.3854 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - 0s 16ms/step - loss: 0.5999 - accuracy: 0.6517 - f1_score: 0.6530 - val_loss: 0.8748 - val_accuracy: 0.5154 - val_f1_score: 0.5521 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6052 - accuracy: 0.6487 - f1_score: 0.6491 - val_loss: 1.1365 - val_accuracy: 0.3796 - val_f1_score: 0.3594 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5934 - accuracy: 0.6507 - f1_score: 0.6526 - val_loss: 0.9717 - val_accuracy: 0.5031 - val_f1_score: 0.5417 - lr: 0.0010
# Epoch 24/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5914 - accuracy: 0.6637 - f1_score: 0.6612 - val_loss: 1.0306 - val_accuracy: 0.4444 - val_f1_score: 0.4531 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6015 - accuracy: 0.6547 - f1_score: 0.6565 - val_loss: 0.8421 - val_accuracy: 0.4877 - val_f1_score: 0.5286 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6043 - accuracy: 0.6647 - f1_score: 0.6622 - val_loss: 0.9141 - val_accuracy: 0.4475 - val_f1_score: 0.4557 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6481 - accuracy: 0.5908 - f1_score: 0.5904 - val_loss: 1.0198 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.7427 - accuracy: 0.5000 - f1_score: 0.5015 - val_loss: 1.0357 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.7304 - accuracy: 0.5000 - f1_score: 0.5031 - val_loss: 1.1242 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.7092 - accuracy: 0.5000 - f1_score: 0.4995 - val_loss: 1.0269 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6724 - accuracy: 0.5050 - f1_score: 0.5044 - val_loss: 0.9826 - val_accuracy: 0.2963 - val_f1_score: 0.2891 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6222 - accuracy: 0.6178 - f1_score: 0.6188
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6222 - accuracy: 0.6178 - f1_score: 0.6188 - val_loss: 0.7752 - val_accuracy: 0.5278 - val_f1_score: 0.5625 - lr: 0.0010
# Epoch 33/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6103 - accuracy: 0.6377 - f1_score: 0.6404 - val_loss: 0.8172 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 5.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5978 - accuracy: 0.6527 - f1_score: 0.6525 - val_loss: 0.8451 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 5.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5917 - accuracy: 0.6567 - f1_score: 0.6569 - val_loss: 0.9291 - val_accuracy: 0.4938 - val_f1_score: 0.5339 - lr: 5.0000e-04
# Epoch 36/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5909 - accuracy: 0.6687 - f1_score: 0.6686 - val_loss: 0.9694 - val_accuracy: 0.4877 - val_f1_score: 0.5286 - lr: 5.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5805 - accuracy: 0.6727 - f1_score: 0.6710 - val_loss: 0.8872 - val_accuracy: 0.4938 - val_f1_score: 0.5339 - lr: 5.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5795 - accuracy: 0.6786 - f1_score: 0.6779 - val_loss: 0.8338 - val_accuracy: 0.5556 - val_f1_score: 0.5859 - lr: 5.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5830 - accuracy: 0.6717 - f1_score: 0.6731 - val_loss: 0.7052 - val_accuracy: 0.6265 - val_f1_score: 0.6849 - lr: 5.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5974 - accuracy: 0.6517 - f1_score: 0.6505 - val_loss: 0.8781 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 5.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - 0s 16ms/step - loss: 0.5729 - accuracy: 0.6876 - f1_score: 0.6872 - val_loss: 0.8738 - val_accuracy: 0.5525 - val_f1_score: 0.5833 - lr: 5.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5731 - accuracy: 0.6876 - f1_score: 0.6826 - val_loss: 1.0018 - val_accuracy: 0.4660 - val_f1_score: 0.5104 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5774 - accuracy: 0.6747 - f1_score: 0.6714 - val_loss: 1.1013 - val_accuracy: 0.4012 - val_f1_score: 0.4557 - lr: 5.0000e-04
# Epoch 44/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5700 - accuracy: 0.6886 - f1_score: 0.6912 - val_loss: 0.9685 - val_accuracy: 0.5216 - val_f1_score: 0.5573 - lr: 5.0000e-04
# Epoch 45/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5684 - accuracy: 0.6856 - f1_score: 0.6873 - val_loss: 0.9116 - val_accuracy: 0.4969 - val_f1_score: 0.5365 - lr: 5.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5533 - accuracy: 0.6986 - f1_score: 0.6989 - val_loss: 0.8918 - val_accuracy: 0.5463 - val_f1_score: 0.5781 - lr: 5.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5472 - accuracy: 0.7046 - f1_score: 0.7038 - val_loss: 0.8441 - val_accuracy: 0.5370 - val_f1_score: 0.5703 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5423 - accuracy: 0.7096 - f1_score: 0.7071 - val_loss: 0.8339 - val_accuracy: 0.5617 - val_f1_score: 0.5911 - lr: 5.0000e-04
# Epoch 49/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5363 - accuracy: 0.7126 - f1_score: 0.7147 - val_loss: 0.8650 - val_accuracy: 0.5340 - val_f1_score: 0.5677 - lr: 5.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5287 - accuracy: 0.7086 - f1_score: 0.7092 - val_loss: 0.8835 - val_accuracy: 0.5494 - val_f1_score: 0.5807 - lr: 5.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5274 - accuracy: 0.7206 - f1_score: 0.7174 - val_loss: 0.9121 - val_accuracy: 0.4907 - val_f1_score: 0.5312 - lr: 5.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5253 - accuracy: 0.7066 - f1_score: 0.7052 - val_loss: 0.9636 - val_accuracy: 0.5216 - val_f1_score: 0.5573 - lr: 5.0000e-04
# Epoch 53/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5542 - accuracy: 0.6657 - f1_score: 0.6652 - val_loss: 0.9055 - val_accuracy: 0.3889 - val_f1_score: 0.4453 - lr: 5.0000e-04
# Epoch 54/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5636 - accuracy: 0.6667 - f1_score: 0.6662 - val_loss: 0.8333 - val_accuracy: 0.5648 - val_f1_score: 0.5937 - lr: 5.0000e-04
# Epoch 55/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5386 - accuracy: 0.6966 - f1_score: 0.6985 - val_loss: 0.7192 - val_accuracy: 0.6358 - val_f1_score: 0.6927 - lr: 5.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5302 - accuracy: 0.7265 - f1_score: 0.7273 - val_loss: 0.8246 - val_accuracy: 0.5772 - val_f1_score: 0.6432 - lr: 5.0000e-04
# Epoch 57/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5250 - accuracy: 0.7156 - f1_score: 0.7166 - val_loss: 0.9226 - val_accuracy: 0.5093 - val_f1_score: 0.5469 - lr: 5.0000e-04
# Epoch 58/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5256 - accuracy: 0.7265 - f1_score: 0.7268 - val_loss: 0.9697 - val_accuracy: 0.4599 - val_f1_score: 0.5052 - lr: 5.0000e-04
# Epoch 59/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5099 - accuracy: 0.7066 - f1_score: 0.7037 - val_loss: 0.8336 - val_accuracy: 0.6019 - val_f1_score: 0.6641 - lr: 5.0000e-04
# Epoch 60/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5090 - accuracy: 0.7255 - f1_score: 0.7284 - val_loss: 0.8862 - val_accuracy: 0.5309 - val_f1_score: 0.5651 - lr: 5.0000e-04
# Epoch 61/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5001 - accuracy: 0.7325 - f1_score: 0.7316 - val_loss: 1.0080 - val_accuracy: 0.4753 - val_f1_score: 0.5182 - lr: 5.0000e-04
# Epoch 62/10000
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4981 - accuracy: 0.7315 - f1_score: 0.7337 - val_loss: 0.9147 - val_accuracy: 0.5401 - val_f1_score: 0.5729 - lr: 5.0000e-04
# Epoch 63/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5039 - accuracy: 0.7315 - f1_score: 0.7327 - val_loss: 0.8761 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 5.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5093 - accuracy: 0.7335 - f1_score: 0.7341 - val_loss: 0.9724 - val_accuracy: 0.4691 - val_f1_score: 0.5130 - lr: 5.0000e-04
# Epoch 65/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5014 - accuracy: 0.7315 - f1_score: 0.7307 - val_loss: 0.9508 - val_accuracy: 0.5123 - val_f1_score: 0.5495 - lr: 5.0000e-04
# Epoch 66/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4959 - accuracy: 0.7186 - f1_score: 0.7169 - val_loss: 0.9690 - val_accuracy: 0.4877 - val_f1_score: 0.5286 - lr: 5.0000e-04
# Epoch 67/10000
# 16/16 [==============================] - 0s 18ms/step - loss: 0.5344 - accuracy: 0.6966 - f1_score: 0.6944 - val_loss: 0.8295 - val_accuracy: 0.5000 - val_f1_score: 0.5391 - lr: 5.0000e-04
# Epoch 68/10000
# 16/16 [==============================] - 0s 17ms/step - loss: 0.5159 - accuracy: 0.7395 - f1_score: 0.7400 - val_loss: 0.8884 - val_accuracy: 0.6142 - val_f1_score: 0.6745 - lr: 5.0000e-04
# Epoch 69/10000
# 16/16 [==============================] - 0s 17ms/step - loss: 0.5126 - accuracy: 0.7315 - f1_score: 0.7301 - val_loss: 0.7719 - val_accuracy: 0.5741 - val_f1_score: 0.6016 - lr: 5.0000e-04
# Epoch 70/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5036 - accuracy: 0.7216 - f1_score: 0.7219 - val_loss: 0.8822 - val_accuracy: 0.5556 - val_f1_score: 0.5859 - lr: 5.0000e-04
# Epoch 71/10000
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4883 - accuracy: 0.7395 - f1_score: 0.7420 - val_loss: 0.9485 - val_accuracy: 0.5864 - val_f1_score: 0.6510 - lr: 5.0000e-04
# Epoch 72/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6404 - accuracy: 0.5928 - f1_score: 0.5918 - val_loss: 0.8983 - val_accuracy: 0.3056 - val_f1_score: 0.3750 - lr: 5.0000e-04
# Epoch 73/10000
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6991 - accuracy: 0.5259 - f1_score: 0.5239 - val_loss: 1.0604 - val_accuracy: 0.2623 - val_f1_score: 0.2604 - lr: 5.0000e-04
# Epoch 74/10000
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6750 - accuracy: 0.5130 - f1_score: 0.5122 - val_loss: 0.9759 - val_accuracy: 0.2963 - val_f1_score: 0.3672 - lr: 5.0000e-04
# Epoch 75/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6407 - accuracy: 0.5661 - f1_score: 0.5661
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6417 - accuracy: 0.5639 - f1_score: 0.5625 - val_loss: 0.9992 - val_accuracy: 0.3457 - val_f1_score: 0.4089 - lr: 5.0000e-04
# Epoch 76/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6105 - accuracy: 0.5948 - f1_score: 0.5974 - val_loss: 0.9371 - val_accuracy: 0.3889 - val_f1_score: 0.4453 - lr: 2.5000e-04
# Epoch 77/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5888 - accuracy: 0.6287 - f1_score: 0.6255 - val_loss: 0.9491 - val_accuracy: 0.4074 - val_f1_score: 0.4609 - lr: 2.5000e-04
# Epoch 78/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5712 - accuracy: 0.6687 - f1_score: 0.6666 - val_loss: 0.8818 - val_accuracy: 0.4753 - val_f1_score: 0.5182 - lr: 2.5000e-04
# Epoch 79/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5530 - accuracy: 0.6896 - f1_score: 0.6896 - val_loss: 0.9156 - val_accuracy: 0.5154 - val_f1_score: 0.5521 - lr: 2.5000e-04
# Epoch 80/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5425 - accuracy: 0.6946 - f1_score: 0.6940 - val_loss: 0.8513 - val_accuracy: 0.5432 - val_f1_score: 0.5755 - lr: 2.5000e-04
# Epoch 81/10000
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5278 - accuracy: 0.7166 - f1_score: 0.7175 - val_loss: 0.8766 - val_accuracy: 0.5525 - val_f1_score: 0.5833 - lr: 2.5000e-04
# Epoch 82/10000
# 16/16 [==============================] - 0s 16ms/step - loss: 0.5210 - accuracy: 0.7265 - f1_score: 0.7258 - val_loss: 0.9543 - val_accuracy: 0.5154 - val_f1_score: 0.5521 - lr: 2.5000e-04
# Epoch 83/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5141 - accuracy: 0.7196 - f1_score: 0.7164 - val_loss: 0.8528 - val_accuracy: 0.5895 - val_f1_score: 0.6146 - lr: 2.5000e-04
# Epoch 84/10000
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5156 - accuracy: 0.7196 - f1_score: 0.7189 - val_loss: 0.8120 - val_accuracy: 0.5895 - val_f1_score: 0.6146 - lr: 2.5000e-04
# Epoch 85/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.5047 - accuracy: 0.7186 - f1_score: 0.7185Restoring model weights from the end of the best epoch: 55.
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5047 - accuracy: 0.7186 - f1_score: 0.7185 - val_loss: 0.8558 - val_accuracy: 0.5648 - val_f1_score: 0.5937 - lr: 2.5000e-04
# Epoch 85: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.6358024691358025

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6358024691358025
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.37      0.53      0.43        85
#            0       0.80      0.67      0.73       239
#
#     accuracy                           0.64       324
#    macro avg       0.58      0.60      0.58       324
# weighted avg       0.69      0.64      0.65       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 206 chiếm khoảng 63.580246913580254% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 45 chiếm khoảng 52.94117647058824% so với thực tế
