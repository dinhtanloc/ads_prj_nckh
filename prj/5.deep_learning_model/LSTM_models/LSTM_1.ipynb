# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Dense, LSTM, BatchNormalization, Dropout

def build_model():
    model = Sequential()

    model.add(LSTM(units=64, input_shape=(42,1), activation='relu'))

    # Add BatchNormalization
    model.add(BatchNormalization())

    # Add Dropout
    model.add(Dropout(0.5))
    model.add(Dense(units=96,
                           activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(units=128,
                           activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(units=256,
                           activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(units=256,
                           activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(units=512,
                           activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))


    model.add(Dense(2, activation='softmax'))

    return model


model = build_model()
lr=0.0001
# model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=lr), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)
checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)


lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)


model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 96)                6240
#
#  batch_normalization_1 (Bat  (None, 96)                384
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 96)                0
#
#  dense_1 (Dense)             (None, 128)               12416
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 272226 (1.04 MB)
# Trainable params: 269602 (1.03 MB)
# Non-trainable params: 2624 (10.25 KB)
# _________________________________________________________________

# %%
model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[checkpointer,lr_scheduler])
# Out:
# Epoch 1/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.3278 - accuracy: 0.5139 - f1_score: 0.5139
# Epoch 1: val_loss improved from inf to 0.61116, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 3s 59ms/step - loss: 1.3140 - accuracy: 0.5244 - f1_score: 0.5355 - val_loss: 0.6112 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 2/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.1011 - accuracy: 0.5642 - f1_score: 0.5642
# Epoch 2: val_loss improved from 0.61116 to 0.58216, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 0s 23ms/step - loss: 1.1090 - accuracy: 0.5640 - f1_score: 0.5682 - val_loss: 0.5822 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 3/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.0361 - accuracy: 0.5747 - f1_score: 0.5747
# Epoch 3: val_loss improved from 0.58216 to 0.57540, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 0s 23ms/step - loss: 1.0365 - accuracy: 0.5655 - f1_score: 0.5611 - val_loss: 0.5754 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 4/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.9451 - accuracy: 0.6198 - f1_score: 0.6198
# Epoch 4: val_loss did not improve from 0.57540
# 11/11 [==============================] - 0s 19ms/step - loss: 0.9337 - accuracy: 0.6174 - f1_score: 0.6094 - val_loss: 0.5762 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 5/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 1.0174 - accuracy: 0.6076 - f1_score: 0.6076
# Epoch 5: val_loss improved from 0.57540 to 0.57428, saving model to Emotion_weights.hdf5
# 11/11 [==============================] - 0s 26ms/step - loss: 1.0211 - accuracy: 0.6052 - f1_score: 0.5937 - val_loss: 0.5743 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 6/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.8773 - accuracy: 0.6354 - f1_score: 0.6354
# Epoch 6: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.8672 - accuracy: 0.6372 - f1_score: 0.6321 - val_loss: 0.5774 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 7/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7695 - accuracy: 0.6528 - f1_score: 0.6528
# Epoch 7: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7789 - accuracy: 0.6494 - f1_score: 0.6477 - val_loss: 0.5959 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 8/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7723 - accuracy: 0.6701 - f1_score: 0.6701
# Epoch 8: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7416 - accuracy: 0.6738 - f1_score: 0.6619 - val_loss: 0.6209 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 9/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7976 - accuracy: 0.6545 - f1_score: 0.6545
# Epoch 9: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.8112 - accuracy: 0.6555 - f1_score: 0.6577 - val_loss: 0.5850 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 10/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7462 - accuracy: 0.6997 - f1_score: 0.6997
# Epoch 10: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.7622 - accuracy: 0.6921 - f1_score: 0.6747 - val_loss: 0.5901 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 11/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7945 - accuracy: 0.6753 - f1_score: 0.6753
# Epoch 11: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 24ms/step - loss: 0.7936 - accuracy: 0.6799 - f1_score: 0.6761 - val_loss: 0.6087 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 12/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7435 - accuracy: 0.6840 - f1_score: 0.6840
# Epoch 12: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7530 - accuracy: 0.6768 - f1_score: 0.6903 - val_loss: 0.5934 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 13/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6804 - accuracy: 0.7083 - f1_score: 0.7083
# Epoch 13: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6993 - accuracy: 0.7012 - f1_score: 0.6918 - val_loss: 0.5807 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 14/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7633 - accuracy: 0.6823 - f1_score: 0.6823
# Epoch 14: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.7818 - accuracy: 0.6768 - f1_score: 0.6776 - val_loss: 0.5813 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 15/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.7914 - accuracy: 0.6289 - f1_score: 0.6289
# Epoch 15: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.7971 - accuracy: 0.6433 - f1_score: 0.6463 - val_loss: 0.5770 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 16/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7308 - accuracy: 0.6788 - f1_score: 0.6788
# Epoch 16: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.7197 - accuracy: 0.6814 - f1_score: 0.6903 - val_loss: 0.5758 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 17/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6684 - accuracy: 0.7014 - f1_score: 0.7014
# Epoch 17: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6853 - accuracy: 0.6966 - f1_score: 0.7088 - val_loss: 0.5838 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 18/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7021 - accuracy: 0.6979 - f1_score: 0.6979
# Epoch 18: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7074 - accuracy: 0.6982 - f1_score: 0.6974 - val_loss: 0.5932 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 19/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7487 - accuracy: 0.6858 - f1_score: 0.6858
# Epoch 19: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7263 - accuracy: 0.6936 - f1_score: 0.7060 - val_loss: 0.5928 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 20/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7034 - accuracy: 0.6823 - f1_score: 0.6823
# Epoch 20: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6857 - accuracy: 0.6905 - f1_score: 0.6903 - val_loss: 0.5839 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 21/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.7067 - accuracy: 0.6736 - f1_score: 0.6736
# Epoch 21: val_loss did not improve from 0.57428
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6891 - accuracy: 0.6799 - f1_score: 0.6804 - val_loss: 0.5850 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 0.0010
# Epoch 22/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6526 - accuracy: 0.6858 - f1_score: 0.6858
# Epoch 22: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6613 - accuracy: 0.6829 - f1_score: 0.6747 - val_loss: 0.5976 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 23/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6423 - accuracy: 0.7188 - f1_score: 0.7187
# Epoch 23: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6577 - accuracy: 0.7104 - f1_score: 0.7003 - val_loss: 0.6000 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 24/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6681 - accuracy: 0.6892 - f1_score: 0.6892
# Epoch 24: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6728 - accuracy: 0.6905 - f1_score: 0.6903 - val_loss: 0.6025 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 25/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6620 - accuracy: 0.6992 - f1_score: 0.6992
# Epoch 25: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6699 - accuracy: 0.7058 - f1_score: 0.7088 - val_loss: 0.5985 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 26/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6719 - accuracy: 0.7094 - f1_score: 0.7094
# Epoch 26: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.6678 - accuracy: 0.7134 - f1_score: 0.7244 - val_loss: 0.6047 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 27/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6166 - accuracy: 0.7188 - f1_score: 0.7187
# Epoch 27: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6223 - accuracy: 0.7165 - f1_score: 0.7187 - val_loss: 0.6260 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 28/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6555 - accuracy: 0.7153 - f1_score: 0.7153
# Epoch 28: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6442 - accuracy: 0.7226 - f1_score: 0.7202 - val_loss: 0.6281 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 29/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6272 - accuracy: 0.7240 - f1_score: 0.7240
# Epoch 29: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6458 - accuracy: 0.7180 - f1_score: 0.7116 - val_loss: 0.6127 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 30/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5971 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 30: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6055 - accuracy: 0.7317 - f1_score: 0.7244 - val_loss: 0.5926 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 31/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6090 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 31: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6037 - accuracy: 0.7393 - f1_score: 0.7443 - val_loss: 0.5892 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 32/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6256 - accuracy: 0.7227 - f1_score: 0.7227
# Epoch 32: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.6201 - accuracy: 0.7271 - f1_score: 0.7287 - val_loss: 0.5851 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 33/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6575 - accuracy: 0.7240 - f1_score: 0.7240
# Epoch 33: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6557 - accuracy: 0.7195 - f1_score: 0.7301 - val_loss: 0.5936 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 34/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6188 - accuracy: 0.7378 - f1_score: 0.7378
# Epoch 34: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.6183 - accuracy: 0.7348 - f1_score: 0.7273 - val_loss: 0.6050 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 35/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6060 - accuracy: 0.7207 - f1_score: 0.7207
# Epoch 35: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5969 - accuracy: 0.7210 - f1_score: 0.7273 - val_loss: 0.5933 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 36/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.7241 - f1_score: 0.7301
# Epoch 36: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.6182 - accuracy: 0.7241 - f1_score: 0.7301 - val_loss: 0.5908 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 37/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5873 - accuracy: 0.7422 - f1_score: 0.7422
# Epoch 37: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5868 - accuracy: 0.7424 - f1_score: 0.7429 - val_loss: 0.5839 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 38/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5986 - accuracy: 0.7309 - f1_score: 0.7309
# Epoch 38: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 32ms/step - loss: 0.5954 - accuracy: 0.7332 - f1_score: 0.7344 - val_loss: 0.5857 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 39/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6099 - accuracy: 0.7297 - f1_score: 0.7297
# Epoch 39: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6131 - accuracy: 0.7256 - f1_score: 0.7145 - val_loss: 0.5891 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 40/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5953 - accuracy: 0.7257 - f1_score: 0.7257
# Epoch 40: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.6036 - accuracy: 0.7165 - f1_score: 0.7145 - val_loss: 0.5851 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 41/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5820 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 41: val_loss did not improve from 0.57428
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5800 - accuracy: 0.7348 - f1_score: 0.7358 - val_loss: 0.5834 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 5.0000e-04
# Epoch 42/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6015 - accuracy: 0.7287 - f1_score: 0.7216
# Epoch 42: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.6015 - accuracy: 0.7287 - f1_score: 0.7216 - val_loss: 0.5805 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 43/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6082 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 43: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.6122 - accuracy: 0.7287 - f1_score: 0.7131 - val_loss: 0.5823 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 44/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6022 - accuracy: 0.7234 - f1_score: 0.7234
# Epoch 44: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.6062 - accuracy: 0.7210 - f1_score: 0.7145 - val_loss: 0.5807 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 45/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5938 - accuracy: 0.7297 - f1_score: 0.7297
# Epoch 45: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5987 - accuracy: 0.7287 - f1_score: 0.7259 - val_loss: 0.5786 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 46/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.7302 - f1_score: 0.7230
# Epoch 46: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.6183 - accuracy: 0.7302 - f1_score: 0.7230 - val_loss: 0.5783 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 47/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5763 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 47: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5741 - accuracy: 0.7500 - f1_score: 0.7500 - val_loss: 0.5759 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 48/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6024 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 48: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.6024 - accuracy: 0.7302 - f1_score: 0.7401 - val_loss: 0.5763 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 49/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6227 - accuracy: 0.7101 - f1_score: 0.7101
# Epoch 49: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.6175 - accuracy: 0.7226 - f1_score: 0.7244 - val_loss: 0.5796 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 50/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6119 - accuracy: 0.7328 - f1_score: 0.7328
# Epoch 50: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.6129 - accuracy: 0.7332 - f1_score: 0.7344 - val_loss: 0.5877 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 51/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5851 - accuracy: 0.7409 - f1_score: 0.7415
# Epoch 51: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5851 - accuracy: 0.7409 - f1_score: 0.7415 - val_loss: 0.5895 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 52/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5918 - accuracy: 0.7188 - f1_score: 0.7187
# Epoch 52: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5776 - accuracy: 0.7271 - f1_score: 0.7244 - val_loss: 0.5878 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 53/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6130 - accuracy: 0.7297 - f1_score: 0.7297
# Epoch 53: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.6112 - accuracy: 0.7302 - f1_score: 0.7315 - val_loss: 0.5845 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 54/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5972 - accuracy: 0.7302 - f1_score: 0.7443
# Epoch 54: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.5972 - accuracy: 0.7302 - f1_score: 0.7443 - val_loss: 0.5817 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 55/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5808 - accuracy: 0.7326 - f1_score: 0.7326
# Epoch 55: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5738 - accuracy: 0.7378 - f1_score: 0.7344 - val_loss: 0.5768 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 56/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6063 - accuracy: 0.7246 - f1_score: 0.7246
# Epoch 56: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6057 - accuracy: 0.7241 - f1_score: 0.7216 - val_loss: 0.5755 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 57/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6109 - accuracy: 0.7324 - f1_score: 0.7324
# Epoch 57: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5999 - accuracy: 0.7409 - f1_score: 0.7415 - val_loss: 0.5794 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 58/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5884 - accuracy: 0.7359 - f1_score: 0.7359
# Epoch 58: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5859 - accuracy: 0.7393 - f1_score: 0.7486 - val_loss: 0.5811 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 59/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5822 - accuracy: 0.7396 - f1_score: 0.7396
# Epoch 59: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5850 - accuracy: 0.7393 - f1_score: 0.7443 - val_loss: 0.5783 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 60/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5796 - accuracy: 0.7305 - f1_score: 0.7305
# Epoch 60: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5677 - accuracy: 0.7409 - f1_score: 0.7415 - val_loss: 0.5771 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 61/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5907 - accuracy: 0.7396 - f1_score: 0.7396
# Epoch 61: val_loss did not improve from 0.57428
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5815 - accuracy: 0.7454 - f1_score: 0.7500 - val_loss: 0.5779 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 2.5000e-04
# Epoch 62/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5549 - accuracy: 0.7552 - f1_score: 0.7552
# Epoch 62: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5722 - accuracy: 0.7424 - f1_score: 0.7216 - val_loss: 0.5777 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 63/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5913 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 63: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5852 - accuracy: 0.7561 - f1_score: 0.7642 - val_loss: 0.5789 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 64/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5692 - accuracy: 0.7465 - f1_score: 0.7465
# Epoch 64: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5854 - accuracy: 0.7409 - f1_score: 0.7415 - val_loss: 0.5791 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 65/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5955 - accuracy: 0.7431 - f1_score: 0.7431
# Epoch 65: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5791 - accuracy: 0.7530 - f1_score: 0.7614 - val_loss: 0.5812 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 66/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5980 - accuracy: 0.7305 - f1_score: 0.7305
# Epoch 66: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5824 - accuracy: 0.7363 - f1_score: 0.7244 - val_loss: 0.5816 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 67/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5668 - accuracy: 0.7483 - f1_score: 0.7483
# Epoch 67: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5675 - accuracy: 0.7470 - f1_score: 0.7344 - val_loss: 0.5834 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 68/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5651 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 68: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5567 - accuracy: 0.7561 - f1_score: 0.7642 - val_loss: 0.5830 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 69/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5867 - accuracy: 0.7274 - f1_score: 0.7274
# Epoch 69: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5744 - accuracy: 0.7317 - f1_score: 0.7244 - val_loss: 0.5838 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 70/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5403 - accuracy: 0.7604 - f1_score: 0.7604
# Epoch 70: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5612 - accuracy: 0.7454 - f1_score: 0.7457 - val_loss: 0.5844 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 71/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5812 - accuracy: 0.7359 - f1_score: 0.7359
# Epoch 71: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5806 - accuracy: 0.7363 - f1_score: 0.7372 - val_loss: 0.5825 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 72/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5836 - accuracy: 0.7547 - f1_score: 0.7547
# Epoch 72: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5852 - accuracy: 0.7546 - f1_score: 0.7543 - val_loss: 0.5832 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 73/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5886 - accuracy: 0.7396 - f1_score: 0.7396
# Epoch 73: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5951 - accuracy: 0.7348 - f1_score: 0.7230 - val_loss: 0.5816 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 74/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5712 - accuracy: 0.7363 - f1_score: 0.7363
# Epoch 74: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 21ms/step - loss: 0.5746 - accuracy: 0.7378 - f1_score: 0.7429 - val_loss: 0.5808 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 75/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5972 - accuracy: 0.7378 - f1_score: 0.7378
# Epoch 75: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5915 - accuracy: 0.7409 - f1_score: 0.7457 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 76/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5857 - accuracy: 0.7285 - f1_score: 0.7285
# Epoch 76: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5779 - accuracy: 0.7348 - f1_score: 0.7401 - val_loss: 0.5806 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 77/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5870 - accuracy: 0.7587 - f1_score: 0.7587
# Epoch 77: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5906 - accuracy: 0.7515 - f1_score: 0.7472 - val_loss: 0.5818 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 78/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5791 - accuracy: 0.7465 - f1_score: 0.7465
# Epoch 78: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5839 - accuracy: 0.7470 - f1_score: 0.7514 - val_loss: 0.5808 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 79/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5522 - accuracy: 0.7535 - f1_score: 0.7535
# Epoch 79: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5769 - accuracy: 0.7409 - f1_score: 0.7372 - val_loss: 0.5779 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 80/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5756 - accuracy: 0.7535 - f1_score: 0.7535
# Epoch 80: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5846 - accuracy: 0.7515 - f1_score: 0.7514 - val_loss: 0.5774 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 81/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5608 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 81: val_loss did not improve from 0.57428
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5559 - accuracy: 0.7470 - f1_score: 0.7472 - val_loss: 0.5780 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.2500e-04
# Epoch 82/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5830 - accuracy: 0.7441 - f1_score: 0.7441
# Epoch 82: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5810 - accuracy: 0.7424 - f1_score: 0.7472 - val_loss: 0.5782 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 83/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5737 - accuracy: 0.7587 - f1_score: 0.7587
# Epoch 83: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5823 - accuracy: 0.7485 - f1_score: 0.7486 - val_loss: 0.5784 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 84/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5639 - accuracy: 0.7552 - f1_score: 0.7552
# Epoch 84: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5733 - accuracy: 0.7470 - f1_score: 0.7472 - val_loss: 0.5784 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 85/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5764 - accuracy: 0.7431 - f1_score: 0.7431
# Epoch 85: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5762 - accuracy: 0.7439 - f1_score: 0.7358 - val_loss: 0.5788 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 86/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5930 - accuracy: 0.7344 - f1_score: 0.7344
# Epoch 86: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5856 - accuracy: 0.7393 - f1_score: 0.7358 - val_loss: 0.5784 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 87/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5760 - accuracy: 0.7480 - f1_score: 0.7480
# Epoch 87: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5629 - accuracy: 0.7530 - f1_score: 0.7528 - val_loss: 0.5788 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 88/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5718 - accuracy: 0.7422 - f1_score: 0.7422
# Epoch 88: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5718 - accuracy: 0.7439 - f1_score: 0.7486 - val_loss: 0.5778 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 89/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5551 - accuracy: 0.7587 - f1_score: 0.7587
# Epoch 89: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5618 - accuracy: 0.7530 - f1_score: 0.7401 - val_loss: 0.5767 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 90/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5954 - accuracy: 0.7361 - f1_score: 0.7361
# Epoch 90: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5829 - accuracy: 0.7454 - f1_score: 0.7415 - val_loss: 0.5766 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 91/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5784 - accuracy: 0.7378 - f1_score: 0.7378
# Epoch 91: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5739 - accuracy: 0.7424 - f1_score: 0.7472 - val_loss: 0.5765 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 92/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5632 - accuracy: 0.7578 - f1_score: 0.7578
# Epoch 92: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5640 - accuracy: 0.7546 - f1_score: 0.7415 - val_loss: 0.5763 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 93/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5616 - accuracy: 0.7559 - f1_score: 0.7559
# Epoch 93: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5735 - accuracy: 0.7439 - f1_score: 0.7358 - val_loss: 0.5763 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 94/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5686 - accuracy: 0.7517 - f1_score: 0.7517
# Epoch 94: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5732 - accuracy: 0.7485 - f1_score: 0.7486 - val_loss: 0.5763 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 95/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5706 - accuracy: 0.7422 - f1_score: 0.7422
# Epoch 95: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5707 - accuracy: 0.7515 - f1_score: 0.7557 - val_loss: 0.5763 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 96/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5825 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 96: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5858 - accuracy: 0.7470 - f1_score: 0.7386 - val_loss: 0.5766 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 97/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5827 - accuracy: 0.7402 - f1_score: 0.7402
# Epoch 97: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5763 - accuracy: 0.7470 - f1_score: 0.7514 - val_loss: 0.5769 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 98/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5724 - accuracy: 0.7484 - f1_score: 0.7484
# Epoch 98: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 24ms/step - loss: 0.5659 - accuracy: 0.7546 - f1_score: 0.7713 - val_loss: 0.5768 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 99/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5829 - accuracy: 0.7441 - f1_score: 0.7441
# Epoch 99: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5722 - accuracy: 0.7500 - f1_score: 0.7543 - val_loss: 0.5770 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 100/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5761 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 100: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5775 - accuracy: 0.7530 - f1_score: 0.7528 - val_loss: 0.5786 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 101/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.7607 - f1_score: 0.7727
# Epoch 101: val_loss did not improve from 0.57428
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5707 - accuracy: 0.7607 - f1_score: 0.7727 - val_loss: 0.5798 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 6.2500e-05
# Epoch 102/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5922 - accuracy: 0.7363 - f1_score: 0.7500
# Epoch 102: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5922 - accuracy: 0.7363 - f1_score: 0.7500 - val_loss: 0.5799 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 103/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5567 - accuracy: 0.7517 - f1_score: 0.7517
# Epoch 103: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5634 - accuracy: 0.7439 - f1_score: 0.7443 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 104/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5718 - accuracy: 0.7576 - f1_score: 0.7614
# Epoch 104: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 31ms/step - loss: 0.5718 - accuracy: 0.7576 - f1_score: 0.7614 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 105/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5850 - accuracy: 0.7484 - f1_score: 0.7484
# Epoch 105: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5787 - accuracy: 0.7515 - f1_score: 0.7599 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 106/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5475 - accuracy: 0.7625 - f1_score: 0.7625
# Epoch 106: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5533 - accuracy: 0.7561 - f1_score: 0.7386 - val_loss: 0.5799 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 107/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5592 - accuracy: 0.7546 - f1_score: 0.7628
# Epoch 107: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5592 - accuracy: 0.7546 - f1_score: 0.7628 - val_loss: 0.5794 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 108/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5527 - accuracy: 0.7569 - f1_score: 0.7569
# Epoch 108: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5678 - accuracy: 0.7470 - f1_score: 0.7429 - val_loss: 0.5793 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 109/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5655 - accuracy: 0.7406 - f1_score: 0.7406
# Epoch 109: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5615 - accuracy: 0.7439 - f1_score: 0.7528 - val_loss: 0.5789 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 110/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5884 - accuracy: 0.7469 - f1_score: 0.7469
# Epoch 110: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5854 - accuracy: 0.7470 - f1_score: 0.7472 - val_loss: 0.5785 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 111/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5756 - accuracy: 0.7563 - f1_score: 0.7562
# Epoch 111: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5750 - accuracy: 0.7576 - f1_score: 0.7614 - val_loss: 0.5786 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 112/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5779 - accuracy: 0.7561 - f1_score: 0.7642
# Epoch 112: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5779 - accuracy: 0.7561 - f1_score: 0.7642 - val_loss: 0.5790 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 113/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5685 - accuracy: 0.7637 - f1_score: 0.7637
# Epoch 113: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5761 - accuracy: 0.7561 - f1_score: 0.7642 - val_loss: 0.5797 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 114/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5882 - accuracy: 0.7465 - f1_score: 0.7465
# Epoch 114: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5838 - accuracy: 0.7470 - f1_score: 0.7429 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 115/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5730 - accuracy: 0.7578 - f1_score: 0.7578
# Epoch 115: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5770 - accuracy: 0.7546 - f1_score: 0.7457 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 116/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5741 - accuracy: 0.7656 - f1_score: 0.7656
# Epoch 116: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5763 - accuracy: 0.7622 - f1_score: 0.7528 - val_loss: 0.5804 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 117/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5731 - accuracy: 0.7516 - f1_score: 0.7516
# Epoch 117: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5750 - accuracy: 0.7515 - f1_score: 0.7514 - val_loss: 0.5807 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 118/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5763 - accuracy: 0.7515 - f1_score: 0.7599
# Epoch 118: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5763 - accuracy: 0.7515 - f1_score: 0.7599 - val_loss: 0.5809 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 119/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5707 - accuracy: 0.7547 - f1_score: 0.7547
# Epoch 119: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5703 - accuracy: 0.7546 - f1_score: 0.7543 - val_loss: 0.5806 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 120/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5785 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 120: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5787 - accuracy: 0.7530 - f1_score: 0.7528 - val_loss: 0.5809 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 121/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.7515 - f1_score: 0.7514
# Epoch 121: val_loss did not improve from 0.57428
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5688 - accuracy: 0.7515 - f1_score: 0.7514 - val_loss: 0.5805 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 3.1250e-05
# Epoch 122/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5797 - accuracy: 0.7594 - f1_score: 0.7594
# Epoch 122: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5765 - accuracy: 0.7591 - f1_score: 0.7585 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 123/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5913 - accuracy: 0.7396 - f1_score: 0.7396
# Epoch 123: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5909 - accuracy: 0.7454 - f1_score: 0.7543 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 124/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.7607 - f1_score: 0.7727
# Epoch 124: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 34ms/step - loss: 0.5678 - accuracy: 0.7607 - f1_score: 0.7727 - val_loss: 0.5799 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 125/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5734 - accuracy: 0.7535 - f1_score: 0.7535
# Epoch 125: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5746 - accuracy: 0.7500 - f1_score: 0.7500 - val_loss: 0.5798 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 126/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.7576 - f1_score: 0.7486
# Epoch 126: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5863 - accuracy: 0.7576 - f1_score: 0.7486 - val_loss: 0.5798 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 127/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5599 - accuracy: 0.7656 - f1_score: 0.7656
# Epoch 127: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5648 - accuracy: 0.7591 - f1_score: 0.7585 - val_loss: 0.5796 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 128/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5748 - accuracy: 0.7547 - f1_score: 0.7547
# Epoch 128: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 24ms/step - loss: 0.5764 - accuracy: 0.7546 - f1_score: 0.7543 - val_loss: 0.5796 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 129/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5530 - accuracy: 0.7535 - f1_score: 0.7535
# Epoch 129: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5603 - accuracy: 0.7454 - f1_score: 0.7415 - val_loss: 0.5795 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 130/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5835 - accuracy: 0.7406 - f1_score: 0.7406
# Epoch 130: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5800 - accuracy: 0.7424 - f1_score: 0.7472 - val_loss: 0.5794 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 131/10000
#  7/11 [==================>...........] - ETA: 0s - loss: 0.5769 - accuracy: 0.7411 - f1_score: 0.7411
# Epoch 131: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5673 - accuracy: 0.7576 - f1_score: 0.7528 - val_loss: 0.5794 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 132/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5786 - accuracy: 0.7469 - f1_score: 0.7469
# Epoch 132: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5777 - accuracy: 0.7485 - f1_score: 0.7528 - val_loss: 0.5797 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 133/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5730 - accuracy: 0.7563 - f1_score: 0.7562
# Epoch 133: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 24ms/step - loss: 0.5707 - accuracy: 0.7576 - f1_score: 0.7614 - val_loss: 0.5798 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.5625e-05
# Epoch 134/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5755 - accuracy: 0.7469 - f1_score: 0.7469
# Epoch 134: val_loss did not improve from 0.57428
# ...
# Epoch 549: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5785 - accuracy: 0.7454 - f1_score: 0.7543 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 550/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5699 - accuracy: 0.7594 - f1_score: 0.7594
# Epoch 550: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5665 - accuracy: 0.7622 - f1_score: 0.7699 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 551/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.7576 - f1_score: 0.7614
# Epoch 551: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5708 - accuracy: 0.7576 - f1_score: 0.7614 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 552/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5855 - accuracy: 0.7391 - f1_score: 0.7391
# Epoch 552: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5854 - accuracy: 0.7393 - f1_score: 0.7401 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 553/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5753 - accuracy: 0.7539 - f1_score: 0.7539
# Epoch 553: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5788 - accuracy: 0.7530 - f1_score: 0.7486 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 554/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5647 - accuracy: 0.7515 - f1_score: 0.7557
# Epoch 554: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5647 - accuracy: 0.7515 - f1_score: 0.7557 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 555/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5821 - accuracy: 0.7375 - f1_score: 0.7375
# Epoch 555: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 36ms/step - loss: 0.5825 - accuracy: 0.7363 - f1_score: 0.7330 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 556/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5736 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 556: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5731 - accuracy: 0.7546 - f1_score: 0.7585 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 557/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5722 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 557: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5716 - accuracy: 0.7530 - f1_score: 0.7528 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 558/10000
#  8/11 [====================>.........] - ETA: 0s - loss: 0.5665 - accuracy: 0.7539 - f1_score: 0.7539
# Epoch 558: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 32ms/step - loss: 0.5723 - accuracy: 0.7546 - f1_score: 0.7543 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 559/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5604 - accuracy: 0.7587 - f1_score: 0.7587
# Epoch 559: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5669 - accuracy: 0.7546 - f1_score: 0.7500 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 560/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5817 - accuracy: 0.7516 - f1_score: 0.7516
# Epoch 560: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 30ms/step - loss: 0.5792 - accuracy: 0.7546 - f1_score: 0.7628 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 561/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.7546 - f1_score: 0.7372
# Epoch 561: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.5722 - accuracy: 0.7546 - f1_score: 0.7372 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 562/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5757 - accuracy: 0.7578 - f1_score: 0.7578
# Epoch 562: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.5755 - accuracy: 0.7561 - f1_score: 0.7514 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 563/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5705 - accuracy: 0.7674 - f1_score: 0.7674
# Epoch 563: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5863 - accuracy: 0.7515 - f1_score: 0.7472 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 564/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5690 - accuracy: 0.7578 - f1_score: 0.7578
# Epoch 564: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 34ms/step - loss: 0.5670 - accuracy: 0.7591 - f1_score: 0.7628 - val_loss: 0.5804 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 565/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5665 - accuracy: 0.7517 - f1_score: 0.7517
# Epoch 565: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5625 - accuracy: 0.7576 - f1_score: 0.7656 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 566/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5610 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 566: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 24ms/step - loss: 0.5640 - accuracy: 0.7530 - f1_score: 0.7528 - val_loss: 0.5802 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 567/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5761 - accuracy: 0.7485 - f1_score: 0.7571
# Epoch 567: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.5761 - accuracy: 0.7485 - f1_score: 0.7571 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 568/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5788 - accuracy: 0.7516 - f1_score: 0.7516
# Epoch 568: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5770 - accuracy: 0.7546 - f1_score: 0.7628 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 569/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5702 - accuracy: 0.7594 - f1_score: 0.7594
# Epoch 569: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5740 - accuracy: 0.7561 - f1_score: 0.7472 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 570/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5705 - accuracy: 0.7531 - f1_score: 0.7531
# Epoch 570: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 23ms/step - loss: 0.5678 - accuracy: 0.7546 - f1_score: 0.7585 - val_loss: 0.5800 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 571/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5721 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 571: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 36ms/step - loss: 0.5731 - accuracy: 0.7500 - f1_score: 0.7500 - val_loss: 0.5801 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 572/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.5723 - accuracy: 0.7591 - f1_score: 0.7585
# Epoch 572: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 35ms/step - loss: 0.5723 - accuracy: 0.7591 - f1_score: 0.7585 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 573/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5763 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 573: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 29ms/step - loss: 0.5781 - accuracy: 0.7485 - f1_score: 0.7443 - val_loss: 0.5804 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 574/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5884 - accuracy: 0.7500 - f1_score: 0.7500
# Epoch 574: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 25ms/step - loss: 0.5836 - accuracy: 0.7546 - f1_score: 0.7670 - val_loss: 0.5804 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 575/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5662 - accuracy: 0.7484 - f1_score: 0.7484
# Epoch 575: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 27ms/step - loss: 0.5652 - accuracy: 0.7500 - f1_score: 0.7543 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 576/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.5880 - accuracy: 0.7465 - f1_score: 0.7465
# Epoch 576: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5787 - accuracy: 0.7515 - f1_score: 0.7599 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 577/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5702 - accuracy: 0.7563 - f1_score: 0.7562
# Epoch 577: val_loss did not improve from 0.57428
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5653 - accuracy: 0.7607 - f1_score: 0.7727 - val_loss: 0.5803 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-06
# Epoch 578/10000
#  4/11 [=========>....................] - ETA: 0s - loss: 0.5529 - accuracy: 0.7500 - f1_score: 0.7500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
#       2           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#       3           batch_size=64,epochs= 10000, callbacks=[checkpointer,lr_scheduler])
#
# File d:\ads_test\.conda\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\ads_test\.conda\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File d:\ads_test\.conda\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 5ms/step
# 0.7376543209876543

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7376543209876543
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        85
#            0       0.74      1.00      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.37      0.50      0.42       324
# weighted avg       0.54      0.74      0.63       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 239 chiếm khoảng 73.76543209876543% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 0 chiếm khoảng 0.0% so với thực tế
