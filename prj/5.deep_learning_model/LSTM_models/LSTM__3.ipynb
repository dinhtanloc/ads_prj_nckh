# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # # Tính toán các loss function riêng lẻ
    focal__loss = focal_loss(y_true,y_pred)
    f1__loss = f1_loss(y_true,y_pred)
    dice__loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal__loss) + (f1_weight * f1__loss) + (dice_weight * dice__loss)

    return total_loss

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
from keras.layers import Dense, LSTM, BatchNormalization, Dropout
# from scikeras.wrappers import KerasClassifier 


def build_model(unit):
    model = Sequential()

    model.add(LSTM(units=unit, input_shape=(42,1), activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(optimizer=Adam(lr=0.0001), loss=dice_coef_loss, metrics=['accuracy',f1_score])


    return model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# # Wrap Keras model so it can be used by scikit-learn
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# # Define the grid of hyperparameters to search
# param_grid = {
#     'model__unit': [32, 64, 96,128,184,256,384,512],
 
# }

# # Create a scorer using make_scorer
# f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)

# # Load your data here
# # X_train, y_train = ...
# # X_val, y_val = ...

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
model=build_model(32)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 128)               4224
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 8834 (34.51 KB)
# Trainable params: 8834 (34.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5010 - f1_score: 0.3455
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.hdf5
# 16/16 [==============================] - 2s 29ms/step - loss: 0.6924 - accuracy: 0.5010 - f1_score: 0.3455 - val_loss: 0.4848 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6815 - accuracy: 0.5100 - f1_score: 0.3366
# Epoch 2: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6911 - accuracy: 0.5000 - f1_score: 0.3320 - val_loss: 0.4668 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.5110 - f1_score: 0.3626
# Epoch 3: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6905 - accuracy: 0.5110 - f1_score: 0.3626 - val_loss: 0.4635 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6580 - accuracy: 0.5132 - f1_score: 0.3415
# Epoch 4: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6753 - accuracy: 0.5000 - f1_score: 0.3334 - val_loss: 0.3220 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6447 - accuracy: 0.5156 - f1_score: 0.3936
# Epoch 5: val_f1_score improved from 0.42467 to 0.45658, saving model to best_model.hdf5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6452 - accuracy: 0.5140 - f1_score: 0.3985 - val_loss: 0.4189 - val_accuracy: 0.5278 - val_f1_score: 0.4566 - lr: 0.0010
# Epoch 6/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6012 - accuracy: 0.5748 - f1_score: 0.4844
# Epoch 6: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6075 - accuracy: 0.5719 - f1_score: 0.4683 - val_loss: 0.7388 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 7/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6868 - accuracy: 0.5024 - f1_score: 0.3330
# Epoch 7: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6897 - accuracy: 0.5000 - f1_score: 0.3314 - val_loss: 0.7384 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5000 - f1_score: 0.3327
# Epoch 8: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6910 - accuracy: 0.5000 - f1_score: 0.3327 - val_loss: 0.7381 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6866 - accuracy: 0.5021 - f1_score: 0.3333
# Epoch 9: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7379 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3332
# Epoch 10: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3332 - val_loss: 0.7378 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 11/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6866 - accuracy: 0.5012 - f1_score: 0.3328
# Epoch 11: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6878 - accuracy: 0.5000 - f1_score: 0.3321 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6856 - accuracy: 0.5031 - f1_score: 0.3337
# Epoch 12: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.3316 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 13/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6826 - accuracy: 0.5067 - f1_score: 0.3352
# Epoch 13: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.3315 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 14/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6843 - accuracy: 0.5022 - f1_score: 0.3329
# Epoch 14: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6856 - accuracy: 0.5000 - f1_score: 0.3326 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6898 - accuracy: 0.5010 - f1_score: 0.3333
# Epoch 15: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6906 - accuracy: 0.5000 - f1_score: 0.3327 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6858 - accuracy: 0.4990 - f1_score: 0.3313
# Epoch 16: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6854 - accuracy: 0.5000 - f1_score: 0.3321 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6898 - accuracy: 0.4969 - f1_score: 0.3310
# Epoch 17: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.3330 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.5000 - f1_score: 0.3333
# Epoch 18: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6863 - accuracy: 0.5000 - f1_score: 0.3333 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 19/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6922 - accuracy: 0.4928 - f1_score: 0.3290
# Epoch 19: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.3328 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 20/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6721 - accuracy: 0.5185 - f1_score: 0.3398
# Epoch 20: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6843 - accuracy: 0.5000 - f1_score: 0.3304 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 21/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6782 - accuracy: 0.5156 - f1_score: 0.3394
# Epoch 21: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6858 - accuracy: 0.5000 - f1_score: 0.3307 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 22/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6990 - accuracy: 0.4805 - f1_score: 0.3233
# Epoch 22: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6844 - accuracy: 0.5000 - f1_score: 0.3335 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 23/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6868 - accuracy: 0.5012 - f1_score: 0.3329
# Epoch 23: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6874 - accuracy: 0.5000 - f1_score: 0.3318 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 24/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6864 - accuracy: 0.5011 - f1_score: 0.3327
# Epoch 24: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6874 - accuracy: 0.5000 - f1_score: 0.3328 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 25/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6894 - accuracy: 0.4974 - f1_score: 0.3311
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.3329 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 26/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6939 - accuracy: 0.4900 - f1_score: 0.3277
# Epoch 26: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6866 - accuracy: 0.5000 - f1_score: 0.3325 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 27/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6884 - accuracy: 0.5022 - f1_score: 0.3338
# Epoch 27: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3328 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 28/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6952 - accuracy: 0.4904 - f1_score: 0.3283
# Epoch 28: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6864 - accuracy: 0.5000 - f1_score: 0.3328 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 29/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6980 - accuracy: 0.4831 - f1_score: 0.3246
# Epoch 29: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6857 - accuracy: 0.5000 - f1_score: 0.3336 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 30/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6847 - accuracy: 0.5078 - f1_score: 0.3362
# Epoch 30: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6895 - accuracy: 0.5000 - f1_score: 0.3329 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 31/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6788 - accuracy: 0.5132 - f1_score: 0.3381
# Epoch 31: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6869 - accuracy: 0.5000 - f1_score: 0.3309 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 32/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6846 - accuracy: 0.5000 - f1_score: 0.3317
# Epoch 32: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6852 - accuracy: 0.5000 - f1_score: 0.3314 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 33/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6912 - accuracy: 0.4944 - f1_score: 0.3298
# Epoch 33: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6877 - accuracy: 0.5000 - f1_score: 0.3330 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 34/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6903 - accuracy: 0.4940 - f1_score: 0.3294
# Epoch 34: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6834 - accuracy: 0.5000 - f1_score: 0.3322 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 35/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6840 - accuracy: 0.5033 - f1_score: 0.3335
# Epoch 35: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6865 - accuracy: 0.5000 - f1_score: 0.3323 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 36/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6803 - accuracy: 0.5084 - f1_score: 0.3357
# Epoch 36: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6864 - accuracy: 0.5000 - f1_score: 0.3314 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 37/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6913 - accuracy: 0.4988 - f1_score: 0.3324
# Epoch 37: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3330 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 38/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6865 - accuracy: 0.5036 - f1_score: 0.3342
# Epoch 38: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6892 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 39/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6855 - accuracy: 0.5043 - f1_score: 0.3344
# Epoch 39: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6878 - accuracy: 0.5000 - f1_score: 0.3324 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 40/10000
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6784 - accuracy: 0.5114 - f1_score: 0.3370
# Epoch 40: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6836 - accuracy: 0.5000 - f1_score: 0.3321 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 41/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6852 - accuracy: 0.5060 - f1_score: 0.3353
# Epoch 41: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.3331 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 42/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6850 - accuracy: 0.4988 - f1_score: 0.3311
# Epoch 42: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6850 - accuracy: 0.5000 - f1_score: 0.3311 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 43/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6841 - accuracy: 0.5060 - f1_score: 0.3350
# Epoch 43: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.3326 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 44/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6908 - accuracy: 0.4940 - f1_score: 0.3295
# Epoch 44: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6873 - accuracy: 0.5000 - f1_score: 0.3323 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 45/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6908 - accuracy: 0.4916 - f1_score: 0.3280
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 45: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6858 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 5.0000e-04
# Epoch 46/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6866 - accuracy: 0.5036 - f1_score: 0.3342
# Epoch 46: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6893 - accuracy: 0.5000 - f1_score: 0.3324 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 47/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6963 - accuracy: 0.4880 - f1_score: 0.3271
# Epoch 47: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6867 - accuracy: 0.5000 - f1_score: 0.3326 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 48/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6930 - accuracy: 0.4952 - f1_score: 0.3306
# Epoch 48: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.3339 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 49/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6855 - accuracy: 0.5024 - f1_score: 0.3332
# Epoch 49: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.3321 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 50/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6907 - accuracy: 0.4988 - f1_score: 0.3322
# Epoch 50: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6887 - accuracy: 0.5000 - f1_score: 0.3318 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 51/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6892 - accuracy: 0.4988 - f1_score: 0.3319
# Epoch 51: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.3323 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 52/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6870 - accuracy: 0.5036 - f1_score: 0.3342
# Epoch 52: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6894 - accuracy: 0.5000 - f1_score: 0.3331 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 53/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6869 - accuracy: 0.5036 - f1_score: 0.3342
# Epoch 53: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6894 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6898 - accuracy: 0.5010 - f1_score: 0.3333
# Epoch 54: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6906 - accuracy: 0.5000 - f1_score: 0.3327 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6870 - accuracy: 0.5031 - f1_score: 0.3340
# Epoch 55: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6889 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 56/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6873 - accuracy: 0.5048 - f1_score: 0.3350
# Epoch 56: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6905 - accuracy: 0.5000 - f1_score: 0.3329 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6943 - accuracy: 0.4948 - f1_score: 0.3307
# Epoch 57: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3339 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 58/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6923 - accuracy: 0.4940 - f1_score: 0.3298
# Epoch 58: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6871 - accuracy: 0.5000 - f1_score: 0.3331 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6882 - accuracy: 0.5010 - f1_score: 0.3330
# Epoch 59: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.3324 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 60/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6847 - accuracy: 0.5045 - f1_score: 0.3343
# Epoch 60: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6880 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 61/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6879 - accuracy: 0.5035 - f1_score: 0.3344
# Epoch 61: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6881 - accuracy: 0.5000 - f1_score: 0.3312 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 62/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6839 - accuracy: 0.5072 - f1_score: 0.3357
# Epoch 62: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6882 - accuracy: 0.5000 - f1_score: 0.3312 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 63/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6863 - accuracy: 0.4989 - f1_score: 0.3314
# Epoch 63: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6862 - accuracy: 0.5000 - f1_score: 0.3325 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 64/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6866 - accuracy: 0.5024 - f1_score: 0.3335
# Epoch 64: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6875 - accuracy: 0.5000 - f1_score: 0.3307 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 65/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6823 - accuracy: 0.5096 - f1_score: 0.3368
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 65: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.3320 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 2.5000e-04
# Epoch 66/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6827 - accuracy: 0.5100 - f1_score: 0.3371
# Epoch 66: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.3305 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 67/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6869 - accuracy: 0.4955 - f1_score: 0.3296
# Epoch 67: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6835 - accuracy: 0.5000 - f1_score: 0.3308 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6823 - accuracy: 0.5052 - f1_score: 0.3343
# Epoch 68: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6852 - accuracy: 0.5000 - f1_score: 0.3306 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 69/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6873 - accuracy: 0.5033 - f1_score: 0.3342
# Epoch 69: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6895 - accuracy: 0.5000 - f1_score: 0.3320 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 70/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6786 - accuracy: 0.5123 - f1_score: 0.3376
# Epoch 70: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6849 - accuracy: 0.5000 - f1_score: 0.3297 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6880 - accuracy: 0.5042 - f1_score: 0.3348
# Epoch 71: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6902 - accuracy: 0.5000 - f1_score: 0.3319 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 72/10000
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6827 - accuracy: 0.5078 - f1_score: 0.3358
# Epoch 72: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6884 - accuracy: 0.5000 - f1_score: 0.3320 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 73/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.5000 - f1_score: 0.3317
# Epoch 73: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6883 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 74/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6820 - accuracy: 0.5072 - f1_score: 0.3353
# Epoch 74: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6870 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6807 - accuracy: 0.5083 - f1_score: 0.3357
# Epoch 75: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6842 - accuracy: 0.5000 - f1_score: 0.3295 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 76/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.5000 - f1_score: 0.3322
# Epoch 76: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6856 - accuracy: 0.5000 - f1_score: 0.3322 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 77/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6859 - accuracy: 0.5045 - f1_score: 0.3345
# Epoch 77: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6889 - accuracy: 0.5000 - f1_score: 0.3326 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.5000 - f1_score: 0.3323
# Epoch 78: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6876 - accuracy: 0.5000 - f1_score: 0.3323 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 79/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.7008 - accuracy: 0.4844 - f1_score: 0.3259
# Epoch 79: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6883 - accuracy: 0.5000 - f1_score: 0.3343 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 80/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.3332
# Epoch 80: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.3332 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 81/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6885 - accuracy: 0.4989 - f1_score: 0.3319
# Epoch 81: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6876 - accuracy: 0.5000 - f1_score: 0.3316 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 82/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6904 - accuracy: 0.4976 - f1_score: 0.3315
# Epoch 82: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6890 - accuracy: 0.5000 - f1_score: 0.3333 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 83/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6772 - accuracy: 0.5122 - f1_score: 0.3372
# Epoch 83: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6865 - accuracy: 0.5000 - f1_score: 0.3329 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 84/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6875 - accuracy: 0.5052 - f1_score: 0.3353
# Epoch 84: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6901 - accuracy: 0.5000 - f1_score: 0.3333 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6848 - accuracy: 0.5031 - f1_score: 0.3335
# Epoch 85: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 85: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6868 - accuracy: 0.5000 - f1_score: 0.3314 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 1.2500e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6843 - accuracy: 0.5010 - f1_score: 0.3322
# Epoch 86: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6853 - accuracy: 0.5000 - f1_score: 0.3316 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6885 - accuracy: 0.5000 - f1_score: 0.3325
# Epoch 87: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6887 - accuracy: 0.5000 - f1_score: 0.3325 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6851 - accuracy: 0.5052 - f1_score: 0.3348
# Epoch 88: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6878 - accuracy: 0.5000 - f1_score: 0.3311 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 89/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6828 - accuracy: 0.5100 - f1_score: 0.3371
# Epoch 89: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6886 - accuracy: 0.5000 - f1_score: 0.3316 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 90/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.3330
# Epoch 90: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.3330 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 91/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6835 - accuracy: 0.5067 - f1_score: 0.3353
# Epoch 91: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6879 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 92/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.5000 - f1_score: 0.3324
# Epoch 92: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6893 - accuracy: 0.5000 - f1_score: 0.3324 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 93/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6868 - accuracy: 0.5035 - f1_score: 0.3342
# Epoch 93: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6900 - accuracy: 0.5000 - f1_score: 0.3330 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 94/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6806 - accuracy: 0.5067 - f1_score: 0.3347
# Epoch 94: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6850 - accuracy: 0.5000 - f1_score: 0.3318 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6817 - accuracy: 0.5042 - f1_score: 0.3335
# Epoch 95: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6842 - accuracy: 0.5000 - f1_score: 0.3306 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6822 - accuracy: 0.5010 - f1_score: 0.3318
# Epoch 96: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6833 - accuracy: 0.5000 - f1_score: 0.3313 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 97/10000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6901 - accuracy: 0.4976 - f1_score: 0.3314
# Epoch 97: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6889 - accuracy: 0.5000 - f1_score: 0.3332 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6884 - accuracy: 0.5010 - f1_score: 0.3331
# Epoch 98: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6892 - accuracy: 0.5000 - f1_score: 0.3324 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6887 - accuracy: 0.5010 - f1_score: 0.3331
# Epoch 99: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6895 - accuracy: 0.5000 - f1_score: 0.3325 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6853 - accuracy: 0.5063 - f1_score: 0.3354
# Epoch 100: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6883 - accuracy: 0.5000 - f1_score: 0.3309 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 101/10000
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6976 - accuracy: 0.4792 - f1_score: 0.3222
# Epoch 101: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6841 - accuracy: 0.5000 - f1_score: 0.3314 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6848 - accuracy: 0.4969 - f1_score: 0.3299
# Epoch 102: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6828 - accuracy: 0.5000 - f1_score: 0.3320 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 103/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.5000 - f1_score: 0.3311
# Epoch 103: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6876 - accuracy: 0.5000 - f1_score: 0.3311 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6825 - accuracy: 0.5010 - f1_score: 0.3319
# Epoch 104: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6835 - accuracy: 0.5000 - f1_score: 0.3313 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6848 - accuracy: 0.5010 - f1_score: 0.3324Restoring model weights from the end of the best epoch: 5.
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 105: val_f1_score did not improve from 0.45658
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6857 - accuracy: 0.5000 - f1_score: 0.3317 - val_loss: 0.7377 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 6.2500e-05
# Epoch 105: early stopping

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
# check_model=resnet50
# check_model.load_weights('best_model.h5')
# check_model.summary()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.5277777777777778

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.5277777777777778
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.23      0.35      0.28        85
#            0       0.72      0.59      0.65       239
#
#     accuracy                           0.53       324
#    macro avg       0.48      0.47      0.46       324
# weighted avg       0.59      0.53      0.55       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 171 chiếm khoảng 52.77777777777778% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 30 chiếm khoảng 35.294117647058826% so với thực tế
