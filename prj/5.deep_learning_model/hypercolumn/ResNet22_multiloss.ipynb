# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
def multi_loss(y_true, y_pred):
    # Tính toán các loss function riêng lẻ
    focal_loss = focal_loss(y_true,y_pred)
    f1_loss = f1_loss(y_true,y_pred)
    dice_loss = dice_coef_loss(y_true,y_pred)

    # Đặt trọng số cho từng loss function (nếu cần)
    focal_weight = 0.3
    f1_weight = 0.5
    dice_weight = 0.2

    # Tổng hợp các loss function
    total_loss = (focal_weight * focal_loss) + (f1_weight * f1_loss) + (dice_weight * dice_loss)

    return total_loss

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

def build_model(filters1, filters2, filters3):
    input_shape = (42, 1)
    x_input = Input(shape=input_shape)

    bn_axis = -1

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
    block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

    # Hypercolumn formation
    hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
                                GlobalAveragePooling1D()(block2_output),
                                GlobalAveragePooling1D()(x)], axis=-1)

    # Final Dense layers
    x = Dense(128, activation='relu')(hypercolumns)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

    # Compile model
    # model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])
    model.compile(optimizer=Adam(learning_rate=0.001), loss=multi_loss, metrics=['accuracy',f1_score])
    
    return model

# %%
# from tensorflow.keras.optimizers import Adam
# from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
# from keras.models import Model
# from keras.layers import Input
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

# def build_model(filters1,filters2,filters3,filters4,filters5):
#     input_shape =(42,1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1
#     step=32
#     # Sử dụng filters trong hàm build_resnet_model
#     # filters1 = 96
#     # filters2 = filters1 * 2
#     # filters3 = filters1 * 4
#     # filters4 = filters1 * 6
#     # filters5 = filters1 * 8
#     # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
#     # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
#     # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
#     # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
#     # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

#     learning_rate = 0.0001

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
#     # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
#     # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
#     # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
#     x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
#     # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

#     x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
#     # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
#     # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
#     # Repeat this pattern as needed

#     # Ending layers
#     x = GlobalAveragePooling1D()(x)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(x_input, x, name='resnet50_1d')

#     # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
#     model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
#     return model


# param_grid = {
#     'model__filters1': [32, 64, 96],
#     'model__filters2': [96, 128, 192],
#     'model__filters3': [192, 256, 384],
#     'model__filters4': [256, 384, 512],
#     'model__filters5': [384, 512, 1024],
# }
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# # Create a scorer using make_scorer
# f1_scorer = make_scorer(f1_score, average='macro')

# # Setup GridSearchCV with the f1_scorer
# # grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# # 
# # Tạo đối tượng RandomSearch tuner


# data_order=8

# # # Run grid search
# # grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # # Summarize results
# # print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# # means = grid_result.cv_results_['mean_test_score']
# # stds = grid_result.cv_results_['std_test_score']
# # params = grid_result.cv_results_['params']
# # for mean, std, param in zip(means, stds, params):
# #     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
# resnet50=build_model(32,96,192,256,384)
resnet50=build_model(32,96,192)
resnet50.summary()
# Out:
# Model: "resnet50_1d_hypercolumn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 5, 96)        0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 5, 96)        0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 5, 192)       0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 5, 192)       0           ['add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 96)          0           ['activation_6[0][0]']
#  alAveragePooling1D)
#
#  global_average_pooling1d_1 (Gl  (None, 192)         0           ['activation_15[0][0]']
#  obalAveragePooling1D)
#
#  global_average_pooling1d_2 (Gl  (None, 192)         0           ['activation_21[0][0]']
#  obalAveragePooling1D)
#
#  concatenate (Concatenate)      (None, 480)          0           ['global_average_pooling1d[0][0]'
#                                                                  , 'global_average_pooling1d_1[0][
#                                                                  0]',
#                                                                   'global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  dense (Dense)                  (None, 128)          61568       ['concatenate[0][0]']
#
#  fc1000 (Dense)                 (None, 2)            258         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 365,590
# Trainable params: 365,132
# Non-trainable params: 458
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9065 - accuracy: 0.5167 - f1_score: 0.3390
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 8s 102ms/step - loss: 0.9105 - accuracy: 0.5140 - f1_score: 0.3373 - val_loss: 0.5722 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9258 - accuracy: 0.5031 - f1_score: 0.3327
# Epoch 2: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 0s 30ms/step - loss: 0.9307 - accuracy: 0.5000 - f1_score: 0.3307 - val_loss: 0.5740 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9274 - accuracy: 0.5000 - f1_score: 0.3323
# Epoch 3: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 1s 36ms/step - loss: 0.9272 - accuracy: 0.5000 - f1_score: 0.3323 - val_loss: 0.5734 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9133 - accuracy: 0.5010 - f1_score: 0.3328
# Epoch 4: val_f1_score did not improve from 0.42467
# 16/16 [==============================] - 1s 31ms/step - loss: 0.9124 - accuracy: 0.4960 - f1_score: 0.3293 - val_loss: 0.6589 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7027 - accuracy: 0.5271 - f1_score: 0.4547
# Epoch 5: val_f1_score improved from 0.42467 to 0.43643, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.6966 - accuracy: 0.5329 - f1_score: 0.4661 - val_loss: 0.5461 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4903 - accuracy: 0.6552 - f1_score: 0.6528
# Epoch 6: val_f1_score improved from 0.43643 to 0.44901, saving model to best_model.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4828 - accuracy: 0.6607 - f1_score: 0.6611 - val_loss: 0.5419 - val_accuracy: 0.7407 - val_f1_score: 0.4490 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3774 - accuracy: 0.7323 - f1_score: 0.7293
# Epoch 7: val_f1_score improved from 0.44901 to 0.51576, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3838 - accuracy: 0.7265 - f1_score: 0.7202 - val_loss: 0.4641 - val_accuracy: 0.7037 - val_f1_score: 0.5158 - lr: 0.0010
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3812 - accuracy: 0.7385 - f1_score: 0.7326
# Epoch 8: val_f1_score did not improve from 0.51576
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3780 - accuracy: 0.7385 - f1_score: 0.7327 - val_loss: 0.5155 - val_accuracy: 0.7377 - val_f1_score: 0.4759 - lr: 0.0010
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3156 - accuracy: 0.7719 - f1_score: 0.7698
# Epoch 9: val_f1_score improved from 0.51576 to 0.62387, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3198 - accuracy: 0.7695 - f1_score: 0.7661 - val_loss: 0.4519 - val_accuracy: 0.6296 - val_f1_score: 0.6239 - lr: 0.0010
# Epoch 10/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.3130 - accuracy: 0.7835 - f1_score: 0.7810
# Epoch 10: val_f1_score did not improve from 0.62387
# 16/16 [==============================] - 1s 36ms/step - loss: 0.3053 - accuracy: 0.7894 - f1_score: 0.7870 - val_loss: 0.5483 - val_accuracy: 0.7377 - val_f1_score: 0.4510 - lr: 0.0010
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3102 - accuracy: 0.7740 - f1_score: 0.7708
# Epoch 11: val_f1_score did not improve from 0.62387
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3065 - accuracy: 0.7764 - f1_score: 0.7746 - val_loss: 0.4361 - val_accuracy: 0.7130 - val_f1_score: 0.5195 - lr: 0.0010
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2967 - accuracy: 0.7927 - f1_score: 0.7895
# Epoch 12: val_f1_score did not improve from 0.62387
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2928 - accuracy: 0.7944 - f1_score: 0.7922 - val_loss: 0.4289 - val_accuracy: 0.7191 - val_f1_score: 0.5561 - lr: 0.0010
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3430 - accuracy: 0.7573 - f1_score: 0.7521
# Epoch 13: val_f1_score did not improve from 0.62387
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3421 - accuracy: 0.7585 - f1_score: 0.7542 - val_loss: 0.5640 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3190 - accuracy: 0.7729 - f1_score: 0.7692
# Epoch 14: val_f1_score improved from 0.62387 to 0.66054, saving model to best_model.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.3152 - accuracy: 0.7754 - f1_score: 0.7729 - val_loss: 0.4027 - val_accuracy: 0.6790 - val_f1_score: 0.6605 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2823 - accuracy: 0.8000 - f1_score: 0.7977
# Epoch 15: val_f1_score did not improve from 0.66054
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2851 - accuracy: 0.7974 - f1_score: 0.7940 - val_loss: 0.5595 - val_accuracy: 0.7315 - val_f1_score: 0.4379 - lr: 0.0010
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3054 - accuracy: 0.7823 - f1_score: 0.7806
# Epoch 16: val_f1_score did not improve from 0.66054
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3005 - accuracy: 0.7854 - f1_score: 0.7853 - val_loss: 0.4678 - val_accuracy: 0.7562 - val_f1_score: 0.5190 - lr: 0.0010
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2876 - accuracy: 0.7937 - f1_score: 0.7908
# Epoch 17: val_f1_score did not improve from 0.66054
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2901 - accuracy: 0.7924 - f1_score: 0.7889 - val_loss: 0.4793 - val_accuracy: 0.7500 - val_f1_score: 0.5087 - lr: 0.0010
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2970 - accuracy: 0.7865 - f1_score: 0.7843
# Epoch 18: val_f1_score improved from 0.66054 to 0.73829, saving model to best_model.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2930 - accuracy: 0.7904 - f1_score: 0.7902 - val_loss: 0.3141 - val_accuracy: 0.7438 - val_f1_score: 0.7383 - lr: 0.0010
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2911 - accuracy: 0.7917 - f1_score: 0.7881
# Epoch 19: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2916 - accuracy: 0.7914 - f1_score: 0.7875 - val_loss: 0.5761 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2892 - accuracy: 0.7958 - f1_score: 0.7930
# Epoch 20: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2887 - accuracy: 0.7964 - f1_score: 0.7938 - val_loss: 0.3521 - val_accuracy: 0.6852 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2672 - accuracy: 0.8094 - f1_score: 0.8078
# Epoch 21: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2669 - accuracy: 0.8084 - f1_score: 0.8064 - val_loss: 0.4101 - val_accuracy: 0.6821 - val_f1_score: 0.5671 - lr: 0.0010
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2884 - accuracy: 0.7937 - f1_score: 0.7923
# Epoch 22: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2872 - accuracy: 0.7944 - f1_score: 0.7934 - val_loss: 0.5125 - val_accuracy: 0.7438 - val_f1_score: 0.4748 - lr: 0.0010
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2733 - accuracy: 0.8031 - f1_score: 0.8022
# Epoch 23: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2698 - accuracy: 0.8054 - f1_score: 0.8056 - val_loss: 0.3613 - val_accuracy: 0.7068 - val_f1_score: 0.6053 - lr: 0.0010
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2708 - accuracy: 0.8042 - f1_score: 0.8023
# Epoch 24: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2694 - accuracy: 0.8054 - f1_score: 0.8042 - val_loss: 0.4329 - val_accuracy: 0.7500 - val_f1_score: 0.5376 - lr: 0.0010
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3175 - accuracy: 0.7750 - f1_score: 0.7733
# Epoch 25: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3110 - accuracy: 0.7794 - f1_score: 0.7800 - val_loss: 0.4224 - val_accuracy: 0.7623 - val_f1_score: 0.5502 - lr: 0.0010
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2470 - accuracy: 0.8260 - f1_score: 0.8250
# Epoch 26: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2433 - accuracy: 0.8283 - f1_score: 0.8284 - val_loss: 0.5333 - val_accuracy: 0.7315 - val_f1_score: 0.4618 - lr: 0.0010
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2540 - accuracy: 0.8188 - f1_score: 0.8173
# Epoch 27: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2532 - accuracy: 0.8194 - f1_score: 0.8183 - val_loss: 0.3784 - val_accuracy: 0.7531 - val_f1_score: 0.5970 - lr: 0.0010
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2736 - accuracy: 0.8062 - f1_score: 0.8041
# Epoch 28: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 31ms/step - loss: 0.2792 - accuracy: 0.8024 - f1_score: 0.7983 - val_loss: 0.4713 - val_accuracy: 0.7438 - val_f1_score: 0.5123 - lr: 0.0010
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2614 - accuracy: 0.8125 - f1_score: 0.8108
# Epoch 29: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2645 - accuracy: 0.8094 - f1_score: 0.8062 - val_loss: 0.5548 - val_accuracy: 0.7346 - val_f1_score: 0.4421 - lr: 0.0010
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2553 - accuracy: 0.8167 - f1_score: 0.8147
# Epoch 30: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2505 - accuracy: 0.8204 - f1_score: 0.8203 - val_loss: 0.3276 - val_accuracy: 0.7562 - val_f1_score: 0.6358 - lr: 0.0010
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2260 - accuracy: 0.8385 - f1_score: 0.8370
# Epoch 31: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2287 - accuracy: 0.8363 - f1_score: 0.8337 - val_loss: 0.3309 - val_accuracy: 0.7191 - val_f1_score: 0.6789 - lr: 0.0010
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2583 - accuracy: 0.8135 - f1_score: 0.8121
# Epoch 32: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2611 - accuracy: 0.8124 - f1_score: 0.8103 - val_loss: 0.4259 - val_accuracy: 0.7407 - val_f1_score: 0.5538 - lr: 0.0010
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2797 - accuracy: 0.8010 - f1_score: 0.7989
# Epoch 33: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2840 - accuracy: 0.7984 - f1_score: 0.7951 - val_loss: 0.5369 - val_accuracy: 0.7315 - val_f1_score: 0.4551 - lr: 0.0010
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3086 - accuracy: 0.7792 - f1_score: 0.7769
# Epoch 34: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 40ms/step - loss: 0.3121 - accuracy: 0.7764 - f1_score: 0.7728 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2881 - accuracy: 0.7958 - f1_score: 0.7925
# Epoch 35: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2837 - accuracy: 0.7994 - f1_score: 0.7980 - val_loss: 0.4342 - val_accuracy: 0.7253 - val_f1_score: 0.5461 - lr: 0.0010
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2513 - accuracy: 0.8219 - f1_score: 0.8206
# Epoch 36: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2520 - accuracy: 0.8214 - f1_score: 0.8198 - val_loss: 0.5454 - val_accuracy: 0.7191 - val_f1_score: 0.4505 - lr: 0.0010
# Epoch 37/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3134 - accuracy: 0.7802 - f1_score: 0.7762
# Epoch 37: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3085 - accuracy: 0.7834 - f1_score: 0.7810 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2564 - accuracy: 0.8177 - f1_score: 0.8163
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 38: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2526 - accuracy: 0.8204 - f1_score: 0.8202 - val_loss: 0.4534 - val_accuracy: 0.5802 - val_f1_score: 0.6206 - lr: 0.0010
# Epoch 39/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3204 - accuracy: 0.7698 - f1_score: 0.7672
# Epoch 39: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3191 - accuracy: 0.7715 - f1_score: 0.7694 - val_loss: 0.6162 - val_accuracy: 0.3920 - val_f1_score: 0.4040 - lr: 5.0000e-04
# Epoch 40/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2941 - accuracy: 0.7885 - f1_score: 0.7855
# Epoch 40: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2910 - accuracy: 0.7904 - f1_score: 0.7884 - val_loss: 0.3856 - val_accuracy: 0.7346 - val_f1_score: 0.5877 - lr: 5.0000e-04
# Epoch 41/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2211 - accuracy: 0.8438 - f1_score: 0.8429
# Epoch 41: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2160 - accuracy: 0.8473 - f1_score: 0.8482 - val_loss: 0.4249 - val_accuracy: 0.7315 - val_f1_score: 0.5504 - lr: 5.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.8483 - f1_score: 0.8462
# Epoch 42: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 37ms/step - loss: 0.2123 - accuracy: 0.8483 - f1_score: 0.8462 - val_loss: 0.4049 - val_accuracy: 0.7346 - val_f1_score: 0.5707 - lr: 5.0000e-04
# Epoch 43/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2089 - accuracy: 0.8479 - f1_score: 0.8472
# Epoch 43: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2043 - accuracy: 0.8513 - f1_score: 0.8523 - val_loss: 0.5041 - val_accuracy: 0.7407 - val_f1_score: 0.4832 - lr: 5.0000e-04
# Epoch 44/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2262 - accuracy: 0.8396 - f1_score: 0.8385
# Epoch 44: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2257 - accuracy: 0.8393 - f1_score: 0.8381 - val_loss: 0.4494 - val_accuracy: 0.7222 - val_f1_score: 0.5333 - lr: 5.0000e-04
# Epoch 45/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2051 - accuracy: 0.8510 - f1_score: 0.8504
# Epoch 45: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2019 - accuracy: 0.8533 - f1_score: 0.8538 - val_loss: 0.4061 - val_accuracy: 0.7315 - val_f1_score: 0.5680 - lr: 5.0000e-04
# Epoch 46/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2023 - accuracy: 0.8552 - f1_score: 0.8549
# Epoch 46: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2001 - accuracy: 0.8563 - f1_score: 0.8558 - val_loss: 0.3579 - val_accuracy: 0.7222 - val_f1_score: 0.6068 - lr: 5.0000e-04
# Epoch 47/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2064 - accuracy: 0.8552 - f1_score: 0.8537
# Epoch 47: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2072 - accuracy: 0.8543 - f1_score: 0.8525 - val_loss: 0.3704 - val_accuracy: 0.7253 - val_f1_score: 0.5976 - lr: 5.0000e-04
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2084 - accuracy: 0.8510 - f1_score: 0.8498
# Epoch 48: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2072 - accuracy: 0.8513 - f1_score: 0.8499 - val_loss: 0.3547 - val_accuracy: 0.7284 - val_f1_score: 0.6119 - lr: 5.0000e-04
# Epoch 49/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2090 - accuracy: 0.8500 - f1_score: 0.8485
# Epoch 49: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2088 - accuracy: 0.8503 - f1_score: 0.8490 - val_loss: 0.3452 - val_accuracy: 0.6975 - val_f1_score: 0.6672 - lr: 5.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.8613 - f1_score: 0.8589
# Epoch 50: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1953 - accuracy: 0.8613 - f1_score: 0.8589 - val_loss: 0.3302 - val_accuracy: 0.7284 - val_f1_score: 0.7229 - lr: 5.0000e-04
# Epoch 51/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1917 - accuracy: 0.8646 - f1_score: 0.8630
# Epoch 51: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1905 - accuracy: 0.8653 - f1_score: 0.8641 - val_loss: 0.3300 - val_accuracy: 0.7284 - val_f1_score: 0.6175 - lr: 5.0000e-04
# Epoch 52/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1837 - accuracy: 0.8687 - f1_score: 0.8671
# Epoch 52: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1894 - accuracy: 0.8653 - f1_score: 0.8619 - val_loss: 0.3482 - val_accuracy: 0.7346 - val_f1_score: 0.6179 - lr: 5.0000e-04
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.8750 - f1_score: 0.8746
# Epoch 53: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1716 - accuracy: 0.8752 - f1_score: 0.8750 - val_loss: 0.4160 - val_accuracy: 0.7099 - val_f1_score: 0.5592 - lr: 5.0000e-04
# Epoch 54/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1717 - accuracy: 0.8750 - f1_score: 0.8744
# Epoch 54: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1758 - accuracy: 0.8713 - f1_score: 0.8688 - val_loss: 0.3896 - val_accuracy: 0.6512 - val_f1_score: 0.6320 - lr: 5.0000e-04
# Epoch 55/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1817 - accuracy: 0.8698 - f1_score: 0.8686
# Epoch 55: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1831 - accuracy: 0.8693 - f1_score: 0.8678 - val_loss: 0.3283 - val_accuracy: 0.7284 - val_f1_score: 0.6197 - lr: 5.0000e-04
# Epoch 56/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1616 - accuracy: 0.8813 - f1_score: 0.8805
# Epoch 56: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1616 - accuracy: 0.8812 - f1_score: 0.8805 - val_loss: 0.3622 - val_accuracy: 0.7315 - val_f1_score: 0.6086 - lr: 5.0000e-04
# Epoch 57/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1827 - accuracy: 0.8708 - f1_score: 0.8695
# Epoch 57: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1795 - accuracy: 0.8733 - f1_score: 0.8731 - val_loss: 0.4162 - val_accuracy: 0.7130 - val_f1_score: 0.5606 - lr: 5.0000e-04
# Epoch 58/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1674 - accuracy: 0.8772 - f1_score: 0.8762
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 58: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1681 - accuracy: 0.8772 - f1_score: 0.8771 - val_loss: 0.4204 - val_accuracy: 0.7253 - val_f1_score: 0.5565 - lr: 5.0000e-04
# Epoch 59/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1637 - accuracy: 0.8833 - f1_score: 0.8821
# Epoch 59: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1620 - accuracy: 0.8842 - f1_score: 0.8831 - val_loss: 0.4078 - val_accuracy: 0.7222 - val_f1_score: 0.5657 - lr: 2.5000e-04
# Epoch 60/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1778 - accuracy: 0.8719 - f1_score: 0.8705
# Epoch 60: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1744 - accuracy: 0.8743 - f1_score: 0.8741 - val_loss: 0.4235 - val_accuracy: 0.7253 - val_f1_score: 0.5538 - lr: 2.5000e-04
# Epoch 61/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1751 - accuracy: 0.8760 - f1_score: 0.8751
# Epoch 61: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1734 - accuracy: 0.8772 - f1_score: 0.8769 - val_loss: 0.3960 - val_accuracy: 0.7191 - val_f1_score: 0.5768 - lr: 2.5000e-04
# Epoch 62/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1667 - accuracy: 0.8823 - f1_score: 0.8814
# Epoch 62: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1689 - accuracy: 0.8792 - f1_score: 0.8764 - val_loss: 0.3543 - val_accuracy: 0.7191 - val_f1_score: 0.5992 - lr: 2.5000e-04
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1590 - accuracy: 0.8865 - f1_score: 0.8854
# Epoch 63: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1537 - accuracy: 0.8902 - f1_score: 0.8910 - val_loss: 0.3775 - val_accuracy: 0.7099 - val_f1_score: 0.5783 - lr: 2.5000e-04
# Epoch 64/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1596 - accuracy: 0.8875 - f1_score: 0.8861
# Epoch 64: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1700 - accuracy: 0.8802 - f1_score: 0.8754 - val_loss: 0.4048 - val_accuracy: 0.7284 - val_f1_score: 0.5673 - lr: 2.5000e-04
# Epoch 65/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1587 - accuracy: 0.8873 - f1_score: 0.8860
# Epoch 65: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1662 - accuracy: 0.8832 - f1_score: 0.8822 - val_loss: 0.3847 - val_accuracy: 0.6975 - val_f1_score: 0.5715 - lr: 2.5000e-04
# Epoch 66/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1448 - accuracy: 0.8958 - f1_score: 0.8954
# Epoch 66: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1440 - accuracy: 0.8962 - f1_score: 0.8960 - val_loss: 0.3811 - val_accuracy: 0.7037 - val_f1_score: 0.5743 - lr: 2.5000e-04
# Epoch 67/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1425 - accuracy: 0.8990 - f1_score: 0.8981
# Epoch 67: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1467 - accuracy: 0.8952 - f1_score: 0.8925 - val_loss: 0.3756 - val_accuracy: 0.6667 - val_f1_score: 0.5791 - lr: 2.5000e-04
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1526 - accuracy: 0.8917 - f1_score: 0.8908
# Epoch 68: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1489 - accuracy: 0.8942 - f1_score: 0.8947 - val_loss: 0.3692 - val_accuracy: 0.6728 - val_f1_score: 0.5825 - lr: 2.5000e-04
# Epoch 69/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1417 - accuracy: 0.8990 - f1_score: 0.8980
# Epoch 69: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1374 - accuracy: 0.9022 - f1_score: 0.9028 - val_loss: 0.3620 - val_accuracy: 0.6975 - val_f1_score: 0.5901 - lr: 2.5000e-04
# Epoch 70/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1364 - accuracy: 0.9010 - f1_score: 0.9002
# Epoch 70: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1381 - accuracy: 0.9002 - f1_score: 0.8989 - val_loss: 0.3684 - val_accuracy: 0.7099 - val_f1_score: 0.5865 - lr: 2.5000e-04
# Epoch 71/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1385 - accuracy: 0.9010 - f1_score: 0.9001
# Epoch 71: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1368 - accuracy: 0.9022 - f1_score: 0.9019 - val_loss: 0.3668 - val_accuracy: 0.6883 - val_f1_score: 0.5837 - lr: 2.5000e-04
# Epoch 72/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1342 - accuracy: 0.9042 - f1_score: 0.9032
# Epoch 72: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1344 - accuracy: 0.9042 - f1_score: 0.9032 - val_loss: 0.3667 - val_accuracy: 0.7006 - val_f1_score: 0.5847 - lr: 2.5000e-04
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1320 - accuracy: 0.9062 - f1_score: 0.9053
# Epoch 73: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1359 - accuracy: 0.9042 - f1_score: 0.9019 - val_loss: 0.3647 - val_accuracy: 0.6944 - val_f1_score: 0.5887 - lr: 2.5000e-04
# Epoch 74/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1332 - accuracy: 0.9042 - f1_score: 0.9037
# Epoch 74: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1346 - accuracy: 0.9032 - f1_score: 0.9022 - val_loss: 0.3655 - val_accuracy: 0.6944 - val_f1_score: 0.5884 - lr: 2.5000e-04
# Epoch 75/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1352 - accuracy: 0.9042 - f1_score: 0.9037
# Epoch 75: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1335 - accuracy: 0.9052 - f1_score: 0.9052 - val_loss: 0.3936 - val_accuracy: 0.7284 - val_f1_score: 0.5802 - lr: 2.5000e-04
# Epoch 76/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1392 - accuracy: 0.9042 - f1_score: 0.9025
# Epoch 76: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1405 - accuracy: 0.9032 - f1_score: 0.9011 - val_loss: 0.3605 - val_accuracy: 0.7315 - val_f1_score: 0.5912 - lr: 2.5000e-04
# Epoch 77/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1374 - accuracy: 0.9031 - f1_score: 0.9019
# Epoch 77: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1344 - accuracy: 0.9052 - f1_score: 0.9050 - val_loss: 0.3857 - val_accuracy: 0.7191 - val_f1_score: 0.5777 - lr: 2.5000e-04
# Epoch 78/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9152 - f1_score: 0.9135
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 78: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1191 - accuracy: 0.9152 - f1_score: 0.9135 - val_loss: 0.3777 - val_accuracy: 0.7130 - val_f1_score: 0.5802 - lr: 2.5000e-04
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1330 - accuracy: 0.9052 - f1_score: 0.9044
# Epoch 79: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 31ms/step - loss: 0.1335 - accuracy: 0.9052 - f1_score: 0.9043 - val_loss: 0.3805 - val_accuracy: 0.6944 - val_f1_score: 0.5747 - lr: 1.2500e-04
# Epoch 80/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1275 - accuracy: 0.9083 - f1_score: 0.9067
# Epoch 80: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1276 - accuracy: 0.9082 - f1_score: 0.9065 - val_loss: 0.3792 - val_accuracy: 0.6914 - val_f1_score: 0.5745 - lr: 1.2500e-04
# Epoch 81/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1434 - accuracy: 0.8969 - f1_score: 0.8955
# Epoch 81: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1417 - accuracy: 0.8972 - f1_score: 0.8958 - val_loss: 0.3686 - val_accuracy: 0.6944 - val_f1_score: 0.5849 - lr: 1.2500e-04
# Epoch 82/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1224 - accuracy: 0.9115 - f1_score: 0.9109
# Epoch 82: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1188 - accuracy: 0.9142 - f1_score: 0.9150 - val_loss: 0.3595 - val_accuracy: 0.7160 - val_f1_score: 0.5964 - lr: 1.2500e-04
# Epoch 83/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1288 - accuracy: 0.9073 - f1_score: 0.9065
# Epoch 83: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1273 - accuracy: 0.9082 - f1_score: 0.9078 - val_loss: 0.3659 - val_accuracy: 0.7037 - val_f1_score: 0.5870 - lr: 1.2500e-04
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1094 - accuracy: 0.9208 - f1_score: 0.9201
# Epoch 84: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1173 - accuracy: 0.9172 - f1_score: 0.9136 - val_loss: 0.3907 - val_accuracy: 0.6852 - val_f1_score: 0.5615 - lr: 1.2500e-04
# Epoch 85/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1322 - accuracy: 0.9062 - f1_score: 0.9049
# Epoch 85: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1311 - accuracy: 0.9072 - f1_score: 0.9064 - val_loss: 0.4014 - val_accuracy: 0.6852 - val_f1_score: 0.5567 - lr: 1.2500e-04
# Epoch 86/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1362 - accuracy: 0.9021 - f1_score: 0.9008
# Epoch 86: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1389 - accuracy: 0.9002 - f1_score: 0.8979 - val_loss: 0.3675 - val_accuracy: 0.6944 - val_f1_score: 0.5873 - lr: 1.2500e-04
# Epoch 87/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1260 - accuracy: 0.9115 - f1_score: 0.9101
# Epoch 87: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1234 - accuracy: 0.9132 - f1_score: 0.9127 - val_loss: 0.3616 - val_accuracy: 0.7006 - val_f1_score: 0.5910 - lr: 1.2500e-04
# Epoch 88/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1270 - accuracy: 0.9094 - f1_score: 0.9083
# Epoch 88: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1258 - accuracy: 0.9102 - f1_score: 0.9095 - val_loss: 0.3600 - val_accuracy: 0.7037 - val_f1_score: 0.5891 - lr: 1.2500e-04
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1264 - accuracy: 0.9104 - f1_score: 0.9094
# Epoch 89: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1255 - accuracy: 0.9112 - f1_score: 0.9106 - val_loss: 0.3808 - val_accuracy: 0.7068 - val_f1_score: 0.5787 - lr: 1.2500e-04
# Epoch 90/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1193 - accuracy: 0.9156 - f1_score: 0.9146
# Epoch 90: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1210 - accuracy: 0.9142 - f1_score: 0.9125 - val_loss: 0.3878 - val_accuracy: 0.6914 - val_f1_score: 0.5656 - lr: 1.2500e-04
# Epoch 91/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9142 - f1_score: 0.9123
# Epoch 91: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1198 - accuracy: 0.9142 - f1_score: 0.9123 - val_loss: 0.3788 - val_accuracy: 0.7006 - val_f1_score: 0.5799 - lr: 1.2500e-04
# Epoch 92/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1393 - accuracy: 0.8990 - f1_score: 0.8976
# Epoch 92: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1383 - accuracy: 0.9002 - f1_score: 0.8993 - val_loss: 0.3788 - val_accuracy: 0.6914 - val_f1_score: 0.5771 - lr: 1.2500e-04
# Epoch 93/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1421 - accuracy: 0.9000 - f1_score: 0.8979
# Epoch 93: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1424 - accuracy: 0.8992 - f1_score: 0.8967 - val_loss: 0.3813 - val_accuracy: 0.6914 - val_f1_score: 0.5737 - lr: 1.2500e-04
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1243 - accuracy: 0.9104 - f1_score: 0.9095
# Epoch 94: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1258 - accuracy: 0.9092 - f1_score: 0.9075 - val_loss: 0.3796 - val_accuracy: 0.6914 - val_f1_score: 0.5727 - lr: 1.2500e-04
# Epoch 95/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1229 - accuracy: 0.9125 - f1_score: 0.9122
# Epoch 95: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1203 - accuracy: 0.9142 - f1_score: 0.9146 - val_loss: 0.4010 - val_accuracy: 0.7037 - val_f1_score: 0.5586 - lr: 1.2500e-04
# Epoch 96/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1291 - accuracy: 0.9094 - f1_score: 0.9081
# Epoch 96: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1296 - accuracy: 0.9082 - f1_score: 0.9060 - val_loss: 0.3806 - val_accuracy: 0.7006 - val_f1_score: 0.5745 - lr: 1.2500e-04
# Epoch 97/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1150 - accuracy: 0.9177 - f1_score: 0.9170
# Epoch 97: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1173 - accuracy: 0.9162 - f1_score: 0.9147 - val_loss: 0.4056 - val_accuracy: 0.6975 - val_f1_score: 0.5537 - lr: 1.2500e-04
# Epoch 98/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1147 - accuracy: 0.9177 - f1_score: 0.9172
# Epoch 98: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 98: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1125 - accuracy: 0.9192 - f1_score: 0.9194 - val_loss: 0.4023 - val_accuracy: 0.7006 - val_f1_score: 0.5524 - lr: 1.2500e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1088 - accuracy: 0.9208 - f1_score: 0.9201
# Epoch 99: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1057 - accuracy: 0.9232 - f1_score: 0.9236 - val_loss: 0.4041 - val_accuracy: 0.6944 - val_f1_score: 0.5534 - lr: 6.2500e-05
# Epoch 100/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1137 - accuracy: 0.9177 - f1_score: 0.9169
# Epoch 100: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 32ms/step - loss: 0.1168 - accuracy: 0.9162 - f1_score: 0.9144 - val_loss: 0.4024 - val_accuracy: 0.6914 - val_f1_score: 0.5559 - lr: 6.2500e-05
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1271 - accuracy: 0.9083 - f1_score: 0.9070
# Epoch 101: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1266 - accuracy: 0.9092 - f1_score: 0.9081 - val_loss: 0.3939 - val_accuracy: 0.6944 - val_f1_score: 0.5636 - lr: 6.2500e-05
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1092 - accuracy: 0.9219 - f1_score: 0.9208
# Epoch 102: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1104 - accuracy: 0.9212 - f1_score: 0.9198 - val_loss: 0.3905 - val_accuracy: 0.6975 - val_f1_score: 0.5681 - lr: 6.2500e-05
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1084 - accuracy: 0.9208 - f1_score: 0.9206
# Epoch 103: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1083 - accuracy: 0.9212 - f1_score: 0.9210 - val_loss: 0.3858 - val_accuracy: 0.7006 - val_f1_score: 0.5732 - lr: 6.2500e-05
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1156 - accuracy: 0.9156 - f1_score: 0.9152
# Epoch 104: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1170 - accuracy: 0.9142 - f1_score: 0.9125 - val_loss: 0.3855 - val_accuracy: 0.6944 - val_f1_score: 0.5690 - lr: 6.2500e-05
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1208 - accuracy: 0.9156 - f1_score: 0.9141
# Epoch 105: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1197 - accuracy: 0.9162 - f1_score: 0.9150 - val_loss: 0.3884 - val_accuracy: 0.7006 - val_f1_score: 0.5732 - lr: 6.2500e-05
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1172 - accuracy: 0.9208 - f1_score: 0.9193
# Epoch 106: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1164 - accuracy: 0.9212 - f1_score: 0.9199 - val_loss: 0.3798 - val_accuracy: 0.6975 - val_f1_score: 0.5736 - lr: 6.2500e-05
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1232 - accuracy: 0.9115 - f1_score: 0.9106
# Epoch 107: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1206 - accuracy: 0.9132 - f1_score: 0.9132 - val_loss: 0.3775 - val_accuracy: 0.6975 - val_f1_score: 0.5770 - lr: 6.2500e-05
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1305 - accuracy: 0.9052 - f1_score: 0.9037
# Epoch 108: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1252 - accuracy: 0.9092 - f1_score: 0.9097 - val_loss: 0.3816 - val_accuracy: 0.7006 - val_f1_score: 0.5765 - lr: 6.2500e-05
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1111 - accuracy: 0.9219 - f1_score: 0.9209
# Epoch 109: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1104 - accuracy: 0.9222 - f1_score: 0.9213 - val_loss: 0.4018 - val_accuracy: 0.6914 - val_f1_score: 0.5573 - lr: 6.2500e-05
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1039 - accuracy: 0.9260 - f1_score: 0.9255
# Epoch 110: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1048 - accuracy: 0.9251 - f1_score: 0.9242 - val_loss: 0.4022 - val_accuracy: 0.6914 - val_f1_score: 0.5555 - lr: 6.2500e-05
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1082 - accuracy: 0.9229 - f1_score: 0.9226
# Epoch 111: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1079 - accuracy: 0.9232 - f1_score: 0.9229 - val_loss: 0.4022 - val_accuracy: 0.6914 - val_f1_score: 0.5573 - lr: 6.2500e-05
# Epoch 112/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1103 - accuracy: 0.9219 - f1_score: 0.9213
# Epoch 112: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1084 - accuracy: 0.9232 - f1_score: 0.9232 - val_loss: 0.4006 - val_accuracy: 0.6883 - val_f1_score: 0.5562 - lr: 6.2500e-05
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1372 - accuracy: 0.9000 - f1_score: 0.8983
# Epoch 113: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1315 - accuracy: 0.9042 - f1_score: 0.9047 - val_loss: 0.3841 - val_accuracy: 0.7006 - val_f1_score: 0.5754 - lr: 6.2500e-05
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1103 - accuracy: 0.9208 - f1_score: 0.9199
# Epoch 114: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1115 - accuracy: 0.9202 - f1_score: 0.9189 - val_loss: 0.3659 - val_accuracy: 0.7037 - val_f1_score: 0.5915 - lr: 6.2500e-05
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1059 - accuracy: 0.9229 - f1_score: 0.9225
# Epoch 115: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1086 - accuracy: 0.9202 - f1_score: 0.9181 - val_loss: 0.3890 - val_accuracy: 0.6883 - val_f1_score: 0.5652 - lr: 6.2500e-05
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1227 - accuracy: 0.9115 - f1_score: 0.9105
# Epoch 116: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1192 - accuracy: 0.9142 - f1_score: 0.9145 - val_loss: 0.3787 - val_accuracy: 0.6914 - val_f1_score: 0.5751 - lr: 6.2500e-05
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1186 - accuracy: 0.9146 - f1_score: 0.9139
# Epoch 117: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1188 - accuracy: 0.9142 - f1_score: 0.9132 - val_loss: 0.3759 - val_accuracy: 0.6914 - val_f1_score: 0.5751 - lr: 6.2500e-05
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1180 - accuracy: 0.9156 - f1_score: 0.9144Restoring model weights from the end of the best epoch: 18.
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 118: val_f1_score did not improve from 0.73829
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1145 - accuracy: 0.9182 - f1_score: 0.9182 - val_loss: 0.3868 - val_accuracy: 0.6944 - val_f1_score: 0.5671 - lr: 6.2500e-05
# Epoch 118: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 5ms/step
# 0.7438271604938271

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7438271604938271
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.51      0.62      0.56        85
#            0       0.85      0.79      0.82       239
#
#     accuracy                           0.74       324
#    macro avg       0.68      0.71      0.69       324
# weighted avg       0.76      0.74      0.75       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 241 chiếm khoảng 74.38271604938271% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 53 chiếm khoảng 62.35294117647059% so với thực tế
