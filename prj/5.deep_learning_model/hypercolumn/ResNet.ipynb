# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_loss',
    min_delta=0.00005,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_loss',  # Theo dõi val_loss
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
from tensorflow.keras.models import Model
from scikeras.wrappers import KerasClassifier 

def build_model(filters1, filters2, filters3):
    input_shape = (42, 1)
    x_input = Input(shape=input_shape)

    bn_axis = -1

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
    block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

    # Hypercolumn formation
    hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
                                GlobalAveragePooling1D()(block2_output),
                                GlobalAveragePooling1D()(x)], axis=-1)

    # Final Dense layers
    x = Dense(128, activation='relu')(hypercolumns)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

    # Compile model
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
    return model

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3,filters4,filters5):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

#     x = conv_block(x, 3,[filters3, filters3, filters4], stage=4, block='a')
#     block3_output = identity_block(x, 3,[filters3, filters3, filters4], stage=4, block='b')
#     x = identity_block(block3_output, 3,[filters3, filters3, filters4], stage=4, block='c')
#     x = identity_block(x, 3,[filters3, filters3, filters4], stage=4, block='d')
#     x = identity_block(x, 3,[filters3, filters3, filters4], stage=4, block='e')
#     x = identity_block(x, 3,[filters3, filters3, filters4], stage=4, block='f')

#     x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
#     block4_output = identity_block(x, 3,  [filters4, filters4, filters5], stage=5, block='b')
#     x = identity_block(block4_output, 3,  [filters4, filters4, filters5], stage=5, block='c')

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(block3_output),
#                                 GlobalAveragePooling1D()(block4_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.001), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
#     return model

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer

# # Wrap Keras model so it can be used by scikit-learn
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# # Define the grid of hyperparameters to search
# param_grid = {
#     'model__filters1': [32, 64, 96],
#     'model__filters2': [96, 128, 192],
#     'model__filters3': [192, 256, 384],
# }

# # Create a scorer using make_scorer
# f1_scorer = make_scorer(f1_score, average='macro')

# # Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)

# # Load your data here
# # X_train, y_train = ...
# # X_val, y_val = ...

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(96,192,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d_hypercolumn"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]              0         []
#
#  zero_padding1d (ZeroPaddin  (None, 44, 1)                0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 22, 64)               512       ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 22, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 22, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 10, 96)               6240      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 10, 96)               40        ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 10, 96)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 10, 96)               27744     ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 10, 96)               40        ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 10, 96)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 10, 192)              18624     ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 10, 192)              12480     ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 10, 192)              40        ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 10, 192)              40        ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 10, 192)              0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 10, 192)              0         ['add[0][0]']
#
#  res2b_branch2a (Conv1D)     (None, 10, 96)               18528     ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 10, 96)               40        ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 10, 96)               0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)     (None, 10, 96)               27744     ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 10, 96)               40        ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 10, 96)               0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)     (None, 10, 192)              18624     ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 10, 192)              40        ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 10, 192)              0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 10, 192)              0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)     (None, 10, 96)               18528     ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 10, 96)               40        ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 10, 96)               0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)     (None, 10, 96)               27744     ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 10, 96)               40        ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 10, 96)               0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)     (None, 10, 192)              18624     ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 10, 192)              40        ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 10, 192)              0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 10, 192)              0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 5, 192)               37056     ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 5, 192)               20        ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 5, 192)               0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 5, 192)               110784    ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 5, 192)               20        ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 5, 192)               0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 5, 384)               74112     ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 5, 384)               74112     ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 5, 384)               20        ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 5, 384)               20        ['res3a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 5, 384)               0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 5, 384)               0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)     (None, 5, 192)               73920     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 5, 192)               20        ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 5, 192)               0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)     (None, 5, 192)               110784    ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 5, 192)               20        ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 5, 192)               0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)     (None, 5, 384)               74112     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 5, 384)               20        ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 5, 384)               0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 5, 384)               0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)     (None, 5, 192)               73920     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 5, 192)               20        ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 5, 192)               0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)     (None, 5, 192)               110784    ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 5, 192)               20        ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 5, 192)               0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)     (None, 5, 384)               74112     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 5, 384)               20        ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 5, 384)               0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 5, 384)               0         ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)     (None, 5, 192)               73920     ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormal  (None, 5, 192)               20        ['res3d_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 5, 192)               0         ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)     (None, 5, 192)               110784    ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormal  (None, 5, 192)               20        ['res3d_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 5, 192)               0         ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)     (None, 5, 384)               74112     ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormal  (None, 5, 384)               20        ['res3d_branch2c[0][0]']
#  ization)
#
#  add_6 (Add)                 (None, 5, 384)               0         ['bn3d_branch2c[0][0]',
#                                                                      'activation_18[0][0]']
#
#  activation_21 (Activation)  (None, 5, 384)               0         ['add_6[0][0]']
#
#  global_average_pooling1d (  (None, 192)                  0         ['activation_6[0][0]']
#  GlobalAveragePooling1D)
#
#  global_average_pooling1d_1  (None, 384)                  0         ['activation_15[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_average_pooling1d_2  (None, 384)                  0         ['activation_21[0][0]']
#   (GlobalAveragePooling1D)
#
#  concatenate (Concatenate)   (None, 960)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'global_average_pooling1d_1[0
#                                                                     ][0]',
#                                                                      'global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  dense (Dense)               (None, 128)                  123008    ['concatenate[0][0]']
#
#  fc1000 (Dense)              (None, 2)                    258       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 1392086 (5.31 MB)
# Trainable params: 1391628 (5.31 MB)
# Non-trainable params: 458 (1.79 KB)
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.8457 - accuracy: 0.5010 - f1_score: 0.5010
# Epoch 1: val_loss improved from inf to 0.69886, saving model to best_model.h5
# 16/16 [==============================] - 9s 84ms/step - loss: 0.8457 - accuracy: 0.5040 - f1_score: 0.5054 - val_loss: 0.6989 - val_accuracy: 0.3611 - val_f1_score: 0.4219 - lr: 1.0000e-04
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7388 - accuracy: 0.5115 - f1_score: 0.5115
# Epoch 2: val_loss improved from 0.69886 to 0.69373, saving model to best_model.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.7323 - accuracy: 0.5180 - f1_score: 0.5212 - val_loss: 0.6937 - val_accuracy: 0.4877 - val_f1_score: 0.5286 - lr: 1.0000e-04
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6637 - accuracy: 0.5427 - f1_score: 0.5427
# Epoch 3: val_loss improved from 0.69373 to 0.66553, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.6638 - accuracy: 0.5459 - f1_score: 0.5475 - val_loss: 0.6655 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 1.0000e-04
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5947 - accuracy: 0.6208 - f1_score: 0.6208
# Epoch 4: val_loss improved from 0.66553 to 0.62584, saving model to best_model.h5
# 16/16 [==============================] - 1s 42ms/step - loss: 0.5961 - accuracy: 0.6218 - f1_score: 0.6222 - val_loss: 0.6258 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5341 - accuracy: 0.6844 - f1_score: 0.6844
# Epoch 5: val_loss improved from 0.62584 to 0.60578, saving model to best_model.h5
# 16/16 [==============================] - 1s 44ms/step - loss: 0.5345 - accuracy: 0.6826 - f1_score: 0.6818 - val_loss: 0.6058 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5520 - accuracy: 0.7208 - f1_score: 0.7208
# Epoch 6: val_loss did not improve from 0.60578
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5566 - accuracy: 0.7216 - f1_score: 0.7219 - val_loss: 0.6066 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 1.0000e-04
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4548 - accuracy: 0.7417 - f1_score: 0.7417
# Epoch 7: val_loss improved from 0.60578 to 0.60551, saving model to best_model.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.4540 - accuracy: 0.7495 - f1_score: 0.7533 - val_loss: 0.6055 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 8/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3878 - accuracy: 0.7792 - f1_score: 0.7792
# Epoch 8: val_loss did not improve from 0.60551
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3909 - accuracy: 0.7735 - f1_score: 0.7706 - val_loss: 0.6282 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 1.0000e-04
# Epoch 9/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3108 - accuracy: 0.8490 - f1_score: 0.8490
# Epoch 9: val_loss improved from 0.60551 to 0.59123, saving model to best_model.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.3133 - accuracy: 0.8533 - f1_score: 0.8554 - val_loss: 0.5912 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 1.0000e-04
# Epoch 10/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3400 - accuracy: 0.8240 - f1_score: 0.8240
# Epoch 10: val_loss did not improve from 0.59123
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3378 - accuracy: 0.8244 - f1_score: 0.8245 - val_loss: 0.6396 - val_accuracy: 0.6574 - val_f1_score: 0.6719 - lr: 1.0000e-04
# Epoch 11/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2578 - accuracy: 0.8740 - f1_score: 0.8740
# Epoch 11: val_loss did not improve from 0.59123
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2594 - accuracy: 0.8743 - f1_score: 0.8744 - val_loss: 0.5990 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 1.0000e-04
# Epoch 12/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1457 - accuracy: 0.9375 - f1_score: 0.9375
# Epoch 12: val_loss did not improve from 0.59123
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1494 - accuracy: 0.9361 - f1_score: 0.9355 - val_loss: 0.5953 - val_accuracy: 0.7068 - val_f1_score: 0.7135 - lr: 1.0000e-04
# Epoch 13/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1112 - accuracy: 0.9583 - f1_score: 0.9583
# Epoch 13: val_loss did not improve from 0.59123
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1114 - accuracy: 0.9581 - f1_score: 0.9580 - val_loss: 0.6267 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 1.0000e-04
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0889 - accuracy: 0.9625 - f1_score: 0.9625
# Epoch 14: val_loss did not improve from 0.59123
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0871 - accuracy: 0.9641 - f1_score: 0.9648 - val_loss: 0.6307 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 1.0000e-04
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1055 - accuracy: 0.9510 - f1_score: 0.9510
# Epoch 15: val_loss improved from 0.59123 to 0.59050, saving model to best_model.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1050 - accuracy: 0.9521 - f1_score: 0.9526 - val_loss: 0.5905 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 1.0000e-04
# Epoch 16/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0579 - accuracy: 0.9823 - f1_score: 0.9823
# Epoch 16: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0567 - accuracy: 0.9830 - f1_score: 0.9834 - val_loss: 0.6087 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 1.0000e-04
# Epoch 17/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0300 - accuracy: 0.9885 - f1_score: 0.9885
# Epoch 17: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0297 - accuracy: 0.9890 - f1_score: 0.9893 - val_loss: 0.6557 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 1.0000e-04
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0341 - accuracy: 0.9875 - f1_score: 0.9875
# Epoch 18: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0330 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 0.6997 - val_accuracy: 0.6698 - val_f1_score: 0.7214 - lr: 1.0000e-04
# Epoch 19/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 19: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0158 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.7459 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 1.0000e-04
# Epoch 20/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0410 - accuracy: 0.9833 - f1_score: 0.9833
# Epoch 20: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0412 - accuracy: 0.9840 - f1_score: 0.9844 - val_loss: 0.8699 - val_accuracy: 0.6451 - val_f1_score: 0.7005 - lr: 1.0000e-04
# Epoch 21/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0946 - accuracy: 0.9625 - f1_score: 0.9625
# Epoch 21: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0919 - accuracy: 0.9631 - f1_score: 0.9634 - val_loss: 1.1183 - val_accuracy: 0.5556 - val_f1_score: 0.6250 - lr: 1.0000e-04
# Epoch 22/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0536 - accuracy: 0.9781 - f1_score: 0.9781
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 22: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0533 - accuracy: 0.9790 - f1_score: 0.9795 - val_loss: 1.0995 - val_accuracy: 0.5802 - val_f1_score: 0.6458 - lr: 1.0000e-04
# Epoch 23/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0473 - accuracy: 0.9833 - f1_score: 0.9833
# Epoch 23: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0461 - accuracy: 0.9840 - f1_score: 0.9844 - val_loss: 0.9653 - val_accuracy: 0.6420 - val_f1_score: 0.6979 - lr: 5.0000e-05
# Epoch 24/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0169 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 24: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0165 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 1.0590 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 5.0000e-05
# Epoch 25/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0068 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 25: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0069 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 1.1484 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 5.0000e-05
# Epoch 26/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 26: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0052 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.2132 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 5.0000e-05
# Epoch 27/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 27: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0044 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.2992 - val_accuracy: 0.6358 - val_f1_score: 0.6927 - lr: 5.0000e-05
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 28: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0038 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.3256 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 5.0000e-05
# Epoch 29/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 29: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.3502 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 5.0000e-05
# Epoch 30/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 30: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.3902 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 2.5000e-05
# Epoch 31/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 31: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.4286 - val_accuracy: 0.6698 - val_f1_score: 0.7214 - lr: 2.5000e-05
# Epoch 32/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 32: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.4640 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 2.5000e-05
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 33: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.4958 - val_accuracy: 0.6667 - val_f1_score: 0.7188 - lr: 2.5000e-05
# Epoch 34/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 34: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.5251 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 2.5000e-05
# Epoch 35/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 15.
#
# Epoch 35: val_loss did not improve from 0.59050
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.5490 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 2.5000e-05
# Epoch 35: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 5ms/step
# 0.7407407407407407

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7407407407407407
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.53      0.11      0.18        85
#            0       0.75      0.97      0.85       239
#
#     accuracy                           0.74       324
#    macro avg       0.64      0.54      0.51       324
# weighted avg       0.69      0.74      0.67       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 240 chiếm khoảng 74.07407407407408% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 9 chiếm khoảng 10.588235294117647% so với thực tế
