# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
from sklearn.metrics import f1_score
import tensorflow as tf
def f1_loss(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
    possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return 1 - f1

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
from keras import backend as K

def f1_score(y_true, y_pred):
    """
    F1 score metric.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_score

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=30,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
from tensorflow.keras.models import Model
from scikeras.wrappers import KerasClassifier 

def build_model(learning_rate, filters1, filters2, filters3):
    input_shape = (42, 1)
    x_input = Input(shape=input_shape)

    bn_axis = -1

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
    block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

    # Hypercolumn formation
    hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
                                GlobalAveragePooling1D()(block2_output),
                                GlobalAveragePooling1D()(x)], axis=-1)

    # Final Dense layers
    x = Dense(128, activation='relu')(hypercolumns)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

    # Compile model
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
    
    return model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# Wrap Keras model so it can be used by scikit-learn
model = KerasClassifier(build_fn=build_model, verbose=0)

# Define the grid of hyperparameters to search
param_grid = {
    'model__learning_rate': [0.001, 0.0001],
    'model__filters1': [64, 96, 128],
    'model__filters2': [128, 192, 256],
    'model__filters3': [256, 384, 512],
    'batch_size': [16, 64]
}

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='weighted')

# Setup GridSearchCV with the f1_scorer
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer, n_jobs=-1, cv=3)

# Load your data here
# X_train, y_train = ...
# X_val, y_val = ...

# Run grid search
grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, std, param))
# Out:
# Failed to interrupt the Kernel.
#
# Unable to start Kernel '.conda (Python 3.8.18)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
resNet50.fit(x=dict_data[data_order][0],y=dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 4s 53ms/step - loss: 0.6339 - accuracy: 0.6238 - f1_score: 0.6242 - val_loss: 0.4527 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 2/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5422 - accuracy: 0.6856 - f1_score: 0.6878 - val_loss: 0.4167 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 3/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.4915 - accuracy: 0.6936 - f1_score: 0.6935 - val_loss: 0.3701 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 4/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4513 - accuracy: 0.7136 - f1_score: 0.7141 - val_loss: 0.3531 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 5/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.4239 - accuracy: 0.7335 - f1_score: 0.7326 - val_loss: 0.3360 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 6/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3956 - accuracy: 0.7510 - f1_score: 0.7510
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.499999760009814e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4004 - accuracy: 0.7445 - f1_score: 0.7413 - val_loss: 0.3146 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 1.0000e-04
# Epoch 7/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3846 - accuracy: 0.7585 - f1_score: 0.7560 - val_loss: 0.3138 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.5000e-05
# Epoch 8/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.3738 - accuracy: 0.7635 - f1_score: 0.7619 - val_loss: 0.3133 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.5000e-05
# Epoch 9/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3587 - accuracy: 0.7695 - f1_score: 0.7713 - val_loss: 0.3024 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.5000e-05
# Epoch 10/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3388 - accuracy: 0.7944 - f1_score: 0.7942 - val_loss: 0.2903 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.5000e-05
# Epoch 11/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3236 - accuracy: 0.7974 - f1_score: 0.7977 - val_loss: 0.2873 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.5000e-05
# Epoch 12/10000
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3088 - accuracy: 0.8074 - f1_score: 0.8049 - val_loss: 0.2847 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.5000e-05
# Epoch 13/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3148 - accuracy: 0.7994 - f1_score: 0.7996 - val_loss: 0.2950 - val_accuracy: 0.7438 - val_f1_score: 0.7448 - lr: 9.5000e-05
# Epoch 14/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2801 - accuracy: 0.8273 - f1_score: 0.8270 - val_loss: 0.3003 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 9.5000e-05
# Epoch 15/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3031 - accuracy: 0.8094 - f1_score: 0.8094 - val_loss: 0.3057 - val_accuracy: 0.7284 - val_f1_score: 0.7318 - lr: 9.5000e-05
# Epoch 16/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2670 - accuracy: 0.8363 - f1_score: 0.8373 - val_loss: 0.2847 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.5000e-05
# Epoch 17/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2540 - accuracy: 0.8473 - f1_score: 0.8480 - val_loss: 0.2835 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.5000e-05
# Epoch 18/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2386 - accuracy: 0.8604 - f1_score: 0.8604
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.02499959920533e-05.
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2382 - accuracy: 0.8623 - f1_score: 0.8632 - val_loss: 0.2927 - val_accuracy: 0.7346 - val_f1_score: 0.7370 - lr: 9.5000e-05
# Epoch 19/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2245 - accuracy: 0.8683 - f1_score: 0.8690 - val_loss: 0.2832 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 9.0250e-05
# Epoch 20/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2197 - accuracy: 0.8683 - f1_score: 0.8701 - val_loss: 0.3237 - val_accuracy: 0.6975 - val_f1_score: 0.7057 - lr: 9.0250e-05
# Epoch 21/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2403 - accuracy: 0.8463 - f1_score: 0.8460 - val_loss: 0.2891 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 9.0250e-05
# Epoch 22/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2075 - accuracy: 0.8782 - f1_score: 0.8788 - val_loss: 0.2831 - val_accuracy: 0.7315 - val_f1_score: 0.7344 - lr: 9.0250e-05
# Epoch 23/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2047 - accuracy: 0.8761 - f1_score: 0.8761
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.573749619245064e-05.
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2089 - accuracy: 0.8743 - f1_score: 0.8749 - val_loss: 0.2735 - val_accuracy: 0.7377 - val_f1_score: 0.7396 - lr: 9.0250e-05
# Epoch 24/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1999 - accuracy: 0.8832 - f1_score: 0.8837 - val_loss: 0.2835 - val_accuracy: 0.7222 - val_f1_score: 0.7266 - lr: 8.5737e-05
# Epoch 25/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1871 - accuracy: 0.8832 - f1_score: 0.8816 - val_loss: 0.3033 - val_accuracy: 0.7006 - val_f1_score: 0.7083 - lr: 8.5737e-05
# Epoch 26/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1751 - accuracy: 0.8922 - f1_score: 0.8930 - val_loss: 0.2859 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 8.5737e-05
# Epoch 27/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1616 - accuracy: 0.9042 - f1_score: 0.9052 - val_loss: 0.3357 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 8.5737e-05
# Epoch 28/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1617 - accuracy: 0.9146 - f1_score: 0.9146
# Epoch 28: ReduceLROnPlateau reducing learning rate to 8.145062311086804e-05.
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1625 - accuracy: 0.9132 - f1_score: 0.9125 - val_loss: 0.2875 - val_accuracy: 0.7099 - val_f1_score: 0.7161 - lr: 8.5737e-05
# Epoch 29/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1524 - accuracy: 0.9172 - f1_score: 0.9154 - val_loss: 0.2873 - val_accuracy: 0.7130 - val_f1_score: 0.7187 - lr: 8.1451e-05
# Epoch 30/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1561 - accuracy: 0.9132 - f1_score: 0.9115 - val_loss: 0.3013 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 8.1451e-05
# Epoch 31/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1417 - accuracy: 0.9202 - f1_score: 0.9188 - val_loss: 0.3565 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 8.1451e-05
# Epoch 32/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1455 - accuracy: 0.9232 - f1_score: 0.9228 - val_loss: 0.2776 - val_accuracy: 0.7253 - val_f1_score: 0.7292 - lr: 8.1451e-05
# Epoch 33/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1397 - accuracy: 0.9229 - f1_score: 0.9229
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.737808919046074e-05.
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1368 - accuracy: 0.9242 - f1_score: 0.9248 - val_loss: 0.3009 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 8.1451e-05
# Epoch 34/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1475 - accuracy: 0.9142 - f1_score: 0.9129 - val_loss: 0.2653 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 7.7378e-05
# Epoch 35/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1437 - accuracy: 0.9202 - f1_score: 0.9209 - val_loss: 0.3017 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 7.7378e-05
# Epoch 36/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1244 - accuracy: 0.9321 - f1_score: 0.9326 - val_loss: 0.3019 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 7.7378e-05
# Epoch 37/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1130 - accuracy: 0.9381 - f1_score: 0.9364 - val_loss: 0.2884 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 7.7378e-05
# Epoch 38/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1072 - accuracy: 0.9408 - f1_score: 0.9408
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.350918749580159e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1082 - accuracy: 0.9401 - f1_score: 0.9399 - val_loss: 0.3038 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 7.7378e-05
# Epoch 39/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1110 - accuracy: 0.9441 - f1_score: 0.9443 - val_loss: 0.2947 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 7.3509e-05
# Epoch 40/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1025 - accuracy: 0.9461 - f1_score: 0.9462 - val_loss: 0.3080 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 7.3509e-05
# Epoch 41/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1292 - accuracy: 0.9331 - f1_score: 0.9335 - val_loss: 0.2854 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 7.3509e-05
# Epoch 42/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1133 - accuracy: 0.9331 - f1_score: 0.9315 - val_loss: 0.3120 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 7.3509e-05
# Epoch 43/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1200 - accuracy: 0.9286 - f1_score: 0.9286
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.983372950344346e-05.
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1190 - accuracy: 0.9321 - f1_score: 0.9336 - val_loss: 0.3316 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 7.3509e-05
# Epoch 44/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1067 - accuracy: 0.9431 - f1_score: 0.9418 - val_loss: 0.2958 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 6.9834e-05
# Epoch 45/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0962 - accuracy: 0.9471 - f1_score: 0.9482 - val_loss: 0.2792 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 6.9834e-05
# Epoch 46/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0908 - accuracy: 0.9501 - f1_score: 0.9481 - val_loss: 0.3167 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 6.9834e-05
# Epoch 47/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0807 - accuracy: 0.9611 - f1_score: 0.9609 - val_loss: 0.3428 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 6.9834e-05
# Epoch 48/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0824 - accuracy: 0.9615 - f1_score: 0.9615
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.634204510191921e-05.
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0851 - accuracy: 0.9601 - f1_score: 0.9594 - val_loss: 0.2939 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 6.9834e-05
# Epoch 49/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0785 - accuracy: 0.9601 - f1_score: 0.9609 - val_loss: 0.3111 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 6.6342e-05
# Epoch 50/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0772 - accuracy: 0.9631 - f1_score: 0.9639 - val_loss: 0.2752 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 6.6342e-05
# Epoch 51/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1082 - accuracy: 0.9421 - f1_score: 0.9423 - val_loss: 0.3727 - val_accuracy: 0.6481 - val_f1_score: 0.7031 - lr: 6.6342e-05
# Epoch 52/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0807 - accuracy: 0.9581 - f1_score: 0.9580 - val_loss: 0.3243 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 6.6342e-05
# Epoch 53/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0746 - accuracy: 0.9625 - f1_score: 0.9625
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.302494111878331e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0738 - accuracy: 0.9631 - f1_score: 0.9634 - val_loss: 0.2789 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 6.6342e-05
# Epoch 54/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0737 - accuracy: 0.9641 - f1_score: 0.9643 - val_loss: 0.2645 - val_accuracy: 0.7407 - val_f1_score: 0.7422 - lr: 6.3025e-05
# Epoch 55/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0702 - accuracy: 0.9691 - f1_score: 0.9697 - val_loss: 0.3303 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 6.3025e-05
# Epoch 56/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0575 - accuracy: 0.9731 - f1_score: 0.9736 - val_loss: 0.3281 - val_accuracy: 0.6821 - val_f1_score: 0.7318 - lr: 6.3025e-05
# Epoch 57/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0682 - accuracy: 0.9651 - f1_score: 0.9648 - val_loss: 0.2825 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 6.3025e-05
# Epoch 58/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0608 - accuracy: 0.9729 - f1_score: 0.9729
# Epoch 58: ReduceLROnPlateau reducing learning rate to 5.9873694408452134e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0608 - accuracy: 0.9731 - f1_score: 0.9731 - val_loss: 0.2978 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 6.3025e-05
# Epoch 59/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0555 - accuracy: 0.9760 - f1_score: 0.9766 - val_loss: 0.2980 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 5.9874e-05
# Epoch 60/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0496 - accuracy: 0.9770 - f1_score: 0.9770 - val_loss: 0.3020 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 5.9874e-05
# Epoch 61/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0483 - accuracy: 0.9770 - f1_score: 0.9765 - val_loss: 0.2904 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 5.9874e-05
# Epoch 62/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0469 - accuracy: 0.9760 - f1_score: 0.9761 - val_loss: 0.2997 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 5.9874e-05
# Epoch 63/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0439 - accuracy: 0.9802 - f1_score: 0.9802
# Epoch 63: ReduceLROnPlateau reducing learning rate to 5.68800103792455e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0478 - accuracy: 0.9780 - f1_score: 0.9770 - val_loss: 0.2855 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 5.9874e-05
# Epoch 64/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0508 - accuracy: 0.9770 - f1_score: 0.9765 - val_loss: 0.3105 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 5.6880e-05
# Epoch 65/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0500 - accuracy: 0.9780 - f1_score: 0.9775 - val_loss: 0.2942 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 5.6880e-05
# Epoch 66/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0427 - accuracy: 0.9780 - f1_score: 0.9785 - val_loss: 0.3235 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 5.6880e-05
# Epoch 67/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0420 - accuracy: 0.9800 - f1_score: 0.9805 - val_loss: 0.2842 - val_accuracy: 0.7438 - val_f1_score: 0.7839 - lr: 5.6880e-05
# Epoch 68/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0444 - accuracy: 0.9802 - f1_score: 0.9802
# Epoch 68: ReduceLROnPlateau reducing learning rate to 5.4036009169067255e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0433 - accuracy: 0.9810 - f1_score: 0.9814 - val_loss: 0.2933 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 5.6880e-05
# Epoch 69/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0486 - accuracy: 0.9800 - f1_score: 0.9800 - val_loss: 0.3554 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 5.4036e-05
# Epoch 70/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0463 - accuracy: 0.9800 - f1_score: 0.9800 - val_loss: 0.2952 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 5.4036e-05
# Epoch 71/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0389 - accuracy: 0.9800 - f1_score: 0.9800 - val_loss: 0.2953 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 5.4036e-05
# Epoch 72/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0356 - accuracy: 0.9830 - f1_score: 0.9824 - val_loss: 0.3091 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 5.4036e-05
# Epoch 73/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0408 - accuracy: 0.9810 - f1_score: 0.9810
# Epoch 73: ReduceLROnPlateau reducing learning rate to 5.133420836500591e-05.
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0383 - accuracy: 0.9830 - f1_score: 0.9834 - val_loss: 0.2712 - val_accuracy: 0.7407 - val_f1_score: 0.7812 - lr: 5.4036e-05
# Epoch 74/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0356 - accuracy: 0.9820 - f1_score: 0.9819 - val_loss: 0.2633 - val_accuracy: 0.7469 - val_f1_score: 0.7865 - lr: 5.1334e-05
# Epoch 75/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0464 - accuracy: 0.9840 - f1_score: 0.9834 - val_loss: 0.2915 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 5.1334e-05
# Epoch 76/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0415 - accuracy: 0.9820 - f1_score: 0.9819 - val_loss: 0.3028 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 5.1334e-05
# Epoch 77/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0328 - accuracy: 0.9830 - f1_score: 0.9829 - val_loss: 0.3049 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 5.1334e-05
# Epoch 78/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0314 - accuracy: 0.9830 - f1_score: 0.9829 - val_loss: 0.2798 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 5.1334e-05
# Epoch 79/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0320 - accuracy: 0.9844 - f1_score: 0.9844
# Epoch 79: ReduceLROnPlateau reducing learning rate to 4.876749881077558e-05.
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0330 - accuracy: 0.9840 - f1_score: 0.9839 - val_loss: 0.3012 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 5.1334e-05
# Epoch 80/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0317 - accuracy: 0.9850 - f1_score: 0.9843 - val_loss: 0.2789 - val_accuracy: 0.7377 - val_f1_score: 0.7786 - lr: 4.8767e-05
# Epoch 81/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0286 - accuracy: 0.9860 - f1_score: 0.9863 - val_loss: 0.2838 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 4.8767e-05
# Epoch 82/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0335 - accuracy: 0.9860 - f1_score: 0.9858 - val_loss: 0.3108 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 4.8767e-05
# Epoch 83/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0282 - accuracy: 0.9870 - f1_score: 0.9868 - val_loss: 0.3071 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 4.8767e-05
# Epoch 84/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0306 - accuracy: 0.9865 - f1_score: 0.9865
# Epoch 84: ReduceLROnPlateau reducing learning rate to 4.63291238702368e-05.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0295 - accuracy: 0.9870 - f1_score: 0.9873 - val_loss: 0.2893 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 4.8767e-05
# Epoch 85/10000
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0252 - accuracy: 0.9860 - f1_score: 0.9863 - val_loss: 0.2944 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 4.6329e-05
# Epoch 86/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0254 - accuracy: 0.9880 - f1_score: 0.9878 - val_loss: 0.3224 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 4.6329e-05
# Epoch 87/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0275 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 0.3129 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 4.6329e-05
# Epoch 88/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0228 - accuracy: 0.9890 - f1_score: 0.9882 - val_loss: 0.3112 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 4.6329e-05
# Epoch 89/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0232 - accuracy: 0.9885 - f1_score: 0.9885
# Epoch 89: ReduceLROnPlateau reducing learning rate to 4.4012669059156905e-05.
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0224 - accuracy: 0.9890 - f1_score: 0.9893 - val_loss: 0.3433 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 4.6329e-05
# Epoch 90/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0276 - accuracy: 0.9890 - f1_score: 0.9887 - val_loss: 0.2855 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 4.4013e-05
# Epoch 91/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0263 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 0.2805 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 4.4013e-05
# Epoch 92/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0242 - accuracy: 0.9900 - f1_score: 0.9902 - val_loss: 0.2691 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 4.4013e-05
# Epoch 93/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0223 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 0.2920 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 4.4013e-05
# Epoch 94/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0180 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.181203439657111e-05.
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0195 - accuracy: 0.9910 - f1_score: 0.9907 - val_loss: 0.2965 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 4.4013e-05
# Epoch 95/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0209 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 0.2866 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 4.1812e-05
# Epoch 96/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0196 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 0.2868 - val_accuracy: 0.7315 - val_f1_score: 0.7734 - lr: 4.1812e-05
# Epoch 97/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0208 - accuracy: 0.9900 - f1_score: 0.9897 - val_loss: 0.2710 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 4.1812e-05
# Epoch 98/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0191 - accuracy: 0.9910 - f1_score: 0.9907 - val_loss: 0.2953 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 4.1812e-05
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0188 - accuracy: 0.9906 - f1_score: 0.9906
# Epoch 99: ReduceLROnPlateau reducing learning rate to 3.9721430948702614e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0183 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 0.3011 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 4.1812e-05
# Epoch 100/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0175 - accuracy: 0.9920 - f1_score: 0.9922 - val_loss: 0.3134 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 3.9721e-05
# Epoch 101/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0155 - accuracy: 0.9930 - f1_score: 0.9927 - val_loss: 0.2975 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 3.9721e-05
# Epoch 102/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0163 - accuracy: 0.9930 - f1_score: 0.9927 - val_loss: 0.3130 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.9721e-05
# Epoch 103/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0153 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3257 - val_accuracy: 0.6698 - val_f1_score: 0.7214 - lr: 3.9721e-05
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0152 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 104: ReduceLROnPlateau reducing learning rate to 3.773536009248346e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0147 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3238 - val_accuracy: 0.6728 - val_f1_score: 0.7240 - lr: 3.9721e-05
# Epoch 105/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0165 - accuracy: 0.9930 - f1_score: 0.9932 - val_loss: 0.3335 - val_accuracy: 0.6698 - val_f1_score: 0.7214 - lr: 3.7735e-05
# Epoch 106/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0148 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3020 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 3.7735e-05
# Epoch 107/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0136 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3009 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 3.7735e-05
# Epoch 108/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0135 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3022 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 3.7735e-05
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0140 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 109: ReduceLROnPlateau reducing learning rate to 3.584859277907526e-05.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0137 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.2770 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 3.7735e-05
# Epoch 110/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0150 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3072 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 3.5849e-05
# Epoch 111/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0162 - accuracy: 0.9940 - f1_score: 0.9936 - val_loss: 0.2944 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 3.5849e-05
# Epoch 112/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0143 - accuracy: 0.9930 - f1_score: 0.9932 - val_loss: 0.3214 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 3.5849e-05
# Epoch 113/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0145 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.3093 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.5849e-05
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0137 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 114: ReduceLROnPlateau reducing learning rate to 3.4056162621709515e-05.
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0138 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3088 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 3.5849e-05
# Epoch 115/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0131 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3103 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 3.4056e-05
# Epoch 116/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0123 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.2961 - val_accuracy: 0.7284 - val_f1_score: 0.7708 - lr: 3.4056e-05
# Epoch 117/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0175 - accuracy: 0.9930 - f1_score: 0.9921 - val_loss: 0.3606 - val_accuracy: 0.6481 - val_f1_score: 0.7031 - lr: 3.4056e-05
# Epoch 118/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0136 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3093 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.4056e-05
# Epoch 119/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0127 - accuracy: 0.9944 - f1_score: 0.9944
# Epoch 119: ReduceLROnPlateau reducing learning rate to 3.2353355527448004e-05.
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0119 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3038 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 3.4056e-05
# Epoch 120/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0132 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.2810 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 3.2353e-05
# Epoch 121/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0116 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3014 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 3.2353e-05
# Epoch 122/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0104 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3002 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 3.2353e-05
# Epoch 123/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0118 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3225 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 3.2353e-05
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0129 - accuracy: 0.9948 - f1_score: 0.9948
# Epoch 124: ReduceLROnPlateau reducing learning rate to 3.0735688960703554e-05.
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0127 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3255 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 3.2353e-05
# Epoch 125/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0121 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3106 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.0736e-05
# Epoch 126/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0112 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3169 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 3.0736e-05
# Epoch 127/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0109 - accuracy: 0.9950 - f1_score: 0.9946 - val_loss: 0.3086 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 3.0736e-05
# Epoch 128/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0104 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 0.3118 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.0736e-05
# Epoch 129/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0099 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 129: ReduceLROnPlateau reducing learning rate to 2.9198905031080356e-05.
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0109 - accuracy: 0.9950 - f1_score: 0.9946 - val_loss: 0.3103 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 3.0736e-05
# Epoch 130/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0112 - accuracy: 0.9950 - f1_score: 0.9946 - val_loss: 0.3413 - val_accuracy: 0.6574 - val_f1_score: 0.7109 - lr: 2.9199e-05
# Epoch 131/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0112 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3018 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.9199e-05
# Epoch 132/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0092 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2996 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 2.9199e-05
# Epoch 133/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0094 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2925 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 2.9199e-05
# Epoch 134/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0105 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 134: ReduceLROnPlateau reducing learning rate to 2.7738960125134326e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0102 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3221 - val_accuracy: 0.6759 - val_f1_score: 0.7266 - lr: 2.9199e-05
# Epoch 135/10000
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0101 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2931 - val_accuracy: 0.7253 - val_f1_score: 0.7682 - lr: 2.7739e-05
# Epoch 136/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0094 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3062 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.7739e-05
# Epoch 137/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0095 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.3294 - val_accuracy: 0.6636 - val_f1_score: 0.7161 - lr: 2.7739e-05
# Epoch 138/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0089 - accuracy: 0.9960 - f1_score: 0.9951 - val_loss: 0.2988 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 2.7739e-05
# Epoch 139/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0080 - accuracy: 0.9967 - f1_score: 0.9967
# Epoch 139: ReduceLROnPlateau reducing learning rate to 2.6352012810093584e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0090 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3228 - val_accuracy: 0.6574 - val_f1_score: 0.7109 - lr: 2.7739e-05
# Epoch 140/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0093 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3316 - val_accuracy: 0.6543 - val_f1_score: 0.7083 - lr: 2.6352e-05
# Epoch 141/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0103 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2937 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 2.6352e-05
# Epoch 142/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0116 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2842 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 2.6352e-05
# Epoch 143/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0091 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2938 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 2.6352e-05
# Epoch 144/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0086 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 144: ReduceLROnPlateau reducing learning rate to 2.503441173757892e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0084 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2952 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.6352e-05
# Epoch 145/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0103 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.2760 - val_accuracy: 0.7346 - val_f1_score: 0.7760 - lr: 2.5034e-05
# Epoch 146/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0095 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3079 - val_accuracy: 0.6975 - val_f1_score: 0.7448 - lr: 2.5034e-05
# Epoch 147/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0088 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3211 - val_accuracy: 0.6790 - val_f1_score: 0.7292 - lr: 2.5034e-05
# Epoch 148/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0084 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3034 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.5034e-05
# Epoch 149/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0089 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 149: ReduceLROnPlateau reducing learning rate to 2.3782690459484e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0083 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3025 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.5034e-05
# Epoch 150/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0084 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3139 - val_accuracy: 0.6914 - val_f1_score: 0.7396 - lr: 2.3783e-05
# Epoch 151/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0080 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3087 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 2.3783e-05
# Epoch 152/10000
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0079 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2965 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 2.3783e-05
# Epoch 153/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0077 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3142 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 2.3783e-05
# Epoch 154/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0085 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 154: ReduceLROnPlateau reducing learning rate to 2.2593555331695822e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0079 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3072 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.3783e-05
# Epoch 155/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0098 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.3023 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.2594e-05
# Epoch 156/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0097 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2945 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.2594e-05
# Epoch 157/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0081 - accuracy: 0.9960 - f1_score: 0.9951 - val_loss: 0.2915 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.2594e-05
# Epoch 158/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0085 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3169 - val_accuracy: 0.6852 - val_f1_score: 0.7344 - lr: 2.2594e-05
# Epoch 159/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0076 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 159: ReduceLROnPlateau reducing learning rate to 2.146387687389506e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0074 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3021 - val_accuracy: 0.7099 - val_f1_score: 0.7552 - lr: 2.2594e-05
# Epoch 160/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0076 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2998 - val_accuracy: 0.7160 - val_f1_score: 0.7604 - lr: 2.1464e-05
# Epoch 161/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0078 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3035 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 2.1464e-05
# Epoch 162/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0086 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3146 - val_accuracy: 0.6883 - val_f1_score: 0.7370 - lr: 2.1464e-05
# Epoch 163/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0081 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2897 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.1464e-05
# Epoch 164/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0067 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 164: ReduceLROnPlateau reducing learning rate to 2.0390682857396313e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0076 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.3063 - val_accuracy: 0.7006 - val_f1_score: 0.7474 - lr: 2.1464e-05
# Epoch 165/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0074 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3049 - val_accuracy: 0.7068 - val_f1_score: 0.7526 - lr: 2.0391e-05
# Epoch 166/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0075 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.3057 - val_accuracy: 0.7037 - val_f1_score: 0.7500 - lr: 2.0391e-05
# Epoch 167/10000
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0074 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3029 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 2.0391e-05
# Epoch 168/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0082 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2899 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 2.0391e-05
# Epoch 169/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0083 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 169: ReduceLROnPlateau reducing learning rate to 1.9371147936908527e-05.
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0076 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3078 - val_accuracy: 0.6944 - val_f1_score: 0.7422 - lr: 2.0391e-05
# Epoch 170/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0085 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3328 - val_accuracy: 0.6512 - val_f1_score: 0.7057 - lr: 1.9371e-05
# Epoch 171/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0083 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.3011 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 1.9371e-05
# Epoch 172/10000
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0079 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2908 - val_accuracy: 0.7191 - val_f1_score: 0.7630 - lr: 1.9371e-05
# Epoch 173/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0078 - accuracy: 0.9960 - f1_score: 0.9956 - val_loss: 0.3057 - val_accuracy: 0.7130 - val_f1_score: 0.7578 - lr: 1.9371e-05
# Epoch 174/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0082 - accuracy: 0.9958 - f1_score: 0.9958Restoring model weights from the end of the best epoch: 74.
#
# Epoch 174: ReduceLROnPlateau reducing learning rate to 1.8402590194455114e-05.
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0079 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2979 - val_accuracy: 0.7222 - val_f1_score: 0.7656 - lr: 1.9371e-05
# Epoch 174: early stopping

# %%
history=resNet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resNet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resNet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 3ms/step
# 0.7469135802469136

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7469135802469136
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.54      0.22      0.32        85
#            0       0.77      0.93      0.84       239
#
#     accuracy                           0.75       324
#    macro avg       0.66      0.58      0.58       324
# weighted avg       0.71      0.75      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 242 chiếm khoảng 74.69135802469135% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 19 chiếm khoảng 22.35294117647059% so với thực tế
