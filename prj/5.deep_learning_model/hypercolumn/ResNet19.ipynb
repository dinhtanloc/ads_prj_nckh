# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7838 - accuracy: 0.5167 - f1_score: 0.3880
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 11s 128ms/step - loss: 0.7754 - accuracy: 0.5190 - f1_score: 0.3989 - val_loss: 0.5760 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6546 - accuracy: 0.5865 - f1_score: 0.5804
# Epoch 2: val_f1_score improved from 0.42467 to 0.43643, saving model to best_model.h5
# 16/16 [==============================] - 1s 53ms/step - loss: 0.6546 - accuracy: 0.5898 - f1_score: 0.5850 - val_loss: 0.5687 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 3/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6037 - accuracy: 0.6292 - f1_score: 0.6117
# Epoch 3: val_f1_score improved from 0.43643 to 0.44990, saving model to best_model.h5
# 16/16 [==============================] - 1s 53ms/step - loss: 0.6018 - accuracy: 0.6307 - f1_score: 0.6147 - val_loss: 0.5601 - val_accuracy: 0.7438 - val_f1_score: 0.4499 - lr: 0.0010
# Epoch 4/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5359 - accuracy: 0.6427 - f1_score: 0.6341
# Epoch 4: val_f1_score improved from 0.44990 to 0.46339, saving model to best_model.h5
# 16/16 [==============================] - 1s 54ms/step - loss: 0.5302 - accuracy: 0.6467 - f1_score: 0.6405 - val_loss: 0.5438 - val_accuracy: 0.7377 - val_f1_score: 0.4634 - lr: 0.0010
# Epoch 5/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.
10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1494 - accuracy: 0.8917 - f1_score: 0.8910
# Epoch 98: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1539 - accuracy: 0.8892 - f1_score: 0.8874 - val_loss: 0.3612 - val_accuracy: 0.7346 - val_f1_score: 0.6057 - lr: 2.5000e-04
# Epoch 99/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1423 - accuracy: 0.8969 - f1_score: 0.8966
# Epoch 99: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1422 - accuracy: 0.8972 - f1_score: 0.8971 - val_loss: 0.3428 - val_accuracy: 0.7469 - val_f1_score: 0.6198 - lr: 2.5000e-04
# Epoch 100/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9032 - f1_score: 0.9032
# Epoch 100: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1372 - accuracy: 0.9032 - f1_score: 0.9032 - val_loss: 0.3227 - val_accuracy: 0.7654 - val_f1_score: 0.6392 - lr: 2.5000e-04
# Epoch 101/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1422 - accuracy: 0.8990 - f1_score: 0.8985
# Epoch 101: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1463 - accuracy: 0.8962 - f1_score: 0.8943 - val_loss: 0.3214 - val_accuracy: 0.7623 - val_f1_score: 0.6253 - lr: 2.5000e-04
# Epoch 102/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1573 - accuracy: 0.8885 - f1_score: 0.8874
# Epoch 102: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1623 - accuracy: 0.8842 - f1_score: 0.8811 - val_loss: 0.3311 - val_accuracy: 0.7562 - val_f1_score: 0.6160 - lr: 2.5000e-04
# Epoch 103/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1415 - accuracy: 0.8979 - f1_score: 0.8969
# Epoch 103: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1484 - accuracy: 0.8932 - f1_score: 0.8899 - val_loss: 0.3350 - val_accuracy: 0.7531 - val_f1_score: 0.6137 - lr: 2.5000e-04
# Epoch 104/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1545 - accuracy: 0.8896 - f1_score: 0.8887
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 104: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1531 - accuracy: 0.8902 - f1_score: 0.8895 - val_loss: 0.3492 - val_accuracy: 0.7407 - val_f1_score: 0.6009 - lr: 2.5000e-04
# Epoch 105/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1525 - accuracy: 0.8917 - f1_score: 0.8902
# Epoch 105: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1540 - accuracy: 0.8902 - f1_score: 0.8880 - val_loss: 0.3517 - val_accuracy: 0.7377 - val_f1_score: 0.5972 - lr: 1.2500e-04
# Epoch 106/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1575 - accuracy: 0.8885 - f1_score: 0.8878
# Epoch 106: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1570 - accuracy: 0.8892 - f1_score: 0.8887 - val_loss: 0.3463 - val_accuracy: 0.7500 - val_f1_score: 0.6044 - lr: 1.2500e-04
# Epoch 107/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1414 - accuracy: 0.8990 - f1_score: 0.8984
# Epoch 107: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1490 - accuracy: 0.8932 - f1_score: 0.8897 - val_loss: 0.3409 - val_accuracy: 0.7562 - val_f1_score: 0.6089 - lr: 1.2500e-04
# Epoch 108/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1507 - accuracy: 0.8938 - f1_score: 0.8923
# Epoch 108: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1499 - accuracy: 0.8942 - f1_score: 0.8931 - val_loss: 0.3516 - val_accuracy: 0.7500 - val_f1_score: 0.5988 - lr: 1.2500e-04
# Epoch 109/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1379 - accuracy: 0.9021 - f1_score: 0.9011
# Epoch 109: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1365 - accuracy: 0.9032 - f1_score: 0.9028 - val_loss: 0.3421 - val_accuracy: 0.7407 - val_f1_score: 0.6094 - lr: 1.2500e-04
# Epoch 110/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1449 - accuracy: 0.8969 - f1_score: 0.8958
# Epoch 110: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1483 - accuracy: 0.8942 - f1_score: 0.8919 - val_loss: 0.3402 - val_accuracy: 0.7346 - val_f1_score: 0.6080 - lr: 1.2500e-04
# Epoch 111/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1440 - accuracy: 0.8979 - f1_score: 0.8966
# Epoch 111: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1443 - accuracy: 0.8972 - f1_score: 0.8956 - val_loss: 0.3314 - val_accuracy: 0.7346 - val_f1_score: 0.6167 - lr: 1.2500e-04
# Epoch 112/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9012 - f1_score: 0.9013
# Epoch 112: val_f1_score did not improve from 0.63957
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1380 - accuracy: 0.9012 - f1_score: 0.9013 - val_loss: 0.3327 - val_accuracy: 0.7284 - val_f1_score: 0.6148 - lr: 1.2500e-04
# Epoch 113/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1411 - accuracy: 0.9000 - f1_score: 0.8991
# Epoch 113: val_f1_score improved from 0.63957 to 0.63967, saving model to best_model.h5
# 16/16 [==============================] - 1s 59ms/step - loss: 0.1393 - accuracy: 0.9012 - f1_score: 0.9009 - val_loss: 0.3224 - val_accuracy: 0.7438 - val_f1_score: 0.6397 - lr: 1.2500e-04
# Epoch 114/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1371 - accuracy: 0.9010 - f1_score: 0.9008
# Epoch 114: val_f1_score improved from 0.63967 to 0.64845, saving model to best_model.h5
# 16/16 [==============================] - 1s 56ms/step - loss: 0.1353 - accuracy: 0.9022 - f1_score: 0.9025 - val_loss: 0.3149 - val_accuracy: 0.7593 - val_f1_score: 0.6485 - lr: 1.2500e-04
# Epoch 115/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1327 - accuracy: 0.9031 - f1_score: 0.9025
# Epoch 115: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1314 - accuracy: 0.9042 - f1_score: 0.9041 - val_loss: 0.3436 - val_accuracy: 0.7469 - val_f1_score: 0.6189 - lr: 1.2500e-04
# Epoch 116/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1335 - accuracy: 0.9042 - f1_score: 0.9036
# Epoch 116: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1328 - accuracy: 0.9052 - f1_score: 0.9051 - val_loss: 0.3570 - val_accuracy: 0.7377 - val_f1_score: 0.6077 - lr: 1.2500e-04
# Epoch 117/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1338 - accuracy: 0.9042 - f1_score: 0.9031
# Epoch 117: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1365 - accuracy: 0.9022 - f1_score: 0.9002 - val_loss: 0.3313 - val_accuracy: 0.7500 - val_f1_score: 0.6328 - lr: 1.2500e-04
# Epoch 118/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1278 - accuracy: 0.9104 - f1_score: 0.9097
# Epoch 118: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1295 - accuracy: 0.9082 - f1_score: 0.9061 - val_loss: 0.3383 - val_accuracy: 0.7500 - val_f1_score: 0.6280 - lr: 1.2500e-04
# Epoch 119/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1434 - accuracy: 0.8969 - f1_score: 0.8951
# Epoch 119: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1428 - accuracy: 0.8972 - f1_score: 0.8957 - val_loss: 0.3771 - val_accuracy: 0.7377 - val_f1_score: 0.5909 - lr: 1.2500e-04
# Epoch 120/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1357 - accuracy: 0.9031 - f1_score: 0.9013
# Epoch 120: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1367 - accuracy: 0.9022 - f1_score: 0.9000 - val_loss: 0.3744 - val_accuracy: 0.7377 - val_f1_score: 0.5956 - lr: 1.2500e-04
# Epoch 121/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1386 - accuracy: 0.9021 - f1_score: 0.9009
# Epoch 121: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1403 - accuracy: 0.9012 - f1_score: 0.8996 - val_loss: 0.3698 - val_accuracy: 0.7407 - val_f1_score: 0.5998 - lr: 1.2500e-04
# Epoch 122/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1348 - accuracy: 0.9042 - f1_score: 0.9028
# Epoch 122: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1386 - accuracy: 0.9012 - f1_score: 0.8984 - val_loss: 0.3407 - val_accuracy: 0.7438 - val_f1_score: 0.6216 - lr: 1.2500e-04
# Epoch 123/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1296 - accuracy: 0.9073 - f1_score: 0.9060
# Epoch 123: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1275 - accuracy: 0.9092 - f1_score: 0.9088 - val_loss: 0.3356 - val_accuracy: 0.7500 - val_f1_score: 0.6281 - lr: 1.2500e-04
# Epoch 124/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1279 - accuracy: 0.9094 - f1_score: 0.9084
# Epoch 124: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1291 - accuracy: 0.9082 - f1_score: 0.9067 - val_loss: 0.3214 - val_accuracy: 0.7654 - val_f1_score: 0.6430 - lr: 1.2500e-04
# Epoch 125/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1250 - accuracy: 0.9104 - f1_score: 0.9096
# Epoch 125: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1267 - accuracy: 0.9092 - f1_score: 0.9078 - val_loss: 0.3538 - val_accuracy: 0.7469 - val_f1_score: 0.6123 - lr: 1.2500e-04
# Epoch 126/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1256 - accuracy: 0.9115 - f1_score: 0.9099
# Epoch 126: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1258 - accuracy: 0.9112 - f1_score: 0.9096 - val_loss: 0.3543 - val_accuracy: 0.7438 - val_f1_score: 0.6083 - lr: 1.2500e-04
# Epoch 127/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1417 - accuracy: 0.8969 - f1_score: 0.8960
# Epoch 127: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1384 - accuracy: 0.8992 - f1_score: 0.8995 - val_loss: 0.3653 - val_accuracy: 0.7469 - val_f1_score: 0.6011 - lr: 1.2500e-04
# Epoch 128/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1240 - accuracy: 0.9104 - f1_score: 0.9097
# Epoch 128: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1299 - accuracy: 0.9062 - f1_score: 0.9034 - val_loss: 0.3391 - val_accuracy: 0.7593 - val_f1_score: 0.6231 - lr: 1.2500e-04
# Epoch 129/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1340 - accuracy: 0.9052 - f1_score: 0.9042
# Epoch 129: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1326 - accuracy: 0.9062 - f1_score: 0.9057 - val_loss: 0.3335 - val_accuracy: 0.7562 - val_f1_score: 0.6302 - lr: 1.2500e-04
# Epoch 130/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1182 - accuracy: 0.9156 - f1_score: 0.9149
# Epoch 130: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1216 - accuracy: 0.9132 - f1_score: 0.9113 - val_loss: 0.3106 - val_accuracy: 0.7562 - val_f1_score: 0.6314 - lr: 1.2500e-04
# Epoch 131/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1289 - accuracy: 0.9062 - f1_score: 0.9053
# Epoch 131: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1288 - accuracy: 0.9062 - f1_score: 0.9052 - val_loss: 0.3129 - val_accuracy: 0.7654 - val_f1_score: 0.6472 - lr: 1.2500e-04
# Epoch 132/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1262 - accuracy: 0.9094 - f1_score: 0.9083
# Epoch 132: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1269 - accuracy: 0.9092 - f1_score: 0.9080 - val_loss: 0.3372 - val_accuracy: 0.7593 - val_f1_score: 0.6252 - lr: 1.2500e-04
# Epoch 133/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.
10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1145 - accuracy: 0.9177 - f1_score: 0.9169
# Epoch 194: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 194: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1126 - accuracy: 0.9192 - f1_score: 0.9191 - val_loss: 0.3216 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 1.5625e-05
# Epoch 195/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1195 - accuracy: 0.9146 - f1_score: 0.9126
# Epoch 195: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1188 - accuracy: 0.9152 - f1_score: 0.9136 - val_loss: 0.3214 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 196/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1167 - accuracy: 0.9167 - f1_score: 0.9156
# Epoch 196: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1160 - accuracy: 0.9172 - f1_score: 0.9164 - val_loss: 0.3209 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 197/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1159 - accuracy: 0.9167 - f1_score: 0.9157
# Epoch 197: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1150 - accuracy: 0.9172 - f1_score: 0.9165 - val_loss: 0.3207 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 198/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1106 - accuracy: 0.9208 - f1_score: 0.9202
# Epoch 198: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1130 - accuracy: 0.9182 - f1_score: 0.9159 - val_loss: 0.3205 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 199/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1106 - accuracy: 0.9208 - f1_score: 0.9202
# Epoch 199: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1107 - accuracy: 0.9212 - f1_score: 0.9207 - val_loss: 0.3204 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 200/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9232 - f1_score: 0.9231
# Epoch 200: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1063 - accuracy: 0.9232 - f1_score: 0.9231 - val_loss: 0.3206 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 201/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1232 - accuracy: 0.9135 - f1_score: 0.9126
# Epoch 201: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1211 - accuracy: 0.9152 - f1_score: 0.9149 - val_loss: 0.3212 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 202/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1089 - accuracy: 0.9219 - f1_score: 0.9214
# Epoch 202: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1080 - accuracy: 0.9222 - f1_score: 0.9217 - val_loss: 0.3228 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 203/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1091 - accuracy: 0.9229 - f1_score: 0.9221
# Epoch 203: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1120 - accuracy: 0.9202 - f1_score: 0.9175 - val_loss: 0.3247 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 204/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1073 - accuracy: 0.9240 - f1_score: 0.9234
# Epoch 204: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1056 - accuracy: 0.9251 - f1_score: 0.9252 - val_loss: 0.3253 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 205/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1073 - accuracy: 0.9229 - f1_score: 0.9224
# Epoch 205: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1098 - accuracy: 0.9212 - f1_score: 0.9198 - val_loss: 0.3241 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 206/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1159 - accuracy: 0.9177 - f1_score: 0.9170
# Epoch 206: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1151 - accuracy: 0.9182 - f1_score: 0.9177 - val_loss: 0.3241 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 207/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1072 - accuracy: 0.9240 - f1_score: 0.9229
# Epoch 207: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1094 - accuracy: 0.9222 - f1_score: 0.9203 - val_loss: 0.3235 - val_accuracy: 0.7623 - val_f1_score: 0.6406 - lr: 7.8125e-06
# Epoch 208/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1072 - accuracy: 0.9229 - f1_score: 0.9215
# Epoch 208: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1086 - accuracy: 0.9222 - f1_score: 0.9204 - val_loss: 0.3256 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 209/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1143 - accuracy: 0.9177 - f1_score: 0.9167
# Epoch 209: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1148 - accuracy: 0.9172 - f1_score: 0.9159 - val_loss: 0.3263 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 210/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1130 - accuracy: 0.9198 - f1_score: 0.9190
# Epoch 210: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1133 - accuracy: 0.9192 - f1_score: 0.9179 - val_loss: 0.3264 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 211/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1075 - accuracy: 0.9219 - f1_score: 0.9213
# Epoch 211: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1057 - accuracy: 0.9232 - f1_score: 0.9232 - val_loss: 0.3264 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 212/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1133 - accuracy: 0.9208 - f1_score: 0.9200
# Epoch 212: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1098 - accuracy: 0.9232 - f1_score: 0.9235 - val_loss: 0.3254 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 213/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9271 - f1_score: 0.9273
# Epoch 213: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1023 - accuracy: 0.9271 - f1_score: 0.9273 - val_loss: 0.3247 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 214/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1015 - accuracy: 0.9271 - f1_score: 0.9263Restoring model weights from the end of the best epoch: 114.
#
# Epoch 214: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 214: val_f1_score did not improve from 0.64845
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1082 - accuracy: 0.9212 - f1_score: 0.9173 - val_loss: 0.3254 - val_accuracy: 0.7593 - val_f1_score: 0.6352 - lr: 7.8125e-06
# Epoch 214: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
check_model=resnet50
check_model.load_weights('best_model.h5')
check_model.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res2b_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 10, 32)       0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 10, 32)       0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 10, 96)       0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 10, 96)       0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)        (None, 10, 32)       3104        ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 10, 32)       0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 10, 32)       0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 10, 96)       0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 96)       0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 5, 192)       0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 5, 96)        0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 5, 96)        0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 5, 192)       0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 5, 192)       0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 5, 96)        18528       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 5, 96)        0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 5, 96)        0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 5, 192)       0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 5, 192)       0           ['add_5[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_18[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_19[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_20[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_18[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_21 (Activation)     (None, 3, 256)       0           ['add_6[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_21[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_22[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_23[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_21[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 2, 384)       0           ['add_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_24[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 946,346
# Trainable params: 945,878
# Non-trainable params: 468
# __________________________________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 7ms/step
# 0.7592592592592593

# %%
predictions = check_model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 6ms/step
# 0.7592592592592593

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7592592592592593
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.54      0.58      0.56        85
#            0       0.85      0.82      0.83       239
#
#     accuracy                           0.76       324
#    macro avg       0.69      0.70      0.70       324
# weighted avg       0.76      0.76      0.76       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 246 chiếm khoảng 75.92592592592592% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 49 chiếm khoảng 57.647058823529406% so với thực tế
