# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (656, 42) (656, 2) (324, 42) (324, 2)
# (1001, 42) (1001, 2) (324, 42) (324, 2)
# (1002, 42) (1002, 2) (324, 42) (324, 2)
# (355, 42) (355, 2) (324, 42) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score

# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
# early_stopping = EarlyStopping(monitor='val_loss',
#     min_delta=0.00005,
#     patience=20,
#     verbose=1,
#     restore_best_weights=True,
# )

# lr_scheduler = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=7,
#     min_lr=0.000001,
#     verbose=1,
# )
# checkpoint_callback = ModelCheckpoint(
#     filepath='ResNet10.h5',  # Đường dẫn để lưu model
#     monitor='val_loss',  # Theo dõi val_loss
#     save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
#     verbose=1  # Hiển thị thông báo khi lưu model
# )

early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=7,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
from tensorflow.keras.optimizers import Adam
from keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# from scikeras.wrappers import KerasClassifier 

# lr=0.0001

def build_model(filters1,filters2,filters3,filters4,filters5):
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    bn_axis = -1
    step=32
    # Sử dụng filters trong hàm build_resnet_model
    # filters1 = 96
    # filters2 = filters1 * 2
    # filters3 = filters1 * 4
    # filters4 = filters1 * 6
    # filters5 = filters1 * 8
    # filters1=hp.Int('filter1', min_value=32, max_value=1024, step=step)
    # filters2=hp.Int('filter2', min_value=32, max_value=1024, step=step)
    # filters3=hp.Int('filter3', min_value=32, max_value=1024, step=step)
    # filters4=hp.Int('filter4', min_value=32, max_value=1024, step=step)
    # filters5=hp.Int('filter5', min_value=32, max_value=1024, step=step)

    learning_rate = 0.001

    x = ZeroPadding1D(padding=1)(x_input)
    x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(3, strides=2)(x)

    # ResNet blocks
    x = conv_block(x, 3,[filters1, filters1, filters2], stage=2, block='a', strides=1)
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='b')
    # x = identity_block(x, 3,[filters1, filters1, filters2], stage=2, block='c')

    x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='c')
    # x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')
    
    x = conv_block(x, 3,  [filters3, filters3, filters4], stage=4, block='a')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='b')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='c')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='d')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='e')
    # x = identity_block(x, 3,  [filters3, filters3, filters4], stage=4, block='f')

    x = conv_block(x, 3,  [filters4, filters4, filters5], stage=5, block='a')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='b')
    # x = identity_block(x, 3, [filters4, filters4, filters5], stage=5, block='c')
    # Repeat this pattern as needed

    # Ending layers
    x = GlobalAveragePooling1D()(x)
    x = Dense(2, activation='softmax', name='fc1000')(x)

    # Create model
    model = Model(x_input, x, name='resnet50_1d')

    # model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
    
    return model


param_grid = {
    'model__filters1': [32, 64, 96],
    'model__filters2': [96, 128, 192],
    'model__filters3': [192, 256, 384],
    'model__filters4': [256, 384, 512],
    'model__filters5': [384, 512, 1024],
}
# model = KerasClassifier(build_fn=build_model,epochs=10, verbose=0)

# Create a scorer using make_scorer
f1_scorer = make_scorer(f1_score, average='macro')

# Setup GridSearchCV with the f1_scorer
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer,cv=2, n_jobs=-1,verbose=2)
# 
# Tạo đối tượng RandomSearch tuner


data_order=8

# # Run grid search
# grid_result = grid.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, std, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, std, param))

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
resnet50=build_model(32,96,192,256,384)
resnet50.summary()
# Out:
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 42, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 44, 1)       0           ['input_1[0][0]']
#
#  conv1 (Conv1D)                 (None, 22, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 22, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 22, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 10, 32)       2080        ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 10, 32)       0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 10, 32)       3104        ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 10, 32)      40          ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 10, 32)       0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)        (None, 10, 96)       3168        ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 10, 96)       6240        ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 10, 96)      40          ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 10, 96)      40          ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 10, 96)       0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 10, 96)       0           ['add[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 5, 96)        9312        ['activation_3[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 5, 96)        0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 5, 96)        27744       ['activation_4[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 5, 96)       20          ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 5, 96)        0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)        (None, 5, 192)       18624       ['activation_5[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 5, 192)       18624       ['activation_3[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 5, 192)      20          ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 5, 192)      20          ['res3a_branch1[0][0]']
#  on)
#
#  add_1 (Add)                    (None, 5, 192)       0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_6 (Activation)      (None, 5, 192)       0           ['add_1[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 3, 192)       37056       ['activation_6[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 3, 192)       0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 3, 192)       110784      ['activation_7[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 3, 192)      12          ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 3, 192)       0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)        (None, 3, 256)       49408       ['activation_8[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 3, 256)       49408       ['activation_6[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 3, 256)      12          ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 3, 256)      12          ['res4a_branch1[0][0]']
#  on)
#
#  add_2 (Add)                    (None, 3, 256)       0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_9 (Activation)      (None, 3, 256)       0           ['add_2[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 2, 256)       65792       ['activation_9[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 2, 256)       0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 2, 256)       196864      ['activation_10[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 256)      8           ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 2, 256)       0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)        (None, 2, 384)       98688       ['activation_11[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 2, 384)       98688       ['activation_9[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 384)      8           ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 384)      8           ['res5a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 2, 384)       0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 2, 384)       0           ['add_3[0][0]']
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation_12[0][0]']
#  alAveragePooling1D)
#
#  fc1000 (Dense)                 (None, 2)            770         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 797,442
# Trainable params: 797,154
# Non-trainable params: 288
# __________________________________________________________________________________________________

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.3725 - accuracy: 0.5060 - f1_score: 0.3603
# Epoch 1: val_f1_score improved from -inf to 0.42467, saving model to best_model.h5
# 16/16 [==============================] - 6s 75ms/step - loss: 0.3725 - accuracy: 0.5060 - f1_score: 0.3603 - val_loss: 0.0385 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.5968 - f1_score: 0.5663
# Epoch 2: val_f1_score improved from 0.42467 to 0.43643, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0610 - accuracy: 0.5968 - f1_score: 0.5663 - val_loss: 0.0496 - val_accuracy: 0.7407 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.6717 - f1_score: 0.6617
# Epoch 3: val_f1_score improved from 0.43643 to 0.50350, saving model to best_model.h5
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0526 - accuracy: 0.6717 - f1_score: 0.6617 - val_loss: 0.0402 - val_accuracy: 0.7284 - val_f1_score: 0.5035 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.7116 - f1_score: 0.7031
# Epoch 4: val_f1_score did not improve from 0.50350
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0488 - accuracy: 0.7116 - f1_score: 0.7031 - val_loss: 0.0512 - val_accuracy: 0.7191 - val_f1_score: 0.4736 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.7545 - f1_score: 0.7547
# Epoch 5: val_f1_score did not improve from 0.50350
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0446 - accuracy: 0.7545 - f1_score: 0.7547 - val_loss: 0.0424 - val_accuracy: 0.6235 - val_f1_score: 0.4810 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.8034 - f1_score: 0.7984
# Epoch 6: val_f1_score did not improve from 0.50350
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0370 - accuracy: 0.8034 - f1_score: 0.7984 - val_loss: 0.0417 - val_accuracy: 0.5586 - val_f1_score: 0.4779 - lr: 0.0010
# Epoch 7/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0331 - accuracy: 0.8396 - f1_score: 0.8385
# Epoch 7: val_f1_score improved from 0.50350 to 0.57790, saving model to best_model.h5
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0326 - accuracy: 0.8413 - f1_score: 0.8412 - val_loss: 0.0413 - val_accuracy: 0.5617 - val_f1_score: 0.5779 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.8673 - f1_score: 0.8666
# Epoch 8: val_f1_score did not improve from 0.57790
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0286 - accuracy: 0.8673 - f1_score: 0.8666 - val_loss: 0.0411 - val_accuracy: 0.5309 - val_f1_score: 0.5779 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.8922 - f1_score: 0.8864
# Epoch 9: val_f1_score did not improve from 0.57790
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0262 - accuracy: 0.8922 - f1_score: 0.8864 - val_loss: 0.0453 - val_accuracy: 0.4846 - val_f1_score: 0.5561 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.8483 - f1_score: 0.8432
# Epoch 10: val_f1_score improved from 0.57790 to 0.63976, saving model to best_model.h5
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0326 - accuracy: 0.8483 - f1_score: 0.8432 - val_loss: 0.0420 - val_accuracy: 0.6389 - val_f1_score: 0.6398 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.8992 - f1_score: 0.8965
# Epoch 11: val_f1_score did not improve from 0.63976
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0200 - accuracy: 0.8992 - f1_score: 0.8965 - val_loss: 0.0455 - val_accuracy: 0.5278 - val_f1_score: 0.5508 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9202 - f1_score: 0.9189
# Epoch 12: val_f1_score did not improve from 0.63976
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0175 - accuracy: 0.9202 - f1_score: 0.9189 - val_loss: 0.0485 - val_accuracy: 0.5741 - val_f1_score: 0.6121 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9261 - f1_score: 0.9251
# Epoch 13: val_f1_score improved from 0.63976 to 0.64542, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0170 - accuracy: 0.9261 - f1_score: 0.9251 - val_loss: 0.0447 - val_accuracy: 0.6049 - val_f1_score: 0.6454 - lr: 0.0010
# Epoch 14/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0158 - accuracy: 0.9375 - f1_score: 0.9371
# Epoch 14: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0158 - accuracy: 0.9371 - f1_score: 0.9365 - val_loss: 0.0499 - val_accuracy: 0.5741 - val_f1_score: 0.5979 - lr: 0.0010
# Epoch 15/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0132 - accuracy: 0.9344 - f1_score: 0.9339
# Epoch 15: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0128 - accuracy: 0.9371 - f1_score: 0.9380 - val_loss: 0.0503 - val_accuracy: 0.6420 - val_f1_score: 0.6432 - lr: 0.0010
# Epoch 16/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0106 - accuracy: 0.9565 - f1_score: 0.9561
# Epoch 16: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0102 - accuracy: 0.9601 - f1_score: 0.9605 - val_loss: 0.0968 - val_accuracy: 0.4660 - val_f1_score: 0.5421 - lr: 0.0010
# Epoch 17/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0112 - accuracy: 0.9542 - f1_score: 0.9540
# Epoch 17: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0112 - accuracy: 0.9531 - f1_score: 0.9528 - val_loss: 0.0602 - val_accuracy: 0.6049 - val_f1_score: 0.6343 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9581 - f1_score: 0.9554
# Epoch 18: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0078 - accuracy: 0.9581 - f1_score: 0.9554 - val_loss: 0.0983 - val_accuracy: 0.5216 - val_f1_score: 0.5414 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9571 - f1_score: 0.9577
# Epoch 19: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0101 - accuracy: 0.9571 - f1_score: 0.9577 - val_loss: 0.0597 - val_accuracy: 0.6975 - val_f1_score: 0.6288 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9641 - f1_score: 0.9639
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_f1_score did not improve from 0.64542
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0087 - accuracy: 0.9641 - f1_score: 0.9639 - val_loss: 0.0852 - val_accuracy: 0.6821 - val_f1_score: 0.6046 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9780 - f1_score: 0.9783
# Epoch 21: val_f1_score improved from 0.64542 to 0.67056, saving model to best_model.h5
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0059 - accuracy: 0.9780 - f1_score: 0.9783 - val_loss: 0.1098 - val_accuracy: 0.7500 - val_f1_score: 0.6706 - lr: 5.0000e-04
# Epoch 22/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9920 - f1_score: 0.9919
# Epoch 22: val_f1_score did not improve from 0.67056
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0027 - accuracy: 0.9920 - f1_score: 0.9919 - val_loss: 0.0952 - val_accuracy: 0.6852 - val_f1_score: 0.6639 - lr: 5.0000e-04
# Epoch 23/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 23: val_f1_score did not improve from 0.67056
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0010 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.1054 - val_accuracy: 0.6944 - val_f1_score: 0.6219 - lr: 5.0000e-04
# Epoch 24/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9960 - f1_score: 0.9955
# Epoch 24: val_f1_score did not improve from 0.67056
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0011 - accuracy: 0.9960 - f1_score: 0.9955 - val_loss: 0.1224 - val_accuracy: 0.7006 - val_f1_score: 0.6689 - lr: 5.0000e-04
# Epoch 25/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.5455e-04 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 25: val_f1_score improved from 0.67056 to 0.67609, saving model to best_model.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 3.5455e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.1336 - val_accuracy: 0.7037 - val_f1_score: 0.6761 - lr: 5.0000e-04
# Epoch 26/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.9468e-04 - accuracy: 0.9970 - f1_score: 0.9965
# Epoch 26: val_f1_score improved from 0.67609 to 0.67878, saving model to best_model.h5
# 16/16 [==============================] - 1s 32ms/step - loss: 4.9468e-04 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 0.1348 - val_accuracy: 0.6944 - val_f1_score: 0.6788 - lr: 5.0000e-04
# Epoch 27/10000
# 16/16 [==============================] - ETA: 0s - loss: 7.9207e-04 - accuracy: 0.9970 - f1_score: 0.9957
# Epoch 27: val_f1_score did not improve from 0.67878
# 16/16 [==============================] - 0s 23ms/step - loss: 7.9207e-04 - accuracy: 0.9970 - f1_score: 0.9957 - val_loss: 0.1540 - val_accuracy: 0.6975 - val_f1_score: 0.6760 - lr: 5.0000e-04
# Epoch 28/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9920 - f1_score: 0.9921
# Epoch 28: val_f1_score did not improve from 0.67878
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0027 - accuracy: 0.9920 - f1_score: 0.9921 - val_loss: 0.1594 - val_accuracy: 0.7191 - val_f1_score: 0.6355 - lr: 5.0000e-04
# Epoch 29/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9900 - f1_score: 0.9894
# Epoch 29: val_f1_score did not improve from 0.67878
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0046 - accuracy: 0.9900 - f1_score: 0.9894 - val_loss: 0.1301 - val_accuracy: 0.6204 - val_f1_score: 0.6298 - lr: 5.0000e-04
# Epoch 30/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9860 - f1_score: 0.9861
# Epoch 30: val_f1_score did not improve from 0.67878
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0043 - accuracy: 0.9860 - f1_score: 0.9861 - val_loss: 0.1115 - val_accuracy: 0.7068 - val_f1_score: 0.6433 - lr: 5.0000e-04
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 31: val_f1_score did not improve from 0.67878
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0016 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.1338 - val_accuracy: 0.6790 - val_f1_score: 0.6679 - lr: 5.0000e-04
# Epoch 32/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9950 - f1_score: 0.9940
# Epoch 32: val_f1_score improved from 0.67878 to 0.68867, saving model to best_model.h5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0014 - accuracy: 0.9950 - f1_score: 0.9940 - val_loss: 0.1342 - val_accuracy: 0.7130 - val_f1_score: 0.6887 - lr: 5.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - ETA: 0s - loss: 9.0075e-04 - accuracy: 0.9970 - f1_score: 0.9969
# Epoch 33: val_f1_score did not improve from 0.68867
# 16/16 [==============================] - 0s 25ms/step - loss: 9.0075e-04 - accuracy: 0.9970 - f1_score: 0.9969 - val_loss: 0.1399 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 5.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - ETA: 0s - loss: 9.0279e-04 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 34: val_f1_score did not improve from 0.68867
# 16/16 [==============================] - 0s 25ms/step - loss: 9.0279e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.1601 - val_accuracy: 0.6790 - val_f1_score: 0.6716 - lr: 5.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 35: val_f1_score improved from 0.68867 to 0.69419, saving model to best_model.h5
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 0.1782 - val_accuracy: 0.7469 - val_f1_score: 0.6942 - lr: 5.0000e-04
# Epoch 36/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 9.9198e-04 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 36: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 27ms/step - loss: 9.5658e-04 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.1692 - val_accuracy: 0.6605 - val_f1_score: 0.6098 - lr: 5.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.9478e-04 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 37: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 25ms/step - loss: 3.9478e-04 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.1926 - val_accuracy: 0.7315 - val_f1_score: 0.6699 - lr: 5.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.5965e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 38: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 3.5965e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.7130 - val_f1_score: 0.6723 - lr: 5.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3686e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 39: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 1.3686e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.7099 - val_f1_score: 0.6838 - lr: 5.0000e-04
# Epoch 40/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.9010e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 40: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 27ms/step - loss: 3.6424e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.7130 - val_f1_score: 0.6883 - lr: 5.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - ETA: 0s - loss: 2.6678e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 41: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 2.6678e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.7037 - val_f1_score: 0.6817 - lr: 5.0000e-04
# Epoch 42/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.8420e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 42: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 26ms/step - loss: 3.6696e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.6914 - val_f1_score: 0.6751 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2716e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 43: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 3.2716e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.6852 - val_f1_score: 0.6730 - lr: 2.5000e-04
# Epoch 44/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.3372e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 44: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 3.3372e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.6944 - val_f1_score: 0.6756 - lr: 2.5000e-04
# Epoch 45/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3866e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 45: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 25ms/step - loss: 1.3866e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.7006 - val_f1_score: 0.6797 - lr: 2.5000e-04
# Epoch 46/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.8475e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 46: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 1.8475e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.7006 - val_f1_score: 0.6797 - lr: 2.5000e-04
# Epoch 47/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.7931e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 47: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 28ms/step - loss: 2.0660e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.7068 - val_f1_score: 0.6839 - lr: 2.5000e-04
# Epoch 48/10000
# 16/16 [==============================] - ETA: 0s - loss: 9.1166e-06 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 48: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 9.1166e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.7068 - val_f1_score: 0.6839 - lr: 2.5000e-04
# Epoch 49/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6501e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 49: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6501e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.7068 - val_f1_score: 0.6839 - lr: 2.5000e-04
# Epoch 50/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.0123e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 50: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 1.0123e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.7068 - val_f1_score: 0.6839 - lr: 1.2500e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.4560e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 51: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 3.4560e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.7068 - val_f1_score: 0.6798 - lr: 1.2500e-04
# Epoch 52/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.8916e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 52: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 25ms/step - loss: 1.8916e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2286 - val_accuracy: 0.7130 - val_f1_score: 0.6841 - lr: 1.2500e-04
# Epoch 53/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6175e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 53: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6175e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.7130 - val_f1_score: 0.6841 - lr: 1.2500e-04
# Epoch 54/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 1.2679e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 54: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 29ms/step - loss: 1.2387e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.7130 - val_f1_score: 0.6841 - lr: 1.2500e-04
# Epoch 55/10000
# 16/16 [==============================] - ETA: 0s - loss: 8.3315e-06 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 35.
#
# Epoch 55: val_f1_score did not improve from 0.69419
# 16/16 [==============================] - 0s 25ms/step - loss: 8.3315e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.7099 - val_f1_score: 0.6815 - lr: 1.2500e-04
# Epoch 55: early stopping

# %%
history=resnet50.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = resnet50.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = resnet50.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 1s 4ms/step
# 0.7469135802469136

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7469135802469136
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.52      0.40      0.45        85
#            0       0.80      0.87      0.84       239
#
#     accuracy                           0.75       324
#    macro avg       0.66      0.64      0.64       324
# weighted avg       0.73      0.75      0.74       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 242 chiếm khoảng 74.69135802469135% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 34 chiếm khoảng 40.0% so với thực tế
