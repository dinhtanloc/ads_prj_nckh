# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
# from sklearn.metrics import f1_score
# import tensorflow as tf
# def f1_loss(y_true, y_pred):
#     true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
#     predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
#     possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
#     precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
#     recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
#     f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
#     return 1 - f1

# import tensorflow as tf

def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
import tensorflow as tf
from tensorflow import keras
from keras.activations import relu
from tensorflow.keras.layers import *
from tensorflow.keras import Model
from tensorflow.keras import layers as Layers


class ResBlock(Model):
    def __init__(self, channels, stride=1):
        super(ResBlock, self).__init__(name='ResBlock')
        self.flag = (stride != 1)
        self.conv1 = Conv1D(channels, 3, stride, padding='same')
        self.bn1 = BatchNormalization()
        self.conv2 = Conv1D(channels, 3, padding='same')
        self.bn2 = BatchNormalization()
        self.relu = ReLU()
        if self.flag:
            self.bn3 = BatchNormalization()
            self.conv3 = Conv1D(channels, 1, stride)

    def call(self, x):
        x1 = self.conv1(x)
        x1 = self.bn1(x1)
        x1 = self.relu(x1)
        x1 = self.conv2(x1)
        x1 = self.bn2(x1)
        if self.flag:
            x = self.conv3(x)
            x = self.bn3(x)
        x1 = Layers.add([x, x1])
        x1 = self.relu(x1)
        return x1


class ResNet34(Model):
    def __init__(self):
        super(ResNet34, self).__init__(name='ResNet34')
        self.conv1 = Conv1D(64, 7, 2, padding='same')
        self.bn = BatchNormalization()
        self.relu = ReLU()
        self.mp1 = MaxPooling1D(3, 2)

        self.conv2_1 = ResBlock(64)
        self.conv2_2 = ResBlock(64)
        self.conv2_3 = ResBlock(64)

        self.conv3_1 = ResBlock(128, 2)
        self.conv3_2 = ResBlock(128)
        self.conv3_3 = ResBlock(128)
        self.conv3_4 = ResBlock(128)

        self.conv4_1 = ResBlock(256, 2)
        self.conv4_2 = ResBlock(256)
        self.conv4_3 = ResBlock(256)
        self.conv4_4 = ResBlock(256)
        self.conv4_5 = ResBlock(256)
        self.conv4_6 = ResBlock(256)

        self.conv5_1 = ResBlock(512, 2)
        self.conv5_2 = ResBlock(512)
        self.conv5_3 = ResBlock(512)

        self.pool = GlobalAveragePooling1D()
        self.fc1 = Dense(2, activation='softmax')
        self.dp1 = Dropout(0.5)
        # self.fc2 = Dense(512, activation='relu')
        # self.dp2 = Dropout(0.5)
        # self.fc3 = Dense(64)

    def call(self, x):
        x = self.conv1(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.mp1(x)

        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.conv2_3(x)

        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.conv3_4(x)

        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        # x = self.conv4_4(x)
        # x = self.conv4_5(x)
        # x = self.conv4_6(x)

        # x = self.conv5_1(x)
        # x = self.conv5_2(x)
        # x = self.conv5_3(x)

        x = self.pool(x)
        x = self.dp1(x)
        x = self.fc1(x)
        # x = self.fc2(x)
        # x = self.dp2(x)
        # x = self.fc3(x)
        return x


model = ResNet34()
model.compile(optimizer=Adam(learning_rate=0.001), loss=focal_loss, metrics=['accuracy',f1_score])

model.build(input_shape=(None,42,1))
model.summary()
# Out:
# Model: "ResNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  512
#
#  batch_normalization (Batch  multiple                  256
#  Normalization)
#
#  re_lu (ReLU)                multiple                  0
#
#  max_pooling1d (MaxPooling1  multiple                  0
#  D)
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  83840
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  331520
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  global_average_pooling1d (  multiple                  0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               multiple                  514
#
#  dropout (Dropout)           multiple                  0
#
# =================================================================
# Total params: 1582594 (6.04 MB)
# Trainable params: 1575810 (6.01 MB)
# Non-trainable params: 6784 (26.50 KB)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 8s 65ms/step - loss: 0.3525 - accuracy: 0.5589 - f1_score: 0.5550 - val_loss: 0.1740 - val_accuracy: 0.7346 - val_f1_score: 0.4320 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2187 - accuracy: 0.6447 - f1_score: 0.6384 - val_loss: 0.0689 - val_accuracy: 0.4630 - val_f1_score: 0.4128 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1463 - accuracy: 0.7106 - f1_score: 0.7070 - val_loss: 0.1027 - val_accuracy: 0.7407 - val_f1_score: 0.4724 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1216 - accuracy: 0.7365 - f1_score: 0.7346 - val_loss: 0.6580 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1209 - accuracy: 0.7076 - f1_score: 0.7029 - val_loss: 0.5402 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0830 - accuracy: 0.7725 - f1_score: 0.7652 - val_loss: 0.3366 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0537 - accuracy: 0.8204 - f1_score: 0.8168 - val_loss: 0.1449 - val_accuracy: 0.7099 - val_f1_score: 0.5901 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0382 - accuracy: 0.8463 - f1_score: 0.8462 - val_loss: 0.1373 - val_accuracy: 0.7500 - val_f1_score: 0.6050 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0280 - accuracy: 0.8782 - f1_score: 0.8768 - val_loss: 0.1523 - val_accuracy: 0.7346 - val_f1_score: 0.5454 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0220 - accuracy: 0.9062 - f1_score: 0.9053 - val_loss: 0.1329 - val_accuracy: 0.7130 - val_f1_score: 0.6208 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0167 - accuracy: 0.9331 - f1_score: 0.9322 - val_loss: 0.0673 - val_accuracy: 0.6975 - val_f1_score: 0.6853 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0186 - accuracy: 0.9212 - f1_score: 0.9204 - val_loss: 0.0947 - val_accuracy: 0.7068 - val_f1_score: 0.5823 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0113 - accuracy: 0.9521 - f1_score: 0.9523 - val_loss: 0.0878 - val_accuracy: 0.7099 - val_f1_score: 0.6360 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0082 - accuracy: 0.9601 - f1_score: 0.9594 - val_loss: 0.1101 - val_accuracy: 0.7006 - val_f1_score: 0.6528 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0100 - accuracy: 0.9661 - f1_score: 0.9667 - val_loss: 0.1503 - val_accuracy: 0.7037 - val_f1_score: 0.6124 - lr: 0.0010
# Epoch 16/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0072 - accuracy: 0.9671 - f1_score: 0.9675 - val_loss: 0.1341 - val_accuracy: 0.7099 - val_f1_score: 0.6351 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0076 - accuracy: 0.9681 - f1_score: 0.9684 - val_loss: 0.1580 - val_accuracy: 0.6698 - val_f1_score: 0.6084 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0053 - accuracy: 0.9750 - f1_score: 0.9752 - val_loss: 0.1592 - val_accuracy: 0.6759 - val_f1_score: 0.6362 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0047 - accuracy: 0.9810 - f1_score: 0.9800 - val_loss: 0.1533 - val_accuracy: 0.6944 - val_f1_score: 0.6462 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0063 - accuracy: 0.9820 - f1_score: 0.9816 - val_loss: 0.1754 - val_accuracy: 0.7006 - val_f1_score: 0.6339 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0099 - accuracy: 0.9701 - f1_score: 0.9685 - val_loss: 0.2045 - val_accuracy: 0.6975 - val_f1_score: 0.6337 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0289 - accuracy: 0.9142 - f1_score: 0.9131 - val_loss: 0.3590 - val_accuracy: 0.7191 - val_f1_score: 0.5734 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0238 - accuracy: 0.8912 - f1_score: 0.8910 - val_loss: 0.3072 - val_accuracy: 0.7006 - val_f1_score: 0.5927 - lr: 0.0010
# Epoch 24/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0170 - accuracy: 0.9232 - f1_score: 0.9219 - val_loss: 0.1902 - val_accuracy: 0.6698 - val_f1_score: 0.6622 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0079 - accuracy: 0.9711 - f1_score: 0.9709 - val_loss: 0.1668 - val_accuracy: 0.6698 - val_f1_score: 0.6402 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0039 - accuracy: 0.9850 - f1_score: 0.9846 - val_loss: 0.2190 - val_accuracy: 0.7068 - val_f1_score: 0.5540 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0057 - accuracy: 0.9731 - f1_score: 0.9730 - val_loss: 0.2434 - val_accuracy: 0.6975 - val_f1_score: 0.5183 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0028 - accuracy: 0.9890 - f1_score: 0.9886 - val_loss: 0.2089 - val_accuracy: 0.7130 - val_f1_score: 0.6534 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0013 - accuracy: 0.9930 - f1_score: 0.9928 - val_loss: 0.2514 - val_accuracy: 0.7222 - val_f1_score: 0.5353 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0040 - accuracy: 0.9840 - f1_score: 0.9836 - val_loss: 0.2101 - val_accuracy: 0.6852 - val_f1_score: 0.6376 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9741 - f1_score: 0.9737
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0092 - accuracy: 0.9741 - f1_score: 0.9737 - val_loss: 0.2319 - val_accuracy: 0.6481 - val_f1_score: 0.6079 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0061 - accuracy: 0.9691 - f1_score: 0.9695 - val_loss: 0.3426 - val_accuracy: 0.7284 - val_f1_score: 0.6304 - lr: 5.0000e-04
# Epoch 33/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0038 - accuracy: 0.9860 - f1_score: 0.9852 - val_loss: 0.2168 - val_accuracy: 0.6883 - val_f1_score: 0.6386 - lr: 5.0000e-04
# Epoch 34/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0012 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2087 - val_accuracy: 0.7037 - val_f1_score: 0.6554 - lr: 5.0000e-04
# Epoch 35/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 6.6857e-04 - accuracy: 0.9980 - f1_score: 0.9968 - val_loss: 0.2046 - val_accuracy: 0.7099 - val_f1_score: 0.6564 - lr: 5.0000e-04
# Epoch 36/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6992e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.7037 - val_f1_score: 0.6599 - lr: 5.0000e-04
# Epoch 37/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.2117e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.7037 - val_f1_score: 0.6521 - lr: 5.0000e-04
# Epoch 38/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.7122e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.7006 - val_f1_score: 0.6485 - lr: 5.0000e-04
# Epoch 39/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 6.4060e-04 - accuracy: 0.9980 - f1_score: 0.9975 - val_loss: 0.2136 - val_accuracy: 0.6975 - val_f1_score: 0.6420 - lr: 5.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0014 - accuracy: 0.9950 - f1_score: 0.9950 - val_loss: 0.2460 - val_accuracy: 0.7037 - val_f1_score: 0.6312 - lr: 5.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0021 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.2099 - val_accuracy: 0.6296 - val_f1_score: 0.6408 - lr: 5.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0018 - accuracy: 0.9950 - f1_score: 0.9948 - val_loss: 0.2041 - val_accuracy: 0.6728 - val_f1_score: 0.6612 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0014 - accuracy: 0.9960 - f1_score: 0.9955 - val_loss: 0.2117 - val_accuracy: 0.6574 - val_f1_score: 0.6399 - lr: 5.0000e-04
# Epoch 44/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0014 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 0.2367 - val_accuracy: 0.6451 - val_f1_score: 0.6486 - lr: 5.0000e-04
# Epoch 45/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0020 - accuracy: 0.9920 - f1_score: 0.9915 - val_loss: 0.2603 - val_accuracy: 0.7006 - val_f1_score: 0.6623 - lr: 5.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 6.6008e-04 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.2878 - val_accuracy: 0.6975 - val_f1_score: 0.6262 - lr: 5.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 4.8788e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2383 - val_accuracy: 0.6914 - val_f1_score: 0.6451 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.3097e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.6975 - val_f1_score: 0.6520 - lr: 5.0000e-04
# Epoch 49/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 3.2082e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.7068 - val_f1_score: 0.6536 - lr: 5.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.4713e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2401 - val_accuracy: 0.7068 - val_f1_score: 0.6557 - lr: 5.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.6993e-04 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 0s 29ms/step - loss: 1.6993e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2413 - val_accuracy: 0.7037 - val_f1_score: 0.6541 - lr: 5.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.3025e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.6914 - val_f1_score: 0.6486 - lr: 2.5000e-04
# Epoch 53/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2107e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.7006 - val_f1_score: 0.6515 - lr: 2.5000e-04
# Epoch 54/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 4.2109e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2495 - val_accuracy: 0.7037 - val_f1_score: 0.6537 - lr: 2.5000e-04
# Epoch 55/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 5.1823e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2529 - val_accuracy: 0.7037 - val_f1_score: 0.6537 - lr: 2.5000e-04
# Epoch 56/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 5.3946e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.7037 - val_f1_score: 0.6537 - lr: 2.5000e-04
# Epoch 57/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 3.6853e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2577 - val_accuracy: 0.7006 - val_f1_score: 0.6494 - lr: 2.5000e-04
# Epoch 58/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 3.4281e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.6975 - val_f1_score: 0.6469 - lr: 2.5000e-04
# Epoch 59/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 4.8509e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.7006 - val_f1_score: 0.6494 - lr: 2.5000e-04
# Epoch 60/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.8855e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.7006 - val_f1_score: 0.6494 - lr: 2.5000e-04
# Epoch 61/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 7.6189e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.7006 - val_f1_score: 0.6494 - lr: 2.5000e-04
# Epoch 62/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.9601e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.7068 - val_f1_score: 0.6590 - lr: 2.5000e-04
# Epoch 63/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.0930e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2735 - val_accuracy: 0.6975 - val_f1_score: 0.6469 - lr: 2.5000e-04
# Epoch 64/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.4179e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.6944 - val_f1_score: 0.6423 - lr: 2.5000e-04
# Epoch 65/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 5.0857e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2772 - val_accuracy: 0.6944 - val_f1_score: 0.6423 - lr: 2.5000e-04
# Epoch 66/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.4042e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.6944 - val_f1_score: 0.6445 - lr: 2.5000e-04
# Epoch 67/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 4.8157e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2778 - val_accuracy: 0.6883 - val_f1_score: 0.6379 - lr: 2.5000e-04
# Epoch 68/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 6.3860e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2828 - val_accuracy: 0.6914 - val_f1_score: 0.6400 - lr: 2.5000e-04
# Epoch 69/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.0837e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.6914 - val_f1_score: 0.6375 - lr: 2.5000e-04
# Epoch 70/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.7975e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 2.5000e-04
# Epoch 71/10000
# 16/16 [==============================] - ETA: 0s - loss: 5.8836e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 [==============================] - 0s 25ms/step - loss: 5.8836e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 2.5000e-04
# Epoch 72/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2389e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 73/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.3533e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 74/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.1782e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 75/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.6208e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 76/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.3478e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 77/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.4716e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2885 - val_accuracy: 0.6914 - val_f1_score: 0.6371 - lr: 1.2500e-04
# Epoch 78/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 6.0931e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.6914 - val_f1_score: 0.6371 - lr: 1.2500e-04
# Epoch 79/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.0971e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.6914 - val_f1_score: 0.6371 - lr: 1.2500e-04
# Epoch 80/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 6.1832e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.6914 - val_f1_score: 0.6371 - lr: 1.2500e-04
# Epoch 81/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 8.4418e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.6914 - val_f1_score: 0.6371 - lr: 1.2500e-04
# Epoch 82/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 5.7962e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 83/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.6727e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 84/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.0123e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 85/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.1576e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2918 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 86/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.6911e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 87/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.5763e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 88/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 2.1256e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 89/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.6615e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 90/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 4.4284e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2917 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 91/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 2.0272e-05 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 91: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16/16 [==============================] - 0s 25ms/step - loss: 1.9440e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 1.2500e-04
# Epoch 92/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 6.2547e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.7037 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 93/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.7103e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.7037 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 94/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.0030e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.7037 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 95/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.2657e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.7037 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 96/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.4433e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2931 - val_accuracy: 0.7006 - val_f1_score: 0.6493 - lr: 6.2500e-05
# Epoch 97/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.0400e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.7006 - val_f1_score: 0.6493 - lr: 6.2500e-05
# Epoch 98/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.6761e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.7006 - val_f1_score: 0.6493 - lr: 6.2500e-05
# Epoch 99/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.8697e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2953 - val_accuracy: 0.6975 - val_f1_score: 0.6445 - lr: 6.2500e-05
# Epoch 100/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.0748e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2962 - val_accuracy: 0.6944 - val_f1_score: 0.6394 - lr: 6.2500e-05
# Epoch 101/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.7057e-04 - accuracy: 0.9990 - f1_score: 0.9989 - val_loss: 0.2951 - val_accuracy: 0.6944 - val_f1_score: 0.6421 - lr: 6.2500e-05
# Epoch 102/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 7.8040e-05 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 0.2924 - val_accuracy: 0.7037 - val_f1_score: 0.6606 - lr: 6.2500e-05
# Epoch 103/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.9734e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.7006 - val_f1_score: 0.6627 - lr: 6.2500e-05
# Epoch 104/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.2717e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.7006 - val_f1_score: 0.6627 - lr: 6.2500e-05
# Epoch 105/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.7138e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.6975 - val_f1_score: 0.6566 - lr: 6.2500e-05
# Epoch 106/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.2840e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2937 - val_accuracy: 0.7006 - val_f1_score: 0.6589 - lr: 6.2500e-05
# Epoch 107/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 9.3798e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.7006 - val_f1_score: 0.6589 - lr: 6.2500e-05
# Epoch 108/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.2561e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2945 - val_accuracy: 0.7037 - val_f1_score: 0.6606 - lr: 6.2500e-05
# Epoch 109/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.3835e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.7006 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 110/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.0171e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.7006 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 111/10000
# 16/16 [==============================] - ETA: 0s - loss: 1.3147e-05 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 11.
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16/16 [==============================] - 0s 27ms/step - loss: 1.3147e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.7006 - val_f1_score: 0.6517 - lr: 6.2500e-05
# Epoch 111: early stopping

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
# resnet50=build_model(32,96,192,256,384)
# resnet50.summary()

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
# resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 5.1161290322580646})

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 6ms/step
# 0.6975308641975309

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6975308641975309
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.44      0.53      0.48        85
#            0       0.82      0.76      0.79       239
#
#     accuracy                           0.70       324
#    macro avg       0.63      0.64      0.63       324
# weighted avg       0.72      0.70      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 226 chiếm khoảng 69.75308641975309% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 45 chiếm khoảng 52.94117647058824% so với thực tế
