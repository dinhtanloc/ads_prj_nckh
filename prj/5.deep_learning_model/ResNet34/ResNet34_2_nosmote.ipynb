# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 5

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
# from sklearn.metrics import f1_score
# import tensorflow as tf
# def f1_loss(y_true, y_pred):
#     true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
#     predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
#     possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
#     precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
#     recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
#     f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
#     return 1 - f1

# import tensorflow as tf

def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
import tensorflow as tf
from tensorflow import keras
from keras.activations import relu
from tensorflow.keras.layers import *
from tensorflow.keras import Model
from tensorflow.keras import layers as Layers


class ResBlock(Model):
    def __init__(self, channels, stride=1):
        super(ResBlock, self).__init__(name='ResBlock')
        self.flag = (stride != 1)
        self.conv1 = Conv1D(channels, 3, stride, padding='same')
        self.bn1 = BatchNormalization()
        self.conv2 = Conv1D(channels, 3, padding='same')
        self.bn2 = BatchNormalization()
        self.relu = ReLU()
        if self.flag:
            self.bn3 = BatchNormalization()
            self.conv3 = Conv1D(channels, 1, stride)

    def call(self, x):
        x1 = self.conv1(x)
        x1 = self.bn1(x1)
        x1 = self.relu(x1)
        x1 = self.conv2(x1)
        x1 = self.bn2(x1)
        if self.flag:
            x = self.conv3(x)
            x = self.bn3(x)
        x1 = Layers.add([x, x1])
        x1 = self.relu(x1)
        return x1


class ResNet34(Model):
    def __init__(self):
        super(ResNet34, self).__init__(name='ResNet34')
        self.conv1 = Conv1D(64, 7, 2, padding='same')
        self.bn = BatchNormalization()
        self.relu = ReLU()
        self.mp1 = MaxPooling1D(3, 2)

        self.conv2_1 = ResBlock(64)
        self.conv2_2 = ResBlock(64)
        self.conv2_3 = ResBlock(64)

        self.conv3_1 = ResBlock(128, 2)
        self.conv3_2 = ResBlock(128)
        self.conv3_3 = ResBlock(128)
        self.conv3_4 = ResBlock(128)

        self.conv4_1 = ResBlock(256, 2)
        self.conv4_2 = ResBlock(256)
        self.conv4_3 = ResBlock(256)
        self.conv4_4 = ResBlock(256)
        self.conv4_5 = ResBlock(256)
        self.conv4_6 = ResBlock(256)

        self.conv5_1 = ResBlock(512, 2)
        self.conv5_2 = ResBlock(512)
        self.conv5_3 = ResBlock(512)

        self.pool = GlobalAveragePooling1D()
        self.fc1 = Dense(2, activation='softmax')
        self.dp1 = Dropout(0.5)
        # self.fc2 = Dense(512, activation='relu')
        # self.dp2 = Dropout(0.5)
        # self.fc3 = Dense(64)

    def call(self, x):
        x = self.conv1(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.mp1(x)

        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.conv2_3(x)

        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.conv3_4(x)

        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        # x = self.conv4_4(x)
        # x = self.conv4_5(x)
        # x = self.conv4_6(x)

        # x = self.conv5_1(x)
        # x = self.conv5_2(x)
        # x = self.conv5_3(x)

        x = self.pool(x)
        x = self.dp1(x)
        x = self.fc1(x)
        # x = self.fc2(x)
        # x = self.dp2(x)
        # x = self.fc3(x)
        return x


model = ResNet34()
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])

model.build(input_shape=(None,42,1))
model.summary()
# Out:
# Model: "ResNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  512
#
#  batch_normalization (Batch  multiple                  256
#  Normalization)
#
#  re_lu (ReLU)                multiple                  0
#
#  max_pooling1d (MaxPooling1  multiple                  0
#  D)
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  83840
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  331520
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  global_average_pooling1d (  multiple                  0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               multiple                  514
#
#  dropout (Dropout)           multiple                  0
#
# =================================================================
# Total params: 1582594 (6.04 MB)
# Trainable params: 1575810 (6.01 MB)
# Non-trainable params: 6784 (26.50 KB)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 11/11 [==============================] - 8s 83ms/step - loss: 1.2990 - accuracy: 0.5152 - f1_score: 0.4681 - val_loss: 2.0552 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 2/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 1.0669 - accuracy: 0.5960 - f1_score: 0.5472 - val_loss: 0.7984 - val_accuracy: 0.7377 - val_f1_score: 0.4247 - lr: 0.0010
# Epoch 3/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 1.0112 - accuracy: 0.6204 - f1_score: 0.5715 - val_loss: 0.8040 - val_accuracy: 0.7346 - val_f1_score: 0.4238 - lr: 0.0010
# Epoch 4/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.9131 - accuracy: 0.5976 - f1_score: 0.5638 - val_loss: 0.7887 - val_accuracy: 0.4506 - val_f1_score: 0.4486 - lr: 0.0010
# Epoch 5/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.8112 - accuracy: 0.6692 - f1_score: 0.6126 - val_loss: 0.8201 - val_accuracy: 0.7377 - val_f1_score: 0.4355 - lr: 0.0010
# Epoch 6/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.7981 - accuracy: 0.7119 - f1_score: 0.6520 - val_loss: 2.2586 - val_accuracy: 0.5062 - val_f1_score: 0.4438 - lr: 0.0010
# Epoch 7/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.6260 - accuracy: 0.7454 - f1_score: 0.6902 - val_loss: 0.6625 - val_accuracy: 0.7346 - val_f1_score: 0.4627 - lr: 0.0010
# Epoch 8/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.4447 - accuracy: 0.8095 - f1_score: 0.7746 - val_loss: 0.6138 - val_accuracy: 0.7068 - val_f1_score: 0.4729 - lr: 0.0010
# Epoch 9/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.4843 - accuracy: 0.8323 - f1_score: 0.7742 - val_loss: 0.6827 - val_accuracy: 0.6667 - val_f1_score: 0.4868 - lr: 0.0010
# Epoch 10/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.6443 - accuracy: 0.7820 - f1_score: 0.7272 - val_loss: 0.7192 - val_accuracy: 0.6605 - val_f1_score: 0.6262 - lr: 0.0010
# Epoch 11/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5221 - accuracy: 0.7713 - f1_score: 0.7274 - val_loss: 0.7584 - val_accuracy: 0.7068 - val_f1_score: 0.4729 - lr: 0.0010
# Epoch 12/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3656 - accuracy: 0.8582 - f1_score: 0.8184 - val_loss: 0.9932 - val_accuracy: 0.6173 - val_f1_score: 0.5110 - lr: 0.0010
# Epoch 13/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3188 - accuracy: 0.8735 - f1_score: 0.8353 - val_loss: 0.9663 - val_accuracy: 0.6574 - val_f1_score: 0.5501 - lr: 0.0010
# Epoch 14/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2518 - accuracy: 0.8887 - f1_score: 0.8579 - val_loss: 0.9071 - val_accuracy: 0.6944 - val_f1_score: 0.5570 - lr: 0.0010
# Epoch 15/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1907 - accuracy: 0.9360 - f1_score: 0.9194 - val_loss: 1.0815 - val_accuracy: 0.6852 - val_f1_score: 0.6323 - lr: 0.0010
# Epoch 16/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1582 - accuracy: 0.9268 - f1_score: 0.8912 - val_loss: 1.3647 - val_accuracy: 0.7099 - val_f1_score: 0.4550 - lr: 0.0010
# Epoch 17/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2384 - accuracy: 0.9451 - f1_score: 0.9182 - val_loss: 1.1739 - val_accuracy: 0.6883 - val_f1_score: 0.6343 - lr: 0.0010
# Epoch 18/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2731 - accuracy: 0.8704 - f1_score: 0.8318 - val_loss: 0.9894 - val_accuracy: 0.6728 - val_f1_score: 0.6017 - lr: 0.0010
# Epoch 19/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.3025 - accuracy: 0.8902 - f1_score: 0.8491 - val_loss: 1.0440 - val_accuracy: 0.6080 - val_f1_score: 0.6005 - lr: 0.0010
# Epoch 20/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.4087 - accuracy: 0.8140 - f1_score: 0.7831 - val_loss: 0.7677 - val_accuracy: 0.6204 - val_f1_score: 0.6615 - lr: 0.0010
# Epoch 21/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2790 - accuracy: 0.8521 - f1_score: 0.8081 - val_loss: 1.1099 - val_accuracy: 0.6265 - val_f1_score: 0.6678 - lr: 0.0010
# Epoch 22/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1840 - accuracy: 0.9268 - f1_score: 0.9040 - val_loss: 1.3819 - val_accuracy: 0.6451 - val_f1_score: 0.6287 - lr: 0.0010
# Epoch 23/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1003 - accuracy: 0.9649 - f1_score: 0.9549 - val_loss: 2.1456 - val_accuracy: 0.5741 - val_f1_score: 0.6333 - lr: 0.0010
# Epoch 24/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0782 - accuracy: 0.9680 - f1_score: 0.9529 - val_loss: 2.1790 - val_accuracy: 0.5833 - val_f1_score: 0.6401 - lr: 0.0010
# Epoch 25/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1024 - accuracy: 0.9421 - f1_score: 0.9175 - val_loss: 1.7289 - val_accuracy: 0.6698 - val_f1_score: 0.6764 - lr: 0.0010
# Epoch 26/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0810 - accuracy: 0.9787 - f1_score: 0.9580 - val_loss: 1.8717 - val_accuracy: 0.6481 - val_f1_score: 0.6292 - lr: 0.0010
# Epoch 27/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1084 - accuracy: 0.9619 - f1_score: 0.9489 - val_loss: 1.9866 - val_accuracy: 0.6142 - val_f1_score: 0.6460 - lr: 0.0010
# Epoch 28/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1140 - accuracy: 0.9482 - f1_score: 0.9248 - val_loss: 1.4461 - val_accuracy: 0.6759 - val_f1_score: 0.6529 - lr: 0.0010
# Epoch 29/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1549 - accuracy: 0.9466 - f1_score: 0.9151 - val_loss: 1.5445 - val_accuracy: 0.6574 - val_f1_score: 0.6175 - lr: 0.0010
# Epoch 30/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2137 - accuracy: 0.9314 - f1_score: 0.9151 - val_loss: 1.4777 - val_accuracy: 0.7130 - val_f1_score: 0.6333 - lr: 0.0010
# Epoch 31/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1582 - accuracy: 0.9329 - f1_score: 0.9143 - val_loss: 1.3802 - val_accuracy: 0.6852 - val_f1_score: 0.6573 - lr: 0.0010
# Epoch 32/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2630 - accuracy: 0.8872 - f1_score: 0.8560 - val_loss: 1.3923 - val_accuracy: 0.5710 - val_f1_score: 0.5287 - lr: 0.0010
# Epoch 33/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2917 - accuracy: 0.8643 - f1_score: 0.8249 - val_loss: 1.3529 - val_accuracy: 0.6235 - val_f1_score: 0.6071 - lr: 0.0010
# Epoch 34/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2245 - accuracy: 0.8994 - f1_score: 0.8675 - val_loss: 1.1486 - val_accuracy: 0.6790 - val_f1_score: 0.6367 - lr: 0.0010
# Epoch 35/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1664 - accuracy: 0.9253 - f1_score: 0.9033 - val_loss: 1.4511 - val_accuracy: 0.6574 - val_f1_score: 0.6783 - lr: 0.0010
# Epoch 36/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1008 - accuracy: 0.9527 - f1_score: 0.9199 - val_loss: 1.6099 - val_accuracy: 0.6821 - val_f1_score: 0.6795 - lr: 0.0010
# Epoch 37/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1130 - accuracy: 0.9680 - f1_score: 0.9591 - val_loss: 1.8874 - val_accuracy: 0.6667 - val_f1_score: 0.6737 - lr: 0.0010
# Epoch 38/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1497 - accuracy: 0.9436 - f1_score: 0.9240 - val_loss: 2.2812 - val_accuracy: 0.5772 - val_f1_score: 0.5764 - lr: 0.0010
# Epoch 39/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1928 - accuracy: 0.9223 - f1_score: 0.8832 - val_loss: 1.7275 - val_accuracy: 0.6327 - val_f1_score: 0.6169 - lr: 0.0010
# Epoch 40/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.3380 - accuracy: 0.8140 - f1_score: 0.7743 - val_loss: 1.4029 - val_accuracy: 0.6914 - val_f1_score: 0.6843 - lr: 0.0010
# Epoch 41/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2706 - accuracy: 0.8750 - f1_score: 0.8379 - val_loss: 1.5119 - val_accuracy: 0.6327 - val_f1_score: 0.5963 - lr: 0.0010
# Epoch 42/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1884 - accuracy: 0.9223 - f1_score: 0.8898 - val_loss: 1.6368 - val_accuracy: 0.6759 - val_f1_score: 0.5989 - lr: 0.0010
# Epoch 43/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0917 - accuracy: 0.9756 - f1_score: 0.9613 - val_loss: 1.8475 - val_accuracy: 0.6728 - val_f1_score: 0.6587 - lr: 0.0010
# Epoch 44/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0599 - accuracy: 0.9771 - f1_score: 0.9663 - val_loss: 1.8924 - val_accuracy: 0.6790 - val_f1_score: 0.6562 - lr: 0.0010
# Epoch 45/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0546 - accuracy: 0.9771 - f1_score: 0.9709 - val_loss: 2.7888 - val_accuracy: 0.6142 - val_f1_score: 0.6362 - lr: 0.0010
# Epoch 46/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1584 - accuracy: 0.9558 - f1_score: 0.9251 - val_loss: 2.0493 - val_accuracy: 0.6296 - val_f1_score: 0.5966 - lr: 0.0010
# Epoch 47/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1840 - accuracy: 0.9466 - f1_score: 0.9048 - val_loss: 2.1038 - val_accuracy: 0.5802 - val_f1_score: 0.5416 - lr: 0.0010
# Epoch 48/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1428 - accuracy: 0.9314 - f1_score: 0.8886 - val_loss: 1.6945 - val_accuracy: 0.4815 - val_f1_score: 0.4729 - lr: 0.0010
# Epoch 49/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1594 - accuracy: 0.9512 - f1_score: 0.9290 - val_loss: 2.7594 - val_accuracy: 0.4846 - val_f1_score: 0.4313 - lr: 0.0010
# Epoch 50/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1196 - accuracy: 0.9436 - f1_score: 0.9328 - val_loss: 2.1337 - val_accuracy: 0.5833 - val_f1_score: 0.5800 - lr: 0.0010
# Epoch 51/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0355 - accuracy: 0.9939 - f1_score: 0.9924 - val_loss: 1.9017 - val_accuracy: 0.6728 - val_f1_score: 0.6363 - lr: 0.0010
# Epoch 52/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0260 - accuracy: 0.9909 - f1_score: 0.9875 - val_loss: 2.4529 - val_accuracy: 0.6235 - val_f1_score: 0.5709 - lr: 0.0010
# Epoch 53/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0121 - accuracy: 0.9970 - f1_score: 0.9951 - val_loss: 2.0258 - val_accuracy: 0.6728 - val_f1_score: 0.6297 - lr: 0.0010
# Epoch 54/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0172 - accuracy: 0.9939 - f1_score: 0.9908 - val_loss: 2.1799 - val_accuracy: 0.6698 - val_f1_score: 0.6688 - lr: 0.0010
# Epoch 55/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0062 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2017 - val_accuracy: 0.6728 - val_f1_score: 0.6608 - lr: 0.0010
# Epoch 56/10000
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0035 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2618 - val_accuracy: 0.6636 - val_f1_score: 0.6543 - lr: 0.0010
# Epoch 57/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0135 - accuracy: 0.9970 - f1_score: 0.9917 - val_loss: 2.6324 - val_accuracy: 0.6481 - val_f1_score: 0.6545 - lr: 0.0010
# Epoch 58/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2910 - accuracy: 0.9284 - f1_score: 0.9060 - val_loss: 1.4844 - val_accuracy: 0.6667 - val_f1_score: 0.5909 - lr: 0.0010
# Epoch 59/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1723 - accuracy: 0.9405 - f1_score: 0.9040 - val_loss: 1.4935 - val_accuracy: 0.6420 - val_f1_score: 0.6576 - lr: 0.0010
# Epoch 60/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.2119 - accuracy: 0.9219 - f1_score: 0.8981
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2085 - accuracy: 0.9238 - f1_score: 0.9074 - val_loss: 1.0250 - val_accuracy: 0.6821 - val_f1_score: 0.6624 - lr: 0.0010
# Epoch 61/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1031 - accuracy: 0.9558 - f1_score: 0.9398 - val_loss: 1.1398 - val_accuracy: 0.6975 - val_f1_score: 0.6869 - lr: 5.0000e-04
# Epoch 62/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0783 - accuracy: 0.9619 - f1_score: 0.9212 - val_loss: 1.8334 - val_accuracy: 0.5741 - val_f1_score: 0.5733 - lr: 5.0000e-04
# Epoch 63/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0776 - accuracy: 0.9680 - f1_score: 0.9594 - val_loss: 1.4027 - val_accuracy: 0.6512 - val_f1_score: 0.6616 - lr: 5.0000e-04
# Epoch 64/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0415 - accuracy: 0.9893 - f1_score: 0.9712 - val_loss: 1.4808 - val_accuracy: 0.6790 - val_f1_score: 0.6797 - lr: 5.0000e-04
# Epoch 65/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0203 - accuracy: 0.9970 - f1_score: 0.9957 - val_loss: 1.5403 - val_accuracy: 0.6821 - val_f1_score: 0.6809 - lr: 5.0000e-04
# Epoch 66/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0133 - accuracy: 0.9985 - f1_score: 0.9892 - val_loss: 1.5944 - val_accuracy: 0.6975 - val_f1_score: 0.6913 - lr: 5.0000e-04
# Epoch 67/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0198 - accuracy: 0.9970 - f1_score: 0.9909 - val_loss: 1.5936 - val_accuracy: 0.7037 - val_f1_score: 0.6868 - lr: 5.0000e-04
# Epoch 68/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0305 - accuracy: 0.9848 - f1_score: 0.9809 - val_loss: 1.8137 - val_accuracy: 0.6667 - val_f1_score: 0.6666 - lr: 5.0000e-04
# Epoch 69/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0220 - accuracy: 0.9893 - f1_score: 0.9817 - val_loss: 1.6922 - val_accuracy: 0.6975 - val_f1_score: 0.6516 - lr: 5.0000e-04
# Epoch 70/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0339 - accuracy: 0.9909 - f1_score: 0.9782 - val_loss: 1.6803 - val_accuracy: 0.6944 - val_f1_score: 0.6871 - lr: 5.0000e-04
# Epoch 71/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3632 - accuracy: 0.8780 - f1_score: 0.8567 - val_loss: 3.2339 - val_accuracy: 0.4537 - val_f1_score: 0.4532 - lr: 5.0000e-04
# Epoch 72/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1919 - accuracy: 0.9223 - f1_score: 0.8978 - val_loss: 1.3083 - val_accuracy: 0.5278 - val_f1_score: 0.5082 - lr: 5.0000e-04
# Epoch 73/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0955 - accuracy: 0.9604 - f1_score: 0.9264 - val_loss: 1.6611 - val_accuracy: 0.5432 - val_f1_score: 0.5233 - lr: 5.0000e-04
# Epoch 74/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0647 - accuracy: 0.9802 - f1_score: 0.9727 - val_loss: 1.6104 - val_accuracy: 0.5957 - val_f1_score: 0.5513 - lr: 5.0000e-04
# Epoch 75/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0302 - accuracy: 0.9939 - f1_score: 0.9920 - val_loss: 1.6403 - val_accuracy: 0.6265 - val_f1_score: 0.6440 - lr: 5.0000e-04
# Epoch 76/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0175 - accuracy: 0.9985 - f1_score: 0.9980 - val_loss: 1.6989 - val_accuracy: 0.6636 - val_f1_score: 0.6759 - lr: 5.0000e-04
# Epoch 77/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0138 - accuracy: 0.9970 - f1_score: 0.9958 - val_loss: 1.8107 - val_accuracy: 0.6667 - val_f1_score: 0.6765 - lr: 5.0000e-04
# Epoch 78/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0102 - accuracy: 0.9954 - f1_score: 0.9939 - val_loss: 1.7767 - val_accuracy: 0.6759 - val_f1_score: 0.6812 - lr: 5.0000e-04
# Epoch 79/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0176 - accuracy: 0.9939 - f1_score: 0.9910 - val_loss: 1.9313 - val_accuracy: 0.6667 - val_f1_score: 0.6746 - lr: 5.0000e-04
# Epoch 80/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0060 - accuracy: 0.9985 - f1_score: 0.9981 - val_loss: 1.8579 - val_accuracy: 0.6790 - val_f1_score: 0.6781 - lr: 5.0000e-04
# Epoch 81/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0032 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8060 - val_accuracy: 0.6759 - val_f1_score: 0.6626 - lr: 5.0000e-04
# Epoch 82/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0036 - accuracy: 0.9985 - f1_score: 0.9917 - val_loss: 1.7864 - val_accuracy: 0.6759 - val_f1_score: 0.6608 - lr: 5.0000e-04
# Epoch 83/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0091 - accuracy: 0.9985 - f1_score: 0.9937 - val_loss: 1.7291 - val_accuracy: 0.6852 - val_f1_score: 0.6522 - lr: 5.0000e-04
# Epoch 84/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0536 - accuracy: 0.9771 - f1_score: 0.9538 - val_loss: 2.6403 - val_accuracy: 0.6204 - val_f1_score: 0.6462 - lr: 5.0000e-04
# Epoch 85/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0299 - accuracy: 0.9863 - f1_score: 0.9825 - val_loss: 1.8241 - val_accuracy: 0.6728 - val_f1_score: 0.6399 - lr: 5.0000e-04
# Epoch 86/10000
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0288 - accuracy: 0.9931 - f1_score: 0.9900
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0349 - accuracy: 0.9924 - f1_score: 0.9751 - val_loss: 1.9362 - val_accuracy: 0.6605 - val_f1_score: 0.6499 - lr: 5.0000e-04
# Epoch 87/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0114 - accuracy: 0.9970 - f1_score: 0.9948 - val_loss: 1.7913 - val_accuracy: 0.6698 - val_f1_score: 0.6354 - lr: 2.5000e-04
# Epoch 88/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0110 - accuracy: 0.9970 - f1_score: 0.9901 - val_loss: 1.7915 - val_accuracy: 0.6821 - val_f1_score: 0.6522 - lr: 2.5000e-04
# Epoch 89/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0096 - accuracy: 0.9985 - f1_score: 0.9969 - val_loss: 1.7988 - val_accuracy: 0.6914 - val_f1_score: 0.6556 - lr: 2.5000e-04
# Epoch 90/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0059 - accuracy: 0.9985 - f1_score: 0.9981 - val_loss: 1.8091 - val_accuracy: 0.6944 - val_f1_score: 0.6576 - lr: 2.5000e-04
# Epoch 91/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0040 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8222 - val_accuracy: 0.7037 - val_f1_score: 0.6693 - lr: 2.5000e-04
# Epoch 92/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0033 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8244 - val_accuracy: 0.7037 - val_f1_score: 0.6693 - lr: 2.5000e-04
# Epoch 93/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0044 - accuracy: 0.9970 - f1_score: 0.9805 - val_loss: 1.8235 - val_accuracy: 0.7006 - val_f1_score: 0.6629 - lr: 2.5000e-04
# Epoch 94/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0074 - accuracy: 0.9954 - f1_score: 0.9712 - val_loss: 1.8097 - val_accuracy: 0.6975 - val_f1_score: 0.6455 - lr: 2.5000e-04
# Epoch 95/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8062 - val_accuracy: 0.6975 - val_f1_score: 0.6380 - lr: 2.5000e-04
# Epoch 96/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0072 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8465 - val_accuracy: 0.7068 - val_f1_score: 0.6592 - lr: 2.5000e-04
# Epoch 97/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0194 - accuracy: 0.9970 - f1_score: 0.9915 - val_loss: 1.8922 - val_accuracy: 0.7006 - val_f1_score: 0.6591 - lr: 2.5000e-04
# Epoch 98/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0112 - accuracy: 0.9939 - f1_score: 0.9858 - val_loss: 1.8769 - val_accuracy: 0.6975 - val_f1_score: 0.6275 - lr: 2.5000e-04
# Epoch 99/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0297 - accuracy: 0.9893 - f1_score: 0.9856 - val_loss: 1.9073 - val_accuracy: 0.6914 - val_f1_score: 0.6139 - lr: 2.5000e-04
# Epoch 100/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0098 - accuracy: 0.9954 - f1_score: 0.9942 - val_loss: 1.9282 - val_accuracy: 0.6975 - val_f1_score: 0.6497 - lr: 2.5000e-04
# Epoch 101/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0036 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9185 - val_accuracy: 0.6975 - val_f1_score: 0.6458 - lr: 2.5000e-04
# Epoch 102/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9151 - val_accuracy: 0.7006 - val_f1_score: 0.6479 - lr: 2.5000e-04
# Epoch 103/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0064 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9100 - val_accuracy: 0.7006 - val_f1_score: 0.6489 - lr: 2.5000e-04
# Epoch 104/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0025 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9194 - val_accuracy: 0.7037 - val_f1_score: 0.6609 - lr: 2.5000e-04
# Epoch 105/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9202 - val_accuracy: 0.7068 - val_f1_score: 0.6609 - lr: 2.5000e-04
# Epoch 106/10000
# 11/11 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9954 - f1_score: 0.9498
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0124 - accuracy: 0.9954 - f1_score: 0.9498 - val_loss: 1.9055 - val_accuracy: 0.7099 - val_f1_score: 0.6551 - lr: 2.5000e-04
# Epoch 107/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8995 - val_accuracy: 0.7068 - val_f1_score: 0.6277 - lr: 1.2500e-04
# Epoch 108/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0052 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9012 - val_accuracy: 0.7037 - val_f1_score: 0.6113 - lr: 1.2500e-04
# Epoch 109/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0143 - accuracy: 0.9970 - f1_score: 0.9964 - val_loss: 1.9402 - val_accuracy: 0.6944 - val_f1_score: 0.6219 - lr: 1.2500e-04
# Epoch 110/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0268 - accuracy: 0.9954 - f1_score: 0.9893 - val_loss: 1.9509 - val_accuracy: 0.7099 - val_f1_score: 0.6526 - lr: 1.2500e-04
# Epoch 111/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0040 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9681 - val_accuracy: 0.7006 - val_f1_score: 0.6293 - lr: 1.2500e-04
# Epoch 112/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0275 - accuracy: 0.9878 - f1_score: 0.9833 - val_loss: 1.9788 - val_accuracy: 0.6914 - val_f1_score: 0.6145 - lr: 1.2500e-04
# Epoch 113/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0092 - accuracy: 0.9954 - f1_score: 0.9936 - val_loss: 1.9942 - val_accuracy: 0.7006 - val_f1_score: 0.6615 - lr: 1.2500e-04
# Epoch 114/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0023 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0063 - val_accuracy: 0.6914 - val_f1_score: 0.6518 - lr: 1.2500e-04
# Epoch 115/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0054 - accuracy: 0.9970 - f1_score: 0.9814 - val_loss: 1.9909 - val_accuracy: 0.6852 - val_f1_score: 0.6382 - lr: 1.2500e-04
# Epoch 116/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0087 - accuracy: 0.9970 - f1_score: 0.9961 - val_loss: 1.9444 - val_accuracy: 0.7006 - val_f1_score: 0.6383 - lr: 1.2500e-04
# Epoch 117/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0067 - accuracy: 0.9985 - f1_score: 0.9966 - val_loss: 1.9592 - val_accuracy: 0.6975 - val_f1_score: 0.6360 - lr: 1.2500e-04
# Epoch 118/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0045 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9784 - val_accuracy: 0.6914 - val_f1_score: 0.6435 - lr: 1.2500e-04
# Epoch 119/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0030 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0040 - val_accuracy: 0.6914 - val_f1_score: 0.6509 - lr: 1.2500e-04
# Epoch 120/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0060 - accuracy: 0.9970 - f1_score: 0.9897 - val_loss: 2.0246 - val_accuracy: 0.6914 - val_f1_score: 0.6552 - lr: 1.2500e-04
# Epoch 121/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0030 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0299 - val_accuracy: 0.7006 - val_f1_score: 0.6614 - lr: 1.2500e-04
# Epoch 122/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0281 - val_accuracy: 0.6975 - val_f1_score: 0.6562 - lr: 1.2500e-04
# Epoch 123/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0279 - val_accuracy: 0.6975 - val_f1_score: 0.6562 - lr: 1.2500e-04
# Epoch 124/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0265 - val_accuracy: 0.7006 - val_f1_score: 0.6580 - lr: 1.2500e-04
# Epoch 125/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0020 - accuracy: 0.9985 - f1_score: 0.9930 - val_loss: 2.0247 - val_accuracy: 0.7006 - val_f1_score: 0.6580 - lr: 1.2500e-04
# Epoch 126/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 126: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0041 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0252 - val_accuracy: 0.7006 - val_f1_score: 0.6619 - lr: 1.2500e-04
# Epoch 127/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0284 - val_accuracy: 0.6975 - val_f1_score: 0.6626 - lr: 6.2500e-05
# Epoch 128/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0228 - val_accuracy: 0.7006 - val_f1_score: 0.6647 - lr: 6.2500e-05
# Epoch 129/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0168 - val_accuracy: 0.6975 - val_f1_score: 0.6607 - lr: 6.2500e-05
# Epoch 130/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0125 - val_accuracy: 0.7006 - val_f1_score: 0.6627 - lr: 6.2500e-05
# Epoch 131/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0127 - val_accuracy: 0.7006 - val_f1_score: 0.6606 - lr: 6.2500e-05
# Epoch 132/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0087 - val_accuracy: 0.6944 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 133/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0053 - val_accuracy: 0.6944 - val_f1_score: 0.6548 - lr: 6.2500e-05
# Epoch 134/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0023 - val_accuracy: 0.7006 - val_f1_score: 0.6590 - lr: 6.2500e-05
# Epoch 135/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0009 - val_accuracy: 0.7006 - val_f1_score: 0.6590 - lr: 6.2500e-05
# Epoch 136/10000
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0027 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9962 - val_accuracy: 0.6883 - val_f1_score: 0.6384 - lr: 6.2500e-05
# Epoch 137/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0013 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9952 - val_accuracy: 0.6883 - val_f1_score: 0.6387 - lr: 6.2500e-05
# Epoch 138/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 7.3451e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9964 - val_accuracy: 0.6883 - val_f1_score: 0.6387 - lr: 6.2500e-05
# Epoch 139/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 8.2964e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9977 - val_accuracy: 0.6883 - val_f1_score: 0.6387 - lr: 6.2500e-05
# Epoch 140/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 7.2906e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9952 - val_accuracy: 0.6883 - val_f1_score: 0.6387 - lr: 6.2500e-05
# Epoch 141/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 9.0526e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9918 - val_accuracy: 0.6883 - val_f1_score: 0.6387 - lr: 6.2500e-05
# Epoch 142/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 8.0088e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9921 - val_accuracy: 0.6914 - val_f1_score: 0.6432 - lr: 6.2500e-05
# Epoch 143/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 6.4960e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9917 - val_accuracy: 0.6914 - val_f1_score: 0.6432 - lr: 6.2500e-05
# Epoch 144/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0128 - accuracy: 0.9970 - f1_score: 0.9515 - val_loss: 1.9932 - val_accuracy: 0.6914 - val_f1_score: 0.6432 - lr: 6.2500e-05
# Epoch 145/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 8.6178e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9539 - val_accuracy: 0.7006 - val_f1_score: 0.6405 - lr: 6.2500e-05
# Epoch 146/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0042 - accuracy: 0.9984 - f1_score: 0.9983
# Epoch 146: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0041 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 1.9470 - val_accuracy: 0.6944 - val_f1_score: 0.6249 - lr: 6.2500e-05
# Epoch 147/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9490 - val_accuracy: 0.6944 - val_f1_score: 0.6249 - lr: 3.1250e-05
# Epoch 148/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9503 - val_accuracy: 0.6944 - val_f1_score: 0.6249 - lr: 3.1250e-05
# Epoch 149/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0073 - accuracy: 0.9970 - f1_score: 0.9818 - val_loss: 1.9593 - val_accuracy: 0.6914 - val_f1_score: 0.6265 - lr: 3.1250e-05
# Epoch 150/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9684 - val_accuracy: 0.6883 - val_f1_score: 0.6228 - lr: 3.1250e-05
# Epoch 151/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9705 - val_accuracy: 0.6883 - val_f1_score: 0.6228 - lr: 3.1250e-05
# Epoch 152/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9711 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 153/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9733 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 154/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9741 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 155/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0010 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9750 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 156/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9772 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 157/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9802 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 158/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9841 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 159/10000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9866 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 160/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9860 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 161/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9864 - val_accuracy: 0.6914 - val_f1_score: 0.6281 - lr: 3.1250e-05
# Epoch 162/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0019 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9886 - val_accuracy: 0.6944 - val_f1_score: 0.6354 - lr: 3.1250e-05
# Epoch 163/10000
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0017 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9919 - val_accuracy: 0.6944 - val_f1_score: 0.6354 - lr: 3.1250e-05
# Epoch 164/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9930 - val_accuracy: 0.6944 - val_f1_score: 0.6354 - lr: 3.1250e-05
# Epoch 165/10000
# 11/11 [==============================] - 0s 28ms/step - loss: 6.0487e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9947 - val_accuracy: 0.6944 - val_f1_score: 0.6354 - lr: 3.1250e-05
# Epoch 166/10000
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000   Restoring model weights from the end of the best epoch: 66.
#
# Epoch 166: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0019 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9968 - val_accuracy: 0.6944 - val_f1_score: 0.6354 - lr: 3.1250e-05
# Epoch 166: early stopping

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
# resnet50=build_model(32,96,192,256,384)
# resnet50.summary()

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
# resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 5.1161290322580646})

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.6975308641975309

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.6975308641975309
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.44      0.56      0.49        85
#            0       0.83      0.74      0.78       239
#
#     accuracy                           0.70       324
#    macro avg       0.63      0.65      0.64       324
# weighted avg       0.73      0.70      0.71       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 226 chiếm khoảng 69.75308641975309% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 48 chiếm khoảng 56.470588235294116% so với thực tế
