# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
# from sklearn.metrics import f1_score
# import tensorflow as tf
# def f1_loss(y_true, y_pred):
#     true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
#     predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
#     possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
#     precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
#     recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
#     f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
#     return 1 - f1

# import tensorflow as tf

def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
import tensorflow as tf
from tensorflow import keras
from keras.activations import relu
from tensorflow.keras.layers import *
from tensorflow.keras import Model
from tensorflow.keras import layers as Layers


class ResBlock(Model):
    def __init__(self, channels, stride=1):
        super(ResBlock, self).__init__(name='ResBlock')
        self.flag = (stride != 1)
        self.conv1 = Conv1D(channels, 3, stride, padding='same')
        self.bn1 = BatchNormalization()
        self.conv2 = Conv1D(channels, 3, padding='same')
        self.bn2 = BatchNormalization()
        self.relu = ReLU()
        if self.flag:
            self.bn3 = BatchNormalization()
            self.conv3 = Conv1D(channels, 1, stride)

    def call(self, x):
        x1 = self.conv1(x)
        x1 = self.bn1(x1)
        x1 = self.relu(x1)
        x1 = self.conv2(x1)
        x1 = self.bn2(x1)
        if self.flag:
            x = self.conv3(x)
            x = self.bn3(x)
        x1 = Layers.add([x, x1])
        x1 = self.relu(x1)
        return x1


class ResNet34(Model):
    def __init__(self):
        super(ResNet34, self).__init__(name='ResNet34')
        self.conv1 = Conv1D(64, 7, 2, padding='same')
        self.bn = BatchNormalization()
        self.relu = ReLU()
        self.mp1 = MaxPooling1D(3, 2)

        self.conv2_1 = ResBlock(64)
        self.conv2_2 = ResBlock(64)
        self.conv2_3 = ResBlock(64)

        self.conv3_1 = ResBlock(128, 2)
        self.conv3_2 = ResBlock(128)
        self.conv3_3 = ResBlock(128)
        self.conv3_4 = ResBlock(128)

        self.conv4_1 = ResBlock(256, 2)
        self.conv4_2 = ResBlock(256)
        self.conv4_3 = ResBlock(256)
        self.conv4_4 = ResBlock(256)
        self.conv4_5 = ResBlock(256)
        self.conv4_6 = ResBlock(256)

        self.conv5_1 = ResBlock(512, 2)
        self.conv5_2 = ResBlock(512)
        self.conv5_3 = ResBlock(512)

        self.pool = GlobalAveragePooling1D()
        self.fc1 = Dense(2, activation='softmax')
        self.dp1 = Dropout(0.5)
        # self.fc2 = Dense(512, activation='relu')
        # self.dp2 = Dropout(0.5)
        # self.fc3 = Dense(64)

    def call(self, x):
        x = self.conv1(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.mp1(x)

        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.conv2_3(x)

        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.conv3_4(x)

        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        # x = self.conv4_4(x)
        # x = self.conv4_5(x)
        # x = self.conv4_6(x)

        # x = self.conv5_1(x)
        # x = self.conv5_2(x)
        # x = self.conv5_3(x)

        x = self.pool(x)
        x = self.dp1(x)
        x = self.fc1(x)
        # x = self.fc2(x)
        # x = self.dp2(x)
        # x = self.fc3(x)
        return x


model = ResNet34()
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(learning_rate=0.001), loss=f1_loss, metrics=['accuracy',f1_score])

model.build(input_shape=(None,42,1))
model.summary()
# Out:
# Model: "ResNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  512
#
#  batch_normalization (Batch  multiple                  256
#  Normalization)
#
#  re_lu (ReLU)                multiple                  0
#
#  max_pooling1d (MaxPooling1  multiple                  0
#  D)
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  83840
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  331520
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  global_average_pooling1d (  multiple                  0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               multiple                  514
#
#  dropout (Dropout)           multiple                  0
#
# =================================================================
# Total params: 1582594 (6.04 MB)
# Trainable params: 1575810 (6.01 MB)
# Non-trainable params: 6784 (26.50 KB)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 8s 64ms/step - loss: 1.3247 - accuracy: 0.5469 - f1_score: 0.5099 - val_loss: 1.5561 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1949 - accuracy: 0.6108 - f1_score: 0.5794 - val_loss: 5.8084 - val_accuracy: 0.2623 - val_f1_score: 0.2054 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8657 - accuracy: 0.7146 - f1_score: 0.7056 - val_loss: 10.2785 - val_accuracy: 0.2593 - val_f1_score: 0.2055 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.6745 - accuracy: 0.7595 - f1_score: 0.7521 - val_loss: 0.8625 - val_accuracy: 0.6451 - val_f1_score: 0.5046 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6958 - accuracy: 0.7535 - f1_score: 0.7443 - val_loss: 0.8391 - val_accuracy: 0.7006 - val_f1_score: 0.5087 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.5201 - accuracy: 0.8084 - f1_score: 0.8051 - val_loss: 2.8443 - val_accuracy: 0.5617 - val_f1_score: 0.5385 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3384 - accuracy: 0.8543 - f1_score: 0.8526 - val_loss: 1.3224 - val_accuracy: 0.6235 - val_f1_score: 0.5591 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3515 - accuracy: 0.8802 - f1_score: 0.8771 - val_loss: 0.7722 - val_accuracy: 0.7037 - val_f1_score: 0.6278 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.4187 - accuracy: 0.8403 - f1_score: 0.8354 - val_loss: 1.1308 - val_accuracy: 0.6574 - val_f1_score: 0.5636 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2859 - accuracy: 0.8892 - f1_score: 0.8877 - val_loss: 0.8376 - val_accuracy: 0.7068 - val_f1_score: 0.6619 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1741 - accuracy: 0.9271 - f1_score: 0.9273 - val_loss: 0.9990 - val_accuracy: 0.6759 - val_f1_score: 0.6133 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1960 - accuracy: 0.9361 - f1_score: 0.9359 - val_loss: 1.1000 - val_accuracy: 0.6420 - val_f1_score: 0.6139 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.3000 - accuracy: 0.8882 - f1_score: 0.8852 - val_loss: 3.0127 - val_accuracy: 0.5401 - val_f1_score: 0.5220 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2994 - accuracy: 0.8663 - f1_score: 0.8639 - val_loss: 1.3735 - val_accuracy: 0.6451 - val_f1_score: 0.6101 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1948 - accuracy: 0.9182 - f1_score: 0.9158 - val_loss: 1.2112 - val_accuracy: 0.6605 - val_f1_score: 0.6344 - lr: 0.0010
# Epoch 16/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1460 - accuracy: 0.9461 - f1_score: 0.9462 - val_loss: 1.2354 - val_accuracy: 0.6451 - val_f1_score: 0.6454 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0726 - accuracy: 0.9661 - f1_score: 0.9659 - val_loss: 1.2749 - val_accuracy: 0.7037 - val_f1_score: 0.6753 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0840 - accuracy: 0.9641 - f1_score: 0.9640 - val_loss: 1.4502 - val_accuracy: 0.7006 - val_f1_score: 0.6587 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1132 - accuracy: 0.9681 - f1_score: 0.9677 - val_loss: 1.5317 - val_accuracy: 0.6852 - val_f1_score: 0.6649 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1495 - accuracy: 0.9451 - f1_score: 0.9441 - val_loss: 1.2349 - val_accuracy: 0.6821 - val_f1_score: 0.5739 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1509 - accuracy: 0.9391 - f1_score: 0.9374 - val_loss: 1.5346 - val_accuracy: 0.6728 - val_f1_score: 0.6098 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1273 - accuracy: 0.9521 - f1_score: 0.9517 - val_loss: 1.5103 - val_accuracy: 0.6451 - val_f1_score: 0.6489 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0844 - accuracy: 0.9651 - f1_score: 0.9641 - val_loss: 1.5638 - val_accuracy: 0.6667 - val_f1_score: 0.6129 - lr: 0.0010
# Epoch 24/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1241 - accuracy: 0.9521 - f1_score: 0.9522 - val_loss: 1.5004 - val_accuracy: 0.6944 - val_f1_score: 0.6233 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0630 - accuracy: 0.9701 - f1_score: 0.9704 - val_loss: 1.6683 - val_accuracy: 0.6944 - val_f1_score: 0.6248 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0406 - accuracy: 0.9880 - f1_score: 0.9876 - val_loss: 1.7625 - val_accuracy: 0.6667 - val_f1_score: 0.6268 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0384 - accuracy: 0.9850 - f1_score: 0.9851 - val_loss: 1.8166 - val_accuracy: 0.6883 - val_f1_score: 0.6553 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0422 - accuracy: 0.9900 - f1_score: 0.9890 - val_loss: 3.3153 - val_accuracy: 0.5957 - val_f1_score: 0.5812 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1216 - accuracy: 0.9721 - f1_score: 0.9704 - val_loss: 4.0003 - val_accuracy: 0.4722 - val_f1_score: 0.5070 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2072 - accuracy: 0.9271 - f1_score: 0.9267 - val_loss: 3.6576 - val_accuracy: 0.5370 - val_f1_score: 0.5207 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1409 - accuracy: 0.9451 - f1_score: 0.9434 - val_loss: 3.6020 - val_accuracy: 0.5309 - val_f1_score: 0.5163 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0643 - accuracy: 0.9701 - f1_score: 0.9690 - val_loss: 2.1577 - val_accuracy: 0.6512 - val_f1_score: 0.6675 - lr: 0.0010
# Epoch 33/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0701 - accuracy: 0.9681 - f1_score: 0.9678 - val_loss: 2.4629 - val_accuracy: 0.6790 - val_f1_score: 0.6432 - lr: 0.0010
# Epoch 34/10000
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0643 - accuracy: 0.9840 - f1_score: 0.9841 - val_loss: 1.9955 - val_accuracy: 0.6883 - val_f1_score: 0.5692 - lr: 0.0010
# Epoch 35/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0995 - accuracy: 0.9541 - f1_score: 0.9511 - val_loss: 3.3364 - val_accuracy: 0.6142 - val_f1_score: 0.5787 - lr: 0.0010
# Epoch 36/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0920 - accuracy: 0.9741 - f1_score: 0.9734 - val_loss: 2.7220 - val_accuracy: 0.6420 - val_f1_score: 0.6284 - lr: 0.0010
# Epoch 37/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0678 - accuracy: 0.9681 - f1_score: 0.9675 - val_loss: 2.0855 - val_accuracy: 0.6667 - val_f1_score: 0.6781 - lr: 0.0010
# Epoch 38/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0381 - accuracy: 0.9920 - f1_score: 0.9916 - val_loss: 1.8296 - val_accuracy: 0.7160 - val_f1_score: 0.6963 - lr: 0.0010
# Epoch 39/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0307 - accuracy: 0.9890 - f1_score: 0.9891 - val_loss: 2.1459 - val_accuracy: 0.6728 - val_f1_score: 0.6829 - lr: 0.0010
# Epoch 40/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0140 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 1.8815 - val_accuracy: 0.6975 - val_f1_score: 0.6601 - lr: 0.0010
# Epoch 41/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0151 - accuracy: 0.9940 - f1_score: 0.9939 - val_loss: 1.7729 - val_accuracy: 0.6944 - val_f1_score: 0.6075 - lr: 0.0010
# Epoch 42/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0145 - accuracy: 0.9930 - f1_score: 0.9931 - val_loss: 2.2101 - val_accuracy: 0.6698 - val_f1_score: 0.6605 - lr: 0.0010
# Epoch 43/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0469 - accuracy: 0.9860 - f1_score: 0.9862 - val_loss: 1.9268 - val_accuracy: 0.6914 - val_f1_score: 0.6674 - lr: 0.0010
# Epoch 44/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1415 - accuracy: 0.9551 - f1_score: 0.9540 - val_loss: 2.5772 - val_accuracy: 0.6574 - val_f1_score: 0.6533 - lr: 0.0010
# Epoch 45/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1462 - accuracy: 0.9321 - f1_score: 0.9308 - val_loss: 3.3976 - val_accuracy: 0.6512 - val_f1_score: 0.6333 - lr: 0.0010
# Epoch 46/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1026 - accuracy: 0.9651 - f1_score: 0.9625 - val_loss: 2.1232 - val_accuracy: 0.6728 - val_f1_score: 0.6494 - lr: 0.0010
# Epoch 47/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1148 - accuracy: 0.9611 - f1_score: 0.9594 - val_loss: 2.0798 - val_accuracy: 0.6667 - val_f1_score: 0.6629 - lr: 0.0010
# Epoch 48/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0722 - accuracy: 0.9701 - f1_score: 0.9705 - val_loss: 1.6141 - val_accuracy: 0.6852 - val_f1_score: 0.6545 - lr: 0.0010
# Epoch 49/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0375 - accuracy: 0.9880 - f1_score: 0.9882 - val_loss: 1.8350 - val_accuracy: 0.6698 - val_f1_score: 0.6559 - lr: 0.0010
# Epoch 50/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0178 - accuracy: 0.9910 - f1_score: 0.9911 - val_loss: 1.7696 - val_accuracy: 0.6605 - val_f1_score: 0.6552 - lr: 0.0010
# Epoch 51/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0104 - accuracy: 0.9970 - f1_score: 0.9964 - val_loss: 1.7530 - val_accuracy: 0.6759 - val_f1_score: 0.6704 - lr: 0.0010
# Epoch 52/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0401 - accuracy: 0.9860 - f1_score: 0.9862 - val_loss: 1.8918 - val_accuracy: 0.7006 - val_f1_score: 0.6963 - lr: 0.0010
# Epoch 53/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0389 - accuracy: 0.9880 - f1_score: 0.9881 - val_loss: 1.9568 - val_accuracy: 0.7191 - val_f1_score: 0.7149 - lr: 0.0010
# Epoch 54/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1024 - accuracy: 0.9721 - f1_score: 0.9716 - val_loss: 2.1972 - val_accuracy: 0.6574 - val_f1_score: 0.6595 - lr: 0.0010
# Epoch 55/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0487 - accuracy: 0.9850 - f1_score: 0.9845 - val_loss: 2.0746 - val_accuracy: 0.6698 - val_f1_score: 0.6597 - lr: 0.0010
# Epoch 56/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0223 - accuracy: 0.9920 - f1_score: 0.9921 - val_loss: 1.8744 - val_accuracy: 0.6698 - val_f1_score: 0.5997 - lr: 0.0010
# Epoch 57/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0110 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 1.7645 - val_accuracy: 0.7068 - val_f1_score: 0.6386 - lr: 0.0010
# Epoch 58/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0114 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 1.9959 - val_accuracy: 0.6975 - val_f1_score: 0.6080 - lr: 0.0010
# Epoch 59/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0311 - accuracy: 0.9880 - f1_score: 0.9881 - val_loss: 1.8893 - val_accuracy: 0.7191 - val_f1_score: 0.6883 - lr: 0.0010
# Epoch 60/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0147 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 1.7763 - val_accuracy: 0.7222 - val_f1_score: 0.6554 - lr: 0.0010
# Epoch 61/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0300 - accuracy: 0.9880 - f1_score: 0.9873 - val_loss: 1.7195 - val_accuracy: 0.7253 - val_f1_score: 0.6808 - lr: 0.0010
# Epoch 62/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0171 - accuracy: 0.9950 - f1_score: 0.9951 - val_loss: 2.1417 - val_accuracy: 0.6728 - val_f1_score: 0.6546 - lr: 0.0010
# Epoch 63/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0484 - accuracy: 0.9840 - f1_score: 0.9842 - val_loss: 2.0227 - val_accuracy: 0.6944 - val_f1_score: 0.6292 - lr: 0.0010
# Epoch 64/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0257 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 2.1913 - val_accuracy: 0.6543 - val_f1_score: 0.6441 - lr: 0.0010
# Epoch 65/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0505 - accuracy: 0.9870 - f1_score: 0.9871 - val_loss: 2.0095 - val_accuracy: 0.6914 - val_f1_score: 0.6802 - lr: 0.0010
# Epoch 66/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0261 - accuracy: 0.9880 - f1_score: 0.9882 - val_loss: 1.9710 - val_accuracy: 0.7191 - val_f1_score: 0.6482 - lr: 0.0010
# Epoch 67/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0569 - accuracy: 0.9760 - f1_score: 0.9760 - val_loss: 1.8742 - val_accuracy: 0.7284 - val_f1_score: 0.7132 - lr: 0.0010
# Epoch 68/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0294 - accuracy: 0.9890 - f1_score: 0.9880 - val_loss: 4.6370 - val_accuracy: 0.6327 - val_f1_score: 0.6264 - lr: 0.0010
# Epoch 69/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0427 - accuracy: 0.9870 - f1_score: 0.9860 - val_loss: 1.9283 - val_accuracy: 0.6821 - val_f1_score: 0.6697 - lr: 0.0010
# Epoch 70/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0130 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 2.0195 - val_accuracy: 0.7222 - val_f1_score: 0.6952 - lr: 0.0010
# Epoch 71/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0220 - accuracy: 0.9890 - f1_score: 0.9892 - val_loss: 1.9541 - val_accuracy: 0.7130 - val_f1_score: 0.6828 - lr: 0.0010
# Epoch 72/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0223 - accuracy: 0.9940 - f1_score: 0.9933 - val_loss: 1.9577 - val_accuracy: 0.6914 - val_f1_score: 0.6855 - lr: 0.0010
# Epoch 73/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0334 - accuracy: 0.9917 - f1_score: 0.9916
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0331 - accuracy: 0.9920 - f1_score: 0.9921 - val_loss: 1.9791 - val_accuracy: 0.6975 - val_f1_score: 0.7034 - lr: 0.0010
# Epoch 74/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0428 - accuracy: 0.9790 - f1_score: 0.9788 - val_loss: 2.2629 - val_accuracy: 0.6883 - val_f1_score: 0.6899 - lr: 5.0000e-04
# Epoch 75/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0124 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 1.9713 - val_accuracy: 0.7006 - val_f1_score: 0.6761 - lr: 5.0000e-04
# Epoch 76/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0061 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 1.8402 - val_accuracy: 0.7130 - val_f1_score: 0.6760 - lr: 5.0000e-04
# Epoch 77/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8570 - val_accuracy: 0.7099 - val_f1_score: 0.6649 - lr: 5.0000e-04
# Epoch 78/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0022 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8636 - val_accuracy: 0.7068 - val_f1_score: 0.6734 - lr: 5.0000e-04
# Epoch 79/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 8.7563e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8546 - val_accuracy: 0.6944 - val_f1_score: 0.6642 - lr: 5.0000e-04
# Epoch 80/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0011 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8319 - val_accuracy: 0.6883 - val_f1_score: 0.6600 - lr: 5.0000e-04
# Epoch 81/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 9.6617e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8294 - val_accuracy: 0.6883 - val_f1_score: 0.6617 - lr: 5.0000e-04
# Epoch 82/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 8.3550e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8339 - val_accuracy: 0.6821 - val_f1_score: 0.6553 - lr: 5.0000e-04
# Epoch 83/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0014 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8230 - val_accuracy: 0.6759 - val_f1_score: 0.6435 - lr: 5.0000e-04
# Epoch 84/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8333 - val_accuracy: 0.6914 - val_f1_score: 0.6533 - lr: 5.0000e-04
# Epoch 85/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 4.8808e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8502 - val_accuracy: 0.6883 - val_f1_score: 0.6449 - lr: 5.0000e-04
# Epoch 86/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 6.5362e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8629 - val_accuracy: 0.6883 - val_f1_score: 0.6449 - lr: 5.0000e-04
# Epoch 87/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 6.8405e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8732 - val_accuracy: 0.6852 - val_f1_score: 0.6429 - lr: 5.0000e-04
# Epoch 88/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 7.2200e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8800 - val_accuracy: 0.6944 - val_f1_score: 0.6509 - lr: 5.0000e-04
# Epoch 89/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 2.7214e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.8904 - val_accuracy: 0.6944 - val_f1_score: 0.6610 - lr: 5.0000e-04
# Epoch 90/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 3.5931e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9039 - val_accuracy: 0.6944 - val_f1_score: 0.6610 - lr: 5.0000e-04
# Epoch 91/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 4.2618e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9142 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 5.0000e-04
# Epoch 92/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.3354e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9265 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 5.0000e-04
# Epoch 93/10000
# 16/16 [==============================] - ETA: 0s - loss: 3.2821e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 0s 26ms/step - loss: 3.2821e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9412 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 5.0000e-04
# Epoch 94/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.5203e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9522 - val_accuracy: 0.7037 - val_f1_score: 0.6656 - lr: 2.5000e-04
# Epoch 95/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 9.1140e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9711 - val_accuracy: 0.6975 - val_f1_score: 0.6612 - lr: 2.5000e-04
# Epoch 96/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6803e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9880 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 2.5000e-04
# Epoch 97/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.8603e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 1.9972 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 98/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 2.0841e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0024 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 99/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 6.1929e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0096 - val_accuracy: 0.7037 - val_f1_score: 0.6656 - lr: 2.5000e-04
# Epoch 100/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 3.1357e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0163 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 2.5000e-04
# Epoch 101/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 3.0938e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0241 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 2.5000e-04
# Epoch 102/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.2708e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0321 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 103/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6300e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0365 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 104/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.1070e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0413 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 105/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.5717e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0450 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 106/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.3435e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0488 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 107/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.2330e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0530 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 108/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 2.2569e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0617 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 2.5000e-04
# Epoch 109/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.7075e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0669 - val_accuracy: 0.6975 - val_f1_score: 0.6613 - lr: 2.5000e-04
# Epoch 110/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.6586e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0749 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 2.5000e-04
# Epoch 111/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.0504e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0789 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 2.5000e-04
# Epoch 112/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 2.0689e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 2.5000e-04
# Epoch 113/10000
# 16/16 [==============================] - ETA: 0s - loss: 4.3726e-04 - accuracy: 1.0000 - f1_score: 1.0000
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 [==============================] - 0s 26ms/step - loss: 4.3726e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0819 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 2.5000e-04
# Epoch 114/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.4714e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0852 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 1.2500e-04
# Epoch 115/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2698e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0860 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 1.2500e-04
# Epoch 116/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.7274e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0898 - val_accuracy: 0.7006 - val_f1_score: 0.6634 - lr: 1.2500e-04
# Epoch 117/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 4.9833e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0930 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 118/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 3.6251e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.0977 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 119/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 2.6113e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1053 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 120/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.9346e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1107 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 121/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.8426e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1167 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 122/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2194e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1193 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 123/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2363e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1221 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 124/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.4887e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1227 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 125/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2914e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1215 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 126/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 1.7932e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1264 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 127/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.6609e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1275 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 128/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.5150e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1301 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 129/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.8563e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1328 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 130/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.3613e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1361 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 131/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.0181e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1384 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 132/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.4832e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1404 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 133/10000
# 16/16 [==============================] - ETA: 0s - loss: 8.0360e-04 - accuracy: 0.9990 - f1_score: 0.9990
# Epoch 133: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16/16 [==============================] - 0s 26ms/step - loss: 8.0360e-04 - accuracy: 0.9990 - f1_score: 0.9990 - val_loss: 2.1421 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 1.2500e-04
# Epoch 134/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6586e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1419 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 6.2500e-05
# Epoch 135/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.3082e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1422 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 6.2500e-05
# Epoch 136/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2400e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1420 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 6.2500e-05
# Epoch 137/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 5.9606e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1487 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 6.2500e-05
# Epoch 138/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 8.0096e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1507 - val_accuracy: 0.7006 - val_f1_score: 0.6635 - lr: 6.2500e-05
# Epoch 139/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6476e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1670 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 140/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 1.5823e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1655 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 141/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.0725e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1646 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 142/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.7683e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1651 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 143/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.8210e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1655 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 144/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.1677e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1611 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 145/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 2.4137e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1604 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 146/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0392e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1586 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 147/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2248e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1574 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 148/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.5537e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1562 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 149/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.7031e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1580 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 150/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 2.6573e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1603 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 151/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 1.4942e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1600 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 152/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 1.2071e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1598 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 153/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3377e-04 - accuracy: 1.0000 - f1_score: 1.0000Restoring model weights from the end of the best epoch: 53.
#
# Epoch 153: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16/16 [==============================] - 0s 28ms/step - loss: 1.3063e-04 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1620 - val_accuracy: 0.6944 - val_f1_score: 0.6592 - lr: 6.2500e-05
# Epoch 153: early stopping

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
# resnet50=build_model(32,96,192,256,384)
# resnet50.summary()

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
# resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 5.1161290322580646})

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.7191358024691358

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7191358024691358
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.47      0.60      0.53        85
#            0       0.84      0.76      0.80       239
#
#     accuracy                           0.72       324
#    macro avg       0.66      0.68      0.66       324
# weighted avg       0.75      0.72      0.73       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 233 chiếm khoảng 71.91358024691358% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 51 chiếm khoảng 60.0% so với thực tế
