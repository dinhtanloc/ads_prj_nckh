# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)

from libs.lib import *
# Out:
# d:\ads_test
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Set data order
data_order = 8

# %%
# wandb.init(project="ads1_prj_VGG19n")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
exps_dir = "../../../exps"
# exps_dir = sys.argv[3]

if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
dict_data=[]
y_list = []
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    
    # Khởi tạo một trình chuyển đổi OneHotEncoder
    encoder = OneHotEncoder()
    
    # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
    labels_reshaped = labels.reshape(-1, 1)
    
    # Fit trình chuyển đổi vào dữ liệu
    encoder.fit(labels_reshaped)
    
    # Chuyển đổi labels sang dạng one-hot encoding
    onehot_labels = encoder.transform(labels_reshaped)
    return onehot_labels
for scaler in ['Standard_Label','MinMax_Label']:
    for type in ['basic','class_dict_weight','Oversampling','SMOTE','Undersampling']:
        x_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_train.xlsx')
        y_train = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_train.xlsx')
        x_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/x_test.xlsx')
        y_test = pd.read_excel(f'{exps_dir}/{scaler}/{type}/feature/y_test.xlsx')
        y_list.append(y_test)
        y_train=oneHot(y_train)
        y_test=oneHot(y_test)
        # Tạo một tensor TensorFlow
        # data_table = tf.placeholder(shape=(None, 42), dtype=tf.float32)  # Đây là một ví dụ, bạn có thể có dữ liệu thực tế khác

        # Thêm một chiều mới vào cuối tensor
        x_train = tf.expand_dims(x_train, axis=-1)
        x_test = tf.expand_dims(x_test, axis=-1)
        print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
        dict_data.append((x_train,y_train,x_test,y_test))

class_weights_dict=dict(np.load(f'{exps_dir}/Standard_Label/class_dict_weight/feature/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
print(len(dict_data))
# Out:
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (656, 42, 1) (656, 2) (324, 42, 1) (324, 2)
# (1001, 42, 1) (1001, 2) (324, 42, 1) (324, 2)
# (1002, 42, 1) (1002, 2) (324, 42, 1) (324, 2)
# (355, 42, 1) (355, 2) (324, 42, 1) (324, 2)
# 10

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{exps_dir}/feature1/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np

# # Dữ liệu label đã được mã hóa
# def oneHot(arr):
#     labels = np.array(arr)
#     # Khởi tạo một trình chuyển đổi OneHotEncoder
#     encoder = OneHotEncoder(sparse=False)
    
#     # Reshape lại dữ liệu labels để có dạng cột (cần là ma trận 2D)
#     labels_reshaped = labels.reshape(-1, 1)
    
#     # Fit trình chuyển đổi vào dữ liệu
#     encoder.fit(labels_reshaped)
    
#     # Chuyển đổi labels sang dạng one-hot encoding
#     onehot_labels = encoder.transform(labels_reshaped)
#     return onehot_labels

# y_train=oneHot(y_train)
# y_test=oneHot(y_test)

# %%
x_test.shape
# Out:
# (330, 42)

# %%
x_train.shape
# Out:
# (1022, 42)

# %% [markdown]
# #### * Xây dựng model:

# %%
#from tensorflow.keras.utils import to_categorical
#y_train = to_categorical(y_train, num_classes=2)
#y_test = to_categorical(y_test, num_classes=2)
#y_train

# %%
# from sklearn.metrics import f1_score
# import tensorflow as tf
# def f1_loss(y_true, y_pred):
#     true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32))
#     predicted_positives = tf.reduce_sum(tf.cast(y_pred, tf.float32))
#     possible_positives = tf.reduce_sum(tf.cast(y_true, tf.float32))
    
#     precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
#     recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    
#     f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
#     return 1 - f1

# import tensorflow as tf

def f1_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Calculate true positives, predicted positives, and possible positives for each class
    tp = tf.reduce_sum(y_true * y_pred, axis=0)
    predicted_positives = tf.reduce_sum(y_pred, axis=0)
    possible_positives = tf.reduce_sum(y_true, axis=0)
    
    # Calculate precision and recall for each class
    precision = tp / (predicted_positives + tf.keras.backend.epsilon())
    recall = tp / (possible_positives + tf.keras.backend.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    
    # Calculate the macro F1 score
    f1_macro = tf.reduce_mean(f1)
    
    # Return the F1 loss
    return 1 - f1_macro

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=-1)
    denominator = tf.reduce_sum(y_true + y_pred, axis=-1)
    return 1 - (numerator + 1) / (denominator + 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
# from keras import backend as K

# def f1_score(y_true, y_pred):
#     """
#     F1 score metric.
#     """
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
#     precision = true_positives / (predicted_positives + K.epsilon())
#     recall = true_positives / (possible_positives + K.epsilon())
    
#     f1_score = 2 * (precision * recall) / (precision + recall + K.epsilon())
#     return f1_score



def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    # Convert predictions to binary (0 or 1)
    y_pred = K.round(y_pred)
    
    # Calculate True Positives, False Positives and False Negatives for each class
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)
    
    # Calculate precision and recall for each class
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())
    
    # Calculate F1 score for each class
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Calculate macro F1 score
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# Example of how to use the custom F1 score metric in model compilation

# %%
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, BatchNormalization, Activation, add, MaxPooling1D, GlobalAveragePooling1D, Dense
from keras.models import Model
import keras.backend as K

def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=2):
    """A block that has a conv layer at shortcut."""
    filters1, filters2, filters3 = filters
    bn_axis=1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv1D(filters1, 1, strides=strides, name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters2, kernel_size, padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv1D(filters3, 1, name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv1D(filters3, 1, strides=strides, name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
early_stopping = EarlyStopping(monitor='val_f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.hdf5',  # Đường dẫn để lưu model
    monitor='val_f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1,  # Hiển thị thông báo khi lưu model
    save_format="tf"
)

# %%
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import ZeroPadding1D, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, BatchNormalization, Activation, concatenate, Input
# from tensorflow.keras.models import Model
# from scikeras.wrappers import KerasClassifier 

# def build_model(filters1, filters2, filters3):
#     input_shape = (42, 1)
#     x_input = Input(shape=input_shape)

#     bn_axis = -1

#     x = ZeroPadding1D(padding=1)(x_input)
#     x = Conv1D(64, 7, strides=2, padding='same', name='conv1')(x)
#     x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     x = Activation('relu')(x)
#     x = MaxPooling1D(3, strides=2)(x)

#     # ResNet blocks
#     x = conv_block(x, 3, [filters1, filters1, filters2], stage=2, block='a', strides=1)
#     block1_output = identity_block(x, 3, [filters1, filters1, filters2], stage=2, block='b')
#     x = identity_block(block1_output, 3, [filters1, filters1, filters2], stage=2, block='c')

#     x = conv_block(x, 3, [filters2, filters2, filters3], stage=3, block='a')
#     block2_output = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='b')
#     x = identity_block(block2_output, 3, [filters2, filters2, filters3], stage=3, block='c')
#     x = identity_block(x, 3, [filters2, filters2, filters3], stage=3, block='d')

   

#     # Hypercolumn formation
#     hypercolumns = concatenate([GlobalAveragePooling1D()(block1_output),
#                                 GlobalAveragePooling1D()(block2_output),
#                                 GlobalAveragePooling1D()(x)], axis=-1)

#     # Final Dense layers
#     x = Dense(128, activation='relu')(hypercolumns)
#     x = Dense(2, activation='softmax', name='fc1000')(x)

#     # Create model
#     model = Model(inputs=x_input, outputs=x, name='resnet50_1d_hypercolumn')

#     # Compile model
#     model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
    
#     return model

# %%
import tensorflow as tf
from tensorflow import keras
from keras.activations import relu
from tensorflow.keras.layers import *
from tensorflow.keras import Model
from tensorflow.keras import layers as Layers


class ResBlock(Model):
    def __init__(self, channels, stride=1):
        super(ResBlock, self).__init__(name='ResBlock')
        self.flag = (stride != 1)
        self.conv1 = Conv1D(channels, 3, stride, padding='same')
        self.bn1 = BatchNormalization()
        self.conv2 = Conv1D(channels, 3, padding='same')
        self.bn2 = BatchNormalization()
        self.relu = ReLU()
        if self.flag:
            self.bn3 = BatchNormalization()
            self.conv3 = Conv1D(channels, 1, stride)

    def call(self, x):
        x1 = self.conv1(x)
        x1 = self.bn1(x1)
        x1 = self.relu(x1)
        x1 = self.conv2(x1)
        x1 = self.bn2(x1)
        if self.flag:
            x = self.conv3(x)
            x = self.bn3(x)
        x1 = Layers.add([x, x1])
        x1 = self.relu(x1)
        return x1


class ResNet34(Model):
    def __init__(self):
        super(ResNet34, self).__init__(name='ResNet34')
        self.conv1 = Conv1D(64, 7, 2, padding='same')
        self.bn = BatchNormalization()
        self.relu = ReLU()
        self.mp1 = MaxPooling1D(3, 2)

        self.conv2_1 = ResBlock(64)
        self.conv2_2 = ResBlock(64)
        self.conv2_3 = ResBlock(64)

        self.conv3_1 = ResBlock(128, 2)
        self.conv3_2 = ResBlock(128)
        self.conv3_3 = ResBlock(128)
        self.conv3_4 = ResBlock(128)

        self.conv4_1 = ResBlock(256, 2)
        self.conv4_2 = ResBlock(256)
        self.conv4_3 = ResBlock(256)
        self.conv4_4 = ResBlock(256)
        self.conv4_5 = ResBlock(256)
        self.conv4_6 = ResBlock(256)

        self.conv5_1 = ResBlock(512, 2)
        self.conv5_2 = ResBlock(512)
        self.conv5_3 = ResBlock(512)

        self.pool = GlobalAveragePooling1D()
        self.fc1 = Dense(2, activation='softmax')
        self.dp1 = Dropout(0.5)
        # self.fc2 = Dense(512, activation='relu')
        # self.dp2 = Dropout(0.5)
        # self.fc3 = Dense(64)

    def call(self, x):
        x = self.conv1(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.mp1(x)

        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.conv2_3(x)

        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.conv3_4(x)

        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        # x = self.conv4_4(x)
        # x = self.conv4_5(x)
        # x = self.conv4_6(x)

        # x = self.conv5_1(x)
        # x = self.conv5_2(x)
        # x = self.conv5_3(x)

        x = self.pool(x)
        x = self.dp1(x)
        x = self.fc1(x)
        # x = self.fc2(x)
        # x = self.dp2(x)
        # x = self.fc3(x)
        return x


model = ResNet34()
model.compile(optimizer=Adam(learning_rate=0.001), loss=dice_coef_loss, metrics=['accuracy',f1_score])

model.build(input_shape=(None,42,1))
model.summary()
# Out:
# Model: "ResNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  512
#
#  batch_normalization (Batch  multiple                  256
#  Normalization)
#
#  re_lu (ReLU)                multiple                  0
#
#  max_pooling1d (MaxPooling1  multiple                  0
#  D)
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  25216
#
#  ResBlock (ResBlock)         multiple                  83840
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  99584
#
#  ResBlock (ResBlock)         multiple                  331520
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  395776
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  ResBlock (ResBlock)         multiple                  0 (unused)
#
#  global_average_pooling1d (  multiple                  0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               multiple                  514
#
#  dropout (Dropout)           multiple                  0
#
# =================================================================
# Total params: 1582594 (6.04 MB)
# Trainable params: 1575810 (6.01 MB)
# Non-trainable params: 6784 (26.50 KB)
# _________________________________________________________________

# %%
model.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
          validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
          batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})
# Out:
# Epoch 1/10000
# 16/16 [==============================] - 8s 63ms/step - loss: 0.5544 - accuracy: 0.6068 - f1_score: 0.6035 - val_loss: 0.7398 - val_accuracy: 0.2593 - val_f1_score: 0.2036 - lr: 0.0010
# Epoch 2/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4119 - accuracy: 0.7046 - f1_score: 0.7009 - val_loss: 0.2704 - val_accuracy: 0.7284 - val_f1_score: 0.4287 - lr: 0.0010
# Epoch 3/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3928 - accuracy: 0.7146 - f1_score: 0.7149 - val_loss: 0.2714 - val_accuracy: 0.7284 - val_f1_score: 0.4515 - lr: 0.0010
# Epoch 4/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3882 - accuracy: 0.7206 - f1_score: 0.7167 - val_loss: 0.2728 - val_accuracy: 0.7284 - val_f1_score: 0.4638 - lr: 0.0010
# Epoch 5/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.4053 - accuracy: 0.7086 - f1_score: 0.7063 - val_loss: 0.3841 - val_accuracy: 0.6204 - val_f1_score: 0.4995 - lr: 0.0010
# Epoch 6/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3077 - accuracy: 0.7754 - f1_score: 0.7702 - val_loss: 0.3697 - val_accuracy: 0.6235 - val_f1_score: 0.5368 - lr: 0.0010
# Epoch 7/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3350 - accuracy: 0.7575 - f1_score: 0.7556 - val_loss: 0.5896 - val_accuracy: 0.4074 - val_f1_score: 0.4146 - lr: 0.0010
# Epoch 8/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3175 - accuracy: 0.7705 - f1_score: 0.7683 - val_loss: 0.2669 - val_accuracy: 0.7346 - val_f1_score: 0.5174 - lr: 0.0010
# Epoch 9/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3731 - accuracy: 0.7315 - f1_score: 0.7325 - val_loss: 0.4650 - val_accuracy: 0.5370 - val_f1_score: 0.5148 - lr: 0.0010
# Epoch 10/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2822 - accuracy: 0.7954 - f1_score: 0.7955 - val_loss: 0.3613 - val_accuracy: 0.6358 - val_f1_score: 0.5252 - lr: 0.0010
# Epoch 11/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2692 - accuracy: 0.8044 - f1_score: 0.8033 - val_loss: 0.4093 - val_accuracy: 0.5864 - val_f1_score: 0.4884 - lr: 0.0010
# Epoch 12/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3274 - accuracy: 0.7645 - f1_score: 0.7604 - val_loss: 0.3148 - val_accuracy: 0.6883 - val_f1_score: 0.6518 - lr: 0.0010
# Epoch 13/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2898 - accuracy: 0.7914 - f1_score: 0.7910 - val_loss: 0.2597 - val_accuracy: 0.7407 - val_f1_score: 0.5362 - lr: 0.0010
# Epoch 14/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3523 - accuracy: 0.7455 - f1_score: 0.7436 - val_loss: 0.2729 - val_accuracy: 0.7284 - val_f1_score: 0.5091 - lr: 0.0010
# Epoch 15/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3307 - accuracy: 0.7625 - f1_score: 0.7632 - val_loss: 0.2738 - val_accuracy: 0.7284 - val_f1_score: 0.5840 - lr: 0.0010
# Epoch 16/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2905 - accuracy: 0.7924 - f1_score: 0.7886 - val_loss: 0.3706 - val_accuracy: 0.6296 - val_f1_score: 0.5011 - lr: 0.0010
# Epoch 17/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2674 - accuracy: 0.8064 - f1_score: 0.8062 - val_loss: 0.3377 - val_accuracy: 0.6605 - val_f1_score: 0.5684 - lr: 0.0010
# Epoch 18/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2365 - accuracy: 0.8313 - f1_score: 0.8304 - val_loss: 0.2758 - val_accuracy: 0.7253 - val_f1_score: 0.7035 - lr: 0.0010
# Epoch 19/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.3069 - accuracy: 0.7784 - f1_score: 0.7754 - val_loss: 0.5870 - val_accuracy: 0.4167 - val_f1_score: 0.4631 - lr: 0.0010
# Epoch 20/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3252 - accuracy: 0.7625 - f1_score: 0.7588 - val_loss: 0.3897 - val_accuracy: 0.6080 - val_f1_score: 0.6012 - lr: 0.0010
# Epoch 21/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3523 - accuracy: 0.7455 - f1_score: 0.7435 - val_loss: 0.6364 - val_accuracy: 0.3673 - val_f1_score: 0.3351 - lr: 0.0010
# Epoch 22/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3187 - accuracy: 0.7725 - f1_score: 0.7715 - val_loss: 0.4679 - val_accuracy: 0.5309 - val_f1_score: 0.5165 - lr: 0.0010
# Epoch 23/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2473 - accuracy: 0.8194 - f1_score: 0.8188 - val_loss: 0.3137 - val_accuracy: 0.6852 - val_f1_score: 0.6297 - lr: 0.0010
# Epoch 24/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.3163 - accuracy: 0.7695 - f1_score: 0.7602 - val_loss: 0.3023 - val_accuracy: 0.6944 - val_f1_score: 0.6624 - lr: 0.0010
# Epoch 25/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2512 - accuracy: 0.8174 - f1_score: 0.8141 - val_loss: 0.3159 - val_accuracy: 0.6821 - val_f1_score: 0.6254 - lr: 0.0010
# Epoch 26/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3346 - accuracy: 0.7605 - f1_score: 0.7560 - val_loss: 0.4529 - val_accuracy: 0.5463 - val_f1_score: 0.5295 - lr: 0.0010
# Epoch 27/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3010 - accuracy: 0.7844 - f1_score: 0.7819 - val_loss: 0.3557 - val_accuracy: 0.6451 - val_f1_score: 0.5128 - lr: 0.0010
# Epoch 28/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2848 - accuracy: 0.7934 - f1_score: 0.7906 - val_loss: 0.3101 - val_accuracy: 0.6914 - val_f1_score: 0.6033 - lr: 0.0010
# Epoch 29/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2320 - accuracy: 0.8313 - f1_score: 0.8312 - val_loss: 0.3867 - val_accuracy: 0.6142 - val_f1_score: 0.6032 - lr: 0.0010
# Epoch 30/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2519 - accuracy: 0.8174 - f1_score: 0.8155 - val_loss: 0.3930 - val_accuracy: 0.6080 - val_f1_score: 0.6054 - lr: 0.0010
# Epoch 31/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2587 - accuracy: 0.8134 - f1_score: 0.8106 - val_loss: 0.2761 - val_accuracy: 0.7222 - val_f1_score: 0.6552 - lr: 0.0010
# Epoch 32/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2501 - accuracy: 0.8214 - f1_score: 0.8219 - val_loss: 0.2957 - val_accuracy: 0.7037 - val_f1_score: 0.6567 - lr: 0.0010
# Epoch 33/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2492 - accuracy: 0.8224 - f1_score: 0.8185 - val_loss: 0.3127 - val_accuracy: 0.6883 - val_f1_score: 0.5473 - lr: 0.0010
# Epoch 34/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2942 - accuracy: 0.7884 - f1_score: 0.7883 - val_loss: 0.3776 - val_accuracy: 0.6235 - val_f1_score: 0.5192 - lr: 0.0010
# Epoch 35/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2452 - accuracy: 0.8253 - f1_score: 0.8248 - val_loss: 0.3473 - val_accuracy: 0.6512 - val_f1_score: 0.6607 - lr: 0.0010
# Epoch 36/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.3322 - accuracy: 0.7625 - f1_score: 0.7565 - val_loss: 0.3361 - val_accuracy: 0.6605 - val_f1_score: 0.6764 - lr: 0.0010
# Epoch 37/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3386 - accuracy: 0.7545 - f1_score: 0.7490 - val_loss: 0.6447 - val_accuracy: 0.3580 - val_f1_score: 0.4089 - lr: 0.0010
# Epoch 38/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3673 - accuracy: 0.7375 - f1_score: 0.7365
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3664 - accuracy: 0.7365 - f1_score: 0.7349 - val_loss: 0.6775 - val_accuracy: 0.3210 - val_f1_score: 0.3316 - lr: 0.0010
# Epoch 39/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3504 - accuracy: 0.7455 - f1_score: 0.7436 - val_loss: 0.6065 - val_accuracy: 0.3920 - val_f1_score: 0.4002 - lr: 5.0000e-04
# Epoch 40/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2537 - accuracy: 0.8174 - f1_score: 0.8145 - val_loss: 0.4090 - val_accuracy: 0.5926 - val_f1_score: 0.5621 - lr: 5.0000e-04
# Epoch 41/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2359 - accuracy: 0.8283 - f1_score: 0.8260 - val_loss: 0.3593 - val_accuracy: 0.6420 - val_f1_score: 0.6330 - lr: 5.0000e-04
# Epoch 42/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2527 - accuracy: 0.8184 - f1_score: 0.8176 - val_loss: 0.4060 - val_accuracy: 0.5957 - val_f1_score: 0.5990 - lr: 5.0000e-04
# Epoch 43/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2291 - accuracy: 0.8343 - f1_score: 0.8349 - val_loss: 0.2680 - val_accuracy: 0.7315 - val_f1_score: 0.7278 - lr: 5.0000e-04
# Epoch 44/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2188 - accuracy: 0.8423 - f1_score: 0.8410 - val_loss: 0.2739 - val_accuracy: 0.7253 - val_f1_score: 0.5842 - lr: 5.0000e-04
# Epoch 45/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2358 - accuracy: 0.8303 - f1_score: 0.8285 - val_loss: 0.2524 - val_accuracy: 0.7500 - val_f1_score: 0.6403 - lr: 5.0000e-04
# Epoch 46/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2216 - accuracy: 0.8373 - f1_score: 0.8363 - val_loss: 0.2434 - val_accuracy: 0.7562 - val_f1_score: 0.6563 - lr: 5.0000e-04
# Epoch 47/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2333 - accuracy: 0.8323 - f1_score: 0.8307 - val_loss: 0.2603 - val_accuracy: 0.7377 - val_f1_score: 0.6221 - lr: 5.0000e-04
# Epoch 48/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2158 - accuracy: 0.8443 - f1_score: 0.8439 - val_loss: 0.2585 - val_accuracy: 0.7407 - val_f1_score: 0.6345 - lr: 5.0000e-04
# Epoch 49/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2107 - accuracy: 0.8483 - f1_score: 0.8473 - val_loss: 0.2562 - val_accuracy: 0.7438 - val_f1_score: 0.7268 - lr: 5.0000e-04
# Epoch 50/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2172 - accuracy: 0.8423 - f1_score: 0.8411 - val_loss: 0.2761 - val_accuracy: 0.7222 - val_f1_score: 0.6093 - lr: 5.0000e-04
# Epoch 51/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2217 - accuracy: 0.8393 - f1_score: 0.8378 - val_loss: 0.2678 - val_accuracy: 0.7346 - val_f1_score: 0.5950 - lr: 5.0000e-04
# Epoch 52/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2296 - accuracy: 0.8353 - f1_score: 0.8320 - val_loss: 0.2812 - val_accuracy: 0.7191 - val_f1_score: 0.7211 - lr: 5.0000e-04
# Epoch 53/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2292 - accuracy: 0.8333 - f1_score: 0.8295 - val_loss: 0.2896 - val_accuracy: 0.7099 - val_f1_score: 0.7140 - lr: 5.0000e-04
# Epoch 54/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1974 - accuracy: 0.8573 - f1_score: 0.8551 - val_loss: 0.2732 - val_accuracy: 0.7253 - val_f1_score: 0.5974 - lr: 5.0000e-04
# Epoch 55/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2172 - accuracy: 0.8423 - f1_score: 0.8388 - val_loss: 0.2657 - val_accuracy: 0.7346 - val_f1_score: 0.6243 - lr: 5.0000e-04
# Epoch 56/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2023 - accuracy: 0.8533 - f1_score: 0.8488 - val_loss: 0.2680 - val_accuracy: 0.7315 - val_f1_score: 0.6152 - lr: 5.0000e-04
# Epoch 57/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2040 - accuracy: 0.8523 - f1_score: 0.8476 - val_loss: 0.2799 - val_accuracy: 0.7191 - val_f1_score: 0.5814 - lr: 5.0000e-04
# Epoch 58/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2232 - accuracy: 0.8383 - f1_score: 0.8383 - val_loss: 0.2812 - val_accuracy: 0.7191 - val_f1_score: 0.5704 - lr: 5.0000e-04
# Epoch 59/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2276 - accuracy: 0.8363 - f1_score: 0.8352 - val_loss: 0.3422 - val_accuracy: 0.6574 - val_f1_score: 0.5912 - lr: 5.0000e-04
# Epoch 60/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2385 - accuracy: 0.8273 - f1_score: 0.8238 - val_loss: 0.4740 - val_accuracy: 0.5247 - val_f1_score: 0.5508 - lr: 5.0000e-04
# Epoch 61/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2165 - accuracy: 0.8443 - f1_score: 0.8395 - val_loss: 0.4460 - val_accuracy: 0.5556 - val_f1_score: 0.5734 - lr: 5.0000e-04
# Epoch 62/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2149 - accuracy: 0.8423 - f1_score: 0.8407 - val_loss: 0.3975 - val_accuracy: 0.6019 - val_f1_score: 0.6473 - lr: 5.0000e-04
# Epoch 63/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.8433 - f1_score: 0.8416
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2170 - accuracy: 0.8433 - f1_score: 0.8416 - val_loss: 0.2916 - val_accuracy: 0.7099 - val_f1_score: 0.5994 - lr: 5.0000e-04
# Epoch 64/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2273 - accuracy: 0.8353 - f1_score: 0.8340 - val_loss: 0.2809 - val_accuracy: 0.7191 - val_f1_score: 0.6161 - lr: 2.5000e-04
# Epoch 65/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2022 - accuracy: 0.8543 - f1_score: 0.8555 - val_loss: 0.2810 - val_accuracy: 0.7191 - val_f1_score: 0.7196 - lr: 2.5000e-04
# Epoch 66/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1751 - accuracy: 0.8733 - f1_score: 0.8734 - val_loss: 0.2945 - val_accuracy: 0.7037 - val_f1_score: 0.7121 - lr: 2.5000e-04
# Epoch 67/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1852 - accuracy: 0.8643 - f1_score: 0.8622 - val_loss: 0.2655 - val_accuracy: 0.7346 - val_f1_score: 0.7362 - lr: 2.5000e-04
# Epoch 68/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1796 - accuracy: 0.8713 - f1_score: 0.8685 - val_loss: 0.2694 - val_accuracy: 0.7315 - val_f1_score: 0.7294 - lr: 2.5000e-04
# Epoch 69/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1867 - accuracy: 0.8643 - f1_score: 0.8626 - val_loss: 0.2620 - val_accuracy: 0.7377 - val_f1_score: 0.7213 - lr: 2.5000e-04
# Epoch 70/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1889 - accuracy: 0.8623 - f1_score: 0.8597 - val_loss: 0.2669 - val_accuracy: 0.7315 - val_f1_score: 0.7155 - lr: 2.5000e-04
# Epoch 71/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1979 - accuracy: 0.8563 - f1_score: 0.8553 - val_loss: 0.3019 - val_accuracy: 0.6975 - val_f1_score: 0.7074 - lr: 2.5000e-04
# Epoch 72/10000
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1904 - accuracy: 0.8613 - f1_score: 0.8587 - val_loss: 0.3472 - val_accuracy: 0.6543 - val_f1_score: 0.6797 - lr: 2.5000e-04
# Epoch 73/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2028 - accuracy: 0.8523 - f1_score: 0.8513 - val_loss: 0.3313 - val_accuracy: 0.6698 - val_f1_score: 0.6886 - lr: 2.5000e-04
# Epoch 74/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1963 - accuracy: 0.8573 - f1_score: 0.8547 - val_loss: 0.3169 - val_accuracy: 0.6852 - val_f1_score: 0.7003 - lr: 2.5000e-04
# Epoch 75/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2111 - accuracy: 0.8473 - f1_score: 0.8435 - val_loss: 0.3488 - val_accuracy: 0.6512 - val_f1_score: 0.6789 - lr: 2.5000e-04
# Epoch 76/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2066 - accuracy: 0.8503 - f1_score: 0.8468 - val_loss: 0.3365 - val_accuracy: 0.6636 - val_f1_score: 0.6867 - lr: 2.5000e-04
# Epoch 77/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2071 - accuracy: 0.8493 - f1_score: 0.8463 - val_loss: 0.3378 - val_accuracy: 0.6605 - val_f1_score: 0.6868 - lr: 2.5000e-04
# Epoch 78/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.2086 - accuracy: 0.8483 - f1_score: 0.8463 - val_loss: 0.3052 - val_accuracy: 0.6944 - val_f1_score: 0.6047 - lr: 2.5000e-04
# Epoch 79/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2015 - accuracy: 0.8523 - f1_score: 0.8504 - val_loss: 0.3138 - val_accuracy: 0.6852 - val_f1_score: 0.7028 - lr: 2.5000e-04
# Epoch 80/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1938 - accuracy: 0.8593 - f1_score: 0.8568 - val_loss: 0.3175 - val_accuracy: 0.6821 - val_f1_score: 0.7021 - lr: 2.5000e-04
# Epoch 81/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1850 - accuracy: 0.8653 - f1_score: 0.8653 - val_loss: 0.2969 - val_accuracy: 0.7068 - val_f1_score: 0.7156 - lr: 2.5000e-04
# Epoch 82/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1884 - accuracy: 0.8643 - f1_score: 0.8625 - val_loss: 0.3078 - val_accuracy: 0.6914 - val_f1_score: 0.6023 - lr: 2.5000e-04
# Epoch 83/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1956 - accuracy: 0.8573 - f1_score: 0.8560 - val_loss: 0.3118 - val_accuracy: 0.6883 - val_f1_score: 0.5968 - lr: 2.5000e-04
# Epoch 84/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1917 - accuracy: 0.8613 - f1_score: 0.8623 - val_loss: 0.3276 - val_accuracy: 0.6728 - val_f1_score: 0.5872 - lr: 2.5000e-04
# Epoch 85/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1867 - accuracy: 0.8653 - f1_score: 0.8631 - val_loss: 0.3389 - val_accuracy: 0.6605 - val_f1_score: 0.6466 - lr: 2.5000e-04
# Epoch 86/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1846 - accuracy: 0.8663 - f1_score: 0.8640 - val_loss: 0.3122 - val_accuracy: 0.6883 - val_f1_score: 0.6667 - lr: 2.5000e-04
# Epoch 87/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.8752 - f1_score: 0.8730
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1717 - accuracy: 0.8752 - f1_score: 0.8730 - val_loss: 0.3206 - val_accuracy: 0.6821 - val_f1_score: 0.6607 - lr: 2.5000e-04
# Epoch 88/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1915 - accuracy: 0.8623 - f1_score: 0.8621 - val_loss: 0.3164 - val_accuracy: 0.6852 - val_f1_score: 0.6628 - lr: 1.2500e-04
# Epoch 89/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1901 - accuracy: 0.8633 - f1_score: 0.8624 - val_loss: 0.3142 - val_accuracy: 0.6852 - val_f1_score: 0.6629 - lr: 1.2500e-04
# Epoch 90/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1844 - accuracy: 0.8663 - f1_score: 0.8643 - val_loss: 0.3086 - val_accuracy: 0.6914 - val_f1_score: 0.6573 - lr: 1.2500e-04
# Epoch 91/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1798 - accuracy: 0.8693 - f1_score: 0.8679 - val_loss: 0.2925 - val_accuracy: 0.7068 - val_f1_score: 0.6680 - lr: 1.2500e-04
# Epoch 92/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1717 - accuracy: 0.8752 - f1_score: 0.8741 - val_loss: 0.2918 - val_accuracy: 0.7068 - val_f1_score: 0.6702 - lr: 1.2500e-04
# Epoch 93/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1832 - accuracy: 0.8683 - f1_score: 0.8679 - val_loss: 0.2966 - val_accuracy: 0.7068 - val_f1_score: 0.6724 - lr: 1.2500e-04
# Epoch 94/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1886 - accuracy: 0.8623 - f1_score: 0.8603 - val_loss: 0.2894 - val_accuracy: 0.7130 - val_f1_score: 0.6767 - lr: 1.2500e-04
# Epoch 95/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1800 - accuracy: 0.8703 - f1_score: 0.8692 - val_loss: 0.2867 - val_accuracy: 0.7130 - val_f1_score: 0.6712 - lr: 1.2500e-04
# Epoch 96/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1721 - accuracy: 0.8752 - f1_score: 0.8741 - val_loss: 0.2841 - val_accuracy: 0.7160 - val_f1_score: 0.6084 - lr: 1.2500e-04
# Epoch 97/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1763 - accuracy: 0.8723 - f1_score: 0.8700 - val_loss: 0.2739 - val_accuracy: 0.7253 - val_f1_score: 0.6826 - lr: 1.2500e-04
# Epoch 98/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1762 - accuracy: 0.8733 - f1_score: 0.8721 - val_loss: 0.2747 - val_accuracy: 0.7222 - val_f1_score: 0.6141 - lr: 1.2500e-04
# Epoch 99/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1734 - accuracy: 0.8752 - f1_score: 0.8752 - val_loss: 0.2726 - val_accuracy: 0.7284 - val_f1_score: 0.6864 - lr: 1.2500e-04
# Epoch 100/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1720 - accuracy: 0.8743 - f1_score: 0.8726 - val_loss: 0.2896 - val_accuracy: 0.7099 - val_f1_score: 0.6743 - lr: 1.2500e-04
# Epoch 101/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1694 - accuracy: 0.8772 - f1_score: 0.8753 - val_loss: 0.2975 - val_accuracy: 0.7006 - val_f1_score: 0.7097 - lr: 1.2500e-04
# Epoch 102/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1706 - accuracy: 0.8762 - f1_score: 0.8721 - val_loss: 0.2837 - val_accuracy: 0.7160 - val_f1_score: 0.7214 - lr: 1.2500e-04
# Epoch 103/10000
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1666 - accuracy: 0.8812 - f1_score: 0.8800 - val_loss: 0.2752 - val_accuracy: 0.7253 - val_f1_score: 0.6318 - lr: 1.2500e-04
# Epoch 104/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1646 - accuracy: 0.8802 - f1_score: 0.8782 - val_loss: 0.2764 - val_accuracy: 0.7222 - val_f1_score: 0.7244 - lr: 1.2500e-04
# Epoch 105/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1649 - accuracy: 0.8802 - f1_score: 0.8783 - val_loss: 0.2885 - val_accuracy: 0.7099 - val_f1_score: 0.7153 - lr: 1.2500e-04
# Epoch 106/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1579 - accuracy: 0.8852 - f1_score: 0.8843 - val_loss: 0.2802 - val_accuracy: 0.7160 - val_f1_score: 0.7196 - lr: 1.2500e-04
# Epoch 107/10000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1552 - accuracy: 0.8873 - f1_score: 0.8862
# Epoch 107: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1608 - accuracy: 0.8832 - f1_score: 0.8821 - val_loss: 0.2796 - val_accuracy: 0.7160 - val_f1_score: 0.7192 - lr: 1.2500e-04
# Epoch 108/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1612 - accuracy: 0.8822 - f1_score: 0.8805 - val_loss: 0.2857 - val_accuracy: 0.7160 - val_f1_score: 0.7200 - lr: 6.2500e-05
# Epoch 109/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1606 - accuracy: 0.8832 - f1_score: 0.8819 - val_loss: 0.2970 - val_accuracy: 0.7068 - val_f1_score: 0.7134 - lr: 6.2500e-05
# Epoch 110/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1685 - accuracy: 0.8792 - f1_score: 0.8749 - val_loss: 0.2853 - val_accuracy: 0.7130 - val_f1_score: 0.6232 - lr: 6.2500e-05
# Epoch 111/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1601 - accuracy: 0.8832 - f1_score: 0.8813 - val_loss: 0.2867 - val_accuracy: 0.7130 - val_f1_score: 0.6255 - lr: 6.2500e-05
# Epoch 112/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1616 - accuracy: 0.8832 - f1_score: 0.8819 - val_loss: 0.2901 - val_accuracy: 0.7099 - val_f1_score: 0.6224 - lr: 6.2500e-05
# Epoch 113/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1616 - accuracy: 0.8832 - f1_score: 0.8818 - val_loss: 0.2868 - val_accuracy: 0.7130 - val_f1_score: 0.6212 - lr: 6.2500e-05
# Epoch 114/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1577 - accuracy: 0.8852 - f1_score: 0.8853 - val_loss: 0.2852 - val_accuracy: 0.7130 - val_f1_score: 0.6191 - lr: 6.2500e-05
# Epoch 115/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1662 - accuracy: 0.8772 - f1_score: 0.8758 - val_loss: 0.2968 - val_accuracy: 0.7037 - val_f1_score: 0.6191 - lr: 6.2500e-05
# Epoch 116/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1539 - accuracy: 0.8872 - f1_score: 0.8865 - val_loss: 0.2964 - val_accuracy: 0.7037 - val_f1_score: 0.6192 - lr: 6.2500e-05
# Epoch 117/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1623 - accuracy: 0.8822 - f1_score: 0.8809 - val_loss: 0.2989 - val_accuracy: 0.7006 - val_f1_score: 0.6162 - lr: 6.2500e-05
# Epoch 118/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1589 - accuracy: 0.8842 - f1_score: 0.8813 - val_loss: 0.2997 - val_accuracy: 0.7006 - val_f1_score: 0.6162 - lr: 6.2500e-05
# Epoch 119/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1639 - accuracy: 0.8812 - f1_score: 0.8803 - val_loss: 0.3050 - val_accuracy: 0.6944 - val_f1_score: 0.6117 - lr: 6.2500e-05
# Epoch 120/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1604 - accuracy: 0.8842 - f1_score: 0.8812 - val_loss: 0.3039 - val_accuracy: 0.6944 - val_f1_score: 0.6131 - lr: 6.2500e-05
# Epoch 121/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1606 - accuracy: 0.8842 - f1_score: 0.8802 - val_loss: 0.2903 - val_accuracy: 0.7099 - val_f1_score: 0.6188 - lr: 6.2500e-05
# Epoch 122/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1515 - accuracy: 0.8912 - f1_score: 0.8898 - val_loss: 0.2894 - val_accuracy: 0.7130 - val_f1_score: 0.6243 - lr: 6.2500e-05
# Epoch 123/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1471 - accuracy: 0.8932 - f1_score: 0.8907 - val_loss: 0.2889 - val_accuracy: 0.7099 - val_f1_score: 0.7151 - lr: 6.2500e-05
# Epoch 124/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1459 - accuracy: 0.8942 - f1_score: 0.8918 - val_loss: 0.2847 - val_accuracy: 0.7130 - val_f1_score: 0.6246 - lr: 6.2500e-05
# Epoch 125/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1547 - accuracy: 0.8882 - f1_score: 0.8870 - val_loss: 0.2859 - val_accuracy: 0.7130 - val_f1_score: 0.6212 - lr: 6.2500e-05
# Epoch 126/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1424 - accuracy: 0.8972 - f1_score: 0.8974 - val_loss: 0.2815 - val_accuracy: 0.7222 - val_f1_score: 0.6258 - lr: 6.2500e-05
# Epoch 127/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.8862 - f1_score: 0.8854
# Epoch 127: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1585 - accuracy: 0.8862 - f1_score: 0.8854 - val_loss: 0.2719 - val_accuracy: 0.7315 - val_f1_score: 0.6326 - lr: 6.2500e-05
# Epoch 128/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1461 - accuracy: 0.8952 - f1_score: 0.8948 - val_loss: 0.2714 - val_accuracy: 0.7315 - val_f1_score: 0.6326 - lr: 3.1250e-05
# Epoch 129/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1580 - accuracy: 0.8862 - f1_score: 0.8840 - val_loss: 0.2756 - val_accuracy: 0.7284 - val_f1_score: 0.6302 - lr: 3.1250e-05
# Epoch 130/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1440 - accuracy: 0.8962 - f1_score: 0.8961 - val_loss: 0.2832 - val_accuracy: 0.7160 - val_f1_score: 0.6202 - lr: 3.1250e-05
# Epoch 131/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1509 - accuracy: 0.8902 - f1_score: 0.8879 - val_loss: 0.2869 - val_accuracy: 0.7130 - val_f1_score: 0.6179 - lr: 3.1250e-05
# Epoch 132/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1423 - accuracy: 0.8972 - f1_score: 0.8972 - val_loss: 0.2886 - val_accuracy: 0.7130 - val_f1_score: 0.6188 - lr: 3.1250e-05
# Epoch 133/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1481 - accuracy: 0.8932 - f1_score: 0.8919 - val_loss: 0.2902 - val_accuracy: 0.7099 - val_f1_score: 0.6164 - lr: 3.1250e-05
# Epoch 134/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1405 - accuracy: 0.8982 - f1_score: 0.8940 - val_loss: 0.2885 - val_accuracy: 0.7130 - val_f1_score: 0.6188 - lr: 3.1250e-05
# Epoch 135/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1428 - accuracy: 0.8962 - f1_score: 0.8949 - val_loss: 0.2871 - val_accuracy: 0.7130 - val_f1_score: 0.6188 - lr: 3.1250e-05
# Epoch 136/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1418 - accuracy: 0.8982 - f1_score: 0.8981 - val_loss: 0.2843 - val_accuracy: 0.7160 - val_f1_score: 0.6211 - lr: 3.1250e-05
# Epoch 137/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1429 - accuracy: 0.8962 - f1_score: 0.8925 - val_loss: 0.2911 - val_accuracy: 0.7099 - val_f1_score: 0.6138 - lr: 3.1250e-05
# Epoch 138/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1464 - accuracy: 0.8942 - f1_score: 0.8936 - val_loss: 0.2888 - val_accuracy: 0.7099 - val_f1_score: 0.6138 - lr: 3.1250e-05
# Epoch 139/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1503 - accuracy: 0.8912 - f1_score: 0.8905 - val_loss: 0.2844 - val_accuracy: 0.7160 - val_f1_score: 0.6233 - lr: 3.1250e-05
# Epoch 140/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1392 - accuracy: 0.9002 - f1_score: 0.8981 - val_loss: 0.2899 - val_accuracy: 0.7099 - val_f1_score: 0.6156 - lr: 3.1250e-05
# Epoch 141/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1452 - accuracy: 0.8942 - f1_score: 0.8942 - val_loss: 0.2869 - val_accuracy: 0.7130 - val_f1_score: 0.6179 - lr: 3.1250e-05
# Epoch 142/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1431 - accuracy: 0.8962 - f1_score: 0.8960 - val_loss: 0.2910 - val_accuracy: 0.7068 - val_f1_score: 0.6134 - lr: 3.1250e-05
# Epoch 143/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1471 - accuracy: 0.8942 - f1_score: 0.8926 - val_loss: 0.2913 - val_accuracy: 0.7068 - val_f1_score: 0.6134 - lr: 3.1250e-05
# Epoch 144/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1429 - accuracy: 0.8972 - f1_score: 0.8953 - val_loss: 0.2931 - val_accuracy: 0.7068 - val_f1_score: 0.6134 - lr: 3.1250e-05
# Epoch 145/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1458 - accuracy: 0.8952 - f1_score: 0.8944 - val_loss: 0.2930 - val_accuracy: 0.7068 - val_f1_score: 0.6134 - lr: 3.1250e-05
# Epoch 146/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1334 - accuracy: 0.9032 - f1_score: 0.9018 - val_loss: 0.2945 - val_accuracy: 0.7037 - val_f1_score: 0.6112 - lr: 3.1250e-05
# Epoch 147/10000
# 16/16 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.8962 - f1_score: 0.8964
# Epoch 147: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1427 - accuracy: 0.8962 - f1_score: 0.8964 - val_loss: 0.2954 - val_accuracy: 0.7037 - val_f1_score: 0.6112 - lr: 3.1250e-05
# Epoch 148/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1485 - accuracy: 0.8932 - f1_score: 0.8909 - val_loss: 0.2978 - val_accuracy: 0.7006 - val_f1_score: 0.6089 - lr: 1.5625e-05
# Epoch 149/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1379 - accuracy: 0.8992 - f1_score: 0.8980 - val_loss: 0.2931 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 150/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1356 - accuracy: 0.9022 - f1_score: 0.9024 - val_loss: 0.2933 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 151/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1438 - accuracy: 0.8942 - f1_score: 0.8921 - val_loss: 0.2936 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 152/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1485 - accuracy: 0.8922 - f1_score: 0.8907 - val_loss: 0.2937 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 153/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1438 - accuracy: 0.8972 - f1_score: 0.8962 - val_loss: 0.2934 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 154/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1427 - accuracy: 0.8962 - f1_score: 0.8951 - val_loss: 0.2931 - val_accuracy: 0.7068 - val_f1_score: 0.6181 - lr: 1.5625e-05
# Epoch 155/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1412 - accuracy: 0.8992 - f1_score: 0.8988 - val_loss: 0.2895 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 156/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1407 - accuracy: 0.8982 - f1_score: 0.8945 - val_loss: 0.2881 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 157/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1443 - accuracy: 0.8952 - f1_score: 0.8934 - val_loss: 0.2886 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 158/10000
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1455 - accuracy: 0.8942 - f1_score: 0.8942 - val_loss: 0.2872 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 159/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1510 - accuracy: 0.8882 - f1_score: 0.8854 - val_loss: 0.2869 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 160/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1416 - accuracy: 0.8972 - f1_score: 0.8973 - val_loss: 0.2863 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 161/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1557 - accuracy: 0.8872 - f1_score: 0.8864 - val_loss: 0.2868 - val_accuracy: 0.7130 - val_f1_score: 0.6236 - lr: 1.5625e-05
# Epoch 162/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1541 - accuracy: 0.8902 - f1_score: 0.8855 - val_loss: 0.2892 - val_accuracy: 0.7099 - val_f1_score: 0.6171 - lr: 1.5625e-05
# Epoch 163/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1370 - accuracy: 0.9012 - f1_score: 0.9000 - val_loss: 0.2879 - val_accuracy: 0.7130 - val_f1_score: 0.6194 - lr: 1.5625e-05
# Epoch 164/10000
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1405 - accuracy: 0.8982 - f1_score: 0.8961 - val_loss: 0.2877 - val_accuracy: 0.7130 - val_f1_score: 0.6194 - lr: 1.5625e-05
# Epoch 165/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1334 - accuracy: 0.9042 - f1_score: 0.9025 - val_loss: 0.2930 - val_accuracy: 0.7068 - val_f1_score: 0.6117 - lr: 1.5625e-05
# Epoch 166/10000
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1497 - accuracy: 0.8932 - f1_score: 0.8899 - val_loss: 0.2881 - val_accuracy: 0.7130 - val_f1_score: 0.6161 - lr: 1.5625e-05
# Epoch 167/10000
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1430 - accuracy: 0.8969 - f1_score: 0.8953Restoring model weights from the end of the best epoch: 67.
#
# Epoch 167: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1383 - accuracy: 0.9002 - f1_score: 0.9004 - val_loss: 0.2921 - val_accuracy: 0.7099 - val_f1_score: 0.6140 - lr: 1.5625e-05
# Epoch 167: early stopping

# %%
# best_params = grid_result.best_params_
# print("Best parameters:", best_params)

# %% [markdown]
# Best parameters: {'model__filters1': 32, 'model__filters2': 96, 'model__filters3': 192, 'model__filters4': 256, 'model__filters5': 384}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__kernel': 3, 'model__unit': 64}

# %% [markdown]
# Best parameters: {'model__filters1': 64, 'model__filters2': 128, 'model__filters3': 256, 'model__learning_rate': 0.001, 'model__unit': 64}

# %%
# # Truy xuất mô hình tốt nhất
# best_estimator = grid_result.best_estimator_

# # Kiểm tra và truy xuất mô hình Keras từ best_estimator
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray())
# best_estimator.build_fn(64, 128, 256).summary()

# %%
# resnet50=build_model(32,96,192,256,384)
# resnet50.summary()

# %%
# best_estimator.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler],class_weight={0: 0.654690618762475, 1: 2.1161290322580646})

# %%
# history=best_estimator.history.history
# fig,axes=plt.subplots(1,2, figsize=(15,8))
# axes[0].plot(pd.DataFrame(history['val_accuracy']))
# axes[0].set_title('Training Process')

# axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
# axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
# axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
# axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
# axes[1].set_title('Training Process')
# axes[1].legend()

# plt.show()
# plt.savefig('train.png')

# %%
# resnet50.fit(dict_data[data_order][0],dict_data[data_order][1].toarray(),
#           validation_data=(dict_data[data_order][2],dict_data[data_order][3].toarray()),
#           batch_size=64,epochs= 10000, callbacks=[early_stopping,lr_scheduler,checkpoint_callback],class_weight={0: 0.654690618762475, 1: 5.1161290322580646})

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')

axes[1].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[1].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].legend()

plt.show()
plt.savefig('train.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lấy dữ liệu từ history
history = model.history.history

# Vẽ biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Biểu đồ accuracy của tập kiểm tra và tập validation
axes[0].plot(pd.DataFrame(history['accuracy']), label='Train Accuracy')
axes[0].plot(pd.DataFrame(history['val_accuracy']), label='Validation Accuracy')
axes[0].set_title('Training Process')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Biểu đồ loss của tập kiểm tra và tập validation
axes[1].plot(pd.DataFrame(history['loss']), label='Train Loss')
axes[1].plot(pd.DataFrame(history['val_loss']), label='Validation Loss')
axes[1].set_title('Training Process')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Hiển thị biểu đồ
plt.show()

# Lưu biểu đồ vào file
plt.savefig('train.png')

# %%
predictions = model.predict(dict_data[data_order][2])
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_list[data_order], predictions)
accuracy
# Out:
# 11/11 [==============================] - 0s 4ms/step
# 0.7345679012345679

# %%
x_test =dict_data[data_order][2]
y_test=y_list[data_order]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Đánh giá độ chính xác
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Hiển thị báo cáo phân loại
print("Classification Report:")
print(classification_report(y_test, predictions,labels=[1,0]))

# # Hiển thị ma trận nhầm lẫn
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred,labels=[1,0]))
# Out:
# Accuracy: 0.7345679012345679
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.50      0.69      0.58        85
#            0       0.87      0.75      0.81       239
#
#     accuracy                           0.73       324
#    macro avg       0.68      0.72      0.69       324
# weighted avg       0.77      0.73      0.75       324

# %%
# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_test, predictions,ax,name='model'):    
    # Tính toán FPR và TPR từ decision function
    fpr, tpr, _ = roc_curve(y_test, predictions)
    
    # Tính diện tích dưới đường cong ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Vẽ đường cong ROC
    ax.plot(fpr, tpr, lw=4, label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  # Đặt kích thước và độ dày cho nhãn trục x
    ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   # Đặt kích thước và độ dày cho nhãn trục y
    ax.set_title(f'ROC of {name}',fontsize=20, weight='bold')  # Đặt kích thước và độ dày cho tiêu đề
    ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'})  # Đặt kích thước và độ dày cho chú thích

fig, axes = plt.subplots(1, 1, figsize=(8, 8))

plot_roc_curve(y_test,predictions,axes)
# predictions

# %%
def check_result(prediction):
    prediction = (prediction > 0.5).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
solandung=0
hopdonggianlan=0
for indx in range(len(x_test)):
    y_predict = predictions
    #print(y_predict[0][0])
    Y_check = check_result(y_test.iloc[indx])
    print('True:', Y_check)
    print('Predicted:', check_result(y_predict[indx]))
    print("----------------------------")
    if Y_check==check_result(y_predict[indx]):
        solandung+=1
        if Y_check=='Y':
            hopdonggianlan+=1
# Out:
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: Y
# Predicted: Y
# ----------------------------
# True: N
# Predicted: N
# ----------------------------
# True: N
# Predicted: N
# ----------------------------

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# Số lần dự đoán đúng: 238 chiếm khoảng 73.4567901234568% tổng lần dự đoán
# Số hợp đồng gian lận trong lần kiểm tra: 59 chiếm khoảng 69.41176470588235% so với thực tế
